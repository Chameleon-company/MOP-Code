# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt 
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
path = '/content/drive/My Drive/DataSets/project _python/pm2.5.csv'
df_1 = pd.read_csv(path)

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120830 entries, 0 to 120829
# Data columns (total 15 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   120830 non-null  int64
#  1   id           120830 non-null  int64
#  2   site_id      120830 non-null  object
#  3   sensor_id    120830 non-null  object
#  4   value        120826 non-null  float64
#  5   local_time   120830 non-null  object
#  6   type         120830 non-null  object
#  7   units        120830 non-null  object
#  8   Date         120830 non-null  object
#  9   Time         120830 non-null  object
#  10  description  120830 non-null  object
#  11  last_data    120830 non-null  object
#  12  latitude     120830 non-null  float64
#  13  longitude    120830 non-null  float64
#  14  location     120830 non-null  object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 13.8+ MB

# %%
df_1['local_time']= pd.to_datetime(df_1['local_time'])

# %%
df_1['Month'] = df_1['local_time'].dt.month
df_1['Day'] = df_1['local_time'].dt.day

# %%
data_arc1045= df_1[df_1['site_id'].isin(['arc1045'])]

# %%
data_arc1045.Month.unique()
# Out:
# array([11, 12,  1,  2,  3,  4,  7,  5,  6,  8])

# %%
data_arc1045_nov= data_arc1045[data_arc1045['Month'].isin(['11'])]

# %%
data_arc1045_nov['value'].describe()
# Out:
# count    1467.000000
# mean        7.633674
# std         4.274765
# min         3.300000
# 25%         5.600000
# 50%         6.600000
# 75%         8.100000
# max        86.700000
# Name: value, dtype: float64

# %%
ax = sns.lineplot(x="local_time", y="value", hue="site_id",
                  err_style="bars", ci=68, data=data_arc1045_nov)

# %%
data_arc1045_dec= data_arc1045[data_arc1045['Month'].isin(['12'])]
data_arc1045_dec['value'].describe()
# Out:
# count    2914.000000
# mean       12.325738
# std        17.312923
# min         3.300000
# 25%         6.500000
# 50%         8.300000
# 75%        11.400000
# max       228.900000
# Name: value, dtype: float64

# %%
ax = sns.lineplot(x="local_time", y="value", hue="site_id",
                  err_style="bars", ci=68, data=data_arc1045_dec)

# %%
data_arc1045_jan= data_arc1045[data_arc1045['Month'].isin(['1'])]
data_arc1045_jan['value'].describe()
# Out:
# count    2917.000000
# mean       46.445081
# std       109.937423
# min         3.600000
# 25%         6.800000
# 50%         9.300000
# 75%        26.700000
# max       937.100000
# Name: value, dtype: float64

# %%
ax = sns.lineplot(x="local_time", y="value", hue="site_id",
                  err_style="bars", ci=68, data=data_arc1045_jan)

# %%
data_arc1045_feb= data_arc1045[data_arc1045['Month'].isin(['2'])]
data_arc1045_feb['value'].describe()
# Out:
# count    2769.000000
# mean       11.659986
# std        14.040659
# min         3.300000
# 25%         5.900000
# 50%         7.100000
# 75%        10.100000
# max        99.600000
# Name: value, dtype: float64

# %%
ax = sns.lineplot(x="local_time", y="value", hue="site_id",
                  err_style="bars", ci=68, data=data_arc1045_feb)

# %%
data_arc1045_march= data_arc1045[data_arc1045['Month'].isin(['3'])]
data_arc1045_march['value'].describe()
# Out:
# count    2972.000000
# mean        6.871703
# std         3.443282
# min         4.200000
# 25%         5.300000
# 50%         6.100000
# 75%         7.300000
# max        88.500000
# Name: value, dtype: float64

# %%
ax = sns.lineplot(x="local_time", y="value", hue="site_id",
                  err_style="bars", ci=68, data=data_arc1045_march)

# %%
data_arc1045_april= data_arc1045[data_arc1045['Month'].isin(['4'])]
data_arc1045_april['value'].describe()
# Out:
# count    2733.000000
# mean        7.683205
# std         8.672505
# min         4.000000
# 25%         5.200000
# 50%         6.300000
# 75%         8.100000
# max       296.600000
# Name: value, dtype: float64

# %%
ax = sns.lineplot(x="local_time", y="value", hue="site_id",
                  err_style="bars", ci=68, data=data_arc1045_april)

# %%
data_arc1045_may= data_arc1045[data_arc1045['Month'].isin(['5'])]
data_arc1045_may['value'].describe()
# Out:
# count    1831.000000
# mean        8.438995
# std         5.268426
# min         4.300000
# 25%         5.500000
# 50%         6.400000
# 75%         8.800000
# max        65.300000
# Name: value, dtype: float64

# %%
ax = sns.lineplot(x="local_time", y="value", hue="site_id",
                  err_style="bars", ci=68, data=data_arc1045_may)

# %%
data_arc1045_june= data_arc1045[data_arc1045['Month'].isin(['6'])]
data_arc1045_june['value'].describe()
# Out:
# count    2840.000000
# mean        9.945951
# std         6.448838
# min         4.000000
# 25%         5.900000
# 50%         7.600000
# 75%        11.900000
# max        73.100000
# Name: value, dtype: float64

# %%
ax = sns.lineplot(x="local_time", y="value", hue="site_id",
                  err_style="bars", ci=68, data=data_arc1045_june)

# %%
data_arc1045_july= data_arc1045[data_arc1045['Month'].isin(['7'])]
data_arc1045_july['value'].describe()
# Out:
# count    2941.000000
# mean        9.948759
# std         6.739602
# min         4.100000
# 25%         5.700000
# 50%         7.100000
# 75%        11.900000
# max        50.900000
# Name: value, dtype: float64

# %%
ax = sns.lineplot(x="local_time", y="value", hue="site_id",
                  err_style="bars", ci=68, data=data_arc1045_july)

# %%
data_arc1045_aug=data_arc1045[data_arc1045['Month'].isin(['8'])]
data_arc1045_aug['value'].describe()
# Out:
# count    457.000000
# mean       6.707877
# std        1.890855
# min        4.100000
# 25%        5.300000
# 50%        6.300000
# 75%        7.600000
# max       19.800000
# Name: value, dtype: float64

# %%
ax = sns.lineplot(x="local_time", y="value", hue="site_id",
                  err_style="bars", ci=68, data=data_arc1045_aug)
