# %%
#Import Statement
from datetime import date
import holidays
import pandas as pd
import tensorflow as tf
from math import *
import numpy as np
import matplotlib.pyplot as plt
import warnings
import io
import seaborn as sns
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from google.colab import files
warnings.filterwarnings("ignore")

import statsmodels.api as sm
from statsmodels.tsa.api import VAR
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Dropout
from keras.callbacks import EarlyStopping
from statsmodels.tsa.statespace.varmax import VARMAX

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-57742975-370c-4d55-a486-62b5694bcc2e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-57742975-370c-4d55-a486-62b5694bcc2e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dataset_for_prediction.csv to dataset_for_prediction.csv

# %%
#Fetch the dataset
dataset = pd.read_csv(io.BytesIO(uploaded['electricity_demand.csv']))
dataset.head()
# Out:
#        date      demand        RRP  ...  rainfall  school_day  holiday
# 0  1/1/2015   99635.030  25.633696  ...       0.0           N        Y
# 1  1/2/2015  129606.010  33.138988  ...       0.0           N        N
# 2  1/3/2015  142300.540  34.564855  ...       0.0           N        N
# 3  1/4/2015  104330.715  25.005560  ...       4.2           N        N
# 4  1/5/2015  118132.200  26.724176  ...       0.0           N        N
#
# [5 rows x 9 columns]

# %%
#Format the date column of the dataset
dataset['date'] = pd.to_datetime(dataset['date'], infer_datetime_format=True)

# %%
#Plot the electricity demand using date column
sns.set(rc={'figure.figsize':(11.7,8.27)})
dataset.set_index('date')['demand'].plot()

# %%
#Display information about the electricity demand dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2251 entries, 0 to 2250
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             2251 non-null   datetime64[ns]
#  1   demand           2251 non-null   float64
#  2   RRP              2251 non-null   float64
#  3   min_temperature  2251 non-null   float64
#  4   max_temperature  2251 non-null   float64
#  5   solar_exposure   2251 non-null   float64
#  6   rainfall         2251 non-null   float64
#  7   school_day       2251 non-null   object
#  8   holiday          2251 non-null   object
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 158.4+ KB

# %%
#Display the number of rows in dataset
dataset.count()
# Out:
# date               2251
# demand             2251
# RRP                2251
# min_temperature    2251
# max_temperature    2251
# solar_exposure     2251
# rainfall           2251
# school_day         2251
# holiday            2251
# dtype: int64

# %%
#Set the date column as index
dataset.set_index('date', inplace=True)

# %%
#Replace the school day and holiday with appropriate values
dataset['school_day'] = dataset['school_day'].replace(to_replace ="N", value = 0)
dataset['school_day'] = dataset['school_day'].replace(to_replace ="Y", value = 1)
dataset['holiday'] = dataset['holiday'].replace(to_replace ="N", value = 0)
dataset['holiday'] = dataset['holiday'].replace(to_replace ="Y", value = 1)

# %%
#Split the dataset to form training and testing set
training_set = dataset.iloc[:2191]
testing_set = dataset.iloc[2192:]

# %%
#Display the training and testing dataset
print("Training dataset: \n", training_set.tail())
print("\nTesting dataset: \n", testing_set.head())
# Out:
# Training dataset:
#                 demand        RRP  ...  school_day  holiday
# date                              ...
# 2020-12-26  88980.895  31.239583  ...           0        0
# 2020-12-27  96137.560   6.380417  ...           0        0
# 2020-12-28  85792.090   8.254583  ...           0        1
# 2020-12-29  90537.375  23.902917  ...           0        0
# 2020-12-30  93732.335  29.288958  ...           0        0
#
# [5 rows x 8 columns]
#
# Testing dataset:
#                  demand        RRP  ...  school_day  holiday
# date                               ...
# 2021-01-01   92926.685  18.296383  ...           0        1
# 2021-01-02   98995.065  21.890208  ...           0        0
# 2021-01-03   94371.480  19.487708  ...           0        0
# 2021-01-04   99640.535   4.791042  ...           0        0
# 2021-01-05  103840.455   7.464583  ...           0        0
#
# [5 rows x 8 columns]

# %%
#Display the shape of the training and testing dataset
print("Training dataset shape: ", training_set.shape)
print("Testing dataset shape: ", testing_set.shape)
# Out:
# Training dataset shape:  (2191, 8)
# Testing dataset shape:  (59, 8)

# %%
#Employ Information Criterion Akaike (AIC) as a model selection criterion
forecasting_model = VAR(training_set, freq='D')
results_aic = []
for p in range(1,30):
  results = forecasting_model.fit(p)
  results_aic.append(results.aic)

# %%
#Plot the AIC and order
sns.set()
plt.plot(list(np.arange(1,30,1)), results_aic)
plt.xlabel("Order")
plt.ylabel("AIC")
plt.show()

# %%
#Train the VAR model using order '15'
results = forecasting_model.fit(15)
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 07, May, 2021
# Time:                     07:43:06
# --------------------------------------------------------------------
# No. of Equations:         8.00000    BIC:                    25.2627
# Nobs:                     2176.00    HQIC:                   23.6583
# Log likelihood:          -48467.0    FPE:                7.47260e+09
# AIC:                      22.7336    Det(Omega_mle):     4.84680e+09
# --------------------------------------------------------------------
# Results for equation demand
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                   39744.058111      6199.673925            6.411           0.000
# L1.demand                   0.823539         0.024034           34.265           0.000
# L1.RRP                      3.703410         1.381443            2.681           0.007
# L1.min_temperature        -10.409487        80.139447           -0.130           0.897
# L1.max_temperature      -1084.536659       426.116659           -2.545           0.011
# L1.solar_exposure       -1098.786465       163.074289           -6.738           0.000
# L1.rainfall                52.298418        41.074986            1.273           0.203
# L1.school_day            2547.706993      1015.153847            2.510           0.012
# L1.holiday               4476.355768       960.408031            4.661           0.000
# L2.demand                  -0.269757         0.030244           -8.919           0.000
# L2.RRP                     -4.543914         1.416585           -3.208           0.001
# L2.min_temperature         99.880950        85.782905            1.164           0.244
# L2.max_temperature        -45.471540       527.415131           -0.086           0.931
# L2.solar_exposure        -166.754081       172.484209           -0.967           0.334
# L2.rainfall               -75.633148        41.609128           -1.818           0.069
# L2.school_day           -1884.573610      1408.356902           -1.338           0.181
# L2.holiday                335.057401       992.600244            0.338           0.736
# L3.demand                   0.088117         0.030877            2.854           0.004
# L3.RRP                      0.556305         1.418121            0.392           0.695
# L3.min_temperature         13.062764        85.877035            0.152           0.879
# L3.max_temperature       -908.925417       528.079193           -1.721           0.085
# L3.solar_exposure         109.130299       173.006341            0.631           0.528
# L3.rainfall               -83.305716        41.654521           -2.000           0.046
# L3.school_day             563.460787      1410.617812            0.399           0.690
# L3.holiday                765.208279       999.357397            0.766           0.444
# L4.demand                  -0.017862         0.030947           -0.577           0.564
# L4.RRP                     -2.051371         1.418965           -1.446           0.148
# L4.min_temperature         57.174376        85.859449            0.666           0.505
# L4.max_temperature        376.595967       530.349252            0.710           0.478
# L4.solar_exposure          97.878846       175.667177            0.557           0.577
# L4.rainfall                19.060930        41.727882            0.457           0.648
# L4.school_day            -942.832547      1410.266674           -0.669           0.504
# L4.holiday               -378.051850      1000.991090           -0.378           0.706
# L5.demand                  -0.029541         0.030898           -0.956           0.339
# L5.RRP                      1.593108         1.420946            1.121           0.262
# L5.min_temperature         84.319705        85.733769            0.984           0.325
# L5.max_temperature       -689.988408       529.551942           -1.303           0.193
# L5.solar_exposure        -131.556633       175.067391           -0.751           0.452
# L5.rainfall               -16.385422        41.709149           -0.393           0.694
# L5.school_day             382.608514      1407.873530            0.272           0.786
# L5.holiday               -601.247443      1005.194024           -0.598           0.550
# L6.demand                   0.048690         0.030829            1.579           0.114
# L6.RRP                      0.935717         1.417410            0.660           0.509
# L6.min_temperature        -32.289787        85.865078           -0.376           0.707
# L6.max_temperature       -615.312569       531.085848           -1.159           0.247
# L6.solar_exposure           3.816319       175.321319            0.022           0.983
# L6.rainfall              -169.952385        41.655007           -4.080           0.000
# L6.school_day             702.968441      1407.812127            0.499           0.618
# L6.holiday              -1587.947711      1009.626968           -1.573           0.116
# L7.demand                   0.342532         0.030865           11.098           0.000
# L7.RRP                     -7.443187         1.417123           -5.252           0.000
# L7.min_temperature        163.233156        85.655095            1.906           0.057
# L7.max_temperature      -1526.589235       530.487782           -2.878           0.004
# L7.solar_exposure        -136.068071       175.470705           -0.775           0.438
# L7.rainfall                 9.899895        41.966930            0.236           0.814
# L7.school_day            1111.315298      1407.654566            0.789           0.430
# L7.holiday               4928.909906      1011.070985            4.875           0.000
# L8.demand                  -0.250262         0.031449           -7.958           0.000
# L8.RRP                     -0.321882         1.433208           -0.225           0.822
# L8.min_temperature       -131.678996        85.796195           -1.535           0.125
# L8.max_temperature        633.520226       531.119199            1.193           0.233
# L8.solar_exposure          32.114789       177.265671            0.181           0.856
# L8.rainfall               -32.260716        41.638475           -0.775           0.438
# L8.school_day            -501.912025      1406.812419           -0.357           0.721
# L8.holiday              -3418.439117      1011.614639           -3.379           0.001
# L9.demand                   0.028367         0.030793            0.921           0.357
# L9.RRP                      5.103150         1.431878            3.564           0.000
# L9.min_temperature        110.525317        85.877795            1.287           0.198
# L9.max_temperature        312.137029       530.760489            0.588           0.556
# L9.solar_exposure         339.697149       177.059184            1.919           0.055
# L9.rainfall               -41.305632        41.412908           -0.997           0.319
# L9.school_day            -182.133691      1406.867193           -0.129           0.897
# L9.holiday                217.876226      1006.723431            0.216           0.829
# L10.demand                  0.016937         0.030736            0.551           0.582
# L10.RRP                     2.249383         1.432085            1.571           0.116
# L10.min_temperature        57.321384        85.830952            0.668           0.504
# L10.max_temperature        30.391897       530.537256            0.057           0.954
# L10.solar_exposure        494.359182       176.271176            2.805           0.005
# L10.rainfall               71.515030        41.448626            1.725           0.084
# L10.school_day          -2284.069716      1404.203345           -1.627           0.104
# L10.holiday              1394.037881      1003.173158            1.390           0.165
# L11.demand                 -0.012967         0.030795           -0.421           0.674
# L11.RRP                    -3.385227         1.430615           -2.366           0.018
# L11.min_temperature        -1.923271        85.882537           -0.022           0.982
# L11.max_temperature      -187.720380       530.359914           -0.354           0.723
# L11.solar_exposure       -426.789494       176.243665           -2.422           0.015
# L11.rainfall              -66.288076        41.632756           -1.592           0.111
# L11.school_day            818.952910      1403.180649            0.584           0.559
# L11.holiday              -607.005751      1000.678413           -0.607           0.544
# L12.demand                 -0.032290         0.030870           -1.046           0.296
# L12.RRP                    -0.054432         1.430818           -0.038           0.970
# L12.min_temperature       204.704592        85.876236            2.384           0.017
# L12.max_temperature       -67.817478       530.298677           -0.128           0.898
# L12.solar_exposure        245.106942       176.320639            1.390           0.164
# L12.rainfall              -46.787608        41.680121           -1.123           0.262
# L12.school_day            440.285563      1409.540295            0.312           0.755
# L12.holiday               942.306438       998.838647            0.943           0.345
# L13.demand                  0.047051         0.030749            1.530           0.126
# L13.RRP                     2.813002         1.430310            1.967           0.049
# L13.min_temperature       114.716222        85.904817            1.335           0.182
# L13.max_temperature     -1709.195110       529.662241           -3.227           0.001
# L13.solar_exposure        -81.997572       176.249382           -0.465           0.642
# L13.rainfall                5.135817        41.719126            0.123           0.902
# L13.school_day           1289.659559      1417.577086            0.910           0.363
# L13.holiday               876.299295       997.734412            0.878           0.380
# L14.demand                  0.246655         0.029799            8.277           0.000
# L14.RRP                    -1.144268         1.423671           -0.804           0.422
# L14.min_temperature       -31.249040        85.651729           -0.365           0.715
# L14.max_temperature     -1465.155446       531.416346           -2.757           0.006
# L14.solar_exposure         70.799476       176.107530            0.402           0.688
# L14.rainfall              -12.368644        41.246342           -0.300           0.764
# L14.school_day           -697.368417      1416.264883           -0.492           0.622
# L14.holiday              4300.013663       989.507790            4.346           0.000
# L15.demand                 -0.179813         0.023435           -7.673           0.000
# L15.RRP                    -3.303526         1.387802           -2.380           0.017
# L15.min_temperature        60.614818        67.454703            0.899           0.369
# L15.max_temperature       312.010186       501.362199            0.622           0.534
# L15.solar_exposure        116.683746       168.955270            0.691           0.490
# L15.rainfall              -13.199166        39.413696           -0.335           0.738
# L15.school_day           -768.026256      1024.752005           -0.749           0.454
# L15.holiday             -3012.539920       958.434027           -3.143           0.002
# ======================================================================================
#
# Results for equation RRP
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                     104.559102       102.796927            1.017           0.309
# L1.demand                   0.001647         0.000399            4.134           0.000
# L1.RRP                      0.235049         0.022906           10.262           0.000
# L1.min_temperature         -0.209474         1.328794           -0.158           0.875
# L1.max_temperature         -4.773595         7.065450           -0.676           0.499
# L1.solar_exposure          -4.088868         2.703938           -1.512           0.130
# L1.rainfall                -0.050448         0.681065           -0.074           0.941
# L1.school_day              32.278255        16.832288            1.918           0.055
# L1.holiday                 10.086628        15.924546            0.633           0.526
# L2.demand                  -0.000461         0.000501           -0.919           0.358
# L2.RRP                     -0.003035         0.023488           -0.129           0.897
# L2.min_temperature          0.195710         1.422368            0.138           0.891
# L2.max_temperature          2.130815         8.745082            0.244           0.807
# L2.solar_exposure          -0.568484         2.859964           -0.199           0.842
# L2.rainfall                -0.324416         0.689922           -0.470           0.638
# L2.school_day             -49.889070        23.351996           -2.136           0.033
# L2.holiday                -16.333395        16.458326           -0.992           0.321
# L3.demand                  -0.000519         0.000512           -1.014           0.310
# L3.RRP                      0.035792         0.023514            1.522           0.128
# L3.min_temperature          1.462390         1.423929            1.027           0.304
# L3.max_temperature        -10.524084         8.756092           -1.202           0.229
# L3.solar_exposure          -0.853455         2.868622           -0.298           0.766
# L3.rainfall                -0.412885         0.690675           -0.598           0.550
# L3.school_day              16.469960        23.389484            0.704           0.481
# L3.holiday                -23.802796        16.570367           -1.436           0.151
# L4.demand                   0.000640         0.000513            1.248           0.212
# L4.RRP                      0.038446         0.023528            1.634           0.102
# L4.min_temperature         -0.733291         1.423637           -0.515           0.606
# L4.max_temperature         -5.993569         8.793732           -0.682           0.496
# L4.solar_exposure          -2.068789         2.912741           -0.710           0.478
# L4.rainfall                 0.194513         0.691891            0.281           0.779
# L4.school_day             -10.579079        23.383662           -0.452           0.651
# L4.holiday                 33.686637        16.597455            2.030           0.042
# L5.demand                  -0.001120         0.000512           -2.187           0.029
# L5.RRP                      0.035523         0.023561            1.508           0.132
# L5.min_temperature         -1.329560         1.421553           -0.935           0.350
# L5.max_temperature          4.845485         8.780512            0.552           0.581
# L5.solar_exposure          -1.761360         2.902796           -0.607           0.544
# L5.rainfall                -0.555618         0.691580           -0.803           0.422
# L5.school_day               3.651216        23.343981            0.156           0.876
# L5.holiday                  6.413708        16.667144            0.385           0.700
# L6.demand                   0.000033         0.000511            0.064           0.949
# L6.RRP                      0.028422         0.023502            1.209           0.227
# L6.min_temperature          0.895827         1.423731            0.629           0.529
# L6.max_temperature          8.337854         8.805946            0.947           0.344
# L6.solar_exposure           7.620069         2.907007            2.621           0.009
# L6.rainfall                -0.989803         0.690683           -1.433           0.152
# L6.school_day               5.863754        23.342963            0.251           0.802
# L6.holiday                -31.276578        16.740647           -1.868           0.062
# L7.demand                   0.001415         0.000512            2.764           0.006
# L7.RRP                     -0.009017         0.023497           -0.384           0.701
# L7.min_temperature          0.829186         1.420249            0.584           0.559
# L7.max_temperature         -1.038171         8.796029           -0.118           0.906
# L7.solar_exposure           6.187152         2.909484            2.127           0.033
# L7.rainfall                 0.709946         0.695855            1.020           0.308
# L7.school_day               5.466678        23.340351            0.234           0.815
# L7.holiday                 18.901394        16.764590            1.127           0.260
# L8.demand                  -0.001219         0.000521           -2.338           0.019
# L8.RRP                      0.010241         0.023764            0.431           0.667
# L8.min_temperature         -0.606445         1.422589           -0.426           0.670
# L8.max_temperature         -6.549355         8.806499           -0.744           0.457
# L8.solar_exposure           0.743087         2.939246            0.253           0.800
# L8.rainfall                 1.340009         0.690408            1.941           0.052
# L8.school_day             -21.868982        23.326387           -0.938           0.348
# L8.holiday                -11.412008        16.773604           -0.680           0.496
# L9.demand                   0.000098         0.000511            0.191           0.848
# L9.RRP                      0.051858         0.023742            2.184           0.029
# L9.min_temperature          0.608549         1.423942            0.427           0.669
# L9.max_temperature         10.863224         8.800551            1.234           0.217
# L9.solar_exposure           0.084192         2.935822            0.029           0.977
# L9.rainfall                -0.012708         0.686668           -0.019           0.985
# L9.school_day               4.631675        23.327295            0.199           0.843
# L9.holiday                 -5.937447        16.692503           -0.356           0.722
# L10.demand                  0.001366         0.000510            2.681           0.007
# L10.RRP                     0.015775         0.023745            0.664           0.506
# L10.min_temperature         2.077840         1.423165            1.460           0.144
# L10.max_temperature       -10.082468         8.796850           -1.146           0.252
# L10.solar_exposure         -4.573269         2.922756           -1.565           0.118
# L10.rainfall                3.024150         0.687261            4.400           0.000
# L10.school_day             -0.980356        23.283126           -0.042           0.966
# L10.holiday                 0.755292        16.633636            0.045           0.964
# L11.demand                 -0.001814         0.000511           -3.554           0.000
# L11.RRP                     0.008698         0.023721            0.367           0.714
# L11.min_temperature        -1.272380         1.424020           -0.894           0.372
# L11.max_temperature         2.084895         8.793909            0.237           0.813
# L11.solar_exposure         -3.444525         2.922300           -1.179           0.239
# L11.rainfall               -1.773431         0.690314           -2.569           0.010
# L11.school_day              2.916022        23.266169            0.125           0.900
# L11.holiday               -42.701811        16.592270           -2.574           0.010
# L12.demand                  0.000951         0.000512            1.857           0.063
# L12.RRP                     0.026254         0.023724            1.107           0.268
# L12.min_temperature         0.968248         1.423916            0.680           0.497
# L12.max_temperature        -5.215443         8.792894           -0.593           0.553
# L12.solar_exposure         -2.801190         2.923576           -0.958           0.338
# L12.rainfall               -0.414790         0.691099           -0.600           0.548
# L12.school_day             12.478149        23.371618            0.534           0.593
# L12.holiday                22.767289        16.561765            1.375           0.169
# L13.demand                 -0.000092         0.000510           -0.179           0.858
# L13.RRP                     0.026806         0.023716            1.130           0.258
# L13.min_temperature        -1.351429         1.424390           -0.949           0.343
# L13.max_temperature         9.985374         8.782341            1.137           0.256
# L13.solar_exposure          0.016111         2.922395            0.006           0.996
# L13.rainfall                0.193078         0.691746            0.279           0.780
# L13.school_day            -10.888109        23.504876           -0.463           0.643
# L13.holiday                -6.227276        16.543456           -0.376           0.707
# L14.demand                 -0.000663         0.000494           -1.342           0.180
# L14.RRP                     0.021386         0.023606            0.906           0.365
# L14.min_temperature         0.258271         1.420193            0.182           0.856
# L14.max_temperature        -4.235684         8.811426           -0.481           0.631
# L14.solar_exposure         -0.485952         2.920043           -0.166           0.868
# L14.rainfall               -0.239177         0.683906           -0.350           0.727
# L14.school_day             -4.501629        23.483119           -0.192           0.848
# L14.holiday               -10.864442        16.407050           -0.662           0.508
# L15.demand                 -0.000479         0.000389           -1.231           0.218
# L15.RRP                     0.037639         0.023011            1.636           0.102
# L15.min_temperature         1.024957         1.118468            0.916           0.359
# L15.max_temperature        -3.608894         8.313097           -0.434           0.664
# L15.solar_exposure         -0.955550         2.801451           -0.341           0.733
# L15.rainfall                0.405996         0.653519            0.621           0.534
# L15.school_day              3.909712        16.991435            0.230           0.818
# L15.holiday               -12.352212        15.891815           -0.777           0.437
# ======================================================================================
#
# Results for equation min_temperature
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                     -12.070904         1.780954           -6.778           0.000
# L1.demand                   0.000004         0.000007            0.545           0.586
# L1.RRP                     -0.000037         0.000397           -0.092           0.927
# L1.min_temperature          0.319725         0.023021           13.888           0.000
# L1.max_temperature          3.398746         0.122409           27.766           0.000
# L1.solar_exposure          -0.094721         0.046846           -2.022           0.043
# L1.rainfall                 0.009949         0.011799            0.843           0.399
# L1.school_day              -0.425114         0.291619           -1.458           0.145
# L1.holiday                  0.097126         0.275892            0.352           0.725
# L2.demand                   0.000018         0.000009            2.045           0.041
# L2.RRP                     -0.000554         0.000407           -1.360           0.174
# L2.min_temperature         -0.025223         0.024642           -1.024           0.306
# L2.max_temperature         -0.468595         0.151508           -3.093           0.002
# L2.solar_exposure          -0.009210         0.049549           -0.186           0.853
# L2.rainfall                -0.004270         0.011953           -0.357           0.721
# L2.school_day               0.852839         0.404573            2.108           0.035
# L2.holiday                  0.376155         0.285140            1.319           0.187
# L3.demand                  -0.000015         0.000009           -1.732           0.083
# L3.RRP                      0.000010         0.000407            0.024           0.981
# L3.min_temperature          0.040457         0.024670            1.640           0.101
# L3.max_temperature          0.194943         0.151699            1.285           0.199
# L3.solar_exposure          -0.033197         0.049699           -0.668           0.504
# L3.rainfall                -0.003442         0.011966           -0.288           0.774
# L3.school_day              -0.395172         0.405222           -0.975           0.329
# L3.holiday                  0.044448         0.287081            0.155           0.877
# L4.demand                   0.000010         0.000009            1.098           0.272
# L4.RRP                     -0.000373         0.000408           -0.915           0.360
# L4.min_temperature          0.000325         0.024664            0.013           0.989
# L4.max_temperature          0.112588         0.152351            0.739           0.460
# L4.solar_exposure           0.016557         0.050463            0.328           0.743
# L4.rainfall                 0.010441         0.011987            0.871           0.384
# L4.school_day              -0.110362         0.405121           -0.272           0.785
# L4.holiday                 -0.034671         0.287550           -0.121           0.904
# L5.demand                  -0.000003         0.000009           -0.393           0.694
# L5.RRP                     -0.000462         0.000408           -1.131           0.258
# L5.min_temperature          0.029686         0.024628            1.205           0.228
# L5.max_temperature          0.030492         0.152122            0.200           0.841
# L5.solar_exposure          -0.062525         0.050291           -1.243           0.214
# L5.rainfall                -0.007342         0.011982           -0.613           0.540
# L5.school_day              -0.119247         0.404434           -0.295           0.768
# L5.holiday                 -0.094321         0.288758           -0.327           0.744
# L6.demand                   0.000006         0.000009            0.643           0.520
# L6.RRP                     -0.000392         0.000407           -0.963           0.335
# L6.min_temperature          0.001202         0.024666            0.049           0.961
# L6.max_temperature          0.069612         0.152563            0.456           0.648
# L6.solar_exposure          -0.024081         0.050364           -0.478           0.633
# L6.rainfall                 0.016026         0.011966            1.339           0.180
# L6.school_day               0.205376         0.404416            0.508           0.612
# L6.holiday                  0.054518         0.290031            0.188           0.851
# L7.demand                   0.000005         0.000009            0.599           0.549
# L7.RRP                     -0.000310         0.000407           -0.761           0.447
# L7.min_temperature          0.016473         0.024606            0.669           0.503
# L7.max_temperature          0.020561         0.152391            0.135           0.893
# L7.solar_exposure          -0.007770         0.050407           -0.154           0.877
# L7.rainfall                 0.005650         0.012056            0.469           0.639
# L7.school_day               0.364232         0.404371            0.901           0.368
# L7.holiday                  0.017963         0.290446            0.062           0.951
# L8.demand                  -0.000003         0.000009           -0.287           0.774
# L8.RRP                     -0.000055         0.000412           -0.133           0.894
# L8.min_temperature         -0.018355         0.024646           -0.745           0.456
# L8.max_temperature          0.143259         0.152572            0.939           0.348
# L8.solar_exposure           0.053840         0.050922            1.057           0.290
# L8.rainfall                 0.003775         0.011961            0.316           0.752
# L8.school_day               0.143549         0.404129            0.355           0.722
# L8.holiday                  0.202647         0.290602            0.697           0.486
# L9.demand                  -0.000009         0.000009           -0.996           0.319
# L9.RRP                      0.000374         0.000411            0.909           0.363
# L9.min_temperature          0.047560         0.024670            1.928           0.054
# L9.max_temperature          0.028814         0.152469            0.189           0.850
# L9.solar_exposure           0.023949         0.050863            0.471           0.638
# L9.rainfall                -0.002456         0.011897           -0.206           0.836
# L9.school_day              -0.919715         0.404145           -2.276           0.023
# L9.holiday                  0.275770         0.289197            0.954           0.340
# L10.demand                  0.000007         0.000009            0.752           0.452
# L10.RRP                     0.000153         0.000411            0.371           0.711
# L10.min_temperature         0.010222         0.024656            0.415           0.678
# L10.max_temperature         0.107030         0.152405            0.702           0.483
# L10.solar_exposure          0.020571         0.050637            0.406           0.685
# L10.rainfall                0.009585         0.011907            0.805           0.421
# L10.school_day              0.245372         0.403380            0.608           0.543
# L10.holiday                -0.161044         0.288177           -0.559           0.576
# L11.demand                  0.000004         0.000009            0.410           0.682
# L11.RRP                     0.000180         0.000411            0.439           0.661
# L11.min_temperature         0.036597         0.024671            1.483           0.138
# L11.max_temperature        -0.186495         0.152354           -1.224           0.221
# L11.solar_exposure          0.020228         0.050629            0.400           0.689
# L11.rainfall                0.010846         0.011960            0.907           0.364
# L11.school_day             -0.056052         0.403086           -0.139           0.889
# L11.holiday                -0.329627         0.287461           -1.147           0.252
# L12.demand                 -0.000010         0.000009           -1.127           0.260
# L12.RRP                     0.000096         0.000411            0.233           0.816
# L12.min_temperature         0.005001         0.024669            0.203           0.839
# L12.max_temperature         0.135140         0.152337            0.887           0.375
# L12.solar_exposure         -0.007905         0.050651           -0.156           0.876
# L12.rainfall               -0.007984         0.011973           -0.667           0.505
# L12.school_day              0.259919         0.404913            0.642           0.521
# L12.holiday                 0.606158         0.286932            2.113           0.035
# L13.demand                  0.000006         0.000009            0.641           0.521
# L13.RRP                     0.000394         0.000411            0.958           0.338
# L13.min_temperature         0.001032         0.024678            0.042           0.967
# L13.max_temperature        -0.095961         0.152154           -0.631           0.528
# L13.solar_exposure          0.057422         0.050630            1.134           0.257
# L13.rainfall                0.024087         0.011984            2.010           0.044
# L13.school_day             -0.148277         0.407221           -0.364           0.716
# L13.holiday                 0.041945         0.286615            0.146           0.884
# L14.demand                 -0.000005         0.000009           -0.630           0.529
# L14.RRP                    -0.000027         0.000409           -0.067           0.947
# L14.min_temperature        -0.021052         0.024605           -0.856           0.392
# L14.max_temperature         0.088608         0.152658            0.580           0.562
# L14.solar_exposure          0.036934         0.050590            0.730           0.465
# L14.rainfall                0.011385         0.011849            0.961           0.337
# L14.school_day             -0.127664         0.406844           -0.314           0.754
# L14.holiday                 0.493669         0.284252            1.737           0.082
# L15.demand                  0.000007         0.000007            0.990           0.322
# L15.RRP                    -0.000187         0.000399           -0.469           0.639
# L15.min_temperature         0.020708         0.019377            1.069           0.285
# L15.max_temperature         0.009009         0.144024            0.063           0.950
# L15.solar_exposure         -0.032210         0.048535           -0.664           0.507
# L15.rainfall               -0.009708         0.011322           -0.857           0.391
# L15.school_day              0.126023         0.294376            0.428           0.669
# L15.holiday                -0.422639         0.275325           -1.535           0.125
# ======================================================================================
#
# Results for equation max_temperature
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       1.723306         0.353639            4.873           0.000
# L1.demand                  -0.000001         0.000001           -0.548           0.584
# L1.RRP                      0.000172         0.000079            2.179           0.029
# L1.min_temperature         -0.015161         0.004571           -3.317           0.001
# L1.max_temperature          0.468695         0.024306           19.283           0.000
# L1.solar_exposure          -0.053069         0.009302           -5.705           0.000
# L1.rainfall                -0.009379         0.002343           -4.003           0.000
# L1.school_day              -0.024302         0.057906           -0.420           0.675
# L1.holiday                 -0.110970         0.054783           -2.026           0.043
# L2.demand                  -0.000001         0.000002           -0.396           0.692
# L2.RRP                     -0.000089         0.000081           -1.106           0.269
# L2.min_temperature          0.012556         0.004893            2.566           0.010
# L2.max_temperature         -0.033479         0.030085           -1.113           0.266
# L2.solar_exposure          -0.029322         0.009839           -2.980           0.003
# L2.rainfall                -0.007620         0.002373           -3.210           0.001
# L2.school_day               0.007899         0.080335            0.098           0.922
# L2.holiday                  0.105922         0.056619            1.871           0.061
# L3.demand                  -0.000003         0.000002           -1.701           0.089
# L3.RRP                      0.000053         0.000081            0.658           0.511
# L3.min_temperature          0.002726         0.004899            0.557           0.578
# L3.max_temperature          0.037330         0.030122            1.239           0.215
# L3.solar_exposure          -0.001237         0.009869           -0.125           0.900
# L3.rainfall                -0.002570         0.002376           -1.081           0.279
# L3.school_day               0.062638         0.080464            0.778           0.436
# L3.holiday                 -0.038419         0.057005           -0.674           0.500
# L4.demand                   0.000003         0.000002            1.568           0.117
# L4.RRP                      0.000031         0.000081            0.378           0.706
# L4.min_temperature          0.003047         0.004898            0.622           0.534
# L4.max_temperature         -0.003204         0.030252           -0.106           0.916
# L4.solar_exposure           0.012805         0.010020            1.278           0.201
# L4.rainfall                 0.003590         0.002380            1.508           0.131
# L4.school_day              -0.037556         0.080444           -0.467           0.641
# L4.holiday                 -0.028940         0.057098           -0.507           0.612
# L5.demand                  -0.000004         0.000002           -2.019           0.043
# L5.RRP                     -0.000051         0.000081           -0.635           0.526
# L5.min_temperature          0.002605         0.004890            0.533           0.594
# L5.max_temperature          0.047372         0.030206            1.568           0.117
# L5.solar_exposure          -0.025201         0.009986           -2.524           0.012
# L5.rainfall                -0.002573         0.002379           -1.082           0.279
# L5.school_day              -0.038964         0.080307           -0.485           0.628
# L5.holiday                  0.002061         0.057338            0.036           0.971
# L6.demand                   0.000002         0.000002            0.956           0.339
# L6.RRP                      0.000080         0.000081            0.984           0.325
# L6.min_temperature          0.006155         0.004898            1.257           0.209
# L6.max_temperature         -0.000028         0.030294           -0.001           0.999
# L6.solar_exposure          -0.008261         0.010001           -0.826           0.409
# L6.rainfall                 0.000750         0.002376            0.316           0.752
# L6.school_day               0.048270         0.080304            0.601           0.548
# L6.holiday                  0.020554         0.057591            0.357           0.721
# L7.demand                   0.000000         0.000002            0.223           0.823
# L7.RRP                     -0.000192         0.000081           -2.372           0.018
# L7.min_temperature          0.001170         0.004886            0.239           0.811
# L7.max_temperature          0.015701         0.030260            0.519           0.604
# L7.solar_exposure          -0.008705         0.010009           -0.870           0.384
# L7.rainfall                 0.000210         0.002394            0.088           0.930
# L7.school_day               0.003828         0.080295            0.048           0.962
# L7.holiday                 -0.082328         0.057673           -1.428           0.153
# L8.demand                  -0.000001         0.000002           -0.745           0.456
# L8.RRP                      0.000074         0.000082            0.902           0.367
# L8.min_temperature          0.000651         0.004894            0.133           0.894
# L8.max_temperature          0.026031         0.030296            0.859           0.390
# L8.solar_exposure           0.011109         0.010112            1.099           0.272
# L8.rainfall                -0.004024         0.002375           -1.694           0.090
# L8.school_day               0.048628         0.080247            0.606           0.545
# L8.holiday                 -0.041920         0.057704           -0.726           0.468
# L9.demand                  -0.000000         0.000002           -0.063           0.950
# L9.RRP                      0.000116         0.000082            1.423           0.155
# L9.min_temperature          0.004042         0.004899            0.825           0.409
# L9.max_temperature          0.045599         0.030275            1.506           0.132
# L9.solar_exposure           0.019175         0.010100            1.899           0.058
# L9.rainfall                -0.000194         0.002362           -0.082           0.934
# L9.school_day              -0.024956         0.080250           -0.311           0.756
# L9.holiday                 -0.000296         0.057425           -0.005           0.996
# L10.demand                 -0.000000         0.000002           -0.263           0.792
# L10.RRP                     0.000091         0.000082            1.109           0.267
# L10.min_temperature         0.000444         0.004896            0.091           0.928
# L10.max_temperature        -0.002980         0.030263           -0.098           0.922
# L10.solar_exposure         -0.005523         0.010055           -0.549           0.583
# L10.rainfall                0.002012         0.002364            0.851           0.395
# L10.school_day             -0.140240         0.080098           -1.751           0.080
# L10.holiday                 0.012792         0.057223            0.224           0.823
# L11.demand                 -0.000001         0.000002           -0.443           0.658
# L11.RRP                    -0.000144         0.000082           -1.760           0.078
# L11.min_temperature         0.001806         0.004899            0.369           0.712
# L11.max_temperature         0.064342         0.030253            2.127           0.033
# L11.solar_exposure         -0.007568         0.010053           -0.753           0.452
# L11.rainfall                0.000928         0.002375            0.391           0.696
# L11.school_day              0.031299         0.080040            0.391           0.696
# L11.holiday                -0.094424         0.057080           -1.654           0.098
# L12.demand                  0.000001         0.000002            0.296           0.767
# L12.RRP                     0.000025         0.000082            0.311           0.756
# L12.min_temperature         0.000272         0.004899            0.055           0.956
# L12.max_temperature         0.004649         0.030249            0.154           0.878
# L12.solar_exposure          0.009157         0.010058            0.910           0.363
# L12.rainfall               -0.000481         0.002377           -0.202           0.840
# L12.school_day             -0.014178         0.080402           -0.176           0.860
# L12.holiday                 0.065134         0.056975            1.143           0.253
# L13.demand                 -0.000001         0.000002           -0.614           0.539
# L13.RRP                     0.000125         0.000082            1.530           0.126
# L13.min_temperature        -0.003158         0.004900           -0.644           0.519
# L13.max_temperature         0.044484         0.030213            1.472           0.141
# L13.solar_exposure         -0.006048         0.010054           -0.602           0.547
# L13.rainfall               -0.000470         0.002380           -0.198           0.843
# L13.school_day              0.078054         0.080861            0.965           0.334
# L13.holiday                -0.077819         0.056912           -1.367           0.172
# L14.demand                 -0.000001         0.000002           -0.328           0.743
# L14.RRP                    -0.000002         0.000081           -0.025           0.980
# L14.min_temperature         0.004854         0.004886            0.994           0.320
# L14.max_temperature         0.029595         0.030313            0.976           0.329
# L14.solar_exposure          0.010088         0.010045            1.004           0.315
# L14.rainfall                0.001943         0.002353            0.826           0.409
# L14.school_day             -0.137241         0.080786           -1.699           0.089
# L14.holiday                -0.008193         0.056443           -0.145           0.885
# L15.demand                  0.000001         0.000001            0.713           0.476
# L15.RRP                    -0.000149         0.000079           -1.876           0.061
# L15.min_temperature         0.004319         0.003848            1.122           0.262
# L15.max_temperature        -0.008358         0.028598           -0.292           0.770
# L15.solar_exposure          0.004063         0.009637            0.422           0.673
# L15.rainfall                0.002097         0.002248            0.933           0.351
# L15.school_day              0.117235         0.058453            2.006           0.045
# L15.holiday                -0.062423         0.054671           -1.142           0.254
# ======================================================================================
#
# Results for equation solar_exposure
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -1.001683         0.859034           -1.166           0.244
# L1.demand                   0.000004         0.000003            1.090           0.276
# L1.RRP                      0.000458         0.000191            2.392           0.017
# L1.min_temperature         -0.044888         0.011104           -4.042           0.000
# L1.max_temperature          0.501675         0.059043            8.497           0.000
# L1.solar_exposure          -0.153089         0.022596           -6.775           0.000
# L1.rainfall                -0.001558         0.005691           -0.274           0.784
# L1.school_day               0.044216         0.140661            0.314           0.753
# L1.holiday                 -0.055642         0.133075           -0.418           0.676
# L2.demand                   0.000000         0.000004            0.066           0.947
# L2.RRP                     -0.000012         0.000196           -0.062           0.951
# L2.min_temperature         -0.005066         0.011886           -0.426           0.670
# L2.max_temperature          0.152692         0.073079            2.089           0.037
# L2.solar_exposure          -0.025899         0.023900           -1.084           0.279
# L2.rainfall                 0.002402         0.005765            0.417           0.677
# L2.school_day               0.127963         0.195144            0.656           0.512
# L2.holiday                  0.053485         0.137536            0.389           0.697
# L3.demand                   0.000001         0.000004            0.236           0.813
# L3.RRP                     -0.000003         0.000196           -0.016           0.987
# L3.min_temperature          0.001339         0.011899            0.113           0.910
# L3.max_temperature         -0.003720         0.073171           -0.051           0.959
# L3.solar_exposure          -0.021431         0.023972           -0.894           0.371
# L3.rainfall                -0.003583         0.005772           -0.621           0.535
# L3.school_day              -0.262725         0.195457           -1.344           0.179
# L3.holiday                 -0.004269         0.138472           -0.031           0.975
# L4.demand                   0.000005         0.000004            1.205           0.228
# L4.RRP                     -0.000194         0.000197           -0.986           0.324
# L4.min_temperature         -0.011935         0.011897           -1.003           0.316
# L4.max_temperature         -0.052419         0.073486           -0.713           0.476
# L4.solar_exposure          -0.006627         0.024341           -0.272           0.785
# L4.rainfall                 0.000836         0.005782            0.145           0.885
# L4.school_day               0.055917         0.195408            0.286           0.775
# L4.holiday                  0.144814         0.138698            1.044           0.296
# L5.demand                  -0.000011         0.000004           -2.496           0.013
# L5.RRP                     -0.000040         0.000197           -0.204           0.838
# L5.min_temperature          0.022627         0.011879            1.905           0.057
# L5.max_temperature          0.048179         0.073375            0.657           0.511
# L5.solar_exposure          -0.004800         0.024258           -0.198           0.843
# L5.rainfall                 0.001592         0.005779            0.276           0.783
# ...
# L10.solar_exposure         -0.004271         0.003781           -1.130           0.259
# L10.rainfall               -0.000377         0.000889           -0.424           0.671
# L10.school_day              0.040808         0.030124            1.355           0.176
# L10.holiday                -0.001511         0.021521           -0.070           0.944
# L11.demand                 -0.000001         0.000001           -2.082           0.037
# L11.RRP                     0.000002         0.000031            0.058           0.954
# L11.min_temperature        -0.001492         0.001842           -0.810           0.418
# L11.max_temperature         0.018821         0.011378            1.654           0.098
# L11.solar_exposure          0.000873         0.003781            0.231           0.817
# L11.rainfall               -0.000157         0.000893           -0.175           0.861
# L11.school_day              0.002418         0.030102            0.080           0.936
# L11.holiday                 0.004944         0.021467            0.230           0.818
# L12.demand                  0.000001         0.000001            1.795           0.073
# L12.RRP                     0.000020         0.000031            0.636           0.525
# L12.min_temperature        -0.000193         0.001842           -0.105           0.917
# L12.max_temperature        -0.005348         0.011376           -0.470           0.638
# L12.solar_exposure         -0.000612         0.003783           -0.162           0.871
# L12.rainfall               -0.001495         0.000894           -1.672           0.095
# L12.school_day             -0.063651         0.030238           -2.105           0.035
# L12.holiday                -0.005778         0.021428           -0.270           0.787
# L13.demand                  0.000000         0.000001            0.138           0.890
# L13.RRP                     0.000009         0.000031            0.282           0.778
# L13.min_temperature         0.003787         0.001843            2.055           0.040
# L13.max_temperature        -0.006974         0.011363           -0.614           0.539
# L13.solar_exposure         -0.000262         0.003781           -0.069           0.945
# L13.rainfall               -0.000136         0.000895           -0.152           0.879
# L13.school_day              0.046276         0.030411            1.522           0.128
# L13.holiday                 0.008400         0.021404            0.392           0.695
# L14.demand                 -0.000001         0.000001           -0.837           0.402
# L14.RRP                    -0.000017         0.000031           -0.565           0.572
# L14.min_temperature        -0.003601         0.001837           -1.960           0.050
# L14.max_temperature         0.003501         0.011400            0.307           0.759
# L14.solar_exposure          0.005234         0.003778            1.385           0.166
# L14.rainfall               -0.000500         0.000885           -0.565           0.572
# L14.school_day              0.121745         0.030383            4.007           0.000
# L14.holiday                -0.019343         0.021228           -0.911           0.362
# L15.demand                  0.000000         0.000001            0.815           0.415
# L15.RRP                     0.000026         0.000030            0.882           0.378
# L15.min_temperature        -0.000926         0.001447           -0.640           0.522
# L15.max_temperature         0.001815         0.010756            0.169           0.866
# L15.solar_exposure          0.000201         0.003625            0.056           0.956
# L15.rainfall               -0.000489         0.000846           -0.579           0.563
# L15.school_day             -0.157391         0.021984           -7.159           0.000
# L15.holiday                -0.003905         0.020561           -0.190           0.849
# ======================================================================================
#
# Results for equation holiday
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.201658         0.147621           -1.366           0.172
# L1.demand                  -0.000002         0.000001           -2.954           0.003
# L1.RRP                     -0.000016         0.000033           -0.497           0.619
# L1.min_temperature          0.000539         0.001908            0.282           0.778
# L1.max_temperature         -0.001513         0.010146           -0.149           0.881
# L1.solar_exposure          -0.003159         0.003883           -0.814           0.416
# L1.rainfall                -0.002395         0.000978           -2.449           0.014
# L1.school_day              -0.037487         0.024172           -1.551           0.121
# L1.holiday                  0.200922         0.022868            8.786           0.000
# L2.demand                   0.000000         0.000001            0.549           0.583
# L2.RRP                      0.000141         0.000034            4.176           0.000
# L2.min_temperature         -0.000929         0.002043           -0.455           0.649
# L2.max_temperature          0.016762         0.012558            1.335           0.182
# L2.solar_exposure          -0.004308         0.004107           -1.049           0.294
# L2.rainfall                -0.000115         0.000991           -0.116           0.908
# L2.school_day              -0.023454         0.033534           -0.699           0.484
# L2.holiday                  0.050848         0.023635            2.151           0.031
# L3.demand                  -0.000000         0.000001           -0.310           0.757
# L3.RRP                     -0.000075         0.000034           -2.221           0.026
# L3.min_temperature          0.002368         0.002045            1.158           0.247
# L3.max_temperature         -0.008730         0.012574           -0.694           0.488
# L3.solar_exposure          -0.003204         0.004119           -0.778           0.437
# L3.rainfall                 0.002266         0.000992            2.284           0.022
# L3.school_day              -0.007206         0.033588           -0.215           0.830
# L3.holiday                  0.023462         0.023796            0.986           0.324
# L4.demand                   0.000001         0.000001            1.139           0.255
# L4.RRP                      0.000122         0.000034            3.604           0.000
# L4.min_temperature         -0.003849         0.002044           -1.882           0.060
# L4.max_temperature         -0.006177         0.012628           -0.489           0.625
# L4.solar_exposure          -0.004653         0.004183           -1.112           0.266
# L4.rainfall                 0.000891         0.000994            0.896           0.370
# L4.school_day              -0.013929         0.033580           -0.415           0.678
# L4.holiday                 -0.070048         0.023835           -2.939           0.003
# L5.demand                  -0.000000         0.000001           -0.054           0.957
# L5.RRP                     -0.000097         0.000034           -2.879           0.004
# L5.min_temperature         -0.001114         0.002041           -0.546           0.585
# L5.max_temperature          0.030863         0.012609            2.448           0.014
# L5.solar_exposure          -0.005744         0.004169           -1.378           0.168
# L5.rainfall                 0.000483         0.000993            0.486           0.627
# L5.school_day               0.021323         0.033523            0.636           0.525
# L5.holiday                 -0.017437         0.023935           -0.729           0.466
# L6.demand                  -0.000001         0.000001           -0.984           0.325
# L6.RRP                      0.000025         0.000034            0.752           0.452
# L6.min_temperature          0.002972         0.002045            1.453           0.146
# L6.max_temperature          0.013113         0.012646            1.037           0.300
# L6.solar_exposure          -0.003929         0.004175           -0.941           0.347
# L6.rainfall                 0.004728         0.000992            4.766           0.000
# L6.school_day               0.005470         0.033521            0.163           0.870
# L6.holiday                  0.061701         0.024040            2.567           0.010
# L7.demand                   0.000001         0.000001            1.202           0.229
# L7.RRP                     -0.000037         0.000034           -1.084           0.278
# L7.min_temperature         -0.003941         0.002040           -1.932           0.053
# L7.max_temperature         -0.002833         0.012631           -0.224           0.823
# L7.solar_exposure          -0.008231         0.004178           -1.970           0.049
# L7.rainfall                 0.000772         0.000999            0.773           0.440
# L7.school_day              -0.058029         0.033518           -1.731           0.083
# L7.holiday                 -0.002559         0.024075           -0.106           0.915
# L8.demand                   0.000001         0.000001            1.229           0.219
# L8.RRP                      0.000002         0.000034            0.069           0.945
# L8.min_temperature          0.000613         0.002043            0.300           0.764
# L8.max_temperature          0.012695         0.012647            1.004           0.315
# L8.solar_exposure          -0.006755         0.004221           -1.600           0.110
# L8.rainfall                 0.000552         0.000991            0.557           0.578
# L8.school_day               0.111273         0.033498            3.322           0.001
# L8.holiday                 -0.030697         0.024088           -1.274           0.203
# L9.demand                  -0.000001         0.000001           -0.919           0.358
# L9.RRP                     -0.000019         0.000034           -0.571           0.568
# L9.min_temperature         -0.001192         0.002045           -0.583           0.560
# L9.max_temperature          0.020346         0.012638            1.610           0.107
# L9.solar_exposure          -0.001239         0.004216           -0.294           0.769
# L9.rainfall                 0.000340         0.000986            0.345           0.730
# L9.school_day              -0.031967         0.033499           -0.954           0.340
# L9.holiday                 -0.014701         0.023971           -0.613           0.540
# L10.demand                  0.000001         0.000001            1.086           0.277
# L10.RRP                     0.000021         0.000034            0.611           0.541
# L10.min_temperature        -0.001625         0.002044           -0.795           0.427
# L10.max_temperature        -0.006761         0.012633           -0.535           0.593
# L10.solar_exposure         -0.007652         0.004197           -1.823           0.068
# L10.rainfall                0.002006         0.000987            2.033           0.042
# L10.school_day             -0.014159         0.033436           -0.423           0.672
# L10.holiday                -0.007211         0.023887           -0.302           0.763
# L11.demand                  0.000000         0.000001            0.158           0.875
# L11.RRP                    -0.000008         0.000034           -0.224           0.822
# L11.min_temperature         0.000811         0.002045            0.397           0.692
# L11.max_temperature        -0.005629         0.012628           -0.446           0.656
# L11.solar_exposure          0.002899         0.004197            0.691           0.490
# L11.rainfall                0.000138         0.000991            0.139           0.889
# L11.school_day              0.039999         0.033411            1.197           0.231
# L11.holiday                 0.011075         0.023827            0.465           0.642
# L12.demand                  0.000000         0.000001            0.197           0.844
# L12.RRP                    -0.000008         0.000034           -0.238           0.812
# L12.min_temperature        -0.005861         0.002045           -2.867           0.004
# L12.max_temperature         0.006816         0.012627            0.540           0.589
# L12.solar_exposure          0.000167         0.004198            0.040           0.968
# L12.rainfall               -0.001834         0.000992           -1.848           0.065
# L12.school_day             -0.058186         0.033563           -1.734           0.083
# L12.holiday                -0.002170         0.023783           -0.091           0.927
# L13.demand                 -0.000001         0.000001           -1.126           0.260
# L13.RRP                     0.000012         0.000034            0.355           0.723
# L13.min_temperature         0.000829         0.002045            0.405           0.685
# L13.max_temperature         0.037674         0.012612            2.987           0.003
# L13.solar_exposure          0.010032         0.004197            2.391           0.017
# L13.rainfall                0.000066         0.000993            0.066           0.947
# L13.school_day              0.020575         0.033754            0.610           0.542
# L13.holiday                -0.005097         0.023757           -0.215           0.830
# L14.demand                  0.000002         0.000001            2.861           0.004
# L14.RRP                    -0.000025         0.000034           -0.746           0.456
# L14.min_temperature         0.003097         0.002039            1.519           0.129
# L14.max_temperature        -0.014679         0.012654           -1.160           0.246
# L14.solar_exposure          0.003215         0.004193            0.767           0.443
# L14.rainfall                0.000108         0.000982            0.110           0.913
# L14.school_day             -0.038387         0.033723           -1.138           0.255
# L14.holiday                 0.001450         0.023561            0.062           0.951
# L15.demand                 -0.000002         0.000001           -3.607           0.000
# L15.RRP                    -0.000005         0.000033           -0.158           0.874
# L15.min_temperature        -0.000337         0.001606           -0.210           0.834
# L15.max_temperature        -0.006943         0.011938           -0.582           0.561
# L15.solar_exposure         -0.000374         0.004023           -0.093           0.926
# L15.rainfall                0.000679         0.000938            0.723           0.469
# L15.school_day              0.043243         0.024400            1.772           0.076
# L15.holiday                -0.041461         0.022821           -1.817           0.069
# ======================================================================================
#
# Correlation matrix of residuals
#                      demand       RRP  min_temperature  max_temperature  solar_exposure  rainfall  school_day   holiday
# demand             1.000000  0.261493         0.108167         0.267541       -0.019503 -0.072064    0.003826 -0.298541
# RRP                0.261493  1.000000         0.030477         0.136403       -0.052238 -0.037845    0.007084 -0.031292
# min_temperature    0.108167  0.030477         1.000000         0.235669        0.120896 -0.075023   -0.004017 -0.021738
# max_temperature    0.267541  0.136403         0.235669         1.000000       -0.147213 -0.226159    0.016277 -0.064907
# solar_exposure    -0.019503 -0.052238         0.120896        -0.147213        1.000000  0.046514   -0.011051 -0.004688
# rainfall          -0.072064 -0.037845        -0.075023        -0.226159        0.046514  1.000000   -0.019410 -0.004232
# school_day         0.003826  0.007084        -0.004017         0.016277       -0.011051 -0.019410    1.000000  0.008634
# holiday           -0.298541 -0.031292        -0.021738        -0.064907       -0.004688 -0.004232    0.008634  1.000000

# %%
#Forecast the electricity demand for 59 days (January and February 2021)
print(results.k_ar)
laaged_values = training_set.values[-results.k_ar:]
forecast = pd.DataFrame(results.forecast(y= laaged_values, steps=59), index = testing_set.index)
forecast
# Out:
# 15
#                         0           1          2  ...         5         6         7
# date                                              ...
# 2021-01-01   98963.695263  -13.767266  12.832427  ...  1.280129  0.093304  0.154526
# 2021-01-02   98089.291266   83.619691  12.815915  ...  0.339981  0.162511 -0.029336
# 2021-01-03   92696.304948  158.525314  12.149436  ...  1.032070  0.044116  0.047715
# 2021-01-04   92868.629292   80.606607  13.577324  ...  5.689020  0.038793  0.009797
# 2021-01-05  105995.983103   55.668282  13.561114  ... -0.948197  0.106658  0.024459
# 2021-01-06  107469.383007   36.042340  13.305462  ...  1.361348  0.185061  0.024790
# 2021-01-07  111077.099846   45.705137  14.819407  ...  1.480124  0.109608 -0.058362
# 2021-01-08  106613.888353   49.526038  13.815456  ...  2.169921  0.186796  0.049915
# 2021-01-09  106304.889510   27.479025  13.571103  ...  1.222183  0.207975  0.067520
# 2021-01-10   96633.582450   78.603872  13.971865  ...  1.051807  0.200712  0.167083
# 2021-01-11   98767.278018   48.282476  13.724994  ...  1.466500  0.259826  0.118001
# 2021-01-12  110579.460913   72.321238  13.878247  ...  0.196946  0.299223  0.060676
# 2021-01-13  109317.204733   95.365000  13.852093  ...  3.301404  0.368289  0.031195
# 2021-01-14  108654.085908  111.826826  13.791594  ...  2.765813  0.378730  0.067692
# 2021-01-15  109690.512444   98.315999  13.821012  ...  2.212912  0.455558  0.053462
# 2021-01-16  108417.519675  101.692654  13.703417  ...  3.121106  0.454107  0.067192
# 2021-01-17  102262.188177   88.978220  13.963391  ...  2.196138  0.460096  0.070666
# 2021-01-18  102048.266153   88.029018  13.752784  ...  2.151852  0.484444  0.051690
# 2021-01-19  110282.281914   97.496702  13.651295  ...  2.261107  0.528238  0.096860
# 2021-01-20  110966.194530   74.357478  13.884922  ...  1.586598  0.572405  0.066272
# 2021-01-21  110690.605651   85.094831  13.811920  ...  2.009798  0.574915  0.066895
# 2021-01-22  111332.908976   95.014580  14.224636  ...  1.382044  0.614912  0.048741
# 2021-01-23  110440.215210   94.241493  14.268365  ...  1.777898  0.619483  0.078674
# 2021-01-24  105798.284664   86.348541  14.037557  ...  1.741241  0.628108  0.048022
# 2021-01-25  105419.881475   84.007110  13.922864  ...  1.651511  0.646386  0.049786
# 2021-01-26  111961.073255   92.719040  13.917880  ...  1.667823  0.673232  0.085982
# 2021-01-27  112857.401279   85.116125  14.115354  ...  1.504726  0.696670  0.046994
# 2021-01-28  111960.750466   91.805638  14.153552  ...  1.736600  0.698565  0.042914
# 2021-01-29  112344.748095   99.342547  14.174651  ...  1.852119  0.717529  0.042729
# 2021-01-30  111435.165006   87.298897  14.094616  ...  1.826155  0.708466  0.053614
# 2021-01-31  107346.055708   84.966040  13.992782  ...  1.969248  0.703358  0.046143
# 2021-02-01  107233.187673   82.496350  14.000659  ...  1.759663  0.707613  0.044589
# 2021-02-02  112660.442097   89.761454  13.952798  ...  1.712245  0.719512  0.070470
# 2021-02-03  113608.089552   84.590378  13.970560  ...  1.691095  0.727802  0.050352
# 2021-02-04  112818.743276   85.917707  14.031428  ...  1.654992  0.724264  0.043640
# 2021-02-05  113145.883040   92.241238  14.043741  ...  1.690119  0.730830  0.046745
# 2021-02-06  112542.849299   86.227274  14.020734  ...  1.678636  0.713600  0.057578
# 2021-02-07  109069.320167   82.823870  13.970474  ...  1.804571  0.703769  0.046582
# 2021-02-08  108906.868111   83.697974  13.937900  ...  1.648693  0.703787  0.048895
# 2021-02-09  113340.315720   86.554461  13.910638  ...  1.598725  0.708081  0.068882
# 2021-02-10  114217.641466   83.895721  13.926239  ...  1.629493  0.709444  0.054782
# 2021-02-11  113353.239449   84.390239  13.992405  ...  1.594415  0.703506  0.045409
# 2021-02-12  113524.608955   89.297568  14.017277  ...  1.654062  0.701230  0.050293
# 2021-02-13  112881.982420   85.523354  13.974588  ...  1.710267  0.683509  0.059885
# 2021-02-14  109968.859659   80.705900  13.910711  ...  1.782112  0.672307  0.051013
# 2021-02-15  109849.849225   81.814700  13.870193  ...  1.687659  0.670468  0.053765
# 2021-02-16  113654.414323   84.708812  13.860160  ...  1.616824  0.671479  0.068639
# 2021-02-17  114556.833079   82.585512  13.877812  ...  1.638193  0.670925  0.057282
# 2021-02-18  113703.801255   83.222332  13.914382  ...  1.636484  0.666177  0.048357
# 2021-02-19  113810.185290   86.969744  13.928704  ...  1.646149  0.662678  0.052867
# 2021-02-20  113309.303961   83.818724  13.893278  ...  1.675988  0.647733  0.060810
# 2021-02-21  110884.447980   79.573010  13.842345  ...  1.728954  0.638865  0.052732
# 2021-02-22  110806.759135   80.875337  13.816931  ...  1.650662  0.638321  0.054570
# 2021-02-23  113973.352386   83.637774  13.807733  ...  1.594165  0.639799  0.066887
# 2021-02-24  114812.198975   81.710492  13.822797  ...  1.616463  0.640209  0.057943
# 2021-02-25  113993.331899   82.220508  13.853894  ...  1.621684  0.638063  0.049691
# 2021-02-26  114064.557606   85.369838  13.865058  ...  1.626779  0.635433  0.053829
# 2021-02-27  113655.113377   82.971333  13.834543  ...  1.663899  0.624220  0.059935
# 2021-02-28  111628.179685   79.468285  13.787707  ...  1.718217  0.618333  0.053452
#
# [59 rows x 8 columns]

# %%
#Combine the original demand and forecasted demand
output = pd.DataFrame()
output['demand'] = testing_set['demand']
output['forecasted_demand'] = forecast[0]

# %%
output
# Out:
#                 demand  forecasted_demand
# date
# 2021-01-01   92926.685       98963.695263
# 2021-01-02   98995.065       98089.291266
# 2021-01-03   94371.480       92696.304948
# 2021-01-04   99640.535       92868.629292
# 2021-01-05  103840.455      105995.983103
# 2021-01-06  100748.620      107469.383007
# 2021-01-07  100672.950      111077.099846
# 2021-01-08  103763.200      106613.888353
# 2021-01-09  106315.210      106304.889510
# 2021-01-10  115294.305       96633.582450
# 2021-01-11  145310.190       98767.278018
# 2021-01-12  114536.745      110579.460913
# 2021-01-13  121549.910      109317.204733
# 2021-01-14  110439.435      108654.085908
# 2021-01-15  103034.345      109690.512444
# 2021-01-16   95483.195      108417.519675
# 2021-01-17   89423.690      102262.188177
# 2021-01-18  101924.855      102048.266153
# 2021-01-19  100606.690      110282.281914
# 2021-01-20  105651.595      110966.194530
# 2021-01-21  123959.205      110690.605651
# 2021-01-22  120658.935      111332.908976
# 2021-01-23  113037.050      110440.215210
# 2021-01-24  132074.090      105798.284664
# 2021-01-25  146866.295      105419.881475
# 2021-01-26  106198.015      111961.073255
# 2021-01-27  102432.385      112857.401279
# 2021-01-28  115724.350      111960.750466
# 2021-01-29  119316.355      112344.748095
# 2021-01-30   98708.145      111435.165006
# 2021-01-31   92223.405      107346.055708
# 2021-02-01  109911.080      107233.187673
# 2021-02-02  106137.670      112660.442097
# 2021-02-03  106099.945      113608.089552
# 2021-02-04  118860.370      112818.743276
# 2021-02-05  120490.880      113145.883040
# 2021-02-06   95849.585      112542.849299
# 2021-02-07   91865.305      109069.320167
# 2021-02-08  104202.115      108906.868111
# 2021-02-09  106834.665      113340.315720
# 2021-02-10  124620.445      114217.641466
# 2021-02-11  134863.920      113353.239449
# 2021-02-12  114298.005      113524.608955
# 2021-02-13   97268.160      112881.982420
# 2021-02-14   93060.700      109968.859659
# 2021-02-15  106845.460      109849.849225
# 2021-02-16  122517.035      113654.414323
# 2021-02-17  129301.420      114556.833079
# 2021-02-18  132916.100      113703.801255
# 2021-02-19  137419.645      113810.185290
# 2021-02-20  121578.705      113309.303961
# 2021-02-21  106024.855      110884.447980
# 2021-02-22  105572.525      110806.759135
# 2021-02-23  104875.770      113973.352386
# 2021-02-24  108577.110      114812.198975
# 2021-02-25  107456.345      113993.331899
# 2021-02-26  107807.000      114064.557606
# 2021-02-27  103417.660      113655.113377
# 2021-02-28   97551.090      111628.179685

# %%
#Plot the demand and forecasted demand
output.plot()

# %%
#Performance metric
print("Mean Absolute Error: ", mean_absolute_error(output['demand'],output['forecasted_demand']))
print("Mean Absolute Percentage Error: ", np.mean(np.abs((output['demand'] - output['forecasted_demand']) / output['demand'])) * 100)
print("Mean Squared Error: ", mean_squared_error(output['demand'],output['forecasted_demand']))
print("Root Mean Squared Error: ", sqrt(mean_squared_error(output['demand'],output['forecasted_demand'])))
print("R2 Score: ", r2_score(output['demand'],output['forecasted_demand']))
# Out:
# Mean Absolute Error:  10111.69206205011
# Mean Absolute Percentage Error:  8.914966107210857
# Mean Squared Error:  177982084.60728446
# Root Mean Squared Error:  13340.992639503422
# R2 Score:  -0.007341255213599407

# %%
#Split the dataset into the training and testing set
training_set = dataset.iloc[:2191]
training_set_target = training_set['demand']
training_set = training_set.drop(columns=['demand'])

testing_set = dataset.iloc[2192:]
testing_set_target = testing_set['demand']
testing_set = testing_set.drop(columns=['demand'])

#Convert the series to dataframe
training_set_target = pd.DataFrame(training_set_target)
testing_set_target = pd.DataFrame(testing_set_target)

# %%
#Display the training and testing dataset
print("Training dataset:\n", training_set.head())
print("\nTraining target dataset:\n", training_set_target.head())
print("\nTesting dataset:\n", testing_set.head())
print("\nTesting target dataset:\n",testing_set_target.head())
# Out:
# Training dataset:
#                    RRP  min_temperature  ...  school_day  holiday
# date                                    ...
# 2015-01-01  25.633696             13.3  ...           0        1
# 2015-01-02  33.138988             15.4  ...           0        0
# 2015-01-03  34.564855             20.0  ...           0        0
# 2015-01-04  25.005560             16.3  ...           0        0
# 2015-01-05  26.724176             15.0  ...           0        0
#
# [5 rows x 7 columns]
#
# Training target dataset:
#                  demand
# date
# 2015-01-01   99635.030
# 2015-01-02  129606.010
# 2015-01-03  142300.540
# 2015-01-04  104330.715
# 2015-01-05  118132.200
#
# Testing dataset:
#                    RRP  min_temperature  ...  school_day  holiday
# date                                    ...
# 2021-01-01  18.296383             14.3  ...           0        1
# 2021-01-02  21.890208             16.8  ...           0        0
# 2021-01-03  19.487708             17.4  ...           0        0
# 2021-01-04   4.791042             15.4  ...           0        0
# 2021-01-05   7.464583             15.1  ...           0        0
#
# [5 rows x 7 columns]
#
# Testing target dataset:
#                  demand
# date
# 2021-01-01   92926.685
# 2021-01-02   98995.065
# 2021-01-03   94371.480
# 2021-01-04   99640.535
# 2021-01-05  103840.455

# %%
#Import statement
from sklearn.preprocessing import MinMaxScaler

#Normalize the dataset using MinMax scaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))
training_set = scaler.fit_transform(training_set)
testing_set = scaler.fit_transform(testing_set)

training_set_target = scaler_y.fit_transform(training_set_target)
testing_set_target = scaler_y.fit_transform(testing_set_target)

# %%
print("Training dataset shape: ", training_set.shape)
print("Training dataset target shape: ", training_set_target.shape)

print("Testing dataset shape:", testing_set.shape)
print("Testing dataset target shape: ",testing_set_target.shape)
# Out:
# Training dataset shape:  (2191, 7)
# Training dataset target shape:  (2191, 1)
# Testing dataset shape: (59, 7)
# Testing dataset target shape:  (59, 1)

# %%
training_set = np.reshape(training_set, (training_set.shape[0], 1, training_set.shape[1]))
testing_set = np.reshape(testing_set, (testing_set.shape[0], 1, testing_set.shape[1]))

# %%
print("Training dataset shape: ", training_set.shape)
print("Training dataset target shape: ", training_set_target.shape)

print("Testing dataset shape:", testing_set.shape)
print("Testing dataset target shape: ",testing_set_target.shape)
# Out:
# Training dataset shape:  (2191, 1, 7)
# Training dataset target shape:  (2191, 1)
# Testing dataset shape: (59, 1, 7)
# Testing dataset target shape:  (59, 1)

# %%
#Design the LSTM model
model = Sequential()
model.add(LSTM(256, input_shape= (2191, 7), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, return_sequences=False))
model.add(Dense(1))

# %%
#Display the summary of LSTM model
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 2191, 256)         270336
# _________________________________________________________________
# dropout (Dropout)            (None, 2191, 256)         0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 2191, 128)         197120
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2191, 128)         0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 2191, 64)          49408
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2191, 64)          0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 529,313
# Trainable params: 529,313
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor='loss', min_delta=0, patience=2, verbose=0,
    mode='auto', baseline=None, restore_best_weights=False
)
model.compile(loss='mean_absolute_error',
              optimizer='adam')

history = model.fit(x=training_set, y=training_set_target, epochs=500, shuffle=False, batch_size=313, callbacks=[callback])
# Out:
# Epoch 1/500
# WARNING:tensorflow:Model was constructed with shape (None, 2191, 7) for input KerasTensor(type_spec=TensorSpec(shape=(None, 2191, 7), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (313, 1, 7).
# WARNING:tensorflow:Model was constructed with shape (None, 2191, 7) for input KerasTensor(type_spec=TensorSpec(shape=(None, 2191, 7), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (313, 1, 7).
# 7/7 [==============================] - 5s 35ms/step - loss: 0.4416
# Epoch 2/500
# 7/7 [==============================] - 0s 36ms/step - loss: 0.4062
# Epoch 3/500
# 7/7 [==============================] - 0s 34ms/step - loss: 0.3393
# Epoch 4/500
# 7/7 [==============================] - 0s 36ms/step - loss: 0.2112
# Epoch 5/500
# 7/7 [==============================] - 0s 36ms/step - loss: 0.1567
# Epoch 6/500
# 7/7 [==============================] - 0s 34ms/step - loss: 0.1365
# Epoch 7/500
# 7/7 [==============================] - 0s 34ms/step - loss: 0.1518
# Epoch 8/500
# 7/7 [==============================] - 0s 35ms/step - loss: 0.1404

# %%
#Predict the electricity demand for training and test dataset
train_pred = model.predict(training_set)
test_pred = model.predict(testing_set)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 2191, 7) for input KerasTensor(type_spec=TensorSpec(shape=(None, 2191, 7), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 1, 7).

# %%
#Apply inverse transformation to the predictions

train_pred = scaler_y.inverse_transform(train_pred)
training_set_target = scaler_y.inverse_transform(training_set_target)
test_pred = scaler_y.inverse_transform(test_pred)
testing_set_target = scaler_y.inverse_transform(testing_set_target)

# %%
#Performance metric
print("Mean Absolute Error: ", mean_absolute_error(training_set_target[:,0], train_pred[:,0]))
print("Mean Absolute Percentage Error: ", np.mean(np.abs((training_set_target[:,0] - train_pred[:,0]) / training_set_target[:,0])) * 100)
print("Mean Squared Error: ", mean_squared_error(training_set_target[:,0], train_pred[:,0]))
print("Root Mean Squared Error: ", sqrt(mean_squared_error(training_set_target[:,0], train_pred[:,0])))
print("R2 Score: ", r2_score(training_set_target[:,0], train_pred[:,0]))
# Out:
# Mean Absolute Error:  7591.305902985321
# Mean Absolute Percentage Error:  6.7110157590492605
# Mean Squared Error:  86472242.67480741
# Root Mean Squared Error:  9299.045256089865
# R2 Score:  -0.0644128575745877

# %%
print("Mean Absolute Error: ", mean_absolute_error(testing_set_target[:,0], test_pred[:,0]))
print("Mean Absolute Percentage Error: ", np.mean(np.abs((testing_set_target[:,0] - test_pred[:,0]) / testing_set_target[:,0])) * 100)
print("Mean Squared Error: ", mean_squared_error(testing_set_target[:,0], test_pred[:,0]))
print("Root Mean Squared Error: ", sqrt(mean_squared_error(testing_set_target[:,0], test_pred[:,0])))
print("R2 Score: ", r2_score(testing_set_target[:,0], test_pred[:,0]))
# Out:
# Mean Absolute Error:  10164.762743644069
# Mean Absolute Percentage Error:  9.489764002064012
# Mean Squared Error:  135354259.69171798
# Root Mean Squared Error:  11634.184960353603
# R2 Score:  0.2339232897669845

# %%
training_set_target.shape
# Out:
# (2191, 1)

# %%
# plot baseline and predictions
sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.plot(training_set_target[:200])
plt.plot(train_pred[:200])
plt.legend(['Demand', 'Prediction'])
plt.show()

# %%
# plot baseline and predictions
sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.plot(testing_set_target)
plt.plot(test_pred)
plt.legend(['Demand', 'Prediction'])
plt.show()

# %%
#Forming the training dataset
training_set = dataset.iloc[:]
training_set_target = training_set['demand']
training_set = training_set.drop(columns=['demand'])
training_set_target = pd.DataFrame(training_set_target)

print("Training set: \n", training_set.head())
print("\nTraining dataset target: \n", training_set_target.head())
print("\nShape of training set: ", training_set.shape)
# Out:
# Training set:
#                    RRP  min_temperature  ...  school_day  holiday
# date                                    ...
# 2015-01-01  25.633696             13.3  ...           0        1
# 2015-01-02  33.138988             15.4  ...           0        0
# 2015-01-03  34.564855             20.0  ...           0        0
# 2015-01-04  25.005560             16.3  ...           0        0
# 2015-01-05  26.724176             15.0  ...           0        0
#
# [5 rows x 7 columns]
#
# Training dataset target:
#                  demand
# date
# 2015-01-01   99635.030
# 2015-01-02  129606.010
# 2015-01-03  142300.540
# 2015-01-04  104330.715
# 2015-01-05  118132.200
#
# Shape of training set:  (2251, 7)

# %%
#Fetch the prediction dataset
prediction_set = pd.read_csv(io.BytesIO(uploaded['dataset_for_prediction.csv']))
prediction_set = prediction_set.drop(columns=['demand'])
prediction_set.head()
# Out:
#          date        RRP  min_temperature  ...   rainfall  school_day  holiday
# 0  03-01-2021  16.113191        12.506416  ...   1.000000           Y        N
# 1  03-02-2021  20.828125        12.016535  ...   1.000000           Y        N
# 2  03-03-2021  24.979167        11.526654  ...   1.733333           Y        N
# 3  03-04-2021  24.135417        11.036772  ...  12.800000           Y        N
# 4  03-05-2021  21.580625        10.546891  ...  32.700000           Y        N
#
# [5 rows x 8 columns]

# %%
#Replace the school day and holiday with appropriate values
prediction_set['school_day'] = prediction_set['school_day'].replace(to_replace ="N", value = 0)
prediction_set['school_day'] = prediction_set['school_day'].replace(to_replace ="Y", value = 1)
prediction_set['holiday'] = prediction_set['holiday'].replace(to_replace ="N", value = 0)
prediction_set['holiday'] = prediction_set['holiday'].replace(to_replace ="Y", value = 1)

# %%
#Format the date column of the prediction dataset
prediction_set['date'] = pd.to_datetime(prediction_set['date'], infer_datetime_format=True)
prediction_set.set_index('date', inplace=True)

# %%
prediction_set.head()
# Out:
#                   RRP  min_temperature  ...  school_day  holiday
# date                                    ...
# 2021-03-01  16.113191        12.506416  ...           1        0
# 2021-03-02  20.828125        12.016535  ...           1        0
# 2021-03-03  24.979167        11.526654  ...           1        0
# 2021-03-04  24.135417        11.036772  ...           1        0
# 2021-03-05  21.580625        10.546891  ...           1        0
#
# [5 rows x 7 columns]

# %%
#Import statement
from sklearn.preprocessing import MinMaxScaler

#Normalize the dataset using MinMax scaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))
training_set = scaler.fit_transform(training_set)
prediction_set = scaler.fit_transform(prediction_set)

training_set_target = scaler_y.fit_transform(training_set_target)

# %%
training_set = np.reshape(training_set, (training_set.shape[0], 1, training_set.shape[1]))
prediction_set = np.reshape(prediction_set, (prediction_set.shape[0], 1, prediction_set.shape[1]))

print("Shape of training data set: ", training_set.shape)
print("Shape of prediction data set: ", prediction_set.shape)
# Out:
# Shape of training data set:  (2251, 1, 7)
# Shape of prediction data set:  (184, 1, 7)

# %%
#Design the LSTM model
model = Sequential()
model.add(LSTM(256, input_shape= (2251, 7), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, return_sequences=False))
model.add(Dense(1))

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_24 (LSTM)               (None, 2251, 256)         270336
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 2251, 256)         0
# _________________________________________________________________
# lstm_25 (LSTM)               (None, 2251, 128)         197120
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 2251, 128)         0
# _________________________________________________________________
# lstm_26 (LSTM)               (None, 2251, 64)          49408
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 2251, 64)          0
# _________________________________________________________________
# lstm_27 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 529,313
# Trainable params: 529,313
# Non-trainable params: 0
# _________________________________________________________________

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor='loss', min_delta=0, patience=2, verbose=0,
    mode='auto', baseline=None, restore_best_weights=False
)
model.compile(loss='mean_absolute_error',
              optimizer='adam')

history = model.fit(x=training_set, y=training_set_target, epochs=500, shuffle=False, batch_size=64, callbacks=[callback])
# Out:
# Epoch 1/500
# WARNING:tensorflow:Model was constructed with shape (None, 2251, 7) for input KerasTensor(type_spec=TensorSpec(shape=(None, 2251, 7), dtype=tf.float32, name='lstm_24_input'), name='lstm_24_input', description="created by layer 'lstm_24_input'"), but it was called on an input with incompatible shape (None, 1, 7).
# WARNING:tensorflow:Model was constructed with shape (None, 2251, 7) for input KerasTensor(type_spec=TensorSpec(shape=(None, 2251, 7), dtype=tf.float32, name='lstm_24_input'), name='lstm_24_input', description="created by layer 'lstm_24_input'"), but it was called on an input with incompatible shape (None, 1, 7).
# 36/36 [==============================] - 7s 16ms/step - loss: 0.3897
# Epoch 2/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1402
# Epoch 3/500
# 36/36 [==============================] - 1s 15ms/step - loss: 0.1468
# Epoch 4/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1474
# Epoch 5/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1460
# Epoch 6/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1451
# Epoch 7/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1452
# Epoch 8/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1447
# Epoch 9/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1417
# Epoch 10/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1390
# Epoch 11/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1404
# Epoch 12/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1382
# Epoch 13/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1390
# Epoch 14/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1359
# Epoch 15/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1367
# Epoch 16/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1366
# Epoch 17/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1366
# Epoch 18/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1351
# Epoch 19/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1372
# Epoch 20/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1346
# Epoch 21/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1357
# Epoch 22/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1354
# Epoch 23/500
# 36/36 [==============================] - 1s 15ms/step - loss: 0.1338
# Epoch 24/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1341
# Epoch 25/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1341
# Epoch 26/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1359
# Epoch 27/500
# 36/36 [==============================] - 1s 16ms/step - loss: 0.1349

# %%
predictions = model.predict(prediction_set)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 2251, 7) for input KerasTensor(type_spec=TensorSpec(shape=(None, 2251, 7), dtype=tf.float32, name='lstm_24_input'), name='lstm_24_input', description="created by layer 'lstm_24_input'"), but it was called on an input with incompatible shape (None, 1, 7).

# %%
predictions = scaler_y.inverse_transform(predictions)

# %%
prediction_set = pd.read_csv(io.BytesIO(uploaded['dataset_for_prediction.csv']))
prediction_set['date'] = pd.to_datetime(prediction_set['date'], infer_datetime_format=True)
prediction_set.set_index('date', inplace=True)
prediction_set['demand'] = predictions
prediction_set.head()
# Out:
#                    demand        RRP  ...  school_day  holiday
# date                                  ...
# 2021-03-01  125487.773438  16.113191  ...           Y        N
# 2021-03-02  132754.093750  20.828125  ...           Y        N
# 2021-03-03  136789.796875  24.979167  ...           Y        N
# 2021-03-04  134322.921875  24.135417  ...           Y        N
# 2021-03-05  128298.718750  21.580625  ...           Y        N
#
# [5 rows x 8 columns]

# %%
dataset.head()
# Out:
#                 demand        RRP  ...  school_day  holiday
# date                               ...
# 2015-01-01   99635.030  25.633696  ...           0        1
# 2015-01-02  129606.010  33.138988  ...           0        0
# 2015-01-03  142300.540  34.564855  ...           0        0
# 2015-01-04  104330.715  25.005560  ...           0        0
# 2015-01-05  118132.200  26.724176  ...           0        0
#
# [5 rows x 8 columns]

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.plot(dataset['demand'])
plt.plot(prediction_set['demand'])
plt.legend(['Demand','Prediction'])
plt.show()

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.plot(dataset['demand'][-424:])
plt.plot(prediction_set['demand'])
plt.legend(['Demand','Prediction'])
plt.show()

# %%
#Converting dataframe to csv file and downloading the file
prediction_set.to_csv('Prediction_data.csv') 
files.download('Prediction_data.csv')

# %%
#Split the dataset to form training and testing set
training_set = dataset.iloc[:2191]
testing_set = dataset.iloc[2192:]

#Display the training and testing dataset
print("Training dataset: \n", training_set.tail())
print("\nTesting dataset: \n", testing_set.head())
# Out:
# Training dataset:
#                 demand        RRP  ...  school_day  holiday
# date                              ...
# 2020-12-26  88980.895  31.239583  ...           0        0
# 2020-12-27  96137.560   6.380417  ...           0        0
# 2020-12-28  85792.090   8.254583  ...           0        1
# 2020-12-29  90537.375  23.902917  ...           0        0
# 2020-12-30  93732.335  29.288958  ...           0        0
#
# [5 rows x 8 columns]
#
# Testing dataset:
#                  demand        RRP  ...  school_day  holiday
# date                               ...
# 2021-01-01   92926.685  18.296383  ...           0        1
# 2021-01-02   98995.065  21.890208  ...           0        0
# 2021-01-03   94371.480  19.487708  ...           0        0
# 2021-01-04   99640.535   4.791042  ...           0        0
# 2021-01-05  103840.455   7.464583  ...           0        0
#
# [5 rows x 8 columns]

# %%
#Build the model for order ranging between 1 to 5.
for i in range(5):
    i += 1
    model = sm.tsa.VARMAX(training_set, order=(i,0))
    model_result = model.fit()
    print('Order = ', i)
    print('AIC: ', model_result.aic)
    print('BIC: ', model_result.bic)
    print('HQIC: ', model_result.hqic)

# %%
#Build the VARMA model
model = VARMAX(training_set, order=(1, 1))

# %%
#Fit the VARMA model
model_fit = model.fit()

# %%
#Predicted the output for next 60 days
prediction = model_fit.forecast(60)
print(prediction)
# Out:
#                    demand        RRP  ...  school_day   holiday
# 2020-12-31  100469.058389  51.568769  ...    0.030844  0.109660
# 2021-01-01  105858.472432  64.411784  ...    0.067823  0.117582
# 2021-01-02  109262.259713  70.439929  ...    0.103779  0.109564
# 2021-01-03  111390.356950  73.601557  ...    0.138594  0.100849
# 2021-01-04  112791.527671  75.280768  ...    0.171928  0.093711
# 2021-01-05  113769.530648  76.126849  ...    0.203518  0.088047
# 2021-01-06  114492.829023  76.508898  ...    0.233278  0.083424
# 2021-01-07  115055.674464  76.638616  ...    0.261225  0.079518
# 2021-01-08  115511.883464  76.634616  ...    0.287421  0.076124
# 2021-01-09  115893.083587  76.562072  ...    0.311950  0.073121
# 2021-01-10  116218.580085  76.456353  ...    0.334903  0.070429
# 2021-01-11  116500.720962  76.336483  ...    0.356372  0.067996
# 2021-01-12  116747.835213  76.212595  ...    0.376448  0.065785
# 2021-01-13  116965.856703  76.090002  ...    0.395219  0.063768
# 2021-01-14  117159.233108  75.971411  ...    0.412766  0.061923
# 2021-01-15  117331.444008  75.858119  ...    0.429169  0.060232
# 2021-01-16  117485.303908  75.750669  ...    0.444501  0.058678
# 2021-01-17  117623.145685  75.649193  ...    0.458830  0.057249
# 2021-01-18  117746.936626  75.553613  ...    0.472221  0.055934
# 2021-01-19  117858.355613  75.463737  ...    0.484736  0.054721
# 2021-01-20  117958.847258  75.379320  ...    0.496432  0.053601
# 2021-01-21  118049.661835  75.300095  ...    0.507361  0.052567
# 2021-01-22  118131.886016  75.225785  ...    0.517573  0.051611
# 2021-01-23  118206.467362  75.156119  ...    0.527116  0.050727
# 2021-01-24  118274.234333  75.090830  ...    0.536033  0.049908
# 2021-01-25  118335.912927  75.029664  ...    0.544364  0.049149
# 2021-01-26  118392.140691  74.972375  ...    0.552148  0.048445
# 2021-01-27  118443.478613  74.918731  ...    0.559421  0.047792
# 2021-01-28  118490.421278  74.868511  ...    0.566217  0.047186
# 2021-01-29  118533.405572  74.821505  ...    0.572566  0.046624
# 2021-01-30  118572.818151  74.777516  ...    0.578497  0.046101
# 2021-01-31  118609.001892  74.736357  ...    0.584039  0.045615
# 2021-02-01  118642.261435  74.697850  ...    0.589216  0.045163
# 2021-02-02  118672.867987  74.661830  ...    0.594053  0.044743
# 2021-02-03  118701.063468  74.628140  ...    0.598572  0.044352
# 2021-02-04  118727.064099  74.596633  ...    0.602794  0.043988
# 2021-02-05  118751.063516  74.567170  ...    0.606738  0.043649
# 2021-02-06  118773.235469  74.539621  ...    0.610422  0.043333
# 2021-02-07  118793.736172  74.513865  ...    0.613864  0.043039
# 2021-02-08  118812.706338  74.489785  ...    0.617079  0.042765
# 2021-02-09  118830.272962  74.467276  ...    0.620083  0.042509
# 2021-02-10  118846.550870  74.446234  ...    0.622889  0.042271
# 2021-02-11  118861.644071  74.426567  ...    0.625511  0.042049
# 2021-02-12  118875.646946  74.408185  ...    0.627960  0.041842
# 2021-02-13  118888.645283  74.391005  ...    0.630248  0.041649
# 2021-02-14  118900.717190  74.374949  ...    0.632385  0.041469
# 2021-02-15  118911.933895  74.359944  ...    0.634381  0.041301
# 2021-02-16  118922.360451  74.345923  ...    0.636246  0.041144
# 2021-02-17  118932.056359  74.332820  ...    0.637988  0.040998
# 2021-02-18  118941.076118  74.320576  ...    0.639616  0.040862
# 2021-02-19  118949.469710  74.309135  ...    0.641136  0.040734
# 2021-02-20  118957.283035  74.298445  ...    0.642556  0.040615
# 2021-02-21  118964.558293  74.288456  ...    0.643883  0.040504
# 2021-02-22  118971.334326  74.279124  ...    0.645122  0.040401
# 2021-02-23  118977.646923  74.270404  ...    0.646280  0.040304
# 2021-02-24  118983.529095  74.262257  ...    0.647361  0.040214
# 2021-02-25  118989.011316  74.254646  ...    0.648371  0.040130
# 2021-02-26  118994.121745  74.247534  ...    0.649315  0.040051
# 2021-02-27  118998.886424  74.240890  ...    0.650197  0.039978
# 2021-02-28  119003.329451  74.234683  ...    0.651020  0.039909
#
# [60 rows x 8 columns]

# %%
#Combine the original demand and forecasted demand
prediction = prediction.iloc[1:]
output = pd.DataFrame()
output['demand'] = testing_set['demand']
output['forecasted_demand'] = prediction['demand']

# %%
#Plot the output of the VARMA model
output.plot()

# %%
#Performance metric
print("Mean Absolute Error: ", mean_absolute_error(output['demand'],output['forecasted_demand']))
print("Mean Absolute Percentage Error: ", np.mean(np.abs((output['demand'] - output['forecasted_demand']) / output['demand'])) * 100)
print("Mean Squared Error: ", mean_squared_error(output['demand'],output['forecasted_demand']))
print("Root Mean Squared Error: ", sqrt(mean_squared_error(output['demand'],output['forecasted_demand'])))
print("R2 score: ", r2_score(output['demand'],output['forecasted_demand']))
# Out:
# Mean Absolute Error:  12839.50738277082
# Mean Absolute Percentage Error:  12.124562468378993
# Mean Squared Error:  220242180.0772266
# Root Mean Squared Error:  14840.558617424973
# R2 score:  -0.2465245286878317

# %%
pip install --upgrade mxnet~=1.7 gluonts
# Out:
# Collecting mxnet~=1.7
#   Downloading https://files.pythonhosted.org/packages/30/07/66174e78c12a3048db9039aaa09553e35035ef3a008ba3e0ed8d2aa3c47b/mxnet-1.8.0.post0-py2.py3-none-manylinux2014_x86_64.whl (46.9MB)
#      |████████████████████████████████| 46.9MB 93kB/s
# Collecting gluonts
#   Downloading https://files.pythonhosted.org/packages/9b/85/46fd20392a2ede6f395f5051597ba0fbc6b986cf8cb1c14980f0c127e743/gluonts-0.7.1-py3-none-any.whl (896kB)
#      |████████████████████████████████| 901kB 36.5MB/s
# Requirement already satisfied, skipping upgrade: numpy<2.0.0,>1.16.0 in /usr/local/lib/python3.7/dist-packages (from mxnet~=1.7) (1.19.5)
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading https://files.pythonhosted.org/packages/53/39/4ab213673844e0c004bed8a0781a0721a3f6bb23eb8854ee75c236428892/graphviz-0.8.4-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: requests<3,>=2.20.0 in /usr/local/lib/python3.7/dist-packages (from mxnet~=1.7) (2.23.0)
# Requirement already satisfied, skipping upgrade: toolz~=0.10 in /usr/local/lib/python3.7/dist-packages (from gluonts) (0.11.1)
# Requirement already satisfied, skipping upgrade: matplotlib~=3.0 in /usr/local/lib/python3.7/dist-packages (from gluonts) (3.2.2)
# Requirement already satisfied, skipping upgrade: tqdm~=4.23 in /usr/local/lib/python3.7/dist-packages (from gluonts) (4.41.1)
# Requirement already satisfied, skipping upgrade: pandas~=1.0 in /usr/local/lib/python3.7/dist-packages (from gluonts) (1.1.5)
# Requirement already satisfied, skipping upgrade: holidays>=0.9 in /usr/local/lib/python3.7/dist-packages (from gluonts) (0.10.5.2)
# Collecting pydantic~=1.1
#   Downloading https://files.pythonhosted.org/packages/2b/a3/0ffdb6c63f45f10d19b8e8b32670b22ed089cafb29732f6bf8ce518821fb/pydantic-1.8.1-cp37-cp37m-manylinux2014_x86_64.whl (10.1MB)
#      |████████████████████████████████| 10.1MB 41.4MB/s
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet~=1.7) (2020.12.5)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet~=1.7) (1.24.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet~=1.7) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet~=1.7) (3.0.4)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib~=3.0->gluonts) (2.4.7)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib~=3.0->gluonts) (2.8.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib~=3.0->gluonts) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib~=3.0->gluonts) (1.3.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas~=1.0->gluonts) (2018.9)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from holidays>=0.9->gluonts) (1.15.0)
# Requirement already satisfied, skipping upgrade: korean-lunar-calendar in /usr/local/lib/python3.7/dist-packages (from holidays>=0.9->gluonts) (0.2.1)
# Requirement already satisfied, skipping upgrade: hijri-converter in /usr/local/lib/python3.7/dist-packages (from holidays>=0.9->gluonts) (2.1.1)
# Requirement already satisfied, skipping upgrade: convertdate>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from holidays>=0.9->gluonts) (2.3.2)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from pydantic~=1.1->gluonts) (3.7.4.3)
# Requirement already satisfied, skipping upgrade: pymeeus<=1,>=0.3.13 in /usr/local/lib/python3.7/dist-packages (from convertdate>=2.3.0->holidays>=0.9->gluonts) (0.5.11)
# Installing collected packages: graphviz, mxnet, pydantic, gluonts
#   Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
# Successfully installed gluonts-0.7.1 graphviz-0.8.4 mxnet-1.8.0.post0 pydantic-1.8.1

# %%
from gluonts.model.lstnet import LSTNetEstimator
from gluonts.evaluation.backtest import backtest_metrics
from gluonts.evaluation import MultivariateEvaluator

# %%
#Split the dataset to form training and testing set
training_set = dataset.iloc[:2191]
testing_set = dataset.iloc[2192:]

#Display the training and testing dataset
print("Training dataset: \n", training_set.tail())
print("\nTesting dataset: \n", testing_set.head())
# Out:
# Training dataset:
#                 demand        RRP  ...  school_day  holiday
# date                              ...
# 2020-12-26  88980.895  31.239583  ...           0        0
# 2020-12-27  96137.560   6.380417  ...           0        0
# 2020-12-28  85792.090   8.254583  ...           0        1
# 2020-12-29  90537.375  23.902917  ...           0        0
# 2020-12-30  93732.335  29.288958  ...           0        0
#
# [5 rows x 8 columns]
#
# Testing dataset:
#                  demand        RRP  ...  school_day  holiday
# date                               ...
# 2021-01-01   92926.685  18.296383  ...           0        1
# 2021-01-02   98995.065  21.890208  ...           0        0
# 2021-01-03   94371.480  19.487708  ...           0        0
# 2021-01-04   99640.535   4.791042  ...           0        0
# 2021-01-05  103840.455   7.464583  ...           0        0
#
# [5 rows x 8 columns]

# %%
estimator = LSTNetEstimator(freq='D', prediction_length= 59, context_length= 12, num_series= 7, skip_size= 4, ar_window= 4, channels= 24*5)
agg_metrics = backtest_metrics(test_dataset=training_set, predictor= testing_set)
# Out:
#   0%|          | 0/2191 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-14a8aec1f5f5> in <module>()
#       1 estimator = LSTNetEstimator(freq='D', prediction_length= 59, context_length= 12, num_series= 7, skip_size= 4, ar_window= 4, channels= 24*5)
# ----> 2 agg_metrics = backtest_metrics(test_dataset=training_set, predictor= testing_set)
#
# /usr/local/lib/python3.7/dist-packages/gluonts/evaluation/backtest.py in backtest_metrics(test_dataset, predictor, evaluator, num_samples, logging_file)
#     164         logger = logging.getLogger(__name__)
#     165
# --> 166     test_statistics = calculate_dataset_statistics(test_dataset)
#     167     serialize_message(logger, test_dataset_stats_key, test_statistics)
#     168
#
# /usr/local/lib/python3.7/dist-packages/gluonts/dataset/stat.py in calculate_dataset_statistics(ts_dataset)
#     176
#     177             # TARGET
# --> 178             target = ts[FieldName.TARGET]
#     179             observed_target = target[~np.isnan(target)]
#     180             num_observations = len(observed_target)
#
# TypeError: string indices must be integers

# %% [markdown]
# The predictor parameter requires a certain value. We browsed through relevant resources and official documentation but were unable to find the exact parameters which were supposed to be passed. Due to this reason we could not further code the model.

# %%
# !pip install sagemaker
import logging
from sagemaker.mxnet import MXNet
# Out:
# Collecting sagemaker
#   Downloading https://files.pythonhosted.org/packages/35/e1/73c6e43131147b86062f823e8cfd8a17b19a93b1bdb365eee2c8214cfad2/sagemaker-2.39.1.tar.gz (409kB)
#      |████████████████████████████████| 409kB 6.4MB/s
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from sagemaker) (20.3.0)
# Collecting boto3>=1.16.32
#   Downloading https://files.pythonhosted.org/packages/b0/56/97a4dd51951f3b23c734ad2bb4d9be30198d38b053fbfe65902f3a8b7e28/boto3-1.17.68-py2.py3-none-any.whl (131kB)
#      |████████████████████████████████| 133kB 20.1MB/s
# Requirement already satisfied: google-pasta in /usr/local/lib/python3.7/dist-packages (from sagemaker) (0.2.0)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from sagemaker) (1.19.5)
# Requirement already satisfied: protobuf>=3.1 in /usr/local/lib/python3.7/dist-packages (from sagemaker) (3.12.4)
# Collecting protobuf3-to-dict>=0.1.5
#   Downloading https://files.pythonhosted.org/packages/6b/55/522bb43539fed463275ee803d79851faaebe86d17e7e3dbc89870d0322b9/protobuf3-to-dict-0.1.5.tar.gz
# Collecting smdebug_rulesconfig==1.0.1
#   Downloading https://files.pythonhosted.org/packages/26/a1/45a13a05198bbe9527bab2c5e5daa8bd02678aa825eec14783e767bfa7d1/smdebug_rulesconfig-1.0.1-py2.py3-none-any.whl
# Requirement already satisfied: importlib-metadata>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from sagemaker) (3.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from sagemaker) (20.9)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from sagemaker) (1.1.5)
# Collecting pathos
#   Downloading https://files.pythonhosted.org/packages/10/9e/0100b1d500851fc8e093da5463ca38e013c86ea0855e7c510ca0d3e1f7c1/pathos-0.2.7-py2.py3-none-any.whl (81kB)
#      |████████████████████████████████| 81kB 7.7MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading https://files.pythonhosted.org/packages/07/cb/5f001272b6faeb23c1c9e0acc04d48eaaf5c862c17709d20e3469c6e0139/jmespath-0.10.0-py2.py3-none-any.whl
# Collecting s3transfer<0.5.0,>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/63/d0/693477c688348654ddc21dcdce0817653a294aa43f41771084c25e7ff9c7/s3transfer-0.4.2-py2.py3-none-any.whl (79kB)
#      |████████████████████████████████| 81kB 8.1MB/s
# Collecting botocore<1.21.0,>=1.20.68
#   Downloading https://files.pythonhosted.org/packages/43/8d/214334141c72d426d4a19c11f185ad23d4b604ce230a67fb1dfc36ac7b80/botocore-1.20.68-py2.py3-none-any.whl (7.5MB)
#      |████████████████████████████████| 7.5MB 16.3MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from google-pasta->sagemaker) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.1->sagemaker) (56.0.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4.0->sagemaker) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4.0->sagemaker) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->sagemaker) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->sagemaker) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->sagemaker) (2018.9)
# Collecting ppft>=1.6.6.3
#   Downloading https://files.pythonhosted.org/packages/51/7b/e63dcf1f9b5ecd37691ee8a7029f71ddb7cafab780a60e312d913afc0f29/ppft-1.6.6.3-py3-none-any.whl (65kB)
#      |████████████████████████████████| 71kB 8.1MB/s
# Requirement already satisfied: dill>=0.3.3 in /usr/local/lib/python3.7/dist-packages (from pathos->sagemaker) (0.3.3)
# Requirement already satisfied: multiprocess>=0.70.11 in /usr/local/lib/python3.7/dist-packages (from pathos->sagemaker) (0.70.11.1)
# Collecting pox>=0.2.9
#   Downloading https://files.pythonhosted.org/packages/6b/06/600e1b1103336ce94cf01e63a6c7b134f0edccf59bbf99189c975e2f257e/pox-0.2.9-py2.py3-none-any.whl
# Collecting urllib3<1.27,>=1.25.4
#   Downloading https://files.pythonhosted.org/packages/09/c6/d3e3abe5b4f4f16cf0dfc9240ab7ce10c2baa0e268989a4e3ec19e90c84e/urllib3-1.26.4-py2.py3-none-any.whl (153kB)
#      |████████████████████████████████| 153kB 45.2MB/s
# Building wheels for collected packages: sagemaker, protobuf3-to-dict
#   Building wheel for sagemaker (setup.py) ... done
#   Created wheel for sagemaker: filename=sagemaker-2.39.1-py2.py3-none-any.whl size=573461 sha256=db0d94892a6b61a690c1328082f63e758a512242ae03c787ae309fcac3cc7245
#   Stored in directory: /root/.cache/pip/wheels/17/15/45/ef42abda7e4a3ee3a7df478aaf51c220f32c62146ea7e12fd6
#   Building wheel for protobuf3-to-dict (setup.py) ... done
#   Created wheel for protobuf3-to-dict: filename=protobuf3_to_dict-0.1.5-cp37-none-any.whl size=4030 sha256=8332d1af38de0b1a570b20b764eab1c062b55439e9906dce31e99013e78b7aae
#   Stored in directory: /root/.cache/pip/wheels/37/42/d8/1609d310cabebc2cf60eca038fa2b0c8503412963734a6fc31
# Successfully built sagemaker protobuf3-to-dict
# ERROR: requests 2.23.0 has requirement urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you'll have urllib3 1.26.4 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# Installing collected packages: jmespath, urllib3, botocore, s3transfer, boto3, protobuf3-to-dict, smdebug-rulesconfig, ppft, pox, pathos, sagemaker
#   Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed boto3-1.17.68 botocore-1.20.68 jmespath-0.10.0 pathos-0.2.7 pox-0.2.9 ppft-1.6.6.3 protobuf3-to-dict-0.1.5 s3transfer-0.4.2 sagemaker-2.39.1 smdebug-rulesconfig-1.0.1 urllib3-1.26.4

# %%
CONTEXT_LENGTH = 12
PREDICTION_LENGTH = 6
hyperparameters = {
    'context_length': CONTEXT_LENGTH,
    'prediction_length': PREDICTION_LENGTH,
    'skip_size': 4,
    'ar_window': 4,
    'channels': 72,
    'scaling': False,
    'output_activation': 'sigmoid',
    'epochs': 1,
}
mxnet_estimator = MXNet('train.py',
                        instance_type='ml.p2.xlarge',
                        instance_count=1,
                        framework_version='1.6.0',
                        py_version='py3',
                        hyperparameters={'batch-size': 313,
                                         'epochs': 10,
                                         'learning-rate': 0.1},role = None)
estimator.fit(training_set)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-3e54c4748ec1> in <module>()
#      18                         hyperparameters={'batch-size': 313,
#      19                                          'epochs': 10,
# ---> 20                                          'learning-rate': 0.1},role = None)
#      21 estimator.fit(training_set)
#
# /usr/local/lib/python3.7/dist-packages/sagemaker/mxnet/estimator.py in __init__(self, entry_point, framework_version, py_version, source_dir, hyperparameters, image_uri, distribution, **kwargs)
#     168
#     169         super(MXNet, self).__init__(
# --> 170             entry_point, source_dir, hyperparameters, image_uri=image_uri, **kwargs
#     171         )
#     172
#
# /usr/local/lib/python3.7/dist-packages/sagemaker/estimator.py in __init__(self, entry_point, source_dir, hyperparameters, container_log_level, code_location, image_uri, dependencies, enable_network_isolation, git_config, checkpoint_s3_uri, checkpoint_local_path, enable_sagemaker_metrics, **kwargs)
#    2138             :class:`~sagemaker.estimator.EstimatorBase`.
#    2139         """
# -> 2140         super(Framework, self).__init__(enable_network_isolation=enable_network_isolation, **kwargs)
#    2141         image_uri = renamed_kwargs("image_name", "image_uri", image_uri, kwargs)
#    2142         if entry_point.startswith("s3://"):
#
# /usr/local/lib/python3.7/dist-packages/sagemaker/estimator.py in __init__(self, role, instance_count, instance_type, volume_size, volume_kms_key, max_run, input_mode, output_path, output_kms_key, base_job_name, sagemaker_session, tags, subnets, security_group_ids, model_uri, model_channel_name, metric_definitions, encrypt_inter_container_traffic, use_spot_instances, max_wait, checkpoint_s3_uri, checkpoint_local_path, rules, debugger_hook_config, tensorboard_output_config, enable_sagemaker_metrics, enable_network_isolation, profiler_config, disable_profiler, environment, **kwargs)
#     315                 )
#     316         else:
# --> 317             self.sagemaker_session = sagemaker_session or Session()
#     318
#     319         self.base_job_name = base_job_name
#
# /usr/local/lib/python3.7/dist-packages/sagemaker/session.py in __init__(self, boto_session, sagemaker_client, sagemaker_runtime_client, sagemaker_featurestore_runtime_client, default_bucket)
#     122             sagemaker_client=sagemaker_client,
#     123             sagemaker_runtime_client=sagemaker_runtime_client,
# --> 124             sagemaker_featurestore_runtime_client=sagemaker_featurestore_runtime_client,
#     125         )
#     126
#
# /usr/local/lib/python3.7/dist-packages/sagemaker/session.py in _initialize(self, boto_session, sagemaker_client, sagemaker_runtime_client, sagemaker_featurestore_runtime_client)
#     142         if self._region_name is None:
#     143             raise ValueError(
# --> 144                 "Must setup local AWS configuration with a region supported by SageMaker."
#     145             )
#     146
#
# ValueError: Must setup local AWS configuration with a region supported by SageMaker.

# %% [markdown]
# We need to setup the AWS configuration and did not find any relevant resources to setup the account. Due to this reason we could not further code the model.
