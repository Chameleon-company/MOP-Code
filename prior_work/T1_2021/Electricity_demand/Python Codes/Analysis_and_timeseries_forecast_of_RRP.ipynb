# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder 
from pandas import read_csv
from statsmodels.tsa.stattools import adfuller, kpss, acf, pacf, grangercausalitytests
from statsmodels.tsa.api import VAR

from fbprophet import Prophet
from fbprophet.plot import plot_plotly

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, LeakyReLU, Dropout
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.callbacks import EarlyStopping
from keras.metrics import MeanAbsoluteError
from keras.losses import MeanSquaredError
from keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from math import sqrt

pd.reset_option('all')

import seaborn as sns

sns.set(rc={'figure.figsize':(11.7,8.27)})
# Out:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.

# %%
#Reading as pandas dataframe
data = pd.read_csv('electricity_demand.csv')

# %%
#Viewing the data rows
data.head()
# Out:
#         date      demand        RRP  ...  rainfall  school_day  holiday
# 0  1/01/2015   99635.030  25.633696  ...       0.0           N        Y
# 1  1/02/2015  129606.010  33.138988  ...       0.0           N        N
# 2  1/03/2015  142300.540  34.564855  ...       0.0           N        N
# 3  1/04/2015  104330.715  25.005560  ...       4.2           N        N
# 4  1/05/2015  118132.200  26.724176  ...       0.0           N        N
#
# [5 rows x 9 columns]

# %%
#Encoding the categorical features in our data
data [['school_day', 'holiday']] = data[['school_day', 'holiday']].apply(LabelEncoder().fit_transform)

# %%
#Getting the correlation matrix
data.corr()
# Out:
#                    demand       RRP  ...  school_day   holiday
# demand           1.000000  0.228934  ...    0.163933 -0.241669
# RRP              0.228934  1.000000  ...    0.008829 -0.031031
# min_temperature -0.152410  0.059147  ...   -0.084688  0.064289
# max_temperature -0.066570  0.150755  ...   -0.090167  0.039383
# solar_exposure  -0.275652  0.043693  ...   -0.102242  0.041119
# rainfall        -0.067747 -0.029845  ...   -0.021966 -0.011630
# school_day       0.163933  0.008829  ...    1.000000 -0.165140
# holiday         -0.241669 -0.031031  ...   -0.165140  1.000000
#
# [8 rows x 8 columns]

# %% [markdown]
# *Since the column demand and demand_pos_RRP have similar values, to avoid redundancy we need to remove the demand_pos_RRP column before building our model, as the demand is our dependent variable and we do not want data leakage in our model. Similarly, we can see that the RRP and the RRP_positive is highly correlated (~0.99), we need to remove one of these features before building our model. As the features RRP is slighly higher correlated with the depedent variable demand, we drop the demand_pos_RRP column.*

# %%
#Check for NA values
data.isnull().sum(axis = 0)
# Out:
# date               0
# demand             0
# RRP                0
# min_temperature    0
# max_temperature    0
# solar_exposure     0
# rainfall           0
# school_day         0
# holiday            0
# dtype: int64

# %% [markdown]
# *As the columns solar_exposure and rainfall have NA values, we can replace the NA values with the average values of the respective columns.*

# %%
#Filing NA values with average values for respective columns  
data.fillna(data.mean(), inplace = True)

# %%
#Validating the changes
data.isnull().sum(axis = 0)
# Out:
# date               0
# demand             0
# RRP                0
# min_temperature    0
# max_temperature    0
# solar_exposure     0
# rainfall           0
# school_day         0
# holiday            0
# dtype: int64

# %%
#Correlation plot
rs = np.random.RandomState(0)
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_8cfacca6_a563_11eb_a77a_0242ac1c0002row0_col0,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row1_col1,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row2_col2,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row3_col3,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row4_col4,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row5_col5,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row6_col6,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row7_col7{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row0_col1,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row1_col4{
#             background-color:  #8db0fe;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row0_col2,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row0_col4,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row0_col7,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row3_col5,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row4_col0,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row5_col1,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row5_col3,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row7_col1,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row7_col6{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row0_col3,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row0_col5{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row0_col6{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row1_col0{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row1_col2{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row1_col3{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row1_col5{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row1_col6{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row1_col7,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row7_col3{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row2_col0{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row2_col1{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row2_col3{
#             background-color:  #f59d7e;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row2_col4{
#             background-color:  #dcdddd;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row2_col5{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row2_col6{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row2_col7,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row7_col4{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row3_col0,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row5_col0{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row3_col1{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row3_col2{
#             background-color:  #f59f80;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row3_col4{
#             background-color:  #f7b497;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row3_col6{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row3_col7{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row4_col1{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row4_col2{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row4_col3{
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row4_col5,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row7_col0{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row4_col6{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row4_col7{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row5_col2,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row6_col4{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row5_col4,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row6_col5{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row5_col6{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row5_col7{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row6_col0{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row6_col1{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row6_col2,#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row6_col7{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row6_col3{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row7_col2{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_8cfacca6_a563_11eb_a77a_0242ac1c0002row7_col5{
#             background-color:  #6282ea;
#             color:  #000000;
#         }</style><table id="T_8cfacca6_a563_11eb_a77a_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >demand</th>        <th class="col_heading level0 col1" >RRP</th>        <th class="col_heading level0 col2" >min_temperature</th>        <th class="col_heading level0 col3" >max_temperature</th>        <th class="col_heading level0 col4" >solar_exposure</th>        <th class="col_heading level0 col5" >rainfall</th>        <th class="col_heading level0 col6" >school_day</th>        <th class="col_heading level0 col7" >holiday</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8cfacca6_a563_11eb_a77a_0242ac1c0002level0_row0" class="row_heading level0 row0" >demand</th>
#                         <td id="T_8cfacca6_a563_11eb_a77a_0242ac1c0002row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_8cfacca6_a563_11eb_a77a_0242ac1c0002row0_col1" class="data row0 col1" >0.228934</td>
#                         <td id="T_8cfacca6_a563_11eb_a77a_0242ac1c0002row0_col2" class="data row0 col2" >-0.152410</td>
#                         <td id="T_8cfacca6_a563_11eb_a77a_0242ac1c0002row0_col3" class="data row0 col3" >-0.066570</td>
#                         <td id="T_8cfacca6_a563_11eb_a77a_0242ac1c0002row0_col4" class="data row0 col4" >-0.275652</td>
#                         <td id="T_8cfacca6_a563_11eb_a77a_0242ac1c0002row0_col5" class="data row0 col5" >-0.067747</td>
#                         <td id="T_8cfacca6_a563_11eb_a77a_0242ac1c0002row0_col6" class="data row0 col6" >0.163933</td>
#                         <td id="T_8cfacca6_a563_11eb_a77a_0242ac1c0002row0_

# %% [markdown]
# #Demand feature

# %%
#Histogram of the dependent variable
sns.histplot(data=data, x="demand")

# %%
#Pairplot of the features to understand the trend
sns.pairplot(data, diag_kws={'bins': 10})

# %%
#Splitting into indepedent features and dependent features.
x = data[[ 'RRP', 'min_temperature', 'max_temperature',
       'solar_exposure', 'rainfall', 'school_day', 'holiday']]
y = data['demand']

# %% [markdown]
# Relevant features using f_regression and mutual info analysis.

# %%
#Identifying relevant features using Feature selection 
from sklearn.feature_selection import SelectKBest, f_regression, mutual_info_regression

xy = SelectKBest(f_regression, k = 'all')
xy.fit(x, y)
# Out:
# SelectKBest(k='all', score_func=<function f_regression at 0x7f9306f26170>)

# %%
for i in range(7):
  print("The p-value for the variable", x.columns[i],"is", round((xy.pvalues_[i]),4))
# Out:
# The p-value for the variable RRP is 0.0
# The p-value for the variable min_temperature is 0.0
# The p-value for the variable max_temperature is 0.0016
# The p-value for the variable solar_exposure is 0.0
# The p-value for the variable rainfall is 0.0013
# The p-value for the variable school_day is 0.0
# The p-value for the variable holiday is 0.0

# %%
for i in range(7):
  print("The scores for the variable", x.columns[i],"is", round((xy.scores_[i]),4))
# Out:
# The scores for the variable RRP is 124.3908
# The scores for the variable min_temperature is 53.4837
# The scores for the variable max_temperature is 10.0111
# The scores for the variable solar_exposure is 184.94
# The scores for the variable rainfall is 10.3698
# The scores for the variable school_day is 62.1089
# The scores for the variable holiday is 139.497

# %% [markdown]
# *With 5% level of significance, we determine that using the ANOVA feature selection, we determine that all variables are relevant in predicting the electricity demand. However, the score for the max temperature and rainfall is very low.*

# %% [markdown]
# #Forecast RRP feature using time-series modelling

# %%
df = data[['date','min_temperature', 'max_temperature',
       'solar_exposure', 'rainfall', 'school_day', 'holiday', 'RRP']]

# %%
len(df)
# Out:
# 2251

# %% [markdown]
# #Checking for stationarity using the ADFuller test

# %% [markdown]
# **Stationarity means that the statistical properties of a process generating a time series do not change over time.**

# %%
#Split into x, y
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
#Convert date to appropriate format
x['date'] = pd.to_datetime(x['date'])
df.drop(columns = ['date'], inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Fuller test for checking stationarity in the features
for i in range(len(df.columns)):
  result = adfuller(df[df.columns[i]])
  if result[1] > 0.05:
    print(df.columns[i],"Series is non stationary")
  else: 
    print(df.columns[i], "Stationary")
# Out:
# min_temperature Stationary
# max_temperature Series is non stationary
# solar_exposure Series is non stationary
# rainfall Stationary
# school_day Stationary
# holiday Stationary
# RRP Stationary

# %% [markdown]
# #Granger causality test
#
# H0 - X(t) does not granger cause Y(t), previous values of x does not help in forecasting y.
#
# H1 - X(t) granger causes Y(t) i.e. previous x values help in forecasting y. Here x is the weather features while the y is the RRP.

# %%
#Granger causality test between min temperature and RRP 
res = grangercausalitytests(df[['min_temperature', 'RRP']], maxlag=8)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=11.3229 , p=0.0008  , df_denom=2247, df_num=1
# ssr based chi2 test:   chi2=11.3380 , p=0.0008  , df=1
# likelihood ratio test: chi2=11.3095 , p=0.0008  , df=1
# parameter F test:         F=11.3229 , p=0.0008  , df_denom=2247, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=7.0007  , p=0.0009  , df_denom=2244, df_num=2
# ssr based chi2 test:   chi2=14.0325 , p=0.0009  , df=2
# likelihood ratio test: chi2=13.9889 , p=0.0009  , df=2
# parameter F test:         F=7.0007  , p=0.0009  , df_denom=2244, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.4084  , p=0.0010  , df_denom=2241, df_num=3
# ssr based chi2 test:   chi2=16.2759 , p=0.0010  , df=3
# likelihood ratio test: chi2=16.2173 , p=0.0010  , df=3
# parameter F test:         F=5.4084  , p=0.0010  , df_denom=2241, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=4.7333  , p=0.0008  , df_denom=2238, df_num=4
# ssr based chi2 test:   chi2=19.0091 , p=0.0008  , df=4
# likelihood ratio test: chi2=18.9292 , p=0.0008  , df=4
# parameter F test:         F=4.7333  , p=0.0008  , df_denom=2238, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.9989  , p=0.0013  , df_denom=2235, df_num=5
# ssr based chi2 test:   chi2=20.0931 , p=0.0012  , df=5
# likelihood ratio test: chi2=20.0037 , p=0.0012  , df=5
# parameter F test:         F=3.9989  , p=0.0013  , df_denom=2235, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.3735  , p=0.0026  , df_denom=2232, df_num=6
# ssr based chi2 test:   chi2=20.3590 , p=0.0024  , df=6
# likelihood ratio test: chi2=20.2673 , p=0.0025  , df=6
# parameter F test:         F=3.3735  , p=0.0026  , df_denom=2232, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.6438  , p=0.0101  , df_denom=2229, df_num=7
# ssr based chi2 test:   chi2=18.6315 , p=0.0094  , df=7
# likelihood ratio test: chi2=18.5545 , p=0.0097  , df=7
# parameter F test:         F=2.6438  , p=0.0101  , df_denom=2229, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.4014  , p=0.0141  , df_denom=2226, df_num=8
# ssr based chi2 test:   chi2=19.3575 , p=0.0131  , df=8
# likelihood ratio test: chi2=19.2745 , p=0.0135  , df=8
# parameter F test:         F=2.4014  , p=0.0141  , df_denom=2226, df_num=8

# %% [markdown]
# Decision - Reject Null hypothesis, meaning previous values of min temp is useful in forecasting RRP.

# %%
#Granger causality test between max temperature and RRP 
res = grangercausalitytests(df[['max_temperature', 'RRP']], maxlag=8)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0263  , p=0.8711  , df_denom=2247, df_num=1
# ssr based chi2 test:   chi2=0.0264  , p=0.8710  , df=1
# likelihood ratio test: chi2=0.0264  , p=0.8710  , df=1
# parameter F test:         F=0.0263  , p=0.8711  , df_denom=2247, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.8303  , p=0.0030  , df_denom=2244, df_num=2
# ssr based chi2 test:   chi2=11.6867 , p=0.0029  , df=2
# likelihood ratio test: chi2=11.6564 , p=0.0029  , df=2
# parameter F test:         F=5.8303  , p=0.0030  , df_denom=2244, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.4923  , p=0.0151  , df_denom=2241, df_num=3
# ssr based chi2 test:   chi2=10.5095 , p=0.0147  , df=3
# likelihood ratio test: chi2=10.4850 , p=0.0149  , df=3
# parameter F test:         F=3.4923  , p=0.0151  , df_denom=2241, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.6514  , p=0.0316  , df_denom=2238, df_num=4
# ssr based chi2 test:   chi2=10.6483 , p=0.0308  , df=4
# likelihood ratio test: chi2=10.6231 , p=0.0311  , df=4
# parameter F test:         F=2.6514  , p=0.0316  , df_denom=2238, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.0597  , p=0.0676  , df_denom=2235, df_num=5
# ssr based chi2 test:   chi2=10.3493 , p=0.0659  , df=5
# likelihood ratio test: chi2=10.3256 , p=0.0665  , df=5
# parameter F test:         F=2.0597  , p=0.0676  , df_denom=2235, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.6014  , p=0.1427  , df_denom=2232, df_num=6
# ssr based chi2 test:   chi2=9.6641  , p=0.1395  , df=6
# likelihood ratio test: chi2=9.6433  , p=0.1405  , df=6
# parameter F test:         F=1.6014  , p=0.1427  , df_denom=2232, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.2577  , p=0.0273  , df_denom=2229, df_num=7
# ssr based chi2 test:   chi2=15.9105 , p=0.0259  , df=7
# likelihood ratio test: chi2=15.8543 , p=0.0265  , df=7
# parameter F test:         F=2.2577  , p=0.0273  , df_denom=2229, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.9466  , p=0.0495  , df_denom=2226, df_num=8
# ssr based chi2 test:   chi2=15.6919 , p=0.0470  , df=8
# likelihood ratio test: chi2=15.6373 , p=0.0479  , df=8
# parameter F test:         F=1.9466  , p=0.0495  , df_denom=2226, df_num=8

# %% [markdown]
# Decision - Reject Null hypothesis, meaning previous values of max temp is useful in forecasting RRP.

# %%
#Granger causality test between solar exposure and RRP 
res = grangercausalitytests(df[['solar_exposure', 'RRP']], maxlag=15)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.3662  , p=0.0117  , df_denom=2247, df_num=1
# ssr based chi2 test:   chi2=6.3747  , p=0.0116  , df=1
# likelihood ratio test: chi2=6.3657  , p=0.0116  , df=1
# parameter F test:         F=6.3662  , p=0.0117  , df_denom=2247, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.5087  , p=0.0111  , df_denom=2244, df_num=2
# ssr based chi2 test:   chi2=9.0375  , p=0.0109  , df=2
# likelihood ratio test: chi2=9.0194  , p=0.0110  , df=2
# parameter F test:         F=4.5087  , p=0.0111  , df_denom=2244, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.3790  , p=0.0176  , df_denom=2241, df_num=3
# ssr based chi2 test:   chi2=10.1688 , p=0.0172  , df=3
# likelihood ratio test: chi2=10.1458 , p=0.0174  , df=3
# parameter F test:         F=3.3790  , p=0.0176  , df_denom=2241, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.9419  , p=0.0034  , df_denom=2238, df_num=4
# ssr based chi2 test:   chi2=15.8309 , p=0.0033  , df=4
# likelihood ratio test: chi2=15.7754 , p=0.0033  , df=4
# parameter F test:         F=3.9419  , p=0.0034  , df_denom=2238, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.0450  , p=0.0096  , df_denom=2235, df_num=5
# ssr based chi2 test:   chi2=15.2999 , p=0.0092  , df=5
# likelihood ratio test: chi2=15.2481 , p=0.0094  , df=5
# parameter F test:         F=3.0450  , p=0.0096  , df_denom=2235, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.3893  , p=0.0264  , df_denom=2232, df_num=6
# ssr based chi2 test:   chi2=14.4194 , p=0.0253  , df=6
# likelihood ratio test: chi2=14.3733 , p=0.0257  , df=6
# parameter F test:         F=2.3893  , p=0.0264  , df_denom=2232, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.8270  , p=0.0780  , df_denom=2229, df_num=7
# ssr based chi2 test:   chi2=12.8752 , p=0.0752  , df=7
# likelihood ratio test: chi2=12.8384 , p=0.0761  , df=7
# parameter F test:         F=1.8270  , p=0.0780  , df_denom=2229, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.3620  , p=0.2083  , df_denom=2226, df_num=8
# ssr based chi2 test:   chi2=10.9794 , p=0.2029  , df=8
# likelihood ratio test: chi2=10.9527 , p=0.2044  , df=8
# parameter F test:         F=1.3620  , p=0.2083  , df_denom=2226, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.9258  , p=0.5013  , df_denom=2223, df_num=9
# ssr based chi2 test:   chi2=8.4035  , p=0.4941  , df=9
# likelihood ratio test: chi2=8.3877  , p=0.4956  , df=9
# parameter F test:         F=0.9258  , p=0.5013  , df_denom=2223, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9253  , p=0.5085  , df_denom=2220, df_num=10
# ssr based chi2 test:   chi2=9.3408  , p=0.5001  , df=10
# likelihood ratio test: chi2=9.3214  , p=0.5019  , df=10
# parameter F test:         F=0.9253  , p=0.5085  , df_denom=2220, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.7536  , p=0.0568  , df_denom=2217, df_num=11
# ssr based chi2 test:   chi2=19.4901 , p=0.0528  , df=11
# likelihood ratio test: chi2=19.4058 , p=0.0542  , df=11
# parameter F test:         F=1.7536  , p=0.0568  , df_denom=2217, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.7037  , p=0.0599  , df_denom=2214, df_num=12
# ssr based chi2 test:   chi2=20.6753 , p=0.0553  , df=12
# likelihood ratio test: chi2=20.5804 , p=0.0569  , df=12
# parameter F test:         F=1.7037  , p=0.0599  , df_denom=2214, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=1.9007  , p=0.0258  , df_denom=2211, df_num=13
# ssr based chi2 test:   chi2=25.0103 , p=0.0230  , df=13
# likelihood ratio test: chi2=24.8716 , p=0.0240  , df=13
# parameter F test:         F=1.9007  , p=0.0258  , df_denom=2211, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=1.8734  , p=0.0248  , df_denom=2208, df_num=14
# ssr based chi2 test:   chi2=26.5719 , p=0.0219  , df=14
# likelihood ratio test: chi2=26.4153 , p=0.0229  , df=14
# parameter F test:         F=1.8734  , p=0.0248  , df_denom=2208, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=1.9959  , p=0.0126  , df_denom=2205, df_num=15
# ssr based chi2 test:   chi2=30.3590 , p=0.0107  , df=15
# likelihood ratio test: chi2=30.1548 , p=0.0114  , df=15
# parameter F test:         F=1.9959  , p=0.0126  , df_denom=2205, df_num=15

# %% [markdown]
# Decision - Reject Null hypothesis, meaning previous values of solar exposure is useful in forecasting RRP.

# %%
#Granger causality test between rainfall and RRP 
res = grangercausalitytests(df[['rainfall', 'RRP']], maxlag=15)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4077  , p=0.5232  , df_denom=2247, df_num=1
# ssr based chi2 test:   chi2=0.4082  , p=0.5229  , df=1
# likelihood ratio test: chi2=0.4082  , p=0.5229  , df=1
# parameter F test:         F=0.4077  , p=0.5232  , df_denom=2247, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.3836  , p=0.2509  , df_denom=2244, df_num=2
# ssr based chi2 test:   chi2=2.7733  , p=0.2499  , df=2
# likelihood ratio test: chi2=2.7716  , p=0.2501  , df=2
# parameter F test:         F=1.3836  , p=0.2509  , df_denom=2244, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0340  , p=0.3764  , df_denom=2241, df_num=3
# ssr based chi2 test:   chi2=3.1117  , p=0.3747  , df=3
# likelihood ratio test: chi2=3.1095  , p=0.3750  , df=3
# parameter F test:         F=1.0340  , p=0.3764  , df_denom=2241, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.9382  , p=0.4407  , df_denom=2238, df_num=4
# ssr based chi2 test:   chi2=3.7681  , p=0.4383  , df=4
# likelihood ratio test: chi2=3.7649  , p=0.4388  , df=4
# parameter F test:         F=0.9382  , p=0.4407  , df_denom=2238, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7826  , p=0.5622  , df_denom=2235, df_num=5
# ssr based chi2 test:   chi2=3.9321  , p=0.5592  , df=5
# likelihood ratio test: chi2=3.9286  , p=0.5597  , df=5
# parameter F test:         F=0.7826  , p=0.5622  , df_denom=2235, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6755  , p=0.6695  , df_denom=2232, df_num=6
# ssr based chi2 test:   chi2=4.0766  , p=0.6663  , df=6
# likelihood ratio test: chi2=4.0729  , p=0.6668  , df=6
# parameter F test:         F=0.6755  , p=0.6695  , df_denom=2232, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6245  , p=0.7360  , df_denom=2229, df_num=7
# ssr based chi2 test:   chi2=4.4010  , p=0.7326  , df=7
# likelihood ratio test: chi2=4.3967  , p=0.7331  , df=7
# parameter F test:         F=0.6245  , p=0.7360  , df_denom=2229, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5826  , p=0.7930  , df_denom=2226, df_num=8
# ssr based chi2 test:   chi2=4.6961  , p=0.7895  , df=8
# likelihood ratio test: chi2=4.6912  , p=0.7900  , df=8
# parameter F test:         F=0.5826  , p=0.7930  , df_denom=2226, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5072  , p=0.8703  , df_denom=2223, df_num=9
# ssr based chi2 test:   chi2=4.6040  , p=0.8674  , df=9
# likelihood ratio test: chi2=4.5993  , p=0.8677  , df=9
# parameter F test:         F=0.5072  , p=0.8703  , df_denom=2223, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.4654  , p=0.9128  , df_denom=2220, df_num=10
# ssr based chi2 test:   chi2=4.6982  , p=0.9104  , df=10
# likelihood ratio test: chi2=4.6933  , p=0.9107  , df=10
# parameter F test:         F=0.4654  , p=0.9128  , df_denom=2220, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.4183  , p=0.9488  , df_denom=2217, df_num=11
# ssr based chi2 test:   chi2=4.6487  , p=0.9470  , df=11
# likelihood ratio test: chi2=4.6439  , p=0.9472  , df=11
# parameter F test:         F=0.4183  , p=0.9488  , df_denom=2217, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.4222  , p=0.9555  , df_denom=2214, df_num=12
# ssr based chi2 test:   chi2=5.1231  , p=0.9537  , df=12
# likelihood ratio test: chi2=5.1173  , p=0.9539  , df=12
# parameter F test:         F=0.4222  , p=0.9555  , df_denom=2214, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=0.4746  , p=0.9395  , df_denom=2211, df_num=13
# ssr based chi2 test:   chi2=6.2455  , p=0.9368  , df=13
# likelihood ratio test: chi2=6.2368  , p=0.9371  , df=13
# parameter F test:         F=0.4746  , p=0.9395  , df_denom=2211, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=0.5672  , p=0.8920  , df_denom=2208, df_num=14
# ssr based chi2 test:   chi2=8.0447  , p=0.8870  , df=14
# likelihood ratio test: chi2=8.0302  , p=0.8877  , df=14
# parameter F test:         F=0.5672  , p=0.8920  , df_denom=2208, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=0.5573  , p=0.9082  , df_denom=2205, df_num=15
# ssr based chi2 test:   chi2=8.4774  , p=0.9032  , df=15
# likelihood ratio test: chi2=8.4614  , p=0.9040  , df=15
# parameter F test:         F=0.5573  , p=0.9082  , df_denom=2205, df_num=15

# %% [markdown]
# Decision - Fail to reject Null hypothesis, meaning previous values of rainfall is not useful in forecasting RRP.

# %% [markdown]
# #Var Model

# %%
#Formatting the dataset
dff = data[['date', 'min_temperature', 'max_temperature', 'solar_exposure', 'rainfall', 'RRP']]
dff['date'] = pd.to_datetime(dff['date'])

dff.set_index('date', inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Train-test split
train_data = dff[:int(0.95*(len(dff)))]
test_data = dff[int(0.95*(len(dff))):]

# %%
#View the train data
train_data
# Out:
#             min_temperature  max_temperature  ...  rainfall        RRP
# date                                          ...
# 2015-01-01             13.3             26.9  ...       0.0  25.633696
# 2015-01-02             15.4             38.8  ...       0.0  33.138988
# 2015-01-03             20.0             38.2  ...       0.0  34.564855
# 2015-01-04             16.3             21.4  ...       4.2  25.005560
# 2015-01-05             15.0             22.0  ...       0.0  26.724176
# ...                     ...              ...  ...       ...        ...
# 2020-11-03             12.1             30.4  ...       0.0  41.192083
# 2020-11-04             21.9             22.8  ...       0.0  56.009792
# 2020-11-05             11.1             15.8  ...       2.8  49.173125
# 2020-11-06              9.5             16.6  ...       0.2  58.043333
# 2020-11-07             11.3             16.1  ...       1.6  27.226042
#
# [2138 rows x 5 columns]

# %%
test_data
# Out:
#             min_temperature  max_temperature  solar_exposure  rainfall
# date
# 2020-11-08              8.4             19.5            28.9       0.0
# 2020-11-09             11.3             29.0            28.8       0.0
# 2020-11-10             16.1             32.0            29.1       0.0
# 2020-11-11             22.8             28.3             6.5       0.0
# 2020-11-12             19.3             25.5            20.6       4.0
# ...                     ...              ...             ...       ...
# 2021-02-24             11.6             20.2            23.3       0.0
# 2021-02-25             10.7             24.3            18.9       0.0
# 2021-02-26             12.3             19.7            15.7       0.4
# 2021-02-27             11.1             18.6            11.8       0.0
# 2021-02-28              7.9             26.7            23.3       0.0
#
# [113 rows x 4 columns]

# %%
train_data.shape
# Out:
# (2138, 4)

# %%
test_data.shape
# Out:
# (113, 4)

# %%
#Create the VAR instance
var = VAR(train_data, freq = 'D')

# %%
#Fit the model
var_fit= var.fit(maxlags = 15)

# %%
#Model summary
print(var_fit.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 11, Apr, 2021
# Time:                     11:37:48
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                    10.6064
# Nobs:                     2123.00    HQIC:                   10.1940
# Log likelihood:          -22373.7    FPE:                    21076.1
# AIC:                      9.95583    Det(Omega_mle):         18818.3
# --------------------------------------------------------------------
# Results for equation min_temperature
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -1.073712         0.318987           -3.366           0.001
# L1.min_temperature          0.323454         0.023980           13.488           0.000
# L1.max_temperature          0.343777         0.013132           26.178           0.000
# L1.solar_exposure          -0.005733         0.010409           -0.551           0.582
# L1.rainfall                 0.005693         0.011791            0.483           0.629
# L2.min_temperature         -0.029008         0.025408           -1.142           0.254
# L2.max_temperature         -0.057616         0.015584           -3.697           0.000
# L2.solar_exposure          -0.011418         0.011395           -1.002           0.316
# L2.rainfall                -0.008175         0.011920           -0.686           0.493
# L3.min_temperature          0.057682         0.025426            2.269           0.023
# L3.max_temperature          0.002533         0.015702            0.161           0.872
# L3.solar_exposure           0.030484         0.011448            2.663           0.008
# L3.rainfall                -0.005042         0.011937           -0.422           0.673
# L4.min_temperature          0.000547         0.025498            0.021           0.983
# L4.max_temperature          0.010526         0.015682            0.671           0.502
# L4.solar_exposure          -0.014668         0.011462           -1.280           0.201
# L4.rainfall                 0.005896         0.011938            0.494           0.621
# L5.min_temperature          0.030527         0.025486            1.198           0.231
# L5.max_temperature         -0.004302         0.015654           -0.275           0.783
# L5.solar_exposure           0.006449         0.011467            0.562           0.574
# L5.rainfall                -0.012776         0.011942           -1.070           0.285
# L6.min_temperature          0.013055         0.025490            0.512           0.609
# L6.max_temperature         -0.001774         0.015671           -0.113           0.910
# L6.solar_exposure          -0.001495         0.011483           -0.130           0.896
# L6.rainfall                 0.025707         0.011946            2.152           0.031
# L7.min_temperature          0.024580         0.025497            0.964           0.335
# L7.max_temperature         -0.011782         0.015660           -0.752           0.452
# L7.solar_exposure           0.026110         0.011471            2.276           0.023
# L7.rainfall                 0.009137         0.011940            0.765           0.444
# L8.min_temperature         -0.014975         0.025511           -0.587           0.557
# L8.max_temperature          0.004904         0.015681            0.313           0.754
# L8.solar_exposure           0.002942         0.011514            0.256           0.798
# L8.rainfall                 0.005913         0.011861            0.499           0.618
# L9.min_temperature          0.058247         0.025480            2.286           0.022
# L9.max_temperature          0.000626         0.015667            0.040           0.968
# L9.solar_exposure           0.009237         0.011580            0.798           0.425
# L9.rainfall                 0.004414         0.011851            0.372           0.710
# L10.min_temperature        -0.003531         0.025492           -0.139           0.890
# L10.max_temperature         0.014275         0.015633            0.913           0.361
# L10.solar_exposure          0.001928         0.011578            0.166           0.868
# L10.rainfall                0.000165         0.011845            0.014           0.989
# L11.min_temperature         0.042148         0.025470            1.655           0.098
# L11.max_temperature        -0.007444         0.015636           -0.476           0.634
# L11.solar_exposure         -0.011855         0.011592           -1.023           0.306
# L11.rainfall                0.014392         0.011835            1.216           0.224
# L12.min_temperature        -0.002827         0.025460           -0.111           0.912
# L12.max_temperature        -0.002415         0.015674           -0.154           0.878
# L12.solar_exposure          0.006923         0.011584            0.598           0.550
# L12.rainfall               -0.012941         0.011824           -1.094           0.274
# L13.min_temperature         0.008948         0.025395            0.352           0.725
# L13.max_temperature        -0.005604         0.015647           -0.358           0.720
# L13.solar_exposure         -0.010418         0.011596           -0.898           0.369
# L13.rainfall                0.021628         0.011818            1.830           0.067
# L14.min_temperature        -0.028737         0.025292           -1.136           0.256
# L14.max_temperature         0.005519         0.015629            0.353           0.724
# L14.solar_exposure         -0.008641         0.011607           -0.744           0.457
# L14.rainfall                0.006717         0.011754            0.572           0.568
# L15.min_temperature         0.044606         0.020286            2.199           0.028
# L15.max_temperature        -0.003679         0.014801           -0.249           0.804
# L15.solar_exposure          0.022393         0.011317            1.979           0.048
# L15.rainfall               -0.008864         0.011253           -0.788           0.431
# ======================================================================================
#
# Results for equation max_temperature
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       4.293525         0.586701            7.318           0.000
# L1.min_temperature          0.008876         0.044106            0.201           0.841
# L1.max_temperature          0.347357         0.024153           14.381           0.000
# L1.solar_exposure           0.225835         0.019146           11.796           0.000
# L1.rainfall                -0.058716         0.021686           -2.708           0.007
# L2.min_temperature          0.061106         0.046733            1.308           0.191
# L2.max_temperature         -0.070377         0.028664           -2.455           0.014
# L2.solar_exposure          -0.001234         0.020958           -0.059           0.953
# L2.rainfall                -0.055768         0.021924           -2.544           0.011
# L3.min_temperature          0.024089         0.046764            0.515           0.606
# L3.max_temperature         -0.005339         0.028880           -0.185           0.853
# L3.solar_exposure           0.008141         0.021057            0.387           0.699
# L3.rainfall                -0.029471         0.021955           -1.342           0.179
# L4.min_temperature          0.035691         0.046897            0.761           0.447
# L4.max_temperature         -0.000681         0.028844           -0.024           0.981
# L4.solar_exposure          -0.005384         0.021081           -0.255           0.798
# L4.rainfall                 0.009326         0.021958            0.425           0.671
# L5.min_temperature          0.033800         0.046875            0.721           0.471
# L5.max_temperature          0.010317         0.028791            0.358           0.720
# L5.solar_exposure           0.056019         0.021090            2.656           0.008
# L5.rainfall                -0.011765         0.021964           -0.536           0.592
# L6.min_temperature          0.027650         0.046883            0.590           0.555
# L6.max_temperature         -0.020103         0.028824           -0.697           0.486
# L6.solar_exposure           0.008845         0.021121            0.419           0.675
# L6.rainfall                -0.010121         0.021971           -0.461           0.645
# L7.min_temperature          0.006843         0.046896            0.146           0.884
# L7.max_temperature          0.033116         0.028803            1.150           0.250
# L7.solar_exposure          -0.030262         0.021099           -1.434           0.151
# L7.rainfall                -0.003216         0.021961           -0.146           0.884
# L8.min_temperature         -0.014375         0.046921           -0.306           0.759
# L8.max_temperature          0.003247         0.028842            0.113           0.910
# L8.solar_exposure          -0.019779         0.021177           -0.934           0.350
# L8.rainfall                -0.022566         0.021815           -1.034           0.301
# L9.min_temperature          0.080652         0.046865            1.721           0.085
# L9.max_temperature          0.012528         0.028816            0.435           0.664
# L9.solar_exposure           0.016783         0.021298            0.788           0.431
# L9.rainfall                 0.004391         0.021797            0.201           0.840
# L10.min_temperature        -0.005723         0.046887           -0.122           0.903
# L10.max_temperature        -0.009616         0.028754           -0.334           0.738
# L10.solar_exposure          0.036640         0.021295            1.721           0.085
# L10.rainfall               -0.005444         0.021787           -0.250           0.803
# L11.min_temperature        -0.006756         0.046846           -0.144           0.885
# L11.max_temperature         0.076169         0.028759            2.649           0.008
# L11.solar_exposure         -0.023161         0.021320           -1.086           0.277
# L11.rainfall                0.003201         0.021767            0.147           0.883
# L12.min_temperature         0.004850         0.046828            0.104           0.918
# L12.max_temperature        -0.002610         0.028828           -0.091           0.928
# L12.solar_exposure         -0.024632         0.021305           -1.156           0.248
# L12.rainfall               -0.016016         0.021748           -0.736           0.461
# L13.min_temperature         0.006351         0.046709            0.136           0.892
# L13.max_temperature         0.030125         0.028779            1.047           0.295
# L13.solar_exposure          0.022758         0.021328            1.067           0.286
# L13.rainfall               -0.023457         0.021737           -1.079           0.281
# L14.min_temperature         0.012131         0.046519            0.261           0.794
# L14.max_temperature         0.023351         0.028746            0.812           0.417
# L14.solar_exposure         -0.033352         0.021348           -1.562           0.118
# L14.rainfall                0.016542         0.021619            0.765           0.444
# L15.min_temperature         0.087369         0.037311            2.342           0.019
# L15.max_temperature        -0.017361         0.027223           -0.638           0.524
# L15.solar_exposure          0.020927         0.020815            1.005           0.315
# L15.rainfall                0.009149         0.020698            0.442           0.658
# ======================================================================================
#
# Results for equation solar_exposure
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       4.231762         0.734891            5.758           0.000
# L1.min_temperature          0.149300         0.055246            2.702           0.007
# L1.max_temperature         -0.332581         0.030254          -10.993           0.000
# L1.solar_exposure           0.358505         0.023981           14.949           0.000
# L1.rainfall                -0.045216         0.027164           -1.665           0.096
# L2.min_temperature          0.014208         0.058536            0.243           0.808
# L2.max_temperature         -0.086494         0.035904           -2.409           0.016
# L2.solar_exposure           0.093102         0.026251            3.547           0.000
# L2.rainfall                -0.011201         0.027462           -0.408           0.683
# L3.min_temperature         -0.077643         0.058576           -1.326           0.185
# L3.max_temperature          0.004985         0.036175            0.138           0.890
# L3.solar_exposure          -0.034282         0.026375           -1.300           0.194
# L3.rainfall                 0.018398         0.027501            0.669           0.504
# L4.min_temperature          0.105784         0.058742            1.801           0.072
# L4.max_temperature         -0.007026         0.036129           -0.194           0.846
# L4.solar_exposure           0.071269         0.026406            2.699           0.007
# L4.rainfall                 0.048174         0.027504            1.752           0.080
# L5.min_temperature          0.031864         0.058714            0.543           0.587
# L5.max_temperature         -0.030552         0.036064           -0.847           0.397
# L5.solar_exposure           0.132191         0.026417            5.004           0.000
# L5.rainfall                 0.047403         0.027512            1.723           0.085
# L6.min_temperature         -0.123735         0.058725           -2.107           0.035
# L6.max_temperature         -0.004287         0.036104           -0.119           0.905
# L6.solar_exposure           0.061931         0.026455            2.341           0.019
# L6.rainfall                -0.053609         0.027521           -1.948           0.051
# L7.min_temperature          0.150276         0.058742            2.558           0.011
# L7.max_temperature         -0.035428         0.036078           -0.982           0.326
# L7.solar_exposure           0.011012         0.026428            0.417           0.677
# L7.rainfall                 0.048792         0.027508            1.774           0.076
# L8.min_temperature          0.020123         0.058773            0.342           0.732
# L8.max_temperature         -0.021172         0.036126           -0.586           0.558
# L8.solar_exposure           0.098579         0.026525            3.716           0.000
# L8.rainfall                 0.018891         0.027325            0.691           0.489
# L9.min_temperature          0.021089         0.058702            0.359           0.719
# L9.max_temperature         -0.004322         0.036094           -0.120           0.905
# L9.solar_exposure           0.058035         0.026678            2.175           0.030
# L9.rainfall                 0.068454         0.027303            2.507           0.012
# L10.min_temperature         0.028072         0.058730            0.478           0.633
# L10.max_temperature        -0.055288         0.036017           -1.535           0.125
# L10.solar_exposure          0.103403         0.026674            3.877           0.000
# L10.rainfall                0.027228         0.027290            0.998           0.318
# L11.min_temperature         0.037483         0.058678            0.639           0.523
# L11.max_temperature        -0.022954         0.036023           -0.637           0.524
# L11.solar_exposure          0.054193         0.026706            2.029           0.042
# L11.rainfall               -0.017315         0.027265           -0.635           0.525
# L12.min_temperature        -0.037548         0.058656           -0.640           0.522
# L12.max_temperature         0.049913         0.036110            1.382           0.167
# L12.solar_exposure          0.032388         0.026687            1.214           0.225
# L12.rainfall                0.069794         0.027241            2.562           0.010
# L13.min_temperature         0.054436         0.058507            0.930           0.352
# L13.max_temperature        -0.037565         0.036048           -1.042           0.297
# L13.solar_exposure          0.088137         0.026715            3.299           0.001
# L13.rainfall                0.017786         0.027227            0.653           0.514
# L14.min_temperature        -0.048900         0.058269           -0.839           0.401
# L14.max_temperature         0.012500         0.036006            0.347           0.728
# L14.solar_exposure          0.037381         0.026740            1.398           0.162
# L14.rainfall               -0.004736         0.027079           -0.175           0.861
# L15.min_temperature        -0.001875         0.046736           -0.040           0.968
# L15.max_temperature         0.038096         0.034099            1.117           0.264
# L15.solar_exposure          0.004696         0.026072            0.180           0.857
# L15.rainfall                0.004633         0.025926            0.179           0.858
# ======================================================================================
#
# Results for equation rainfall
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.969714         0.606801            1.598           0.110
# L1.min_temperature          0.047772         0.045617            1.047           0.295
# L1.max_temperature          0.071659         0.024981            2.869           0.004
# L1.solar_exposure          -0.266768         0.019801          -13.472           0.000
# L1.rainfall                 0.153961         0.022429            6.864           0.000
# L2.min_temperature          0.115990         0.048334            2.400           0.016
# L2.max_temperature         -0.071292         0.029646           -2.405           0.016
# L2.solar_exposure           0.090660         0.021676            4.183           0.000
# L2.rainfall                 0.062987         0.022675            2.778           0.005
# L3.min_temperature          0.006088         0.048366            0.126           0.900
# L3.max_temperature         -0.019769         0.029869           -0.662           0.508
# L3.solar_exposure           0.072876         0.021778            3.346           0.001
# L3.rainfall                -0.014726         0.022707           -0.649           0.517
# L4.min_temperature          0.001112         0.048503            0.023           0.982
# L4.max_temperature          0.001366         0.029832            0.046           0.963
# L4.solar_exposure          -0.027557         0.021803           -1.264           0.206
# L4.rainfall                 0.000079         0.022710            0.003           0.997
# L5.min_temperature         -0.087932         0.048480           -1.814           0.070
# L5.max_temperature          0.026468         0.029778            0.889           0.374
# L5.solar_exposure           0.019405         0.021813            0.890           0.374
# L5.rainfall                 0.024413         0.022717            1.075           0.283
# L6.min_temperature          0.074748         0.048489            1.542           0.123
# L6.max_temperature          0.037204         0.029811            1.248           0.212
# L6.solar_exposure           0.007719         0.021844            0.353           0.724
# L6.rainfall                -0.023459         0.022724           -1.032           0.302
# L7.min_temperature         -0.049948         0.048503           -1.030           0.303
# L7.max_temperature          0.017058         0.029790            0.573           0.567
# L7.solar_exposure          -0.058078         0.021822           -2.661           0.008
# L7.rainfall                 0.025529         0.022713            1.124           0.261
# L8.min_temperature          0.101318         0.048529            2.088           0.037
# L8.max_temperature         -0.004286         0.029830           -0.144           0.886
# L8.solar_exposure           0.083680         0.021902            3.821           0.000
# L8.rainfall                -0.015282         0.022562           -0.677           0.498
# L9.min_temperature         -0.014613         0.048471           -0.301           0.763
# L9.max_temperature          0.005671         0.029803            0.190           0.849
# L9.solar_exposure          -0.057696         0.022028           -2.619           0.009
# L9.rainfall                -0.009547         0.022544           -0.423           0.672
# L10.min_temperature        -0.020616         0.048493           -0.425           0.671
# L10.max_temperature        -0.060953         0.029739           -2.050           0.040
# L10.solar_exposure          0.019930         0.022025            0.905           0.366
# L10.rainfall                0.009108         0.022533            0.404           0.686
# L11.min_temperature         0.022874         0.048451            0.472           0.637
# L11.max_temperature         0.000776         0.029745            0.026           0.979
# L11.solar_exposure          0.020788         0.022051            0.943           0.346
# L11.rainfall               -0.006244         0.022513           -0.277           0.782
# L12.min_temperature         0.006011         0.048433            0.124           0.901
# L12.max_temperature        -0.036507         0.029816           -1.224           0.221
# L12.solar_exposure          0.024932         0.022035            1.131           0.258
# L12.rainfall                0.027411         0.022493            1.219           0.223
# L13.min_temperature        -0.038817         0.048309           -0.804           0.422
# L13.max_temperature        -0.004352         0.029765           -0.146           0.884
# L13.solar_exposure          0.043928         0.022058            1.991           0.046
# L13.rainfall               -0.017917         0.022482           -0.797           0.425
# L14.min_temperature         0.022756         0.048113            0.473           0.636
# L14.max_temperature         0.034397         0.029731            1.157           0.247
# L14.solar_exposure         -0.008646         0.022079           -0.392           0.695
# L14.rainfall                0.011564         0.022359            0.517           0.605
# L15.min_temperature        -0.055569         0.038590           -1.440           0.150
# L15.max_temperature        -0.022220         0.028156           -0.789           0.430
# L15.solar_exposure         -0.023459         0.021528           -1.090           0.276
# L15.rainfall                0.027536         0.021407            1.286           0.198
# ======================================================================================
#
# Correlation matrix of residuals
#                    min_temperature  max_temperature  solar_exposure  rainfall
# min_temperature           1.000000         0.245445       -0.236968 -0.095973
# max_temperature           0.245445         1.000000        0.243193 -0.174401
# solar_exposure           -0.236968         0.243193        1.000000 -0.094835
# rainfall                 -0.095973        -0.174401       -0.094835  1.000000

# %%
#Finding the best lag value which gives least AIC for the model
var.select_order(100).summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
#Building a model based on the best lag value
results = var.fit(11)

# %%
print(results.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 11, Apr, 2021
# Time:                     11:38:00
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                    10.4292
# Nobs:                     2127.00    HQIC:                   10.1254
# Log likelihood:          -22474.1    FPE:                    20952.3
# AIC:                      9.94998    Det(Omega_mle):         19269.1
# --------------------------------------------------------------------
# Results for equation min_temperature
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -1.096247         0.285694           -3.837           0.000
# L1.min_temperature          0.322824         0.023848           13.537           0.000
# L1.max_temperature          0.343381         0.013020           26.372           0.000
# L1.solar_exposure          -0.005621         0.010232           -0.549           0.583
# L1.rainfall                 0.004998         0.011724            0.426           0.670
# L2.min_temperature         -0.026866         0.025250           -1.064           0.287
# L2.max_temperature         -0.055861         0.015495           -3.605           0.000
# L2.solar_exposure          -0.009496         0.011167           -0.850           0.395
# L2.rainfall                -0.008261         0.011861           -0.696           0.486
# L3.min_temperature          0.056171         0.025265            2.223           0.026
# L3.max_temperature          0.003831         0.015615            0.245           0.806
# L3.solar_exposure           0.028450         0.011251            2.529           0.011
# L3.rainfall                -0.004890         0.011877           -0.412           0.681
# L4.min_temperature          0.002621         0.025304            0.104           0.917
# L4.max_temperature          0.009769         0.015614            0.626           0.532
# L4.solar_exposure          -0.014283         0.011274           -1.267           0.205
# L4.rainfall                 0.005702         0.011783            0.484           0.628
# L5.min_temperature          0.032252         0.025293            1.275           0.202
# L5.max_temperature         -0.003898         0.015593           -0.250           0.803
# L5.solar_exposure           0.006379         0.011271            0.566           0.571
# L5.rainfall                -0.012998         0.011781           -1.103           0.270
# L6.min_temperature          0.016318         0.025294            0.645           0.519
# L6.max_temperature          0.000564         0.015583            0.036           0.971
# L6.solar_exposure          -0.000302         0.011335           -0.027           0.979
# L6.rainfall                 0.025154         0.011766            2.138           0.033
# L7.min_temperature          0.028514         0.025317            1.126           0.260
# L7.max_temperature         -0.011209         0.015568           -0.720           0.472
# L7.solar_exposure           0.025436         0.011313            2.248           0.025
# L7.rainfall                 0.012382         0.011770            1.052           0.293
# L8.min_temperature         -0.011541         0.025342           -0.455           0.649
# L8.max_temperature          0.000819         0.015582            0.053           0.958
# L8.solar_exposure           0.003784         0.011338            0.334           0.739
# L8.rainfall                 0.005323         0.011781            0.452           0.651
# L9.min_temperature          0.058502         0.025300            2.312           0.021
# L9.max_temperature          0.000741         0.015553            0.048           0.962
# L9.solar_exposure           0.009680         0.011456            0.845           0.398
# L9.rainfall                 0.006974         0.011751            0.594           0.553
# L10.min_temperature         0.001008         0.025227            0.040           0.968
# L10.max_temperature         0.014898         0.015520            0.960           0.337
# L10.solar_exposure          0.005423         0.011451            0.474           0.636
# L10.rainfall               -0.000199         0.011681           -0.017           0.986
# L11.min_temperature         0.036286         0.020188            1.797           0.072
# L11.max_temperature        -0.007201         0.014737           -0.489           0.625
# L11.solar_exposure         -0.009717         0.011183           -0.869           0.385
# L11.rainfall                0.012670         0.011080            1.144           0.253
# ======================================================================================
#
# Results for equation max_temperature
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       4.481612         0.525958            8.521           0.000
# L1.min_temperature          0.013169         0.043904            0.300           0.764
# L1.max_temperature          0.351346         0.023970           14.657           0.000
# L1.solar_exposure           0.223681         0.018837           11.874           0.000
# L1.rainfall                -0.064453         0.021584           -2.986           0.003
# L2.min_temperature          0.056904         0.046485            1.224           0.221
# L2.max_temperature         -0.067189         0.028527           -2.355           0.019
# L2.solar_exposure          -0.004397         0.020558           -0.214           0.831
# L2.rainfall                -0.057759         0.021836           -2.645           0.008
# L3.min_temperature          0.033418         0.046512            0.718           0.472
# L3.max_temperature          0.000226         0.028748            0.008           0.994
# L3.solar_exposure           0.005417         0.020712            0.262           0.794
# L3.rainfall                -0.030713         0.021866           -1.405           0.160
# L4.min_temperature          0.041197         0.046583            0.884           0.376
# L4.max_temperature          0.000784         0.028744            0.027           0.978
# L4.solar_exposure          -0.007662         0.020755           -0.369           0.712
# L4.rainfall                 0.008501         0.021693            0.392           0.695
# L5.min_temperature          0.039562         0.046564            0.850           0.396
# L5.max_temperature          0.013365         0.028706            0.466           0.642
# L5.solar_exposure           0.060158         0.020749            2.899           0.004
# L5.rainfall                -0.007419         0.021688           -0.342           0.732
# L6.min_temperature          0.034505         0.046566            0.741           0.459
# L6.max_temperature         -0.016331         0.028687           -0.569           0.569
# L6.solar_exposure           0.007358         0.020868            0.353           0.724
# L6.rainfall                -0.008570         0.021660           -0.396           0.692
# L7.min_temperature          0.008474         0.046608            0.182           0.856
# L7.max_temperature          0.035957         0.028661            1.255           0.210
# L7.solar_exposure          -0.031202         0.020826           -1.498           0.134
# L7.rainfall                 0.002227         0.021668            0.103           0.918
# L8.min_temperature         -0.002818         0.046655           -0.060           0.952
# L8.max_temperature          0.007041         0.028686            0.245           0.806
# L8.solar_exposure          -0.017157         0.020873           -0.822           0.411
# L8.rainfall                -0.016426         0.021689           -0.757           0.449
# L9.min_temperature          0.085241         0.046576            1.830           0.067
# L9.max_temperature          0.015684         0.028633            0.548           0.584
# L9.solar_exposure           0.015770         0.021090            0.748           0.455
# L9.rainfall                 0.005144         0.021633            0.238           0.812
# L10.min_temperature         0.004939         0.046442            0.106           0.915
# L10.max_temperature        -0.004696         0.028573           -0.164           0.869
# L10.solar_exposure          0.033974         0.021081            1.612           0.107
# L10.rainfall               -0.002207         0.021505           -0.103           0.918
# L11.min_temperature         0.036319         0.037166            0.977           0.328
# L11.max_temperature         0.064860         0.027130            2.391           0.017
# L11.solar_exposure         -0.022636         0.020587           -1.100           0.272
# L11.rainfall                0.014493         0.020397            0.711           0.477
# ======================================================================================
#
# Results for equation solar_exposure
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       4.205360         0.663508            6.338           0.000
# L1.min_temperature          0.151274         0.055386            2.731           0.006
# L1.max_temperature         -0.334527         0.030239          -11.063           0.000
# L1.solar_exposure           0.367407         0.023763           15.461           0.000
# L1.rainfall                -0.040850         0.027228           -1.500           0.134
# L2.min_temperature          0.016096         0.058641            0.274           0.784
# L2.max_temperature         -0.088863         0.035987           -2.469           0.014
# L2.solar_exposure           0.102475         0.025934            3.951           0.000
# L2.rainfall                -0.003878         0.027547           -0.141           0.888
# L3.min_temperature         -0.068902         0.058677           -1.174           0.240
# L3.max_temperature          0.002154         0.036266            0.059           0.953
# L3.solar_exposure          -0.012280         0.026129           -0.470           0.638
# L3.rainfall                 0.017533         0.027585            0.636           0.525
# L4.min_temperature          0.126854         0.058766            2.159           0.031
# L4.max_temperature         -0.003348         0.036262           -0.092           0.926
# L4.solar_exposure           0.087943         0.026183            3.359           0.001
# L4.rainfall                 0.058695         0.027366            2.145           0.032
# L5.min_temperature          0.036758         0.058742            0.626           0.531
# L5.max_temperature         -0.036099         0.036213           -0.997           0.319
# L5.solar_exposure           0.143579         0.026175            5.485           0.000
# L5.rainfall                 0.042440         0.027360            1.551           0.121
# L6.min_temperature         -0.095403         0.058744           -1.624           0.104
# L6.max_temperature         -0.019147         0.036190           -0.529           0.597
# L6.solar_exposure           0.076547         0.026325            2.908           0.004
# L6.rainfall                -0.053340         0.027325           -1.952           0.051
# L7.min_temperature          0.143707         0.058798            2.444           0.015
# L7.max_temperature         -0.031663         0.036156           -0.876           0.381
# L7.solar_exposure           0.020095         0.026273            0.765           0.444
# L7.rainfall                 0.052075         0.027335            1.905           0.057
# L8.min_temperature          0.023389         0.058856            0.397           0.691
# L8.max_temperature         -0.017174         0.036188           -0.475           0.635
# L8.solar_exposure           0.111710         0.026332            4.242           0.000
# L8.rainfall                 0.019252         0.027362            0.704           0.482
# L9.min_temperature          0.033547         0.058757            0.571           0.568
# L9.max_temperature          0.007198         0.036121            0.199           0.842
# L9.solar_exposure           0.061147         0.026606            2.298           0.022
# L9.rainfall                 0.071181         0.027290            2.608           0.009
# L10.min_temperature         0.021850         0.058588            0.373           0.709
# L10.max_temperature        -0.060855         0.036045           -1.688           0.091
# L10.solar_exposure          0.100500         0.026595            3.779           0.000
# L10.rainfall                0.039597         0.027129            1.460           0.144
# L11.min_temperature         0.079918         0.046886            1.705           0.088
# L11.max_temperature         0.005058         0.034225            0.148           0.883
# L11.solar_exposure          0.065616         0.025971            2.526           0.012
# L11.rainfall               -0.013986         0.025732           -0.544           0.587
# ======================================================================================
#
# Results for equation rainfall
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.878521         0.544230            1.614           0.106
# L1.min_temperature          0.051417         0.045429            1.132           0.258
# L1.max_temperature          0.066420         0.024803            2.678           0.007
# L1.solar_exposure          -0.266864         0.019492          -13.691           0.000
# L1.rainfall                 0.155912         0.022333            6.981           0.000
# L2.min_temperature          0.116868         0.048099            2.430           0.015
# L2.max_temperature         -0.075694         0.029518           -2.564           0.010
# L2.solar_exposure           0.099105         0.021272            4.659           0.000
# L2.rainfall                 0.065830         0.022595            2.913           0.004
# L3.min_temperature          0.004528         0.048128            0.094           0.925
# L3.max_temperature         -0.020000         0.029746           -0.672           0.501
# L3.solar_exposure           0.075467         0.021432            3.521           0.000
# L3.rainfall                -0.016986         0.022626           -0.751           0.453
# L4.min_temperature         -0.001065         0.048202           -0.022           0.982
# L4.max_temperature         -0.001517         0.029743           -0.051           0.959
# L4.solar_exposure          -0.030812         0.021476           -1.435           0.151
# L4.rainfall                -0.000503         0.022447           -0.022           0.982
# L5.min_temperature         -0.083105         0.048182           -1.725           0.085
# L5.max_temperature          0.019304         0.029703            0.650           0.516
# L5.solar_exposure           0.023103         0.021470            1.076           0.282
# L5.rainfall                 0.025825         0.022441            1.151           0.250
# L6.min_temperature          0.079011         0.048184            1.640           0.101
# L6.max_temperature          0.029170         0.029684            0.983           0.326
# L6.solar_exposure           0.011732         0.021593            0.543           0.587
# L6.rainfall                -0.024559         0.022413           -1.096           0.273
# L7.min_temperature         -0.055757         0.048228           -1.156           0.248
# L7.max_temperature          0.016330         0.029657            0.551           0.582
# L7.solar_exposure          -0.054103         0.021550           -2.511           0.012
# L7.rainfall                 0.018557         0.022421            0.828           0.408
# L8.min_temperature          0.101512         0.048276            2.103           0.035
# L8.max_temperature         -0.005954         0.029683           -0.201           0.841
# L8.solar_exposure           0.087101         0.021598            4.033           0.000
# L8.rainfall                -0.015426         0.022443           -0.687           0.492
# L9.min_temperature         -0.021567         0.048194           -0.447           0.655
# L9.max_temperature          0.005676         0.029628            0.192           0.848
# L9.solar_exposure          -0.057930         0.021823           -2.655           0.008
# L9.rainfall                -0.011825         0.022384           -0.528           0.597
# L10.min_temperature        -0.022453         0.048056           -0.467           0.640
# L10.max_temperature        -0.062270         0.029565           -2.106           0.035
# L10.solar_exposure          0.019420         0.021814            0.890           0.373
# L10.rainfall                0.015056         0.022252            0.677           0.499
# L11.min_temperature        -0.015687         0.038457           -0.408           0.683
# L11.max_temperature         0.006542         0.028072            0.233           0.816
# L11.solar_exposure          0.026692         0.021302            1.253           0.210
# L11.rainfall               -0.018447         0.021106           -0.874           0.382
# ======================================================================================
#
# Correlation matrix of residuals
#                    min_temperature  max_temperature  solar_exposure  rainfall
# min_temperature           1.000000         0.243820       -0.237652 -0.099762
# max_temperature           0.243820         1.000000        0.239673 -0.174449
# solar_exposure           -0.237652         0.239673        1.000000 -0.088299
# rainfall                 -0.099762        -0.174449       -0.088299  1.000000

# %%
lag = results.k_ar

# %%
#Forecast for the next 100 days
forecast_RRP = results.forecast(train_data.values[-lag:], steps = 100)

# %%
test_data
# Out:
#             min_temperature  max_temperature  solar_exposure  rainfall
# date
# 2020-11-08              8.4             19.5            28.9       0.0
# 2020-11-09             11.3             29.0            28.8       0.0
# 2020-11-10             16.1             32.0            29.1       0.0
# 2020-11-11             22.8             28.3             6.5       0.0
# 2020-11-12             19.3             25.5            20.6       4.0
# ...                     ...              ...             ...       ...
# 2021-02-24             11.6             20.2            23.3       0.0
# 2021-02-25             10.7             24.3            18.9       0.0
# 2021-02-26             12.3             19.7            15.7       0.4
# 2021-02-27             11.1             18.6            11.8       0.0
# 2021-02-28              7.9             26.7            23.3       0.0
#
# [113 rows x 4 columns]

# %%
#Performance of the model on the test set
mean_absolute_error(forecast_RRP[:,4], test_data['RRP'][:100])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RRP'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-7c94f031ccb1> in <module>()
#       1 #Performance of the model on the test set
# ----> 2 mean_absolute_error(forecast_RRP[:,3], test_data['RRP'][:100])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'RRP'

# %%
#Performance of the model on the test set
sqrt(mean_squared_error(forecast_RRP[:,4], test_data['RRP'][:100]))
# Out:
# 54.46286770543855

# %%
forecast_RRP_df = pd.DataFrame(test_data['RRP'])
forecast_RRP_df = forecast_RRP_df[:100]

# %%
forecast_RRP_df['Forecast_RRP'] = forecast_RRP[:,4]

# %%
#View in a dataframe
forecast_RRP_df
# Out:
#                   RRP  Forecast_RRP
# date
# 2020-11-08  22.317917     44.850063
# 2020-11-09  46.335417     53.912942
# 2020-11-10  41.227500     85.557587
# 2020-11-11  42.645417     82.665324
# 2020-11-12  23.034583     67.306025
# ...               ...           ...
# 2021-02-11  28.216458     78.747995
# 2021-02-12  27.597083     78.717052
# 2021-02-13   6.259792     78.686312
# 2021-02-14  -0.228333     78.655780
# 2021-02-15  19.106042     78.625466
#
# [100 rows x 2 columns]

# %% [markdown]
# #Prophet model

# %%
#Create our prophet model with 95% confidence interval
prophet = Prophet(interval_width=0.95, seasonality_mode='multiplicative', n_changepoints=23, seasonality_prior_scale=10)

# %%
#We need date as an indepedent variable for the prophet model hence we reset our index.
train_data.reset_index(inplace = True)
test_data.reset_index(inplace = True)

# %%
train_data
# Out:
#            date  min_temperature  ...  rainfall        RRP
# 0    2015-01-01             13.3  ...       0.0  25.633696
# 1    2015-01-02             15.4  ...       0.0  33.138988
# 2    2015-01-03             20.0  ...       0.0  34.564855
# 3    2015-01-04             16.3  ...       4.2  25.005560
# 4    2015-01-05             15.0  ...       0.0  26.724176
# ...         ...              ...  ...       ...        ...
# 2133 2020-11-03             12.1  ...       0.0  41.192083
# 2134 2020-11-04             21.9  ...       0.0  56.009792
# 2135 2020-11-05             11.1  ...       2.8  49.173125
# 2136 2020-11-06              9.5  ...       0.2  58.043333
# 2137 2020-11-07             11.3  ...       1.6  27.226042
#
# [2138 rows x 6 columns]

# %%
#For the prophet model, the date variable should be renamed to ds while the value to be forecasted has to renamed as y
train_data.rename({'date':'ds', 'RRP':'y'}, inplace = True, axis = 'columns')
test_data.rename({'date':'ds', 'RRP':'y'}, inplace = True, axis = 'columns')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Adding indepedent features to our Univariate model
prophet.add_regressor('min_temperature', standardize=False)
prophet.add_regressor('max_temperature', standardize=False)
prophet.add_regressor('solar_exposure', standardize=False)
prophet.add_regressor('rainfall', standardize=False)

# %%
#Training the Multivariate model
prophet.fit(train_data)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
#Formatting
test_data_ = test_data.drop(columns = 'y')

# %%
#Predict for the test set
future = prophet.predict(test_data)

# %%
#Performance metric on the test set 
mean_absolute_error(future['yhat'], test_data['y'])
# Out:
# 14.605398649061387

# %%
#Performance of the model on the test set
sqrt(mean_squared_error(future['yhat'], test_data['y']))
# Out:
# 17.74249866469692

# %%
df_prophet = pd.DataFrame(test_data['y'])

# %%
df_prophet['Forecast_RRP_'] = future['yhat']

# %%
df_prophet
# Out:
#              y  Forecast_RRP_
# 0    22.317917      28.386375
# 1    46.335417      56.293392
# 2    41.227500      55.125837
# 3    42.645417      36.514105
# 4    23.034583      49.956327
# ..         ...            ...
# 108  25.840417       9.048231
# 109  21.205833      29.112746
# 110  25.796250      13.483767
# 111  29.897083       9.057054
# 112  22.412917      21.750399
#
# [113 rows x 2 columns]

# %% [markdown]
# #LSTM model

# %%
#Remove date variable 
train_data.drop(columns=['ds'], inplace = True)
test_data.drop(columns=['ds'], inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Split into train and test data 
train_x = train_data.iloc[:,0:4]
train_y = train_data['y']
test_x = test_data.iloc[:,0:4]
test_y = test_data['y']

# %%
#LSTM is sensitive to non-scaled data, hence we scale our data
scaler = MinMaxScaler()
train_x = scaler.fit_transform(train_x)
test_x = scaler.transform(test_x)

# %%
#Create our train and test generator, predictiing RRP based on 30 previous days
win_length = 30
batch_size = 32
num_features = 4

train_generator = TimeseriesGenerator(train_x, train_y, length = win_length, sampling_rate = 1, batch_size = batch_size)
test_generator = TimeseriesGenerator(test_x, test_y, length = win_length, sampling_rate = 1, batch_size = batch_size)

# %%
#Define our LSTM model  
model = Sequential()
model.add(LSTM(128, input_shape= (win_length, num_features), return_sequences=False))
model.add(Dense(1))

# %%
print(model.summary())
# Out:
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_35 (LSTM)               (None, 128)               68096
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 68,225
# Trainable params: 68,225
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Fit our model on train time series generator
early_stopping = EarlyStopping(monitor='val_loss', patience=2, mode='min')

model.compile(loss=MeanSquaredError(),
              optimizer=Adam(),
              metrics=[MeanAbsoluteError()])

history = model.fit_generator(train_generator, epochs=10,
                    validation_data=test_generator,
                    shuffle=False,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning:
#
# `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# 66/66 [==============================] - 4s 36ms/step - loss: 9146.8434 - mean_absolute_error: 51.3268 - val_loss: 213.9392 - val_mean_absolute_error: 11.8466
# Epoch 2/10
# 66/66 [==============================] - 2s 29ms/step - loss: 8026.9013 - mean_absolute_error: 36.2910 - val_loss: 236.0655 - val_mean_absolute_error: 11.9236
# Epoch 3/10
# 66/66 [==============================] - 2s 29ms/step - loss: 7607.6875 - mean_absolute_error: 31.3199 - val_loss: 333.9862 - val_mean_absolute_error: 14.3006

# %%
#Evaluate the performance
model.evaluate_generator(test_generator, verbose=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1877: UserWarning:
#
# `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# [333.9862365722656, 14.300609588623047]

# %%
#Making predictions
predictions=model.predict(test_generator)
predictions = predictions.ravel()

# %%
#Format data
actual_data = test_y[win_length:]

# %%
#Performance metric of the model
mean_absolute_error(predictions, actual_data)
# Out:
# 14.300609780754703

# %%
#Performance metric of the model
sqrt(mean_squared_error(predictions, actual_data))
# Out:
# 18.275291263518888

# %%
#Print the predictions
predictions
# Out:
# array([34.275536, 34.27519 , 34.276253, 34.27598 , 34.276165, 34.276703,
#        34.276882, 34.277363, 34.277233, 34.276226, 34.276432, 34.27579 ,
#        34.276035, 34.276012, 34.275253, 34.275593, 34.27615 , 34.275806,
#        34.275845, 34.276585, 34.2756  , 34.27591 , 34.276073, 34.276333,
#        34.275143, 34.276707, 34.276073, 34.276752, 34.275135, 34.275482,
#        34.27544 , 34.276585, 34.276493, 34.276867, 34.27707 , 34.27727 ,
#        34.276207, 34.276203, 34.276104, 34.275333, 34.27532 , 34.276043,
#        34.27609 , 34.27597 , 34.27622 , 34.276844, 34.27651 , 34.27664 ,
#        34.27705 , 34.277195, 34.275467, 34.276493, 34.275593, 34.275257,
#        34.277523, 34.276196, 34.275112, 34.275608, 34.276455, 34.27615 ,
#        34.276165, 34.27582 , 34.27553 , 34.275288, 34.27631 , 34.2767  ,
#        34.276386, 34.276203, 34.2757  , 34.27554 , 34.276093, 34.276432,
#        34.27665 , 34.27691 , 34.276997, 34.27593 , 34.275253, 34.275658,
#        34.275585, 34.275757, 34.27572 , 34.275364, 34.274986],
#       dtype=float32)

# %% [markdown]
# RRP from March 2021 to August 2021

# %%
weather_features = pd.read_csv('predicted_weather_features.csv')

# %%
weather_features
# Out:
#       min_temp  max_temp      solar   rainfall
# 0    12.506416    20.844  14.810004   1.000000
# 1    12.016535    20.244  15.744815   1.000000
# 2    11.526654    19.144  15.494148   1.733333
# 3    11.036772    16.892  13.976392  12.800000
# 4    10.546891    16.680  13.893853  32.700000
# ..         ...       ...        ...        ...
# 179  10.412694    17.984  14.492277   0.000000
# 180   9.922813    19.660  14.623790   0.050000
# 181   9.432931    21.376  14.505982   1.000000
# 182  12.378017    20.928  14.810004   1.533333
# 183  11.888136    20.408  14.676794   1.533333
#
# [184 rows x 4 columns]

# %%
rng = pd.date_range('2021-03-01', periods=184, freq='D')
weather_features['Date'] = pd.DataFrame({ 'Date': rng}) 
weather_features['Date'] = weather_features['Date'].astype('datetime64[ns]')
weather_features = weather_features[['Date', 'min_temp', 'max_temp', 'solar', 'rainfall']]

# %%
weather_features.columns = test_data_.columns

# %%
future_ = prophet.predict(weather_features)

# %%
data['RRP']
# Out:
# 0       25.633696
# 1       33.138988
# 2       34.564855
# 3       25.005560
# 4       26.724176
#           ...
# 2246    25.840417
# 2247    21.205833
# 2248    25.796250
# 2249    29.897083
# 2250    22.412917
# Name: RRP, Length: 2251, dtype: float64

# %%
RRP = data['RRP']
RRP_ = future_['yhat']

# %%
RRP__ = RRP.append(RRP_, ignore_index=True)

# %%
rng = pd.date_range('2015-01-01', periods=2435, freq='D')
Dates = pd.DataFrame({ 'Date': rng})

# %%
Dates
# Out:
#            Date
# 0    2015-01-01
# 1    2015-01-02
# 2    2015-01-03
# 3    2015-01-04
# 4    2015-01-05
# ...         ...
# 2430 2021-08-27
# 2431 2021-08-28
# 2432 2021-08-29
# 2433 2021-08-30
# 2434 2021-08-31
#
# [2435 rows x 1 columns]

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.plot(Dates, RRP__)
plt.ylim(-30, 600)
plt.xlabel('Dates')
plt.ylabel('RRP')
# Out:
# Text(0, 0.5, 'RRP')

# %%
pred = pd.DataFrame(Dates)

# %%
pred['RRP'] = RRP__

# %%
pred['Data'] = 'Actual Data'

# %%
pred['Data'][2250:] = 'Predicted Data'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.plot(pred['Date'], pred['RRP'])
plt.ylim(-30, 600)
plt.xlabel('Dates')
plt.ylabel('RRP')
# Out:
# Text(0, 0.5, 'RRP')

# %%
sns.lineplot(pred['Date'][1000:], pred['RRP'][1000:], hue = pred['Data'])
plt.ylim(-30, 600)
plt.xlabel('Dates')
plt.ylabel('RRP')
# Out:
# Text(0, 0.5, 'RRP')
