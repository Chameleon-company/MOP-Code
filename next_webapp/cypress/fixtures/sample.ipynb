# %% [markdown]
# _****Usecase Template****_
#   <div class="usecase-title">{usecase Name}</div>
#
# <div class="usecase-details"><b>Authored by: </b> {Author/s}</div>
# <div class="usecase-details"><b>Date Created: </b> {Trimester #, YYYY}</div>
# <div class="usecase-details"><b>Time to Complete:</b> {90} mins</div>
# <div class="usecase-details"><b>Level: </b>{Intermediate}</div>
# <div class="usecase-details"><b>Pre-requisite Skills: </b>{Python, and add any more skills needed/ not skills that will be taught throughout this use case}</div>

# %% [markdown]
# <div class="usecase-unnumbered-heading"><b>Scenario</b></div>

# %% [markdown]
# {Using User Story format, write a description of the problem you are trying to solve for this usecase.}

# %% [markdown]
# <div class="usecase-unnumbered-heading"><b>What this usecase will teach you</b></div>

# %% [markdown]
# <div class="usecase-body">{Description of what this usecase will teach the user.}</div>
#
# <div class="usecase-list">
#
# - {Learning outcome 1}
# - {Learning outcome 2}
# - {Learning outcome 3}
#
# </div>

# %% [markdown]
# <div class="usecase-unnumbered-heading"><b>Background</b></div>

# %% [markdown]
# {Write your usecase background here. Keep it concise. We're not after "War and Peace" but enough background information to inform the reader on the rationale for solving this problem or background non-technical information that helps explain the approach.}

# %% [markdown]
# <div class="usecase-unnumbered-heading"><b>Data Sets</b></div>

# %% [markdown]
# <div class="usecase-body">{List your datasets here and links to them either in the Melbourne Open Data Platform or to where they are stored in the dependency folder/ what website you sourced them from. You may also add a short description below about the dataset.}</div>

# %% [markdown]
# <div class="usecase-datasets">
#
# - {Dataset 1 - LINK}
# - {Dataset 2 - LINK}
# - {Dataset 3 - LINK}
#
# </div>

# %% [markdown]
# <div class="usecase-unnumbered-heading"><b>Contents</b></div>

# %% [markdown]
# _Update this list to match the actual numbered headings in your notebook once your content is finalised. Use anchor tags pointing to your section `id`s to make them clickable (see Style Guide Reference for details)._
#
# <div class="usecase-contents">
#
# 1. <a href="#section-1">{Your first analysis section heading}</a>
# 2. <a href="#section-2">{Your next analysis section heading}</a>
# 3. <a href="#section-3">{Your next analysis section heading}</a>
# 4. <a href="#section-4">{Your next analysis section heading}</a>
# 5. <a href="#section-5">{Your next analysis section heading}</a>
#   - 5.1. <a href="#subsection-5-1">{Subsection}</a>
# 6. <a href="#section-6">{Your next analysis section heading}</a>
#
# </div>

# %% [markdown]
# <div class="usecase-code-divider">{*DELETE ME* Your notebook's analysis and code content begins below. Start the numbering shown in the Contents page above, including subsections (e.g. 5.1.) and sub-subsections (e.g. 5.1.1.) where needed.}</div>

# %% [markdown]
# <div class="usecase-unnumbered-heading"><b>Conclusion</b></div>

# %% [markdown]
# <div class="usecase-body">{Summary of what was achieved and learned from this analysis, along with observations for further opportunities.}</div>

# %% [markdown]
# **What we achieved in this analysis**
# {Add an explanation of your achievements here}
#
# **What we learned from this analysis**
# {Add an explanation of your learnings here}
#
# **Observations for further opportunities**
# {Add an explanation of further opportunities here}
