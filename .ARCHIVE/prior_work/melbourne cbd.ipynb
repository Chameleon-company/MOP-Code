# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# 4/3wF_tt0ffjn1Xaq6tX96QGuySzuscjkoOKKDrsAly6g819pQ08GFsbU
# Mounted at /content/drive

# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt 
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
path = '/content/drive/My Drive/DataSets/project _python/Microclimate_version3.csv'
df_1 = pd.read_csv(path)

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49857 entries, 0 to 49856
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       49857 non-null  object
#  1   Time       49857 non-null  object
#  2   Location   49857 non-null  object
#  3   Value      42714 non-null  float64
#  4   New_Value  49857 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 1.9+ MB

# %%
df_1['Date']= pd.to_datetime(df_1['Date'])

# %%
df_1['Month'] = df_1['Date'].dt.month
df_1['Day'] = df_1['Date'].dt.day

# %%
df_1['Month'] = df_1['Month'].astype(str)

# %%
df_1["Month"].replace({"1":"January", "2":"Febuary", "3":"March", "4":"April", "5":"May", "6":"June", "7":"July", "8":"August"}, inplace=True)

# %%
df_1.head()
# Out:
#         Date   Time  Location  Value  New_Value   Month  Day
# 0 2020-08-13  20:00  Brooklyn   32.8       32.8  August   13
# 1 2020-08-13  21:00  Brooklyn   23.5       23.5  August   13
# 2 2020-08-13  22:00  Brooklyn   14.3       14.3  August   13
# 3 2020-08-13  23:00  Brooklyn    9.3        9.3  August   13
# 4 2020-06-01  20:00  Brighton   34.3       34.3    June    1

# %%
df_1.groupby(['Location','Time'])[['New_Value']].mean()
# Out:
#                        New_Value
# Location        Time
# Alphington      0:00    7.838282
#                 10:00  10.009608
#                 11:00  11.224096
#                 12:00  12.419459
#                 13:00  13.163481
# ...                          ...
# Thomastown East 5:00    4.650000
#                 6:00    4.100000
#                 7:00    3.800000
#                 8:00    6.700000
#                 9:00    6.000000
#
# [336 rows x 1 columns]

# %%
data_cbd= df_1[df_1['Location'].isin(['Melbourne CBD'])]

# %%
gapminder_not_2002 = data_cbd[data_cbd['Month']=='January']

# %%
gapminder_not_2002.head()
# Out:
#            Date  Time       Location  Value  New_Value    Month  Day
# 1524 2020-01-13  0:00  Melbourne CBD   40.7       40.7  January   13
# 1525 2020-01-13  1:00  Melbourne CBD   71.3       71.3  January   13
# 1526 2020-01-13  2:00  Melbourne CBD   70.7       70.7  January   13
# 1527 2020-01-13  3:00  Melbourne CBD   60.5       60.5  January   13
# 1528 2020-01-13  4:00  Melbourne CBD   64.6       64.6  January   13

# %%
data_cbd.groupby(['Time'])[['New_Value']].describe()
# Out:
#       New_Value                        ...
#           count       mean        std  ...       50%        75%    max
# Time                                   ...
# 0:00      220.0  10.638641  17.170298  ...  8.250000  11.400000  178.3
# 10:00     220.0   7.093914   8.937777  ...  5.200000   8.700000   89.8
# 11:00     220.0   8.143499  10.596668  ...  5.900000   9.930208  114.9
# 12:00     220.0   8.886307  13.094470  ...  5.745455  10.612240  130.3
# 13:00     220.0  10.729637  27.118823  ...  5.400000  10.125000  358.4
# 14:00     220.0  10.831707  30.846348  ...  5.408333   9.325000  411.5
# 15:00     220.0  10.188314  29.443985  ...  4.500000   8.978125  398.8
# 16:00     220.0   9.451976  27.566502  ...  4.800000   8.025000  376.6
# 17:00     220.0   9.535347  26.770989  ...  5.283333   8.900000  370.0
# 18:00     220.0   9.095398  25.961506  ...  5.000000   8.600000  359.4
# 19:00     220.0   8.565276  23.358734  ...  4.300000   8.900000  322.7
# ...

# %%
data_cbd.groupby(['Month'])[['New_Value']].describe()
# Out:
#         New_Value                        ...
#             count       mean        std  ...       50%        75%    max
# Month                                    ...
# 10          192.0   8.807362   6.171606  ...  8.100000  12.300000   30.4
# 11          192.0   7.624557   7.345210  ...  6.500000   9.015948   48.1
# 12          192.0   5.133441   3.918952  ...  4.714063   6.519828   23.1
# 9           192.0  12.792618  12.876515  ...  8.600000  16.704592   58.4
# April       600.0   6.287608   4.259133  ...  6.300000   8.600000   31.7
# August      216.0   9.382721  10.410407  ...  5.250000  12.850000   52.1
# Febuary     576.0   6.554488   4.494776  ...  6.000000   9.300000   27.8
# January     624.0  20.564583  49.643198  ...  7.200000  12.800000  411.5
# July        648.0   9.259591   8.614468  ...  6.600000  12.025000   48.1
# June        604.0   8.470414   7.991881  ...  6.400000  11.225000   52.3
# March       624.0   5.220881   3.424568  ...  4.900000   7.538839   14.3
# ...

# %%
ax = sns.lineplot(x="Time", y="New_Value", hue="Location",
                  err_style="bars", ci=68, data=data_cbd_jan)
