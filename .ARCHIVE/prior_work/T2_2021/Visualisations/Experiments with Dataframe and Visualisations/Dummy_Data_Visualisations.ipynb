# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#import dataset from data.csv file
df = pd.read_csv('Dummy_Data.csv')
df.head()
# Out:
#    Unnamed: 0  Bay_id      Status  Hour  Minutes  DayOfWeek        Date
# 0           0    1001  Unoccupied     0        0  Wednesday  2021-08-04
# 1           1    1002     Present     0        0  Wednesday  2021-08-04
# 2           2    1003  Unoccupied     0        0  Wednesday  2021-08-04
# 3           3    1004  Unoccupied     0        0  Wednesday  2021-08-04
# 4           4    1005  Unoccupied     0        0  Wednesday  2021-08-04

# %%
df.groupby(['DayOfWeek','Status']).size()
# Out:
# DayOfWeek  Status
# Friday     Present       238
#            Unoccupied    242
# Monday     Present       223
#            Unoccupied    257
# Saturday   Present       252
#            Unoccupied    228
# Sunday     Present       248
#            Unoccupied    232
# Thursday   Present       242
#            Unoccupied    238
# Tuesday    Present       228
#            Unoccupied    252
# Wednesday  Present       234
#            Unoccupied    246
# dtype: int64

# %%
sns.set(font_scale=1.4)
df.groupby('Status').DayOfWeek.value_counts().unstack(0).plot(kind='bar', figsize=(10, 6), rot=0)
plt.xlabel("Day of the Week", labelpad=14)
plt.ylabel("Count", labelpad=14)
plt.title("Count of Unoccupied and Present Parkings", y=1.02)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
df.groupby(['Hour','Status']).size()
# Out:
# Hour  Status
# 0     Present       68
#       Unoccupied    72
# 1     Present       69
#       Unoccupied    71
# 2     Present       80
#       Unoccupied    60
# 3     Present       72
#       Unoccupied    68
# 4     Present       73
#       Unoccupied    67
# 5     Present       68
#       Unoccupied    72
# 6     Present       74
#       Unoccupied    66
# 7     Present       65
#       Unoccupied    75
# 8     Present       74
#       Unoccupied    66
# 9     Present       63
#       Unoccupied    77
# 10    Present       63
#       Unoccupied    77
# 11    Present       57
#       Unoccupied    83
# 12    Present       73
#       Unoccupied    67
# 13    Present       70
#       Unoccupied    70
# 14    Present       68
#       Unoccupied    72
# 15    Present       75
#       Unoccupied    65
# 16    Present       60
#       Unoccupied    80
# 17    Present       71
#       Unoccupied    69
# 18    Present       79
#       Unoccupied    61
# 19    Present       69
# ...

# %%
df.groupby('Status').Hour.value_counts().unstack(0).plot(kind='bar', figsize=(12, 6), rot=0)
plt.xlabel("Hour of the Day", labelpad=14)
plt.ylabel("Count", labelpad=14)
plt.title("Count of Unoccupied and Present Parkings", y=1.02)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
df.groupby(['Minutes','Status']).size()
# Out:
# Minutes  Status
# 0        Present       411
#          Unoccupied    429
# 15       Present       429
#          Unoccupied    411
# 30       Present       418
#          Unoccupied    422
# 45       Present       407
#          Unoccupied    433
# dtype: int64

# %%
df.groupby('Status').Minutes.value_counts().unstack(0).plot(kind='bar', figsize=(10, 6), rot=0)
plt.xlabel("Minutes of the Day", labelpad=14)
plt.ylabel("Count", labelpad=14)
plt.title("Count of Unoccupied and Present Parkings", y=1.02)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
df.groupby(['Bay_id','Status']).size()
# Out:
# Bay_id  Status
# 1001    Present       344
#         Unoccupied    328
# 1002    Present       320
#         Unoccupied    352
# 1003    Present       319
#         Unoccupied    353
# 1004    Present       349
#         Unoccupied    323
# 1005    Present       333
#         Unoccupied    339
# dtype: int64

# %%
df.groupby('Status').Bay_id.value_counts().unstack(0).plot(kind='bar', figsize=(10, 6), rot=0)
plt.xlabel("Bay ID", labelpad=14)
plt.ylabel("Count", labelpad=14)
plt.title("Count of Unoccupied and Present Parkings", y=1.02)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
df.groupby(['Bay_id','Status']).size()
# Out:
# Bay_id  Status
# 1001    Present       344
#         Unoccupied    328
# 1002    Present       320
#         Unoccupied    352
# 1003    Present       319
#         Unoccupied    353
# 1004    Present       349
#         Unoccupied    323
# 1005    Present       333
#         Unoccupied    339
# dtype: int64

# %%
#Stacked  bar chart

# %%
sns.set(font_scale=1.4)
df.groupby('Status').DayOfWeek.value_counts().unstack(0).plot(kind='bar', figsize=(10, 6), rot=0, stacked=True)
plt.xlabel("Day of the Week", labelpad=14)
plt.ylabel("Count", labelpad=14)
plt.title("Count of Unoccupied and Present Parkings", y=1.02)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
df.groupby('Status').Minutes.value_counts().unstack(0).plot(kind='bar', figsize=(10, 6), rot=0, stacked=True)
plt.xlabel("Minutes of the Day", labelpad=14)
plt.ylabel("Count", labelpad=14)
plt.title("Count of Unoccupied and Present Parkings", y=1.02)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
df.groupby('Status').Bay_id.value_counts().unstack(0).plot(kind='bar', figsize=(10, 6), rot=0, stacked=True)
plt.xlabel("Bay ID", labelpad=14)
plt.ylabel("Count", labelpad=14)
plt.title("Count of Unoccupied and Present Parkings", y=1.02)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
