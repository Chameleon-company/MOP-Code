# %% [markdown]
# # Summary Table for Open Data

# %%
import sys 
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt 
sys.path.append('/Users/wuyoscar/Documents/Project/Playground')

# %% [markdown]
# # Constructing keyword Search function
#     * Process
#     * outcome:

# %%
import deakin
table, client = deakin.top_table(top=20)
table
# Out:
#                                                  Name         id  \
# 0   Pedestrian Counting System - Monthly (counts p...  b2ak-trbp
# 1         Median House Prices - By Type and Sale Year  i8px-csib
# 2                       On-street Parking Bay Sensors  vh2v-4nfs
# 3   Trees, with species and dimensions (Urban Forest)  fp38-wiyy
# 4        Cafes and restaurants, with seating capacity  xt2y-tnn9
# 5                              On-street Parking Bays  crvt-b4kt
# 6                                    Building Permits  r5bg-2hj8
# 7   Buildings with name, age, size, accessibility,...  pmhb-s6pn
# 8                                 2019 Aerial Imagery  cwpe-ugri
# 9                        Development Activity Monitor  gh7s-qda8
# 10      Pedestrian Counting System - Sensor Locations  h57g-5234
# 11                On-street Car Park Bay Restrictions  ntht-5rk7
# 12                                         Drainpipes  3bff-vaa5
# 13           Pay Stay zones linked to street segments  7q9g-yyvg
# 14        Business establishments per block by ANZSIC  jsun-ttri
# 15                              Residential dwellings  44kh-ty54
# 16                                   Street addresses  a7rp-xtya
# 17                           2018 Building Footprints  pq2z-35fu
# 18  Median House Prices by Transfer Year from 2000...  67fb-mvax
# 19              City of Melbourne 3D Point Cloud 2018  2dqj-9ydd
#
#                                              link  downloadCount  \
# 0   https://data.melbourne.vic.gov.au/d/b2ak-trbp           8406
# 1   https://data.melbourne.vic.gov.au/d/i8px-csib           3132
# 2   https://data.melbourne.vic.gov.au/d/vh2v-4nfs       12075418
# 3   https://data.melbourne.vic.gov.au/d/fp38-wiyy           6214
# 4   https://data.melbourne.vic.gov.au/d/xt2y-tnn9          15961
# 5   https://data.melbourne.vic.gov.au/d/crvt-b4kt          39776
# 6   https://data.melbourne.vic.gov.au/d/r5bg-2hj8           2429
# 7   https://data.melbourne.vic.gov.au/d/pmhb-s6pn           3152
# 8   https://data.melbourne.vic.gov.au/d/cwpe-ugri              0
# 9   https://data.melbourne.vic.gov.au/d/gh7s-qda8           6168
# 10  https://data.melbourne.vic.gov.au/d/h57g-5234           2041
# 11  https://data.melbourne.vic.gov.au/d/ntht-5rk7         555217
# 12  https://data.melbourne.vic.gov.au/d/3bff-vaa5          11802
# 13  https://data.melbourne.vic.gov.au/d/7q9g-yyvg           1711
# 14  https://data.melbourne.vic.gov.au/d/jsun-ttri            805
# 15  https://data.melbourne.vic.gov.au/d/44kh-ty54           1878
# 16  https://data.melbourne.vic.gov.au/d/a7rp-xtya         163068
# 17  https://data.melbourne.vic.gov.au/d/pq2z-35fu           1180
# 18  https://data.melbourne.vic.gov.au/d/67fb-mvax           1221
# 19  https://data.melbourne.vic.gov.au/d/2dqj-9ydd              0
#
#     page_views_last_month
# 0                    1256
# 1                    1022
# 2                     789
# 3                     735
# 4                     643
# 5                     618
# 6                     575
# 7                     455
# 8                     437
# 9                     419
# 10                    368
# 11                    360
# 12                    354
# 13                    338
# 14                    337
# 15                    319
# 16                    305
# 17                    297
# 18                    289
# 19                    283

# %%
table  = deakin.keyword_search('parking')
table
# Out:
#                                                  Name         Id  Downloads
# 0                       On-street Parking Bay Sensors  vh2v-4nfs   12074742
# 1            Pay Stay zones linked to street segments  7q9g-yyvg       1696
# 2                              On-street Parking Bays  crvt-b4kt      39776
# 3                 On-street Car Park Bay Restrictions  ntht-5rk7     550225
# 4   Street furniture including bollards, bicycle r...  8fgn-5q6t       2197
# 5                                    Street addresses  a7rp-xtya     163068
# 6         Off-street car parks with capacity and type  krh5-hhjn       1494
# 7            On-street Car Parking Sensor Data - 2017  u9sa-j86i       1359
# 8                                        Street names  2x56-ai8r    9808179
# 9          On-street Car Parking Meters with Location  vdsi-4gtj       2339
# 10           On-street Car Parking Sensor Data - 2016  dj7e-rdx9       1428
# 11           On-street Car Parking Sensor Data - 2019  7pgd-bdf2        172
# 12  On-street Car Parking Sensor Data - 2020 (Jan ...  4n3a-s6rn        235
# 13  Street lights with emitted lux level (council-...  hg8j-vcww       8649
# 14                        Off-street car parking 2019  g9am-cna5        402
# 15                    Off-street car parking 2017 map  reaf-a4my        150
# 16           On-street Car Parking Sensor Data - 2014  t6hb-9uf2       1715
# 17           On-street Car Parking Sensor Data - 2011  vkxi-k7ps        996
# 18           On-street Car Parking Sensor Data - 2015  apua-t2tb       1371
# 19           On-street Car Parking Sensor Data - 2018  5532-ig9r         67
# 20           On-street Car Parking Sensor Data - 2012  vbe9-m4tk       1231
# 21           On-street Car Parking Sensor Data - 2013  7jq6-k9kf       1192

# %%
for each_dataset in client.datasets():
    #print(each_dataset.keys())
    for key in each_dataset.keys():
        print('key_1:',key)
        for key_2 in each_dataset[key].keys():
            print('key_2',key_2, each_dataset[key][key_2])
        
    print('\n'*5)

    '''
    for key_name in each_dataset['resource']:
        print(key_name,":" ,each_dataset['resource'][str(key_name)])
    '''

'''
for each_dataset in client.datasets():
#   if ['bay_id'] in (each_dataset['resource']['columns_field_name']):
    for col_name in each_dataset['resource']['columns_field_name']:
        if 'bay' in col_name:
            print(each_dataset['resource']['name'])
            print(each_dataset['resource']['columns_field_name'] )
            print('\n','*'*30,'\n')
'''
    for col_name in each_dataset['resource']['columns_field_name']:
        if 'bay' in col_name:
            print(each_dataset['resource']['name'])
            print(each_dataset['resource']['columns_field_name'] )
            print('\n','*'*30,'\n')

# %%
for each_dataset in client.datasets():
#   if ['bay_id'] in (each_dataset['resource']['columns_field_name']):
    #print(each_dataset['permalink'])
    for key in each_dataset.keys():
        print(key)
        print(each_dataset[key])
        
    print('\n****\n')

# %% [markdown]
# ## Parking Dataset with their unique identifiers

# %%
import deakin 
table, client= deakin.top_table()

# %%
from bs4 import BeautifulSoup
for i in client.datasets():
    print(i['classification']['domain_category'])
    print(i['classification']['domain_tags'])
    print("**********")
# Out:
# {'categories': ['finance'], 'tags': [], 'domain_category': 'Transport', 'domain_tags': ['accessibility', 'cityreactivation', 'covid-19', 'foot traffic', 'pedestrian count', 'pedestrian sensors', 'safemobility', 'sensors', 'traffic flow'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All data held by the City of Melbourne has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Monthly'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'How-to-use_Linked-to', 'value': 'http://www.pedestrian.melbourne.vic.gov.au/'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Hourly'}]}
# **********
# {'categories': ['environment'], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['citizenreporter', 'eventsplanner', 'forest', 'tree', '#urbanforest', 'urban forest'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Monthly'}]}
# **********
# {'categories': ['environment', 'demographics'], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['accessibility', 'changemaker', 'citizenreporter', 'forest', 'park', 'researcher', 'street', 'tree', 'trees', 'urbanforest', '#urbanforest', 'urban forest'], 'domain_metadata': [{'key': 'Quality_Known-Issues', 'value': 'Date and year planted fields may have missing date values. '}, {'key': "Quality_What's-included", 'value': 'All data held by the City of Melbourne has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Monthly'}]}
# **********
# {'categories': ['transportation', 'economy'], 'tags': [], 'domain_category': 'Transport', 'domain_tags': ['parking', 'sensor', 'near real-time', 'vacancy', 'transport', 'travel', 'disability', 'accessibility', 'sensors', 'safemobility'], 'domain_metadata': [{'key': 'Data-management_Source-data-update-frequency', 'value': 'Real-time'}, {'key': 'Quality_Update-frequency', 'value': '2 Minutes'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Quality_Known-Issues', 'value': 'Parking Sensors are not operational on Public Holidays. Parking Sensors will show car parks as vacant when blocked by construction zones. '}, {'key': "Quality_What's-included", 'value': 'All active sensor readings. Number of sensor readings may fluctuate as sensor connections connect/reconnect to the network. '}, {'key': 'How-to-use_Further-information', 'value': 'http://www.melbourne.vic.gov.au/parking-and-transport/parking/Pages/parking-faqs.aspx'}]}
# **********
# {'categories': ['transportation'], 'tags': [], 'domain_category': 'Transport', 'domain_tags': ['parking', 'paystay', 'street', 'travel'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Quarterly'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Monthly'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'Property', 'domain_tags': ['growth city', 'house prices', 'house sale', 'property', 'residence', 'stats'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['transportation'], 'tags': [], 'domain_category': 'Transport', 'domain_tags': ['accessibility', 'areas', 'bays', 'cars', 'cityreactivation', 'parking', 'transport', 'trucks'], 'domain_metadata': [{'key': 'Quality_Source-data-update-frequency', 'value': 'Daily'}, {'key': 'Quality_Data-quality-statement', 'value': 'This data contains all spatially mapped on-street car parking bays. There is a large number of bays which have not yet been mapped. Data has been collected from a number of years, there may be parking bays that no longer exist that still show in dataset. Users are advised to contact council using the email listed to report data errors. '}, {'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': "Quality_What's-included", 'value': 'All surveyed parking bay data'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Daily'}]}
# **********
# {'categories': ['economy', 'politics', 'demographics'], 'tags': [], 'domain_category': 'Business', 'domain_tags': ['beverage', 'business', 'cafe', 'census of land use and employment', 'cityreactivation', 'clue', 'food', 'industry', 'restaurant'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'Full dataset has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Quality_Data-quality-statement', 'value': 'A team of 4 census officers conduct field interviews which involves visiting every establishment in every building in the Census area (City of Melbourne municipality). Every commercial property is surveyed at least once every two years.'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['environment', 'finance', 'transportation'], 'tags': [], 'domain_category': 'Property', 'domain_tags': ['accessibility', 'activity', 'building', 'cityreactivation', 'covid-19', 'dam', 'dev', 'development', 'dwellings', 'monitor', 'office', 'property', 'retail'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'Data has been completed with information availible at the time of publish'}, {'key': 'Quality_Update-frequency', 'value': 'Monthly'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'How-to-use_Further-information', 'value': 'https://data.melbourne.vic.gov.au/api/views/gh7s-qda8/files/51e3db26-a063-4825-ae6c-1a40c0259c75?download=true&filename=DAM_-_Info_-_DAM_May_2016_Meta_Data_Info.pdf'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Monthly'}]}
# **********
# {'categories': ['housing & development', 'demographics', 'transportation'], 'tags': [], 'domain_category': 'Property', 'domain_tags': ['accessibility', 'bicycle', 'building', 'census of land use and employment', 'changemaker', 'cityreactivation', 'clue', 'construction date', 'entrepreneur', 'floors', 'people', 'refurbish', 'safemobility', 'use'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All data held by the City of Melbourne has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Data-quality-statement', 'value': 'Building accessibility data is collected to track accessibility for internal City of Melbourne purposes. This data is provided as a community service by the City of Melbourne. It is not and does not purport to be a complete guide. There may be errors or omissions. Data is liable to change. The City of Melbourne accepts no responsibility in respect of any claim arising from use or reliance upon this data.'}, {'key': 'How-to-use_Further-information', 'value': 'http://www.melbourne.vic.gov.au/clue'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['housing & development', 'demographics'], 'tags': [], 'domain_category': 'Property', 'domain_tags': ['accessibility', 'building', 'cityreactivation', 'permits', 'planning'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Monthly'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Weekly'}]}
# **********
# {'categories': ['transportation', 'recreation', 'economy'], 'tags': [], 'domain_category': 'Transport', 'domain_tags': ['accessibility', 'bay', 'car', 'parking', 'restrictions', 'signs', 'transport'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All parking signs that have a relevant mapped parking bay.'}, {'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Quality_Source-data-update-frequency', 'value': 'Daily'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Daily'}]}
# **********
# {'categories': ['housing & development'], 'tags': [], 'domain_category': 'Property', 'domain_tags': ['3d', 'building', 'footprint', 'placesforpeople'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All data held by the City of Melbourne has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['environmental monitoring', 'humidity', 'light', 'researcher', 'sensors', 'temperature'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Static (not updated)'}]}
# **********
# {'categories': ['infrastructure', 'politics'], 'tags': [], 'domain_category': 'City Council', 'domain_tags': ['accessibility', 'barbeques', 'bicycle rails', 'bollards', 'drinking fountains', 'eventsplanner', 'hoops', 'horse troughs', 'information pillars', 'litter bins', 'picnic setting', 'rubbish bin', 'safemobility', 'seats'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All data has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'How-to-use_Further-information', 'value': 'Data is updated yearly (but refreshed overnight)'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Weekly'}]}
# **********
# {'categories': ['housing & development'], 'tags': [], 'domain_category': 'Property', 'domain_tags': ['3d', 'accessibility', 'activity', 'building', 'cityreactivation', 'dam', 'dev', 'development', 'development footprints', 'dwellings', 'footprints', 'monitor', 'office', 'planning', 'property', 'retail'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All known major developments'}, {'key': 'Quality_Update-frequency', 'value': 'Monthly'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Monthly'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'Property', 'domain_tags': ['boundaries', 'cityreactivation', 'land', 'property', 'safemobility'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': 'Quality_Source-data-update-frequency', 'value': 'Daily'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Daily'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'Property', 'domain_tags': ['addresses', 'property', 'safe mobility', 'street'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'Property', 'domain_tags': ['growth city', 'house prices', 'property', 'residence', 'stats'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['environment', 'finance', 'demographics'], 'tags': [], 'domain_category': 'Property', 'domain_tags': ['census of land use and employment', 'cityreactivation', 'clue', 'dwelling', 'house', 'residential', 'student apartment', 'townhouse'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'Full dataset has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Quality_Data-quality-statement', 'value': "Data is summarised from the City of Melbourne's property rates database. "}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['transportation', 'housing & development', 'demographics'], 'tags': [], 'domain_category': 'Transport', 'domain_tags': ['accessibility', 'census of land use and employment', 'cityreactivation', 'clue', 'parking'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'Full dataset has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Quality_Data-quality-statement', 'value': "A team of 4 census officers conduct field interviews which involves visiting every establishment in every building in the Census area (City of Melbourne municipality). Every commercial property is surveyed at least once every two years. Information about residential properties is based on the Council's property rates database."}, {'key': 'How-to-use_Further-information', 'value': 'http://www.melbourne.vic.gov.au/clue'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['economy', 'demographics', 'transportation'], 'tags': [], 'domain_category': 'Business', 'domain_tags': ['accessibility', 'anzsic', 'business', 'census of land use and employment', 'cityreactivation', 'clue', 'industry', 'trading name'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'Full dataset has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Quality_Data-quality-statement', 'value': 'A team of 4 census officers conduct field interviews which involves visiting every establishment in every building in the Census area (City of Melbourne municipality). Every commercial property is surveyed at least once every two years.'}, {'key': 'How-to-use_Further-information', 'value': 'http://www.melbourne.vic.gov.au/clue'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['education', 'infrastructure'], 'tags': [], 'domain_category': 'People', 'domain_tags': ['accessibility', 'buildings', 'cityreactivation', 'eventsplanner', 'landmarks', 'recreation', 'significant', 'sport', 'transport', 'worship'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All data held by the City of Melbourne has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Monthly'}]}
# **********
# {'categories': ['economy'], 'tags': [], 'domain_category': 'Business', 'domain_tags': ['census of land use and employment', 'cityreactivation', 'clue', 'employment', 'establishments', 'floor space'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All data held by the City of Melbourne has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Quality_Data-quality-statement', 'value': 'A team of up to 6 surveyors conducts a field survey which involves visiting every establishment in every building in the Census area (City of Melbourne municipality). Every commercial property is surveyed at least once every two years.'}, {'key': 'How-to-use_Further-information', 'value': 'http://www.melbourne.vic.gov.au/clue'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['demographics'], 'tags': [], 'domain_category': 'City Council', 'domain_tags': ['3d', 'building', 'cloud', 'heights', 'lidar', 'model', 'planning', 'point'], 'domain_metadata': [{'key': 'Quality_Known-Issues', 'value': 'None'}, {'key': 'Quality_Data-quality-statement', 'value': 'Supplied survey control used for control (Madigan Surveying) – 25 cm absolute accuracy'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': "Quality_What's-included", 'value': 'XYZ points for buildings, terrain, vegetation (non classified) for the City of Melbourne area.'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Static (not updated)'}]}
# **********
# {'categories': ['transportation', 'recreation', 'environment'], 'tags': [], 'domain_category': 'Transport', 'domain_tags': ['changemaker', 'citizenreporter', 'entrepreneur', 'parking', 'sensors'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All data has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'How-to-use_Further-information', 'value': 'http://www.melbourne.vic.gov.au/ParkingTransportandRoads/Parking/Pages/InGroundSensors.aspx'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Real-time'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['forest', 'soils', 'tree', '#urbanforest', 'urban forest'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All data held by the City of Melbourne has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Static (not updated)'}]}
# **********
# {'categories': ['environment', 'infrastructure'], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['assets', 'changemaker', 'energy', 'environment', 'ghg', 'green house gas'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'Some information has been removed due to contractual agreements with suppliers'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'How-to-use_Linked-to', 'value': 'Environmental Data - Assets, Environmental Data - GHG Factors'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['housing & development'], 'tags': [], 'domain_category': 'Property', 'domain_tags': ['3d', 'accessibility', 'building', 'development', 'footprint', 'planning'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Static (not updated)'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'Transport', 'domain_tags': ['pedestrian', 'sensors', 'foot traffic', 'traffic flow', 'safemobility'], 'domain_metadata': [{'key': 'Data-management_Source-data-update-frequency', 'value': '15 Minutes'}, {'key': 'Quality_Update-frequency', 'value': '15 Minutes'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Quality_Known-Issues', 'value': 'None'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'Business', 'domain_tags': ['census of land use and employment', 'clue', 'small areas', 'suburb'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All data held by the City of Melbourne has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'Transport', 'domain_tags': ['cityreactivation', 'directions', 'foot traffic', 'locations', 'pedestrian', 'safemobility', 'sensors', 'status', 'traffic flow'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All data held by the City of Melbourne has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Daily'}]}
# **********
# {'categories': ['demographics', 'economy'], 'tags': [], 'domain_category': 'Property', 'domain_tags': ['3d', 'analysis', 'buildings', 'dsm', 'environment', 'geo', 'gis', 'mesh', 'model', 'modelling', 'photo', 'planning', 'spatial', 'terrain', 'vegetation'], 'domain_metadata': [{'key': 'Quality_Known-Issues', 'value': 'None'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Static (not updated)'}]}
# **********
# {'categories': ['transportation', 'demographics'], 'tags': [], 'domain_category': 'Transport', 'domain_tags': ['count', 'movement', 'transport', 'vehicle'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'How-to-use_Linked-to', 'value': 'Road Corridor'}, {'key': 'How-to-use_Further-information', 'value': 'To create a spatial dataset use the road_segment and the seg_id fields to join the two datasets'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['economy', 'demographics', 'transportation'], 'tags': [], 'domain_category': 'Business', 'domain_tags': ['bar', 'beverage', 'business', 'census of land use and employment', 'cityreactivation', 'clue', 'food', 'industry', 'pub'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'Full dataset has been included.'}, {'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Data-quality-statement', 'value': ' A team of 4 census officers conduct field interviews which involves visiting every establishment in every building in the Census area (City of Melbourne municipality). Every commercial property is surveyed at least once every two years.'}, {'key': 'How-to-use_Further-information', 'value': 'http://www.melbourne.vic.gov.au/clue'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['transportation', 'public safety'], 'tags': [], 'domain_category': 'Transport', 'domain_tags': ['accessibility', 'parking', 'sensors', 'transport', 'travel'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Real-time'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['climate adaptation', 'green', 'infrastructure', 'rooftop', '#urbanforest'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All data held by the City of Melbourne has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'How-to-use_Linked-to', 'value': 'http://cityofmelbourne.maps.arcgis.com/apps/MapSeries/index.html?appid=5c6bf1fc3f094e418e55eb1bce03953e'}, {'key': 'How-to-use_Further-information', 'value': 'http://www.melbourne.vic.gov.au/Sustainability/RooftopProject/Pages/Rooftop.aspx'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Static (not updated)'}]}
# **********
# {'categories': ['environment', 'economy', 'infrastructure'], 'tags': [], 'domain_category': 'Business', 'domain_tags': ['business', 'census of land use and employment', 'cityreactivation', 'clue', 'employment', 'industry', 'jobs'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'This dataset has been confidentialised to protect the commercially sensitive information of individual businesses. Data in cells which pertain to two or fewer businesses have been suppressed and are shown as a blank cell. The row and column totals refer to the true total, including those suppressed cells.'}, {'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Data-quality-statement', 'value': 'A team of 4 census officers conduct field interviews which involves visiting every establishment in every building in the Census area (City of Melbourne municipality). Every commercial property is surveyed at least once every two years.'}, {'key': 'How-to-use_Linked-to', 'value': 'https://data.melbourne.vic.gov.au/Economy/Census-of-Land-Use-and-Employment-Blocks/aia8-ryiq'}, {'key': 'How-to-use_Further-information', 'value': 'http://www.melbourne.vic.gov.au/clue'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['housing & development', 'demographics'], 'tags': [], 'domain_category': 'Property', 'domain_tags': ['3d', 'boundary', 'building footprint', 'development', 'planning', 'property', 'spatial', 'structures'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Static (not updated)'}]}
# **********
# {'categories': ['infrastructure', 'environment', 'economy'], 'tags': [], 'domain_category': 'Business', 'domain_tags': ['census of land use and employment', 'cityreactivation', 'clue', 'floor space', 'office', 'retail', 'space use'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'This dataset has been confidentialised to protect the commercially sensitive information of individual businesses. Data in cells which pertain to two or fewer businesses have been suppressed and are shown as a blank cell. The row and column totals refer to the true total, including those suppressed cells.'}, {'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Data-quality-statement', 'value': 'A team of 4 census officers conduct field interviews which involves visiting every establishment in every building in the Census area (City of Melbourne municipality). Every commercial property is surveyed at least once every two years.'}, {'key': 'How-to-use_Linked-to', 'value': 'https://data.melbourne.vic.gov.au/Economy/Census-of-Land-Use-and-Employment-Blocks/aia8-ryiq'}, {'key': 'How-to-use_Further-information', 'value': 'http://www.melbourne.vic.gov.au/clue'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'Property', 'domain_tags': ['area', 'boundaries', 'location', 'postcode'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All data held by the City of Melbourne has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Monthly'}]}
# **********
# {'categories': ['public safety', 'demographics', 'economy'], 'tags': [], 'domain_category': 'People', 'domain_tags': ['city services', 'indicators', 'liveability', 'measures', 'melbourne', 'performance', 'quality of life', 'stats'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'These are indicators and in most cases City of Melbourne keeps or has access to more detailed data or underlying unit records and historical data.'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Quality_Data-quality-statement', 'value': "This data set has been verified by independent verifiers for accreditation under ISO. Where City of Melbourne didn't have data to report the indicators were left blank."}, {'key': 'How-to-use_Further-information', 'value': 'http://open.dataforcities.org/'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['infrastructure', 'recreation'], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['climate adaptation', 'green infrastructure', 'greening', 'laneways', '#urbanforest'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All data held by the City of Melbourne has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Static (not updated)'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'Transport', 'domain_tags': ['accessibility', 'aids', 'hearing', 'innovation', 'pids', 'safemobility', 'stations', 'train', 'transport'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'Data relating to stations with accessibility information'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Quality_Data-quality-statement', 'value': 'Data may not be complete'}, {'key': 'How-to-use_Further-information', 'value': 'Data will be availible for duration of Open Innovation Competition only. '}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Static (not updated)'}]}
# **********
# {'categories': ['environment', 'economy', 'social services'], 'tags': [], 'domain_category': 'Business', 'domain_tags': ['business', 'census of land use and employment', 'cityreactivation', 'clue', 'industry'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'Full dataset has been included.'}, {'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Data-quality-statement', 'value': 'A team of 4 census officers conduct field interviews which involves visiting every establishment in every building in the Census area (City of Melbourne municipality). Every commercial property is surveyed at least once every two years.'}, {'key': 'How-to-use_Further-information', 'value': 'http://www.melbourne.vic.gov.au/clue'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['housing & development', 'demographics', 'transportation'], 'tags': [], 'domain_category': 'Property', 'domain_tags': ['accessibility', 'bicycle', 'building', 'census of land use and employment', 'changemaker', 'clue', 'clue2019', 'construction date', 'entrepreneur', 'floors', 'people', 'use'], 'domain_metadata': [{'key': 'Quality_Known-Issues', 'value': 'None'}, {'key': "Quality_What's-included", 'value': 'All data held by the City of Melbourne has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Every two years'}, {'key': 'Quality_Data-quality-statement', 'value': 'Building accessibility data is collected to track accessibility for internal City of Melbourne purposes. This data is provided as a community service by the City of Melbourne. It is not and does not purport to be a complete guide. There may be errors or omissions. Data is liable to change. The City of Melbourne accepts no responsibility in respect of any claim arising from use or reliance upon this data.'}, {'key': 'How-to-use_Further-information', 'value': 'http://www.melbourne.vic.gov.au/clue'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Every two years'}]}
# **********
# {'categories': ['environment', 'infrastructure'], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['bins', 'dumped rubbish', 'green waste', 'hard waste', 'recycling', 'rubbish', 'waste'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All monthly waste data from April 2009 - March 2020'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Monthly'}]}
# **********
# {'categories': ['demographics'], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['aerial', 'image', 'imagery', 'melbourne', 'property'], 'domain_metadata': [{'key': 'Quality_Known-Issues', 'value': 'None'}, {'key': "Quality_What's-included", 'value': 'All imagery for the City of Melbourne boundary'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'How-to-use_Further-information', 'value': 'http://www.arborcarbon.com.au/'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Static (not updated)'}]}
# **********
# {'categories': ['transportation'], 'tags': [], 'domain_category': 'Transport', 'domain_tags': ['laneways', 'roads', 'safemobility', 'segments', 'street names'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Weekly'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'People', 'domain_tags': ['assistance', 'food', 'help', 'homeless', 'services', 'support'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All known information has been provided, however, some organisations may not have complete data for all fields'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Quality_Data-quality-statement', 'value': 'This data has been retrofitted from the original helping out booklet, please feel free to contact us to notify of any data issues'}, {'key': 'How-to-use_Further-information', 'value': 'https://www.melbourne.vic.gov.au/CommunityServices/SocialSupport/Documents/Helping_Out_Booklet.pdf'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}, {'key': 'Melbourne-Metadata_Further-Information', 'value': 'https://www.melbourne.vic.gov.au/CommunityServices/SocialSupport/Documents/Helping_Out_Booklet.pdf'}]}
# **********
# {'categories': ['demographics', 'education'], 'tags': [], 'domain_category': 'People', 'domain_tags': ['city services', 'community cohesion', 'food', 'health', 'indicators', 'liveability', 'measures', 'performance', 'quality of life', 'safety', 'stats', 'wellbeing'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All data held by the City of Melbourne has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'City Council', 'domain_tags': ['accessibility', 'assets', 'communitysafety', 'fire', 'hydrant'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Weekly'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'Transport', 'domain_tags': ['accessibility', 'names', 'roads', 'safemobility', 'streets'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Weekly'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'City Council', 'domain_tags': ['barbecue', 'bbq', 'eventsplanner', 'food', 'parks', 'picnic', 'public bbq'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All data held by the City of Melbourne has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Weekly'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['3d', 'analysis', 'buildings', 'dsm', 'environment', 'geo', 'gis', 'model', 'modelling', 'planning', 'spatial', 'terrain', 'vegetation'], 'domain_metadata': [{'key': 'Quality_Known-Issues', 'value': 'No known issues'}, {'key': "Quality_What's-included", 'value': 'All surface data for City of Melbourne municipality'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Static (not updated)'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'City Council', 'domain_tags': ['accessibility', 'cityreactivation', 'eventsplanner', 'footpath', 'gradients', 'safemobility'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All data held by the City of Melbourne has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Static (not updated)'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'City Council', 'domain_tags': ['cityreactivation', 'drain', 'drainage', 'drainpipes', 'drains', 'flow', 'ocd-drainpipes-0.2', 'opencouncildata', 'pipe', 'pipes', 'water'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Weekly'}]}
# **********
# {'categories': ['transportation'], 'tags': [], 'domain_category': 'Transport', 'domain_tags': ['car', 'machine', 'meters', 'parking', 'ticket', 'transport'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All council managed parking meter assets'}, {'key': 'Quality_Update-frequency', 'value': 'Monthly'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Quality_Source-data-update-frequency', 'value': 'Daily'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Daily'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'City Council', 'domain_tags': ['accessibility', 'cityreactivation', 'eventsplanner', 'ocd-toilets-1.2', 'opencouncildata', 'toilets'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All data held by the City of Melbourne has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Quality_Source-data-update-frequency', 'value': 'Monthly'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Monthly'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'City Council', 'domain_tags': ['budget', 'charges', 'citizenreporter', 'facilities', 'fees'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'Only raw data tables from the annual plan and budget have been included, tables that are calculations from this data has not been included'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Data-quality-statement', 'value': 'This dataset is from the figures provided in the Annual plan and budget each financial year'}, {'key': 'How-to-use_Further-information', 'value': 'http://www.melbourne.vic.gov.au/AboutCouncil/financegovernance/Budget/Documents/Annual_Plan_Budget_Document_2014_2015.pdf'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'City Council', 'domain_tags': ['accessibility', 'art', 'artwork', 'eventsplanner', 'fountain', 'monument', 'street art'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All data held by the City of Melbourne has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Monthly'}]}
# **********
# {'categories': ['environment'], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['citizenreporter', 'eventsplanner', 'forest', 'tree', '#urbanforest', 'urban forest'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['politics', 'economy', 'housing & development'], 'tags': [], 'domain_category': 'Business', 'domain_tags': ['beverage', 'business', 'census of land use and employment', 'clue', 'clue2019', 'food', 'industry'], 'domain_metadata': [{'key': 'Quality_Known-Issues', 'value': 'None'}, {'key': 'Quality_Data-quality-statement', 'value': 'A team of up to 6 surveyors conducts a field survey which involves visiting every establishment in every building in the Census area (City of Melbourne municipality). Every commercial property is surveyed at least once every two years.'}, {'key': 'Quality_Update-frequency', 'value': 'Every two years'}, {'key': "Quality_What's-included", 'value': 'Full dataset has been included'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Every two years'}]}
# **********
# {'categories': ['recreation', 'environment'], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['air quality', 'cityreactivation', 'environment', 'environmental monitoring', 'microclimate', 'particulate', 'pressure', 'sensor', 'sensors', 'temperature', 'wind'], 'domain_metadata': [{'key': 'Quality_Known-Issues', 'value': 'Note this dataset may not contain a reading for every sensor for every 15 minutes as the sensor devices might not have a reading for each value. There may be situations where no readings are reported for all sensors or only some readings are reported at a particular site. '}, {'key': 'Quality_Update-frequency', 'value': 'Hourly'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Hourly'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'Property', 'domain_tags': ['boundaries', 'entrepreneur', 'municipality', 'safemobility'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All data held by the City of Melbourne has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['housing & development', 'infrastructure', 'environment'], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['assets', 'carbon', 'changemaker', 'energy', 'environment', 'ghg', 'green house gas'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'Some information has been removed due to contractual agreements with suppliers'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'How-to-use_Linked-to', 'value': 'Environmental Data - Assets, Environmental Data - Billing Data'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['changemaker', 'forest', 'heat', 'parks', 'researcher', 'thermal', 'trees', '#urbanforest', 'urban forest'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'The whole thermal image file has been provided, however it is supplied as a geodatabase file that is used in Esri mapping system'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Static (not updated)'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'Transport', 'domain_tags': ['ptv', 'public transport', 'routes', 'trams'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All data held by the City of Melbourne has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['demographics'], 'tags': [], 'domain_category': 'People', 'domain_tags': ['growth', 'household type', 'population forecasts', 'small areas', 'stats'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'The latest City of Melbourne population forecasts for household types. Forecasts are provided for Melbourne LGA and Census of Land Use and Employment small areas.'}, {'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['transportation'], 'tags': [], 'domain_category': 'Transport', 'domain_tags': ['accessibility', 'bus stops', 'eventsplanner', 'signs'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'The whole dataset has been included (many non meaningful fields will be removed over time)'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Quality_Data-quality-statement', 'value': 'The location of these signs are completely accurate, however the dataset is not as meaningful as could be, we are continually working on improving this dataset and value your feedback'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Static (not updated)'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'City Council', 'domain_tags': ['drinking', 'eventsplanner', 'fountain', 'summer', 'tap', 'water'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All data held by the City of Melbourne has been included'}, {'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Weekly'}]}
# **********
# {'categories': ['transportation'], 'tags': [], 'domain_category': 'Transport', 'domain_tags': ['accessibility', 'area', 'cityreactivation', 'engineering', 'polygons', 'road', 'safemobility', 'surface', 'surfaces'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'Complete'}, {'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Weekly'}, {'key': 'Internal-management_IMGF-risk-level', 'value': 'Low risk'}, {'key': 'Internal-management_Update-mechanism', 'value': 'Scheduled FME job'}, {'key': 'Internal-management_Source-system-(GIS,-AssetMaster,-etc)', 'value': 'GIS, AssetMaster'}]}
# **********
# {'categories': ['environment', 'demographics'], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['greening', 'schedule', 'tree', 'tree planting', 'trees', 'urban forest'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['demographics', 'health'], 'tags': [], 'domain_category': 'Property', 'domain_tags': ['aerial', 'gis', 'image', 'imagery', 'melbourne', 'ortho', 'property', 'spatial'], 'domain_metadata': [{'key': 'Quality_Known-Issues', 'value': 'None'}, {'key': "Quality_What's-included", 'value': 'All imagery for the City of Melbourne boundary'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Static (not updated)'}]}
# **********
# ...
# **********
# {'categories': ['infrastructure', 'economy', 'environment'], 'tags': [], 'domain_category': 'Business', 'domain_tags': ['census of land use and employment', 'cityreactivation', 'clue', 'clue2018', 'clue blocks', 'employment', 'jobs', 'office', 'retail', 'space use'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'This dataset has been confidentialised to protect the commercially sensitive information of individual businesses. Data in cells which pertain to two or fewer businesses have been suppressed and are shown as a blank cell. The row and column totals refer to the true total, including those suppressed cells.'}, {'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Data-quality-statement', 'value': 'A team of 4 census officers conduct field interviews which involves visiting every establishment in every building in the Census area (City of Melbourne municipality). Every commercial property is surveyed at least once every two years.'}, {'key': 'How-to-use_Linked-to', 'value': 'https://data.melbourne.vic.gov.au/Economy/Census-of-Land-Use-and-Employment-Blocks/aia8-ryiq'}, {'key': 'How-to-use_Further-information', 'value': 'http://www.melbourne.vic.gov.au/clue'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['environment', 'social services', 'economy'], 'tags': [], 'domain_category': 'Business', 'domain_tags': ['anzsic', 'clue', 'clue2019', 'clue blocks', 'floor space', 'industry'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'This data set has been confidentialised to protect the commercially sensitive information of individual businesses. Data in cells which pertain to two or fewer businesses have been suppressed and are shown as a blank cell. The row and column totals refer to the true total, including those suppressed cells. CLUE unique codes for residential, vacant, open space and common area floor space are not included in ANZSIC1 classification and not found in this data set. '}, {'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Data-quality-statement', 'value': 'A team of 4 census officers conduct field interviews which involves visiting every establishment in every building in the Census area (City of Melbourne municipality). Every commercial property is surveyed at least once every two years.'}, {'key': 'How-to-use_Further-information', 'value': 'http://www.melbourne.vic.gov.au/clue'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['transportation', 'public safety'], 'tags': [], 'domain_category': 'Transport', 'domain_tags': ['accessibility', 'parking', 'sensors', 'transport', 'travel'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Static (not updated)'}]}
# **********
# {'categories': ['public safety', 'demographics'], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['canopy cover', 'image', 'imagery', 'multispectral', 'nir', 'plants', 'tree', 'vegetation', 'vegetation health'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'All imagery for the City of Melbourne boundary'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Quality_Data-quality-statement', 'value': 'Data has been quality assured'}, {'key': 'How-to-use_Further-information', 'value': 'http://www.arborcarbon.com.au/ '}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Static (not updated)'}]}
# **********
# {'categories': ['environment', 'economy', 'infrastructure'], 'tags': [], 'domain_category': 'Business', 'domain_tags': ['anzsic', 'clue', 'clue 2019', 'clue blocks', 'floor space', 'industry'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'This data set has been confidentialised to protect the commercially sensitive information of individual businesses. Data in cells which pertain to two or fewer businesses have been suppressed and are shown as a blank cell. The row and column totals refer to the true total, including those suppressed cells. CLUE unique codes for residential, vacant, open space and common area floor space are not included in ANZSIC1 classification and not found in this data set.'}, {'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Data-quality-statement', 'value': 'A team of 4 census officers conduct field interviews which involves visiting every establishment in every building in the Census area (City of Melbourne municipality). Every commercial property is surveyed at least once every two years.'}, {'key': 'How-to-use_Further-information', 'value': 'http://www.melbourne.vic.gov.au/clue'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['finance'], 'tags': [], 'domain_category': 'Business', 'domain_tags': ['budget', 'citizenreporter', 'costs', 'funding', 'grants'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'Only raw data tables from the annual plan and budget have been included, tables that are calculations from this data has not been included'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Quality_Data-quality-statement', 'value': 'This dataset is from the figures provided in the Annual plan and budget each financial year'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'Property', 'domain_tags': ['berth', 'berths', 'board', 'dock', 'marine', 'transport', 'water'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['environment', 'social services', 'economy'], 'tags': [], 'domain_category': 'Business', 'domain_tags': ['anzsic', 'clue', 'clue blocks', 'floor space', 'industry'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'This data set has been confidentialised to protect the commercially sensitive information of individual businesses. Data in cells which pertain to two or fewer businesses have been suppressed and are shown as a blank cell. The row and column totals refer to the true total, including those suppressed cells. CLUE unique codes for residential, vacant, open space and common area floor space are not included in ANZSIC1 classification and not found in this data set. '}, {'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Data-quality-statement', 'value': 'A team of 4 census officers conduct field interviews which involves visiting every establishment in every building in the Census area (City of Melbourne municipality). Every commercial property is surveyed at least once every two years.'}, {'key': 'How-to-use_Further-information', 'value': 'http://www.melbourne.vic.gov.au/clue'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['environment'], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['greening', 'plant', 'tree', 'urbanforest', 'vegetation', 'vegetation health'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['environment'], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['dsrf', 'polystyrene', 'recycling', 'waste'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Daily'}]}
# **********
# {'categories': ['demographics', 'environment'], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['building managment', 'buildings', 'cityreactivation', 'climate', 'electricity', 'energy', 'energy management', 'energy performance', 'green buildings', 'property management'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'Modelled energy consumption for every block in City of Melbourne municipality'}, {'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'How-to-use_Further-information', 'value': 'http://imap.vic.gov.au/uploads/Meeting%20Agendas/2014%20August/Att%207a_IMAP_Energy_Map_-_CSIRO_-_Energy_Use_2011-2026_Report_-_2014June30_-Final_pdf_11.2MB.pdf'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'City Council', 'domain_tags': ['banner', 'pole', 'bookable', 'city events', 'promotion', 'assets'], 'domain_metadata': [{'key': 'Data-management_Source-data-update-frequency', 'value': 'Weekly'}, {'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}]}
# **********
# {'categories': ['demographics', 'environment'], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['building managment', 'buildings', 'cityreactivation', 'climate', 'electricity', 'energy', 'energy management', 'energy performance', 'green buildings', 'property management'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'Modelled energy consumption for every block in City of Melbourne municipality'}, {'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'How-to-use_Further-information', 'value': 'http://imap.vic.gov.au/uploads/Meeting%20Agendas/2014%20August/Att%207a_IMAP_Energy_Map_-_CSIRO_-_Energy_Use_2011-2026_Report_-_2014June30_-Final_pdf_11.2MB.pdf'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['demographics', 'environment'], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['building managment', 'buildings', 'cityreactivation', 'climate', 'electricity', 'energy', 'energy management', 'energy performance', 'green buildings', 'property management'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'Modelled energy consumption for every block in City of Melbourne municipality'}, {'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'How-to-use_Further-information', 'value': 'http://imap.vic.gov.au/uploads/Meeting%20Agendas/2014%20August/Att%207a_IMAP_Energy_Map_-_CSIRO_-_Energy_Use_2011-2026_Report_-_2014June30_-Final_pdf_11.2MB.pdf'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['finance'], 'tags': [], 'domain_category': 'Business', 'domain_tags': ['budget', 'citizenreporter', 'equity', 'surplus'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'Only raw data tables from the annual plan and budget have been included, tables that are calculations from this data has not been included'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Quality_Data-quality-statement', 'value': 'This dataset is from the figures provided in the Annual plan and budget each financial year'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': ['environment', 'economy', 'infrastructure'], 'tags': [], 'domain_category': 'Business', 'domain_tags': ['anzsic', 'clue', 'clue 2018', 'clue blocks', 'floor space', 'industry'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'This data set has been confidentialised to protect the commercially sensitive information of individual businesses. Data in cells which pertain to two or fewer businesses have been suppressed and are shown as a blank cell. The row and column totals refer to the true total, including those suppressed cells. CLUE unique codes for residential, vacant, open space and common area floor space are not included in ANZSIC1 classification and not found in this data set.'}, {'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Data-quality-statement', 'value': 'A team of 4 census officers conduct field interviews which involves visiting every establishment in every building in the Census area (City of Melbourne municipality). Every commercial property is surveyed at least once every two years.'}, {'key': 'How-to-use_Further-information', 'value': 'http://www.melbourne.vic.gov.au/clue'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Annually'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['soil', 'moisture', 'sensor', 'iot', 'sensors', 'temperature'], 'domain_metadata': [{'key': 'Data-management_Source-data-update-frequency', 'value': 'Daily'}, {'key': 'Quality_Update-frequency', 'value': 'Daily'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Quality_Known-Issues', 'value': 'None'}]}
# **********
# {'categories': ['environment'], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['centreplace', 'commingled', 'dsrf', 'recycling', 'waste'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Daily'}]}
# **********
# {'categories': ['demographics'], 'tags': [], 'domain_category': 'People', 'domain_tags': ['diversity', 'food security', 'health', 'indicators', 'learning', 'liveability', 'participation in activities', 'residents', 'safety', 'stats', 'wellbeing'], 'domain_metadata': [{'key': "Quality_What's-included", 'value': 'Resident indicator results derived from the City of Melbourne Social Indicator Survey (CoMSIS).'}, {'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Static (not updated)'}]}
# **********
# {'categories': ['environment'], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['commingled', 'dsrf', 'recycling', 'waste'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Daily'}]}
# **********
# {'categories': ['environment'], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['bales', 'cardboard', 'dsrf', 'recycling', 'waste'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Static (not updated)'}, {'key': 'Quality_Reliability-level', 'value': 'Useful with caveats'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Daily'}]}
# **********
# {'categories': [], 'tags': [], 'domain_category': 'Environment', 'domain_tags': ['canopy', 'citizenreporter', 'eventsplanner', 'forest', 'tree', '#urbanforest', 'urban forest'], 'domain_metadata': [{'key': 'Quality_Update-frequency', 'value': 'Annually'}, {'key': 'Quality_Reliability-level', 'value': 'Reliable and timely'}, {'key': 'Data-management_Source-data-update-frequency', 'value': 'Static (not updated)'}]}
# **********

# %%
content = BeautifulSoup(client.datasets()[0]['resource']['description'])
content
# Out:
# <html><body><p>This dataset contains hourly pedestrian counts since 2009 from pedestrian sensor devices located across the city. The data is updated on a monthly basis and can be used to determine variations in pedestrian activity throughout the day.
# </p><p>The sensor_id column can be used to merge the data with the <a href="https://data.melbourne.vic.gov.au/Transport-Movement/Pedestrian-Counting-System-Sensor-Locations/h57g-5234">Pedestrian Counting System - Sensor Locations</a> dataset which details the location, status and directional readings of sensors. Any changes to sensor locations are important to consider when analysing and interpreting pedestrian counts over time.
# </p><p><b>Importants notes about this dataset:</b>
# <br/>•	Where no pedestrians have passed underneath a sensor during an hour, a count of zero will be shown for the sensor for that hour.
# <br/>•	Directional readings are not included, though we hope to make this available later in the year.  Directional readings are provided in the <a href=" https://data.melbourne.vic.gov.au/d/d6mv-s43h">Pedestrian Counting System – Past Hour (counts per minute)</a> dataset.
# </p><p>The <a href="https://www.melbourne.vic.gov.au/about-melbourne/research-and-statistics/city-population/Pages/pedestrian-counting-system.aspx">Pedestrian Counting System</a> helps to understand how people use different city locations at different times of day to better inform decision-making and plan for the future. A representation of pedestrian volume which compares each location on any given day and time can be found in our <a href="http://www.pedestrian.melbourne.vic.gov.au/?_ga=2.44607906.760678413.1541972518-340051665.1506055261">Online Visualisation</a>.</p><p><b>Related datasets: </b><br/><b><a href=" https://data.melbourne.vic.gov.au/d/d6mv-s43h">Pedestrian Counting System – Past Hour (counts per minute)</a></b><br/><b><a href="https://data.melbourne.vic.gov.au/d/h57g-5234">Pedestrian Counting System - Sensor Locations</a></b></p></body></html>

# %%
for i in content.find_all('b'):
    print(i.string)
# Out:
# Importants notes about this dataset:
# Related datasets:
# Pedestrian Counting System – Past Hour (counts per minute)
# Pedestrian Counting System - Sensor Locations

# %%
import pandas as pd 
result  =client.get_all('vh2v-4nfs')
results_df = pd.DataFrame.from_records(result)
results_df = results_df.iloc[:,:-1]
#results_df.to_csv()

# %%
'Street Name Labels'.find('street')
# Out:
# -1

# %%
table, client= deakin.top_table()
data_table = deakin.keyword_search('parking')
id_list = data_table['Id']
name_list = data_table['Name']
for i in range(len(id_list)):
    name = name_list[i]
    name= name + '.csv'
    name = '_'.join(name.split(' '))
    print(name)
    print(id_list[i])
# Out:
# On-street_Parking_Bay_Sensors.csv
# vh2v-4nfs
# On-street_Parking_Bays.csv
# crvt-b4kt
# Parking_bay_arrivals_and_departures_2014.csv
# mq3i-cbxd
# On-street_Car_Parking_Sensor_Data_-_2017.csv
# u9sa-j86i
# Free_and_cheap_support_services,_with_opening_hours,_public_transport_and_parking_options_(Helping_Out).csv
# jtcb-iab6
# On-street_Car_Parking_Meters_with_Location.csv
# vdsi-4gtj
# On-street_Car_Parking_Sensor_Data_-_2016.csv
# dj7e-rdx9
# On-street_Car_Parking_Sensor_Data_-_2019.csv
# 7pgd-bdf2
# On-street_Car_Parking_Sensor_Data_-_2020_(Jan_-_May).csv
# 4n3a-s6rn
# Pay_Stay_parking_restrictions.csv
# ambt-72qg
# Off-street_car_parking_2019.csv
# g9am-cna5
# Sign_Panels_(Non_Parking).csv
# fzjr-9nrn
# Parking_restrictions_(southeast_CBD_only)_2014.csv
# xgce-vkbh
# Off-street_car_parking_2017_map.csv
# reaf-a4my
# On-street_Car_Parking_Sensor_Data_-_2014.csv
# t6hb-9uf2
# On-street_Car_Parking_Sensor_Data_-_2015.csv
# apua-t2tb
# On-street_Car_Parking_Sensor_Data_-_2011.csv
# vkxi-k7ps
# On-street_Car_Parking_Sensor_Data_-_2018.csv
# 5532-ig9r
# On-street_Car_Parking_Sensor_Data_-_2012.csv
# vbe9-m4tk
# On-street_Car_Parking_Sensor_Data_-_2013.csv
# 7jq6-k9kf

# %%
import pandas as pd 
import os 
pref_path = os.getcwd()+'/Datasets'
result  =client.get('vh2v-4nfs',limit=5000)
name = client.get_metadata('vh2v-4nfs')['name']+'.csv'
results_df = pd.DataFrame.from_records(result)
results_df = results_df.iloc[:,:-1]


try:
    os.makedirs(pref_path)
except OSError:
    pass
else:
    print ("Successfully created the directory %s" % path)

results_df.to_csv(os.path.join(pref_path,name),index=False)
print("Successfully save in directory %s" %os.path.join(pref_path,name))

# %%
# Out:
# '/Users/wuyoscar/Documents/Project/Playground/Oscar/Datasets/On-street Parking Bay Sensors.csv'

# %%
results_df
# Out:
#      bay_id st_marker_id      status  \
# 0       856         671W  Unoccupied
# 1      5358        8897W  Unoccupied
# 2      5524       11981W  Unoccupied
# 3      2256        3953S  Unoccupied
# 4      1260        4450E  Unoccupied
# ...     ...          ...         ...
# 1237   2694       10324E  Unoccupied
# 1238   2696       10326E  Unoccupied
# 1239   3004        5062E  Unoccupied
# 1240   2702       10332E  Unoccupied
# 1241   3019        5100E     Present
#
#                                                location                  lat  \
# 0     {'latitude': '-37.81445691781761', 'longitude'...   -37.81445691781761
# 1     {'latitude': '-37.82450433070958', 'longitude'...   -37.82450433070958
# 2     {'latitude': '-37.81427144972767', 'longitude'...   -37.81427144972767
# 3     {'latitude': '-37.812690507137376', 'longitude...  -37.812690507137376
# 4     {'latitude': '-37.813977354508374', 'longitude...  -37.813977354508374
# ...                                                 ...                  ...
# 1237  {'latitude': '-37.80300386158146', 'longitude'...   -37.80300386158146
# 1238  {'latitude': '-37.80304693129534', 'longitude'...   -37.80304693129534
# 1239  {'latitude': '-37.80512292678459', 'longitude'...   -37.80512292678459
# 1240  {'latitude': '-37.80323724450006', 'longitude'...   -37.80323724450006
# 1241  {'latitude': '-37.804378178842995', 'longitude...  -37.804378178842995
#
#                      lon
# 0     144.96873486337353
# 1     144.96163789794954
# 2     144.98277676593383
# 3     144.95336732046133
# 4      144.9547467827323
# ...                  ...
# 1237  144.94403243100396
# 1238  144.94402475908936
# 1239  144.95805252500634
# 1240  144.94399118932236
# 1241   144.9577120543801
#
# [1242 rows x 6 columns]

# %%
check_list = []
for i in a.lower().split():
    if "street name label".find(i) != -1:
        check_list.append(1)
    else:
        check_list.append(0)

any(check_list)
# Out:
# True

# %%
a = 'AStreet name label'
a.lower().split()
# Out:
# ['astreet', 'name', 'label']

# %%
from bs4 import BeautifulSoup
data_id = ['vh2v-4nfs']
content = client.get_metadata('vh2v-4nfs')
b_content=BeautifulSoup(content['description'],'lxml')
b_content
b_content.p
# Out:
# <p>Contains information from in-ground car parking bay sensors across the city with status indicating if a car is present or not present, the spatial coordinate of the sensor, and the street marker id.
#
# <b>Accessing the most current data:</b>
# To access the most recent data please use the <a href="https://data.melbourne.vic.gov.au/resource/vh2v-4nfs.json?$limit=5000">v2.0 SODA API endpoint</a>
# or the <a href="https://data.melbourne.vic.gov.au/api/views/vh2v-4nfs/rows.csv?accessType=DOWNLOAD">CSV download link</a>. Accessing the data from Socrata's v2.1 SODA API will access cached data which is only updated hourly.
#
# <b>Additional information:</b>
# Further information about City of Melbourne's parking sensors can be found <a href="https://www.melbourne.vic.gov.au/parking-and-transport/parking/Pages/parking-faqs.aspx#sensors">here</a>.
#
# <b>How the data joins:</b>
# There are three datasets that make up the live parking sensor release. They are the on-street parking bay sensors, <a href="https://data.melbourne.vic.gov.au/Transport-Movement/On-street-Parking-Bays/crvt-b4kt">on-street parking bays</a> and the <a href="https://data.melbourne.vic.gov.au/Transport-Movement/On-street-Car-Park-Bay-Restrictions/ntht-5rk7/data">on-street car park bay restrictions</a>.
# The way the datasets join is as follows. The on-street parking bay sensors join to the on-street parking bays by the marker_id attribute. The on-street parking bay sensors join to the on-street car park bay information by the bay_id attribute. The on-street parking bays and the on-street car park bay information don’t currently join.
#
# <b>Outages</b>
# This dataset is updated through network relays and can be disrupted causing delays in data updates. Users of this data are encouraged to monitor the dataset's last updated timestamp in the <a href="https://data.melbourne.vic.gov.au/api/catalog/v1?ids=vh2v-4nfs" target="_blank">catalogue API JSON endpoint</a> to check for delays in the data being updated.
#
# <b>Disclaimer</b>
# While all due care has been taken to ensure the data of this website is accurate, current and available please note:
# ·         there may be errors or omission in it
# ·         there may be occasions where the data is not available and/or the website will be unavailable.
#
# The City of Melbourne and its employees accept no responsibility for any loss, damage, claim, expense, cost or liability whatsoever (including in contract, tort including negligence, pursuant to statue and otherwise) arising in respect of or in connection with accessing, using or reliance upon the data in this website, or the unavailability of the data or the website.</p>

# %%
from bs4 import BeautifulSoup
content = client.get_metadata('krg7-hmyt')
b_content=BeautifulSoup(content['description'],'lxml')
print(b_content)
result = b_content.p
print(result)
a = result.find(text='How the data joins:')
# Out:
# <html><body><p>Tree canopy within City of Melbourne mapped using 2021 high resolution multi-spectral imagery. The canopy polygons represent actual tree canopy extents on both private and public property across the city.</p></body></html>
# <p>Tree canopy within City of Melbourne mapped using 2021 high resolution multi-spectral imagery. The canopy polygons represent actual tree canopy extents on both private and public property across the city.</p>
