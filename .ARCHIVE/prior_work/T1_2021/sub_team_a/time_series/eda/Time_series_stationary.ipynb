# %%
from statsmodels.tsa.stattools import adfuller, kpss
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.vector_ar.var_model import VAR
from math import sqrt
from sklearn.metrics import mean_absolute_error, mean_squared_error
from pandas.plotting import autocorrelation_plot
from sklearn.model_selection import train_test_split
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
np.set_printoptions(suppress=True)

# %%
df = pd.read_csv('for_time_series_VAR_model.csv')

# %%
#df_Pedestrian=df[['Total_Pedestrian_Count_per_day','Date']]

#Augmented Dickey Fuller test (ADF Test)
result = adfuller(df['Total_Pedestrian_Count_per_day'].values, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'p-value: {result[1]}')
for key, value in result[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# ADF Statistic: -2.1340124129475764
# p-value: 0.23105973610232755
# Critial Values:
#    1%, -3.4334544462214303
# Critial Values:
#    5%, -2.8629114161159666
# Critial Values:
#    10%, -2.5675000767713883

# %%
# Splitting the dataset into train & test subsets
df=df[['Rainfall amount (millimetres)',
      'Minimum temperature (Degree C)','Maximum temperature (Degree C)',
      'Daily global solar exposure (MJ/m*m)','Total_Pedestrian_Count_per_day','Date','Covid Restrictions']]
df['Date'] = pd.to_datetime(df['Date'])
df.drop(index=(df.loc[(df['Covid Restrictions']=='Restrictions')].index))
df.index = df.Date
df = df.drop(['Date','Covid Restrictions'],axis=1)

df_norm=df.apply(lambda x: (x - np.min(x)) / (np.max(x) - np.min(x)))

n_obs = 10
df_train, df_test = df_norm[:-n_obs], df_norm[-n_obs:]

# %%
# Augmented Dickey-Fuller Test (ADF Test) to check for stationarity
from statsmodels.tsa.stattools import adfuller

def adf_test(df):
    dftest = adfuller(df, autolag='AIC')
    adf = pd.Series(dftest[0:4], index = ['Test Statistic','p-value','# Lags','# Observations'])

    for key, value in dftest[4].items():
       adf['Critical Value (%s)'%key] = value
    print (adf)

    p = adf['p-value']
    if p <= 0.05:
        print("\nSeries is Stationary")
    else:
        print("\nSeries is Non-Stationary")


for i in df_train.columns:
    print("Column: ",i)
    print('--------------------------------------')
    adf_test(df_train[i])
    print('\n')

# Differencing all variables to get rid of Stationarity
df_differenced=df_train
df_differenced['Total_Pedestrian_Count_per_day']=np.log(df_differenced['Total_Pedestrian_Count_per_day'])
df_differenced['Daily global solar exposure (MJ/m*m)']=np.log(df_differenced['Daily global solar exposure (MJ/m*m)'])
df_differenced=df_differenced[~df_differenced.isin([np.nan, np.inf, -np.inf]).any(1)].dropna()
# Running the ADF test once again to test for Stationarity
for i in df_differenced.columns:
    print("Column: ",i)
    print('--------------------------------------')
    adf_test(df_differenced[i])
    print('\n')

# Differencing all variables to get rid of Stationarity
df_differenced['Total_Pedestrian_Count_per_day']=df_differenced['Total_Pedestrian_Count_per_day'].diff()
df_differenced['Daily global solar exposure (MJ/m*m)']=df_differenced['Daily global solar exposure (MJ/m*m)'].diff()
df_differenced=df_differenced[~df_differenced.isin([np.nan, np.inf, -np.inf]).any(1)].dropna()

# Running the ADF test once again to test for Stationarity
for i in df_differenced.columns:
    print("Column: ",i)
    print('--------------------------------------')
    adf_test(df_differenced[i])
    print('\n')
# Out:
# Column:  Rainfall amount (millimetres)
# --------------------------------------
# Test Statistic           -24.337858
# p-value                    0.000000
# # Lags                     2.000000
# # Observations          2119.000000
# Critical Value (1%)       -3.433440
# Critical Value (5%)       -2.862905
# Critical Value (10%)      -2.567497
# dtype: float64
#
# Series is Stationary
#
#
# Column:  Minimum temperature (Degree C)
# --------------------------------------
# Test Statistic            -3.391451
# p-value                    0.011254
# # Lags                    16.000000
# # Observations          2105.000000
# Critical Value (1%)       -3.433460
# Critical Value (5%)       -2.862914
# Critical Value (10%)      -2.567501
# dtype: float64
#
# Series is Stationary
#
#
# Column:  Maximum temperature (Degree C)
# --------------------------------------
# Test Statistic            -2.792574
# p-value                    0.059342
# # Lags                    24.000000
# # Observations          2097.000000
# Critical Value (1%)       -3.433472
# Critical Value (5%)       -2.862919
# Critical Value (10%)      -2.567504
# dtype: float64
#
# Series is Non-Stationary
#
#
# Column:  Daily global solar exposure (MJ/m*m)
# --------------------------------------
# Test Statistic            -2.517933
# p-value                    0.111172
# # Lags                    18.000000
# # Observations          2103.000000
# Critical Value (1%)       -3.433463
# Critical Value (5%)       -2.862915
# Critical Value (10%)      -2.567502
# dtype: float64
#
# Series is Non-Stationary
#
#
# Column:  Total_Pedestrian_Count_per_day
# --------------------------------------
# Test Statistic            -1.791533
# p-value                    0.384673
# # Lags                    22.000000
# # Observations          2099.000000
# Critical Value (1%)       -3.433469
# Critical Value (5%)       -2.862918
# Critical Value (10%)      -2.567504
# dtype: float64
#
# Series is Non-Stationary
#
#
# Column:  Rainfall amount (millimetres)
# --------------------------------------
# Test Statistic           -24.377605
# p-value                    0.000000
# # Lags                     2.000000
# # Observations          2117.000000
# Critical Value (1%)       -3.433443
# Critical Value (5%)       -2.862906
# Critical Value (10%)      -2.567497
# dtype: float64
#
# Series is Stationary
#
#
# Column:  Minimum temperature (Degree C)
# --------------------------------------
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Test Statistic            -3.378342
# p-value                    0.011720
# # Lags                    16.000000
# # Observations          2103.000000
# Critical Value (1%)       -3.433463
# Critical Value (5%)       -2.862915
# Critical Value (10%)      -2.567502
# dtype: float64
#
# Series is Stationary
#
#
# Column:  Maximum temperature (Degree C)
# --------------------------------------
# Test Statistic            -2.775584
# p-value                    0.061847
# # Lags                    24.000000
# # Observations          2095.000000
# Critical Value (1%)       -3.433475
# Critical Value (5%)       -2.862921
# Critical Value (10%)      -2.567505
# dtype: float64
#
# Series is Non-Stationary
#
#
# Column:  Daily global solar exposure (MJ/m*m)
# --------------------------------------
# Test Statistic            -2.667422
# p-value                    0.079847
# # Lags                    18.000000
# # Observations          2101.000000
# Critical Value (1%)       -3.433466
# Critical Value (5%)       -2.862917
# Critical Value (10%)      -2.567503
# dtype: float64
#
# Series is Non-Stationary
#
#
# Column:  Total_Pedestrian_Count_per_day
# --------------------------------------
# Test Statistic            -2.205039
# p-value                    0.204422
# # Lags                    24.000000
# # Observations          2095.000000
# Critical Value (1%)       -3.433475
# Critical Value (5%)       -2.862921
# Critical Value (10%)      -2.567505
# dtype: float64
#
# Series is Non-Stationary
#
#
# Column:  Rainfall amount (millimetres)
# --------------------------------------
# Test Statistic           -24.364223
# p-value                    0.000000
# # Lags                     2.000000
# # Observations          2116.000000
# Critical Value (1%)       -3.433444
# Critical Value (5%)       -2.862907
# Critical Value (10%)      -2.567498
# dtype: float64
#
# Series is Stationary
#
#
# Column:  Minimum temperature (Degree C)
# --------------------------------------
# Test Statistic            -3.361806
# p-value                    0.012332
# # Lags                    16.000000
# # Observations          2102.000000
# Critical Value (1%)       -3.433465
# Critical Value (5%)       -2.862916
# Critical Value (10%)      -2.567503
# dtype: float64
#
# Series is Stationary
#
#
# Column:  Maximum temperature (Degree C)
# --------------------------------------
# Test Statistic            -2.741537
# p-value                    0.067122
# # Lags                    24.000000
# # Observations          2094.000000
# Critical Value (1%)       -3.433477
# Critical Value (5%)       -2.862921
# Critical Value (10%)      -2.567505
# dtype: float64
#
# Series is Non-Stationary
#
#
# Column:  Daily global solar exposure (MJ/m*m)
# --------------------------------------
# Test Statistic         -1.825170e+01
# p-value                 2.342079e-30
# # Lags                  1.700000e+01
# # Observations          2.101000e+03
# Critical Value (1%)    -3.433466e+00
# Critical Value (5%)    -2.862917e+00
# Critical Value (10%)   -2.567503e+00
# dtype: float64
#
# Series is Stationary
#
#
# Column:  Total_Pedestrian_Count_per_day
# --------------------------------------
# Test Statistic         -1.038978e+01
# p-value                 2.035220e-18
# # Lags                  2.600000e+01
# # Observations          2.092000e+03
# Critical Value (1%)    -3.433480e+00
# Critical Value (5%)    -2.862923e+00
# Critical Value (10%)   -2.567506e+00
# dtype: float64
#
# Series is Stationary

# %%
from statsmodels.tsa.api import VAR

model = VAR(df_differenced)
results = model.fit(maxlags =15, ic = 'aic')

forecast_values = results.forecast(results.y, steps=len(df_test))
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/wrapper.py:35: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)

# %%
forecast_values=pd.DataFrame(forecast_values,index=df_test.index,columns=['Rainfall amount (millimetres)',
      'Minimum temperature (Degree C)','Maximum temperature (Degree C)',
      'Daily global solar exposure (MJ/m*m)','Total_Pedestrian_Count_per_day'])

# %%
# Actual vs Forecasted Plots
fig, axes = plt.subplots(nrows = 3, ncols = 2, dpi = 100, figsize = (15,10))

for i, (col,ax) in enumerate(zip(df.columns, axes.flatten())):
    forecast_values[col].plot(color = 'b', legend = True,label="forecast",ax = ax).autoscale(axis =' x',tight = True)
    df_test[col].plot(color = 'g', legend = True,label="test",ax = ax)

    ax.set_title('Sensor: ' + col + ' - Actual vs Forecast')
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')

    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize = 6)

plt.tight_layout()
plt.savefig('actual_forecast.png')
plt.show()

# %%
from statsmodels.tsa.api import VAR

model = VAR(df_differenced)
results = model.fit(maxlags = 10, ic = 'aic')
print(results.summary())

# Forecasting for 200 steps ahead
lag_order = results.k_ar
predicted = results.forecast(df_differenced.values[-lag_order:], n_obs)
forecast = pd.DataFrame(predicted, index = df_norm.index[-n_obs:], columns = df_norm.columns)

# Plotting the Forecasted values
p1 = results.plot_forecast(1)
p1.tight_layout()

# Inverting the Differencing Transformation
def invert_transformation(df, df_forecast, second_diff=False):
    for col in df.columns:
        # Undo the 2nd Differencing
        if second_diff:
            df_forecast[str(col)] = (df_test[col].iloc[-1] - df[col].iloc[-2]) + df_forecast[str(col)].cumsum()

        # Undo the 1st Differencing
        df_forecast[str(col)] = df[col].iloc[-1] + df_forecast[str(col)].cumsum()

    return df_forecast

forecast_values = invert_transformation(df_train, forecast, second_diff=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 25, Apr, 2021
# Time:                     08:43:37
# --------------------------------------------------------------------
# No. of Equations:         5.00000    BIC:                   -19.5488
# Nobs:                     2110.00    HQIC:                  -19.9395
# Log likelihood:           6534.49    FPE:                1.74734e-09
# AIC:                     -20.1652    Det(Omega_mle):     1.56872e-09
# --------------------------------------------------------------------
# Results for equation Rainfall amount (millimetres)
# ==========================================================================================================
#                                              coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------------------------------
# const                                           0.009923         0.006042            1.642           0.101
# L1.Rainfall amount (millimetres)                0.143354         0.022647            6.330           0.000
# L1.Minimum temperature (Degree C)               0.030723         0.023116            1.329           0.184
# L1.Maximum temperature (Degree C)               0.038040         0.015239            2.496           0.013
# L1.Daily global solar exposure (MJ/m*m)        -0.050900         0.004039          -12.601           0.000
# L1.Total_Pedestrian_Count_per_day              -0.051141         0.010580           -4.834           0.000
# L2.Rainfall amount (millimetres)                0.112527         0.022830            4.929           0.000
# L2.Minimum temperature (Degree C)               0.049658         0.024432            2.032           0.042
# L2.Maximum temperature (Degree C)              -0.034156         0.018655           -1.831           0.067
# L2.Daily global solar exposure (MJ/m*m)        -0.038959         0.005341           -7.294           0.000
# L2.Total_Pedestrian_Count_per_day              -0.034905         0.011691           -2.986           0.003
# L3.Rainfall amount (millimetres)               -0.017097         0.022792           -0.750           0.453
# L3.Minimum temperature (Degree C)               0.012225         0.024387            0.501           0.616
# L3.Maximum temperature (Degree C)              -0.035837         0.018769           -1.909           0.056
# L3.Daily global solar exposure (MJ/m*m)        -0.022560         0.006077           -3.712           0.000
# L3.Total_Pedestrian_Count_per_day              -0.016662         0.012141           -1.372           0.170
# L4.Rainfall amount (millimetres)                0.009896         0.022696            0.436           0.663
# L4.Minimum temperature (Degree C)               0.016236         0.024397            0.665           0.506
# L4.Maximum temperature (Degree C)              -0.015536         0.018736           -0.829           0.407
# L4.Daily global solar exposure (MJ/m*m)        -0.026096         0.006458           -4.041           0.000
# L4.Total_Pedestrian_Count_per_day              -0.019905         0.012373           -1.609           0.108
# L5.Rainfall amount (millimetres)                0.026342         0.022732            1.159           0.247
# L5.Minimum temperature (Degree C)              -0.038170         0.024393           -1.565           0.118
# L5.Maximum temperature (Degree C)              -0.019810         0.018705           -1.059           0.290
# L5.Daily global solar exposure (MJ/m*m)        -0.018008         0.006604           -2.727           0.006
# L5.Total_Pedestrian_Count_per_day              -0.012025         0.012316           -0.976           0.329
# L6.Rainfall amount (millimetres)               -0.012144         0.022758           -0.534           0.594
# L6.Minimum temperature (Degree C)               0.044034         0.024394            1.805           0.071
# L6.Maximum temperature (Degree C)               0.001108         0.018730            0.059           0.953
# L6.Daily global solar exposure (MJ/m*m)        -0.011779         0.006485           -1.816           0.069
# L6.Total_Pedestrian_Count_per_day              -0.025213         0.012372           -2.038           0.042
# L7.Rainfall amount (millimetres)                0.014186         0.022749            0.624           0.533
# L7.Minimum temperature (Degree C)              -0.036869         0.024331           -1.515           0.130
# L7.Maximum temperature (Degree C)               0.011539         0.018735            0.616           0.538
# L7.Daily global solar exposure (MJ/m*m)        -0.016654         0.006074           -2.742           0.006
# L7.Total_Pedestrian_Count_per_day              -0.006769         0.012120           -0.559           0.576
# L8.Rainfall amount (millimetres)               -0.010809         0.022541           -0.480           0.632
# L8.Minimum temperature (Degree C)               0.078985         0.024220            3.261           0.001
# L8.Maximum temperature (Degree C)              -0.015507         0.018770           -0.826           0.409
# L8.Daily global solar exposure (MJ/m*m)        -0.000817         0.005355           -0.152           0.879
# L8.Total_Pedestrian_Count_per_day               0.012653         0.011682            1.083           0.279
# L9.Rainfall amount (millimetres)               -0.011758         0.022095           -0.532           0.595
# L9.Minimum temperature (Degree C)              -0.053449         0.019200           -2.784           0.005
# L9.Maximum temperature (Degree C)              -0.017909         0.018137           -0.987           0.323
# L9.Daily global solar exposure (MJ/m*m)        -0.005506         0.003910           -1.408           0.159
# L9.Total_Pedestrian_Count_per_day               0.013508         0.010636            1.270           0.204
# ==========================================================================================================
#
# Results for equation Minimum temperature (Degree C)
# ==========================================================================================================
#                                              coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------------------------------
# const                                           0.054215         0.006273            8.643           0.000
# L1.Rainfall amount (millimetres)                0.031597         0.023512            1.344           0.179
# L1.Minimum temperature (Degree C)               0.320596         0.023999           13.359           0.000
# L1.Maximum temperature (Degree C)               0.453961         0.015821           28.694           0.000
# L1.Daily global solar exposure (MJ/m*m)        -0.010131         0.004193           -2.416           0.016
# L1.Total_Pedestrian_Count_per_day               0.015485         0.010983            1.410           0.159
# L2.Rainfall amount (millimetres)               -0.022974         0.023701           -0.969           0.332
# L2.Minimum temperature (Degree C)              -0.018676         0.025364           -0.736           0.462
# L2.Maximum temperature (Degree C)              -0.065838         0.019367           -3.400           0.001
# L2.Daily global solar exposure (MJ/m*m)        -0.013754         0.005545           -2.481           0.013
# L2.Total_Pedestrian_Count_per_day               0.021351         0.012137            1.759           0.079
# L3.Rainfall amount (millimetres)               -0.012486         0.023661           -0.528           0.598
# L3.Minimum temperature (Degree C)               0.043530         0.025318            1.719           0.086
# L3.Maximum temperature (Degree C)               0.013615         0.019485            0.699           0.485
# L3.Daily global solar exposure (MJ/m*m)        -0.005520         0.006309           -0.875           0.382
# L3.Total_Pedestrian_Count_per_day               0.001237         0.012605            0.098           0.922
# L4.Rainfall amount (millimetres)                0.024760         0.023562            1.051           0.293
# L4.Minimum temperature (Degree C)               0.015231         0.025328            0.601           0.548
# L4.Maximum temperature (Degree C)               0.020018         0.019450            1.029           0.303
# L4.Daily global solar exposure (MJ/m*m)        -0.011707         0.006705           -1.746           0.081
# L4.Total_Pedestrian_Count_per_day               0.017723         0.012845            1.380           0.168
# L5.Rainfall amount (millimetres)               -0.000398         0.023599           -0.017           0.987
# L5.Minimum temperature (Degree C)               0.038253         0.025323            1.511           0.131
# L5.Maximum temperature (Degree C)              -0.000592         0.019419           -0.031           0.976
# L5.Daily global solar exposure (MJ/m*m)        -0.004558         0.006856           -0.665           0.506
# L5.Total_Pedestrian_Count_per_day               0.002139         0.012786            0.167           0.867
# L6.Rainfall amount (millimetres)                0.041457         0.023627            1.755           0.079
# L6.Minimum temperature (Degree C)               0.011230         0.025324            0.443           0.657
# L6.Maximum temperature (Degree C)               0.002785         0.019445            0.143           0.886
# L6.Daily global solar exposure (MJ/m*m)        -0.004700         0.006732           -0.698           0.485
# L6.Total_Pedestrian_Count_per_day               0.002144         0.012844            0.167           0.867
# L7.Rainfall amount (millimetres)                0.030460         0.023617            1.290           0.197
# L7.Minimum temperature (Degree C)               0.028682         0.025260            1.135           0.256
# L7.Maximum temperature (Degree C)               0.002173         0.019450            0.112           0.911
# L7.Daily global solar exposure (MJ/m*m)         0.000740         0.006306            0.117           0.907
# L7.Total_Pedestrian_Count_per_day               0.020883         0.012582            1.660           0.097
# L8.Rainfall amount (millimetres)               -0.010777         0.023401           -0.461           0.645
# L8.Minimum temperature (Degree C)              -0.018796         0.025145           -0.747           0.455
# L8.Maximum temperature (Degree C)               0.005292         0.019486            0.272           0.786
# L8.Daily global solar exposure (MJ/m*m)         0.004273         0.005560            0.769           0.442
# L8.Total_Pedestrian_Count_per_day               0.005411         0.012128            0.446           0.655
# L9.Rainfall amount (millimetres)                0.010329         0.022938            0.450           0.652
# L9.Minimum temperature (Degree C)               0.066057         0.019932            3.314           0.001
# L9.Maximum temperature (Degree C)               0.018324         0.018829            0.973           0.330
# L9.Daily global solar exposure (MJ/m*m)         0.001469         0.004059            0.362           0.717
# L9.Total_Pedestrian_Count_per_day              -0.002117         0.011041           -0.192           0.848
# ==========================================================================================================
#
# Results for equation Maximum temperature (Degree C)
# ==========================================================================================================
#                                              coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------------------------------
# const                                           0.010646         0.009587            1.111           0.267
# L1.Rainfall amount (millimetres)               -0.074919         0.035931           -2.085           0.037
# L1.Minimum temperature (Degree C)              -0.006716         0.036676           -0.183           0.855
# L1.Maximum temperature (Degree C)               0.448736         0.024178           18.560           0.000
# L1.Daily global solar exposure (MJ/m*m)         0.042920         0.006409            6.697           0.000
# L1.Total_Pedestrian_Count_per_day               0.055033         0.016785            3.279           0.001
# L2.Rainfall amount (millimetres)               -0.096398         0.036221           -2.661           0.008
# L2.Minimum temperature (Degree C)               0.071531         0.038763            1.845           0.065
# L2.Maximum temperature (Degree C)              -0.066755         0.029597           -2.255           0.024
# L2.Daily global solar exposure (MJ/m*m)         0.054125         0.008474            6.387           0.000
# L2.Total_Pedestrian_Count_per_day               0.026868         0.018548            1.449           0.147
# L3.Rainfall amount (millimetres)               -0.046504         0.036160           -1.286           0.198
# L3.Minimum temperature (Degree C)               0.019680         0.038692            0.509           0.611
# L3.Maximum temperature (Degree C)               0.038342         0.029778            1.288           0.198
# L3.Daily global solar exposure (MJ/m*m)         0.049055         0.009641            5.088           0.000
# L3.Total_Pedestrian_Count_per_day               0.024455         0.019263            1.270           0.204
# L4.Rainfall amount (millimetres)                0.039126         0.036008            1.087           0.277
# L4.Minimum temperature (Degree C)               0.030324         0.038707            0.783           0.433
# L4.Maximum temperature (Degree C)               0.050116         0.029725            1.686           0.092
# L4.Daily global solar exposure (MJ/m*m)         0.043039         0.010246            4.200           0.000
# L4.Total_Pedestrian_Count_per_day               0.024189         0.019630            1.232           0.218
# L5.Rainfall amount (millimetres)               -0.018889         0.036065           -0.524           0.600
# L5.Minimum temperature (Degree C)               0.021236         0.038700            0.549           0.583
# L5.Maximum temperature (Degree C)               0.057219         0.029677            1.928           0.054
# L5.Daily global solar exposure (MJ/m*m)         0.057582         0.010478            5.495           0.000
# L5.Total_Pedestrian_Count_per_day               0.014015         0.019539            0.717           0.473
# L6.Rainfall amount (millimetres)               -0.023473         0.036107           -0.650           0.516
# L6.Minimum temperature (Degree C)               0.014182         0.038702            0.366           0.714
# L6.Maximum temperature (Degree C)               0.023623         0.029716            0.795           0.427
# L6.Daily global solar exposure (MJ/m*m)         0.047634         0.010288            4.630           0.000
# L6.Total_Pedestrian_Count_per_day               0.013256         0.019629            0.675           0.499
# L7.Rainfall amount (millimetres)               -0.001462         0.036093           -0.041           0.968
# L7.Minimum temperature (Degree C)              -0.000329         0.038603           -0.009           0.993
# L7.Maximum temperature (Degree C)               0.069529         0.029724            2.339           0.019
# L7.Daily global solar exposure (MJ/m*m)         0.028181         0.009637            2.924           0.003
# L7.Total_Pedestrian_Count_per_day               0.034768         0.019229            1.808           0.071
# L8.Rainfall amount (millimetres)               -0.034470         0.035763           -0.964           0.335
# L8.Minimum temperature (Degree C)              -0.018706         0.038427           -0.487           0.626
# L8.Maximum temperature (Degree C)               0.039784         0.029779            1.336           0.182
# L8.Daily global solar exposure (MJ/m*m)         0.021694         0.008496            2.553           0.011
# L8.Total_Pedestrian_Count_per_day              -0.016252         0.018535           -0.877           0.381
# L9.Rainfall amount (millimetres)               -0.012760         0.035055           -0.364           0.716
# L9.Minimum temperature (Degree C)               0.083141         0.030461            2.729           0.006
# L9.Maximum temperature (Degree C)               0.070978         0.028775            2.467           0.014
# L9.Daily global solar exposure (MJ/m*m)         0.006523         0.006204            1.051           0.293
# L9.Total_Pedestrian_Count_per_day               0.019252         0.016874            1.141           0.254
# ==========================================================================================================
#
# Results for equation Daily global solar exposure (MJ/m*m)
# ==========================================================================================================
#                                              coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------------------------------
# const                                          -0.047101         0.036695           -1.284           0.199
# L1.Rainfall amount (millimetres)               -0.169168         0.137533           -1.230           0.219
# L1.Minimum temperature (Degree C)               0.264164         0.140382            1.882           0.060
# L1.Maximum temperature (Degree C)              -0.764101         0.092546           -8.256           0.000
# L1.Daily global solar exposure (MJ/m*m)        -0.747220         0.024530          -30.461           0.000
# L1.Total_Pedestrian_Count_per_day               0.038529         0.064249            0.600           0.549
# L2.Rainfall amount (millimetres)                0.038743         0.138642            0.279           0.780
# L2.Minimum temperature (Degree C)               0.249178         0.148371            1.679           0.093
# L2.Maximum temperature (Degree C)              -0.346985         0.113289           -3.063           0.002
# L2.Daily global solar exposure (MJ/m*m)        -0.628494         0.032435          -19.377           0.000
# L2.Total_Pedestrian_Count_per_day               0.053096         0.070997            0.748           0.455
# L3.Rainfall amount (millimetres)                0.144623         0.138410            1.045           0.296
# L3.Minimum temperature (Degree C)               0.036107         0.148100            0.244           0.807
# L3.Maximum temperature (Degree C)              -0.106710         0.113982           -0.936           0.349
# L3.Daily global solar exposure (MJ/m*m)        -0.575335         0.036903          -15.590           0.000
# L3.Total_Pedestrian_Count_per_day               0.124178         0.073732            1.684           0.092
# L4.Rainfall amount (millimetres)                0.246661         0.137827            1.790           0.074
# L4.Minimum temperature (Degree C)               0.223318         0.148158            1.507           0.132
# L4.Maximum temperature (Degree C)               0.021460         0.113778            0.189           0.850
# L4.Daily global solar exposure (MJ/m*m)        -0.477784         0.039219          -12.182           0.000
# L4.Total_Pedestrian_Count_per_day               0.124955         0.075137            1.663           0.096
# L5.Rainfall amount (millimetres)                0.160804         0.138046            1.165           0.244
# L5.Minimum temperature (Degree C)              -0.026747         0.148133           -0.181           0.857
# L5.Maximum temperature (Degree C)              -0.053605         0.113594           -0.472           0.637
# L5.Daily global solar exposure (MJ/m*m)        -0.377373         0.040107           -9.409           0.000
# L5.Total_Pedestrian_Count_per_day               0.154999         0.074790            2.072           0.038
# L6.Rainfall amount (millimetres)               -0.045035         0.138207           -0.326           0.745
# L6.Minimum temperature (Degree C)              -0.099488         0.148139           -0.672           0.502
# L6.Maximum temperature (Degree C)               0.031531         0.113744            0.277           0.782
# L6.Daily global solar exposure (MJ/m*m)        -0.312002         0.039380           -7.923           0.000
# L6.Total_Pedestrian_Count_per_day               0.116002         0.075135            1.544           0.123
# L7.Rainfall amount (millimetres)                0.305614         0.138151            2.212           0.027
# L7.Minimum temperature (Degree C)               0.352735         0.147759            2.387           0.017
# L7.Maximum temperature (Degree C)              -0.174745         0.113773           -1.536           0.125
# L7.Daily global solar exposure (MJ/m*m)        -0.234343         0.036887           -6.353           0.000
# L7.Total_Pedestrian_Count_per_day               0.068394         0.073602            0.929           0.353
# L8.Rainfall amount (millimetres)                0.162570         0.136889            1.188           0.235
# L8.Minimum temperature (Degree C)              -0.001666         0.147087           -0.011           0.991
# L8.Maximum temperature (Degree C)               0.031695         0.113986            0.278           0.781
# L8.Daily global solar exposure (MJ/m*m)        -0.137586         0.032521           -4.231           0.000
# L8.Total_Pedestrian_Count_per_day               0.060057         0.070945            0.847           0.397
# L9.Rainfall amount (millimetres)                0.034228         0.134179            0.255           0.799
# L9.Minimum temperature (Degree C)               0.100021         0.116597            0.858           0.391
# L9.Maximum temperature (Degree C)               0.096675         0.110142            0.878           0.380
# L9.Daily global solar exposure (MJ/m*m)        -0.070598         0.023746           -2.973           0.003
# L9.Total_Pedestrian_Count_per_day               0.097771         0.064588            1.514           0.130
# ==========================================================================================================
#
# Results for equation Total_Pedestrian_Count_per_day
# ==========================================================================================================
#                                              coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------------------------------
# const                                          -0.011660         0.013002           -0.897           0.370
# L1.Rainfall amount (millimetres)               -0.007863         0.048730           -0.161           0.872
# L1.Minimum temperature (Degree C)               0.083063         0.049740            1.670           0.095
# L1.Maximum temperature (Degree C)              -0.115730         0.032791           -3.529           0.000
# L1.Daily global solar exposure (MJ/m*m)        -0.017011         0.008691           -1.957           0.050
# L1.Total_Pedestrian_Count_per_day              -0.506425         0.022764          -22.246           0.000
# L2.Rainfall amount (millimetres)                0.060641         0.049123            1.234           0.217
# L2.Minimum temperature (Degree C)               0.039903         0.052570            0.759           0.448
# L2.Maximum temperature (Degree C)              -0.071578         0.040140           -1.783           0.075
# L2.Daily global solar exposure (MJ/m*m)        -0.007241         0.011492           -0.630           0.529
# L2.Total_Pedestrian_Count_per_day              -0.439291         0.025156          -17.463           0.000
# L3.Rainfall amount (millimetres)               -0.020437         0.049041           -0.417           0.677
# L3.Minimum temperature (Degree C)              -0.082032         0.052474           -1.563           0.118
# L3.Maximum temperature (Degree C)               0.056955         0.040386            1.410           0.158
# L3.Daily global solar exposure (MJ/m*m)        -0.029333         0.013075           -2.243           0.025
# L3.Total_Pedestrian_Count_per_day              -0.249342         0.026124           -9.544           0.000
# L4.Rainfall amount (millimetres)                0.030158         0.048834            0.618           0.537
# L4.Minimum temperature (Degree C)               0.067622         0.052495            1.288           0.198
# L4.Maximum temperature (Degree C)               0.013929         0.040313            0.346           0.730
# L4.Daily global solar exposure (MJ/m*m)        -0.035370         0.013896           -2.545           0.011
# L4.Total_Pedestrian_Count_per_day              -0.268269         0.026622          -10.077           0.000
# L5.Rainfall amount (millimetres)                0.123519         0.048912            2.525           0.012
# L5.Minimum temperature (Degree C)               0.013752         0.052486            0.262           0.793
# L5.Maximum temperature (Degree C)              -0.072882         0.040248           -1.811           0.070
# L5.Daily global solar exposure (MJ/m*m)        -0.022840         0.014211           -1.607           0.108
# L5.Total_Pedestrian_Count_per_day              -0.285446         0.026500          -10.772           0.000
# L6.Rainfall amount (millimetres)                0.050293         0.048969            1.027           0.304
# L6.Minimum temperature (Degree C)              -0.057766         0.052488           -1.101           0.271
# L6.Maximum temperature (Degree C)              -0.048064         0.040301           -1.193           0.233
# L6.Daily global solar exposure (MJ/m*m)        -0.011517         0.013953           -0.825           0.409
# L6.Total_Pedestrian_Count_per_day              -0.117388         0.026622           -4.410           0.000
# L7.Rainfall amount (millimetres)                0.020050         0.048949            0.410           0.682
# L7.Minimum temperature (Degree C)               0.075625         0.052354            1.445           0.149
# L7.Maximum temperature (Degree C)               0.069699         0.040312            1.729           0.084
# L7.Daily global solar exposure (MJ/m*m)        -0.052787         0.013070           -4.039           0.000
# L7.Total_Pedestrian_Count_per_day               0.340267         0.026078           13.048           0.000
# L8.Rainfall amount (millimetres)                0.039797         0.048502            0.821           0.412
# L8.Minimum temperature (Degree C)              -0.005964         0.052115           -0.114           0.909
# L8.Maximum temperature (Degree C)               0.049918         0.040387            1.236           0.216
# L8.Daily global solar exposure (MJ/m*m)        -0.035638         0.011523           -3.093           0.002
# L8.Total_Pedestrian_Count_per_day               0.245705         0.025137            9.775           0.000
# L9.Rainfall amount (millimetres)               -0.050215         0.047542           -1.056           0.291
# L9.Minimum temperature (Degree C)              -0.002913         0.041312           -0.071           0.944
# L9.Maximum temperature (Degree C)              -0.033066         0.039025           -0.847           0.397
# L9.Daily global solar exposure (MJ/m*m)        -0.003000         0.008414           -0.357           0.721
# L9.Total_Pedestrian_Count_per_day               0.072343         0.022885            3.161           0.002
# ==========================================================================================================
#
# Correlation matrix of residuals
#                                         Rainfall amount (millimetres)  Minimum temperature (Degree C)  Maximum temperature (Degree C)  Daily global solar exposure (MJ/m*m)  Total_Pedestrian_Count_per_day
# Rainfall amount (millimetres)                                1.000000                       -0.105668                       -0.194775                             -0.136999                       -0.101492
# Minimum temperature (Degree C)                              -0.105668                        1.000000                        0.258506                             -0.227861                       -0.068078
# Maximum temperature (Degree C)                              -0.194775                        0.258506                        1.000000                              0.238448                        0.022464
# Daily global solar exposure (MJ/m*m)                        -0.136999                       -0.227861                        0.238448                              1.000000                        0.251907
# Total_Pedestrian_Count_per_day                              -0.101492                       -0.068078                        0.022464                              0.251907                        1.000000

# %%
# MSE
from sklearn.metrics import mean_squared_error
from numpy import asarray as arr
mse = mean_squared_error(df_test, forecast_values)
print('\nMean Squared Error:',mse)
# Out:
# Mean Squared Error: 74.17711110302174
