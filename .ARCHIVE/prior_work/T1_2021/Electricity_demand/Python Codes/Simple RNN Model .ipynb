# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Input, Dense, Dropout, LSTM, SimpleRNN
from keras.optimizers import Adam, RMSprop
from keras.utils import plot_model
from keras.callbacks import ReduceLROnPlateau,TensorBoard,ModelCheckpoint,EarlyStopping

# %%
#import dataset from data.csv file
dataset = pd.read_csv('electricity_demand.csv')
dataset.head()
# Out:
#        date      demand        RRP  min_temperature  max_temperature  \
# 0  1/1/2015   99635.030  25.633696             13.3         5.186521
# 1  1/2/2015  129606.010  33.138988             15.4         6.228965
# 2  1/3/2015  142300.540  34.564855             20.0         6.180615
# 3  1/4/2015  104330.715  25.005560             16.3         4.626013
# 4  1/5/2015  118132.200  26.724176             15.0         4.690416
#
#    solar_exposure  rainfall school_day holiday
# 0        0.000000       0.0          N       Y
# 1        0.880597       0.0          N       N
# 2        1.011321       0.0          N       N
# 3        1.051587       4.2          N       N
# 4        0.820847       0.0          N       N

# %%
#Dataset correlation matrix
corrmat = dataset.corr()
corrmat.style.background_gradient(cmap='Blues').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_aca28_row0_col0,#T_aca28_row1_col1,#T_aca28_row2_col2,#T_aca28_row3_col3,#T_aca28_row4_col4,#T_aca28_row5_col5{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_aca28_row0_col1{
#             background-color:  #c6dbef;
#             color:  #000000;
#         }#T_aca28_row0_col2,#T_aca28_row2_col0,#T_aca28_row3_col5,#T_aca28_row5_col1,#T_aca28_row5_col3,#T_aca28_row5_col4{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_aca28_row0_col3{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_aca28_row0_col4{
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }#T_aca28_row0_col5{
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }#T_aca28_row1_col0{
#             background-color:  #add0e6;
#             color:  #000000;
#         }#T_aca28_row1_col2,#T_aca28_row4_col3{
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }#T_aca28_row1_col3{
#             background-color:  #c7dcef;
#             color:  #000000;
#         }#T_aca28_row1_col4{
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }#T_aca28_row1_col5{
#             background-color:  #e1edf8;
#             color:  #000000;
#         }#T_aca28_row2_col1{
#             background-color:  #e6f0f9;
#             color:  #000000;
#         }#T_aca28_row2_col3,#T_aca28_row3_col2{
#             background-color:  #2171b5;
#             color:  #f1f1f1;
#         }#T_aca28_row2_col4{
#             background-color:  #cee0f2;
#             color:  #000000;
#         }#T_aca28_row2_col5{
#             background-color:  #dce9f6;
#             color:  #000000;
#         }#T_aca28_row3_col0{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_aca28_row3_col1{
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }#T_aca28_row3_col4,#T_aca28_row5_col0{
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }#T_aca28_row4_col0{
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }#T_aca28_row4_col1{
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }#T_aca28_row4_col2{
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }#T_aca28_row4_col5{
#             background-color:  #dfecf7;
#             color:  #000000;
#         }#T_aca28_row5_col2{
#             background-color:  #dceaf6;
#             color:  #000000;
#         }</style><table id="T_aca28_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >demand</th>        <th class="col_heading level0 col1" >RRP</th>        <th class="col_heading level0 col2" >min_temperature</th>        <th class="col_heading level0 col3" >max_temperature</th>        <th class="col_heading level0 col4" >solar_exposure</th>        <th class="col_heading level0 col5" >rainfall</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_aca28_level0_row0" class="row_heading level0 row0" >demand</th>
#                         <td id="T_aca28_row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_aca28_row0_col1" class="data row0 col1" >0.23</td>
#                         <td id="T_aca28_row0_col2" class="data row0 col2" >-0.15</td>
#                         <td id="T_aca28_row0_col3" class="data row0 col3" >-0.12</td>
#                         <td id="T_aca28_row0_col4" class="data row0 col4" >0.04</td>
#                         <td id="T_aca28_row0_col5" class="data row0 col5" >-0.07</td>
#             </tr>
#             <tr>
#                         <th id="T_aca28_level0_row1" class="row_heading level0 row1" >RRP</th>
#                         <td id="T_aca28_row1_col0" class="data row1 col0" >0.23</td>
#                         <td id="T_aca28_row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_aca28_row1_col2" class="data row1 col2" >0.06</td>
#                         <td id="T_aca28_row1_col3" class="data row1 col3" >0.13</td>
#                         <td id="T_aca28_row1_col4" class="data row1 col4" >-0.01</td>
#                         <td id="T_aca28_row1_col5" class="data row1 col5" >-0.03</td>
#             </tr>
#             <tr>
#                         <th id="T_aca28_level0_row2" class="row_heading level0 row2" >min_temperature</th>
#                         <td id="T_aca28_row2_col0" class="data row2 col0" >-0.15</td>
#                         <td id="T_aca28_row2_col1" class="data row2 col1" >0.06</td>
#                         <td id="T_aca28_row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_aca28_row2_col3" class="data row2 col3" >0.71</td>
#                         <td id="T_aca28_row2_col4" class="data row2 col4" >0.19</td>
#                         <td id="T_aca28_row2_col5" class="data row2 col5" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_aca28_level0_row3" class="row_heading level0 row3" >max_temperature</th>
#                         <td id="T_aca28_row3_col0" class="data row3 col0" >-0.12</td>
#                         <td id="T_aca28_row3_col1" class="data row3 col1" >0.13</td>
#                         <td id="T_aca28_row3_col2" class="data row3 col2" >0.71</td>
#                         <td id="T_aca28_row3_col3" class="data row3 col3" >1.00</td>
#                         <td id="T_aca28_row3_col4" class="data row3 col4" >0.05</td>
#                         <td id="T_aca28_row3_col5" class="data row3 col5" >-0.16</td>
#             </tr>
#             <tr>
#                         <th id="T_aca28_level0_row4" class="row_heading level0 row4" >solar_exposure</th>
#                         <td id="T_aca28_row4_col0" class="data row4 col0" >0.04</td>
#                         <td id="T_aca28_row4_col1" class="data row4 col1" >-0.01</td>
#                         <td id="T_aca28_row4_col2" class="data row4 col2" >0.19</td>
#                         <td id="T_aca28_row4_col3" class="data row4 col3" >0.05</td>
#                         <td id="T_aca28_row4_col4" class="data row4 col4" >1.00</td>
#                         <td id="T_aca28_row4_col5" class="data row4 col5" >-0.02</td>
#             </tr>
#             <tr>
#                         <th id="T_aca28_level0_row5" class="row_heading level0 row5" >rainfall</th>
#                         <td id="T_aca28_row5_col0" class="data row5 col0" >-0.07</td>
#                         <td id="T_aca28_row5_col1" class="data row5 col1" >-0.03</td>
#                         <td id="T_aca28_row5_col2" class="data row5 col2" >0.00</td>
#                         <td id="T_aca28_row5_col3" class="data row5 col3" >-0.16</td>
#                         <td id="T_aca28_row5_col4" class="data row5 col4" >-0.02</td>
#                         <td id="T_aca28_row5_col5" class="data row5 col5" >1.00</td>
#             </tr>
#     </tbody></table>

# %%
sns.heatmap(dataset.corr(), annot=True, cmap = 'Blues')
plt.show()

# %%
#Check for NA/Missing values
dataset.isnull().sum(axis = 0)
# Out:
# date               0
# demand             0
# RRP                0
# min_temperature    0
# max_temperature    0
# solar_exposure     0
# rainfall           0
# school_day         0
# holiday            0
# dtype: int64

# %%
#Check for rows in a column
dataset.count()
# Out:
# date               2251
# demand             2251
# RRP                2251
# min_temperature    2251
# max_temperature    2251
# solar_exposure     2251
# rainfall           2251
# school_day         2251
# holiday            2251
# dtype: int64

# %%
#Histogram of 'demand'
sns.distplot(dataset.demand.dropna(),kde = False, bins = 15)
# Out:
# C:\Users\patel\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='demand'>

# %%
#Obtain counts for each value in specific column in descending order
dataset.demand.value_counts()
# Out:
# 101793.035    2
# 121605.395    2
# 126073.530    1
# 133989.155    1
# 103763.200    1
#              ..
# 114740.520    1
# 135273.325    1
# 107164.520    1
# 112634.635    1
# 103556.740    1
# Name: demand, Length: 2249, dtype: int64

# %%
#Obtain counts for each value in specific column in descending order
dataset.RRP.value_counts()
# Out:
# 45.627913     1
# 52.320158     1
# 34.506522     1
# 72.412230     1
# 100.819670    1
#              ..
# 77.421790     1
# 26.724176     1
# 75.491413     1
# 144.393435    1
# 74.062543     1
# Name: RRP, Length: 2251, dtype: int64

# %%
plt.scatter(dataset.min_temperature, dataset.max_temperature)
plt.title('Scatter Plot')
plt.xlabel('Min Temperature')
plt.ylabel('Max Temperature')
plt.show()

# %%
plt.scatter(dataset.RRP, dataset.demand)
plt.title('Scatter Plot')
plt.xlabel('RRP (AUD)')
plt.ylabel('Demand (MWh)')
plt.show()

# %%
#Obtain counts for each value in specific column in descending order
dataset.demand.value_counts()
# Out:
# 101793.035    2
# 121605.395    2
# 126073.530    1
# 133989.155    1
# 103763.200    1
#              ..
# 114740.520    1
# 135273.325    1
# 107164.520    1
# 112634.635    1
# 103556.740    1
# Name: demand, Length: 2249, dtype: int64

# %%
#Format 'date' column 
dataset['date'] = pd.to_datetime(dataset['date'], infer_datetime_format=True)

# %%
#Plot the 'demand' using date column
dataset.set_index('date')['demand'].plot(color='red')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
#Set 'date' as index
dataset.set_index('date', inplace=True)

# %%
#Replace 'Y' with 1 and 'N' with 0
dataset['school_day'] = dataset['school_day'].replace(to_replace ="N", value = 0)
dataset['school_day'] = dataset['school_day'].replace(to_replace ="Y", value = 1)
dataset['holiday'] = dataset['holiday'].replace(to_replace ="N", value = 0)
dataset['holiday'] = dataset['holiday'].replace(to_replace ="Y", value = 1)

# %%
dataset.head()
# Out:
#                 demand        RRP  min_temperature  max_temperature  \
# date
# 2015-01-01   99635.030  25.633696             13.3         5.186521
# 2015-01-02  129606.010  33.138988             15.4         6.228965
# 2015-01-03  142300.540  34.564855             20.0         6.180615
# 2015-01-04  104330.715  25.005560             16.3         4.626013
# 2015-01-05  118132.200  26.724176             15.0         4.690416
#
#             solar_exposure  rainfall  school_day  holiday
# date
# 2015-01-01        0.000000       0.0           0        1
# 2015-01-02        0.880597       0.0           0        0
# 2015-01-03        1.011321       0.0           0        0
# 2015-01-04        1.051587       4.2           0        0
# 2015-01-05        0.820847       0.0           0        0

# %%
#Split dataset into train and test
train_set = dataset.iloc[:2191]
train_set_target = train_set['demand']
train_set = train_set.drop(columns=['demand'])

test_set = dataset.iloc[2192:]
test_set_target = test_set['demand']
test_set = test_set.drop(columns=['demand'])

#Convert the series to dataframe
train_set_target = pd.DataFrame(train_set_target)
test_set_target = pd.DataFrame(test_set_target)

# %%
#Normalise the dataset 
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))
train_set = scaler.fit_transform(train_set)
test_set = scaler.fit_transform(test_set)

train_set_target = scaler_y.fit_transform(train_set_target)
test_set_target = scaler_y.fit_transform(test_set_target)

# %%
print(train_set.shape)
print(train_set_target.shape)
print(test_set.shape)
print(test_set_target.shape)
# Out:
# (2191, 7)
# (2191, 1)
# (59, 7)
# (59, 1)

# %%
train_set = np.reshape(train_set, (train_set.shape[0], 1, train_set.shape[1]))
test_set = np.reshape(test_set, (test_set.shape[0], 1, test_set.shape[1]))

# %%
print(train_set.shape)
print(train_set_target.shape)
print(test_set.shape)
print(test_set_target.shape)
# Out:
# (2191, 1, 7)
# (2191, 1)
# (59, 1, 7)
# (59, 1)

# %%
# SimpleRNN model
model = Sequential()
model.add(SimpleRNN(units=50, input_shape=(2191,7), activation="relu"))
model.add(Dense(500, activation="relu")) 
model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mean_absolute_error', optimizer='rmsprop')

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_1 (SimpleRNN)     (None, 50)                2900
# _________________________________________________________________
# dense_2 (Dense)              (None, 500)               25500
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 501
# =================================================================
# Total params: 28,901
# Trainable params: 28,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x=train_set,y=train_set_target, epochs=500, batch_size=100, verbose=2)
# Out:
# Epoch 1/500
# WARNING:tensorflow:Model was constructed with shape (None, 2191, 7) for input KerasTensor(type_spec=TensorSpec(shape=(None, 2191, 7), dtype=tf.float32, name='simple_rnn_1_input'), name='simple_rnn_1_input', description="created by layer 'simple_rnn_1_input'"), but it was called on an input with incompatible shape (None, 1, 7).
# WARNING:tensorflow:Model was constructed with shape (None, 2191, 7) for input KerasTensor(type_spec=TensorSpec(shape=(None, 2191, 7), dtype=tf.float32, name='simple_rnn_1_input'), name='simple_rnn_1_input', description="created by layer 'simple_rnn_1_input'"), but it was called on an input with incompatible shape (None, 1, 7).
# 22/22 - 1s - loss: 0.1446
# Epoch 2/500
# 22/22 - 0s - loss: 0.1257
# Epoch 3/500
# 22/22 - 0s - loss: 0.1151
# Epoch 4/500
# 22/22 - 0s - loss: 0.1131
# Epoch 5/500
# 22/22 - 0s - loss: 0.1088
# Epoch 6/500
# 22/22 - 0s - loss: 0.1089
# Epoch 7/500
# 22/22 - 0s - loss: 0.1034
# Epoch 8/500
# 22/22 - 0s - loss: 0.1023
# Epoch 9/500
# 22/22 - 0s - loss: 0.1032
# Epoch 10/500
# 22/22 - 0s - loss: 0.1010
# Epoch 11/500
# 22/22 - 0s - loss: 0.0994
# Epoch 12/500
# 22/22 - 0s - loss: 0.0992
# Epoch 13/500
# 22/22 - 0s - loss: 0.0979
# Epoch 14/500
# 22/22 - 0s - loss: 0.0980
# Epoch 15/500
# 22/22 - 0s - loss: 0.0975
# Epoch 16/500
# 22/22 - 0s - loss: 0.0943
# Epoch 17/500
# 22/22 - 0s - loss: 0.0976
# Epoch 18/500
# 22/22 - 0s - loss: 0.0957
# Epoch 19/500
# 22/22 - 0s - loss: 0.0950
# Epoch 20/500
# 22/22 - 0s - loss: 0.0952
# Epoch 21/500
# 22/22 - 0s - loss: 0.0948
# Epoch 22/500
# 22/22 - 0s - loss: 0.0946
# Epoch 23/500
# 22/22 - 0s - loss: 0.0940
# Epoch 24/500
# 22/22 - 0s - loss: 0.0943
# Epoch 25/500
# 22/22 - 0s - loss: 0.0952
# Epoch 26/500
# 22/22 - 0s - loss: 0.0931
# Epoch 27/500
# 22/22 - 0s - loss: 0.0939
# Epoch 28/500
# 22/22 - 0s - loss: 0.0928
# Epoch 29/500
# 22/22 - 0s - loss: 0.0934
# Epoch 30/500
# 22/22 - 0s - loss: 0.0931
# Epoch 31/500
# 22/22 - 0s - loss: 0.0919
# Epoch 32/500
# 22/22 - 0s - loss: 0.0920
# Epoch 33/500
# 22/22 - 0s - loss: 0.0922
# Epoch 34/500
# 22/22 - 0s - loss: 0.0928
# Epoch 35/500
# 22/22 - 0s - loss: 0.0927
# Epoch 36/500
# 22/22 - 0s - loss: 0.0931
# Epoch 37/500
# 22/22 - 0s - loss: 0.0920
# Epoch 38/500
# 22/22 - 0s - loss: 0.0912
# Epoch 39/500
# 22/22 - 0s - loss: 0.0930
# Epoch 40/500
# 22/22 - 0s - loss: 0.0928
# Epoch 41/500
# 22/22 - 0s - loss: 0.0921
# Epoch 42/500
# 22/22 - 0s - loss: 0.0925
# Epoch 43/500
# 22/22 - 0s - loss: 0.0913
# Epoch 44/500
# 22/22 - 0s - loss: 0.0911
# Epoch 45/500
# 22/22 - 0s - loss: 0.0925
# Epoch 46/500
# 22/22 - 0s - loss: 0.0910
# Epoch 47/500
# 22/22 - 0s - loss: 0.0904
# Epoch 48/500
# 22/22 - 0s - loss: 0.0913
# Epoch 49/500
# 22/22 - 0s - loss: 0.0915
# Epoch 50/500
# 22/22 - 0s - loss: 0.0923
# Epoch 51/500
# 22/22 - 0s - loss: 0.0891
# Epoch 52/500
# 22/22 - 0s - loss: 0.0918
# Epoch 53/500
# 22/22 - 0s - loss: 0.0919
# Epoch 54/500
# 22/22 - 0s - loss: 0.0904
# Epoch 55/500
# 22/22 - 0s - loss: 0.0901
# Epoch 56/500
# 22/22 - 0s - loss: 0.0908
# Epoch 57/500
# 22/22 - 0s - loss: 0.0902
# Epoch 58/500
# 22/22 - 0s - loss: 0.0916
# Epoch 59/500
# 22/22 - 0s - loss: 0.0894
# Epoch 60/500
# 22/22 - 0s - loss: 0.0911
# Epoch 61/500
# 22/22 - 0s - loss: 0.0911
# Epoch 62/500
# 22/22 - 0s - loss: 0.0899
# Epoch 63/500
# 22/22 - 0s - loss: 0.0917
# Epoch 64/500
# 22/22 - 0s - loss: 0.0911
# Epoch 65/500
# 22/22 - 0s - loss: 0.0905
# Epoch 66/500
# 22/22 - 0s - loss: 0.0903
# Epoch 67/500
# 22/22 - 0s - loss: 0.0915
# Epoch 68/500
# 22/22 - 0s - loss: 0.0903
# Epoch 69/500
# 22/22 - 0s - loss: 0.0903
# Epoch 70/500
# 22/22 - 0s - loss: 0.0900
# Epoch 71/500
# 22/22 - 0s - loss: 0.0896
# Epoch 72/500
# 22/22 - 0s - loss: 0.0887
# Epoch 73/500
# 22/22 - 0s - loss: 0.0899
# Epoch 74/500
# 22/22 - 0s - loss: 0.0910
# Epoch 75/500
# 22/22 - 0s - loss: 0.0902
# Epoch 76/500
# 22/22 - 0s - loss: 0.0912
# Epoch 77/500
# 22/22 - 0s - loss: 0.0886
# Epoch 78/500
# 22/22 - 0s - loss: 0.0907
# Epoch 79/500
# 22/22 - 0s - loss: 0.0896
# Epoch 80/500
# 22/22 - 0s - loss: 0.0897
# Epoch 81/500
# 22/22 - 0s - loss: 0.0896
# Epoch 82/500
# 22/22 - 0s - loss: 0.0909
# Epoch 83/500
# 22/22 - 0s - loss: 0.0891
# Epoch 84/500
# 22/22 - 0s - loss: 0.0898
# Epoch 85/500
# 22/22 - 0s - loss: 0.0900
# Epoch 86/500
# 22/22 - 0s - loss: 0.0906
# Epoch 87/500
# 22/22 - 0s - loss: 0.0887
# Epoch 88/500
# 22/22 - 0s - loss: 0.0895
# Epoch 89/500
# 22/22 - 0s - loss: 0.0892
# Epoch 90/500
# 22/22 - 0s - loss: 0.0896
# Epoch 91/500
# 22/22 - 0s - loss: 0.0886
# Epoch 92/500
# 22/22 - 0s - loss: 0.0898
# Epoch 93/500
# 22/22 - 0s - loss: 0.0890
# Epoch 94/500
# 22/22 - 0s - loss: 0.0886
# Epoch 95/500
# 22/22 - 0s - loss: 0.0893
# Epoch 96/500
# 22/22 - 0s - loss: 0.0888
# Epoch 97/500
# 22/22 - 0s - loss: 0.0900
# Epoch 98/500
# 22/22 - 0s - loss: 0.0898
# Epoch 99/500
# 22/22 - 0s - loss: 0.0885
# Epoch 100/500
# 22/22 - 0s - loss: 0.0885
# Epoch 101/500
# 22/22 - 0s - loss: 0.0895
# Epoch 102/500
# 22/22 - 0s - loss: 0.0897
# Epoch 103/500
# 22/22 - 0s - loss: 0.0873
# Epoch 104/500
# 22/22 - 0s - loss: 0.0888
# Epoch 105/500
# 22/22 - 0s - loss: 0.0895
# Epoch 106/500
# 22/22 - 0s - loss: 0.0885
# Epoch 107/500
# 22/22 - 0s - loss: 0.0877
# Epoch 108/500
# 22/22 - 0s - loss: 0.0889
# Epoch 109/500
# 22/22 - 0s - loss: 0.0879
# Epoch 110/500
# 22/22 - 0s - loss: 0.0894
# Epoch 111/500
# 22/22 - 0s - loss: 0.0889
# Epoch 112/500
# 22/22 - 0s - loss: 0.0878
# Epoch 113/500
# 22/22 - 0s - loss: 0.0893
# Epoch 114/500
# 22/22 - 0s - loss: 0.0877
# Epoch 115/500
# 22/22 - 0s - loss: 0.0885
# Epoch 116/500
# 22/22 - 0s - loss: 0.0883
# Epoch 117/500
# 22/22 - 0s - loss: 0.0883
# Epoch 118/500
# 22/22 - 0s - loss: 0.0878
# Epoch 119/500
# 22/22 - 0s - loss: 0.0887
# Epoch 120/500
# 22/22 - 0s - loss: 0.0884
# Epoch 121/500
# 22/22 - 0s - loss: 0.0893
# Epoch 122/500
# 22/22 - 0s - loss: 0.0885
# Epoch 123/500
# 22/22 - 0s - loss: 0.0882
# Epoch 124/500
# 22/22 - 0s - loss: 0.0887
# Epoch 125/500
# 22/22 - 0s - loss: 0.0881
# Epoch 126/500
# 22/22 - 0s - loss: 0.0886
# Epoch 127/500
# 22/22 - 0s - loss: 0.0873
# Epoch 128/500
# 22/22 - 0s - loss: 0.0877
# Epoch 129/500
# 22/22 - 0s - loss: 0.0872
# Epoch 130/500
# 22/22 - 0s - loss: 0.0872
# Epoch 131/500
# 22/22 - 0s - loss: 0.0877
# Epoch 132/500
# 22/22 - 0s - loss: 0.0873
# Epoch 133/500
# 22/22 - 0s - loss: 0.0882
# Epoch 134/500
# 22/22 - 0s - loss: 0.0883
# Epoch 135/500
# 22/22 - 0s - loss: 0.0888
# Epoch 136/500
# 22/22 - 0s - loss: 0.0882
# Epoch 137/500
# 22/22 - 0s - loss: 0.0882
# Epoch 138/500
# 22/22 - 0s - loss: 0.0876
# Epoch 139/500
# 22/22 - 0s - loss: 0.0874
# Epoch 140/500
# 22/22 - 0s - loss: 0.0887
# Epoch 141/500
# 22/22 - 0s - loss: 0.0879
# Epoch 142/500
# 22/22 - 0s - loss: 0.0858
# Epoch 143/500
# 22/22 - 0s - loss: 0.0875
# Epoch 144/500
# 22/22 - 0s - loss: 0.0885
# Epoch 145/500
# 22/22 - 0s - loss: 0.0882
# Epoch 146/500
# 22/22 - 0s - loss: 0.0866
# Epoch 147/500
# 22/22 - 0s - loss: 0.0875
# Epoch 148/500
# 22/22 - 0s - loss: 0.0868
# Epoch 149/500
# 22/22 - 0s - loss: 0.0870
# Epoch 150/500
# 22/22 - 0s - loss: 0.0876
# Epoch 151/500
# 22/22 - 0s - loss: 0.0880
# Epoch 152/500
# 22/22 - 0s - loss: 0.0874
# Epoch 153/500
# 22/22 - 0s - loss: 0.0869
# Epoch 154/500
# 22/22 - 0s - loss: 0.0867
# Epoch 155/500
# 22/22 - 0s - loss: 0.0877
# Epoch 156/500
# 22/22 - 0s - loss: 0.0877
# Epoch 157/500
# 22/22 - 0s - loss: 0.0875
# Epoch 158/500
# 22/22 - 0s - loss: 0.0866
# Epoch 159/500
# 22/22 - 0s - loss: 0.0868
# Epoch 160/500
# 22/22 - 0s - loss: 0.0880
# Epoch 161/500
# 22/22 - 0s - loss: 0.0871
# Epoch 162/500
# 22/22 - 0s - loss: 0.0872
# Epoch 163/500
# 22/22 - 0s - loss: 0.0865
# Epoch 164/500
# 22/22 - 0s - loss: 0.0874
# Epoch 165/500
# 22/22 - 0s - loss: 0.0863
# Epoch 166/500
# 22/22 - 0s - loss: 0.0865
# Epoch 167/500
# 22/22 - 0s - loss: 0.0865
# Epoch 168/500
# 22/22 - 0s - loss: 0.0862
# Epoch 169/500
# 22/22 - 0s - loss: 0.0880
# Epoch 170/500
# 22/22 - 0s - loss: 0.0862
# Epoch 171/500
# 22/22 - 0s - loss: 0.0868
# Epoch 172/500
# 22/22 - 0s - loss: 0.0867
# Epoch 173/500
# 22/22 - 0s - loss: 0.0877
# Epoch 174/500
# 22/22 - 0s - loss: 0.0867
# Epoch 175/500
# 22/22 - 0s - loss: 0.0866
# Epoch 176/500
# 22/22 - 0s - loss: 0.0864
# Epoch 177/500
# 22/22 - 0s - loss: 0.0864
# Epoch 178/500
# 22/22 - 0s - loss: 0.0863
# Epoch 179/500
# 22/22 - 0s - loss: 0.0869
# Epoch 180/500
# 22/22 - 0s - loss: 0.0860
# Epoch 181/500
# 22/22 - 0s - loss: 0.0854
# Epoch 182/500
# 22/22 - 0s - loss: 0.0860
# Epoch 183/500
# 22/22 - 0s - loss: 0.0855
# Epoch 184/500
# 22/22 - 0s - loss: 0.0863
# Epoch 185/500
# 22/22 - 0s - loss: 0.0859
# Epoch 186/500
# 22/22 - 0s - loss: 0.0864
# Epoch 187/500
# 22/22 - 0s - loss: 0.0862
# Epoch 188/500
# 22/22 - 0s - loss: 0.0865
# Epoch 189/500
# 22/22 - 0s - loss: 0.0855
# Epoch 190/500
# 22/22 - 0s - loss: 0.0862
# Epoch 191/500
# 22/22 - 0s - loss: 0.0864
# Epoch 192/500
# 22/22 - 0s - loss: 0.0863
# Epoch 193/500
# 22/22 - 0s - loss: 0.0859
# Epoch 194/500
# 22/22 - 0s - loss: 0.0860
# Epoch 195/500
# 22/22 - 0s - loss: 0.0864
# Epoch 196/500
# 22/22 - 0s - loss: 0.0854
# Epoch 197/500
# 22/22 - 0s - loss: 0.0853
# Epoch 198/500
# 22/22 - 0s - loss: 0.0870
# Epoch 199/500
# 22/22 - 0s - loss: 0.0851
# Epoch 200/500
# 22/22 - 0s - loss: 0.0866
# Epoch 201/500
# 22/22 - 0s - loss: 0.0851
# Epoch 202/500
# 22/22 - 0s - loss: 0.0855
# Epoch 203/500
# 22/22 - 0s - loss: 0.0865
# Epoch 204/500
# 22/22 - 0s - loss: 0.0858
# Epoch 205/500
# 22/22 - 0s - loss: 0.0864
# Epoch 206/500
# 22/22 - 0s - loss: 0.0857
# Epoch 207/500
# 22/22 - 0s - loss: 0.0853
# Epoch 208/500
# 22/22 - 0s - loss: 0.0861
# Epoch 209/500
# 22/22 - 0s - loss: 0.0859
# Epoch 210/500
# 22/22 - 0s - loss: 0.0855
# Epoch 211/500
# 22/22 - 0s - loss: 0.0858
# Epoch 212/500
# 22/22 - 0s - loss: 0.0852
# Epoch 213/500
# 22/22 - 0s - loss: 0.0858
# Epoch 214/500
# 22/22 - 0s - loss: 0.0846
# Epoch 215/500
# 22/22 - 0s - loss: 0.0859
# Epoch 216/500
# 22/22 - 0s - loss: 0.0860
# Epoch 217/500
# 22/22 - 0s - loss: 0.0857
# Epoch 218/500
# 22/22 - 0s - loss: 0.0859
# Epoch 219/500
# 22/22 - 0s - loss: 0.0854
# Epoch 220/500
# 22/22 - 0s - loss: 0.0858
# Epoch 221/500
# 22/22 - 0s - loss: 0.0856
# Epoch 222/500
# 22/22 - 0s - loss: 0.0857
# Epoch 223/500
# 22/22 - 0s - loss: 0.0854
# Epoch 224/500
# 22/22 - 0s - loss: 0.0853
# Epoch 225/500
# 22/22 - 0s - loss: 0.0849
# Epoch 226/500
# 22/22 - 0s - loss: 0.0848
# Epoch 227/500
# 22/22 - 0s - loss: 0.0845
# Epoch 228/500
# 22/22 - 0s - loss: 0.0867
# Epoch 229/500
# 22/22 - 0s - loss: 0.0854
# Epoch 230/500
# 22/22 - 0s - loss: 0.0849
# Epoch 231/500
# 22/22 - 0s - loss: 0.0854
# Epoch 232/500
# 22/22 - 0s - loss: 0.0856
# Epoch 233/500
# 22/22 - 0s - loss: 0.0850
# Epoch 234/500
# 22/22 - 0s - loss: 0.0850
# Epoch 235/500
# 22/22 - 0s - loss: 0.0862
# Epoch 236/500
# 22/22 - 0s - loss: 0.0853
# Epoch 237/500
# 22/22 - 0s - loss: 0.0856
# Epoch 238/500
# 22/22 - 0s - loss: 0.0858
# Epoch 239/500
# 22/22 - 0s - loss: 0.0846
# Epoch 240/500
# 22/22 - 0s - loss: 0.0843
# Epoch 241/500
# 22/22 - 0s - loss: 0.0850
# Epoch 242/500
# 22/22 - 0s - loss: 0.0847
# Epoch 243/500
# 22/22 - 0s - loss: 0.0849
# Epoch 244/500
# 22/22 - 0s - loss: 0.0855
# Epoch 245/500
# 22/22 - 0s - loss: 0.0847
# Epoch 246/500
# 22/22 - 0s - loss: 0.0848
# Epoch 247/500
# 22/22 - 0s - loss: 0.0841
# Epoch 248/500
# 22/22 - 0s - loss: 0.0845
# Epoch 249/500
# 22/22 - 0s - loss: 0.0843
# Epoch 250/500
# 22/22 - 0s - loss: 0.0846
# Epoch 251/500
# 22/22 - 0s - loss: 0.0842
# Epoch 252/500
# 22/22 - 0s - loss: 0.0859
# Epoch 253/500
# 22/22 - 0s - loss: 0.0854
# Epoch 254/500
# 22/22 - 0s - loss: 0.0839
# Epoch 255/500
# 22/22 - 0s - loss: 0.0847
# Epoch 256/500
# 22/22 - 0s - loss: 0.0854
# Epoch 257/500
# 22/22 - 0s - loss: 0.0843
# Epoch 258/500
# 22/22 - 0s - loss: 0.0843
# Epoch 259/500
# 22/22 - 0s - loss: 0.0851
# Epoch 260/500
# 22/22 - 0s - loss: 0.0845
# Epoch 261/500
# 22/22 - 0s - loss: 0.0848
# Epoch 262/500
# 22/22 - 0s - loss: 0.0843
# Epoch 263/500
# 22/22 - 0s - loss: 0.0845
# Epoch 264/500
# 22/22 - 0s - loss: 0.0846
# Epoch 265/500
# 22/22 - 0s - loss: 0.0841
# Epoch 266/500
# 22/22 - 0s - loss: 0.0852
# Epoch 267/500
# 22/22 - 0s - loss: 0.0843
# Epoch 268/500
# 22/22 - 0s - loss: 0.0841
# Epoch 269/500
# 22/22 - 0s - loss: 0.0848
# Epoch 270/500
# 22/22 - 0s - loss: 0.0842
# Epoch 271/500
# 22/22 - 0s - loss: 0.0848
# Epoch 272/500
# 22/22 - 0s - loss: 0.0845
# Epoch 273/500
# 22/22 - 0s - loss: 0.0842
# Epoch 274/500
# 22/22 - 0s - loss: 0.0832
# Epoch 275/500
# 22/22 - 0s - loss: 0.0840
# Epoch 276/500
# 22/22 - 0s - loss: 0.0844
# Epoch 277/500
# 22/22 - 0s - loss: 0.0841
# Epoch 278/500
# 22/22 - 0s - loss: 0.0842
# Epoch 279/500
# 22/22 - 0s - loss: 0.0839
# Epoch 280/500
# 22/22 - 0s - loss: 0.0843
# Epoch 281/500
# 22/22 - 0s - loss: 0.0837
# Epoch 282/500
# 22/22 - 0s - loss: 0.0843
# Epoch 283/500
# 22/22 - 0s - loss: 0.0843
# Epoch 284/500
# 22/22 - 0s - loss: 0.0843
# Epoch 285/500
# 22/22 - 0s - loss: 0.0842
# Epoch 286/500
# 22/22 - 0s - loss: 0.0837
# Epoch 287/500
# 22/22 - 0s - loss: 0.0842
# Epoch 288/500
# 22/22 - 0s - loss: 0.0833
# Epoch 289/500
# 22/22 - 0s - loss: 0.0837
# Epoch 290/500
# 22/22 - 0s - loss: 0.0836
# Epoch 291/500
# 22/22 - 0s - loss: 0.0832
# Epoch 292/500
# 22/22 - 0s - loss: 0.0838
# Epoch 293/500
# 22/22 - 0s - loss: 0.0829
# Epoch 294/500
# 22/22 - 0s - loss: 0.0841
# Epoch 295/500
# 22/22 - 0s - loss: 0.0843
# Epoch 296/500
# 22/22 - 0s - loss: 0.0841
# Epoch 297/500
# 22/22 - 0s - loss: 0.0844
# Epoch 298/500
# 22/22 - 0s - loss: 0.0842
# Epoch 299/500
# 22/22 - 0s - loss: 0.0841
# Epoch 300/500
# 22/22 - 0s - loss: 0.0836
# Epoch 301/500
# 22/22 - 0s - loss: 0.0834
# Epoch 302/500
# 22/22 - 0s - loss: 0.0830
# Epoch 303/500
# 22/22 - 0s - loss: 0.0833
# Epoch 304/500
# 22/22 - 0s - loss: 0.0831
# Epoch 305/500
# 22/22 - 0s - loss: 0.0831
# Epoch 306/500
# 22/22 - 0s - loss: 0.0843
# Epoch 307/500
# 22/22 - 0s - loss: 0.0841
# Epoch 308/500
# 22/22 - 0s - loss: 0.0838
# Epoch 309/500
# 22/22 - 0s - loss: 0.0839
# Epoch 310/500
# 22/22 - 0s - loss: 0.0837
# Epoch 311/500
# 22/22 - 0s - loss: 0.0837
# Epoch 312/500
# 22/22 - 0s - loss: 0.0839
# Epoch 313/500
# 22/22 - 0s - loss: 0.0829
# Epoch 314/500
# 22/22 - 0s - loss: 0.0835
# Epoch 315/500
# 22/22 - 0s - loss: 0.0835
# Epoch 316/500
# 22/22 - 0s - loss: 0.0835
# Epoch 317/500
# 22/22 - 0s - loss: 0.0832
# Epoch 318/500
# 22/22 - 0s - loss: 0.0839
# Epoch 319/500
# 22/22 - 0s - loss: 0.0828
# Epoch 320/500
# 22/22 - 0s - loss: 0.0841
# Epoch 321/500
# 22/22 - 0s - loss: 0.0830
# Epoch 322/500
# 22/22 - 0s - loss: 0.0835
# Epoch 323/500
# 22/22 - 0s - loss: 0.0836
# Epoch 324/500
# 22/22 - 0s - loss: 0.0833
# Epoch 325/500
# 22/22 - 0s - loss: 0.0838
# Epoch 326/500
# 22/22 - 0s - loss: 0.0830
# Epoch 327/500
# 22/22 - 0s - loss: 0.0834
# Epoch 328/500
# 22/22 - 0s - loss: 0.0836
# Epoch 329/500
# 22/22 - 0s - loss: 0.0824
# Epoch 330/500
# 22/22 - 0s - loss: 0.0832
# Epoch 331/500
# 22/22 - 0s - loss: 0.0835
# Epoch 332/500
# 22/22 - 0s - loss: 0.0830
# Epoch 333/500
# 22/22 - 0s - loss: 0.0832
# Epoch 334/500
# 22/22 - 0s - loss: 0.0829
# Epoch 335/500
# 22/22 - 0s - loss: 0.0834
# Epoch 336/500
# 22/22 - 0s - loss: 0.0832
# Epoch 337/500
# 22/22 - 0s - loss: 0.0836
# Epoch 338/500
# 22/22 - 0s - loss: 0.0837
# Epoch 339/500
# 22/22 - 0s - loss: 0.0827
# Epoch 340/500
# 22/22 - 0s - loss: 0.0827
# Epoch 341/500
# 22/22 - 0s - loss: 0.0833
# Epoch 342/500
# 22/22 - 0s - loss: 0.0831
# Epoch 343/500
# 22/22 - 0s - loss: 0.0826
# Epoch 344/500
# 22/22 - 0s - loss: 0.0830
# Epoch 345/500
# 22/22 - 0s - loss: 0.0829
# Epoch 346/500
# 22/22 - 0s - loss: 0.0824
# Epoch 347/500
# 22/22 - 0s - loss: 0.0840
# Epoch 348/500
# 22/22 - 0s - loss: 0.0827
# Epoch 349/500
# 22/22 - 0s - loss: 0.0827
# Epoch 350/500
# 22/22 - 0s - loss: 0.0831
# Epoch 351/500
# 22/22 - 0s - loss: 0.0829
# Epoch 352/500
# 22/22 - 0s - loss: 0.0825
# Epoch 353/500
# 22/22 - 0s - loss: 0.0828
# Epoch 354/500
# 22/22 - 0s - loss: 0.0827
# Epoch 355/500
# 22/22 - 0s - loss: 0.0826
# Epoch 356/500
# 22/22 - 0s - loss: 0.0825
# Epoch 357/500
# 22/22 - 0s - loss: 0.0828
# Epoch 358/500
# 22/22 - 0s - loss: 0.0821
# Epoch 359/500
# 22/22 - 0s - loss: 0.0824
# Epoch 360/500
# 22/22 - 0s - loss: 0.0820
# Epoch 361/500
# 22/22 - 0s - loss: 0.0835
# Epoch 362/500
# 22/22 - 0s - loss: 0.0818
# Epoch 363/500
# 22/22 - 0s - loss: 0.0818
# Epoch 364/500
# 22/22 - 0s - loss: 0.0817
# Epoch 365/500
# 22/22 - 0s - loss: 0.0832
# Epoch 366/500
# 22/22 - 0s - loss: 0.0824
# Epoch 367/500
# 22/22 - 0s - loss: 0.0822
# Epoch 368/500
# 22/22 - 0s - loss: 0.0835
# Epoch 369/500
# 22/22 - 0s - loss: 0.0823
# Epoch 370/500
# 22/22 - 0s - loss: 0.0829
# Epoch 371/500
# 22/22 - 0s - loss: 0.0828
# Epoch 372/500
# 22/22 - 0s - loss: 0.0834
# Epoch 373/500
# 22/22 - 0s - loss: 0.0827
# Epoch 374/500
# 22/22 - 0s - loss: 0.0815
# Epoch 375/500
# 22/22 - 0s - loss: 0.0824
# Epoch 376/500
# 22/22 - 0s - loss: 0.0826
# Epoch 377/500
# 22/22 - 0s - loss: 0.0824
# Epoch 378/500
# 22/22 - 0s - loss: 0.0819
# Epoch 379/500
# 22/22 - 0s - loss: 0.0825
# Epoch 380/500
# 22/22 - 0s - loss: 0.0822
# Epoch 381/500
# 22/22 - 0s - loss: 0.0819
# Epoch 382/500
# 22/22 - 0s - loss: 0.0819
# Epoch 383/500
# 22/22 - 0s - loss: 0.0820
# Epoch 384/500
# 22/22 - 0s - loss: 0.0827
# Epoch 385/500
# 22/22 - 0s - loss: 0.0828
# Epoch 386/500
# 22/22 - 0s - loss: 0.0823
# Epoch 387/500
# 22/22 - 0s - loss: 0.0814
# Epoch 388/500
# 22/22 - 0s - loss: 0.0825
# Epoch 389/500
# 22/22 - 0s - loss: 0.0820
# Epoch 390/500
# 22/22 - 0s - loss: 0.0824
# Epoch 391/500
# 22/22 - 0s - loss: 0.0824
# Epoch 392/500
# 22/22 - 0s - loss: 0.0821
# Epoch 393/500
# 22/22 - 0s - loss: 0.0826
# Epoch 394/500
# 22/22 - 0s - loss: 0.0826
# Epoch 395/500
# 22/22 - 0s - loss: 0.0822
# Epoch 396/500
# 22/22 - 0s - loss: 0.0827
# Epoch 397/500
# 22/22 - 0s - loss: 0.0826
# Epoch 398/500
# 22/22 - 0s - loss: 0.0825
# Epoch 399/500
# 22/22 - 0s - loss: 0.0820
# Epoch 400/500
# 22/22 - 0s - loss: 0.0823
# Epoch 401/500
# 22/22 - 0s - loss: 0.0821
# Epoch 402/500
# 22/22 - 0s - loss: 0.0819
# Epoch 403/500
# 22/22 - 0s - loss: 0.0828
# Epoch 404/500
# 22/22 - 0s - loss: 0.0815
# Epoch 405/500
# 22/22 - 0s - loss: 0.0824
# Epoch 406/500
# 22/22 - 0s - loss: 0.0825
# Epoch 407/500
# 22/22 - 0s - loss: 0.0818
# Epoch 408/500
# 22/22 - 0s - loss: 0.0820
# Epoch 409/500
# 22/22 - 0s - loss: 0.0823
# Epoch 410/500
# 22/22 - 0s - loss: 0.0825
# Epoch 411/500
# 22/22 - 0s - loss: 0.0817
# Epoch 412/500
# 22/22 - 0s - loss: 0.0813
# Epoch 413/500
# 22/22 - 0s - loss: 0.0815
# Epoch 414/500
# 22/22 - 0s - loss: 0.0820
# Epoch 415/500
# 22/22 - 0s - loss: 0.0818
# Epoch 416/500
# 22/22 - 0s - loss: 0.0817
# Epoch 417/500
# 22/22 - 0s - loss: 0.0818
# Epoch 418/500
# 22/22 - 0s - loss: 0.0820
# Epoch 419/500
# 22/22 - 0s - loss: 0.0811
# Epoch 420/500
# 22/22 - 0s - loss: 0.0820
# Epoch 421/500
# 22/22 - 0s - loss: 0.0821
# Epoch 422/500
# 22/22 - 0s - loss: 0.0819
# Epoch 423/500
# 22/22 - 0s - loss: 0.0810
# Epoch 424/500
# 22/22 - 0s - loss: 0.0821
# Epoch 425/500
# 22/22 - 0s - loss: 0.0824
# Epoch 426/500
# 22/22 - 0s - loss: 0.0820
# Epoch 427/500
# 22/22 - 0s - loss: 0.0823
# Epoch 428/500
# 22/22 - 0s - loss: 0.0811
# Epoch 429/500
# 22/22 - 0s - loss: 0.0820
# Epoch 430/500
# 22/22 - 0s - loss: 0.0817
# Epoch 431/500
# 22/22 - 0s - loss: 0.0818
# Epoch 432/500
# 22/22 - 0s - loss: 0.0819
# Epoch 433/500
# 22/22 - 0s - loss: 0.0821
# Epoch 434/500
# 22/22 - 0s - loss: 0.0822
# Epoch 435/500
# 22/22 - 0s - loss: 0.0815
# Epoch 436/500
# 22/22 - 0s - loss: 0.0815
# Epoch 437/500
# 22/22 - 0s - loss: 0.0808
# Epoch 438/500
# 22/22 - 0s - loss: 0.0809
# Epoch 439/500
# 22/22 - 0s - loss: 0.0816
# Epoch 440/500
# 22/22 - 0s - loss: 0.0816
# Epoch 441/500
# 22/22 - 0s - loss: 0.0820
# Epoch 442/500
# 22/22 - 0s - loss: 0.0815
# Epoch 443/500
# 22/22 - 0s - loss: 0.0815
# Epoch 444/500
# 22/22 - 0s - loss: 0.0808
# Epoch 445/500
# 22/22 - 0s - loss: 0.0812
# Epoch 446/500
# 22/22 - 0s - loss: 0.0808
# Epoch 447/500
# 22/22 - 0s - loss: 0.0812
# Epoch 448/500
# 22/22 - 0s - loss: 0.0816
# Epoch 449/500
# 22/22 - 0s - loss: 0.0823
# Epoch 450/500
# 22/22 - 0s - loss: 0.0811
# Epoch 451/500
# 22/22 - 0s - loss: 0.0818
# Epoch 452/500
# 22/22 - 0s - loss: 0.0812
# Epoch 453/500
# 22/22 - 0s - loss: 0.0811
# Epoch 454/500
# 22/22 - 0s - loss: 0.0814
# Epoch 455/500
# 22/22 - 0s - loss: 0.0816
# Epoch 456/500
# 22/22 - 0s - loss: 0.0816
# Epoch 457/500
# 22/22 - 0s - loss: 0.0811
# Epoch 458/500
# 22/22 - 0s - loss: 0.0809
# Epoch 459/500
# 22/22 - 0s - loss: 0.0815
# Epoch 460/500
# 22/22 - 0s - loss: 0.0818
# Epoch 461/500
# 22/22 - 0s - loss: 0.0815
# Epoch 462/500
# 22/22 - 0s - loss: 0.0813
# Epoch 463/500
# 22/22 - 0s - loss: 0.0812
# Epoch 464/500
# 22/22 - 0s - loss: 0.0818
# Epoch 465/500
# 22/22 - 0s - loss: 0.0809
# Epoch 466/500
# 22/22 - 0s - loss: 0.0804
# Epoch 467/500
# 22/22 - 0s - loss: 0.0814
# Epoch 468/500
# 22/22 - 0s - loss: 0.0815
# Epoch 469/500
# 22/22 - 0s - loss: 0.0814
# Epoch 470/500
# 22/22 - 0s - loss: 0.0816
# Epoch 471/500
# 22/22 - 0s - loss: 0.0809
# Epoch 472/500
# 22/22 - 0s - loss: 0.0811
# Epoch 473/500
# 22/22 - 0s - loss: 0.0810
# Epoch 474/500
# 22/22 - 0s - loss: 0.0811
# Epoch 475/500
# 22/22 - 0s - loss: 0.0804
# Epoch 476/500
# 22/22 - 0s - loss: 0.0817
# Epoch 477/500
# 22/22 - 0s - loss: 0.0818
# Epoch 478/500
# 22/22 - 0s - loss: 0.0803
# Epoch 479/500
# 22/22 - 0s - loss: 0.0805
# Epoch 480/500
# 22/22 - 0s - loss: 0.0806
# Epoch 481/500
# 22/22 - 0s - loss: 0.0815
# Epoch 482/500
# 22/22 - 0s - loss: 0.0806
# Epoch 483/500
# 22/22 - 0s - loss: 0.0816
# Epoch 484/500
# 22/22 - 0s - loss: 0.0809
# Epoch 485/500
# 22/22 - 0s - loss: 0.0805
# Epoch 486/500
# 22/22 - 0s - loss: 0.0808
# Epoch 487/500
# 22/22 - 0s - loss: 0.0807
# Epoch 488/500
# 22/22 - 0s - loss: 0.0811
# Epoch 489/500
# 22/22 - 0s - loss: 0.0809
# Epoch 490/500
# 22/22 - 0s - loss: 0.0808
# Epoch 491/500
# 22/22 - 0s - loss: 0.0814
# Epoch 492/500
# 22/22 - 0s - loss: 0.0810
# Epoch 493/500
# 22/22 - 0s - loss: 0.0810
# Epoch 494/500
# 22/22 - 0s - loss: 0.0809
# Epoch 495/500
# 22/22 - 0s - loss: 0.0805
# Epoch 496/500
# 22/22 - 0s - loss: 0.0807
# Epoch 497/500
# 22/22 - 0s - loss: 0.0806
# Epoch 498/500
# 22/22 - 0s - loss: 0.0810
# Epoch 499/500
# 22/22 - 0s - loss: 0.0808
# Epoch 500/500
# 22/22 - 0s - loss: 0.0810

# %%
#Predict electricity demand for train and test dataset
train_pred = model.predict(train_set)
test_pred = model.predict(test_set)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 2191, 7) for input KerasTensor(type_spec=TensorSpec(shape=(None, 2191, 7), dtype=tf.float32, name='simple_rnn_1_input'), name='simple_rnn_1_input', description="created by layer 'simple_rnn_1_input'"), but it was called on an input with incompatible shape (None, 1, 7).

# %%
print(train_pred.shape)
print(test_pred.shape)
# Out:
# (2191, 1)
# (59, 1)

# %%
#Apply inverse transformation to predictions
train_pred = scaler_y.inverse_transform(train_pred)
train_set_target = scaler_y.inverse_transform(train_set_target)
test_pred = scaler_y.inverse_transform(test_pred)
test_set_target = scaler_y.inverse_transform(test_set_target)

# %%
trainScore = model.evaluate(train_set, train_set_target, verbose=0)
print(trainScore)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 2191, 7) for input KerasTensor(type_spec=TensorSpec(shape=(None, 2191, 7), dtype=tf.float32, name='simple_rnn_1_input'), name='simple_rnn_1_input', description="created by layer 'simple_rnn_1_input'"), but it was called on an input with incompatible shape (None, 1, 7).
# 113683.625

# %%
#Import the relevant performance metric libraries 
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error, r2_score
from math import sqrt

# %%
print("Mean Absolute Error: ", mean_absolute_error(train_set_target[:,0], train_pred[:,0]))
print("Mean Absolute Percentage Error: ", np.mean(np.abs((train_set_target[:,0] - train_pred[:,0]) / train_set_target[:,0])) * 100)
print("Mean Squared Error: ", mean_squared_error(train_set_target[:,0], train_pred[:,0]))
print("Root Mean Squared Error: ", sqrt(mean_squared_error(train_set_target[:,0], train_pred[:,0])))
print("R2 Score: ", r2_score(train_set_target[:,0],train_pred[:,0]))
# Out:
# Mean Absolute Error:  4485.837504933102
# Mean Absolute Percentage Error:  3.992242310820684
# Mean Squared Error:  34040170.8495271
# Root Mean Squared Error:  5834.395499923458
# R2 Score:  0.5809892931477273

# %%
#Real vs predicted Energy Consumption
sns.set(rc={'figure.figsize':(15,10)})
plt.plot(test_set_target,color='black')
plt.plot(test_pred,color='red')
plt.legend(['Real Energy Consumption','Predicted Energy Consumption'])
plt.show()

# %%
Real_Demand = pd.DataFrame(test_set_target, columns = ['Real_Demand'], index = dataset.iloc[2192:].index)
Predicted_Demand = pd.DataFrame(test_pred, columns = ['Predict_Demand'], index = dataset.iloc[2192:].index)

# %%
#Combine the original demand and forecasted demand
output = pd.DataFrame()
output['Real_Demand'] = Real_Demand['Real_Demand']
output['Predicted_Demand'] = Predicted_Demand['Predict_Demand']

# %%
output.head()
# Out:
#             Real_Demand  Predicted_Demand
# date
# 2021-01-01    92926.685     112195.078125
# 2021-01-02    98995.065     159500.000000
# 2021-01-03    94371.480     156841.562500
# 2021-01-04    99640.535     146474.515625
# 2021-01-05   103840.455     169724.828125

# %%
#Define train set
train_set = dataset.iloc[:]
train_set_target = train_set['demand']
train_set = train_set.drop(columns=['demand'])
train_set_target = pd.DataFrame(train_set_target)

# %%
print(train_set.shape)
print(train_set_target.shape)
# Out:
# (2251, 7)
# (2251, 1)

# %%
#Obtain prediction dataset
predict_set = pd.read_csv('dataset_for_prediction.csv')
predict_set = predict_set.drop(columns=['demand'])
predict_set.head()
# Out:
#          date        RRP  min_temperature  max_temperature  solar_exposure  \
# 0  03-01-2021  16.113191        12.506416           20.844       14.810004
# 1  03-02-2021  20.828125        12.016535           20.244       15.744815
# 2  03-03-2021  24.979167        11.526654           19.144       15.494148
# 3  03-04-2021  24.135417        11.036772           16.892       13.976392
# 4  03-05-2021  21.580625        10.546891           16.680       13.893853
#
#     rainfall school_day holiday
# 0   1.000000          Y       N
# 1   1.000000          Y       N
# 2   1.733333          Y       N
# 3  12.800000          Y       N
# 4  32.700000          Y       N

# %%
#Replace 'Y' with 1 and 'N' with 0
predict_set['school_day'] = predict_set['school_day'].replace(to_replace ="N", value = 0)
predict_set['school_day'] = predict_set['school_day'].replace(to_replace ="Y", value = 1)
predict_set['holiday'] = predict_set['holiday'].replace(to_replace ="N", value = 0)
predict_set['holiday'] = predict_set['holiday'].replace(to_replace ="Y", value = 1)

# %%
#Format 'date' column in the predict_set
predict_set['date'] = pd.to_datetime(predict_set['date'], infer_datetime_format=True)
predict_set.set_index('date', inplace=True)

# %%
predict_set.head()
# Out:
#                   RRP  min_temperature  max_temperature  solar_exposure  \
# date
# 2021-03-01  16.113191        12.506416           20.844       14.810004
# 2021-03-02  20.828125        12.016535           20.244       15.744815
# 2021-03-03  24.979167        11.526654           19.144       15.494148
# 2021-03-04  24.135417        11.036772           16.892       13.976392
# 2021-03-05  21.580625        10.546891           16.680       13.893853
#
#              rainfall  school_day  holiday
# date
# 2021-03-01   1.000000           1        0
# 2021-03-02   1.000000           1        0
# 2021-03-03   1.733333           1        0
# 2021-03-04  12.800000           1        0
# 2021-03-05  32.700000           1        0

# %%
#Normalise the dataset using MinMax scaler
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))
train_set = scaler.fit_transform(train_set)
predict_set = scaler.fit_transform(predict_set)

train_set_target = scaler_y.fit_transform(train_set_target)

# %%
train_set = np.reshape(train_set, (train_set.shape[0], 1, train_set.shape[1]))
predict_set = np.reshape(predict_set, (predict_set.shape[0], 1, predict_set.shape[1]))

print(train_set.shape)
print(predict_set.shape)
# Out:
# (2251, 1, 7)
# (184, 1, 7)

# %%
# SimpleRNN model
model = Sequential()
model.add(SimpleRNN(units=50, input_shape=(2251,7), activation="relu"))
model.add(Dense(8, activation="relu")) 
model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mean_absolute_error', optimizer='adam')

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_2 (SimpleRNN)     (None, 50)                2900
# _________________________________________________________________
# dense_4 (Dense)              (None, 8)                 408
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 3,317
# Trainable params: 3,317
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x=train_set,y=train_set_target, epochs=500, batch_size=100, verbose=2)
# Out:
# Epoch 1/500
# WARNING:tensorflow:Model was constructed with shape (None, 2251, 7) for input KerasTensor(type_spec=TensorSpec(shape=(None, 2251, 7), dtype=tf.float32, name='simple_rnn_2_input'), name='simple_rnn_2_input', description="created by layer 'simple_rnn_2_input'"), but it was called on an input with incompatible shape (None, 1, 7).
# WARNING:tensorflow:Model was constructed with shape (None, 2251, 7) for input KerasTensor(type_spec=TensorSpec(shape=(None, 2251, 7), dtype=tf.float32, name='simple_rnn_2_input'), name='simple_rnn_2_input', description="created by layer 'simple_rnn_2_input'"), but it was called on an input with incompatible shape (None, 1, 7).
# 23/23 - 1s - loss: 0.2173
# Epoch 2/500
# 23/23 - 0s - loss: 0.1732
# Epoch 3/500
# 23/23 - 0s - loss: 0.1569
# Epoch 4/500
# 23/23 - 0s - loss: 0.1477
# Epoch 5/500
# 23/23 - 0s - loss: 0.1438
# Epoch 6/500
# 23/23 - 0s - loss: 0.1381
# Epoch 7/500
# 23/23 - 0s - loss: 0.1357
# Epoch 8/500
# 23/23 - 0s - loss: 0.1307
# Epoch 9/500
# 23/23 - 0s - loss: 0.1287
# Epoch 10/500
# 23/23 - 0s - loss: 0.1241
# Epoch 11/500
# 23/23 - 0s - loss: 0.1226
# Epoch 12/500
# 23/23 - 0s - loss: 0.1203
# Epoch 13/500
# 23/23 - 0s - loss: 0.1194
# Epoch 14/500
# 23/23 - 0s - loss: 0.1152
# Epoch 15/500
# 23/23 - 0s - loss: 0.1169
# Epoch 16/500
# 23/23 - 0s - loss: 0.1171
# Epoch 17/500
# 23/23 - 0s - loss: 0.1118
# Epoch 18/500
# 23/23 - 0s - loss: 0.1120
# Epoch 19/500
# 23/23 - 0s - loss: 0.1117
# Epoch 20/500
# 23/23 - 0s - loss: 0.1083
# Epoch 21/500
# 23/23 - 0s - loss: 0.1079
# Epoch 22/500
# 23/23 - 0s - loss: 0.1070
# Epoch 23/500
# 23/23 - 0s - loss: 0.1058
# Epoch 24/500
# 23/23 - 0s - loss: 0.1049
# Epoch 25/500
# 23/23 - 0s - loss: 0.1033
# Epoch 26/500
# 23/23 - 0s - loss: 0.1036
# Epoch 27/500
# 23/23 - 0s - loss: 0.1017
# Epoch 28/500
# 23/23 - 0s - loss: 0.1033
# Epoch 29/500
# 23/23 - 0s - loss: 0.1023
# Epoch 30/500
# 23/23 - 0s - loss: 0.1025
# Epoch 31/500
# 23/23 - 0s - loss: 0.1018
# Epoch 32/500
# 23/23 - 0s - loss: 0.1005
# Epoch 33/500
# 23/23 - 0s - loss: 0.1008
# Epoch 34/500
# 23/23 - 0s - loss: 0.0993
# Epoch 35/500
# 23/23 - 0s - loss: 0.1000
# Epoch 36/500
# 23/23 - 0s - loss: 0.0984
# Epoch 37/500
# 23/23 - 0s - loss: 0.0987
# Epoch 38/500
# 23/23 - 0s - loss: 0.0978
# Epoch 39/500
# 23/23 - 0s - loss: 0.0977
# Epoch 40/500
# 23/23 - 0s - loss: 0.0979
# Epoch 41/500
# 23/23 - 0s - loss: 0.0974
# Epoch 42/500
# 23/23 - 0s - loss: 0.0986
# Epoch 43/500
# 23/23 - 0s - loss: 0.0981
# Epoch 44/500
# 23/23 - 0s - loss: 0.0969
# Epoch 45/500
# 23/23 - 0s - loss: 0.0982
# Epoch 46/500
# 23/23 - 0s - loss: 0.0968
# Epoch 47/500
# 23/23 - 0s - loss: 0.0982
# Epoch 48/500
# 23/23 - 0s - loss: 0.0989
# Epoch 49/500
# 23/23 - 0s - loss: 0.0971
# Epoch 50/500
# 23/23 - 0s - loss: 0.0980
# Epoch 51/500
# 23/23 - 0s - loss: 0.0978
# Epoch 52/500
# 23/23 - 0s - loss: 0.0963
# Epoch 53/500
# 23/23 - 0s - loss: 0.0970
# Epoch 54/500
# 23/23 - 0s - loss: 0.0977
# Epoch 55/500
# 23/23 - 0s - loss: 0.0984
# Epoch 56/500
# 23/23 - 0s - loss: 0.0966
# Epoch 57/500
# 23/23 - 0s - loss: 0.0960
# Epoch 58/500
# 23/23 - 0s - loss: 0.0961
# Epoch 59/500
# 23/23 - 0s - loss: 0.0957
# Epoch 60/500
# 23/23 - 0s - loss: 0.0981
# Epoch 61/500
# 23/23 - 0s - loss: 0.0954
# Epoch 62/500
# 23/23 - 0s - loss: 0.0955
# Epoch 63/500
# 23/23 - 0s - loss: 0.0974
# Epoch 64/500
# 23/23 - 0s - loss: 0.0957
# Epoch 65/500
# 23/23 - 0s - loss: 0.0946
# Epoch 66/500
# 23/23 - 0s - loss: 0.0959
# Epoch 67/500
# 23/23 - 0s - loss: 0.0968
# Epoch 68/500
# 23/23 - 0s - loss: 0.0966
# Epoch 69/500
# 23/23 - 0s - loss: 0.0969
# Epoch 70/500
# 23/23 - 0s - loss: 0.0976
# Epoch 71/500
# 23/23 - 0s - loss: 0.0962
# Epoch 72/500
# 23/23 - 0s - loss: 0.0967
# Epoch 73/500
# 23/23 - 0s - loss: 0.0964
# Epoch 74/500
# 23/23 - 0s - loss: 0.0962
# Epoch 75/500
# 23/23 - 0s - loss: 0.0971
# Epoch 76/500
# 23/23 - 0s - loss: 0.0954
# Epoch 77/500
# 23/23 - 0s - loss: 0.0961
# Epoch 78/500
# 23/23 - 0s - loss: 0.0955
# Epoch 79/500
# 23/23 - 0s - loss: 0.0947
# Epoch 80/500
# 23/23 - 0s - loss: 0.0962
# Epoch 81/500
# 23/23 - 0s - loss: 0.0948
# Epoch 82/500
# 23/23 - 0s - loss: 0.0965
# Epoch 83/500
# 23/23 - 0s - loss: 0.0966
# Epoch 84/500
# 23/23 - 0s - loss: 0.0971
# Epoch 85/500
# 23/23 - 0s - loss: 0.0949
# Epoch 86/500
# 23/23 - 0s - loss: 0.0951
# Epoch 87/500
# 23/23 - 0s - loss: 0.0960
# Epoch 88/500
# 23/23 - 0s - loss: 0.0946
# Epoch 89/500
# 23/23 - 0s - loss: 0.0944
# Epoch 90/500
# 23/23 - 0s - loss: 0.0957
# Epoch 91/500
# 23/23 - 0s - loss: 0.0961
# Epoch 92/500
# 23/23 - 0s - loss: 0.0968
# Epoch 93/500
# 23/23 - 0s - loss: 0.0945
# Epoch 94/500
# 23/23 - 0s - loss: 0.0947
# Epoch 95/500
# 23/23 - 0s - loss: 0.0959
# Epoch 96/500
# 23/23 - 0s - loss: 0.0946
# Epoch 97/500
# 23/23 - 0s - loss: 0.0948
# Epoch 98/500
# 23/23 - 0s - loss: 0.0964
# Epoch 99/500
# 23/23 - 0s - loss: 0.0945
# Epoch 100/500
# 23/23 - 0s - loss: 0.0953
# Epoch 101/500
# 23/23 - 0s - loss: 0.0944
# Epoch 102/500
# 23/23 - 0s - loss: 0.0944
# Epoch 103/500
# 23/23 - 0s - loss: 0.0953
# Epoch 104/500
# 23/23 - 0s - loss: 0.0938
# Epoch 105/500
# 23/23 - 0s - loss: 0.0958
# Epoch 106/500
# 23/23 - 0s - loss: 0.0962
# Epoch 107/500
# 23/23 - 0s - loss: 0.0958
# Epoch 108/500
# 23/23 - 0s - loss: 0.0955
# Epoch 109/500
# 23/23 - 0s - loss: 0.0946
# Epoch 110/500
# 23/23 - 0s - loss: 0.0959
# Epoch 111/500
# 23/23 - 0s - loss: 0.0945
# Epoch 112/500
# 23/23 - 0s - loss: 0.0957
# Epoch 113/500
# 23/23 - 0s - loss: 0.0956
# Epoch 114/500
# 23/23 - 0s - loss: 0.0961
# Epoch 115/500
# 23/23 - 0s - loss: 0.0948
# Epoch 116/500
# 23/23 - 0s - loss: 0.0950
# Epoch 117/500
# 23/23 - 0s - loss: 0.0953
# Epoch 118/500
# 23/23 - 0s - loss: 0.0954
# Epoch 119/500
# 23/23 - 0s - loss: 0.0950
# Epoch 120/500
# 23/23 - 0s - loss: 0.0950
# Epoch 121/500
# 23/23 - 0s - loss: 0.0942
# Epoch 122/500
# 23/23 - 0s - loss: 0.0954
# Epoch 123/500
# 23/23 - 0s - loss: 0.0951
# Epoch 124/500
# 23/23 - 0s - loss: 0.0960
# Epoch 125/500
# 23/23 - 0s - loss: 0.0951
# Epoch 126/500
# 23/23 - 0s - loss: 0.0958
# Epoch 127/500
# 23/23 - 0s - loss: 0.0950
# Epoch 128/500
# 23/23 - 0s - loss: 0.0942
# Epoch 129/500
# 23/23 - 0s - loss: 0.0958
# Epoch 130/500
# 23/23 - 0s - loss: 0.0977
# Epoch 131/500
# 23/23 - 0s - loss: 0.0949
# Epoch 132/500
# 23/23 - 0s - loss: 0.0948
# Epoch 133/500
# 23/23 - 0s - loss: 0.0950
# Epoch 134/500
# 23/23 - 0s - loss: 0.0948
# Epoch 135/500
# 23/23 - 0s - loss: 0.0940
# Epoch 136/500
# 23/23 - 0s - loss: 0.0935
# Epoch 137/500
# 23/23 - 0s - loss: 0.0951
# Epoch 138/500
# 23/23 - 0s - loss: 0.0949
# Epoch 139/500
# 23/23 - 0s - loss: 0.0937
# Epoch 140/500
# 23/23 - 0s - loss: 0.0936
# Epoch 141/500
# 23/23 - 0s - loss: 0.0943
# Epoch 142/500
# 23/23 - 0s - loss: 0.0981
# Epoch 143/500
# 23/23 - 0s - loss: 0.0955
# Epoch 144/500
# 23/23 - 0s - loss: 0.0984
# Epoch 145/500
# 23/23 - 0s - loss: 0.0946
# Epoch 146/500
# 23/23 - 0s - loss: 0.0960
# Epoch 147/500
# 23/23 - 0s - loss: 0.0957
# Epoch 148/500
# 23/23 - 0s - loss: 0.0938
# Epoch 149/500
# 23/23 - 0s - loss: 0.0941
# Epoch 150/500
# 23/23 - 0s - loss: 0.0938
# Epoch 151/500
# 23/23 - 0s - loss: 0.0956
# Epoch 152/500
# 23/23 - 0s - loss: 0.0944
# Epoch 153/500
# 23/23 - 0s - loss: 0.0943
# Epoch 154/500
# 23/23 - 0s - loss: 0.0963
# Epoch 155/500
# 23/23 - 0s - loss: 0.0955
# Epoch 156/500
# 23/23 - 0s - loss: 0.0972
# Epoch 157/500
# 23/23 - 0s - loss: 0.0957
# Epoch 158/500
# 23/23 - 0s - loss: 0.0944
# Epoch 159/500
# 23/23 - 0s - loss: 0.0941
# Epoch 160/500
# 23/23 - 0s - loss: 0.0926
# Epoch 161/500
# 23/23 - 0s - loss: 0.0945
# Epoch 162/500
# 23/23 - 0s - loss: 0.0939
# Epoch 163/500
# 23/23 - 0s - loss: 0.0945
# Epoch 164/500
# 23/23 - 0s - loss: 0.0948
# Epoch 165/500
# 23/23 - 0s - loss: 0.0940
# Epoch 166/500
# 23/23 - 0s - loss: 0.0964
# Epoch 167/500
# 23/23 - 0s - loss: 0.0944
# Epoch 168/500
# 23/23 - 0s - loss: 0.0957
# Epoch 169/500
# 23/23 - 0s - loss: 0.0932
# Epoch 170/500
# 23/23 - 0s - loss: 0.0936
# Epoch 171/500
# 23/23 - 0s - loss: 0.0943
# Epoch 172/500
# 23/23 - 0s - loss: 0.0945
# Epoch 173/500
# 23/23 - 0s - loss: 0.0966
# Epoch 174/500
# 23/23 - 0s - loss: 0.0953
# Epoch 175/500
# 23/23 - 0s - loss: 0.0955
# Epoch 176/500
# 23/23 - 0s - loss: 0.0943
# Epoch 177/500
# 23/23 - 0s - loss: 0.0952
# Epoch 178/500
# 23/23 - 0s - loss: 0.0938
# Epoch 179/500
# 23/23 - 0s - loss: 0.0934
# Epoch 180/500
# 23/23 - 0s - loss: 0.0957
# Epoch 181/500
# 23/23 - 0s - loss: 0.0953
# Epoch 182/500
# 23/23 - 0s - loss: 0.0958
# Epoch 183/500
# 23/23 - 0s - loss: 0.0936
# Epoch 184/500
# 23/23 - 0s - loss: 0.0945
# Epoch 185/500
# 23/23 - 0s - loss: 0.0946
# Epoch 186/500
# 23/23 - 0s - loss: 0.0943
# Epoch 187/500
# 23/23 - 0s - loss: 0.0949
# Epoch 188/500
# 23/23 - 0s - loss: 0.0942
# Epoch 189/500
# 23/23 - 0s - loss: 0.0960
# Epoch 190/500
# 23/23 - 0s - loss: 0.0941
# Epoch 191/500
# 23/23 - 0s - loss: 0.0945
# Epoch 192/500
# 23/23 - 0s - loss: 0.0953
# Epoch 193/500
# 23/23 - 0s - loss: 0.0942
# Epoch 194/500
# 23/23 - 0s - loss: 0.0938
# Epoch 195/500
# 23/23 - 0s - loss: 0.0947
# Epoch 196/500
# 23/23 - 0s - loss: 0.0949
# Epoch 197/500
# 23/23 - 0s - loss: 0.0944
# Epoch 198/500
# 23/23 - 0s - loss: 0.0941
# Epoch 199/500
# 23/23 - 0s - loss: 0.0950
# Epoch 200/500
# 23/23 - 0s - loss: 0.0935
# Epoch 201/500
# 23/23 - 0s - loss: 0.0951
# Epoch 202/500
# 23/23 - 0s - loss: 0.0945
# Epoch 203/500
# 23/23 - 0s - loss: 0.0943
# Epoch 204/500
# 23/23 - 0s - loss: 0.0951
# Epoch 205/500
# 23/23 - 0s - loss: 0.0942
# Epoch 206/500
# 23/23 - 0s - loss: 0.0918
# Epoch 207/500
# 23/23 - 0s - loss: 0.0944
# Epoch 208/500
# 23/23 - 0s - loss: 0.0944
# Epoch 209/500
# 23/23 - 0s - loss: 0.0937
# Epoch 210/500
# 23/23 - 0s - loss: 0.0929
# Epoch 211/500
# 23/23 - 0s - loss: 0.0959
# Epoch 212/500
# 23/23 - 0s - loss: 0.0934
# Epoch 213/500
# 23/23 - 0s - loss: 0.0959
# Epoch 214/500
# 23/23 - 0s - loss: 0.0946
# Epoch 215/500
# 23/23 - 0s - loss: 0.0936
# Epoch 216/500
# 23/23 - 0s - loss: 0.0934
# Epoch 217/500
# 23/23 - 0s - loss: 0.0946
# Epoch 218/500
# 23/23 - 0s - loss: 0.0955
# Epoch 219/500
# 23/23 - 0s - loss: 0.0953
# Epoch 220/500
# 23/23 - 0s - loss: 0.0957
# Epoch 221/500
# 23/23 - 0s - loss: 0.0922
# Epoch 222/500
# 23/23 - 0s - loss: 0.0939
# Epoch 223/500
# 23/23 - 0s - loss: 0.0953
# Epoch 224/500
# 23/23 - 0s - loss: 0.0942
# Epoch 225/500
# 23/23 - 0s - loss: 0.0942
# Epoch 226/500
# 23/23 - 0s - loss: 0.0941
# Epoch 227/500
# 23/23 - 0s - loss: 0.0935
# Epoch 228/500
# 23/23 - 0s - loss: 0.0947
# Epoch 229/500
# 23/23 - 0s - loss: 0.0935
# Epoch 230/500
# 23/23 - 0s - loss: 0.0950
# Epoch 231/500
# 23/23 - 0s - loss: 0.0932
# Epoch 232/500
# 23/23 - 0s - loss: 0.0943
# Epoch 233/500
# 23/23 - 0s - loss: 0.0953
# Epoch 234/500
# 23/23 - 0s - loss: 0.0926
# Epoch 235/500
# 23/23 - 0s - loss: 0.0936
# Epoch 236/500
# 23/23 - 0s - loss: 0.0943
# Epoch 237/500
# 23/23 - 0s - loss: 0.0936
# Epoch 238/500
# 23/23 - 0s - loss: 0.0959
# Epoch 239/500
# 23/23 - 0s - loss: 0.0942
# Epoch 240/500
# 23/23 - 0s - loss: 0.0930
# Epoch 241/500
# 23/23 - 0s - loss: 0.0927
# Epoch 242/500
# 23/23 - 0s - loss: 0.0932
# Epoch 243/500
# 23/23 - 0s - loss: 0.0926
# Epoch 244/500
# 23/23 - 0s - loss: 0.0934
# Epoch 245/500
# 23/23 - 0s - loss: 0.0939
# Epoch 246/500
# 23/23 - 0s - loss: 0.0952
# Epoch 247/500
# 23/23 - 0s - loss: 0.0939
# Epoch 248/500
# 23/23 - 0s - loss: 0.0959
# Epoch 249/500
# 23/23 - 0s - loss: 0.0939
# Epoch 250/500
# 23/23 - 0s - loss: 0.0929
# Epoch 251/500
# 23/23 - 0s - loss: 0.0952
# Epoch 252/500
# 23/23 - 0s - loss: 0.0933
# Epoch 253/500
# 23/23 - 0s - loss: 0.0925
# Epoch 254/500
# 23/23 - 0s - loss: 0.0938
# Epoch 255/500
# 23/23 - 0s - loss: 0.0917
# Epoch 256/500
# 23/23 - 0s - loss: 0.0941
# Epoch 257/500
# 23/23 - 0s - loss: 0.0940
# Epoch 258/500
# 23/23 - 0s - loss: 0.0957
# Epoch 259/500
# 23/23 - 0s - loss: 0.0939
# Epoch 260/500
# 23/23 - 0s - loss: 0.0949
# Epoch 261/500
# 23/23 - 0s - loss: 0.0938
# Epoch 262/500
# 23/23 - 0s - loss: 0.0929
# Epoch 263/500
# 23/23 - 0s - loss: 0.0951
# Epoch 264/500
# 23/23 - 0s - loss: 0.0945
# Epoch 265/500
# 23/23 - 0s - loss: 0.0942
# Epoch 266/500
# 23/23 - 0s - loss: 0.0933
# Epoch 267/500
# 23/23 - 0s - loss: 0.0949
# Epoch 268/500
# 23/23 - 0s - loss: 0.0953
# Epoch 269/500
# 23/23 - 0s - loss: 0.0947
# Epoch 270/500
# 23/23 - 0s - loss: 0.0927
# Epoch 271/500
# 23/23 - 0s - loss: 0.0946
# Epoch 272/500
# 23/23 - 0s - loss: 0.0944
# Epoch 273/500
# 23/23 - 0s - loss: 0.0938
# Epoch 274/500
# 23/23 - 0s - loss: 0.0940
# Epoch 275/500
# 23/23 - 0s - loss: 0.0931
# Epoch 276/500
# 23/23 - 0s - loss: 0.0938
# Epoch 277/500
# 23/23 - 0s - loss: 0.0957
# Epoch 278/500
# 23/23 - 0s - loss: 0.0932
# Epoch 279/500
# 23/23 - 0s - loss: 0.0939
# Epoch 280/500
# 23/23 - 0s - loss: 0.0959
# Epoch 281/500
# 23/23 - 0s - loss: 0.0940
# Epoch 282/500
# 23/23 - 0s - loss: 0.0936
# Epoch 283/500
# 23/23 - 0s - loss: 0.0945
# Epoch 284/500
# 23/23 - 0s - loss: 0.0931
# Epoch 285/500
# 23/23 - 0s - loss: 0.0936
# Epoch 286/500
# 23/23 - 0s - loss: 0.0941
# Epoch 287/500
# 23/23 - 0s - loss: 0.0932
# Epoch 288/500
# 23/23 - 0s - loss: 0.0933
# Epoch 289/500
# 23/23 - 0s - loss: 0.0935
# Epoch 290/500
# 23/23 - 0s - loss: 0.0950
# Epoch 291/500
# 23/23 - 0s - loss: 0.0930
# Epoch 292/500
# 23/23 - 0s - loss: 0.0941
# Epoch 293/500
# 23/23 - 0s - loss: 0.0942
# Epoch 294/500
# 23/23 - 0s - loss: 0.0930
# Epoch 295/500
# 23/23 - 0s - loss: 0.0957
# Epoch 296/500
# 23/23 - 0s - loss: 0.0944
# Epoch 297/500
# 23/23 - 0s - loss: 0.0939
# Epoch 298/500
# 23/23 - 0s - loss: 0.0924
# Epoch 299/500
# 23/23 - 0s - loss: 0.0948
# Epoch 300/500
# 23/23 - 0s - loss: 0.0957
# Epoch 301/500
# 23/23 - 0s - loss: 0.0950
# Epoch 302/500
# 23/23 - 0s - loss: 0.0930
# Epoch 303/500
# 23/23 - 0s - loss: 0.0936
# Epoch 304/500
# 23/23 - 0s - loss: 0.0930
# Epoch 305/500
# 23/23 - 0s - loss: 0.0935
# Epoch 306/500
# 23/23 - 0s - loss: 0.0943
# Epoch 307/500
# 23/23 - 0s - loss: 0.0945
# Epoch 308/500
# 23/23 - 0s - loss: 0.0949
# Epoch 309/500
# 23/23 - 0s - loss: 0.0931
# Epoch 310/500
# 23/23 - 0s - loss: 0.0946
# Epoch 311/500
# 23/23 - 0s - loss: 0.0932
# Epoch 312/500
# 23/23 - 0s - loss: 0.0932
# Epoch 313/500
# 23/23 - 0s - loss: 0.0942
# Epoch 314/500
# 23/23 - 0s - loss: 0.0946
# Epoch 315/500
# 23/23 - 0s - loss: 0.0959
# Epoch 316/500
# 23/23 - 0s - loss: 0.0943
# Epoch 317/500
# 23/23 - 0s - loss: 0.0956
# Epoch 318/500
# 23/23 - 0s - loss: 0.0943
# Epoch 319/500
# 23/23 - 0s - loss: 0.0937
# Epoch 320/500
# 23/23 - 0s - loss: 0.0931
# Epoch 321/500
# 23/23 - 0s - loss: 0.0955
# Epoch 322/500
# 23/23 - 0s - loss: 0.0934
# Epoch 323/500
# 23/23 - 0s - loss: 0.0933
# Epoch 324/500
# 23/23 - 0s - loss: 0.0956
# Epoch 325/500
# 23/23 - 0s - loss: 0.0931
# Epoch 326/500
# 23/23 - 0s - loss: 0.0942
# Epoch 327/500
# 23/23 - 0s - loss: 0.0943
# Epoch 328/500
# 23/23 - 0s - loss: 0.0943
# Epoch 329/500
# 23/23 - 0s - loss: 0.0925
# Epoch 330/500
# 23/23 - 0s - loss: 0.0924
# Epoch 331/500
# 23/23 - 0s - loss: 0.0943
# Epoch 332/500
# 23/23 - 0s - loss: 0.0928
# Epoch 333/500
# 23/23 - 0s - loss: 0.0947
# Epoch 334/500
# 23/23 - 0s - loss: 0.0931
# Epoch 335/500
# 23/23 - 0s - loss: 0.0931
# Epoch 336/500
# 23/23 - 0s - loss: 0.0930
# Epoch 337/500
# 23/23 - 0s - loss: 0.0938
# Epoch 338/500
# 23/23 - 0s - loss: 0.0938
# Epoch 339/500
# 23/23 - 0s - loss: 0.0933
# Epoch 340/500
# 23/23 - 0s - loss: 0.0958
# Epoch 341/500
# 23/23 - 0s - loss: 0.0936
# Epoch 342/500
# 23/23 - 0s - loss: 0.0932
# Epoch 343/500
# 23/23 - 0s - loss: 0.0948
# Epoch 344/500
# 23/23 - 0s - loss: 0.0932
# Epoch 345/500
# 23/23 - 0s - loss: 0.0928
# Epoch 346/500
# 23/23 - 0s - loss: 0.0946
# Epoch 347/500
# 23/23 - 0s - loss: 0.0939
# Epoch 348/500
# 23/23 - 0s - loss: 0.0945
# Epoch 349/500
# 23/23 - 0s - loss: 0.0932
# Epoch 350/500
# 23/23 - 0s - loss: 0.0936
# Epoch 351/500
# 23/23 - 0s - loss: 0.0944
# Epoch 352/500
# 23/23 - 0s - loss: 0.0929
# Epoch 353/500
# 23/23 - 0s - loss: 0.0934
# Epoch 354/500
# 23/23 - 0s - loss: 0.0934
# Epoch 355/500
# 23/23 - 0s - loss: 0.0928
# Epoch 356/500
# 23/23 - 0s - loss: 0.0946
# Epoch 357/500
# 23/23 - 0s - loss: 0.0929
# Epoch 358/500
# 23/23 - 0s - loss: 0.0932
# Epoch 359/500
# 23/23 - 0s - loss: 0.0921
# Epoch 360/500
# 23/23 - 0s - loss: 0.0920
# Epoch 361/500
# 23/23 - 0s - loss: 0.0926
# Epoch 362/500
# 23/23 - 0s - loss: 0.0947
# Epoch 363/500
# 23/23 - 0s - loss: 0.0948
# Epoch 364/500
# 23/23 - 0s - loss: 0.0940
# Epoch 365/500
# 23/23 - 0s - loss: 0.0937
# Epoch 366/500
# 23/23 - 0s - loss: 0.0934
# Epoch 367/500
# 23/23 - 0s - loss: 0.0943
# Epoch 368/500
# 23/23 - 0s - loss: 0.0932
# Epoch 369/500
# 23/23 - 0s - loss: 0.0928
# Epoch 370/500
# 23/23 - 0s - loss: 0.0943
# Epoch 371/500
# 23/23 - 0s - loss: 0.0942
# Epoch 372/500
# 23/23 - 0s - loss: 0.0949
# Epoch 373/500
# 23/23 - 0s - loss: 0.0934
# Epoch 374/500
# 23/23 - 0s - loss: 0.0945
# Epoch 375/500
# 23/23 - 0s - loss: 0.0953
# Epoch 376/500
# 23/23 - 0s - loss: 0.0945
# Epoch 377/500
# 23/23 - 0s - loss: 0.0936
# Epoch 378/500
# 23/23 - 0s - loss: 0.0935
# Epoch 379/500
# 23/23 - 0s - loss: 0.0941
# Epoch 380/500
# 23/23 - 0s - loss: 0.0940
# Epoch 381/500
# 23/23 - 0s - loss: 0.0945
# Epoch 382/500
# 23/23 - 0s - loss: 0.0919
# Epoch 383/500
# 23/23 - 0s - loss: 0.0926
# Epoch 384/500
# 23/23 - 0s - loss: 0.0922
# Epoch 385/500
# 23/23 - 0s - loss: 0.0927
# Epoch 386/500
# 23/23 - 0s - loss: 0.0940
# Epoch 387/500
# 23/23 - 0s - loss: 0.0926
# Epoch 388/500
# 23/23 - 0s - loss: 0.0929
# Epoch 389/500
# 23/23 - 0s - loss: 0.0937
# Epoch 390/500
# 23/23 - 0s - loss: 0.0931
# Epoch 391/500
# 23/23 - 0s - loss: 0.0931
# Epoch 392/500
# 23/23 - 0s - loss: 0.0933
# Epoch 393/500
# 23/23 - 0s - loss: 0.0918
# Epoch 394/500
# 23/23 - 0s - loss: 0.0942
# Epoch 395/500
# 23/23 - 0s - loss: 0.0933
# Epoch 396/500
# 23/23 - 0s - loss: 0.0949
# Epoch 397/500
# 23/23 - 0s - loss: 0.0933
# Epoch 398/500
# 23/23 - 0s - loss: 0.0943
# Epoch 399/500
# 23/23 - 0s - loss: 0.0928
# Epoch 400/500
# 23/23 - 0s - loss: 0.0942
# Epoch 401/500
# 23/23 - 0s - loss: 0.0931
# Epoch 402/500
# 23/23 - 0s - loss: 0.0947
# Epoch 403/500
# 23/23 - 0s - loss: 0.0936
# Epoch 404/500
# 23/23 - 0s - loss: 0.0929
# Epoch 405/500
# 23/23 - 0s - loss: 0.0932
# Epoch 406/500
# 23/23 - 0s - loss: 0.0954
# Epoch 407/500
# 23/23 - 0s - loss: 0.0927
# Epoch 408/500
# 23/23 - 0s - loss: 0.0932
# Epoch 409/500
# 23/23 - 0s - loss: 0.0937
# Epoch 410/500
# 23/23 - 0s - loss: 0.0925
# Epoch 411/500
# 23/23 - 0s - loss: 0.0935
# Epoch 412/500
# 23/23 - 0s - loss: 0.0942
# Epoch 413/500
# 23/23 - 0s - loss: 0.0929
# Epoch 414/500
# 23/23 - 0s - loss: 0.0947
# Epoch 415/500
# 23/23 - 0s - loss: 0.0927
# Epoch 416/500
# 23/23 - 0s - loss: 0.0946
# Epoch 417/500
# 23/23 - 0s - loss: 0.0937
# Epoch 418/500
# 23/23 - 0s - loss: 0.0929
# Epoch 419/500
# 23/23 - 0s - loss: 0.0938
# Epoch 420/500
# 23/23 - 0s - loss: 0.0938
# Epoch 421/500
# 23/23 - 0s - loss: 0.0924
# Epoch 422/500
# 23/23 - 0s - loss: 0.0945
# Epoch 423/500
# 23/23 - 0s - loss: 0.0924
# Epoch 424/500
# 23/23 - 0s - loss: 0.0927
# Epoch 425/500
# 23/23 - 0s - loss: 0.0932
# Epoch 426/500
# 23/23 - 0s - loss: 0.0945
# Epoch 427/500
# 23/23 - 0s - loss: 0.0930
# Epoch 428/500
# 23/23 - 0s - loss: 0.0938
# Epoch 429/500
# 23/23 - 0s - loss: 0.0937
# Epoch 430/500
# 23/23 - 0s - loss: 0.0950
# Epoch 431/500
# 23/23 - 0s - loss: 0.0925
# Epoch 432/500
# 23/23 - 0s - loss: 0.0929
# Epoch 433/500
# 23/23 - 0s - loss: 0.0937
# Epoch 434/500
# 23/23 - 0s - loss: 0.0937
# Epoch 435/500
# 23/23 - 0s - loss: 0.0931
# Epoch 436/500
# 23/23 - 0s - loss: 0.0925
# Epoch 437/500
# 23/23 - 0s - loss: 0.0944
# Epoch 438/500
# 23/23 - 0s - loss: 0.0927
# Epoch 439/500
# 23/23 - 0s - loss: 0.0937
# Epoch 440/500
# 23/23 - 0s - loss: 0.0926
# Epoch 441/500
# 23/23 - 0s - loss: 0.0933
# Epoch 442/500
# 23/23 - 0s - loss: 0.0932
# Epoch 443/500
# 23/23 - 0s - loss: 0.0943
# Epoch 444/500
# 23/23 - 0s - loss: 0.0935
# Epoch 445/500
# 23/23 - 0s - loss: 0.0923
# Epoch 446/500
# 23/23 - 0s - loss: 0.0920
# Epoch 447/500
# 23/23 - 0s - loss: 0.0946
# Epoch 448/500
# 23/23 - 0s - loss: 0.0929
# Epoch 449/500
# 23/23 - 0s - loss: 0.0927
# Epoch 450/500
# 23/23 - 0s - loss: 0.0927
# Epoch 451/500
# 23/23 - 0s - loss: 0.0942
# Epoch 452/500
# 23/23 - 0s - loss: 0.0930
# Epoch 453/500
# 23/23 - 0s - loss: 0.0907
# Epoch 454/500
# 23/23 - 0s - loss: 0.0920
# Epoch 455/500
# 23/23 - 0s - loss: 0.0933
# Epoch 456/500
# 23/23 - 0s - loss: 0.0941
# Epoch 457/500
# 23/23 - 0s - loss: 0.0927
# Epoch 458/500
# 23/23 - 0s - loss: 0.0934
# Epoch 459/500
# 23/23 - 0s - loss: 0.0944
# Epoch 460/500
# 23/23 - 0s - loss: 0.0935
# Epoch 461/500
# 23/23 - 0s - loss: 0.0933
# Epoch 462/500
# 23/23 - 0s - loss: 0.0928
# Epoch 463/500
# 23/23 - 0s - loss: 0.0941
# Epoch 464/500
# 23/23 - 0s - loss: 0.0927
# Epoch 465/500
# 23/23 - 0s - loss: 0.0929
# Epoch 466/500
# 23/23 - 0s - loss: 0.0934
# Epoch 467/500
# 23/23 - 0s - loss: 0.0938
# Epoch 468/500
# 23/23 - 0s - loss: 0.0916
# Epoch 469/500
# 23/23 - 0s - loss: 0.0939
# Epoch 470/500
# 23/23 - 0s - loss: 0.0943
# Epoch 471/500
# 23/23 - 0s - loss: 0.0934
# Epoch 472/500
# 23/23 - 0s - loss: 0.0931
# Epoch 473/500
# 23/23 - 0s - loss: 0.0925
# Epoch 474/500
# 23/23 - 0s - loss: 0.0922
# Epoch 475/500
# 23/23 - 0s - loss: 0.0923
# Epoch 476/500
# 23/23 - 0s - loss: 0.0923
# Epoch 477/500
# 23/23 - 0s - loss: 0.0928
# Epoch 478/500
# 23/23 - 0s - loss: 0.0946
# Epoch 479/500
# 23/23 - 0s - loss: 0.0923
# Epoch 480/500
# 23/23 - 0s - loss: 0.0929
# Epoch 481/500
# 23/23 - 0s - loss: 0.0939
# Epoch 482/500
# 23/23 - 0s - loss: 0.0911
# Epoch 483/500
# 23/23 - 0s - loss: 0.0922
# Epoch 484/500
# 23/23 - 0s - loss: 0.0920
# Epoch 485/500
# 23/23 - 0s - loss: 0.0929
# Epoch 486/500
# 23/23 - 0s - loss: 0.0928
# Epoch 487/500
# 23/23 - 0s - loss: 0.0936
# Epoch 488/500
# 23/23 - 0s - loss: 0.0930
# Epoch 489/500
# 23/23 - 0s - loss: 0.0931
# Epoch 490/500
# 23/23 - 0s - loss: 0.0924
# Epoch 491/500
# 23/23 - 0s - loss: 0.0923
# Epoch 492/500
# 23/23 - 0s - loss: 0.0937
# Epoch 493/500
# 23/23 - 0s - loss: 0.0931
# Epoch 494/500
# 23/23 - 0s - loss: 0.0915
# Epoch 495/500
# 23/23 - 0s - loss: 0.0921
# Epoch 496/500
# 23/23 - 0s - loss: 0.0928
# Epoch 497/500
# 23/23 - 0s - loss: 0.0948
# Epoch 498/500
# 23/23 - 0s - loss: 0.0924
# Epoch 499/500
# 23/23 - 0s - loss: 0.0927
# Epoch 500/500
# 23/23 - 0s - loss: 0.0925

# %%
predictions = model.predict(predict_set)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 2251, 7) for input KerasTensor(type_spec=TensorSpec(shape=(None, 2251, 7), dtype=tf.float32, name='simple_rnn_2_input'), name='simple_rnn_2_input', description="created by layer 'simple_rnn_2_input'"), but it was called on an input with incompatible shape (None, 1, 7).

# %%
predictions = scaler_y.inverse_transform(predictions)

# %%
predict_set = pd.read_csv('dataset_for_prediction.csv')
predict_set['date'] = pd.to_datetime(predict_set['date'], infer_datetime_format=True)
predict_set.set_index('date', inplace=True)
predict_set['demand'] = predictions
predict_set.head()
# Out:
#                    demand        RRP  min_temperature  max_temperature  \
# date
# 2021-03-01  136349.562500  16.113191        12.506416           20.844
# 2021-03-02  124294.718750  20.828125        12.016535           20.244
# 2021-03-03  128100.718750  24.979167        11.526654           19.144
# 2021-03-04  138666.312500  24.135417        11.036772           16.892
# 2021-03-05  161233.515625  21.580625        10.546891           16.680
#
#             solar_exposure   rainfall school_day holiday
# date
# 2021-03-01       14.810004   1.000000          Y       N
# 2021-03-02       15.744815   1.000000          Y       N
# 2021-03-03       15.494148   1.733333          Y       N
# 2021-03-04       13.976392  12.800000          Y       N
# 2021-03-05       13.893853  32.700000          Y       N

# %%
dataset.head()
# Out:
#                 demand        RRP  min_temperature  max_temperature  \
# date
# 2015-01-01   99635.030  25.633696             13.3         5.186521
# 2015-01-02  129606.010  33.138988             15.4         6.228965
# 2015-01-03  142300.540  34.564855             20.0         6.180615
# 2015-01-04  104330.715  25.005560             16.3         4.626013
# 2015-01-05  118132.200  26.724176             15.0         4.690416
#
#             solar_exposure  rainfall  school_day  holiday
# date
# 2015-01-01        0.000000       0.0           0        1
# 2015-01-02        0.880597       0.0           0        0
# 2015-01-03        1.011321       0.0           0        0
# 2015-01-04        1.051587       4.2           0        0
# 2015-01-05        0.820847       0.0           0        0

# %%
#Real vs predicted Energy Consumption (Jan 2015 - Aug 2021)
sns.set(rc={'figure.figsize':(15,10)})
plt.plot(dataset['demand'], color='red')
plt.plot(predict_set['demand'], color='black')
plt.legend(['Real Energy Consumption','Predicted Energy Consumption'])
plt.title("Original and Predicted values for Energy Consumption from Jan 2015 to Aug 2021")
plt.show()

# %%
#Real vs predicted Energy Consumption (Jan 2020 - Aug 2021)
sns.set(rc={'figure.figsize':(15,10)})
plt.plot(dataset['demand'][-424:], color='red')
plt.plot(predict_set['demand'], color='black')
plt.legend(['Real Energy Consumption','Predicted Energy Consumption'])
plt.title("Original and Predicted values for Energy Consumption from Jan 2021 to Aug 2021")
plt.show()

# %%
#Dot graph with connected lines to visualise spread of data
dataset['demand'][-424:].plot(color = 'red', marker = 'o')
predict_set['demand'].plot(color = 'black', marker = 'o')
plt.legend(['Real Energy Consumption','Predicted Energy Consumption'])
plt.title("Original and Predicted values for Energy Consumption from Jan 2021 to Aug 2021")
# Out:
# Text(0.5, 1.0, 'Original and Predicted values for Energy Consumption from Jan 2021 to Aug 2021')
