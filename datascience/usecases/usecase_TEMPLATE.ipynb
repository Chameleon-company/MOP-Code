# %% [markdown]
# _**DELETE BEFORE PUBLISHING**_
#
# _This is the MOP usecase template and style guide. The styling uses the usecase CSS when uploaded to the website, which will not be visible on your local machine unless the fonts below are installed._
#
# _Change any text marked with {} and delete any cells marked DELETE._
#
# _**Rules for this template**_
# - _Every section heading must be numbered automatically (no need to type numbers yourself) — sections are numbered 1., 2., 3.; subsections 1.1., 1.2.; sub-subsections 1.1.1., 1.1.2. etc._
# - _Every heading (at any level) must have a one-line description directly underneath it, before any other content — use the `usecase-heading-description` style shown below._
# - _A contents page is required, placed after Key Takeaways and before your actual analysis/code content begins._
# - _The MOP logo does not need to be included in the usecase itself — it will already appear on the website page. Do not include a logo image here._
# - _See the Example section below for exact structuring, numbering and descriptions should look in practice._
#
# ***

# %%
# WEB DEV TEAM PLEASE DELETE BEFORE PUBLISHING - DS TEAM PLEASE KEEP IN THE FINAL VERSION OF THE USE CASE

from IPython.core.display import HTML
HTML("""
<style>
@import url('https://fonts.googleapis.com/css2?family=Poppins:wght@600;700&family=Inter:wght@400;500&display=swap');

/* Global Fonts and Counters */
body, p, li, div {
    font-family: 'Inter', sans-serif;
}

body {
    counter-reset: h2counter;
}

/* Header Fonts */
.usecase-title,
.usecase-section-header,
.usecase-sub-section-header,
.usecase-sub-sub-section-header,
.usecase-unnumbered-header,
.usecase-subsection-description {
    font-family: 'Poppins', sans-serif;
}

.usecase-title {
    font-size: 1.7em;
    font-weight: 700;
}

/* Metadata Styling */
.usecase-details {
    padding-left: 20px;
    padding-bottom: 8px;
    padding-top: 8px;
    background-color: rgba(5, 150, 105, 0.08);
    font-size: 1.1em;
    color: #121212;
}

.usecase-details-flex {
    display: flex;
}

.usecase-details-flex > div {
    width: 50%;
}

/* Base styling for all main headers (Numbered & Unnumbered) */
.usecase-section-header, 
.usecase-unnumbered-header {
    font-weight: 700;
    font-size: 1.35em;
    color: #059669;
    padding: 14px 4px 6px 4px;
    border-bottom: 3px solid #2DBE6C;
    margin-top: 10px;
}

/* Level 1 - numbered sections specifically (e.g. 1. ) */
.usecase-section-header {
    counter-increment: h2counter;
    counter-reset: h3counter;
}

.usecase-section-header::before {
    content: counter(h2counter) ". ";
}

/* Level 2 - numbered subsections (e.g. 1.1. ) */
.usecase-sub-section-header {
    font-weight: 600;
    font-size: 1.15em;
    color: #1F8F50;
    margin-top: 8px;
    counter-increment: h3counter;
    counter-reset: h4counter;
}

.usecase-sub-section-header::before {
    content: counter(h2counter) "." counter(h3counter) ". ";
}

/* Level 3 - numbered sub-subsections (e.g. 1.1.1. ) */
.usecase-sub-sub-section-header {
    font-weight: 600;
    font-size: 1.05em;
    color: #15803D;
    margin-top: 6px;
    counter-increment: h4counter;
}

.usecase-sub-sub-section-header::before {
    content: counter(h2counter) "." counter(h3counter) "." counter(h4counter) ". ";
}

/* Required description line under every heading */
.usecase-heading-description {
    font-style: italic;
    font-size: 0.95em;
    color: rgba(18, 18, 18, 0.65);
    margin-bottom: 8px;
}

.usecase-subsection-description {
    font-weight: 600;
    font-size: 1em;
    font-style: italic;
    color: #1F8F50;
}

/* Body */
.usecase-body {
    font-size: 1em;
    color: #121212;
    line-height: 1.6;
    margin-bottom: 8px;
}

/* Generic list styling */
.usecase-list {
    line-height: 1.7;
}

.usecase-list ul, .usecase-list ol {
    padding-left: 24px;
    margin-top: 8px;
    margin-bottom: 12px;
}

.usecase-list li {
    margin-bottom: 6px;
}

/* Datasets specific list box */
.usecase-datasets {
    background-color: rgba(5, 150, 105, 0.06);
    border-left: 4px solid #059669;
    padding: 12px 20px;
    border-radius: 0 4px 4px 0;
    margin-top: 12px;
}

.usecase-datasets ul {
    margin-top: 8px;
    margin-bottom: 8px;
}

/* Link styles for both TOC and Datasets */
.usecase-contents a, 
.usecase-datasets a {
    color: #059669;
    text-decoration: none;
}

.usecase-datasets a {
    font-weight: 500;
}

.usecase-contents a:hover, 
.usecase-datasets a:hover {
    text-decoration: underline;
}

/* TOC Container */
.usecase-contents {
    line-height: 1.9;
    padding-left: 20px;
}

/* Content Divider */
.usecase-code-divider {
    font-style: italic;
    color: rgba(18, 18, 18, 0.65);
    background-color: rgba(5, 150, 105, 0.06);
    padding: 10px 16px;
    border-radius: 4px;
    margin-top: 14px;
}
</style>

""")

# %% [markdown]
# _****Usecase Template****_
#   <div class="usecase-title">{usecase Name}</div>
#
# <div class="usecase-details"><b>Authored by: </b> {Author/s}</div>
# <div class="usecase-details"><b>Date Created: </b> {Trimester #, YYYY}</div>

# %% [markdown]
# <div class="usecase-details"><b>Time to Complete:</b> {90} mins</div>
#
# <div class="usecase-details usecase-details-flex">
#     <div><b>Level: </b>{Intermediate}</div>
#     <div><b>Pre-requisite Skills: </b>{Python, and add any more skills needed/ not skills that will be taught throughout this use case}</div>
# </div>

# %% [markdown]
# <div id="scenario" class="usecase-unnumbered-header"><b>Scenario</b></div>

# %% [markdown]
# {Using User Story format, write a description of the problem you are trying to solve for this usecase.}

# %% [markdown]
# <div id="what-this-teaches" class="usecase-unnumbered-header"><b>What this usecase will teach you</b></div>

# %% [markdown]
# <div class="usecase-heading-description">{Description of what this usecase will teach the user.}</div>
#
# <div class="usecase-list">
#
# - {Learning outcome 1}
# - {Learning outcome 2}
# - {Learning outcome 3}
#
# </div>

# %% [markdown]
# <div id="background" class="usecase-unnumbered-header"><b>Background</b></div>

# %% [markdown]
# {Write your usecase background here. Keep it concise. We're not after "War and Peace" but enough background information to inform the reader on the rationale for solving this problem or background non-technical information that helps explain the approach.}

# %% [markdown]
# <div id="data-sets" class="usecase-unnumbered-header"><b>Data Sets</b></div>

# %% [markdown]
# <div class="usecase-heading-description">{List your datasets here and links to them either in the Melbourne Open Data Platform or to where they are stored in the dependency folder/ what website you sourced them from. You may also add a short description below about the dataset.}</div>

# %% [markdown]
# <div class="usecase-datasets">
#
# - {Dataset 1 - LINK}
# - {Dataset 2 - LINK}
# - {Dataset 3 - LINK}
#
# </div>

# %% [markdown]
# <div class="usecase-unnumbered-header"><b>Contents</b></div>

# %% [markdown]
# _Update this list to match the actual numbered headings in your notebook once your content is finalised. Use anchor tags pointing to your section `id`s to make them clickable (see Style Guide Reference for details)._
#
# <div class="usecase-contents">
#
# 1. <a href="#section-1">{Your first analysis section heading}</a>
# 2. <a href="#section-2">{Your next analysis section heading}</a>
# 3. <a href="#section-3">{Your next analysis section heading}</a>
# 4. <a href="#section-4">{Your next analysis section heading}</a>
# 5. <a href="#section-5">{Your next analysis section heading}</a>
#   - 5.1. <a href="#subsection-5-1">{Subsection}</a>
# 6. <a href="#section-6">{Your next analysis section heading}</a>
#
# </div>

# %% [markdown]
# <div class="usecase-code-divider">Your notebook's analysis and code content begins below. Start the numbering shown in the Contents page above, including subsections (e.g. 5.1.) and sub-subsections (e.g. 5.1.1.) where needed.</div>

# %% [markdown]
# <div id="conclusion" class="usecase-unnumbered-header"><b>Conclusion</b></div>

# %% [markdown]
# <div class="usecase-heading-description">{Summary of what was achieved and learned from this analysis, along with observations for further opportunities.}</div>

# %% [markdown]
# **What we achieved in this analysis**
# {Add an explanation of your achievements here}
#
# **What we learned from this analysis**
# {Add an explanation of your learnings here}
#
# **Observations for further opportunities**
# {Add an explanation of further opportunities here}

# %% [markdown]
# ***
#
# _**DELETE BEFORE PUBLISHING**_
#
# ## Style guide reference
#
# ### Headers
#
# Use the HTML classes shown throughout the example above and defined in the CSS cell:
#
# - `usecase-title` for the main title of the usecase
# - `usecase-details` for the date, duration, level, author, and skill metadata fields
# - `usecase-section-header` for numbered top-level sections (1., 2., 3.)
# - `usecase-sub-section-header` for numbered subsections (1.1., 1.2.)
# - `usecase-sub-sub-section-header` for numbered sub-subsections (1.1.1.) — only use this if a subsection genuinely needs breaking down further
# - `usecase-subsection-description` for an italicised note or callout, not counted in the numbering
# - `usecase-heading-description` directly underneath **every** heading at any level — this is required, not optional
# - `usecase-datasets` for highlighting the list of data sets used in the analysis
# - `usecase-list` for wrapping standard bulleted or numbered lists to ensure proper spacing and font
# - `usecase-unnumbered-header` for unnumbered headings at the start and end of the use case (e.g., Scenario, Background, Contents, Conclusion)
# - `usecase-contents` for the contents page
# - `usecase-code-divider` for the block separating template intro from code
# - `usecase-body` for any general body of text
#
# ### Clickable Table of Contents
#
# To ensure users can click the Contents list and jump to the relevant section, do the following:
#
# 1. **Add a unique ID to your section header tag:** `<div id="my-section" class="usecase-section-header"><b>Header Title</b></div>`
# 2. **Wrap your contents list item in an anchor tag pointing to that ID:** `<a href="#my-section">Header Title</a>`
#
# ## Plot colour schemes
# Use the same colour (Primary Green) or the colour palette below, in order throughout your notebook, unless there are more than 6 colours in your plot, then you can add other colours that are distinct to the ones below.
#
# <div style="text-align: left;">
#
# | Colour | Hex |
# |-----|-----|
# |<p style="color:#059669;">Primary Green</p>|#059669|
# |<p style="color:#9333EA;">Distinct Purple</p>|#9333EA|
# |<p style="color:#F97316;">Distinct Orange</p>|#F97316|
# |<p style="color:#2563EB;">Distinct Blue</p>|#2563EB|
# |<p style="color:#EAB308;">Distinct Yellow</p>|#EAB308|
# |<p style="color:#EC4899;">Distinct Pink</p>|#EC4899|
#
# </div>
