# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from tabulate import tabulate
import folium
from folium import plugins

# %%
data = pd.read_csv('data_cafe.csv',index_col=0)
data.head(10)
# Out:
#    clue_small_area                      industry_anzsic4_description  \
# 0        Docklands                             Cafes and Restaurants
# 1        Docklands                             Cafes and Restaurants
# 2  North Melbourne                            Takeaway Food Services
# 3  North Melbourne                Non-Residential Property Operators
# 4  North Melbourne                            Takeaway Food Services
# 5  North Melbourne                            Takeaway Food Services
# 6       Kensington                             Cafes and Restaurants
# 7       Kensington                             Cafes and Restaurants
# 8       Kensington  Bakery Product Manufacturing (Non-factory based)
# 9       Kensington                             Cafes and Restaurants
#
#    number_of_seats   longitude   latitude
# 0               54  144.936589 -37.811859
# 1               34  144.952479 -37.822884
# 2               10  144.940961 -37.789743
# 3              300  144.936687 -37.794859
# 4               10  144.941404 -37.795017
# 5                8  144.941404 -37.795017
# 6               80  144.928633 -37.794042
# 7               54  144.928763 -37.794054
# 8                6  144.929314 -37.794092
# 9               50  144.930179 -37.794260

# %%
#Checking dataset:
data.isna().sum()
# Out:
# clue_small_area                 0
# industry_anzsic4_description    0
# number_of_seats                 0
# longitude                       0
# latitude                        0
# dtype: int64

# %%
final = (data.loc[data['industry_anzsic4_description']=='Cafes and Restaurants']
         .groupby(['clue_small_area','industry_anzsic4_description'])
         .agg({'number_of_seats':'sum','longitude':'mean','latitude':'mean'})
         .reset_index()
        )

# %%
final.head(10)
# Out:
#          clue_small_area industry_anzsic4_description  number_of_seats  \
# 0                Carlton        Cafes and Restaurants            13294
# 1              Docklands        Cafes and Restaurants            13407
# 2         East Melbourne        Cafes and Restaurants             5429
# 3             Kensington        Cafes and Restaurants             1041
# 4        Melbourne (CBD)        Cafes and Restaurants            66452
# 5  Melbourne (Remainder)        Cafes and Restaurants             2765
# 6        North Melbourne        Cafes and Restaurants             3247
# 7              Parkville        Cafes and Restaurants             2340
# 8         Port Melbourne        Cafes and Restaurants              935
# 9            South Yarra        Cafes and Restaurants              682
#
#     longitude   latitude
# 0  144.966085 -37.800992
# 1  144.945594 -37.818142
# 2  144.981429 -37.812974
# 3  144.927706 -37.791884
# 4  144.963550 -37.813519
# 5  144.979236 -37.839969
# 6  144.951079 -37.802489
# 7  144.954590 -37.791788
# 8  144.916663 -37.825455
# 9  144.981562 -37.834691

# %%
final['clue_small_area'].unique()
# Out:
# array(['Carlton', 'Docklands', 'East Melbourne', 'Kensington',
#        'Melbourne (CBD)', 'Melbourne (Remainder)', 'North Melbourne',
#        'Parkville', 'Port Melbourne', 'South Yarra', 'Southbank',
#        'West Melbourne (Residential)'], dtype=object)

# %%
# Importing Dwelling dataset.
dataD = pd.read_csv('Dwelling_modelling_final.csv')
dataD = dataD.drop(['Unnamed: 0'], axis =1)
dataD.head(10)
# Out:
#   clue_small_area  year  Total_Dwelling
# 0         Carlton  2002              47
# 1         Carlton  2003             754
# 2         Carlton  2004              58
# 3         Carlton  2005             394
# 4         Carlton  2006             310
# 5         Carlton  2007             676
# 6         Carlton  2008             173
# 7         Carlton  2009             291
# 8         Carlton  2010              35
# 9         Carlton  2011             279

# %%
dataD['year'] = pd.to_datetime(dataD['year'],format=('%Y'),exact ='False')

# %%
dwelling= (dataD.loc[dataD['year'].dt.year== 2022]).reset_index()

# %%
dwelling.head(10)
# Out:
#    index               clue_small_area       year  Total_Dwelling
# 0     20                       Carlton 2022-01-01            1065
# 1     41                     Docklands 2022-01-01             344
# 2     55                East Melbourne 2022-01-01               0
# 3     74                    Kensington 2022-01-01             146
# 4     96               Melbourne (CBD) 2022-01-01             724
# 5    127               North Melbourne 2022-01-01              16
# 6    164                Port Melbourne 2022-01-01               0
# 7    190                     Southbank 2022-01-01            1994
# 8    218  West Melbourne (Residential) 2022-01-01             704

# %%
def graph_dwelling(data):
    '''
        using seaborn to visualise the dwelling data
    '''
    ax = sns.barplot(
    y='Total_Dwelling',
    x = 'clue_small_area',
    data = data
    
        )
    warnings.filterwarnings('ignore')
    sns.set_style("darkgrid")
    plt.xticks(rotation =90)
    plt.title('Total number of Dwelling for Melbourne')
    plt.show()
   
    total = np.array(data['Total_Dwelling'].sum())
    data['Percentage %']= np.round((data['Total_Dwelling']/total)*100,2)
    temp =data.loc[:,['clue_small_area','Percentage %']]
    
    print('The Percentage of growth per suburb is displaying below:')
    print()
    print(temp.sort_values(by='Percentage %',ascending = False))
#graph_dwelling(dwelling)

# %%
graph_dwelling(dwelling)
# Out:
# The Percentage of growth per suburb is displaying below:
#
#                 clue_small_area  Percentage %
# 7                     Southbank         39.94
# 0                       Carlton         21.33
# 4               Melbourne (CBD)         14.50
# 8  West Melbourne (Residential)         14.10
# 1                     Docklands          6.89
# 3                    Kensington          2.92
# 5               North Melbourne          0.32
# 2                East Melbourne          0.00
# 6                Port Melbourne          0.00

# %%
def graph_cafe(data):
    '''
        using seaborn to visualise the dwelling data
    '''
    ax = sns.barplot(
    y='number_of_seats',
    x = 'clue_small_area',
    data = data
    
        )
    warnings.filterwarnings('ignore')
    sns.set_style("darkgrid")
    plt.xticks(rotation =90)
    plt.show()
    
    total = np.array(data['number_of_seats'].sum())
    data['Percentage %']= np.round((data['number_of_seats']/total)*100,2)
    temp =data.loc[:,['clue_small_area','Percentage %']]
    
    print('The Percentage of cafe in each area:')
    print()
    print(temp.sort_values(by='Percentage %',ascending = True))

# %%
graph_cafe(final)
# Out:
# The Percentage of cafe in each area:
#
#                  clue_small_area  Percentage %
# 9                    South Yarra          0.53
# 8                 Port Melbourne          0.73
# 3                     Kensington          0.81
# 11  West Melbourne (Residential)          1.06
# 7                      Parkville          1.83
# 5          Melbourne (Remainder)          2.16
# 6                North Melbourne          2.53
# 2                 East Melbourne          4.24
# 0                        Carlton         10.37
# 1                      Docklands         10.46
# 10                     Southbank         13.42
# 4                Melbourne (CBD)         51.85

# %% [markdown]
# ## Observations:
# - From the two gaph above, South bank and Carlton stands out as area of growth for 2022.
# - From the second bar, South bank and Carlton stands out once more as the a potential for a new cafe
# due to the low number of cafe present combared to the wider Melbourne.

# %% [markdown]
# ## Merging the two dataset to obtain new information.
# - Producing a table containing the number of seat / dwelling for each suburb.
# - Drop the rows:  'Melbourne(remainder),Parkville , South Yarra they are missing in the Dwelling data set.

# %%
final.head(3)
# Out:
#   clue_small_area industry_anzsic4_description  number_of_seats   longitude  \
# 0         Carlton        Cafes and Restaurants            13294  144.966085
# 1       Docklands        Cafes and Restaurants            13407  144.945594
# 2  East Melbourne        Cafes and Restaurants             5429  144.981429
#
#     latitude  Percentage %
# 0 -37.800992         10.37
# 1 -37.818142         10.46
# 2 -37.812974          4.24

# %%
final =final.drop([5,7,9])

# %%
final = final.sort_values('clue_small_area').reset_index(drop = True)

# %%
dwelling.sort_values('clue_small_area')
# Out:
#    index               clue_small_area       year  Total_Dwelling  \
# 0     20                       Carlton 2022-01-01            1065
# 1     41                     Docklands 2022-01-01             344
# 2     55                East Melbourne 2022-01-01               0
# 3     74                    Kensington 2022-01-01             146
# 4     96               Melbourne (CBD) 2022-01-01             724
# 5    127               North Melbourne 2022-01-01              16
# 6    164                Port Melbourne 2022-01-01               0
# 7    190                     Southbank 2022-01-01            1994
# 8    218  West Melbourne (Residential) 2022-01-01             704
#
#    Percentage %
# 0         21.33
# 1          6.89
# 2          0.00
# 3          2.92
# 4         14.50
# 5          0.32
# 6          0.00
# 7         39.94
# 8         14.10

# %%
final['seat/Dwelling'] = np.round((final['number_of_seats']/dwelling['Total_Dwelling']),2)

# %%
final.sort_values('seat/Dwelling',ascending = True).head(10)
# Out:
#                 clue_small_area industry_anzsic4_description  number_of_seats  \
# 8  West Melbourne (Residential)        Cafes and Restaurants             1360
# 3                    Kensington        Cafes and Restaurants             1041
# 7                     Southbank        Cafes and Restaurants            17198
# 0                       Carlton        Cafes and Restaurants            13294
# 1                     Docklands        Cafes and Restaurants            13407
# 4               Melbourne (CBD)        Cafes and Restaurants            66452
# 5               North Melbourne        Cafes and Restaurants             3247
# 2                East Melbourne        Cafes and Restaurants             5429
# 6                Port Melbourne        Cafes and Restaurants              935
#
#     longitude   latitude  Percentage %  seat/Dwelling
# 8  144.950661 -37.807716          1.06           1.93
# 3  144.927706 -37.791884          0.81           7.13
# 7  144.961741 -37.823605         13.42           8.62
# 0  144.966085 -37.800992         10.37          12.48
# 1  144.945594 -37.818142         10.46          38.97
# 4  144.963550 -37.813519         51.85          91.78
# 5  144.951079 -37.802489          2.53         202.94
# 2  144.981429 -37.812974          4.24            inf
# 6  144.916663 -37.825455          0.73            inf

# %% [markdown]
# ## Visualising using folium

# %%
m = folium.Map([-37.8105, 144.9624], zoom_start=13)
for index, row in final.iterrows():
    if row['seat/Dwelling'] >= 150:
        marker_color = 'darkred'
        fill_color = 'darkred'
        
    elif row['seat/Dwelling'] >= 100:
        marker_color = 'darkred'
        fill_color = 'red'
    elif row['seat/Dwelling'] >= 50:
        marker_color = 'darkred'
        fill_color = 'lightred'
    elif row['seat/Dwelling'] >= 10:
        marker_color = 'darkred'
        fill_color = 'orange'
    else:
        marker_color='darkred'
        fill_color = 'darkpurple'

        
    folium.Circle(
              location=[row['latitude'], row['longitude']],
              popup= 'Clients:' +str(row['seat/Dwelling']),
              tooltip=row['clue_small_area'],
              radius=row['seat/Dwelling']*10,
              color=marker_color,
              fill=True,
              fill_color=fill_color,
           ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ccc47c35f7a03cfd8ae8e8ea7aec8fda {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ccc47c35f7a03cfd8ae8e8ea7aec8fda&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ccc47c35f7a03cfd8ae8e8ea7aec8fda = L.map(
#                 &quot;map_ccc47c35f7a03cfd8ae8e8ea7aec8fda&quot;,
#                 {
#                     center: [-37.8105, 144.9624],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_006bd8539610ab512b3d1b50662f321e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ccc47c35f7a03cfd8ae8e8ea7aec8fda);
#
#
#             var circle_bb8430e780542d0e9c0e66ab2aa730a3 = L.circle(
#                 [-37.80099163315519, 144.96608468382195],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 124.80000000000001, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ccc47c35f7a03cfd8ae8e8ea7aec8fda);
#
#
#         var popup_69f2dea8e900437ff127a4aec75c5a16 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ff21e5974adbc3373cf4237d6d0030df = $(`&lt;div id=&quot;html_ff21e5974adbc3373cf4237d6d0030df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Clients:12.48&lt;/div&gt;`)[0];
#                 popup_69f2dea8e900437ff127a4aec75c5a16.setContent(html_ff21e5974adbc3373cf4237d6d0030df);
#
#
#
#         circle_bb8430e780542d0e9c0e66ab2aa730a3.bindPopup(popup_69f2dea8e900437ff127a4aec75c5a16)
#         ;
#
#
#
#
#             circle_bb8430e780542d0e9c0e66ab2aa730a3.bindTooltip(
#                 `&lt;div&gt;
#                      Carlton
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_9c77af06cb7cc8d8e8abeffc87305179 = L.circle(
#                 [-37.818142222364365, 144.94559423359516],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 389.7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ccc47c35f7a03cfd8ae8e8ea7aec8fda);
#
#
#         var popup_3a03604765a41328226146156401225a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_47e2c1d9840a3a56d48242e2cd4aac87 = $(`&lt;div id=&quot;html_47e2c1d9840a3a56d48242e2cd4aac87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Clients:38.97&lt;/div&gt;`)[0];
#                 popup_3a03604765a41328226146156401225a.setContent(html_47e2c1d9840a3a56d48242e2cd4aac87);
#
#
#
#         circle_9c77af06cb7cc8d8e8abeffc87305179.bindPopup(popup_3a03604765a41328226146156401225a)
#         ;
#
#
#
#
#             circle_9c77af06cb7cc8d8e8abeffc87305179.bindTooltip(
#                 `&lt;div&gt;
#                      Docklands
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_8305aa7f1f702aab890bb3bbb5cb7b16 = L.circle(
#                 [-37.81297418224491, 144.98142945751502],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: Infinity, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ccc47c35f7a03cfd8ae8e8ea7aec8fda);
#
#
#         var popup_c93edc2b6e4fa3061a18c32f0441d22f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b1f6bf59be0fa6cc35ab5a7591076be1 = $(`&lt;div id=&quot;html_b1f6bf59be0fa6cc35ab5a7591076be1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Clients:inf&lt;/div&gt;`)[0];
#                 popup_c93edc2b6e4fa3061a18c32f0441d22f.setConten

# %%
n = folium.Map([-37.8105, 144.9624], zoom_start=11)
locations =list(zip(final['latitude'],final['longitude']))
cluster = plugins.MarkerCluster(locations =locations,
                               popus =final['seat/Dwelling'].tolist())
n.add_child(cluster)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb0beaef03d5d4379e116b3b9efa001f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb0beaef03d5d4379e116b3b9efa001f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb0beaef03d5d4379e116b3b9efa001f = L.map(
#                 &quot;map_cb0beaef03d5d4379e116b3b9efa001f&quot;,
#                 {
#                     center: [-37.8105, 144.9624],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0fd860b4bb5bc7ed2d10e058f97f377c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cb0beaef03d5d4379e116b3b9efa001f);
#
#
#             var marker_cluster_165f07027fbd02e7e662136ae5518ee8 = L.markerClusterGroup(
#                 {&quot;popus&quot;: [12.48, 38.97, Infinity, 7.13, 91.78, 202.94, Infinity, 8.62, 1.93]}
#             );
#             map_cb0beaef03d5d4379e116b3b9efa001f.addLayer(marker_cluster_165f07027fbd02e7e662136ae5518ee8);
#
#
#             var marker_9b902becb6bf411f9a7f3ca7ee6b9303 = L.marker(
#                 [-37.80099163315519, 144.96608468382195],
#                 {}
#             ).addTo(marker_cluster_165f07027fbd02e7e662136ae5518ee8);
#
#
#             var marker_3ef011964ec418b82c781a9ad44cc672 = L.marker(
#                 [-37.818142222364365, 144.94559423359516],
#                 {}
#             ).addTo(marker_cluster_165f07027fbd02e7e662136ae5518ee8);
#
#
#             var marker_9d775054be979950751dac212c74dd63 = L.marker(
#                 [-37.81297418224491, 144.98142945751502],
#                 {}
#             ).addTo(marker_cluster_165f07027fbd02e7e662136ae5518ee8);
#
#
#             var marker_7fd184961520b398308a53ab5987ac7a = L.marker(
#                 [-37.79188356556477, 144.9277061543456],
#                 {}
#             ).addTo(marker_cluster_165f07027fbd02e7e662136ae5518ee8);
#
#
#             var marker_0f6d39496997dbcdb64d20236a1b64fa = L.marker(
#                 [-37.81351936722431, 144.96355022181265],
#                 {}
#             ).addTo(marker_cluster_165f07027fbd02e7e662136ae5518ee8);
#
#
#             var marker_994ced70f9467480d1b1a0cd01f93a65 = L.marker(
#                 [-37.80248881156454, 144.95107941519345],
#                 {}
#             ).addTo(marker_cluster_165f07027fbd02e7e662136ae5518ee8);
#
#
#             var marker_fa2912bc0348b2351a5b5c855924988c = L.marker(
#                 [-37.825455136748424, 144.9166625981464],
#                 {}
#             ).addTo(marker_cluster_165f07027fbd02e7e662136ae5518ee8);
#
#
#             var marker_85421362f36535a2e6dcd9c1025afbd8 = L.marker(
#                 [-37.82360469996121, 144.9617413627295],
#                 {}
#             ).addTo(marker_cluster_165f07027fbd02e7e662136ae5518ee8);
#
#
#             var marker_daed5ec718ab40a87f6ad469e60ce30d = L.marker(
#                 [-37.8077162984126, 144.95066071635426],
#                 {}
#             ).addTo(marker_cluster_165f07027fbd02e7e662136ae5518ee8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
f =folium.Map([-37.8105, 144.9624], zoom_start=13)
for index, row in final.iterrows():
    folium.Marker([row['latitude'], row['longitude']],
                      popup=row['clue_small_area'],
                      tooltip=[row['clue_small_area'], row['seat/Dwelling']]           
                 ).add_to(f)

        
f
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_acb3e2402cf4fa4e8f8a86ef766d2133 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_acb3e2402cf4fa4e8f8a86ef766d2133&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_acb3e2402cf4fa4e8f8a86ef766d2133 = L.map(
#                 &quot;map_acb3e2402cf4fa4e8f8a86ef766d2133&quot;,
#                 {
#                     center: [-37.8105, 144.9624],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6ba36fbbffa28d3b9c16870f11493282 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_acb3e2402cf4fa4e8f8a86ef766d2133);
#
#
#             var marker_31bbeaf17320f5bc2d6fd00d100a3404 = L.marker(
#                 [-37.80099163315519, 144.96608468382195],
#                 {}
#             ).addTo(map_acb3e2402cf4fa4e8f8a86ef766d2133);
#
#
#         var popup_380b74091acb9dae0d077a5d26ed8b43 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_856c63ee770c4782e5cc27a22c91786f = $(`&lt;div id=&quot;html_856c63ee770c4782e5cc27a22c91786f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Carlton&lt;/div&gt;`)[0];
#                 popup_380b74091acb9dae0d077a5d26ed8b43.setContent(html_856c63ee770c4782e5cc27a22c91786f);
#
#
#
#         marker_31bbeaf17320f5bc2d6fd00d100a3404.bindPopup(popup_380b74091acb9dae0d077a5d26ed8b43)
#         ;
#
#
#
#
#             marker_31bbeaf17320f5bc2d6fd00d100a3404.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;Carlton&#x27;, 12.48]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_915abdc4993acd66ac888385f84680b1 = L.marker(
#                 [-37.818142222364365, 144.94559423359516],
#                 {}
#             ).addTo(map_acb3e2402cf4fa4e8f8a86ef766d2133);
#
#
#         var popup_c96ce53e19d7eab190cb6111a1e40db8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e1227d2880e9d54e0009676d0b3e080 = $(`&lt;div id=&quot;html_8e1227d2880e9d54e0009676d0b3e080&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Docklands&lt;/div&gt;`)[0];
#                 popup_c96ce53e19d7eab190cb6111a1e40db8.setContent(html_8e1227d2880e9d54e0009676d0b3e080);
#
#
#
#         marker_915abdc4993acd66ac888385f84680b1.bindPopup(popup_c96ce53e19d7eab190cb6111a1e40db8)
#         ;
#
#
#
#
#             marker_915abdc4993acd66ac888385f84680b1.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;Docklands&#x27;, 38.97]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0854690b206ee6b1291842025ca706cf = L.marker(
#                 [-37.81297418224491, 144.98142945751502],
#                 {}
#             ).addTo(map_acb3e2402cf4fa4e8f8a86ef766d2133);
#
#
#         var popup_de30b21be3c956e726fbc1aae91587ff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04e42f50c18d01c72a8ae2028e0f783d = $(`&lt;div id=&quot;html_04e42f50c18d01c72a8ae2028e0f783d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;East Melbourne&lt;/div&gt;`)[0];
#                 popup_de30b21be3c956e726fbc1aae91587ff.setContent(html_04e42f50c18d01c72a8ae2028e0f783d);
#
#
#
#         marker_0854690b206ee6b1291842025ca706cf.bindPopup(popup_de30b21be3c956e726fbc1aae91587ff)
#         ;
#
#
#
#
#             marker_0854690b206ee6b1291842025ca706cf.bindTooltip(
#                 `&lt;div&gt;
#                      [&#x27;East Melbourne&#x27;, inf]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a769363563f9a49d50f1dd3ce4a280eb = L.marker(
#                 [-37.79188356556477, 144.9277061543456],
#                 {}
#             ).addTo(map_acb3e2402cf4fa4e8f8a86ef766d2133);
#
#
#         var popup_a07cb82da14453887015892593618ca1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9adc835e4f65d44335d9e492de6b56ae = $(`&lt;div id=&quot;html_9adc835e4f65d44335d9e492de6b56ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kensington&lt;/div&gt;`)[0];
#                 popup_a07cb82da14453887015892593618ca1.setContent(html_9adc835e4f65d44335d9e492de6b56ae);
#
#
#
#         marker_a769363563f9a49d50f1dd3ce4a280eb.bindPopup(popup_a07cb82da14453887015892593618ca1)
#         ;
#
#
#
#
#             marker_a769363563f9a49d50f1dd3ce4a280eb.bindTooltip(
#                 `&lt;div&gt;

# %% [markdown]
# # References:
#     - https://www.linkedin.com/pulse/mapping-australian-geograph-data-python-dilan-jayasekara/
#     - https://python-graph-gallery.com/312-add-markers-on-folium-map/
