# %% [markdown]
# _**DELETE BEFORE PUBLISHING**_
#
# _This is a template also containing the style guide for use cases. The styling uses the use-case css when uploaded to the website, which will not be visible on your local machine._
#
# _Change any text marked with {} and delete any cells marked DELETE_
#
# ***

# %%
# DELETE BEFORE PUBLISHING
# This is just here so you can preview the styling on your local machine

from IPython.core.display import HTML
HTML("""
<style>
.usecase-title, .usecase-duration, .usecase-section-header {
    padding-left: 15px;
    padding-bottom: 10px;
    padding-top: 10px;
    padding-right: 15px;
    background-color: #0f9295;
    color: #fff;
}

.usecase-title {
    font-size: 1.7em;
    font-weight: bold;
}

.usecase-authors, .usecase-level, .usecase-skill {
    padding-left: 15px;
    padding-bottom: 7px;
    padding-top: 7px;
    background-color: #baeaeb;
    font-size: 1.4em;
    color: #121212;
}

.usecase-level-skill  {
    display: flex;
}

.usecase-level, .usecase-skill {
    width: 50%;
}

.usecase-duration, .usecase-skill {
    text-align: right;
    padding-right: 15px;
    padding-bottom: 8px;
    font-size: 1.4em;
}

.usecase-section-header {
    font-weight: bold;
    font-size: 1.5em;
}

.usecase-subsection-header, .usecase-subsection-blurb {
    font-weight: bold;
    font-size: 1.2em;
    color: #121212;
}

.usecase-subsection-blurb {
    font-size: 1em;
    font-style: italic;
}
</style>
""")
# Out:
# <style>
# .usecase-title, .usecase-duration, .usecase-section-header {
#     padding-left: 15px;
#     padding-bottom: 8px;
#     padding-top: 8px;
#     padding-right: 15px;
#     background-color: #0f9295;
#     color: #fff;
# }
#
# .usecase-title {
#     font-size: 1.7em;
#     font-weight: bold;
# }
#
# .usecase-authors, .usecase-level, .usecase-skill {
#     padding-left: 15px;
#     padding-bottom: 6px;
#     padding-top: 6px;
#     background-color: #baeaeb;
#     font-size: 1.4em;
#     color: #121212;
# }
#
# .usecase-level-skill  {
#     display: flex;
# }
#
# .usecase-level, .usecase-skill {
#     width: 50%;
# }
#
# .usecase-duration, .usecase-skill {
#     text-align: right;
#     padding-right: 15px;
#     padding-bottom: 6px;
#     font-size: 1.4em;
# }
#
# .usecase-section-header {
#     font-weight: bold;
#     font-size: 1.5em;
# }
#
# .usecase-subsection-header, .usecase-subsection-blurb {
#     font-weight: bold;
#     font-size: 1.2em;
#     color: #121212;
# }
#
# .usecase-subsection-blurb {
#     font-size: 1em;
#     font-style: italic;
# }
# </style>

# %% [markdown]
# <div class="usecase-title">{Use Case Name}</div>
#
# <div class="usecase-authors"><b>Authored by: </b> {Author/s}</div>

# %% [markdown]
# <div class="usecase-duration"><b>Duration:</b> {90} mins</div>
#
# <div class="usecase-level-skill">
#     <div class="usecase-level"><b>Level: </b>{Intermediate}</div>
#     <div class="usecase-skill"><b>Pre-requisite Skills: </b>{Python, and add any more skills needed}</div>
# </div>

# %% [markdown]
# <div class="usecase-section-header">Scenario</div>

# %% [markdown]
# {Using User Story format, write a description of the problem you are trying to solve for this use case.}

# %% [markdown]
# <div class="usecase-section-header">What this use case will teach you</div>

# %% [markdown]
# At the end of this use case you will:
# - {list the skills demonstrated in your use case}

# %% [markdown]
# <div class="usecase-section-header">{Heading for introduction or background relating to problem}</div>

# %% [markdown]
# {Write your introduction here. Keep it concise. We're not after "War and Peace" but enough background information to inform the reader on the rationale for solving this problem or background non-technical information that helps explain the approach. You may also wish to give information on the datasets, particularly how to source those not being imported from the client's open data portal.}

# %% [markdown]
# ***
#
# _**DELETE BEFORE PUBLISHING**_
#
# ## Style guide for use cases
#
# ### Headers
#
# For styling within your markdown cells, there are two choices you can use for headers.
#
# 1) You can use HTML classes specific to the use case styling:
#
# ```<p class="usecase-subsection-header">This is a subsection header.</p>```
#
# <p style="font-weight: bold; font-size: 1.2em;">This is a subsection header.</p>
#
# ```<p class="usecase-subsection-blurb">This is a blurb header.</p>```
#
# <p style="font-weight: bold; font-size: 1em; font-style:italic;">This is a blurb header.</p>
#
#
# 2) Or if you like you can use the markdown header styles:
#
# ```# for h1```
#
# ```## for h2```
#
# ```### for h3```
#
# ```#### for h4```
#
# ```##### for h5```
#
# ## Plot colour schemes
#
# General advice:
# 1. Use the same colour or colour palette throughout your notebook, unless variety is necessary
# 2. Select a palette based on the type of data being represented
# 3. Consider accessibility (colourblindness, low vision)
#
# #### 1) If all of your plots only use 1-2 colors use one of the company style colors:
#
# | Light theme | Dark Theme |
# |-----|-----|
# |<p style="color:#2af598;">#2af598</p>|<p style="color:#08af64;">#08af64</p>|
# |<p style="color:#22e4ac;">#22e4ac</p>|<p style="color:#14a38e;">#14a38e</p>|
# |<p style="color:#1bd7bb;">#1bd7bb</p>|<p style="color:#0f9295;">#0f9295</p>|
# |<p style="color:#14c9cb;">#14c9cb</p>|<p style="color:#056b8a;">#056b8a</p>|
# |<p style="color:#0fbed8;">#0fbed8</p>|<p style="color:#121212;">#121212</p>|
# |<p style="color:#08b3e5;">#08b3e5</p>||
#
#
# #### 2) If your plot needs multiple colors, choose an appropriate palette using either of the following tutorials:
# - https://seaborn.pydata.org/tutorial/color_palettes.html
# - https://matplotlib.org/stable/tutorials/colors/colormaps.html
#
# #### 3) Consider accessibility as well.
#
# For qualitative plotting Seaborn's 'colorblind' palette is recommended. For maps with sequential or diverging it is recommended to use one of the Color Brewer schemes which can be previewed at https://colorbrewer2.org/.
#
# If you want to design your own colour scheme, it should use the same principles as Cynthia Brewer's research (with variation not only in hue but also, saturation or luminance).
#
# ### References
#
# Be sure to acknowledge your sources and any attributions using links or a reference list.
#
# If you have quite a few references, you might wish to have a dedicated section for references at the end of your document, linked using footnote style numbers.
#
# You can connect your in-text reference by adding the number with a HTML link: ```<a href="#fn-1">[1]</a>```
#
# and add a matching ID in the reference list using the ```<fn>``` tag: ```<fn id="fn-1">[1] Author (Year) _Title_, Publisher, Publication location.</fn>```

# %%
import pandas as pd
from sodapy import Socrata

# find the parking dataset @ https://data.melbourne.vic.gov.au/Transport/On-street-Parking-Bay-Sensors/vh2v-4nfs
parking_dataset_id = 'vh2v-4nfs'
# app tokens are just used to manage throttling (not authentication)
app_token = '[your app token]' #find out about app tokens @ https://dev.socrata.com/docs/app-tokens.html
bucket = 'opendataplayground.deakin'

# Access open data through Socrata client
client = Socrata(
    "data.melbourne.vic.gov.au",
    app_token,
    timeout=120
)

# read snapshot of parking sensors status
api_results = client.get_all(parking_dataset_id)
parking_sensors = pd.DataFrame.from_dict(api_results)
parking_sensors = parking_sensors.astype({'lat':'float64', 'lon':'float64'})
# remove duplicates found in the parking sensor data    
parking_sensors = parking_sensors.drop_duplicates()
parking_sensors[['lat', 'lon', 'status']].to_json('./latest_parking_sensors.json')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-d616bb2cd5a7> in <module>
#      17 # read snapshot of parking sensors status
#      18 api_results = client.get_all(parking_dataset_id)
# ---> 19 parking_sensors = pd.DataFrame.from_dict(api_results)
#      20 parking_sensors = parking_sensors.astype({'lat':'float64', 'lon':'float64'})
#      21 # remove duplicates found in the parking sensor data
#
# D:\Programs\Anaconda\lib\site-packages\pandas\core\frame.py in from_dict(cls, data, orient, dtype, columns)
#    1762
#    1763         if orient != "tight":
# -> 1764             return cls(data, index=index, columns=columns, dtype=dtype)
#    1765         else:
#    1766             realdata = data["data"]
#
# D:\Programs\Anaconda\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     736                     data = np.asarray(data)
#     737                 else:
# --> 738                     data = list(data)
#     739             if len(data) > 0:
#     740                 if is_dataclass(data[0]):
#
# D:\Programs\Anaconda\lib\site-packages\sodapy\socrata.py in get_all(self, *args, **kwargs)
#     427
#     428         while True:
# --> 429             response = self.get(*args, **params)
#     430             for item in response:
#     431                 yield item
#
# D:\Programs\Anaconda\lib\site-packages\sodapy\socrata.py in get(self, dataset_identifier, content_type, **kwargs)
#     410         params = utils.clear_empty_values(params)
#     411
# --> 412         response = self._perform_request(
#     413             "get", resource, headers=headers, params=params
#     414         )
#
# D:\Programs\Anaconda\lib\site-packages\sodapy\socrata.py in _perform_request(self, request_type, resource, **kwargs)
#     553         # handle errors
#     554         if response.status_code not in (200, 202):
# --> 555             utils.raise_for_status(response)
#     556
#     557         # when responses have no content body (ie. delete, set_permission),
#
# D:\Programs\Anaconda\lib\site-packages\sodapy\utils.py in raise_for_status(response)
#      28         if more_info and more_info.lower() != response.reason.lower():
#      29             http_error_msg += ".\n\t{}".format(more_info)
# ---> 30         raise requests.exceptions.HTTPError(http_error_msg, response=response)
#      31
#      32
#
# HTTPError: 404 Client Error: Not Found

# %%
import requests
import json

# %%
import keys as keys
# keys.API

# %%
new_url = 'https://data.melbourne.vic.gov.au/api/records/1.0/search/?dataset=on-street-parking-bay-sensors'

# %%
url_v2 = 'https://data.melbourne.vic.gov.au/api/v2/catalog/datasets/'
sensor_data = 'on-street-parking-bay-sensors'.format('on-street-parking-bay-sensors')
result_count = '20'
filters= 'records?limit={0}&offset=0&timezone=UTC'.format(result_count)

# %%
#  'https://data.melbourne.vic.gov.au/api/v2/catalog/datasets/on-street-parking-bay-sensors/records?limit=10&offset=0&timezone=UTC'

# %%
result = requests.get('{0}{1}/{2}'.format(url_v2, sensor_data,filters))

# %%
result_json = result.json()

# %%
result_json.keys()
# Out:
# dict_keys(['total_count', 'links', 'records'])

# %%
records = result_json['records']

# %%
# records.keys()

# %%
len(records)
# Out:
# 20

# %%
for i in records[:5]:
    print(i['record'])
# Out:
# {'id': '80cf5560abd8566d54c3bf475cad815c8d0b5498', 'timestamp': '2023-03-28T03:37:57.446Z', 'size': 163, 'fields': {'location': {'lon': 144.9494536042484, 'lat': -37.80457831492221}, 'lon': 144.9494536042484, 'lat': -37.80457831492221, 'st_marker_id': 9575, 'status': 'Present', 'bay_id': None, 'parking_zone': 7725, 'last_updated': '2023-03-28T03:37:57.549000+00:00'}}
# {'id': 'a5e4ea85288d429569861fa75c0c290debfb8450', 'timestamp': '2023-03-28T03:37:57.446Z', 'size': 165, 'fields': {'location': {'lon': 144.94946578429776, 'lat': -37.80450871995744}, 'lon': 144.94946578429776, 'lat': -37.80450871995744, 'st_marker_id': 9576, 'status': 'Present', 'bay_id': None, 'parking_zone': 7725, 'last_updated': '2023-03-28T03:37:57.550000+00:00'}}
# {'id': 'b4f87729dfbf5a3d2a346da4d4011fa31569c462', 'timestamp': '2023-03-28T03:37:57.446Z', 'size': 170, 'fields': {'location': {'lon': 144.94952899017608, 'lat': -37.804145819722294}, 'lon': 144.94952899017608, 'lat': -37.804145819722294, 'st_marker_id': 9581, 'status': 'Unoccupied', 'bay_id': None, 'parking_zone': 7725, 'last_updated': '2023-03-28T03:37:57.550000+00:00'}}
# {'id': '4058022ca6d50e6aa536a170f885090f810c2f37', 'timestamp': '2023-03-28T03:37:57.446Z', 'size': 163, 'fields': {'location': {'lon': 144.9492535175426, 'lat': -37.80464076945911}, 'lon': 144.9492535175426, 'lat': -37.80464076945911, 'st_marker_id': 9599, 'status': 'Present', 'bay_id': None, 'parking_zone': 7725, 'last_updated': '2023-03-28T03:37:57.552000+00:00'}}
# {'id': '3237e58df36a56eba7c31df4fa8cab69863dc024', 'timestamp': '2023-03-28T03:37:57.446Z', 'size': 170, 'fields': {'location': {'lon': 144.94944536383048, 'lat': -37.803542045983534}, 'lon': 144.94944536383048, 'lat': -37.803542045983534, 'st_marker_id': 9605, 'status': 'Unoccupied', 'bay_id': None, 'parking_zone': 7725, 'last_updated': '2023-03-28T03:37:57.552000+00:00'}}

# %%
# df = pd.DataFrame.from_records(lambda x: x['record']  in records)

# %%
# df

# %%
df=pd.json_normalize(records)

# %%
df
# Out:
#                                                 links  \
# 0   [{'rel': 'self', 'href': 'https://data.melbour...
# 1   [{'rel': 'self', 'href': 'https://data.melbour...
# 2   [{'rel': 'self', 'href': 'https://data.melbour...
# 3   [{'rel': 'self', 'href': 'https://data.melbour...
# 4   [{'rel': 'self', 'href': 'https://data.melbour...
# 5   [{'rel': 'self', 'href': 'https://data.melbour...
# 6   [{'rel': 'self', 'href': 'https://data.melbour...
# 7   [{'rel': 'self', 'href': 'https://data.melbour...
# 8   [{'rel': 'self', 'href': 'https://data.melbour...
# 9   [{'rel': 'self', 'href': 'https://data.melbour...
# 10  [{'rel': 'self', 'href': 'https://data.melbour...
# 11  [{'rel': 'self', 'href': 'https://data.melbour...
# 12  [{'rel': 'self', 'href': 'https://data.melbour...
# 13  [{'rel': 'self', 'href': 'https://data.melbour...
# 14  [{'rel': 'self', 'href': 'https://data.melbour...
# 15  [{'rel': 'self', 'href': 'https://data.melbour...
# 16  [{'rel': 'self', 'href': 'https://data.melbour...
# 17  [{'rel': 'self', 'href': 'https://data.melbour...
# 18  [{'rel': 'self', 'href': 'https://data.melbour...
# 19  [{'rel': 'self', 'href': 'https://data.melbour...
#
#                                    record.id          record.timestamp  \
# 0   80cf5560abd8566d54c3bf475cad815c8d0b5498  2023-03-28T03:37:57.446Z
# 1   a5e4ea85288d429569861fa75c0c290debfb8450  2023-03-28T03:37:57.446Z
# 2   b4f87729dfbf5a3d2a346da4d4011fa31569c462  2023-03-28T03:37:57.446Z
# 3   4058022ca6d50e6aa536a170f885090f810c2f37  2023-03-28T03:37:57.446Z
# 4   3237e58df36a56eba7c31df4fa8cab69863dc024  2023-03-28T03:37:57.446Z
# 5   69f1b9e0e6bd2336863192d4f12352637c71b378  2023-03-28T03:37:57.446Z
# 6   72bcac1965b34a6076fd96fb9e157c2940e1fcf4  2023-03-28T03:37:57.446Z
# 7   37a80fd45c24df10c7ccc42cd488fc984c3d9117  2023-03-28T03:37:57.446Z
# 8   e927b77a576c5b3cc020492072bd3afe56a086b5  2023-03-28T03:37:57.446Z
# 9   066d49d4f9054c604ead18145a41b3e99f7edcdb  2023-03-28T03:37:57.446Z
# 10  c13c67548e3cad4d345c583db1dc314dd24f9e16  2023-03-28T03:37:57.446Z
# 11  817771da3c6a40d364bd2e28bb580b0c660ff12c  2023-03-28T03:37:57.446Z
# 12  90d00421d01150ef3618e01b948dfcfc6d92e492  2023-03-28T03:37:57.446Z
# 13  f460b41247e5474ce08578e0a4e06650b7213416  2023-03-28T03:37:57.446Z
# 14  66735a580335a47f7f246ee3a3c8487170fa8261  2023-03-28T03:37:57.446Z
# 15  944358ad38b83bb118e379e53c2f0760c8ffd728  2023-03-28T03:37:57.446Z
# 16  f505625cc95fd8ed97bb874fdc0957d0e5ef260d  2023-03-28T03:37:57.446Z
# 17  264ac55113d967ea10d50cf9a878dbaf31b26383  2023-03-28T03:37:57.446Z
# 18  6d6193a6c225e3e1aa3c47de78c740eb51438e05  2023-03-28T03:37:57.446Z
# 19  077c4883cb38110e4644b4c30da45bdbbc15ad16  2023-03-28T03:37:57.446Z
#
#     record.size  record.fields.location.lon  record.fields.location.lat  \
# 0           163                  144.949454                  -37.804578
# 1           165                  144.949466                  -37.804509
# 2           170                  144.949529                  -37.804146
# 3           163                  144.949254                  -37.804641
# 4           170                  144.949445                  -37.803542
# 5           161                  144.948760                  -37.804974
# 6           165                  144.948732                  -37.804971
# 7           167                  144.948619                  -37.804959
# 8           167                  144.948465                  -37.804941
# 9           166                  144.948751                  -37.805078
# 10          168                  144.948723                  -37.805075
# 11          165                  144.948357                  -37.805034
# 12          168                  144.948414                  -37.805040
# 13          168                  144.948583                  -37.805059
# 14          169                  144.951180                  -37.803456
# 15          166                  144.950968                  -37.804655
# 16          166                  144.950959                  -37.804705
# 17          167                  144.950296                  -37.805401
# 18          169                  144.950432                  -37.805416
# 19          169                  144.950459                  -37.805419
#
#     record.fields.lon  record.fields.lat  record.fields.st_marker_id  \
# 0          144.949454         -37.804578                        9575
# 1          144.949466         -37.804509                        9576
# 2          144.949529         -37.804146                        9581
# 3          144.949254         -37.804641                        9599
# 4          144.949445         -37.803542                        9605
# 5          144.948760         -37.804974                        9617
# 6          144.948732         -37.804971                        9619
# 7          144.948619         -37.804959                        9623
# 8          144.948465         -37.804941                        9628
# 9          144.948751         -37.805078                        9633
# 10         144.948723         -37.805075                        9634
# 11         144.948357         -37.805034                        9637
# 12         144.948414         -37.805040                        9639
# 13         144.948583         -37.805059                        9648
# 14         144.951180         -37.803456                       10711
# 15         144.950968         -37.804655                       10728
# 16         144.950959         -37.804705                       10729
# 17         144.950296         -37.805401                       10880
# 18         144.950432         -37.805416                       10885
# 19         144.950459         -37.805419                       10886
#
#    record.fields.status record.fields.bay_id  record.fields.parking_zone  \
# 0               Present                 None                        7725
# 1               Present                 None                        7725
# 2            Unoccupied                 None                        7725
# 3               Present                 None                        7725
# 4            Unoccupied                 None                        7725
# 5               Present                 None                        7753
# 6               Present                 None                        7753
# 7               Present                 None                        7753
# 8               Present                 None                        7753
# 9            Unoccupied                 None                        7753
# 10           Unoccupied                 None                        7753
# 11              Present                 None                        7753
# 12           Unoccupied                 None                        7753
# 13           Unoccupied                 None                        7753
# 14           Unoccupied                 None                        7739
# 15              Present                 None                        7739
# 16              Present                 None                        7739
# 17           Unoccupied                 None                        7981
# 18           Unoccupied                 None                        7981
# 19           Unoccupied                 None                        7981
#
#           record.fields.last_updated
# 0   2023-03-28T03:37:57.549000+00:00
# 1   2023-03-28T03:37:57.550000+00:00
# 2   2023-03-28T03:37:57.550000+00:00
# 3   2023-03-28T03:37:57.552000+00:00
# 4   2023-03-28T03:37:57.552000+00:00
# 5   2023-03-28T03:37:57.554000+00:00
# 6   2023-03-28T03:37:57.554000+00:00
# 7   2023-03-28T03:37:57.554000+00:00
# 8   2023-03-28T03:37:57.555000+00:00
# 9   2023-03-28T03:37:57.556000+00:00
# 10  2023-03-28T03:37:57.556000+00:00
# 11  2023-03-28T03:37:57.557000+00:00
# 12  2023-03-28T03:37:57.557000+00:00
# 13  2023-03-28T03:37:57.559000+00:00
# 14  2023-03-28T03:37:57.559000+00:00
# 15  2023-03-28T03:37:57.561000+00:00
# 16  2023-03-28T03:37:57.561000+00:00
# 17  2023-03-28T03:37:57.562000+00:00
# 18  2023-03-28T03:37:57.563000+00:00
# 19  2023-03-28T03:37:57.564000+00:00

# %%
df.drop(columns=['links'],inplace=True)

# %%
column_names = df.columns.values.tolist()
column_names
# Out:
# ['record.id',
#  'record.timestamp',
#  'record.size',
#  'record.fields.location.lon',
#  'record.fields.location.lat',
#  'record.fields.lon',
#  'record.fields.lat',
#  'record.fields.st_marker_id',
#  'record.fields.status',
#  'record.fields.bay_id',
#  'record.fields.parking_zone',
#  'record.fields.last_updated']

# %%
# Replace location.lat & location.lon
column_names = ['_'.join((a.split(".")[-2:])) if a.split('.')[-2]=='location' else a for a in column_names]
column_names
# Out:
# ['record.id',
#  'record.timestamp',
#  'record.size',
#  'location_lon',
#  'location_lat',
#  'record.fields.lon',
#  'record.fields.lat',
#  'record.fields.st_marker_id',
#  'record.fields.status',
#  'record.fields.bay_id',
#  'record.fields.parking_zone',
#  'record.fields.last_updated']

# %%
column_names = [i.split('.')[-1] for i in column_names]
column_names
# Out:
# ['id',
#  'timestamp',
#  'size',
#  'location_lon',
#  'location_lat',
#  'lon',
#  'lat',
#  'st_marker_id',
#  'status',
#  'bay_id',
#  'parking_zone',
#  'last_updated']

# %%
df.columns = column_names
df
# Out:
#                                           id                 timestamp  size  \
# 0   80cf5560abd8566d54c3bf475cad815c8d0b5498  2023-03-28T03:37:57.446Z   163
# 1   a5e4ea85288d429569861fa75c0c290debfb8450  2023-03-28T03:37:57.446Z   165
# 2   b4f87729dfbf5a3d2a346da4d4011fa31569c462  2023-03-28T03:37:57.446Z   170
# 3   4058022ca6d50e6aa536a170f885090f810c2f37  2023-03-28T03:37:57.446Z   163
# 4   3237e58df36a56eba7c31df4fa8cab69863dc024  2023-03-28T03:37:57.446Z   170
# 5   69f1b9e0e6bd2336863192d4f12352637c71b378  2023-03-28T03:37:57.446Z   161
# 6   72bcac1965b34a6076fd96fb9e157c2940e1fcf4  2023-03-28T03:37:57.446Z   165
# 7   37a80fd45c24df10c7ccc42cd488fc984c3d9117  2023-03-28T03:37:57.446Z   167
# 8   e927b77a576c5b3cc020492072bd3afe56a086b5  2023-03-28T03:37:57.446Z   167
# 9   066d49d4f9054c604ead18145a41b3e99f7edcdb  2023-03-28T03:37:57.446Z   166
# 10  c13c67548e3cad4d345c583db1dc314dd24f9e16  2023-03-28T03:37:57.446Z   168
# 11  817771da3c6a40d364bd2e28bb580b0c660ff12c  2023-03-28T03:37:57.446Z   165
# 12  90d00421d01150ef3618e01b948dfcfc6d92e492  2023-03-28T03:37:57.446Z   168
# 13  f460b41247e5474ce08578e0a4e06650b7213416  2023-03-28T03:37:57.446Z   168
# 14  66735a580335a47f7f246ee3a3c8487170fa8261  2023-03-28T03:37:57.446Z   169
# 15  944358ad38b83bb118e379e53c2f0760c8ffd728  2023-03-28T03:37:57.446Z   166
# 16  f505625cc95fd8ed97bb874fdc0957d0e5ef260d  2023-03-28T03:37:57.446Z   166
# 17  264ac55113d967ea10d50cf9a878dbaf31b26383  2023-03-28T03:37:57.446Z   167
# 18  6d6193a6c225e3e1aa3c47de78c740eb51438e05  2023-03-28T03:37:57.446Z   169
# 19  077c4883cb38110e4644b4c30da45bdbbc15ad16  2023-03-28T03:37:57.446Z   169
#
#     location_lon  location_lat         lon        lat  st_marker_id  \
# 0     144.949454    -37.804578  144.949454 -37.804578          9575
# 1     144.949466    -37.804509  144.949466 -37.804509          9576
# 2     144.949529    -37.804146  144.949529 -37.804146          9581
# 3     144.949254    -37.804641  144.949254 -37.804641          9599
# 4     144.949445    -37.803542  144.949445 -37.803542          9605
# 5     144.948760    -37.804974  144.948760 -37.804974          9617
# 6     144.948732    -37.804971  144.948732 -37.804971          9619
# 7     144.948619    -37.804959  144.948619 -37.804959          9623
# 8     144.948465    -37.804941  144.948465 -37.804941          9628
# 9     144.948751    -37.805078  144.948751 -37.805078          9633
# 10    144.948723    -37.805075  144.948723 -37.805075          9634
# 11    144.948357    -37.805034  144.948357 -37.805034          9637
# 12    144.948414    -37.805040  144.948414 -37.805040          9639
# 13    144.948583    -37.805059  144.948583 -37.805059          9648
# 14    144.951180    -37.803456  144.951180 -37.803456         10711
# 15    144.950968    -37.804655  144.950968 -37.804655         10728
# 16    144.950959    -37.804705  144.950959 -37.804705         10729
# 17    144.950296    -37.805401  144.950296 -37.805401         10880
# 18    144.950432    -37.805416  144.950432 -37.805416         10885
# 19    144.950459    -37.805419  144.950459 -37.805419         10886
#
#         status bay_id  parking_zone                      last_updated
# 0      Present   None          7725  2023-03-28T03:37:57.549000+00:00
# 1      Present   None          7725  2023-03-28T03:37:57.550000+00:00
# 2   Unoccupied   None          7725  2023-03-28T03:37:57.550000+00:00
# 3      Present   None          7725  2023-03-28T03:37:57.552000+00:00
# 4   Unoccupied   None          7725  2023-03-28T03:37:57.552000+00:00
# 5      Present   None          7753  2023-03-28T03:37:57.554000+00:00
# 6      Present   None          7753  2023-03-28T03:37:57.554000+00:00
# 7      Present   None          7753  2023-03-28T03:37:57.554000+00:00
# 8      Present   None          7753  2023-03-28T03:37:57.555000+00:00
# 9   Unoccupied   None          7753  2023-03-28T03:37:57.556000+00:00
# 10  Unoccupied   None          7753  2023-03-28T03:37:57.556000+00:00
# 11     Present   None          7753  2023-03-28T03:37:57.557000+00:00
# 12  Unoccupied   None          7753  2023-03-28T03:37:57.557000+00:00
# 13  Unoccupied   None          7753  2023-03-28T03:37:57.559000+00:00
# 14  Unoccupied   None          7739  2023-03-28T03:37:57.559000+00:00
# 15     Present   None          7739  2023-03-28T03:37:57.561000+00:00
# 16     Present   None          7739  2023-03-28T03:37:57.561000+00:00
# 17  Unoccupied   None          7981  2023-03-28T03:37:57.562000+00:00
# 18  Unoccupied   None          7981  2023-03-28T03:37:57.563000+00:00
# 19  Unoccupied   None          7981  2023-03-28T03:37:57.564000+00:00

# %%
sensor_df = df.copy()

# %%
sensor_df
# Out:
#                                           id                 timestamp  size  \
# 0   80cf5560abd8566d54c3bf475cad815c8d0b5498  2023-03-28T03:37:57.446Z   163
# 1   a5e4ea85288d429569861fa75c0c290debfb8450  2023-03-28T03:37:57.446Z   165
# 2   b4f87729dfbf5a3d2a346da4d4011fa31569c462  2023-03-28T03:37:57.446Z   170
# 3   4058022ca6d50e6aa536a170f885090f810c2f37  2023-03-28T03:37:57.446Z   163
# 4   3237e58df36a56eba7c31df4fa8cab69863dc024  2023-03-28T03:37:57.446Z   170
# 5   69f1b9e0e6bd2336863192d4f12352637c71b378  2023-03-28T03:37:57.446Z   161
# 6   72bcac1965b34a6076fd96fb9e157c2940e1fcf4  2023-03-28T03:37:57.446Z   165
# 7   37a80fd45c24df10c7ccc42cd488fc984c3d9117  2023-03-28T03:37:57.446Z   167
# 8   e927b77a576c5b3cc020492072bd3afe56a086b5  2023-03-28T03:37:57.446Z   167
# 9   066d49d4f9054c604ead18145a41b3e99f7edcdb  2023-03-28T03:37:57.446Z   166
# 10  c13c67548e3cad4d345c583db1dc314dd24f9e16  2023-03-28T03:37:57.446Z   168
# 11  817771da3c6a40d364bd2e28bb580b0c660ff12c  2023-03-28T03:37:57.446Z   165
# 12  90d00421d01150ef3618e01b948dfcfc6d92e492  2023-03-28T03:37:57.446Z   168
# 13  f460b41247e5474ce08578e0a4e06650b7213416  2023-03-28T03:37:57.446Z   168
# 14  66735a580335a47f7f246ee3a3c8487170fa8261  2023-03-28T03:37:57.446Z   169
# 15  944358ad38b83bb118e379e53c2f0760c8ffd728  2023-03-28T03:37:57.446Z   166
# 16  f505625cc95fd8ed97bb874fdc0957d0e5ef260d  2023-03-28T03:37:57.446Z   166
# 17  264ac55113d967ea10d50cf9a878dbaf31b26383  2023-03-28T03:37:57.446Z   167
# 18  6d6193a6c225e3e1aa3c47de78c740eb51438e05  2023-03-28T03:37:57.446Z   169
# 19  077c4883cb38110e4644b4c30da45bdbbc15ad16  2023-03-28T03:37:57.446Z   169
#
#     location_lon  location_lat         lon        lat  st_marker_id  \
# 0     144.949454    -37.804578  144.949454 -37.804578          9575
# 1     144.949466    -37.804509  144.949466 -37.804509          9576
# 2     144.949529    -37.804146  144.949529 -37.804146          9581
# 3     144.949254    -37.804641  144.949254 -37.804641          9599
# 4     144.949445    -37.803542  144.949445 -37.803542          9605
# 5     144.948760    -37.804974  144.948760 -37.804974          9617
# 6     144.948732    -37.804971  144.948732 -37.804971          9619
# 7     144.948619    -37.804959  144.948619 -37.804959          9623
# 8     144.948465    -37.804941  144.948465 -37.804941          9628
# 9     144.948751    -37.805078  144.948751 -37.805078          9633
# 10    144.948723    -37.805075  144.948723 -37.805075          9634
# 11    144.948357    -37.805034  144.948357 -37.805034          9637
# 12    144.948414    -37.805040  144.948414 -37.805040          9639
# 13    144.948583    -37.805059  144.948583 -37.805059          9648
# 14    144.951180    -37.803456  144.951180 -37.803456         10711
# 15    144.950968    -37.804655  144.950968 -37.804655         10728
# 16    144.950959    -37.804705  144.950959 -37.804705         10729
# 17    144.950296    -37.805401  144.950296 -37.805401         10880
# 18    144.950432    -37.805416  144.950432 -37.805416         10885
# 19    144.950459    -37.805419  144.950459 -37.805419         10886
#
#         status bay_id  parking_zone                      last_updated
# 0      Present   None          7725  2023-03-28T03:37:57.549000+00:00
# 1      Present   None          7725  2023-03-28T03:37:57.550000+00:00
# 2   Unoccupied   None          7725  2023-03-28T03:37:57.550000+00:00
# 3      Present   None          7725  2023-03-28T03:37:57.552000+00:00
# 4   Unoccupied   None          7725  2023-03-28T03:37:57.552000+00:00
# 5      Present   None          7753  2023-03-28T03:37:57.554000+00:00
# 6      Present   None          7753  2023-03-28T03:37:57.554000+00:00
# 7      Present   None          7753  2023-03-28T03:37:57.554000+00:00
# 8      Present   None          7753  2023-03-28T03:37:57.555000+00:00
# 9   Unoccupied   None          7753  2023-03-28T03:37:57.556000+00:00
# 10  Unoccupied   None          7753  2023-03-28T03:37:57.556000+00:00
# 11     Present   None          7753  2023-03-28T03:37:57.557000+00:00
# 12  Unoccupied   None          7753  2023-03-28T03:37:57.557000+00:00
# 13  Unoccupied   None          7753  2023-03-28T03:37:57.559000+00:00
# 14  Unoccupied   None          7739  2023-03-28T03:37:57.559000+00:00
# 15     Present   None          7739  2023-03-28T03:37:57.561000+00:00
# 16     Present   None          7739  2023-03-28T03:37:57.561000+00:00
# 17  Unoccupied   None          7981  2023-03-28T03:37:57.562000+00:00
# 18  Unoccupied   None          7981  2023-03-28T03:37:57.563000+00:00
# 19  Unoccupied   None          7981  2023-03-28T03:37:57.564000+00:00

# %%
parking_sensors = sensor_df.astype({'lat':'float64', 'lon':'float64'})

# %%
# parking_sensors = parking_sensors.astype({'lat':'float64', 'lon':'float64'})

# %%
parking_sensors
# Out:
#                                           id                 timestamp  size  \
# 0   80cf5560abd8566d54c3bf475cad815c8d0b5498  2023-03-28T03:37:57.446Z   163
# 1   a5e4ea85288d429569861fa75c0c290debfb8450  2023-03-28T03:37:57.446Z   165
# 2   b4f87729dfbf5a3d2a346da4d4011fa31569c462  2023-03-28T03:37:57.446Z   170
# 3   4058022ca6d50e6aa536a170f885090f810c2f37  2023-03-28T03:37:57.446Z   163
# 4   3237e58df36a56eba7c31df4fa8cab69863dc024  2023-03-28T03:37:57.446Z   170
# 5   69f1b9e0e6bd2336863192d4f12352637c71b378  2023-03-28T03:37:57.446Z   161
# 6   72bcac1965b34a6076fd96fb9e157c2940e1fcf4  2023-03-28T03:37:57.446Z   165
# 7   37a80fd45c24df10c7ccc42cd488fc984c3d9117  2023-03-28T03:37:57.446Z   167
# 8   e927b77a576c5b3cc020492072bd3afe56a086b5  2023-03-28T03:37:57.446Z   167
# 9   066d49d4f9054c604ead18145a41b3e99f7edcdb  2023-03-28T03:37:57.446Z   166
# 10  c13c67548e3cad4d345c583db1dc314dd24f9e16  2023-03-28T03:37:57.446Z   168
# 11  817771da3c6a40d364bd2e28bb580b0c660ff12c  2023-03-28T03:37:57.446Z   165
# 12  90d00421d01150ef3618e01b948dfcfc6d92e492  2023-03-28T03:37:57.446Z   168
# 13  f460b41247e5474ce08578e0a4e06650b7213416  2023-03-28T03:37:57.446Z   168
# 14  66735a580335a47f7f246ee3a3c8487170fa8261  2023-03-28T03:37:57.446Z   169
# 15  944358ad38b83bb118e379e53c2f0760c8ffd728  2023-03-28T03:37:57.446Z   166
# 16  f505625cc95fd8ed97bb874fdc0957d0e5ef260d  2023-03-28T03:37:57.446Z   166
# 17  264ac55113d967ea10d50cf9a878dbaf31b26383  2023-03-28T03:37:57.446Z   167
# 18  6d6193a6c225e3e1aa3c47de78c740eb51438e05  2023-03-28T03:37:57.446Z   169
# 19  077c4883cb38110e4644b4c30da45bdbbc15ad16  2023-03-28T03:37:57.446Z   169
#
#     location_lon  location_lat         lon        lat  st_marker_id  \
# 0     144.949454    -37.804578  144.949454 -37.804578          9575
# 1     144.949466    -37.804509  144.949466 -37.804509          9576
# 2     144.949529    -37.804146  144.949529 -37.804146          9581
# 3     144.949254    -37.804641  144.949254 -37.804641          9599
# 4     144.949445    -37.803542  144.949445 -37.803542          9605
# 5     144.948760    -37.804974  144.948760 -37.804974          9617
# 6     144.948732    -37.804971  144.948732 -37.804971          9619
# 7     144.948619    -37.804959  144.948619 -37.804959          9623
# 8     144.948465    -37.804941  144.948465 -37.804941          9628
# 9     144.948751    -37.805078  144.948751 -37.805078          9633
# 10    144.948723    -37.805075  144.948723 -37.805075          9634
# 11    144.948357    -37.805034  144.948357 -37.805034          9637
# 12    144.948414    -37.805040  144.948414 -37.805040          9639
# 13    144.948583    -37.805059  144.948583 -37.805059          9648
# 14    144.951180    -37.803456  144.951180 -37.803456         10711
# 15    144.950968    -37.804655  144.950968 -37.804655         10728
# 16    144.950959    -37.804705  144.950959 -37.804705         10729
# 17    144.950296    -37.805401  144.950296 -37.805401         10880
# 18    144.950432    -37.805416  144.950432 -37.805416         10885
# 19    144.950459    -37.805419  144.950459 -37.805419         10886
#
#         status bay_id  parking_zone                      last_updated
# 0      Present   None          7725  2023-03-28T03:37:57.549000+00:00
# 1      Present   None          7725  2023-03-28T03:37:57.550000+00:00
# 2   Unoccupied   None          7725  2023-03-28T03:37:57.550000+00:00
# 3      Present   None          7725  2023-03-28T03:37:57.552000+00:00
# 4   Unoccupied   None          7725  2023-03-28T03:37:57.552000+00:00
# 5      Present   None          7753  2023-03-28T03:37:57.554000+00:00
# 6      Present   None          7753  2023-03-28T03:37:57.554000+00:00
# 7      Present   None          7753  2023-03-28T03:37:57.554000+00:00
# 8      Present   None          7753  2023-03-28T03:37:57.555000+00:00
# 9   Unoccupied   None          7753  2023-03-28T03:37:57.556000+00:00
# 10  Unoccupied   None          7753  2023-03-28T03:37:57.556000+00:00
# 11     Present   None          7753  2023-03-28T03:37:57.557000+00:00
# 12  Unoccupied   None          7753  2023-03-28T03:37:57.557000+00:00
# 13  Unoccupied   None          7753  2023-03-28T03:37:57.559000+00:00
# 14  Unoccupied   None          7739  2023-03-28T03:37:57.559000+00:00
# 15     Present   None          7739  2023-03-28T03:37:57.561000+00:00
# 16     Present   None          7739  2023-03-28T03:37:57.561000+00:00
# 17  Unoccupied   None          7981  2023-03-28T03:37:57.562000+00:00
# 18  Unoccupied   None          7981  2023-03-28T03:37:57.563000+00:00
# 19  Unoccupied   None          7981  2023-03-28T03:37:57.564000+00:00

# %%
parking_sensors.drop_duplicates(inplace= True)

# %%
parking_sensors[['lat', 'lon', 'status']].to_json('./latest_parking_sensors.json')
