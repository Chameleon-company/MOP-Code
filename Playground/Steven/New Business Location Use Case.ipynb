# %%
import requests

url = 'https://data.melbourne.vic.gov.au/api/records/1.0/search/?dataset=residential-dwellings'

result = requests.get(url)

result_json= result.json()

print(result.text)

print(result_json)
# Out:
# {"nhits": 188160, "parameters": {"dataset": "residential-dwellings", "rows": 10, "start": 0, "format": "json", "timezone": "UTC"}, "records": [{"datasetid": "residential-dwellings", "recordid": "0d0ba713265b5cd4f23782ac46a9fed2947c81a9", "fields": {"longitude": 144.95475, "property_id": 101096, "building_address": "4-12 Blackwood Street NORTH MELBOURNE 3051", "clue_small_area": "North Melbourne", "block_id": 375, "base_property_id": 101096, "location": [-37.80191, 144.95475], "census_year": "2014", "dwelling_number": 13, "latitude": -37.80191, "dwelling_type": "Residential Apartments"}, "geometry": {"type": "Point", "coordinates": [144.95475, -37.80191]}, "record_timestamp": "2022-12-13T12:31:42.85Z"}, {"datasetid": "residential-dwellings", "recordid": "0bc73695e99fd641aae9e8a670f185371951fa64", "fields": {"longitude": 144.95644, "property_id": 107519, "building_address": "243 Peel Street NORTH MELBOURNE 3051", "clue_small_area": "North Melbourne", "block_id": 375, "base_property_id"
# ...

# %%
url = 'https://data.melbourne.vic.gov.au/api/records/1.0/search/?dataset=employment-by-block-by-clue-industry'

result = requests.get(url)

result_json= result.json()

print(result.text)

print(result_json)
# Out:
# {"nhits": 11788, "parameters": {"dataset": "employment-by-block-by-clue-industry", "rows": 10, "start": 0, "format": "json", "timezone": "UTC"}, "records": [{"datasetid": "employment-by-block-by-clue-industry", "recordid": "c53eb74c69800ef655c642a454a5578c03d9e286", "fields": {"education_and_training": 0, "electricity_gas_water_and_waste_services": 0, "manufacturing": 0, "construction": 0, "finance_and_insurance": 0, "retail_trade": 0, "other_services": 0, "wholesale_trade": 0, "census_year": "2009", "food_and_beverage_services": 0, "transport_postal_and_storage": 0, "rental_and_hiring_services": 0, "accommodation": 0, "agriculture_and_mining": 0, "real_estate_services": 0, "health_care_and_social_assistance": 0, "public_administration_and_safety": 0, "admin_and_support_services": 0, "block_id": 374, "clue_small_area": "North Melbourne", "business_services": 0, "information_media_and_telecommunications": 0}, "record_timestamp": "2022-12-13T12:17:11.035Z"}, {"datasetid": "employment-b
# ...

# %%
url = "https://data.melbourne.vic.gov.au/api/records/1.0/search/?dataset=cafes-and-restaurants-with-seating-capacity"

result = requests.get(url)

result_json= result.json()

print(result.text)

print(result_json)
# Out:
# {"nhits": 56987, "parameters": {"dataset": "cafes-and-restaurants-with-seating-capacity", "rows": 10, "start": 0, "format": "json", "timezone": "UTC"}, "records": [{"datasetid": "cafes-and-restaurants-with-seating-capacity", "recordid": "9dd07c89020bbe7924d81179a73b4b1b62b09f94", "fields": {"location": [-37.82223, 144.95743], "seating_type": "Seats - Outdoor", "census_year": "2002", "property_id": 111467, "base_property_id": 103973, "trading_name": "Melbourne Aquarium", "block_id": 2, "industry_anzsic4_description": "Zoological and Botanical Gardens Operation", "number_of_seats": 38, "building_address": "0 King Street MELBOURNE 3000", "clue_small_area": "Melbourne (CBD)", "business_address": "469-479 King Street MELBOURNE 3000", "industry_anzsic4_code": 8921, "longitude": 144.95743, "latitude": -37.82223}, "geometry": {"type": "Point", "coordinates": [144.95743, -37.82223]}, "record_timestamp": "2022-12-13T13:02:04.789Z"}, {"datasetid": "cafes-and-restaurants-with-seating-capacity", 
# ...
