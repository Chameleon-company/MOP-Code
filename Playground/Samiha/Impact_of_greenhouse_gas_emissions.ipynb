# %% [markdown]
# _**DELETE BEFORE PUBLISHING**_
#
# _This is a template also containing the style guide for use cases. The styling uses the use-case css when uploaded to the website, which will not be visible on your local machine._
#
# _Change any text marked with {} and delete any cells marked DELETE_
#
# ***

# %%
# DELETE BEFORE PUBLISHING
# This is just here so you can preview the styling on your local machine

from IPython.core.display import HTML
HTML("""
<style>
.usecase-title, .usecase-duration, .usecase-section-header {
    padding-left: 15px;
    padding-bottom: 10px;
    padding-top: 10px;
    padding-right: 15px;
    background-color: #0f9295;
    color: #fff;
}

.usecase-title {
    font-size: 1.7em;
    font-weight: bold;
}

.usecase-authors, .usecase-level, .usecase-skill {
    padding-left: 15px;
    padding-bottom: 7px;
    padding-top: 7px;
    background-color: #baeaeb;
    font-size: 1.4em;
    color: #121212;
}

.usecase-level-skill  {
    display: flex;
}

.usecase-level, .usecase-skill {
    width: 50%;
}

.usecase-duration, .usecase-skill {
    text-align: right;
    padding-right: 15px;
    padding-bottom: 8px;
    font-size: 1.4em;
}

.usecase-section-header {
    font-weight: bold;
    font-size: 1.5em;
}

.usecase-subsection-header, .usecase-subsection-blurb {
    font-weight: bold;
    font-size: 1.2em;
    color: #121212;
}

.usecase-subsection-blurb {
    font-size: 1em;
    font-style: italic;
}
</style>
""")
# Out:
# <style>
# .usecase-title, .usecase-duration, .usecase-section-header {
#     padding-left: 15px;
#     padding-bottom: 8px;
#     padding-top: 8px;
#     padding-right: 15px;
#     background-color: #0f9295;
#     color: #fff;
# }
#
# .usecase-title {
#     font-size: 1.7em;
#     font-weight: bold;
# }
#
# .usecase-authors, .usecase-level, .usecase-skill {
#     padding-left: 15px;
#     padding-bottom: 6px;
#     padding-top: 6px;
#     background-color: #baeaeb;
#     font-size: 1.4em;
#     color: #121212;
# }
#
# .usecase-level-skill  {
#     display: flex;
# }
#
# .usecase-level, .usecase-skill {
#     width: 50%;
# }
#
# .usecase-duration, .usecase-skill {
#     text-align: right;
#     padding-right: 15px;
#     padding-bottom: 6px;
#     font-size: 1.4em;
# }
#
# .usecase-section-header {
#     font-weight: bold;
#     font-size: 1.5em;
# }
#
# .usecase-subsection-header, .usecase-subsection-blurb {
#     font-weight: bold;
#     font-size: 1.2em;
#     color: #121212;
# }
# ...

# %% [markdown]
# <div class="usecase-title">{Use Case Name}</div>
#
# <div class="usecase-authors"><b>Authored by: </b> {Author/s}</div>

# %% [markdown]
# <div class="usecase-duration"><b>Duration:</b> {90} mins</div>
#
# <div class="usecase-level-skill">
#     <div class="usecase-level"><b>Level: </b>{Intermediate}</div>
#     <div class="usecase-skill"><b>Pre-requisite Skills: </b>{Python, and add any more skills needed}</div>
# </div>

# %% [markdown]
# <div class="usecase-section-header">Scenario</div>

# %% [markdown]
# {Using User Story format, write a description of the problem you are trying to solve for this use case.}

# %% [markdown]
# <div class="usecase-section-header">What this use case will teach you</div>

# %% [markdown]
# At the end of this use case you will:
# - {list the skills demonstrated in your use case}

# %% [markdown]
# <div class="usecase-section-header">{Heading for introduction or background relating to problem}</div>

# %% [markdown]
# {Write your introduction here. Keep it concise. We're not after "War and Peace" but enough background information to inform the reader on the rationale for solving this problem or background non-technical information that helps explain the approach. You may also wish to give information on the datasets, particularly how to source those not being imported from the client's open data portal.}

# %% [markdown]
# ***
#
# _**DELETE BEFORE PUBLISHING**_
#
# ## Style guide for use cases
#
# ### Headers
#
# For styling within your markdown cells, there are two choices you can use for headers.
#
# 1) You can use HTML classes specific to the use case styling:
#
# ```<p class="usecase-subsection-header">This is a subsection header.</p>```
#
# <p style="font-weight: bold; font-size: 1.2em;">This is a subsection header.</p>
#
# ```<p class="usecase-subsection-blurb">This is a blurb header.</p>```
#
# <p style="font-weight: bold; font-size: 1em; font-style:italic;">This is a blurb header.</p>
#
#
# 2) Or if you like you can use the markdown header styles:
#
# ```# for h1```
#
# ```## for h2```
#
# ```### for h3```
#
# ```#### for h4```
#
# ```##### for h5```
#
# ## Plot colour schemes
#
# General advice:
# 1. Use the same colour or colour palette throughout your notebook, unless variety is necessary
# 2. Select a palette based on the type of data being represented
# 3. Consider accessibility (colourblindness, low vision)
#
# #### 1) If all of your plots only use 1-2 colors use one of the company style colors:
#
# | Light theme | Dark Theme |
# |-----|-----|
# |<p style="color:#2af598;">#2af598</p>|<p style="color:#08af64;">#08af64</p>|
# |<p style="color:#22e4ac;">#22e4ac</p>|<p style="color:#14a38e;">#14a38e</p>|
# |<p style="color:#1bd7bb;">#1bd7bb</p>|<p style="color:#0f9295;">#0f9295</p>|
# |<p style="color:#14c9cb;">#14c9cb</p>|<p style="color:#056b8a;">#056b8a</p>|
# |<p style="color:#0fbed8;">#0fbed8</p>|<p style="color:#121212;">#121212</p>|
# |<p style="color:#08b3e5;">#08b3e5</p>||
#
#
# #### 2) If your plot needs multiple colors, choose an appropriate palette using either of the following tutorials:
# - https://seaborn.pydata.org/tutorial/color_palettes.html
# - https://matplotlib.org/stable/tutorials/colors/colormaps.html
#
# #### 3) Consider accessibility as well.
#
# For qualitative plotting Seaborn's 'colorblind' palette is recommended. For maps with sequential or diverging it is recommended to use one of the Color Brewer schemes which can be previewed at https://colorbrewer2.org/.
#
# If you want to design your own colour scheme, it should use the same principles as Cynthia Brewer's research (with variation not only in hue but also, saturation or luminance).
#
# ### References
#
# Be sure to acknowledge your sources and any attributions using links or a reference list.
#
# If you have quite a few references, you might wish to have a dedicated section for references at the end of your document, linked using footnote style numbers.
#
# You can connect your in-text reference by adding the number with a HTML link: ```<a href="#fn-1">[1]</a>```
#
# and add a matching ID in the reference list using the ```<fn>``` tag: ```<fn id="fn-1">[1] Author (Year) _Title_, Publisher, Publication location.</fn>```

# %%
import requests
import pandas as pd
import numpy as np
from io import StringIO

# %%
base_url='https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/'
dataset_id='city-of-melbourne-municipal-greenhouse-gas-emissions-2013-2020'
with open('/Users/samihahaque/Desktop/key.txt') as file:
    API_KEY=file.read()

url=f'{base_url}{dataset_id}/exports/csv'
params={'select':'*','limit':-1,'lang':'en','timezone':'UTC','api_key':API_KEY}

response=requests.get(url,params=params)

if response.status_code==200:
    url_content=response.content.decode('utf-8')
    gas_emissions_df=pd.read_csv(StringIO(url_content),delimiter=';')
    print(gas_emissions_df.head(10))
else:
    print(f'Request failed with status code {response.status_code}')
# Out:
#    year  population  area_km2  gdp_m  residential_buildings_scope_1  \
# 0  2020      183756  37.7 km2  70221                          36660
# 1  2019      178955  37.7 km2  70221                          37913
# 2  2018      169961   37.7km2  66472                          37520
# 3  2017      152992   37.7km2  69780                          35733
# 4  2016      148000        38  68859                          35547
# 5  2015      139000        38  68859                          35637
# 6  2014      129000        38  67700                          43262
# 7  2013      116431        38  67700                          39165
#
#    residential_buildings_scope_2  residential_buildings_scope_3  \
# 0                         262376                          29450
# 1                         276303                          27089
# 2                         256112                          23936
# 3                         262254                          24283
# ...

# %%
gas_emissions_df.shape
# Out:
# (8, 60)

# %%
gas_emissions_df.head()
# Out:
#    year  population  area_km2  gdp_m  residential_buildings_scope_1  \
# 0  2020      183756  37.7 km2  70221                          36660
# 1  2019      178955  37.7 km2  70221                          37913
# 2  2018      169961   37.7km2  66472                          37520
# 3  2017      152992   37.7km2  69780                          35733
# 4  2016      148000        38  68859                          35547
#
#    residential_buildings_scope_2  residential_buildings_scope_3  \
# 0                         262376                          29450
# 1                         276303                          27089
# 2                         256112                          23936
# 3                         262254                          24283
# 4                         257854                          23656
#
#    commercial_and_institutional_buildings_and_facilities_scope_1  \
# 0                                             138825
# ...

# %%
base_url='https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/'
dataset_id='microclimate-sensor-readings'
with open('/Users/samihahaque/Desktop/key.txt') as file:
    API_KEY=file.read()

url=f'{base_url}{dataset_id}/exports/csv'
params={'select':'*','limit':-1,'lang':'en','timezone':'UTC','api_key':API_KEY}

response=requests.get(url,params=params)

if response.status_code==200:
    url_content=response.content.decode('utf-8')
    sensor_readings_df=pd.read_csv(StringIO(url_content),delimiter=';')
    print(sensor_readings_df.head(10))
else:
    print(f'Request failed with status code {response.status_code}')
# Out:
#                   local_time       id  site_id sensor_id    value  \
# 0  2023-11-29T22:15:02+00:00  8110553     1011        5b    74.38
# 1  2023-11-29T22:15:02+00:00  8110558     1011        5c  1010.80
# 2  2023-11-29T22:15:03+00:00  8110562     1011         6     0.00
# 3  2023-11-29T22:15:04+00:00  8110606     1012         6     0.00
# 4  2023-11-29T22:15:11+00:00  8110489     1009        0a     5.30
# 5  2023-11-29T22:30:02+00:00  8110554     1011        5b    74.19
# 6  2023-11-29T22:30:11+00:00  8110490     1009        0a     5.20
# 7  2023-11-29T22:30:11+00:00  8110500     1009        0b    19.30
# 8  2023-11-29T22:30:11+00:00  8110523     1011        0a     5.90
# 9  2023-11-29T22:30:11+00:00  8110532     1011        0b    24.80
#
#            type    units gatewayhub_id site_status
# 0        TPH.RH        %       arc1055           C
# 1  TPH.PRESSURE      hPa       arc1055           C
# 2            WS     km/h       arc1055           C
# ...

# %%
sensor_readings_df.shape
# Out:
# (56, 9)

# %%
sensor_readings_df.head()
# Out:
#                   local_time       id  site_id sensor_id    value  \
# 0  2023-11-29T22:15:02+00:00  8110553     1011        5b    74.38
# 1  2023-11-29T22:15:02+00:00  8110558     1011        5c  1010.80
# 2  2023-11-29T22:15:03+00:00  8110562     1011         6     0.00
# 3  2023-11-29T22:15:04+00:00  8110606     1012         6     0.00
# 4  2023-11-29T22:15:11+00:00  8110489     1009        0a     5.30
#
#            type   units gatewayhub_id site_status
# 0        TPH.RH       %       arc1055           C
# 1  TPH.PRESSURE     hPa       arc1055           C
# 2            WS    km/h       arc1055           C
# 3            WS    km/h       arc1048           C
# 4         PM2.5  ug/m^3       arc1050           C

# %%
sensor_readings_df.nunique()
# Out:
# local_time       14
# id               56
# site_id           3
# sensor_id         6
# value            44
# type              6
# units             6
# gatewayhub_id     3
# site_status       1
# dtype: int64

# %%
sensor_readings_df['sensor_id'].value_counts()
# Out:
# 0a    12
# 0b    12
# 5b     8
# 5c     8
# 6      8
# 5a     8
# Name: sensor_id, dtype: int64

# %%
sensor_readings_df['local_time'].value_counts()
# Out:
# 2023-11-29T22:30:02+00:00    6
# 2023-11-29T22:30:11+00:00    6
# 2023-11-29T22:45:02+00:00    6
# 2023-11-29T22:45:11+00:00    6
# 2023-11-29T23:00:02+00:00    6
# 2023-11-29T23:00:11+00:00    6
# 2023-11-29T22:15:03+00:00    4
# 2023-11-29T22:15:11+00:00    4
# 2023-11-29T22:15:02+00:00    3
# 2023-11-29T23:00:03+00:00    2
# 2023-11-29T22:15:12+00:00    2
# 2023-11-29T22:30:03+00:00    2
# 2023-11-29T22:45:03+00:00    2
# 2023-11-29T22:15:04+00:00    1
# Name: local_time, dtype: int64

# %%
sensor_readings_df.isnull().sum()
# Out:
# local_time       0
# id               0
# site_id          0
# sensor_id        0
# value            0
# type             0
# units            0
# gatewayhub_id    0
# site_status      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Assuming df is your DataFrame and you want to create a scatter plot between feature1 and feature2
plt.figure(figsize=(8, 6))
sns.scatterplot(x='gatewayhub_id', y='site_id', data=sensor_readings_df)  # Adjust alpha for transparency
plt.title('Scatter Plot of Feature1 vs Feature2')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='sensor_id', y='type', data=sensor_readings_df)  # Adjust alpha for transparency
plt.title('Scatter Plot of Feature1 vs Feature2')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='sensor_id', y='local_time', data=sensor_readings_df)  # Adjust alpha for transparency
plt.title('Scatter Plot of Feature1 vs Feature2')
plt.grid(True)
plt.show()
