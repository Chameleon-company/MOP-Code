# %%
# Import modules
import requests
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
from shapely.geometry import Point

# %%
def fetch_data(base_url, dataset, api_key, num_records=99, offset=0):
    all_records = []
    max_offset = 9900
    while True:
        if offset > max_offset:
            break
        filters = f'{dataset}/records?limit={num_records}&offset={offset}'
        url = f'{base_url}{filters}&api_key={api_key}'
        try:
            result = requests.get(url, timeout = 10)
            result.raise_for_status()
            records = result.json().get('results')
        except requests.exceptions.RequestException as e:
            raise Exception(f'API request failed: {e}')
        if records is None:
            break
        all_records.extend(records)
        if len(records) < num_records:
            break
        offset += num_records
    df = pd.DataFrame(all_records)
    return df


# Base URL for API
API_KEY = os.environ.get('MELBOURNE_API_KEY', input('Please enter you API key: '))
BASE_URL = 'https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/'

# Load datasets using API
# Specific paths for the datasets
SPECIFIC_PATH_DEV = 'development-activity-monitor'
SPECIFIC_PATH_TREE_11 = 'tree-canopies-2011-urban-forest'
SPECIFIC_PATH_TREE_21 = 'tree-canopies-2021-urban-forest'

# Collect data using the API and the fetch_data function
dev_df = fetch_data(BASE_URL, SPECIFIC_PATH_DEV, API_KEY)
tree_11_df = fetch_data(BASE_URL, SPECIFIC_PATH_TREE_11, API_KEY)
tree_21_df = fetch_data(BASE_URL, SPECIFIC_PATH_TREE_21, API_KEY)

# %%
# Convert 'year_completed' to numeric
dev_df['year_completed'] = pd.to_numeric(dev_df['year_completed'])

# Filter developments that were completed on or after 2011 or are still in construction (i.e. is NaN).
dev_df = dev_df[(dev_df['year_completed'] >= 2011) | (dev_df['year_completed'].isna())]

# %%
tree_11_df
# Out:
#                                            geo_point_2d  \
# 0     {'lon': 144.91900753144674, 'lat': -37.7878123...
# 1     {'lon': 144.9431510714485, 'lat': -37.78824563...
# 2     {'lon': 144.944834333959, 'lat': -37.788266369...
# 3     {'lon': 144.9053100082885, 'lat': -37.78756666...
# 4     {'lon': 144.95489600858124, 'lat': -37.7884406...
# ...                                                 ...
# 9994  {'lon': 144.96871673703424, 'lat': -37.7932508...
# 9995  {'lon': 144.93259426850673, 'lat': -37.7926158...
# 9996  {'lon': 144.92412717173622, 'lat': -37.7924709...
# 9997  {'lon': 144.92136564666146, 'lat': -37.7924266...
# 9998  {'lon': 144.92444215272775, 'lat': -37.7924764...
#
#                                               geo_shape      tree_area  \
# 0     {'type': 'Feature', 'geometry': {'coordinates'...   3.4240327292
# 1     {'type': 'Feature', 'geometry': {'coordinates'...  14.0760594471
# 2     {'type': 'Feature', 'geometry': {'coordinates'...  5.49496864441
# 3     {'type': 'Feature', 'geometry': {'coordinates'...  5.39040475601
# 4     {'type': 'Feature', 'geometry': {'coordinates'...  15.7932488746
# ...                                                 ...            ...
# 9994  {'type': 'Feature', 'geometry': {'coordinates'...  4.15527629006
# 9995  {'type': 'Feature', 'geometry': {'coordinates'...  2.59265241523
# 9996  {'type': 'Feature', 'geometry': {'coordinates'...   6.1555987244
# 9997  {'type': 'Feature', 'geometry': {'coordinates'...  21.1210662207
# 9998  {'type': 'Feature', 'geometry': {'coordinates'...  23.8436954763
#
#      street_fro                                         data_lin_1 yearplant  \
# 0          None  Tree Inventory: Existing data (fields from GIS...         0
# 1          None  Tree Inventory: Existing data (fields from GIS...         0
# 2          None  Tree Inventory: Existing data (fields from GIS...         0
# 3          None  Tree Inventory: Existing data (fields from GIS...         0
# 4          None  Tree Inventory: Existing data (fields from GIS...      1998
# ...         ...                                                ...       ...
# 9994       None  Tree Inventory: Existing data (fields from GIS...         0
# 9995       None  Tree Inventory: Existing data (fields from GIS...         0
# 9996       None  Tree Inventory: Existing data (fields from GIS...         0
# 9997       None  Tree Inventory: Existing data (fields from GIS...      2000
# 9998       None  Tree Inventory: Existing data (fields from GIS...         0
#
#      street_nam                                         updated_by  \
# 0          None  Grace Detailed-GIS Services. info@gracegis.com.au
# 1          None  Grace Detailed-GIS Services. info@gracegis.com.au
# 2          None  Grace Detailed-GIS Services. info@gracegis.com.au
# 3          None  Grace Detailed-GIS Services. info@gracegis.com.au
# 4          None  Grace Detailed-GIS Services. info@gracegis.com.au
# ...         ...                                                ...
# 9994       None  Grace Detailed-GIS Services. info@gracegis.com.au
# 9995       None  Grace Detailed-GIS Services. info@gracegis.com.au
# 9996       None  Grace Detailed-GIS Services. info@gracegis.com.au
# 9997       None  Grace Detailed-GIS Services. info@gracegis.com.au
# 9998       None  Grace Detailed-GIS Services. info@gracegis.com.au
#
#          shape_area park_stree  ... street_to         family ggis_id  \
# 0      3.4240327292       None  ...      None           None   67480
# 1     14.0760594471       None  ...      None           None   67481
# 2     5.49496864441       None  ...      None           None   67483
# 3     5.39040475601       None  ...      None           None   67491
# 4     15.7932488746       Park  ...      None      Myrtaceae   67495
# ...             ...        ...  ...       ...            ...     ...
# 9994  4.15527629006       None  ...      None           None   60123
# 9995  2.59265241523       None  ...      None           None   60129
# 9996   6.1555987244       None  ...      None           None   60133
# 9997  21.1210662207     Street  ...      None  Anacardiaceae   60137
# 9998  23.8436954763       None  ...      None           None   60140
#
#         overhead_c                date_plant t11 canopy_dia height_11  \
# 0             None                      None  11        0.0       1.0
# 1             None                      None  11        0.0       8.0
# 2             None                      None  11        0.0       2.0
# 3             None                      None  11        0.0       3.0
# 4     None Present  1998-03-12T08:00:00.000Z  11        0.0       6.0
# ...            ...                       ...  ..        ...       ...
# 9994          None                      None  11        0.0       2.0
# 9995          None                      None  11        0.0       1.0
# 9996          None                      None  11        0.0       2.0
# 9997  None Present  2000-01-01T08:00:00.000Z  11        5.3       4.0
# 9998          None                      None  11        0.0       5.0
#
#                            descriptio roadseg_de
# 0                                None       None
# 1                                None       None
# 2                                None       None
# 3                                None       None
# 4     Tree - Eucalyptus camaldulensis       None
# ...                               ...        ...
# 9994                             None       None
# 9995                             None       None
# 9996                             None       None
# 9997             Tree - Schinus molle       None
# 9998                             None       None
#
# [9999 rows x 51 columns]

# %%
# Filter to only include tree locations
tree_11_df = tree_11_df[['geo_point_2d']]
tree_21_df = tree_21_df[['geo_point_2d']]

# %%
# Filter to development completion and location
dev_df = dev_df.rename(columns={'geopoint': 'geo_point_2d'}) #for convenience in later function
dev_df = dev_df[['year_completed','geo_point_2d']]

# %%
# Function to convert 'geo_point_2d' from dictionary to separate latitude and longitude columns
def extract_lat_lon(df):
    df['latitude'] = df['geo_point_2d'].apply(lambda x: x.get('lat'))
    df['longitude'] = df['geo_point_2d'].apply(lambda x: x.get('lon'))
    return df

# %%
dev_df = extract_lat_lon(dev_df)
tree_11_df = extract_lat_lon(tree_11_df)
tree_21_df = extract_lat_lon(tree_21_df)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2016\3263583511.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['latitude'] = df['geo_point_2d'].apply(lambda x: x.get('lat'))
# C:\Users\User\AppData\Local\Temp\ipykernel_2016\3263583511.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['longitude'] = df['geo_point_2d'].apply(lambda x: x.get('lon'))

# %%
# Convert the DataFrame to a GeoDataFrame
def create_gdf(df):
    geometry = [Point(xy) for xy in zip(df['longitude'], df['latitude'])]
    return gpd.GeoDataFrame(df, crs="EPSG:4326", geometry=geometry)

# %%
dev_gdf = create_gdf(dev_df)
tree_11_gdf = create_gdf(tree_11_df)
tree_21_gdf = create_gdf(tree_21_df)

# %%
# Perform spatial join between development sites and tree canopies
# Adjust 'radius' as necessary for your analysis
radius = 0.001  # roughly equal to 100 meters
buffer_dev_gdf = dev_gdf.copy()
buffer_dev_gdf['geometry'] = buffer_dev_gdf.geometry.buffer(radius)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2016\378276997.py:5: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   buffer_dev_gdf['geometry'] = buffer_dev_gdf.geometry.buffer(radius)

# %%
# Count trees around each development site for both years
trees_near_dev_2011 = gpd.sjoin(buffer_dev_gdf, tree_11_gdf, how='left', op='intersects')
trees_near_dev_2021 = gpd.sjoin(buffer_dev_gdf, tree_21_gdf, how='left', op='intersects')

# Group by development site and count trees
tree_counts_2011 = trees_near_dev_2011.groupby('development_site_id').size()
tree_counts_2021 = trees_near_dev_2021.groupby('development_site_id').size()

# Calculate the change in tree count
tree_change = tree_counts_2021 - tree_counts_2011
# Out:
# C:\Users\User\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:3488: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# C:\Users\User\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:3488: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Ubuntu\home\twar9432\assignments\Team Project\MOP-Code\Playground\Thomas\EDA.ipynb Cell 12 line 6
#       <a href='vscode-notebook-cell://wsl%24/Ubuntu/home/twar9432/assignments/Team%20Project/MOP-Code/Playground/Thomas/EDA.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> trees_near_dev_2021 = gpd.sjoin(buffer_dev_gdf, tree_21_gdf, how='left', op='intersects')
#       <a href='vscode-notebook-cell://wsl%24/Ubuntu/home/twar9432/assignments/Team%20Project/MOP-Code/Playground/Thomas/EDA.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> # Group by development site and count trees
# ----> <a href='vscode-notebook-cell://wsl%24/Ubuntu/home/twar9432/assignments/Team%20Project/MOP-Code/Playground/Thomas/EDA.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a> tree_counts_2011 = trees_near_dev_2011.groupby('development_site_id').size()
#       <a href='vscode-notebook-cell://wsl%24/Ubuntu/home/twar9432/assignments/Team%20Project/MOP-Code/Playground/Thomas/EDA.ipynb#X14sZmlsZQ%3D%3D?line=6'>7</a> tree_counts_2021 = trees_near_dev_2021.groupby('development_site_id').size()
#       <a href='vscode-notebook-cell://wsl%24/Ubuntu/home/twar9432/assignments/Team%20Project/MOP-Code/Playground/Thomas/EDA.ipynb#X14sZmlsZQ%3D%3D?line=8'>9</a> # Calculate the change in tree count
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:8869, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8866 if level is None and by is None:
#    8867     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8869 return DataFrameGroupBy(
#    8870     obj=self,
#    8871     keys=by,
#    8872     axis=axis,
#    8873     level=level,
#    8874     as_index=as_index,
#    8875     sort=sort,
#    8876     group_keys=group_keys,
#    8877     observed=observed,
#    8878     dropna=dropna,
#    8879 )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1278, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1275 self.dropna = dropna
#    1277 if grouper is None:
# -> 1278     grouper, exclusions, obj = get_grouper(
#    1279         obj,
#    1280         keys,
#    1281         axis=axis,
#    1282         level=level,
#    1283         sort=sort,
#    1284         observed=False if observed is lib.no_default else observed,
#    1285         dropna=self.dropna,
#    1286     )
#    1288 if observed is lib.no_default:
#    1289     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\grouper.py:1009, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1007         in_axis, level, gpr = False, gpr, None
#    1008     else:
# -> 1009         raise KeyError(gpr)
#    1010 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1011     # Add key to exclusions
#    1012     exclusions.add(gpr.key)
#
# KeyError: 'development_site_id'
