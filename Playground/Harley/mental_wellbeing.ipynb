# %% [markdown]
# <div class="usecase-title">Mental Wellbeing</div>
#
# <div class="usecase-authors"><b>Authored by: </b>Harley Ngo</div>
#
# <div class="usecase-date"><b>Date: </b> March 2023</div>

# %% [markdown]
# <div class="usecase-duration"><b>Duration:</b> 90 mins</div>
#
# <div class="usecase-level-skill">
#     <div class="usecase-level"><b> Level: </b>Intermediate</div>
#     <div class="usecase-skill"><b> Pre-requisite Skills: </b>Python

# %% [markdown]
# <div class="usecase-subsection-blurb">
#   <i>Dataset 1:</i> Indicators of wellbeing by year (Future Melbourne)
#   <br>
#   <a href="https://data.melbourne.vic.gov.au/explore/dataset/indicators-of-wellbeing-by-year-future-melbourne/table/" target="_blank">Dataset Link</a>
#   <br>
# </div>
# <br>
#
# <div class="usecase-subsection-blurb">
#   <i>Dataset 2:</i> Indicators of quality of life and city services by year
#   <br>
#   <a href="https://data.melbourne.vic.gov.au/explore/dataset/indicators-of-quality-of-life-and-city-services-by-year/table/" target="_blank">Dataset Link</a>
#   <br>
# </div>
# <br>

# %%
#Import core libraries
import requests
import pandas as pd
import numpy as np
import os

# %%
def fetch_data(base_url, dataset, api_key, num_records=99, offset=0):
    all_records = []
    max_offset = 9900

    while True:
        if offset > max_offset:
            break

        filters = f'{dataset}/records?limit={num_records}&offset={offset}'
        url = f'{base_url}{filters}&api_key={api_key}'

        try:
            result = requests.get(url, timeout = 10)
            result.raise_for_status()
            records = result.json().get('results')
        except requests.exceptions.RequestException as e:
            raise Exception(f'API request failed: {e}')
        if records is None:
            break
        all_records.extend(records)
        if len(records) < num_records:
            break

        offset += num_records

    df = pd.DataFrame(all_records)
    return df

BASE_URL = 'https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/'
API_KEY = ''

# %% [markdown]
# #### Dataset 1: Indicators of wellbeing by year (Future Melbourne)

# %%
SENSOR_DATASET = 'indicators-of-wellbeing-by-year-future-melbourne'
activities = fetch_data(BASE_URL, SENSOR_DATASET, API_KEY)
activities.head()
# Out:
#                   indicator_label  \
# 0                          Health
# 1     Currently achieving in life
# 2   Personal relationships (Male)
# 3         Community connectedness
# 4  Community connectedness (Male)
#
#                                indicator_description unit  2012  2013  2014  \
# 0  How satisfied people feel with their health (a...    %  77.9  78.9  78.4
# 1  How satisfied people feel with what people are...    %  73.5  74.8  74.3
# 2  How satisfied people feel with their personal ...    %  76.2  78.4  81.6
# 3  How satisfied people are with feeling part of ...    %  67.4  68.4  70.4
# 4  How satisfied people are with feeling part of ...    %  66.9  69.1  69.5
#
#    2015  2016 population                          source
# 0  77.2  78.6   Resident  Future Melbourne Social Survey
# 1  74.6  75.1   Resident  Future Melbourne Social Survey
# 2  78.1  77.4   Resident  Future Melbourne Social Survey
# 3  70.7  68.9   Resident  Future Melbourne Social Survey
# 4  70.6  67.6   Resident  Future Melbourne Social Survey

# %% [markdown]
# #### Dataset 2: Indicators of quality of life and city services by year

# %%
SENSOR_DATASET = 'indicators-of-quality-of-life-and-city-services-by-year'
activities = fetch_data(BASE_URL, SENSOR_DATASET, API_KEY)
activities.head()
# Out:
#    number indicator_theme               indicator_variable  \
# 0     5.3         Economy     Population Living in Poverty
# 1     7.3          Energy  Public Building Electricity Use
# 2     7.6          Energy         Electrical Interruptions
# 3     8.4     Environment                NO2 Concentration
# 4     8.8     Environment         Change in Native Species
#
#                                 indicator_descriptor        type  \
# 0    Percentage of city population living in poverty        Core
# 1  Energy (electricity) consumption of public bui...        Core
# 2  Average number of electrical interruptions per...  Supporting
# 3               NO? (nitrogen dioxide) concentration  Supporting
# 4      Percentage change in number of native species  Supporting
#
#    greater_melbourne_value greater_melbourne_year greater_melbourne_units  \
# 0                   8.2000                   2014                       %
# 1                      NaN                   None                  kWh/m²
# 2                   1.3069                   2010            /customer/yr
# 3                  15.8693                   2014                   ?g/m³
# 4                      NaN                   None                       %
#
#    melbourne_municipality_value melbourne_municipality_year  \
# 0                       11.0223                        2014
# 1                      360.7616                        2014
# 2                        0.2810                        2010
# 3                       15.8693                        2014
# 4                           NaN                        None
#
#   melbourne_municipality_units
# 0                         None
# 1                         None
# 2                         None
# 3                         None
# 4                         None
