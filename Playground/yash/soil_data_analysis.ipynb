# %%
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %%
pip install folium
# Out:
# Collecting folium
#   Obtaining dependency information for folium from https://files.pythonhosted.org/packages/a2/1a/37c7ee1bc806d6c32621fecc72c19f6a9f9b4369e5e8f406a7c16d49f031/folium-0.15.0-py2.py3-none-any.whl.metadata
#   Downloading folium-0.15.0-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting branca>=0.6.0 (from folium)
#   Obtaining dependency information for branca>=0.6.0 from https://files.pythonhosted.org/packages/2f/e7/603b136221de923055716d23e3047da71f92e0d8ba2c4517ce49a54fe768/branca-0.7.0-py3-none-any.whl.metadata
#   Downloading branca-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\yashd\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in c:\users\yashd\anaconda3\lib\site-packages (from folium) (1.24.3)
# Requirement already satisfied: requests in c:\users\yashd\anaconda3\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\yashd\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yashd\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yashd\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yashd\anaconda3\lib\site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yashd\anaconda3\lib\site-packages (from requests->folium) (2023.7.22)
# Downloading folium-0.15.0-py2.py3-none-any.whl (100 kB)
#    ---------------------------------------- 0.0/100.3 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/100.3 kB ? eta -:--:--
#    ----------- --------------------------- 30.7/100.3 kB 435.7 kB/s eta 0:00:01
#    -------------------------------------- 100.3/100.3 kB 958.1 kB/s eta 0:00:00
# Downloading branca-0.7.0-py3-none-any.whl (25 kB)
# Installing collected packages: branca, folium
# Successfully installed branca-0.7.0 folium-0.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
base_url = 'https://data.melbourne.vic.gov.au/api/explore/v2.0/catalog/datasets/'

#Dataset name
dataset = 'soil-sensor-readings-historical-data'
number_of_records = 200

# Add a filter for the number of results returned
filters = f'records?limit={number_of_records}&offset=0&timezone=UTC'

soil_reading_url = f'{base_url}{dataset}/{filters}'
soil_reading_url
# Out:
# 'https://data.melbourne.vic.gov.au/api/explore/v2.0/catalog/datasets/soil-sensor-readings-historical-data/records?limit=200&offset=0&timezone=UTC'

# %%
# Function that extracts the data from the JSON 
def get_data(base, data_url, offset = 0):
    
    filters = f'records?limit={100}&offset={offset}&timezone=UTC'
    url = f'{base}{data_url}/{filters}'
    result = requests.get(url)
    # if you need to extract more than 9900 records, enter the api key like below
    #result = requests.get(url + f'&apikey={API_KEY}')
    result_json = result.json()
    max_results = result_json['total_count']
    links = result_json['links']
    records = result_json['records']
    records_df = pd.json_normalize(records)
    
    # fix columns names
    records_df.drop(columns=['links'],inplace=True)
    column_names = records_df.columns.values.tolist()
    
    column_names = [i.split('.')[-1] for i in column_names]
    records_df.columns = column_names
    
    next_url = None
    
    # get next url
    if records_df.shape[0] != max_results:
        for l in links:
            if l['rel']=='next':
                next_url = l['href']
                
    return [records_df, next_url, column_names]

# %%
# Appends each set of data 
def add_to_dataframe(dataframe, new_data):
    df = pd.concat([dataframe, new_data])
    return df

# %%
# Extracts the data from the url to produce a pandas dataset
def extract_dataframe(dataset):
    df_new, url_next, column_names = get_data(base_url, dataset)
    df = pd.DataFrame(columns=column_names)
    while url_next != None:
        df_new, url_next, column_names = get_data(base_url, dataset, df.shape[0])
        df = add_to_dataframe(df, df_new)
        # This limits the dataset to only 9900 entries, should be removed if you want to import more data
        # To get more than 9900, enter the API key in the get data function
        if df.shape[0] == 9900:
            break
    return df

# %%
# Base url for v2 api
base_url = 'https://data.melbourne.vic.gov.au/api/explore/v2.0/catalog/datasets/'

# A filter at the end of the url
number_of_records = 100
filters = f'records?limit={number_of_records}&offset=0&timezone=UTC'

# The generated url
# dataset_url = f'{base_url}{dataset}/{filters}'

# %%
# Call the function and produce a dataframe
soil_df = extract_dataframe("soil-sensor-readings-historical-data")

# %%
# Use requests to get the data
result = requests.get(soil_reading_url)

# %%
result_json = result.json()
result_json.keys()
# Out:
# dict_keys(['total_count', 'links', 'records'])

# %%
result_json['total_count']
# Out:
# 1504883

# %%
records = result_json['records']

# %%
soil_df = pd.json_normalize(records)
soil_df.drop(columns = ['links'], inplace=True)

# %%
column_names = soil_df.columns.values.tolist()
column_names = [i.split('.')[-1] for i in column_names]
soil_df.columns = column_names
soil_df = soil_df.drop(columns = 'id')

# %%
soil_df
# Out:
#                                           id                timestamp size  \
# 0   200a9ce3d716056e20f45f6cf7d4ac72aec4cbf3  2023-09-01T07:08:46.91Z  128
# 1   f33bd259c443e08967d418c19a5e849aa4df5eff  2023-09-01T07:08:46.91Z  134
# 2   57a6d3071c60c235c629c95d611ce81ea6ff112e  2023-09-01T07:08:46.91Z  134
# 3   c517ba2d7110eeadf8c0b3311158b3e1f2ca0699  2023-09-01T07:08:46.91Z  140
# 4   fc9e9f6c4e8a522c36539070ad916fac8cc7db03  2023-09-01T07:08:46.91Z  140
# ..                                       ...                      ...  ...
# 95  2938b459e0e988335e39ececbcc3c1b290c4ab54  2023-09-01T07:08:46.91Z  136
# 96  c521e1427eb2f33b6e76fc0401b24f0d3279544b  2023-09-01T07:08:46.91Z  134
# 97  fa5be62a0a45f9d5d1702d4b89cb8681c94b2e46  2023-09-01T07:08:46.91Z  134
# 98  17f7b947923efd5ab44a656624b846786fb23675  2023-09-01T07:08:46.91Z  134
# 99  3d863fb78704f78baed4fd6533886aed0586e019  2023-09-01T07:08:46.91Z  128
#
#                    local_time            site_name site_id        id probe_id  \
# 0   2023-03-26T07:00:00+00:00        Treasury West   75509  16606654  1619058
# 1   2023-03-26T07:00:00+00:00        Treasury West   75509  16606662  1619067
# 2   2023-03-26T07:00:00+00:00  Princes Park Lawn 5   64993  16606675  1303869
# 3   2023-03-26T07:00:00+00:00  Princes Park Lawn 5   64993  16606694  1303877
# 4   2023-03-26T07:00:00+00:00  Princes Park Lawn 5   64993  16606713  1303875
# ..                        ...                  ...     ...       ...      ...
# 95  2023-02-08T19:00:00+00:00       Bourke North 4   64983  16039392  1311659
# 96  2023-02-09T05:00:00+00:00  Princes Park Lawn 5   64993  16039411  1303867
# 97  2023-02-08T23:00:00+00:00       Bourke North 4   64983  16039414  1311651
# 98  2023-02-08T21:00:00+00:00       Bourke North 4   64983  16039418  1311651
# 99  2023-02-09T05:00:00+00:00        Treasury West   75509  16039421  1619075
#
#                    probe_measure  soil_value   unit json_featuretype
# 0          Soil Moisture 80cm #0       48.91   %VWC   SoilSensorData
# 1       Soil Temperature 80cm #0       17.96     ºC   SoilSensorData
# 2          Soil Moisture 40cm #0       33.79   %VWC   SoilSensorData
# 3          Soil Salinity 30cm #0        0.21  µS/cm   SoilSensorData
# 4          Soil Salinity 10cm #0        0.07  µS/cm   SoilSensorData
# ..                           ...         ...    ...              ...
# 95  Soil Moisture 60cm #0 (Sand)       23.19   %VWC   SoilSensorData
# 96         Soil Moisture 20cm #0       25.09   %VWC   SoilSensorData
# 97      Soil Temperature 70cm #0       21.20     ºC   SoilSensorData
# 98      Soil Temperature 70cm #0       21.20     ºC   SoilSensorData
# 99         #0 Soil Moisture 80cm       52.04   %VWC   SoilSensorData
#
# [9900 rows x 12 columns]

# %%
# Use links & iterate calls

def get_data(base, data_url, offset = 0):
    
    filters = f'records?limit={100}&offset={offset}&timezone=UTC'
    url = f'{base}{data_url}/{filters}'
    result = requests.get(url)
    result_json = result.json()
    max_results = result_json['total_count']
    links = result_json['links']
    records = result_json['records']
    records_df = pd.json_normalize(records)
    
    # fix columns names
    records_df.drop(columns=['links'],inplace=True)
    column_names = records_df.columns.values.tolist()
    
    column_names = [i.split('.')[-1] for i in column_names]
    records_df.columns = column_names
    
    next_url = None
    
    # get next url
    if records_df.shape[0] != max_results:
        for l in links:
            if l['rel']=='next':
                next_url = l['href']
                
    return [records_df, next_url, column_names]

# %%
def add_to_dataframe(dataframe, new_data):
    df = pd.concat([dataframe, new_data])
    return df

# %%
def extract_dataframe(base_url, dataset):
    df_new, url_next, column_names = get_data(base_url, dataset)
    df = pd.DataFrame(columns=column_names)
    while url_next != None:
        df_new, url_next, column_names = get_data(base_url, dataset, df.shape[0])
        df = add_to_dataframe(df, df_new)
        if df.shape[0] == 9900:
            break
    return df

# %%
soil_df = extract_dataframe(base_url, dataset)

# %%
soil_df
# Out:
#                                           id                timestamp size  \
# 0   200a9ce3d716056e20f45f6cf7d4ac72aec4cbf3  2023-09-01T07:08:46.91Z  128
# 1   f33bd259c443e08967d418c19a5e849aa4df5eff  2023-09-01T07:08:46.91Z  134
# 2   57a6d3071c60c235c629c95d611ce81ea6ff112e  2023-09-01T07:08:46.91Z  134
# 3   c517ba2d7110eeadf8c0b3311158b3e1f2ca0699  2023-09-01T07:08:46.91Z  140
# 4   fc9e9f6c4e8a522c36539070ad916fac8cc7db03  2023-09-01T07:08:46.91Z  140
# ..                                       ...                      ...  ...
# 95  2938b459e0e988335e39ececbcc3c1b290c4ab54  2023-09-01T07:08:46.91Z  136
# 96  c521e1427eb2f33b6e76fc0401b24f0d3279544b  2023-09-01T07:08:46.91Z  134
# 97  fa5be62a0a45f9d5d1702d4b89cb8681c94b2e46  2023-09-01T07:08:46.91Z  134
# 98  17f7b947923efd5ab44a656624b846786fb23675  2023-09-01T07:08:46.91Z  134
# 99  3d863fb78704f78baed4fd6533886aed0586e019  2023-09-01T07:08:46.91Z  128
#
#                    local_time            site_name site_id        id probe_id  \
# 0   2023-03-26T07:00:00+00:00        Treasury West   75509  16606654  1619058
# 1   2023-03-26T07:00:00+00:00        Treasury West   75509  16606662  1619067
# 2   2023-03-26T07:00:00+00:00  Princes Park Lawn 5   64993  16606675  1303869
# 3   2023-03-26T07:00:00+00:00  Princes Park Lawn 5   64993  16606694  1303877
# 4   2023-03-26T07:00:00+00:00  Princes Park Lawn 5   64993  16606713  1303875
# ..                        ...                  ...     ...       ...      ...
# 95  2023-02-08T19:00:00+00:00       Bourke North 4   64983  16039392  1311659
# 96  2023-02-09T05:00:00+00:00  Princes Park Lawn 5   64993  16039411  1303867
# 97  2023-02-08T23:00:00+00:00       Bourke North 4   64983  16039414  1311651
# 98  2023-02-08T21:00:00+00:00       Bourke North 4   64983  16039418  1311651
# 99  2023-02-09T05:00:00+00:00        Treasury West   75509  16039421  1619075
#
#                    probe_measure  soil_value   unit json_featuretype
# 0          Soil Moisture 80cm #0       48.91   %VWC   SoilSensorData
# 1       Soil Temperature 80cm #0       17.96     ºC   SoilSensorData
# 2          Soil Moisture 40cm #0       33.79   %VWC   SoilSensorData
# 3          Soil Salinity 30cm #0        0.21  µS/cm   SoilSensorData
# 4          Soil Salinity 10cm #0        0.07  µS/cm   SoilSensorData
# ..                           ...         ...    ...              ...
# 95  Soil Moisture 60cm #0 (Sand)       23.19   %VWC   SoilSensorData
# 96         Soil Moisture 20cm #0       25.09   %VWC   SoilSensorData
# 97      Soil Temperature 70cm #0       21.20     ºC   SoilSensorData
# 98      Soil Temperature 70cm #0       21.20     ºC   SoilSensorData
# 99         #0 Soil Moisture 80cm       52.04   %VWC   SoilSensorData
#
# [9900 rows x 12 columns]

# %%
soil_df['probe_measure'].unique()
# Out:
# array(['Soil Moisture 80cm #0', 'Soil Temperature 80cm #0',
#        'Soil Moisture 40cm #0', 'Soil Salinity 30cm #0',
#        'Soil Salinity 10cm #0', 'Soil Moisture 20cm #0 (Clayey Loam)',
#        'Soil Moisture 30cm #0', 'Soil Temperature 10cm #0',
#        'Soil Moisture 10cm #0', 'Soil Moisture 70cm #0 (Clay)',
#        'Soil Moisture 80cm #0 (Clay)', 'Soil Temperature 70cm #0',
#        'Soil Salinity 20cm #0', 'Soil Moisture 20cm #0',
#        '#0 Soil Moisture 80cm', 'Soil Temperature 20cm #0',
#        'Soil Moisture 60cm #0', '#0 Soil Moisture 70cm',
#        'Soil Moisture 40cm #0 (Clay)', 'Soil Temperature 40cm #0',
#        '#0 Soil Moisture 30cm', 'Soil Salinity 50cm #0',
#        'Soil Moisture 50cm #0', '#0 Soil Moisture 60cm',
#        '#0 Soil Moisture 40cm', 'Soil Salinity 40cm #0',
#        'Soil Moisture 70cm #0', 'Soil Moisture 50cm #0 (Clay)',
#        '#0 Soil Moisture 50cm', 'Soil Salinity 70cm #0',
#        'Soil Temperature 50cm #0', 'Soil Moisture 30cm #0 (Clay)',
#        'Soil Moisture 30cm #0 (Sandy Loam)',
#        'Soil Moisture 40cm (Adjusted)', 'Soil Moisture 20cm',
#        'Soil Salinity 40cm', 'Soil Moisture 60cm #0 (Clay)',
#        'Soil Moisture (Adjusted) 20cm', 'Soil Moisture 60cm',
#        'Soil Moisture 20cm #0 (Sandy Loam)',
#        'Soil Moisture 30cm (Adjusted)', 'Soil Moisture 60cm #0 (Loam)',
#        'Soil Salinity 10cm', '#0 Soil Moisture 10cm Clay Loam',
#        'Soil Moisture (Adjusted) 40cm', 'Soil Temperature 30cm #0',
#        'Soil Salinity 70cm', 'Soil Moisture 10cm',
#        'Soil Salinity 60cm #0', '#0 Soil Moisture 20cm',
#        'Soil Temperature 80cm', 'Soil Salinity 30cm',
#        'Soil Temperature 10cm', 'Soil Moisture 40cm',
#        'Soil Moisture 30cm #0 (Sand)', 'Soil Temperature 40cm',
#        'Soil Temperature 70cm', 'Soil Salinity 20cm',
#        'Soil Temperature 20cm', 'Soil Salinity 50cm',
#        'Soil Salinity 80cm #0', 'Soil Moisture 60cm (Adjusted)',
#        'Soil Moisture 10cm (Adjusted)', 'Soil Moisture 80cm (Adjusted)',
#        'Soil Salinity 40 cm #0', 'Soil Temperature 30cm',
#        'Soil Temperature 60cm #0', 'Soil Salinity 60cm',
#        'Soil Moisture 20cm #0 (Sand)', 'Soil Salinity 80cm',
#        'Soil Moisture 40cm #0 (Sand)', 'Soil Moisture 10cm #0 (Sand)',
#        'Soil Moisture 70cm', 'Soil Moisture (Adjusted) 30cm',
#        'Soil Moisture 80cm', 'Soil Moisture 70cm #0 (Loam)',
#        'Soil Temperature 50cm', 'Soil Moisture (Adjusted) 50cm',
#        'Soil Moisture 20cm (Adjusted)',
#        'Soil Moisture 10cm #0 (Clayey Loam)', '#0 Soil Moisture 10cm',
#        'Soil Moisture 30cm', 'Soil Moisture 60cm #0 (Sand)',
#        'Soil Moisture 50cm', 'Soil Moisture 10cm #0 (Sandy Loam)',
#        'Soil Moisture 70cm #0 (Sand)', 'Soil Moisture 80cm #0 (Sand)',
#        'Soil Moisture (Adjusted) 60cm', 'Soil Moisture (Adjusted) 70cm',
#        'Soil Moisture (Adjusted) 10cm',
#        'Soil Moisture 30cm #0 (Clayey Loam)', 'Soil Temperature 60cm',
#        'Soil Moisture (Adjusted) 80cm', 'Soil Moisture 50cm #0 (Sand)',
#        'Soil Moisture 50cm #0 (Loam)', 'Soil Moisture 40cm #0 (Loam)',
#        'Soil Moisture 40cm #0 (Clayey Loam)',
#        'Soil Moisture 70cm (Adjusted)', 'Soil Moisture 80cm #0 (Loam)',
#        'Soil Moisture 50cm (Adjusted)', 'Soil Temperature 050cm',
#        'Soil Temperature 040cm', 'Soil Temperature 030cm',
#        'Soil Moisture 020cm', 'Soil Moisture 040cm (Adjusted)',
#        'Soil Temperature 070cm', 'Soil Temperature 010cm',
#        'Soil Temperature 020cm', 'Soil Moisture 040cm',
#        'Soil Moisture 050cm (Adjusted)', 'Soil Moisture 010cm',
#        'Soil Moisture 030cm', 'Soil Moisture 060cm',
#        'Soil Moisture 080cm', 'Soil Temperature 080cm',
#        'Soil Moisture 010cm (Adjusted)', 'Soil Moisture 030cm (Adjusted)',
#        'Soil Moisture 080cm (Adjusted)', 'Soil Moisture 020cm (Adjusted)'],
#       dtype=object)

# %%
Temperature_10 = soil_df[soil_df['probe_measure'] == 'Soil Temperature 010cm']
Temperature_10 = Temperature_10.sort_values(by='local_time')
Temperature_10
# Out:
#                                           id                timestamp size  \
# 93  0f9fc711be205e790dc2dae0119fbffe991896c2  2023-09-01T07:08:46.91Z  142
# 3   6c052fa818bf89a55cc6187d4f13481a3531d3b8  2023-09-01T07:08:46.91Z  143
# 27  88e1cdbbe8b9f0f3a6a92da82abc8ed037262ce2  2023-09-01T07:08:46.91Z  143
# 49  3577ed61206f8dabdc030c6ad01680de57778172  2023-09-01T07:08:46.91Z  143
# 7   eed0d62d6d23b1dceb1aaf6d712ba1456c8495aa  2023-09-01T07:08:46.91Z  143
# 68  7c701dd955a1fa8977e6ba2d917ddfc0c8575b4a  2023-09-01T07:08:46.91Z  143
# 47  7ba0da125560bcb1062537b62209d5c8447f2e94  2023-09-01T07:08:46.91Z  143
# 63  a2af824e2f7243757474aa814f52cca97c94f960  2023-09-01T07:08:46.91Z  143
# 16  8697cc6bca8907150926e72c34a66990e88f771d  2023-09-01T07:08:46.91Z  143
# 24  ddb96b6dc9fabe6b56543878a1e280813b7ce815  2023-09-01T07:08:46.91Z  143
# 22  299f757a17d1509ff12b3f3d293aeaa541f45dcc  2023-09-01T07:08:46.91Z  143
# 23  3ed169c1d9b2b6e4dd6034b6014a694146fa1277  2023-09-01T07:08:46.91Z  143
#
#                    local_time                site_name site_id        id  \
# 93  2023-02-08T16:00:00+00:00  Southbank Bvd Playspace  126588  16038802
# 3   2023-02-08T16:30:00+00:00  Southbank Bvd Playspace  126588  16038153
# 27  2023-02-08T17:00:00+00:00  Southbank Bvd Playspace  126588  16038336
# 49  2023-02-08T18:00:00+00:00  Southbank Bvd Playspace  126588  16038454
# 7   2023-02-08T18:30:00+00:00  Southbank Bvd Playspace  126588  16038176
# 68  2023-02-08T21:00:00+00:00  Southbank Bvd Playspace  126588  16038644
# 47  2023-02-09T00:30:00+00:00  Southbank Bvd Playspace  126588  16038439
# 63  2023-02-09T01:00:00+00:00  Southbank Bvd Playspace  126588  16038596
# 16  2023-02-09T01:30:00+00:00  Southbank Bvd Playspace  126588  16038253
# 24  2023-03-25T19:30:00+00:00  Southbank Bvd Playspace  126588  16605633
# 22  2023-03-25T23:00:00+00:00  Southbank Bvd Playspace  126588  16605835
# 23  2023-03-25T23:30:00+00:00  Southbank Bvd Playspace  126588  16605931
#
#    probe_id           probe_measure  soil_value unit json_featuretype
# 93  2239501  Soil Temperature 010cm       20.90   ºC   SoilSensorData
# 3   2239501  Soil Temperature 010cm       21.03   ºC   SoilSensorData
# 27  2239501  Soil Temperature 010cm       21.27   ºC   SoilSensorData
# 49  2239501  Soil Temperature 010cm       21.91   ºC   SoilSensorData
# 7   2239501  Soil Temperature 010cm       22.31   ºC   SoilSensorData
# 68  2239501  Soil Temperature 010cm       24.13   ºC   SoilSensorData
# 47  2239501  Soil Temperature 010cm       24.27   ºC   SoilSensorData
# 63  2239501  Soil Temperature 010cm       24.23   ºC   SoilSensorData
# 16  2239501  Soil Temperature 010cm       24.15   ºC   SoilSensorData
# 24  2239501  Soil Temperature 010cm       17.87   ºC   SoilSensorData
# 22  2239501  Soil Temperature 010cm       18.07   ºC   SoilSensorData
# 23  2239501  Soil Temperature 010cm       18.06   ºC   SoilSensorData

# %%
Temperature_20 = soil_df[soil_df['probe_measure'] == 'Soil Temperature 020cm']
Temperature_20 = Temperature_20.sort_values(by='local_time')
Temperature_20
# Out:
#                                           id                timestamp size  \
# 37  d87563a6786991a9838a2f70ea4cbde320a3ed62  2023-09-01T07:08:46.91Z  143
# 14  8b51e540ac500ce83de37e85b7e37163958c7d6a  2023-09-01T07:08:46.91Z  142
# 67  db82de888c3b57cd4308b60301ac3f8e2fd0fd3d  2023-09-01T07:08:46.91Z  143
# 62  987590297ce0ed2dfd0f05aa17a0d6036ff396ce  2023-09-01T07:08:46.91Z  143
# 3   c0a7a7ee109dc03286370c552726f5677db27a6a  2023-09-01T07:08:46.91Z  143
# 42  34a1383e5804104f5164a14f382bb7c67518c694  2023-09-01T07:08:46.91Z  143
# 98  2cfc91fff1130686e76b820839de3a5fe7999a30  2023-09-01T07:08:46.91Z  143
# 97  dab76ebe61729e2b04f1f81fc796f3b4e3ee3aa3  2023-09-01T07:08:46.91Z  143
# 56  2e0a65a60b5c8fce5f87814b4e8b9876007542bd  2023-09-01T07:08:46.91Z  143
# 18  f012586e6d5b9259b45b55d4b2cea38918137bdc  2023-09-01T07:08:46.91Z  143
# 82  efb6db9184bea236292d74ea132c372119f7cfc6  2023-09-01T07:08:46.91Z  143
# 38  e41814f2ed222aa7c7ca6287850b7a5dae669cf1  2023-09-01T07:08:46.91Z  143
# 45  132e98fc2aa1f9f98dc0e0e1796f01f11623cbf9  2023-09-01T07:08:46.91Z  143
# 8   5bacac1cd8d1bda6a135aaa08c14844259892154  2023-09-01T07:08:46.91Z  143
# 88  38ef41b2b197c649d7d6d36bd567db5acbc8f8b2  2023-09-01T07:08:46.91Z  143
# 38  32a07f7e8efef7491d530d8b697ffa79a1e2ef49  2023-09-01T07:08:46.91Z  143
# 84  54c2e482d4dd7a42a705f8c568bc94a6ce54047e  2023-09-01T07:08:46.91Z  143
# 89  b4a91ecca723aec68d0d81db0774e320586261fb  2023-09-01T07:08:46.91Z  143
# 13  811e8f281b89ebe48f82f1cae1e9bc07b926aaf5  2023-09-01T07:08:46.91Z  143
# 58  de48db6d4a0779932d149a57b314596a67a70419  2023-09-01T07:08:46.91Z  143
# 46  62d32ce84787469e82e01d5df2fd43f6b09c920b  2023-09-01T07:08:46.91Z  142
# 49  7f3354675961747bf556ba0a3cc5b8c7b40346c8  2023-09-01T07:08:46.91Z  143
# 1   a56966467832462595860f013138d31571d923cd  2023-09-01T07:08:46.91Z  143
# 9   c1506ffced78c3918476c76ec222bba0d593e1e8  2023-09-01T07:08:46.91Z  143
# 95  f61ed778abb45b30770e64c728d357e05e3ad3d5  2023-09-01T07:08:46.91Z  142
# 43  c176b6d04d12bbe88dbc0c0a66ba4b3d13fbc274  2023-09-01T07:08:46.91Z  142
# 69  7ccd9c326f756d6f801037b644a1f47c19c5088c  2023-09-01T07:08:46.91Z  143
#
#                    local_time                site_name site_id        id  \
# 37  2023-02-12T14:30:00+00:00  Southbank Bvd Playspace  126588  16090824
# 14  2023-02-12T15:00:00+00:00  Southbank Bvd Playspace  126588  16090640
# 67  2023-02-12T17:00:00+00:00  Southbank Bvd Playspace  126588  16091148
# 62  2023-02-12T17:30:00+00:00  Southbank Bvd Playspace  126588  16091114
# 3   2023-02-12T18:30:00+00:00  Southbank Bvd Playspace  126588  16090843
# 42  2023-02-13T00:00:00+00:00  Southbank Bvd Playspace  126588  16091017
# 98  2023-02-13T00:30:00+00:00  Southbank Bvd Playspace  126588  16091270
# 97  2023-02-13T01:30:00+00:00  Southbank Bvd Playspace  126588  16091258
# 56  2023-02-13T02:00:00+00:00  Southbank Bvd Playspace  126588  16091088
# 18  2023-02-20T18:00:00+00:00  Southbank Bvd Playspace  126588  16196960
# 82  2023-02-20T20:00:00+00:00  Southbank Bvd Playspace  126588  16196728
# 38  2023-02-20T21:30:00+00:00  Southbank Bvd Playspace  126588  16197102
# 45  2023-02-20T22:30:00+00:00  Southbank Bvd Playspace  126588  16197148
# 8   2023-02-21T02:00:00+00:00  Southbank Bvd Playspace  126588  16196895
# 88  2023-02-23T14:30:00+00:00  Southbank Bvd Playspace  126588  16236739
# 38  2023-02-23T15:00:00+00:00  Southbank Bvd Playspace  126588  16237103
# 84  2023-02-23T15:30:00+00:00  Southbank Bvd Playspace  126588  16237417
# 89  2023-02-23T16:30:00+00:00  Southbank Bvd Playspace  126588  16236743
# 13  2023-02-23T20:00:00+00:00  Southbank Bvd Playspace  126588  16236950
# 58  2023-02-23T20:30:00+00:00  Southbank Bvd Playspace  126588  16237198
# 46  2023-02-23T21:30:00+00:00  Southbank Bvd Playspace  126588  16237145
# 49  2023-02-23T22:00:00+00:00  Southbank Bvd Playspace  126588  16237153
# 1   2023-02-23T23:00:00+00:00  Southbank Bvd Playspace  126588  16236839
# 9   2023-02-24T00:00:00+00:00  Southbank Bvd Playspace  126588  16236894
# 95  2023-02-24T01:00:00+00:00  Southbank Bvd Playspace  126588  16236774
# 43  2023-02-24T01:30:00+00:00  Southbank Bvd Playspace  126588  16237129
# 69  2023-02-24T02:00:00+00:00  Southbank Bvd Playspace  126588  16237307
#
#    probe_id           probe_measure  soil_value unit json_featuretype
# 37  2239502  Soil Temperature 020cm       21.52   ºC   SoilSensorData
# 14  2239502  Soil Temperature 020cm       21.50   ºC   SoilSensorData
# 67  2239502  Soil Temperature 020cm       21.44   ºC   SoilSensorData
# 62  2239502  Soil Temperature 020cm       21.47   ºC   SoilSensorData
# 3   2239502  Soil Temperature 020cm       21.59   ºC   SoilSensorData
# 42  2239502  Soil Temperature 020cm       22.34   ºC   SoilSensorData
# 98  2239502  Soil Temperature 020cm       22.31   ºC   SoilSensorData
# 97  2239502  Soil Temperature 020cm       22.24   ºC   SoilSensorData
# 56  2239502  Soil Temperature 020cm       22.18   ºC   SoilSensorData
# 18  2239502  Soil Temperature 020cm       23.06   ºC   SoilSensorData
# 82  2239502  Soil Temperature 020cm       23.56   ºC   SoilSensorData
# 38  2239502  Soil Temperature 020cm       24.06   ºC   SoilSensorData
# 45  2239502  Soil Temperature 020cm       24.19   ºC   SoilSensorData
# 8   2239502  Soil Temperature 020cm       23.96   ºC   SoilSensorData
# 88  2239502  Soil Temperature 020cm       23.68   ºC   SoilSensorData
# 38  2239502  Soil Temperature 020cm       23.59   ºC   SoilSensorData
# 84  2239502  Soil Temperature 020cm       23.55   ºC   SoilSensorData
# 89  2239502  Soil Temperature 020cm       23.48   ºC   SoilSensorData
# 13  2239502  Soil Temperature 020cm       24.19   ºC   SoilSensorData
# 58  2239502  Soil Temperature 020cm       24.43   ºC   SoilSensorData
# 46  2239502  Soil Temperature 020cm       24.90   ºC   SoilSensorData
# 49  2239502  Soil Temperature 020cm       25.09   ºC   SoilSensorData
# 1   2239502  Soil Temperature 020cm       25.37   ºC   SoilSensorData
# 9   2239502  Soil Temperature 020cm       25.53   ºC   SoilSensorData
# 95  2239502  Soil Temperature 020cm       25.60   ºC   SoilSensorData
# 43  2239502  Soil Temperature 020cm       25.70   ºC   SoilSensorData
# 69  2239502  Soil Temperature 020cm       25.72   ºC   SoilSensorData

# %%
Temperature_30 = soil_df[soil_df['probe_measure'] == 'Soil Temperature 030cm']
Temperature_30 = Temperature_30.sort_values(by='local_time')
Temperature_30
# Out:
#                                           id                timestamp size  \
# 59  00b3fcbde21bce7044e5df08e65662097c167999  2023-09-01T07:08:46.91Z  143
# 47  6f6a339b6c87c115f40e1e7497f7c2cf10eee877  2023-09-01T07:08:46.91Z  143
# 9   b7ff92a0ceaba3896fb1694996b20cbe3bf966f6  2023-09-01T07:08:46.91Z  143
# 88  66e7118a52b842e00bf255d939c3997db00ed4fa  2023-09-01T07:08:46.91Z  143
# 24  94bfe2e0135ee3a62f06349e716fe4ee23c5a9f4  2023-09-01T07:08:46.91Z  143
# 89  35a21d34202ebe65224c29acbc712d247ff90b95  2023-09-01T07:08:46.91Z  143
# 89  5cebe359b82a419da36415eef2f3508aac00909f  2023-09-01T07:08:46.91Z  143
# 22  55bbad07d4e19a3040a5979e2e43971c57320735  2023-09-01T07:08:46.91Z  143
# 68  6d300b19b8d01accf2198572ad040b97b5d14c3d  2023-09-01T07:08:46.91Z  143
# 52  6315c19fabb7870aff2404b2e6044204d915107c  2023-09-01T07:08:46.91Z  143
# 47  e05da22206970de88bb453038cb65c72b78509b5  2023-09-01T07:08:46.91Z  143
# 77  3905248228fa351952f2dd349c33e5dbf9a984e6  2023-09-01T07:08:46.91Z  143
# 98  1d345d18d3c3ee9e951e74abcda978186a43de8b  2023-09-01T07:08:46.91Z  143
# 64  dbf34378d2b846b9c8a41c1f1f0884b85e66250b  2023-09-01T07:08:46.91Z  143
# 8   629e7a4df63d9cc353e4dfcbe694cba521eb8a63  2023-09-01T07:08:46.91Z  142
# 82  4581d3ed99441350187dc608b8e81c47e4c8964d  2023-09-01T07:08:46.91Z  143
# 79  2f3c6f1238fdc099b0f8f701e061092d183a2296  2023-09-01T07:08:46.91Z  143
#
#                    local_time                site_name site_id        id  \
# 59  2023-02-12T15:30:00+00:00  Southbank Bvd Playspace  126588  16091101
# 47  2023-02-12T16:00:00+00:00  Southbank Bvd Playspace  126588  16091027
# 9   2023-02-12T19:00:00+00:00  Southbank Bvd Playspace  126588  16090924
# 88  2023-02-12T20:00:00+00:00  Southbank Bvd Playspace  126588  16091158
# 24  2023-02-12T22:30:00+00:00  Southbank Bvd Playspace  126588  16090700
# 89  2023-02-13T01:30:00+00:00  Southbank Bvd Playspace  126588  16091162
# 89  2023-02-20T15:30:00+00:00  Southbank Bvd Playspace  126588  16196763
# 22  2023-02-20T17:00:00+00:00  Southbank Bvd Playspace  126588  16196974
# 68  2023-02-20T20:00:00+00:00  Southbank Bvd Playspace  126588  16197330
# 52  2023-02-23T15:00:00+00:00  Southbank Bvd Playspace  126588  16237170
# 47  2023-02-23T16:00:00+00:00  Southbank Bvd Playspace  126588  16237147
# 77  2023-02-23T17:00:00+00:00  Southbank Bvd Playspace  126588  16237362
# 98  2023-02-23T17:30:00+00:00  Southbank Bvd Playspace  126588  16236789
# 64  2023-02-23T20:30:00+00:00  Southbank Bvd Playspace  126588  16237261
# 8   2023-02-23T21:00:00+00:00  Southbank Bvd Playspace  126588  16236893
# 82  2023-02-23T22:00:00+00:00  Southbank Bvd Playspace  126588  16237409
# 79  2023-02-24T01:00:00+00:00  Southbank Bvd Playspace  126588  16237379
#
#    probe_id           probe_measure  soil_value unit json_featuretype
# 59  2239503  Soil Temperature 030cm       21.39   ºC   SoilSensorData
# 47  2239503  Soil Temperature 030cm       21.38   ºC   SoilSensorData
# 9   2239503  Soil Temperature 030cm       21.46   ºC   SoilSensorData
# 88  2239503  Soil Temperature 030cm       21.62   ºC   SoilSensorData
# 24  2239503  Soil Temperature 030cm       21.94   ºC   SoilSensorData
# 89  2239503  Soil Temperature 030cm       21.93   ºC   SoilSensorData
# 89  2239503  Soil Temperature 030cm       23.15   ºC   SoilSensorData
# 22  2239503  Soil Temperature 030cm       22.98   ºC   SoilSensorData
# 68  2239503  Soil Temperature 030cm       23.18   ºC   SoilSensorData
# 52  2239503  Soil Temperature 030cm       23.63   ºC   SoilSensorData
# 47  2239503  Soil Temperature 030cm       23.55   ºC   SoilSensorData
# 77  2239503  Soil Temperature 030cm       23.49   ºC   SoilSensorData
# 98  2239503  Soil Temperature 030cm       23.48   ºC   SoilSensorData
# 64  2239503  Soil Temperature 030cm       24.03   ºC   SoilSensorData
# 8   2239503  Soil Temperature 030cm       24.20   ºC   SoilSensorData
# 82  2239503  Soil Temperature 030cm       24.54   ºC   SoilSensorData
# 79  2239503  Soil Temperature 030cm       25.07   ºC   SoilSensorData

# %%
sns.set_theme()
fig, ax = plt.subplots(figsize=(15, 7.5))

ax.plot(Temperature_10['local_time'],Temperature_10['soil_value'], label = 'Temperature_10')
ax.plot(Temperature_20['local_time'], Temperature_20['soil_value'], label = 'Temperature_20')
ax.plot(Temperature_30['local_time'], Temperature_30['soil_value'], label = 'Temperature_30')



ax.set_xlabel("Date and Time")
ax.set_ylabel("SoilTemperature Value")
ax.set_title("Soil Temperature")

ax.tick_params(axis='x', rotation=45)


plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

# Assuming temp_10, temp_20, and temp_30 are your DataFrame columns
plt.figure(figsize=(15, 8))

plt.hist(Temperature_10['soil_value'], bins = 30, alpha=0.5, label='Temperature_10')
plt.hist(Temperature_20['soil_value'],bins = 30, alpha=0.5, label='Temperature_20')
plt.hist(Temperature_30['soil_value'],bins = 30, alpha=0.5, label='Temperature_30')

plt.xlabel("Soil Temperature Value")
plt.ylabel("Frequency")
plt.title("Histograms of Soil Temperature")

plt.legend()
plt.show()

# %%
sns.set_theme()
fig, ax = plt.subplots(figsize=(15, 7.5))

ax.plot(Temperature_10['local_time'], Temperature_10['soil_value'])

ax.set_xlabel("Date and Time")
ax.set_ylabel("Soil Temperature Value")


ax.tick_params(axis='x', rotation=45)

plt.tight_layout()

plt.show()

# %%
sns.set_theme()
fig, ax = plt.subplots(figsize=(15, 7.5))

ax.plot(Temperature_20['local_time'], Temperature_20['soil_value'])

ax.set_xlabel("Date and Time")
ax.set_ylabel("Soil Temperature Value")


ax.tick_params(axis='x', rotation=45)

plt.tight_layout()

plt.show()

# %%
sns.set_theme()
fig, ax = plt.subplots(figsize=(15, 7.5))

ax.plot(Temperature_30['local_time'], Temperature_30['soil_value'])

ax.set_xlabel("Date and Time")
ax.set_ylabel("Soil Temperature Value")


ax.tick_params(axis='x', rotation=45)

plt.tight_layout()

plt.show()

# %%
base_url = 'https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/'

#Dataset name
dataset = 'soil-sensor-locations'
number_of_records = 84

# Add a filter for the number of results returned
filters = f'records?limit={number_of_records}&offset=0&timezone=UTC'

soil_loc_url = f'{base_url}{dataset}/{filters}'
soil_loc_url

result = requests.get(soil_loc_url)
result_json = result.json()
records = result_json['results']
soil_loc = pd.json_normalize(records)

# %%
soil_loc
# Out:
#     site_id                        site_name    property_name  \
# 0     50921              Replaced by op63369  Fitzroy Gardens
# 1     50924                  Fitzroy West 09  Fitzroy Gardens
# 2     64971                      5th Fairway       Royal Park
# 3     64973                    Argyle Square    Argyle Square
# 4     64976                      9th Fairway       Royal Park
# ..      ...                              ...              ...
# 79    70829  Royal Parade University college             None
# 80    72758               Royal Parade South             None
# 81    75500                     Natures Play       Royal Park
# 82    75502                    Fawkner North     Fawkner Park
# 83    75504                      Batman Park      Batman Park
#
#                latitude           longitude  location.lon  location.lat
# 0    -37.81082691661315  144.98178719594011    144.981787    -37.810827
# 1    -37.81067469320403    144.979618148459    144.979618    -37.810675
# 2    -37.77920999998876  144.95251000000945    144.952510    -37.779210
# 3     -37.8029015228744    144.966010728849    144.966011    -37.802902
# 4    -37.78291999998904  144.95566000000628    144.955660    -37.782920
# ..                  ...                 ...           ...           ...
# 79   -37.79202969998415  144.95872889999418    144.958729    -37.792030
# 80   -37.79632980937252   144.9583068956953    144.958307    -37.796330
# 81     -37.795338542639  144.95093324591195    144.950933    -37.795339
# 82  -37.838433712973945    144.981016125163    144.981016    -37.838434
# 83   -37.82191850932761  144.95636750705123    144.956368    -37.821919
#
# [84 rows x 7 columns]

# %%
soil_loc['latitude'] = soil_loc['latitude'].astype(float)
soil_loc['longitude'] = soil_loc['longitude'].astype(float)

# %%
# Create a base map
m = folium.Map(location=[soil_loc['latitude'].mean(), soil_loc['longitude'].mean()], zoom_start=15)

# Add markers for each sensor site
for _, row in soil_loc.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"Site ID: {row['site_id']}<br>Site Name: {row['site_name']}<br>Property Name: {row['property_name']}",
        icon=folium.Icon(icon="cloud"),
    ).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_79ce231d966d63f3481c3e53a705f806 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_79ce231d966d63f3481c3e53a705f806&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_79ce231d966d63f3481c3e53a705f806 = L.map(
#                 &quot;map_79ce231d966d63f3481c3e53a705f806&quot;,
#                 {
#                     center: [-37.808393183972285, 144.96397654623684],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3c6de528abaadfc31dfd0423f1dc9e3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_f3c6de528abaadfc31dfd0423f1dc9e3.addTo(map_79ce231d966d63f3481c3e53a705f806);
#
#             var marker_fe6669c0f68e756a79e71425ea62da34 = L.marker(
#                 [-37.81082691661315, 144.98178719594011],
#                 {}
#             ).addTo(map_79ce231d966d63f3481c3e53a705f806);
#
#
#             var icon_08007c5515c6fc8cf4ae5b9c6a08978f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fe6669c0f68e756a79e71425ea62da34.setIcon(icon_08007c5515c6fc8cf4ae5b9c6a08978f);
#
#
#         var popup_a6b68658736f596e353052f2a1a3debf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bdeb7ca4030677f650910ff58663d8bc = $(`&lt;div id=&quot;html_bdeb7ca4030677f650910ff58663d8bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Site ID: 50921&lt;br&gt;Site Name: Replaced by op63369&lt;br&gt;Property Name: Fitzroy Gardens&lt;/div&gt;`)[0];
#                 popup_a6b68658736f596e353052f2a1a3debf.setContent(html_bdeb7ca4030677f650910ff58663d8bc);
#
#
#
#         marker_fe6669c0f68e756a79e71425ea62da34.bindPopup(popup_a6b68658736f596e353052f2a1a3debf)
#         ;
#
#
#
#
#             var marker_9d9eefa9cbeebcc4a2ef997713b6acb4 = L.marker(
#                 [-37.81067469320403, 144.979618148459],
#                 {}
#             ).addTo(map_79ce231d966d63f3481c3e53a705f806);
#
#
#             var icon_d19ff2fd5b9413edf183230edee67108 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9d9eefa9cbeebcc4a2ef997713b6acb4.setIcon(icon_d19ff2fd5b9413edf183230edee67108);
#
#
#         var popup_e304ba43b69d3bfbc43224e6fd26802d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d10005f5e4c18741cfab4b7357998d60 = $(`&lt;div id=&quot;html_d10005f5e4c18741cfab4b7357998d60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Site ID: 50924&lt;br&gt;Site Name: Fitzroy West 09&lt;br&gt;Property Name: Fitzroy Gardens&lt;/div&gt;`)[0];
#                 popup_e304ba43b69d3bfbc43224e6fd26802d.setContent(html_d10005f5e4c18741cfab4b7357998d60);
#
#
#
#         marker_9d9eefa9cbeebcc4a2ef997713b6acb4.bindPopup(popup_e304ba43b69d3bfbc43224e6fd26802d)
#         ;
#
#
#
#
#             var marker_10ad07712e2adc4919b68fe4e10259e7 = L.marker(
#                 [-37.77920999998876, 144.95251000000945],
#                 {}
#             ).addTo(map_79ce231d966d63f3481c3e53a705f806);
#
#
#             var icon_e4e071d60e85e20f91319e56a33bf274 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_10ad07712e2adc4919b68fe4e10259e7.setIcon(icon_e4e071d60e85e20f91319e56a33bf274);
#
#
#         var popup_3b3f32602b0d9ef996c63a2b62db9f06 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9ef2a250f5633eb8834df387f74f0e18 = $(`&lt;div id=&quot;html_9ef2a250f5633eb8834df387f74f0e18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Site ID: 64971&lt;br&gt;Site Name: 5th Fairway&lt;br&gt;Property Name: Royal Park&lt;/div&gt;`)[0];
#                 popup_3b3f32602b0d9ef996c63a2b62db9f06.setContent(html_9ef2a250f5633eb8834df387f74f0e18);
#
#
#
#         marker_10ad07712e2adc4919b68fe4e10259e7.bindPopup(popup_3b3f32602b0d9ef996c63a2b62db9f06)
#         ;
#
#
#
#
#             var marker_

# %%
from folium.plugins import MarkerCluster

# Create a base map
m = folium.Map(location=[soil_loc['latitude'].mean(), soil_loc['longitude'].mean()], zoom_start=15)

# Create a Marker Cluster
marker_cluster = MarkerCluster().add_to(m)

# Add markers for each sensor site
for _, row in soil_loc.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"Site ID: {row['site_id']}<br>Site Name: {row['site_name']}<br>Property Name: {row['property_name']}",
        icon=folium.Icon(icon="cloud"),
    ).add_to(marker_cluster)

# %%
pip install geopandas
# Out:
# Collecting geopandas
#   Obtaining dependency information for geopandas from https://files.pythonhosted.org/packages/3e/cf/ede993ed7070c5487e6db550aad490178c06eaa48ad26ff5e5263f995fba/geopandas-0.14.1-py3-none-any.whl.metadata
#   Downloading geopandas-0.14.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting fiona>=1.8.21 (from geopandas)
#   Obtaining dependency information for fiona>=1.8.21 from https://files.pythonhosted.org/packages/7f/27/b24c1610c7ae5716709321f04d38d7b8b71ed531f80df4f697b9ad99cfc3/fiona-1.9.5-cp311-cp311-win_amd64.whl.metadata
#   Downloading fiona-1.9.5-cp311-cp311-win_amd64.whl.metadata (51 kB)
#      ---------------------------------------- 0.0/51.1 kB ? eta -:--:--
#      --------------- ---------------------- 20.5/51.1 kB 640.0 kB/s eta 0:00:01
#      -------------------------------------- 51.1/51.1 kB 517.4 kB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\yashd\anaconda3\lib\site-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\yashd\anaconda3\lib\site-packages (from geopandas) (2.0.3)
# Collecting pyproj>=3.3.0 (from geopandas)
#   Obtaining dependency information for pyproj>=3.3.0 from https://files.pythonhosted.org/packages/79/95/eb68113c5b5737c342bde1bab92705dabe69c16299c5a122616e50f1fbd6/pyproj-3.6.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading pyproj-3.6.1-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=1.8.0 (from geopandas)
#   Obtaining dependency information for shapely>=1.8.0 from https://files.pythonhosted.org/packages/9e/39/029c441d8af32ab423b229c4525ce5ce6707318155b59634811a4c56f5c4/shapely-2.0.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading shapely-2.0.2-cp311-cp311-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\yashd\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (22.1.0)
# Requirement already satisfied: certifi in c:\users\yashd\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (2023.7.22)
# Requirement already satisfied: click~=8.0 in c:\users\yashd\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (8.0.4)
# Collecting click-plugins>=1.0 (from fiona>=1.8.21->geopandas)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5 (from fiona>=1.8.21->geopandas)
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: six in c:\users\yashd\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\yashd\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (68.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yashd\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yashd\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\yashd\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\yashd\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (1.24.3)
# Requirement already satisfied: colorama in c:\users\yashd\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.6)
# Downloading geopandas-0.14.1-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ------- -------------------------------- 0.2/1.1 MB 3.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.3/1.1 MB 3.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.5/1.1 MB 3.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.6/1.1 MB 3.5 MB/s eta 0:00:01
#    --------------------------- ------------ 0.8/1.1 MB 3.5 MB/s eta 0:00:01
#    --------------------------------- ------ 0.9/1.1 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 1.1/1.1 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 3.2 MB/s eta 0:00:00
# Downloading fiona-1.9.5-cp311-cp311-win_amd64.whl (22.9 MB)
#    ---------------------------------------- 0.0/22.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/22.9 MB 4.3 MB/s eta 0:00:06
#     --------------------------------------- 0.3/22.9 MB 3.5 MB/s eta 0:00:07
#     --------------------------------------- 0.4/22.9 MB 3.4 MB/s eta 0:00:07
#    - -------------------------------------- 0.6/22.9 MB 3.4 MB/s eta 0:00:07
#    - -------------------------------------- 0.7/22.9 MB 3.3 MB/s eta 0:00:07
#    - -------------------------------------- 0.9/22.9 MB 3.3 MB/s eta 0:00:07
#    - -------------------------------------- 1.0/22.9 MB 3.3 MB/s eta 0:00:07
#    -- ------------------------------------- 1.2/22.9 MB 3.3 MB/s eta 0:00:07
#    -- ------------------------------------- 1.3/22.9 MB 3.2 MB/s eta 0:00:07
#    -- ------------------------------------- 1.5/22.9 MB 3.2 MB/s eta 0:00:07
#    -- ------------------------------------- 1.6/22.9 MB 3.2 MB/s eta 0:00:07
#    --- ------------------------------------ 1.8/22.9 MB 3.2 MB/s eta 0:00:07
#    --- ------------------------------------ 1.9/22.9 MB 3.2 MB/s eta 0:00:07
#    --- ------------------------------------ 2.0/22.9 MB 3.2 MB/s eta 0:00:07
#    --- ------------------------------------ 2.2/22.9 MB 3.2 MB/s eta 0:00:07
#    ---- ----------------------------------- 2.3/22.9 MB 3.2 MB/s eta 0:00:07
#    ---- ----------------------------------- 2.5/22.9 MB 3.2 MB/s eta 0:00:07
#    ---- ----------------------------------- 2.6/22.9 MB 3.2 MB/s eta 0:00:07
#    ---- ----------------------------------- 2.8/22.9 MB 3.2 MB/s eta 0:00:07
#    ----- ---------------------------------- 2.9/22.9 MB 3.2 MB/s eta 0:00:07
#    ----- ---------------------------------- 3.1/22.9 MB 3.2 MB/s eta 0:00:07
#    ----- ---------------------------------- 3.2/22.9 MB 3.2 MB/s eta 0:00:07
#    ----- ---------------------------------- 3.4/22.9 MB 3.2 MB/s eta 0:00:07
#    ------ --------------------------------- 3.5/22.9 MB 3.2 MB/s eta 0:00:07
#    ------ --------------------------------- 3.7/22.9 MB 3.2 MB/s eta 0:00:07
#    ------ --------------------------------- 3.8/22.9 MB 3.2 MB/s eta 0:00:06
#    ------ --------------------------------- 4.0/22.9 MB 3.2 MB/s eta 0:00:06
#    ------- -------------------------------- 4.1/22.9 MB 3.2 MB/s eta 0:00:06
#    ------- -------------------------------- 4.3/22.9 MB 3.2 MB/s eta 0:00:06
#    ------- -------------------------------- 4.4/22.9 MB 3.2 MB/s eta 0:00:06
#    ------- -------------------------------- 4.5/22.9 MB 3.2 MB/s eta 0:00:06
#    -------- ------------------------------- 4.7/22.9 MB 3.2 MB/s eta 0:00:06
#    -------- ------------------------------- 4.8/22.9 MB 3.2 MB/s eta 0:00:06
#    -------- ------------------------------- 5.0/22.9 MB 3.2 MB/s eta 0:00:06
#    -------- ------------------------------- 5.1/22.9 MB 3.2 MB/s eta 0:00:06
#    --------- ------------------------------ 5.3/22.9 MB 3.2 MB/s eta 0:00:06
#    --------- ------------------------------ 5.4/22.9 MB 3.2 MB/s eta 0:00:06
#    --------- ------------------------------ 5.6/22.9 MB 3.2 MB/s eta 0:00:06
#    --------- ------------------------------ 5.7/22.9 MB 3.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 5.9/22.9 MB 3.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 6.0/22.9 MB 3.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 6.2/22.9 MB 3.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 6.3/22.9 MB 3.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 6.4/22.9 MB 3.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 6.6/22.9 MB 3.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 6.7/22.9 MB 3.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 6.9/22.9 MB 3.2 MB/s eta 0:00:06
#    ------------ --------------------------- 7.0/22.9 MB 3.2 MB/s eta 0:00:06
#    ------------ --------------------------- 7.2/22.9 MB 3.2 MB/s eta 0:00:05
#    ------------ --------------------------- 7.3/22.9 MB 3.2 MB/s eta 0:00:05
#    ------------- -------------------------- 7.5/22.9 MB 3.2 MB/s eta 0:00:05
#    ------------- -------------------------- 7.6/22.9 MB 3.2 MB/s eta 0:00:05
#    ------------- -------------------------- 7.8/22.9 MB 3.2 MB/s eta 0:00:05
#    ------------- -------------------------- 7.9/22.9 MB 3.2 MB/s eta 0:00:05
#    -------------- ------------------------- 8.1/22.9 MB 3.2 MB/s eta 0:00:05
#    -------------- ------------------------- 8.2/22.9 MB 3.2 MB/s eta 0:00:05
#    -------------- ------------------------- 8.4/22.9 MB 3.2 MB/s eta 0:00:05
#    -------------- ------------------------- 8.5/22.9 MB 3.2 MB/s eta 0:00:05
#    --------------- ------------------------ 8.6/22.9 MB 3.2 MB/s eta 0:00:05
#    --------------- ------------------------ 8.8/22.9 MB 3.2 MB/s eta 0:00:05
#    --------------- ------------------------ 8.9/22.9 MB 3.2 MB/s eta 0:00:05
#    --------------- ------------------------ 9.1/22.9 MB 3.2 MB/s eta 0:00:05
#    ---------------- ----------------------- 9.2/22.9 MB 3.2 MB/s eta 0:00:05
#    ---------------- ----------------------- 9.4/22.9 MB 3.2 MB/s eta 0:00:05
#    ---------------- ----------------------- 9.5/22.9 MB 3.2 MB/s eta 0:00:05
#    ---------------- ----------------------- 9.7/22.9 MB 3.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 9.8/22.9 MB 3.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 10.0/22.9 MB 3.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 10.1/22.9 MB 3.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 10.3/22.9 MB 3.2 MB/s eta 0:00:04
#    ------------------ --------------------- 10.4/22.9 MB 3.2 MB/s eta 0:00:04
#    ------------------ --------------------- 10.6/22.9 MB 3.2 MB/s eta 0:00:04
#    ------------------ --------------------- 10.7/22.9 MB 3.2 MB/s eta 0:00:04
#    ------------------ --------------------- 10.9/22.9 MB 3.2 MB/s eta 0:00:04
#    ------------------- -------------------- 11.0/22.9 MB 3.2 MB/s eta 0:00:04
#    ------------------- -------------------- 11.2/22.9 MB 3.2 MB/s eta 0:00:04
#    ------------------- -------------------- 11.3/22.9 MB 3.2 MB/s eta 0:00:04
#    ------------------- -------------------- 11.4/22.9 MB 3.2 MB/s eta 0:00:04
#    -------------------- ------------------- 11.6/22.9 MB 3.2 MB/s eta 0:00:04
#    -------------------- ------------------- 11.7/22.9 MB 3.2 MB/s eta 0:00:04
#    -------------------- ------------------- 11.9/22.9 MB 3.2 MB/s eta 0:00:04
#    --------------------- ------------------ 12.0/22.9 MB 3.2 MB/s eta 0:00:04
#    --------------------- ------------------ 12.2/22.9 MB 3.2 MB/s eta 0:00:04
#    --------------------- ------------------ 12.3/22.9 MB 3.2 MB/s eta 0:00:04
#    --------------------- ------------------ 12.5/22.9 MB 3.2 MB/s eta 0:00:04
#    ---------------------- ----------------- 12.6/22.9 MB 3.2 MB/s eta 0:00:04
#    ---------------------- ----------------- 12.8/22.9 MB 3.2 MB/s eta 0:00:04
#    ---------------------- ----------------- 12.9/22.9 MB 3.2 MB/s eta 0:00:04
#    ---------------------- ----------------- 13.1/22.9 MB 3.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 13.2/22.9 MB 3.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 13.4/22.9 MB 3.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 13.5/22.9 MB 3.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 13.6/22.9 MB 3.2 MB/s eta 0:00:03
#    ------------------------ --------------- 13.8/22.9 MB 3.2 MB/s eta 0:00:03
#    ------------------------ --------------- 14.0/22.9 MB 3.2 MB/s eta 0:00:03
#    ------------------------ --------------- 14.1/22.9 MB 3.2 MB/s eta 0:00:03
#    ------------------------ --------------- 14.2/22.9 MB 3.2 MB/s eta 0:00:03
#    ------------------------- -------------- 14.4/22.9 MB 3.2 MB/s eta 0:00:03
#    ------------------------- -------------- 14.5/22.9 MB 3.2 MB/s eta 0:00:03
#    ------------------------- -------------- 14.7/22.9 MB 3.2 MB/s eta 0:00:03
#    ------------------------- -------------- 14.8/22.9 MB 3.1 MB/s eta 0:00:03
#    -------------------------- ------------- 15.0/22.9 MB 3.2 MB/s eta 0:00:03
#    -------------------------- ------------- 15.1/22.9 MB 3.2 MB/s eta 0:00:03
#    -------------------------- ------------- 15.3/22.9 MB 3.1 MB/s eta 0:00:03
#    -------------------------- ------------- 15.4/22.9 MB 3.2 MB/s eta 0:00:03
#    --------------------------- ------------ 15.6/22.9 MB 3.2 MB/s eta 0:00:03
#    --------------------------- ------------ 15.7/22.9 MB 3.2 MB/s eta 0:00:03
#    --------------------------- ------------ 15.9/22.9 MB 3.2 MB/s eta 0:00:03
#    --------------------------- ------------ 16.0/22.9 MB 3.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 16.1/22.9 MB 3.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 16.3/22.9 MB 3.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 16.4/22.9 MB 3.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 16.6/22.9 MB 3.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 16.7/22.9 MB 3.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 16.9/22.9 MB 3.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 17.0/22.9 MB 3.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 17.2/22.9 MB 3.2 MB/s eta 0:00:02
#    ------------------------------ --------- 17.3/22.9 MB 3.2 MB/s eta 0:00:02
#    ------------------------------ --------- 17.5/22.9 MB 3.2 MB/s eta 0:00:02
#    ------------------------------ --------- 17.6/22.9 MB 3.2 MB/s eta 0:00:02
#    ------------------------------ --------- 17.8/22.9 MB 3.2 MB/s eta 0:00:02
#    ------------------------------- -------- 17.9/22.9 MB 3.2 MB/s eta 0:00:02
#    ------------------------------- -------- 18.1/22.9 MB 3.2 MB/s eta 0:00:02
#    ------------------------------- -------- 18.2/22.9 MB 3.2 MB/s eta 0:00:02
#    -------------------------------- ------- 18.3/22.9 MB 3.2 MB/s eta 0:00:02
#    -------------------------------- ------- 18.5/22.9 MB 3.2 MB/s eta 0:00:02
#    -------------------------------- ------- 18.6/22.9 MB 3.2 MB/s eta 0:00:02
#    -------------------------------- ------- 18.7/22.9 MB 3.2 MB/s eta 0:00:02
#    -------------------------------- ------- 18.9/22.9 MB 3.1 MB/s eta 0:00:02
#    --------------------------------- ------ 19.0/22.9 MB 3.1 MB/s eta 0:00:02
#    --------------------------------- ------ 19.2/22.9 MB 3.1 MB/s eta 0:00:02
#    --------------------------------- ------ 19.3/22.9 MB 3.1 MB/s eta 0:00:02
#    --------------------------------- ------ 19.5/22.9 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 19.6/22.9 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 19.8/22.9 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 19.9/22.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 20.0/22.9 MB 3.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 20.2/22.9 MB 3.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 20.3/22.9 MB 3.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 20.5/22.9 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------ --- 20.6/22.9 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------ --- 20.8/22.9 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------ --- 20.9/22.9 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------ --- 21.1/22.9 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------- -- 21.2/22.9 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------- -- 21.4/22.9 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------- -- 21.5/22.9 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------- -- 21.6/22.9 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 21.8/22.9 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 21.9/22.9 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 22.1/22.9 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 22.2/22.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  22.4/22.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  22.5/22.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  22.7/22.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  22.8/22.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  22.9/22.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 22.9/22.9 MB 3.1 MB/s eta 0:00:00
# Downloading pyproj-3.6.1-cp311-cp311-win_amd64.whl (6.1 MB)
#    ---------------------------------------- 0.0/6.1 MB ? eta -:--:--
#    - -------------------------------------- 0.2/6.1 MB 5.0 MB/s eta 0:00:02
#    -- ------------------------------------- 0.3/6.1 MB 3.9 MB/s eta 0:00:02
#    --- ------------------------------------ 0.5/6.1 MB 3.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.6/6.1 MB 3.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.8/6.1 MB 3.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.9/6.1 MB 3.4 MB/s eta 0:00:02
#    ------ --------------------------------- 1.0/6.1 MB 3.3 MB/s eta 0:00:02
#    ------- -------------------------------- 1.2/6.1 MB 3.3 MB/s eta 0:00:02
#    -------- ------------------------------- 1.4/6.1 MB 3.3 MB/s eta 0:00:02
#    --------- ------------------------------ 1.5/6.1 MB 3.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.6/6.1 MB 3.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.8/6.1 MB 3.3 MB/s eta 0:00:02
#    ------------ --------------------------- 1.9/6.1 MB 3.2 MB/s eta 0:00:02
#    ------------- -------------------------- 2.1/6.1 MB 3.2 MB/s eta 0:00:02
#    -------------- ------------------------- 2.2/6.1 MB 3.2 MB/s eta 0:00:02
#    --------------- ------------------------ 2.4/6.1 MB 3.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.5/6.1 MB 3.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 2.7/6.1 MB 3.2 MB/s eta 0:00:02
#    ------------------ --------------------- 2.8/6.1 MB 3.2 MB/s eta 0:00:02
#    ------------------- -------------------- 3.0/6.1 MB 3.2 MB/s eta 0:00:01
#    -------------------- ------------------- 3.1/6.1 MB 3.2 MB/s eta 0:00:01
#    --------------------- ------------------ 3.3/6.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.4/6.1 MB 3.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.5/6.1 MB 3.2 MB/s eta 0:00:01
#    ------------------------ --------------- 3.7/6.1 MB 3.2 MB/s eta 0:00:01
#    ------------------------- -------------- 3.9/6.1 MB 3.2 MB/s eta 0:00:01
#    -------------------------- ------------- 4.0/6.1 MB 3.2 MB/s eta 0:00:01
#    --------------------------- ------------ 4.1/6.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.3/6.1 MB 3.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.4/6.1 MB 3.2 MB/s eta 0:00:01
#    ------------------------------ --------- 4.6/6.1 MB 3.2 MB/s eta 0:00:01
#    ------------------------------- -------- 4.7/6.1 MB 3.2 MB/s eta 0:00:01
#    -------------------------------- ------- 4.9/6.1 MB 3.2 MB/s eta 0:00:01
#    -------------------------------- ------- 5.0/6.1 MB 3.2 MB/s eta 0:00:01
#    --------------------------------- ------ 5.2/6.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.3/6.1 MB 3.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.5/6.1 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------ --- 5.6/6.1 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------- -- 5.8/6.1 MB 3.2 MB/s eta 0:00:01
#    -------------------------------------- - 5.9/6.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  6.1/6.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.1/6.1 MB 3.2 MB/s eta 0:00:00
# Downloading shapely-2.0.2-cp311-cp311-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    --- ------------------------------------ 0.1/1.4 MB 4.3 MB/s eta 0:00:01
#    ------- -------------------------------- 0.3/1.4 MB 3.5 MB/s eta 0:00:01
#    ------------ --------------------------- 0.4/1.4 MB 3.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.6/1.4 MB 3.3 MB/s eta 0:00:01
#    -------------------- ------------------- 0.7/1.4 MB 3.1 MB/s eta 0:00:01
#    ------------------------ --------------- 0.9/1.4 MB 3.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.0/1.4 MB 3.2 MB/s eta 0:00:01
#    -------------------------------- ------- 1.2/1.4 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------ --- 1.3/1.4 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 3.2 MB/s eta 0:00:00
# Installing collected packages: shapely, pyproj, cligj, click-plugins, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.5 geopandas-0.14.1 pyproj-3.6.1 shapely-2.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
Salinity_10 = soil_df[soil_df['probe_measure'] == 'Soil Salinity 10cm']
Salinity_10 = Salinity_10.sort_values(by='local_time')
Salinity_10
# Out:
#                                           id                timestamp size  \
# 83  fdd2985b73d09ba42c5a03fd0c8190097297c6d1  2023-09-01T07:08:46.91Z  132
# 94  9480f15b7d50fcead96adb6560b8ae8a9bc91d7c  2023-09-01T07:08:46.91Z  141
# 78  769a2a1a61401012b06b936ba1977b24a882d4b8  2023-09-01T07:08:46.91Z  132
# 76  3da042098f027eab653d240dec077adc49790ed7  2023-09-01T07:08:46.91Z  141
# 80  2bb1c96070b529ec1af847d84cadcd75958e6401  2023-09-01T07:08:46.91Z  140
# ..                                       ...                      ...  ...
# 91  e2a51e0864634e751c322225f802cefb05bef8eb  2023-09-01T07:08:46.91Z  142
# 78  096c93cf91c9e46c9ab767514d8036c966a67c62  2023-09-01T07:08:46.91Z  140
# 21  f5c89a92a21cc83991ff43f463f8ed061f0ffad4  2023-09-01T07:08:46.91Z  140
# 92  4c4d89cb1a686ef7227892b82c2653f2d32e8efd  2023-09-01T07:08:46.91Z  141
# 63  b07a69a797409f4b2f9d6e7fb1710a2355007620  2023-09-01T07:08:46.91Z  131
#
#                    local_time                 site_name site_id        id  \
# 83  2023-01-18T05:30:00+00:00            Bourke South 3   88425  15759184
# 94  2023-01-18T05:30:00+00:00    Princess bridge NE p11  101037  15756564
# 78  2023-01-18T06:00:00+00:00            Bourke South 3   88425  15755208
# 76  2023-01-18T06:00:00+00:00    Princess bridge SW p10  101034  15757095
# 80  2023-01-18T06:30:00+00:00    Princess bridge NW p01  101032  15759166
# ..                        ...                       ...     ...       ...
# 91  2023-03-26T17:00:00+00:00  Princess bridge East p06  101038  16610088
# 78  2023-03-26T17:00:00+00:00    Princess bridge NE p11  101037  16610498
# 21  2023-03-26T17:00:00+00:00    Princess bridge NW p01  101032  16612776
# 92  2023-03-26T17:00:00+00:00    Princess bridge SW p10  101034  16612379
# 63  2023-03-26T17:00:00+00:00            Bourke South 3   88425  16607457
#
#    probe_id       probe_measure  soil_value   unit json_featuretype
# 83  1914096  Soil Salinity 10cm        0.17  µS/cm   SoilSensorData
# 94  2019348  Soil Salinity 10cm        0.01  µS/cm   SoilSensorData
# 78  1914096  Soil Salinity 10cm        0.17  µS/cm   SoilSensorData
# 76  2019287  Soil Salinity 10cm        0.04  µS/cm   SoilSensorData
# 80  2019267  Soil Salinity 10cm        0.00  µS/cm   SoilSensorData
# ..      ...                 ...         ...    ...              ...
# 91  2019368  Soil Salinity 10cm        0.00  µS/cm   SoilSensorData
# 78  2019348  Soil Salinity 10cm        0.00  µS/cm   SoilSensorData
# 21  2019267  Soil Salinity 10cm        0.00  µS/cm   SoilSensorData
# 92  2019287  Soil Salinity 10cm        0.03  µS/cm   SoilSensorData
# 63  1914096  Soil Salinity 10cm        0.20  µS/cm   SoilSensorData
#
# [152 rows x 12 columns]

# %%
sns.set_theme()
fig, ax = plt.violinplots(figsize=(15, 7.5))

ax.plot(Salinity_10 ['local_time'], Salinity_10 ['soil_value'])

ax.set_xlabel("Date and Time")
ax.set_ylabel("Soil Temperature Value")


ax.tick_params(axis='x', rotation=45)

plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[148], line 2
#       1 sns.set_theme()
# ----> 2 fig, ax = plt.violinplots(figsize=(15, 7.5))
#       4 ax.plot(Salinity_10 ['local_time'], Salinity_10 ['soil_value'])
#       6 ax.set_xlabel("Date and Time")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'violinplots'

# %%
soil_df['site_name'].unique()
# Out:
# array(['Treasury West', 'Princes Park Lawn 5', '9th Fairway',
#        'Princess bridge East p06', 'Toms Block', 'Bourke South 4',
#        'Flagstaff Gardens 2', 'Natures Play', 'Bourke South 3',
#        'Bourke South 5', 'Treasury Gardens North', 'Bourke North 5',
#        'Flagstaff Gardens 3', 'Royal Parade CSIRO', 'Kings Domain North',
#        'Carlton Gardens South 1', 'Argyle Square', 'Princes Park Oval 3',
#        'Alexandra Gardens Engineers Lawn', 'Docklands Park South',
#        'Princess bridge SW p10', 'Shrine Reserve South East',
#        'Bourke South 1', 'Princes Park Oval 2',
#        "Fitzroy Gardens West '18", 'Princess bridge NW p01',
#        'Ransford Oval', 'Speakers Corner', 'Fawkner North',
#        'Princess bridge NE p11', "Fitzroy Gardens East '18",
#        'Western Oval', 'Bourke North 2', 'Carlton Gardens North',
#        'Point Park', 'Conservatory', 'McAlister Oval', '8th Green',
#        'Southbank Bvd Playspace', 'Bourke South 2', 'Bourke North 4',
#        'Cnr Barry & Leicester', 'Princess bridge SE P01',
#        'Shrine Reserve North East', 'Royal Parade South',
#        'Kings Domain East', 'Treasury Gardens South', 'Ron Barassi Oval',
#        'Shrine Reserve South West', 'Bourke North 6', 'Walker Field',
#        'Princess bridge West p06'], dtype=object)
