# %%
import requests
import pandas as pd
import os

def fetch_data(base_url, dataset, api_key, num_records=99, offset=0):
    all_records = []
    max_offset = 9900  # Maximum number of requests

    while True:
        # maximum limit check
        if offset > max_offset:
            break

        # Create API request URL
        filters = f'{dataset}/records?limit={num_records}&offset={offset}'
        url = f'{base_url}{filters}&api_key={api_key}'

        # Start request
        try:
            result = requests.get(url, timeout=10)
            result.raise_for_status()
            records = result.json().get('results')
        except requests.exceptions.RequestException as e:
            raise Exception(f"API request failed: {e}")
        if records is None:
            break
        all_records.extend(records)
        if len(records) < num_records:
            break

        # next cycle offset
        offset += num_records

    # DataFrame all data
    df = pd.DataFrame(all_records)
    return df
    
API_KEY = os.environ.get('MELBOURNE_API_KEY', input("Please enter your API key: "))
BASE_URL = 'https://melbournetestbed.opendatasoft.com/api/explore/v2.1/catalog/datasets/'
# Out:
# Please enter your API key:  360b9f81e0835e727fcb9c8a97ceab28697c28695731a2171e5d1fb5

# %%
# Microclimate Sensor Readings
CLIMATE_DATASET = 'microclimate-sensor-readings'
microclimate_readings = fetch_data(BASE_URL, CLIMATE_DATASET, API_KEY)
microclimate_readings
# Out:
#                    local_time       id  site_id sensor_id    value  \
# 0   2023-11-29T22:15:02+00:00  8110548     1011        5a    16.64
# 1   2023-11-29T22:15:03+00:00  8110592     1012        5a    18.82
# 2   2023-11-29T22:15:03+00:00  8110597     1012        5b    68.74
# 3   2023-11-29T22:15:03+00:00  8110602     1012        5c  1011.20
# 4   2023-11-29T22:15:11+00:00  8110531     1011        0b    21.80
# 5   2023-11-29T22:15:12+00:00  8110575     1012        0b    29.20
# 6   2023-11-29T22:30:02+00:00  8110559     1011        5c  1010.80
# 7   2023-11-29T22:30:02+00:00  8110593     1012        5a    18.87
# 8   2023-11-29T22:30:02+00:00  8110598     1012        5b    68.79
# 9   2023-11-29T22:30:02+00:00  8110603     1012        5c  1011.30
# 10  2023-11-29T22:30:03+00:00  8110563     1011         6     0.00
# 11  2023-11-29T22:45:02+00:00  8110550     1011        5a    17.07
# 12  2023-11-29T22:45:02+00:00  8110599     1012        5b    68.80
# 13  2023-11-29T22:45:03+00:00  8110608     1012         6     0.00
# 14  2023-11-29T22:45:11+00:00  8110501     1009        0b    27.00
# 15  2023-11-29T22:45:11+00:00  8110533     1011        0b    28.90
# 16  2023-11-29T22:45:11+00:00  8110568     1012        0a     6.10
# 17  2023-11-29T23:00:02+00:00  8110551     1011        5a    17.49
# 18  2023-11-29T23:00:02+00:00  8110561     1011        5c  1010.40
# 19  2023-11-29T23:00:02+00:00  8110595     1012        5a    18.89
# 20  2023-11-29T23:00:11+00:00  8110502     1009        0b    23.30
# 21  2023-11-29T22:15:02+00:00  8110553     1011        5b    74.38
# 22  2023-11-29T22:15:02+00:00  8110558     1011        5c  1010.80
# 23  2023-11-29T22:15:03+00:00  8110562     1011         6     0.00
# 24  2023-11-29T22:15:04+00:00  8110606     1012         6     0.00
# 25  2023-11-29T22:15:11+00:00  8110489     1009        0a     5.30
# 26  2023-11-29T22:30:02+00:00  8110554     1011        5b    74.19
# 27  2023-11-29T22:30:11+00:00  8110490     1009        0a     5.20
# 28  2023-11-29T22:30:11+00:00  8110500     1009        0b    19.30
# 29  2023-11-29T22:30:11+00:00  8110523     1011        0a     5.90
# 30  2023-11-29T22:30:11+00:00  8110532     1011        0b    24.80
# 31  2023-11-29T22:30:11+00:00  8110576     1012        0b    21.30
# 32  2023-11-29T22:45:02+00:00  8110604     1012        5c  1011.10
# 33  2023-11-29T22:45:11+00:00  8110491     1009        0a     5.20
# 34  2023-11-29T23:00:02+00:00  8110556     1011        5b    70.69
# 35  2023-11-29T23:00:02+00:00  8110605     1012        5c  1010.90
# 36  2023-11-29T23:00:03+00:00  8110565     1011         6     0.00
# 37  2023-11-29T23:00:11+00:00  8110492     1009        0a     5.10
# 38  2023-11-29T23:00:11+00:00  8110569     1012        0a     5.50
# 39  2023-11-29T22:15:11+00:00  8110499     1009        0b    22.10
# 40  2023-11-29T22:15:11+00:00  8110522     1011        0a     5.70
# 41  2023-11-29T22:15:12+00:00  8110566     1012        0a     7.00
# 42  2023-11-29T22:30:02+00:00  8110549     1011        5a    16.81
# 43  2023-11-29T22:30:03+00:00  8110607     1012         6     0.00
# 44  2023-11-29T22:30:11+00:00  8110567     1012        0a     5.40
# 45  2023-11-29T22:45:02+00:00  8110555     1011        5b    71.38
# 46  2023-11-29T22:45:02+00:00  8110560     1011        5c  1010.90
# 47  2023-11-29T22:45:02+00:00  8110594     1012        5a    18.89
# 48  2023-11-29T22:45:03+00:00  8110564     1011         6     0.00
# 49  2023-11-29T22:45:11+00:00  8110524     1011        0a     5.50
# 50  2023-11-29T22:45:11+00:00  8110577     1012        0b    25.90
# 51  2023-11-29T23:00:02+00:00  8110600     1012        5b    68.70
# 52  2023-11-29T23:00:03+00:00  8110609     1012         6     0.00
# 53  2023-11-29T23:00:11+00:00  8110525     1011        0a     6.80
# 54  2023-11-29T23:00:11+00:00  8110534     1011        0b    30.20
# 55  2023-11-29T23:00:11+00:00  8110578     1012        0b    21.70
#
#             type    units gatewayhub_id site_status
# 0       TPH.TEMP        C       arc1055           C
# 1       TPH.TEMP        C       arc1048           C
# 2         TPH.RH        %       arc1048           C
# 3   TPH.PRESSURE      hPa       arc1048           C
# 4           PM10  ug\/m^3       arc1055           C
# 5           PM10   ug/m^3       arc1048           C
# 6   TPH.PRESSURE      hPa       arc1055           C
# 7       TPH.TEMP        C       arc1048           C
# 8         TPH.RH        %       arc1048           C
# 9   TPH.PRESSURE      hPa       arc1048           C
# 10            WS     km/h       arc1055           C
# 11      TPH.TEMP        C       arc1055           C
# 12        TPH.RH        %       arc1048           C
# 13            WS     km/h       arc1048           C
# 14          PM10   ug/m^3       arc1050           C
# 15          PM10  ug\/m^3       arc1055           C
# 16         PM2.5   ug/m^3       arc1048           C
# 17      TPH.TEMP        C       arc1055           C
# 18  TPH.PRESSURE      hPa       arc1055           C
# 19      TPH.TEMP        C       arc1048           C
# 20          PM10   ug/m^3       arc1050           C
# 21        TPH.RH        %       arc1055           C
# 22  TPH.PRESSURE      hPa       arc1055           C
# 23            WS     km/h       arc1055           C
# 24            WS     km/h       arc1048           C
# 25         PM2.5   ug/m^3       arc1050           C
# 26        TPH.RH        %       arc1055           C
# 27         PM2.5   ug/m^3       arc1050           C
# 28          PM10   ug/m^3       arc1050           C
# 29         PM2.5  ug\/m^3       arc1055           C
# 30          PM10  ug\/m^3       arc1055           C
# 31          PM10   ug/m^3       arc1048           C
# 32  TPH.PRESSURE      hPa       arc1048           C
# 33         PM2.5   ug/m^3       arc1050           C
# 34        TPH.RH        %       arc1055           C
# 35  TPH.PRESSURE      hPa       arc1048           C
# 36            WS     km/h       arc1055           C
# 37         PM2.5   ug/m^3       arc1050           C
# 38         PM2.5   ug/m^3       arc1048           C
# 39          PM10   ug/m^3       arc1050           C
# 40         PM2.5  ug\/m^3       arc1055           C
# 41         PM2.5   ug/m^3       arc1048           C
# 42      TPH.TEMP        C       arc1055           C
# 43            WS     km/h       arc1048           C
# 44         PM2.5   ug/m^3       arc1048           C
# 45        TPH.RH        %       arc1055           C
# 46  TPH.PRESSURE      hPa       arc1055           C
# 47      TPH.TEMP        C       arc1048           C
# 48            WS     km/h       arc1055           C
# 49         PM2.5  ug\/m^3       arc1055           C
# 50          PM10   ug/m^3       arc1048           C
# 51        TPH.RH        %       arc1048           C
# 52            WS     km/h       arc1048           C
# 53         PM2.5  ug\/m^3       arc1055           C
# 54          PM10  ug\/m^3       arc1055           C
# 55          PM10   ug/m^3       arc1048           C

# %%
#Footpath steepness
FOOTPATH_STEEPNESS_DATASET = 'footpath-steepness'
footpath_steepness = fetch_data(BASE_URL, FOOTPATH_STEEPNESS_DATASET, API_KEY)
footpath_steepness
# Out:
#                                           geo_point_2d  \
# 0    {'lon': 144.94866061456034, 'lat': -37.8230361...
# 1    {'lon': 144.91714933764632, 'lat': -37.7954295...
# 2    {'lon': 144.9172426574227, 'lat': -37.79544286...
# 3    {'lon': 144.92075182140118, 'lat': -37.7958016...
# 4    {'lon': 144.92328274904054, 'lat': -37.7965483...
# ..                                                 ...
# 589  {'lon': 144.9730003110508, 'lat': -37.81031250...
# 590  {'lon': 144.9760404131569, 'lat': -37.81136901...
# 591  {'lon': 144.9760334974833, 'lat': -37.81139773...
# 592  {'lon': 144.97773986715885, 'lat': -37.8122030...
# 593  {'lon': 144.97586037320568, 'lat': -37.8132225...
#
#                                              geo_shape  grade1in  gradepc  \
# 0    {'type': 'Feature', 'geometry': {'coordinates'...       4.2    23.81
# 1    {'type': 'Feature', 'geometry': {'coordinates'...       NaN      NaN
# 2    {'type': 'Feature', 'geometry': {'coordinates'...       NaN      NaN
# 3    {'type': 'Feature', 'geometry': {'coordinates'...      35.1     2.85
# 4    {'type': 'Feature', 'geometry': {'coordinates'...     109.6     0.91
# ..                                                 ...       ...      ...
# 589  {'type': 'Feature', 'geometry': {'coordinates'...      43.7     2.29
# 590  {'type': 'Feature', 'geometry': {'coordinates'...       NaN      NaN
# 591  {'type': 'Feature', 'geometry': {'coordinates'...       NaN      NaN
# 592  {'type': 'Feature', 'geometry': {'coordinates'...      30.1     3.33
# 593  {'type': 'Feature', 'geometry': {'coordinates'...       NaN      NaN
#
#     segside statusid    asset_type  deltaz  streetid  mccid_int   mcc_id  \
# 0      None        8  Road Footway    6.77    3094.0    30821.0  1388075
# 1      None     None  Road Footway     NaN       NaN        NaN  1534622
# 2      None     None  Road Footway     NaN       NaN        NaN  1534622
# 3      None     None  Road Footway    0.23       NaN        NaN  1387592
# 4      None     None  Road Footway    0.01       NaN        NaN  1387085
# ..      ...      ...           ...     ...       ...        ...      ...
# 589    None     None  Road Footway    3.55       NaN        NaN  1467331
# 590    None     None  Road Footway     NaN       NaN        NaN  1384793
# 591    None        3  Road Footway     NaN      36.0    21856.0  1384840
# 592    None     None  Road Footway    7.17       NaN        NaN  1389054
# 593    None     None  Road Footway     NaN       NaN        NaN  1466964
#
#                          address  rlmax  rlmin  distance
# 0                    Yarra River   6.86   0.09     28.43
# 1                           None    NaN    NaN       NaN
# 2                           None    NaN    NaN       NaN
# 3                           None   2.78   2.55      8.07
# 4                           None   3.39   3.38      1.11
# ..                           ...    ...    ...       ...
# 589                         None  37.67  34.12    155.27
# 590                         None    NaN    NaN       NaN
# 591  Cl1643 from Cathedral Place    NaN    NaN       NaN
# 592                         None  32.11  24.94    215.48
# 593                         None    NaN    NaN       NaN
#
# [594 rows x 15 columns]

# %%
#Pedestrian Counting System - Past Hour (counts per minute)
PEDESTRIAN_DATASET = 'pedestrian-counting-system-past-hour-counts-per-minute'
pedestraian_count = fetch_data(BASE_URL, PEDESTRIAN_DATASET, API_KEY)
pedestraian_count
# Out:
#      location_id           sensing_datetime sensing_date sensing_time  \
# 0              3  2024-03-18T09:41:00+00:00   2024-03-18        20:41
# 1              3  2024-03-18T09:44:00+00:00   2024-03-18        20:44
# 2              3  2024-03-18T09:47:00+00:00   2024-03-18        20:47
# 3              3  2024-03-18T09:48:00+00:00   2024-03-18        20:48
# 4              3  2024-03-18T09:51:00+00:00   2024-03-18        20:51
# ..           ...                        ...          ...          ...
# 589           47  2024-03-18T10:19:00+00:00   2024-03-18        21:19
# 590           50  2024-03-18T10:13:00+00:00   2024-03-18        21:13
# 591           50  2024-03-18T10:14:00+00:00   2024-03-18        21:14
# 592           50  2024-03-18T10:17:00+00:00   2024-03-18        21:17
# 593           50  2024-03-18T10:18:00+00:00   2024-03-18        21:18
#
#      direction_1  direction_2  total_of_directions
# 0              9           35                   44
# 1             16           14                   30
# 2             33           13                   46
# 3              6           14                   20
# 4             23           11                   34
# ..           ...          ...                  ...
# 589            5            4                    9
# 590            3            1                    4
# 591            8            3                   11
# 592            6            5                   11
# 593            2            4                    6
#
# [594 rows x 7 columns]

# %%
#https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/footpath-steepness/records?limit=20
#https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/microclimate-sensor-readings/records?limit=1000
#https://melbournetestbed.opendatasoft.com/api/explore/v2.1/catalog/datasets/pedestrian-counting-system-past-hour-counts-per-minute/records?limit=90

# %% [markdown]
# #Dinuk Edited
# _**DELETE BEFORE PUBLISHING**_
#
# _This is a template also containing the style guide for use cases. The styling uses the use-case css when uploaded to the website, which will not be visible on your local machine._
#
# _Change any text marked with {} and delete any cells marked DELETE_
#
# ***

# %%
# DELETE BEFORE PUBLISHING
# This is just here so you can preview the styling on your local machine

from IPython.core.display import HTML
HTML("""
<style>
.usecase-title, .usecase-duration, .usecase-section-header {
    padding-left: 15px;
    padding-bottom: 10px;
    padding-top: 10px;
    padding-right: 15px;
    background-color: #0f9295;
    color: #fff;
}

.usecase-title {
    font-size: 1.7em;
    font-weight: bold;
}

.usecase-authors, .usecase-level, .usecase-skill {
    padding-left: 15px;
    padding-bottom: 7px;
    padding-top: 7px;
    background-color: #baeaeb;
    font-size: 1.4em;
    color: #121212;
}

.usecase-level-skill  {
    display: flex;
}

.usecase-level, .usecase-skill {
    width: 50%;
}

.usecase-duration, .usecase-skill {
    text-align: right;
    padding-right: 15px;
    padding-bottom: 8px;
    font-size: 1.4em;
}

.usecase-section-header {
    font-weight: bold;
    font-size: 1.5em;
}

.usecase-subsection-header, .usecase-subsection-blurb {
    font-weight: bold;
    font-size: 1.2em;
    color: #121212;
}

.usecase-subsection-blurb {
    font-size: 1em;
    font-style: italic;
}
</style>
""")

# %% [markdown]
# <div class="usecase-title">{Use Case Name}</div>
#
# <div class="usecase-authors"><b>Authored by: </b> {Author/s}</div>

# %% [markdown]
# <div class="usecase-duration"><b>Duration:</b> {90} mins</div>
#
# <div class="usecase-level-skill">
#     <div class="usecase-level"><b>Level: </b>{Intermediate}</div>
#     <div class="usecase-skill"><b>Pre-requisite Skills: </b>{Python, and add any more skills needed}</div>
# </div>

# %% [markdown]
# <div class="usecase-section-header">Scenario</div>

# %% [markdown]
# {Using User Story format, write a description of the problem you are trying to solve for this use case.}

# %% [markdown]
# <div class="usecase-section-header">What this use case will teach you</div>

# %% [markdown]
# At the end of this use case you will:
# - {list the skills demonstrated in your use case}

# %% [markdown]
# <div class="usecase-section-header">{Heading for introduction or background relating to problem}</div>

# %% [markdown]
# {Write your introduction here. Keep it concise. We're not after "War and Peace" but enough background information to inform the reader on the rationale for solving this problem or background non-technical information that helps explain the approach. You may also wish to give information on the datasets, particularly how to source those not being imported from the client's open data portal.}

# %% [markdown]
# ***
#
# _**DELETE BEFORE PUBLISHING**_
#
# ## Style guide for use cases
#
# ### Headers
#
# For styling within your markdown cells, there are two choices you can use for headers.
#
# 1) You can use HTML classes specific to the use case styling:
#
# ```<p class="usecase-subsection-header">This is a subsection header.</p>```
#
# <p style="font-weight: bold; font-size: 1.2em;">This is a subsection header.</p>
#
# ```<p class="usecase-subsection-blurb">This is a blurb header.</p>```
#
# <p style="font-weight: bold; font-size: 1em; font-style:italic;">This is a blurb header.</p>
#
#
# 2) Or if you like you can use the markdown header styles:
#
# ```# for h1```
#
# ```## for h2```
#
# ```### for h3```
#
# ```#### for h4```
#
# ```##### for h5```
#
# ## Plot colour schemes
#
# General advice:
# 1. Use the same colour or colour palette throughout your notebook, unless variety is necessary
# 2. Select a palette based on the type of data being represented
# 3. Consider accessibility (colourblindness, low vision)
#
# #### 1) If all of your plots only use 1-2 colors use one of the company style colors:
#
# | Light theme | Dark Theme |
# |-----|-----|
# |<p style="color:#2af598;">#2af598</p>|<p style="color:#08af64;">#08af64</p>|
# |<p style="color:#22e4ac;">#22e4ac</p>|<p style="color:#14a38e;">#14a38e</p>|
# |<p style="color:#1bd7bb;">#1bd7bb</p>|<p style="color:#0f9295;">#0f9295</p>|
# |<p style="color:#14c9cb;">#14c9cb</p>|<p style="color:#056b8a;">#056b8a</p>|
# |<p style="color:#0fbed8;">#0fbed8</p>|<p style="color:#121212;">#121212</p>|
# |<p style="color:#08b3e5;">#08b3e5</p>||
#
#
# #### 2) If your plot needs multiple colors, choose an appropriate palette using either of the following tutorials:
# - https://seaborn.pydata.org/tutorial/color_palettes.html
# - https://matplotlib.org/stable/tutorials/colors/colormaps.html
#
# #### 3) Consider accessibility as well.
#
# For qualitative plotting Seaborn's 'colorblind' palette is recommended. For maps with sequential or diverging it is recommended to use one of the Color Brewer schemes which can be previewed at https://colorbrewer2.org/.
#
# If you want to design your own colour scheme, it should use the same principles as Cynthia Brewer's research (with variation not only in hue but also, saturation or luminance).
#
# ### References
#
# Be sure to acknowledge your sources and any attributions using links or a reference list.
#
# If you have quite a few references, you might wish to have a dedicated section for references at the end of your document, linked using footnote style numbers.
#
# You can connect your in-text reference by adding the number with a HTML link: ```<a href="#fn-1">[1]</a>```
#
# and add a matching ID in the reference list using the ```<fn>``` tag: ```<fn id="fn-1">[1] Author (Year) _Title_, Publisher, Publication location.</fn>```
