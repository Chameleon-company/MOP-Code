# %%
import requests
import pandas as pd

# %%
BASE_URL = 'https://data.melbourne.vic.gov.au/api/v2/catalog/datasets/'

#Dataset name
ArtworksFountainsMonuments = 'public-artworks-fountains-and-monuments'
MemorialsSculptures = 'public-memorials-and-sculptures'
OutdoorArtworks = 'outdoor-artworks'

NUMBER_OF_RECORDS = 10

# Add a filter for the number of results returned
FILTERS = 'records?limit={0}&offset=0&timezone=UTC'.format(NUMBER_OF_RECORDS)
# Same as
FILTERS = f'records?limit={NUMBER_OF_RECORDS}&offset=0&timezone=UTC'

# %%
ArtworksFountainsMonumentsURL = f'{BASE_URL}{publicArtworksFountainsMonuments}/{FILTERS}'
ArtFountainsResult = requests.get(publicArtworksFountainsMonumentsURL)

MemorialsSculpturesURL = f'{BASE_URL}{publicMemorialsSculptures}/{FILTERS}'
MemorialSculpturesResult = requests.get(publicMemorialsSculpturesURL)

OutdoorArtworksURL = f'{BASE_URL}{OutdoorArtworks}/{FILTERS}'
OutdoorArtworksResult = requests.get(OutdoorArtworksURL)

# %%
print(ArtFountainsResult)
print(MemorialSculpturesResult)
print(OutdoorArtworksResult)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
# Use links & iterate calls

def get_data(base, data_url, size = 0):
    
    filters = f'records?limit={10}&offset={size}&timezone=UTC'
    url = f'{base}{data_url}/{filters}'
    result = requests.get(url)
    result_json = result.json()
    max_results = result_json['total_count']
    links = result_json['links']
    records = result_json['records']
    records_df = pd.json_normalize(records)
    
    # fix columns names
    records_df.drop(columns=['links'],inplace=True)
    column_names = records_df.columns.values.tolist()
    
    # Replace location.lat & location.lon
    column_names = ['_'.join((a.split(".")[-2:])) if a.split('.')[-2]=='location' else a for a in column_names]
    column_names = [i.split('.')[-1] for i in column_names]
    records_df.columns = column_names
    
    next_url = None
    
    # get next url
    if records_df.shape[0] != max_results:
        for l in links:
            if l['rel']=='next':
                next_url = l['href']
                
    return [records_df, next_url, column_names]

# %%
# Create function to add API output to dataframe
def add_to_dataframe(dataframe, new_data):
    df = pd.concat([dataframe, new_data])
    return df

# %%
ArtworksFountainsMonumentsDF, url_next, column_names = get_data(BASE_URL,ArtworksFountainsMonuments)

# %%
url_next
# Out:
# 'https://data.melbourne.vic.gov.au/api/v2/catalog/datasets/public-artworks-fountains-and-monuments/records?limit=10&offset=10&timezone=UTC&include_app_metas=False&include_links=False'

# %%
column_names
# Out:
# ['id',
#  'timestamp',
#  'size',
#  'asset_type',
#  'name',
#  'xorg',
#  'xsource',
#  'address_point',
#  'artist',
#  'alternate_name',
#  'art_date',
#  'mel_way_ref',
#  'respective_author',
#  'structure',
#  'lon',
#  'lat',
#  'easting',
#  'northing']

# %%
# Create new empty dataframe with columns
NEW_AFMDF_DF = pd.DataFrame(columns=column_names)
NEW_AFMDF_DF
# Out:
# Empty DataFrame
# Columns: [id, timestamp, size, asset_type, name, xorg, xsource, address_point, artist, alternate_name, art_date, mel_way_ref, respective_author, structure, lon, lat, easting, northing]
# Index: []

# %%
# Add initial output to datframe
NEW_AFMDF_DF = add_to_dataframe(NEW_AFMDF_DF, ArtworksFountainsMonumentsDF)
NEW_AFMDF_DF.head()
# Out:
#                                          id                 timestamp size  \
# 0  84ef8d6f74366bd58a851cb9e62148669b93293f  2022-11-13T09:58:36.005Z  314
# 1  e1b70019e59b104d764e708d5920e0ec682368cc  2022-11-13T09:58:36.005Z  351
# 2  7b0e72c727c7b6d3085eda217982d318476fd018  2022-11-13T09:58:36.005Z  334
# 3  815b6aa3fc2b4f29c01c77767ba16d7fb2902652  2022-11-13T09:58:36.005Z  334
# 4  0c718f6d02d17e51eeb3f3b0b8d283d7bbebc23e  2022-11-13T09:58:36.005Z  283
#
#   asset_type                                   name               xorg  \
# 0   Fountain                         Coles Fountain  City of Melbourne
# 1   Monument  Black Swan Memorial Drinking Fountain  City of Melbourne
# 2        Art                       Federation Bells  City of Melbourne
# 3        Art                       Federation Bells  City of Melbourne
# 4        Art                           Coat of Arms  City of Melbourne
#
#                                 xsource  \
# 0  MCC - Ortho Image March 2005 - Final
# 1  MCC - Ortho Image March 2005 - Final
# 2   MCC - Ground Ortho Image March 2008
# 3   MCC - Ground Ortho Image March 2008
# 4  MCC - Ortho Image March 2005 - Final
#
#                                  address_point  \
# 0            517 Albert Street, EAST MELBOURNE
# 1  Alexandra Gardens, St Kilda Road, MELBOURNE
# 2                    Birrarung Marr, MELBOURNE
# 3                    Birrarung Marr, MELBOURNE
# 4               104 Swanston Street, MELBOURNE
#
#                                       artist alternate_name art_date  \
# 0                            Robert Woodward           None     1981
# 1                           Raymond B. Ewers           None     1974
# 2  Designers Neil McLachlan and Anton Hasell           None     2002
# 3  Designers Neil McLachlan and Anton Hasell           None     2002
# 4                          City of Melbourne           None     1992
#
#   mel_way_ref  respective_author  \
# 0       2F_J1  City Of Melbourne
# 1       2F_J6  City Of Melbourne
# 2      2F_ K6  City of Melbourne
# 3      2F_ K6  City of Melbourne
# 4       2F_F4  City Of Melbourne
#
#                                         structure         lon        lat  \
# 0    Stainless-steel fountain on bluestone paving  144.973484 -37.809771
# 1  Bluestone drinking fountain with bronze plaque  144.971824 -37.819571
# 2    Bronze-alloy bells on galvanised-steel poles  144.974159 -37.818697
# 3    Bronze-alloy bells on galvanised-steel poles  144.974129 -37.818688
# 4                            Brass pavement inlay  144.966444 -37.815048
#
#         easting      northing
# 0  321609.36000  5.813357e+06
# 1  321486.86700  5.812266e+06
# 2  321690.25256  5.812367e+06
# 3  321687.56694  5.812368e+06
# 4  321002.34200  5.812757e+06

# %%
# Get the rest of the Dataset
while url_next != None:
    df_new, url_next, column_names = get_data(BASE_URL, ArtworksFountainsMonuments, NEW_AFMDF_DF.shape[0])
    NEW_AFMDF_DF = add_to_dataframe(NEW_AFMDF_DF, df_new)
    print(NEW_AFMDF_DF.shape)
# Out:
# (20, 18)
# (30, 18)
# (40, 18)
# (50, 18)
# (60, 18)
# (70, 18)
# (80, 18)
# (90, 18)
# (100, 18)
# (110, 18)
# (120, 18)
# (130, 18)
# (140, 18)
# (150, 18)
# (160, 18)
# (170, 18)
# (180, 18)
# (190, 18)
# (200, 18)
# (210, 18)
# (220, 18)
# (230, 18)
# (240, 18)
# (250, 18)
# (260, 18)
# (261, 18)

# %%
MemorialsSculpturesDF, url_next, column_names = get_data(BASE_URL,MemorialsSculptures)

# Create new empty dataframe with columns
NEW_MS_DF = pd.DataFrame(columns=column_names)
NEW_MS_DF
# Out:
# Empty DataFrame
# Columns: [id, timestamp, size, description, title, lon, lat]
# Index: []

# %%
# Get the rest of the Dataset
while url_next != None:
    df_new, url_next, column_names = get_data(BASE_URL, MemorialsSculptures, NEW_MS_DF.shape[0])
    NEW_MS_DF = add_to_dataframe(NEW_MS_DF, df_new)
    print(NEW_MS_DF.shape)
# Out:
# (10, 7)
# (20, 7)
# (30, 7)
# (40, 7)
# (50, 7)
# (60, 7)
# (70, 7)
# (80, 7)
# (90, 7)
# (100, 7)
# (110, 7)
# (120, 7)
# (130, 7)
# (140, 7)
# (150, 7)
# (160, 7)
# (163, 7)

# %%
OutdoorArtworksDF, url_next, column_names = get_data(BASE_URL, OutdoorArtworks)

# Create new empty dataframe with columns
NEW_OA_DF = pd.DataFrame(columns=column_names)
NEW_OA_DF
# Out:
# Empty DataFrame
# Columns: [id, timestamp, size, lon, lat, type, coordinates, type, road_segment, location, latitude, asset_id, history, owner_type, description, object_type, art_date, inscription, longitude, company, service_manager, makers, property, classification, title]
# Index: []
#
# [0 rows x 25 columns]

# %%
# Get the rest of the Dataset
while url_next != None:
    df_new, url_next, column_names = get_data(BASE_URL, OutdoorArtworks, NEW_OA_DF.shape[0])
    NEW_OA_DF = add_to_dataframe(NEW_OA_DF, df_new)
    print(NEW_OA_DF.shape)
# Out:
# (10, 25)
# (20, 25)
# (30, 25)
# (40, 25)
# (50, 25)
# (60, 25)
# (70, 25)
# (80, 25)
# (90, 25)
# (100, 25)
# (110, 25)
# (120, 25)
# (130, 25)
# (140, 25)
# (150, 25)
# (160, 25)
# (170, 25)
# (180, 25)
# (190, 25)
# (200, 25)
# (202, 25)

# %%
import folium

m = folium.Map(location=[-37.818663392, 144.9833294], zoom_start = 16)

folium.Marker(
    location=[-37.818663392, 144.9833294],
    popup='Melbourne Cricket Ground',
    icon=folium.Icon(icon = 'flag',color='orange')
).add_to(m)

for index, row in NEW_AFMDF_DF.iterrows():
    lat = row['lat']
    lon = row['lon'] 
    name = row['name']
    
    folium.Marker([lat, lon], popup=name).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ab8bbd2178a33e2d1ed021c8e33aec2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ab8bbd2178a33e2d1ed021c8e33aec2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ab8bbd2178a33e2d1ed021c8e33aec2 = L.map(
#                 &quot;map_0ab8bbd2178a33e2d1ed021c8e33aec2&quot;,
#                 {
#                     center: [-37.818663392, 144.9833294],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f181a29e231a33f26e49a7d43234c266 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0ab8bbd2178a33e2d1ed021c8e33aec2);
#
#
#             var marker_edb333e0bc16eb8225ee173e20a32841 = L.marker(
#                 [-37.818663392, 144.9833294],
#                 {}
#             ).addTo(map_0ab8bbd2178a33e2d1ed021c8e33aec2);
#
#
#             var icon_abc108df2da2e322e7a90769f76b98ea = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_edb333e0bc16eb8225ee173e20a32841.setIcon(icon_abc108df2da2e322e7a90769f76b98ea);
#
#
#         var popup_5a99c93c235cd002a42108b92ae5d6b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4776ac0d9698b5e9c83ab673f8659b26 = $(`&lt;div id=&quot;html_4776ac0d9698b5e9c83ab673f8659b26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Melbourne Cricket Ground&lt;/div&gt;`)[0];
#                 popup_5a99c93c235cd002a42108b92ae5d6b0.setContent(html_4776ac0d9698b5e9c83ab673f8659b26);
#
#
#
#         marker_edb333e0bc16eb8225ee173e20a32841.bindPopup(popup_5a99c93c235cd002a42108b92ae5d6b0)
#         ;
#
#
#
#
#             var marker_5899b8ac68639e3029a10d4bf8371392 = L.marker(
#                 [-37.8097706189194, 144.973483976518],
#                 {}
#             ).addTo(map_0ab8bbd2178a33e2d1ed021c8e33aec2);
#
#
#         var popup_282de0aa555d4b91b8ad6ecf4cfb74df = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b96519c8475dd70ce283a97540006031 = $(`&lt;div id=&quot;html_b96519c8475dd70ce283a97540006031&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coles Fountain&lt;/div&gt;`)[0];
#                 popup_282de0aa555d4b91b8ad6ecf4cfb74df.setContent(html_b96519c8475dd70ce283a97540006031);
#
#
#
#         marker_5899b8ac68639e3029a10d4bf8371392.bindPopup(popup_282de0aa555d4b91b8ad6ecf4cfb74df)
#         ;
#
#
#
#
#             var marker_a89b250e9a9c8f752747baae770590c8 = L.marker(
#                 [-37.8195705617737, 144.971824407255],
#                 {}
#             ).addTo(map_0ab8bbd2178a33e2d1ed021c8e33aec2);
#
#
#         var popup_2aacfabccd2f70375e8cfaf0de59f139 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_df3a0a2f61aebbfae308039710a89c2b = $(`&lt;div id=&quot;html_df3a0a2f61aebbfae308039710a89c2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Black Swan Memorial Drinking Fountain&lt;/div&gt;`)[0];
#                 popup_2aacfabccd2f70375e8cfaf0de59f139.setContent(html_df3a0a2f61aebbfae308039710a89c2b);
#
#
#
#         marker_a89b250e9a9c8f752747baae770590c8.bindPopup(popup_2aacfabccd2f70375e8cfaf0de59f139)
#         ;
#
#
#
#
#             var marker_9d27ba8c16e19ea0e31f4e2fd10eb78f = L.marker(
#                 [-37.8186973319473, 144.974158800684],
#                 {}
#             ).addTo(map_0ab8bbd2178a33e2d1ed021c8e33aec2);
#
#
#         var popup_dc3b9f3629257e1f6b9d0261d02c627c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_98a15f8dab2a512231c59c6839494af7 = $(`&lt;div id=&quot;html_98a15f8dab2a512231c59c6839494af7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Federation Bells&lt;/div&gt;`)[0];
#                 popup_dc3b9f3629257e1f6b9d0261d02c627c.setContent(html_98a15f8dab2a512231c59c6839494af7);
#
#
#
#         marker_9d27ba8c16e19ea0e31f4e2fd10eb78f.bindPopup(popup_dc3b9f3629257e1f6b9d0261d02c627c)
#         ;
#
#
#
#
#             var marker_8e9df3d366e7a43590e5cbc56b58e350 = L.marker(
#                 [-37.8186882333343, 144.974128540287],
#                 {}
#             ).addTo(map_0ab8bbd2178a33e2d1ed021c8e33aec2);
#
#
#         var popup_e7e5e024baa68040c4e83cd63211b3c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_61954daa067

# %%
import folium

m = folium.Map(location=[-37.818663392, 144.9833294], zoom_start = 16)

folium.Marker(
    location=[-37.818663392, 144.9833294],
    popup='Melbourne Cricket Ground',
    icon=folium.Icon(icon = 'flag',color='orange')
).add_to(m)

for index, row in NEW_AFMDF_DF.iterrows():
    lat = row['lat']
    lon = row['lon'] 
    name = row['name']
    
    folium.Marker([lat, lon], popup=name).add_to(m)
m

# %%
import folium

m = folium.Map(location=[-37.818663392, 144.9833294], zoom_start = 16)

folium.Marker(
    location=[-37.818663392, 144.9833294],
    popup='Melbourne Cricket Ground',
    icon=folium.Icon(icon = 'flag',color='orange')
).add_to(m)

for index, row in NEW_OA_DF.iterrows():
    lat = row['lat']
    lon = row['lon'] 
    name = row['name']
    
    folium.Marker([lat, lon], popup=name).add_to(m)
m
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\MachineLearningSIT307\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\envs\MachineLearningSIT307\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\MachineLearningSIT307\lib\site-packages\pandas\_libs\index.pyx:162, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\MachineLearningSIT307\lib\site-packages\pandas\_libs\index.pyx:203, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File ~\anaconda3\envs\MachineLearningSIT307\lib\site-packages\pandas\_libs\index.pyx:211, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File ~\anaconda3\envs\MachineLearningSIT307\lib\site-packages\pandas\_libs\index.pyx:107, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[161], line 14
#      12     lat = row['lat']
#      13     lon = row['lon']
# ---> 14     name = row['name']
#      16     folium.Marker([lat, lon], popup=name).add_to(m)
#      17 m
#
# File ~\anaconda3\envs\MachineLearningSIT307\lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\anaconda3\envs\MachineLearningSIT307\lib\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~\anaconda3\envs\MachineLearningSIT307\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'name'
