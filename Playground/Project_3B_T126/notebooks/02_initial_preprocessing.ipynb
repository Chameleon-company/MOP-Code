# %% [markdown]
# # Kitchener Watermains + Water Main Breaks
# ## Initial Pre-processing
#
# ### Purpose
#
# This notebook focuses on the initial data cleaning and preparation of the Kitchener watermain datasets for Project 3B.
#
# The main goals are to:
#
# - load and inspect the two raw datasets:
#   - `Kitchener_watermains.csv`
#   - `Kitchener_watermainbreaks.csv`
# - understand the structure, data types, and data quality of each dataset
# - clean and standardise key fields such as dates, numeric values, text fields, and IDs
# - identify useful columns for later analysis and modelling
# - check how the two datasets can be linked together using asset IDs and road segment IDs
# - create a clean and consistent base dataset for the next stages of the project

# %%
#Import required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import Kitchener dataset
breaks = pd.read_csv("data/Kitchener_watermainbreaks.csv")
mains = pd.read_csv("data/Kitchener_watermains.csv")

#Quick check on features
print("\nBreaks info:")
print(breaks.info())

print("\nMains info:")
print(mains.info())
# Out:
# Breaks info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2994 entries, 0 to 2993
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   OBJECTID                                        2994 non-null   int64
#  1   Wat Break Incident ID                           2994 non-null   int64
#  2   Incident date                                   2994 non-null   object
#  3   Type of Asset Broken                            2994 non-null   object
#  4   Does the road need to be closed?                540 non-null    object
#  5   Does the sidewalk need to be closed?            537 non-null    object
#  6   Estimated Hours for Repair                      538 non-null    object
#  7   Estimated Number of Units Impacted              525 non-null    object
#  8   CW Service Request Number                       25 non-null     float64
#  9   Current status of the break                     2994 non-null   object
#  10  Status last updated date                        2843 non-null   object
#  11  CW Workorder #                                  1826 non-null   float64
#  12  Date operations was returned to normal service  106 non-null    object
#  13  Nature of Break                                 2682 non-null   object
#  14  Apparent cause of break                         2558 non-null   object
#  15  Repair Type                                     246 non-null    object
#  16  Type of Planned Maintenance                     0 non-null      float64
#  17  List Valves Closed                              3 non-null      object
#  18  List Valves Opened                              2 non-null      float64
#  19  List Hydrants Called Out                        48 non-null     object
#  20  List Hydrants Called Back In                    36 non-null     object
#  21  Categorization of the Break                     2693 non-null   object
#  22  Road Segment ID                                 2994 non-null   int64
#  23  Closest Civic Number                            2897 non-null   object
#  24  Street                                          2979 non-null   object
#  25  Related Asset ID                                2994 non-null   int64
#  26  Related Asset Depth (m)                         15 non-null     float64
#  27  Depth of Frost (m)                              82 non-null     float64
#  28  Asset Size (cm)                                 2695 non-null   float64
#  29  Year Asset Installed                            2691 non-null   float64
#  30  Asset Material                                  2695 non-null   object
#  31  Asset Exists                                    2994 non-null   object
#  32  GLOBALID                                        2994 non-null   object
#  33  UPDATE_BY                                       2447 non-null   object
#  34  UPDATE_DATE                                     2447 non-null   object
#  35  x                                               2994 non-null   float64
#  36  y                                               2994 non-null   float64
# dtypes: float64(10), int64(4), object(23)
# memory usage: 865.6+ KB
# None
#
# Mains info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16163 entries, 0 to 16162
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OBJECTID              16163 non-null  int64
#  1   WATMAINID             16163 non-null  int64
#  2   STATUS                16163 non-null  object
#  3   PRESSURE_ZONE         16163 non-null  object
#  4   ROADSEGMENTID         16163 non-null  int64
#  5   MAP_LABEL             16163 non-null  object
#  6   CATEGORY              16163 non-null  object
#  7   PIPE_SIZE             16163 non-null  int64
#  8   MATERIAL              16163 non-null  object
#  9   LINED                 16163 non-null  object
#  10  LINED_DATE            54 non-null     object
#  11  LINED_MATERIAL        16163 non-null  object
#  12  INSTALLATION_DATE     16163 non-null  object
#  13  ACQUISITION           16163 non-null  object
#  14  CONSULTANT            4566 non-null   object
#  15  OWNERSHIP             16163 non-null  object
#  16  BRIDGE_MAIN           16163 non-null  object
#  17  BRIDGE_DETAILS        8 non-null      object
#  18  CRITICALITY           16163 non-null  int64
#  19  REL_CLEANING_AREA     16163 non-null  int64
#  20  REL_CLEANING_SUBAREA  16163 non-null  object
#  21  Undersized            16163 non-null  object
#  22  Shallow Main          16163 non-null  object
#  23  Condition Score       16163 non-null  float64
#  24  OVERSIZED             16163 non-null  object
#  25  CLEANED               16163 non-null  object
#  26  Shape__Length         16163 non-null  float64
# dtypes: float64(2), int64(6), object(19)
# memory usage: 3.3+ MB
# None

# %%
#Check for missing values
print("Missing values in breaks:")
print(breaks.isna().sum().sort_values(ascending=False))

print("\nMissing values in mains:")
print(mains.isna().sum().sort_values(ascending=False))
# Out:
# Missing values in breaks:
# Type of Planned Maintenance                       2994
# List Valves Opened                                2992
# List Valves Closed                                2991
# Related Asset Depth (m)                           2979
# CW Service Request Number                         2969
# List Hydrants Called Back In                      2958
# List Hydrants Called Out                          2946
# Depth of Frost (m)                                2912
# Date operations was returned to normal service    2888
# Repair Type                                       2748
# Estimated Number of Units Impacted                2469
# Does the sidewalk need to be closed?              2457
# Estimated Hours for Repair                        2456
# Does the road need to be closed?                  2454
# CW Workorder #                                    1168
# UPDATE_DATE                                        547
# UPDATE_BY                                          547
# Apparent cause of break                            436
# Nature of Break                                    312
# Year Asset Installed                               303
# Categorization of the Break                        301
# Asset Material                                     299
# Asset Size (cm)                                    299
# Status last updated date                           151
# Closest Civic Number                                97
# Street                                              15
# GLOBALID                                             0
# Asset Exists                                         0
# x                                                    0
# OBJECTID                                             0
# Related Asset ID                                     0
# Road Segment ID                                      0
# Wat Break Incident ID                                0
# Current status of the break                          0
# Type of Asset Broken                                 0
# Incident date                                        0
# y                                                    0
# dtype: int64
#
# Missing values in mains:
# BRIDGE_DETAILS          16155
# LINED_DATE              16109
# CONSULTANT              11597
# OBJECTID                    0
# CLEANED                     0
# OVERSIZED                   0
# Condition Score             0
# Shallow Main                0
# Undersized                  0
# REL_CLEANING_SUBAREA        0
# REL_CLEANING_AREA           0
# CRITICALITY                 0
# BRIDGE_MAIN                 0
# OWNERSHIP                   0
# ACQUISITION                 0
# WATMAINID                   0
# INSTALLATION_DATE           0
# LINED_MATERIAL              0
# LINED                       0
# MATERIAL                    0
# PIPE_SIZE                   0
# CATEGORY                    0
# MAP_LABEL                   0
# ROADSEGMENTID               0
# PRESSURE_ZONE               0
# STATUS                      0
# Shape__Length               0
# dtype: int64
