# %%
import pandas as pd
from d2i_tools2 import getMeta
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ## [01] read and extract meta data into df

# %%
metadf = getMeta()

print(f"** Dataframe of extracted meta data has the shape of: {metadf.shape}. **\n")
print(metadf.info())
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# ** Dataframe of extracted meta data has the shape of: (221, 21). **
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 21 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   name                                          221 non-null    object
#  1   id                                            221 non-null    object
#  2   parent_fxf                                    221 non-null    object
#  3   permalink                                     221 non-null    object
#  4   description                                   221 non-null    object
#  5   data_upd_at                                   199 non-null    datetime64[ns, UTC]
#  6   pv_last_wk                                    221 non-null    int64
#  7   pv_last_mth                                   221 non-null    int64
#  8   pv_total                                      221 non-null    int64
#  9   download_count                                221 non-null    int64
#  10  categories                                    221 non-null    object
#  11  domain_category                               221 non-null    object
#  12  domain_tags                                   221 non-null    object
#  13  Quality_What's-included                       147 non-null    object
#  14  Quality_Update-frequency                      221 non-null    object
#  15  Quality_Reliability-level                     184 non-null    object
#  16  How-to-use_Linked-to                          17 non-null     object
#  17  Data-management_Source-data-update-frequency  221 non-null    object
#  18  Quality_Known-Issues                          39 non-null     object
#  19  How-to-use_Further-information                59 non-null     object
#  20  Quality_Data-quality-statement                71 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(4), object(16)
# memory usage: 36.4+ KB
# None

# %% [markdown]
# ## [02] Example to select dataset(s) using their unique dataset id

# %%
# below are the 3 datasets that make up the live parking sensors data whole

dfparking = metadf[metadf.id.isin(['vh2v-4nfs', 'crvt-b4kt', 'ntht-5rk7'])]
dfparking.T

# NOTE: permalink is url to the corresponding dataset on the Melbourne Open Data portal
# Out:
#                                                                                              3   \
# name                                                              on-street parking bay sensors
# id                                                                                    vh2v-4nfs
# parent_fxf                                                                                   []
# permalink                                         https://data.melbourne.vic.gov.au/d/vh2v-4nfs
# description                                   contains information from in-ground car parkin...
# data_upd_at                                                           2021-11-19 02:26:29+00:00
# pv_last_wk                                                                                  157
# pv_last_mth                                                                                 643
# pv_total                                                                                  38600
# download_count                                                                         12084831
# categories                                                            [transportation, economy]
# domain_category                                                                       transport
# domain_tags                                   [parking, sensor, near real-time, vacancy, tra...
# Quality_What's-included                       all active sensor readings. number of sensor r...
# Quality_Update-frequency                                                              2 minutes
# Quality_Reliability-level                                                   useful with caveats
# How-to-use_Linked-to                                                                        NaN
# Data-management_Source-data-update-frequency                                          real-time
# Quality_Known-Issues                          parking sensors are not operational on public ...
# How-to-use_Further-information                http://www.melbourne.vic.gov.au/parking-and-tr...
# Quality_Data-quality-statement                                                              NaN
#
#                                                                                              6   \
# name                                                                     on-street parking bays
# id                                                                                    crvt-b4kt
# parent_fxf                                                                                   []
# permalink                                         https://data.melbourne.vic.gov.au/d/crvt-b4kt
# description                                   this dataset contains spatial polygons which r...
# data_upd_at                                                           2021-08-23 16:04:33+00:00
# pv_last_wk                                                                                  126
# pv_last_mth                                                                                 514
# pv_total                                                                                  25348
# download_count                                                                            39776
# categories                                                                     [transportation]
# domain_category                                                                       transport
# domain_tags                                   [accessibility, areas, bays, cars, cityreactiv...
# Quality_What's-included                                           all surveyed parking bay data
# Quality_Update-frequency                                                                  daily
# Quality_Reliability-level                                                   useful with caveats
# How-to-use_Linked-to                                                                        NaN
# Data-management_Source-data-update-frequency                                              daily
# Quality_Known-Issues                                                                        NaN
# How-to-use_Further-information                                                              NaN
# Quality_Data-quality-statement                this data contains all spatially mapped on-str...
#
#                                                                                              11
# name                                                        on-street car park bay restrictions
# id                                                                                    ntht-5rk7
# parent_fxf                                                                                   []
# permalink                                         https://data.melbourne.vic.gov.au/d/ntht-5rk7
# description                                   each row contains information about the restri...
# data_upd_at                                                           2021-09-14 16:04:00+00:00
# pv_last_wk                                                                                   70
# pv_last_mth                                                                                 294
# pv_total                                                                                  17916
# download_count                                                                           602743
# categories                                                [transportation, recreation, economy]
# domain_category                                                                       transport
# domain_tags                                   [accessibility, bay, car, parking, restriction...
# Quality_What's-included                       all parking signs that have a relevant mapped ...
# Quality_Update-frequency                                                                  daily
# Quality_Reliability-level                                                   useful with caveats
# How-to-use_Linked-to                                                                        NaN
# Data-management_Source-data-update-frequency                                              daily
# Quality_Known-Issues                                                                        NaN
# How-to-use_Further-information                                                              NaN
# Quality_Data-quality-statement                                                              NaN

# %% [markdown]
# ## [03a] Example to inspect meta data of interest -->  "domain tags"

# %%
dfparking[dfparking['id']=='vh2v-4nfs']['domain_tags'].values[0]
# Out:
# ['parking',
#  'sensor',
#  'near real-time',
#  'vacancy',
#  'transport',
#  'travel',
#  'disability',
#  'accessibility',
#  'sensors',
#  'safemobility']

# %% [markdown]
# ## [03b] Example to inspect meta data of interest -->  "Quality_Known-Issues"

# %%
dfparking[dfparking['id']=='vh2v-4nfs']['Quality_Known-Issues'].values[0]
# Out:
# 'parking sensors are not operational on public holidays. parking sensors will show car parks as vacant when blocked by construction zones. '

# %% [markdown]
# ## [04] Checking meta data on 2 pedestrian count datasets

# %%
# with the below 2 datasets, we can get a live geospatial snapshot of the pedestrian counts in City of Melbourne

dfpedestrian = metadf[metadf.id.isin(['d6mv-s43h', 'h57g-5234'])] 
dfpedestrian.T

# .. and so on
# Out:
#                                                                                              28  \
# name                                          pedestrian counting system - past hour (counts...
# id                                                                                    d6mv-s43h
# parent_fxf                                                                                   []
# permalink                                         https://data.melbourne.vic.gov.au/d/d6mv-s43h
# description                                   <b>current issue 23/09/2020</b>\nplease note: ...
# data_upd_at                                                           2021-11-21 06:01:19+00:00
# pv_last_wk                                                                                   34
# pv_last_mth                                                                                  96
# pv_total                                                                                   7935
# download_count                                                                            20794
# categories                                                                                   []
# domain_category                                                                       transport
# domain_tags                                   [pedestrian, sensors, foot traffic, traffic fl...
# Quality_What's-included                                                                     NaN
# Quality_Update-frequency                                                             15 minutes
# Quality_Reliability-level                                                   reliable and timely
# How-to-use_Linked-to                                                                        NaN
# Data-management_Source-data-update-frequency                                         15 minutes
# Quality_Known-Issues                                                                       none
# How-to-use_Further-information                                                              NaN
# Quality_Data-quality-statement                                                              NaN
#
#                                                                                              30
# name                                              pedestrian counting system - sensor locations
# id                                                                                    h57g-5234
# parent_fxf                                                                                   []
# permalink                                         https://data.melbourne.vic.gov.au/d/h57g-5234
# description                                   this dataset contains status, location and dir...
# data_upd_at                                                           2021-09-21 16:44:14+00:00
# pv_last_wk                                                                                   52
# pv_last_mth                                                                                 206
# pv_total                                                                                   7584
# download_count                                                                             2196
# categories                                                                                   []
# domain_category                                                                       transport
# domain_tags                                   [cityreactivation, directions, foot traffic, l...
# Quality_What's-included                       all data held by the city of melbourne has bee...
# Quality_Update-frequency                                                                  daily
# Quality_Reliability-level                                                   useful with caveats
# How-to-use_Linked-to                                                                        NaN
# Data-management_Source-data-update-frequency                                              daily
# Quality_Known-Issues                                                                        NaN
# How-to-use_Further-information                                                              NaN
# Quality_Data-quality-statement                                                              NaN

# %%
metadf[['name','id','data_upd_at','pv_last_wk','pv_last_mth','pv_total','download_count']]
# Out:
#                                                   name         id  \
# 0    pedestrian counting system - monthly (counts p...  b2ak-trbp
# 1                    tree canopies 2011 (urban forest)  y79a-us3f
# 2    trees, with species and dimensions (urban forest)  fp38-wiyy
# 3                        on-street parking bay sensors  vh2v-4nfs
# 4             pay stay zones linked to street segments  7q9g-yyvg
# ..                                                 ...        ...
# 216  cardboard bales collected at degraves st recyc...  hisn-tyup
# 217  city of melbourne population forecasts by smal...  sp4r-xphj
# 218  city of melbourne jobs forecasts by small area...  73qa-862u
# 219  city of melbourne dwellings and household fore...  jizx-9ayp
# 220  city of melbourne floor space forecasts by sma...  ssm6-4b38
#
#                   data_upd_at  pv_last_wk  pv_last_mth  pv_total  \
# 0   2021-11-04 22:38:23+00:00         111          779     73850
# 1                         NaT           3           33     66899
# 2   2021-09-30 16:06:54+00:00          40          269     39834
# 3   2021-11-19 05:28:28+00:00         152          639     38601
# 4   2018-03-02 01:46:14+00:00         112          467     32074
# ..                        ...         ...          ...       ...
# 216 2017-05-12 06:23:18+00:00           0            3       225
# 217 2021-08-12 06:45:16+00:00           7           64       109
# 218 2021-08-12 07:19:52+00:00          12           28        52
# 219 2021-08-12 07:01:29+00:00           2           16        47
# 220 2021-08-12 07:27:00+00:00           1           12        37
#
#      download_count
# 0              8834
# 1              3178
# 2              6395
# 3          12085197
# 4              1819
# ..              ...
# 216             848
# 217              17
# 218              13
# 219               7
# 220               6
#
# [221 rows x 7 columns]

# %% [markdown]
# ## [05] Single keyword search on dataset name

# %%
# trying to get same results as keyword_search() in :
# https://bitbucket-students.deakin.edu.au/projects/D2IC-PG/repos/d2i---melbourne-city/browse/webapp/flaskr/dataset_search.py

# %%
keyword = 'cafe'

mask = metadf['name'].str.contains(keyword)
metadf[mask][['name','id','download_count','permalink']]
# Out:
#                                              name         id  download_count  \
# 7    cafes and restaurants, with seating capacity  xt2y-tnn9           16176
# 60            cafe, restaurant, bistro seats 2020  dyqx-cfn5             650
# 138       cafe, restaurant, bistro seats 2017 map  w2pi-36nk             207
#
#                                          permalink
# 7    https://data.melbourne.vic.gov.au/d/xt2y-tnn9
# 60   https://data.melbourne.vic.gov.au/d/dyqx-cfn5
# 138  https://data.melbourne.vic.gov.au/d/w2pi-36nk

# %% [markdown]
# ## [06] Logging meta data daily via crontab to explore trends

# %%
import os, sys
from datetime import datetime
import pandas as pd
from d2i_tools2 import getMeta

folder = "datasets"
meta_fname, track_fname = "meta_log.csv", "meta_log_track.txt"
meta_log = os.path.join(folder, meta_fname)
track_log = os.path.join(folder, track_fname)

def log_meta(apptoken=None):
    metadf = getMeta(apptoken)
    metadf['log_time'] = datetime.now()
    log_cols = ['name','id','data_upd_at','pv_last_wk','pv_last_mth','pv_total','download_count','log_time']
    if not os.path.isfile(meta_log):
        metadf[log_cols].to_csv(meta_log, mode='w', header=True, index=False)  # first write
        sys.stdout = open(track_log,'w') # write log
        print(f"{datetime.now()}, [meta log] written to file")
    else:
        metadf[log_cols].to_csv(meta_log, mode='a', header=True, index=False)  # subsequent writes
        sys.stdout = open(track_log,'a') # write log
        print(f"{datetime.now()}, [meta log] appended to file")
