# %% [markdown]
# # Housing Recommendation based on distance to nearby utilities
#
# **Authored by**:  Linh Huong Nguyen
#
# **Duration**: 90 mins
#
# **Level**: Intermediate
#
# **Pre-requisite Skills**: Python, Pandas, Matplotlib, NumbPy, Seaborn, Scikit-learn

# %% [markdown]
# ### Scenario

# %% [markdown]
# As a tenant looking for rental houses, and a parent, I would like to calculate the total travelling distance if I have to drop off my kid to school and travel to work, so that I can choose the most suitable place to apply for rent that saves me the most travelling time.

# %% [markdown]
# ### What this use case will teach you

# %% [markdown]
# At the end of this use case, you will have demonstrated the following skills:
#
# * Accessed and imported geospatial and rental listing datasets from open data portals and APIs.
#
# * Performed data cleaning, preprocessing, and geocoding of addresses to ensure spatial accuracy.
#
# * Used geospatial libraries to calculate distances between points of interest (POIs) and rental properties.
#
# * Conducted exploratory data analysis (EDA) to assess accessibility patterns and disparities.
#
# * Visualised geospatial data on interactive maps to highlight proximity patterns and coverage gaps.
#
# * Derived actionable insights to inform housing accessibility and urban development policies.

# %% [markdown]
# ### Background and Introduction

# %% [markdown]
# The accessibility of essential public amenities such as stations and schools and their distance to Melbourne CBD, plays a significant role in shaping rental market dynamics, urban livability, and resident satisfaction. For renters, proximity to these amenities can influence housing decisions, commute times, and quality of life. For policymakers and urban planners, understanding how well rental properties are served by these facilities is crucial for identifying underserved areas, prioritising infrastructure investments, and ensuring equitable access across the community.
#
# This use case addresses the need for a data-driven approach to evaluating the spatial relationship between rental housing and local amenities like stations and schools location. By combining rental property data with geospatial datasets of public transport stations and schools, we can calculate precise distances and analyse accessibility patterns across different rental listings. These insights can help tenants looking for rental places find the location suits their best interest.

# %% [markdown]
# ### Datasets used

# %% [markdown]
# * Open Route Service API
# This dataset provides direction and travelling time by car from different locations on an opensource map. The dataset is accessed through an API key.
#
# * PTV API
# This dataset provides all train stations location in Victoria and their routes, stop times.The dataset is accessed through an user ID and API key.
#
# * Victoria School Locations 2024
# This dataset contains the list of all school locations in Victoria, including primary and secondary schools, government and non-government. Attributes include school name, sector, type, address, phone, and geographic coordinates. Data is sourced from the Victorian Department of Education and accessible via API V2.1.
#
# * [Rental Listings Dataset]
# This dataset contains current rental property listings in the City of Melbourne. Attributes may include address, rental price, property type, number of bedrooms, and listing date. Addresses will be geocoded for spatial analysis.

# %% [markdown]
# ### Importing Datasets

# %% [markdown]
# This section imports essential libraries for data manipulation, visualisation, geospatial analysis, interactive mapping, and fetching data from APIs. These libraries provide the necessary functionality for processing, analysing, and visualising the project data effectively.

# %%
from geopy.geocoders import Nominatim
from scipy.spatial import KDTree
from geopy.distance import geodesic
import openrouteservice
import requests
import pandas as pd
import os
from io import StringIO
import requests
import seaborn as sns
import folium
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import shape, Point
import json
import zipfile
from io import BytesIO
import re
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\phuon\AppData\Local\Temp\ipykernel_22584\3453210452.py:2: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 2.3.2)
#   from scipy.spatial import KDTree
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\phuon\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\Users\phuon\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\Users\phuon\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\phuon\AppData\Local\Temp\ipykernel_22584\3453210452.py", line 6, in <module>
#     import pandas as pd
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\pandas\__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\pandas\compat\__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\pandas\compat\pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\pyarrow\__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\phuon\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "c:\Users\phuon\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "c:\Users\phuon\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\phuon\AppData\Local\Temp\ipykernel_22584\3453210452.py", line 6, in <module>
#     import pandas as pd
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\pandas\__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\pandas\core\api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\pandas\core\dtypes\dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "c:\Users\phuon\anaconda3\Lib\site-packages\pyarrow\__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found

# %% [markdown]
# ### Loading the datasets using API 2.1v

# %% [markdown]
# This section defines functions for fetching data from APIs. The API_Unlimited function retrieves datasets from the Melbourne Open Data Portal using dataset IDs, processes the data into a DataFrame, and provides a preview for verification. Similarly, the fetch_data_from_url function fetches data directly from a given URL, processes it into a DataFrame, and displays a sample for validation. These functions enable seamless access to external datasets for analysis.

# %%
def API_Unlimited_external(datasetname): # pass in dataset name and api key
    dataset_id = datasetname

    base_url = 'https://www.education.vic.gov.au/Documents/about/research/datavic/'
    dataset_id = dataset_id
    format = 'csv'

    url = f'{base_url}{dataset_id}.{format}'
    params = {
        'select': '*',
        'limit': -1,  # all records
        'lang': 'en',
        'timezone': 'UTC'
    }

    # GET request
    response = requests.get(url, params=params)

    if response.status_code == 200:
        # StringIO to read the CSV data
        url_content = response.text
        datasetname = pd.read_csv(StringIO(url_content), delimiter=',')
        print(datasetname.sample(10, random_state=999)) # Test
        return datasetname 
    else:
        return (print(f'Request failed with status code {response.status_code}'))

# %% [markdown]
# ### Fetching and Previewing Datasets

# %% [markdown]
# This section defines the dataset download links required for the use case and fetches the corresponding data using the API_Unlimited_external function. The datasets include school locations which are essential for calculating distance from rental listings to schools.

# %%
download_link = 'dv378_DataVic-SchoolLocations-2024'

# Use functions to download and load data
school_locations = API_Unlimited_external(download_link)
# Out:
#      Education_Sector  Entity_Type  School_No  \
# 1482       Government            1       5244
# 1673       Government            1       5553
# 976        Government            1       3077
# 1926       Government            1       8466
# 1298       Government            1       4923
# 2134      Independent            2       1729
# 1308       Government            1       4943
# 1413       Government            1       5136
# 49           Catholic            2        324
# 352          Catholic            2       1715
#
#                                 School_Name School_Type  \
# 1482                  Findon Primary School     Primary
# 1673              Tulliallan Primary School     Primary
# 976               Korumburra Primary School     Primary
# 1926           Bairnsdale Secondary College   Secondary
# 1298              Mount View Primary School     Primary
# 2134                Sholem Aleichem College     Primary
# 1308  Wilmot Road Primary School Shepparton     Primary
# 1413              James Cook Primary School     Primary
# 49                      Sacred Heart School     Primary
# 352                   Holy Eucharist School     Primary
#
#               Address_Line_1 Address_Line_2      Address_Town Address_State  \
# 1482          Cuthbert Drive            NaN         Mill Park           VIC
# 1673  89 Wheelers Park Drive            NaN  Cranbourne North           VIC
# 976         6 - 16 Mine Road            NaN        Korumburra           VIC
# 1926        90 Mckean Street            NaN        Bairnsdale           VIC
# 1298   274-288 Gallaghers Rd            NaN     Glen Waverley           VIC
# 2134          11 Sinclair St            NaN       ELSTERNWICK           VIC
# 1308       84-90 Wilmot Road            NaN        Shepparton           VIC
# 1413  29-59 James Cook Drive            NaN   Endeavour Hills           VIC
# 49        69-75 Hogan Street            NaN            TATURA           VIC
# 352         20 Chedgey Drive            NaN         ST ALBANS           VIC
#
#       Address_Postcode  ...         Postal_Town Postal_State Postal_Postcode  \
# 1482              3082  ...           MILL PARK          VIC          3082.0
# 1673              3977  ...  Narre Warren South          VIC          3805.0
# 976               3950  ...          KORUMBURRA          VIC          3950.0
# 1926              3875  ...          BAIRNSDALE          VIC          3875.0
# 1298              3150  ...       GLEN WAVERLEY          VIC          3150.0
# 2134              3185  ...         ELSTERNWICK          VIC          3185.0
# 1308              3630  ...          SHEPPARTON          VIC          3630.0
# 1413              3802  ...     ENDEAVOUR HILLS          VIC          3802.0
# 49                3616  ...              TATURA          VIC          3616.0
# 352               3021  ...           ST ALBANS          VIC          3021.0
#
#      Full_Phone_No             Region_Name                AREA_Name LGA_ID  \
# 1482  03 9404 1362  NORTH-WESTERN VICTORIA  North Eastern Melbourne    707
# 1673  03 8766 3100  SOUTH-EASTERN VICTORIA       Southern Melbourne    161
# 976   03 5655 1309  SOUTH-EASTERN VICTORIA          Inner Gippsland    617
# 1926  03 5150 4800  SOUTH-EASTERN VICTORIA          Outer Gippsland    211
# 1298  03 9560 0471  NORTH-EASTERN VICTORIA  Inner Eastern Melbourne    497
# 2134  03 8527 3000  SOUTH-EASTERN VICTORIA        Bayside Peninsula    231
# 1308  03 5821 4953  NORTH-EASTERN VICTORIA                 Goulburn    283
# 1413  03 9700 2601  SOUTH-EASTERN VICTORIA       Southern Melbourne    161
# 49    03 5824 1841  NORTH-EASTERN VICTORIA                 Goulburn    283
# 352   03 8312 0900  SOUTH-WESTERN VICTORIA          Brimbank Melton    118
#
#                     LGA_Name          X         Y
# 1482          Whittlesea (C)  145.05107 -37.66650
# 1673               Casey (C)  145.32734 -38.08160
# 976      South Gippsland (S)  145.82564 -38.43513
# 1926      East Gippsland (S)  147.60500 -37.82871
# 1298              Monash (C)  145.17881 -37.88348
# 2134           Glen Eira (C)  145.00120 -37.88229
# 1308  Greater Shepparton (C)  145.40590 -36.39850
# 1413               Casey (C)  145.24585 -37.97906
# 49    Greater Shepparton (C)  145.22392 -36.43983
# 352             Brimbank (C)  144.81141 -37.75644
#
# [10 rows x 22 columns]

# %%
school_locations= school_locations.dropna(subset=['Y', 'X'])

# %% [markdown]
# ### GTFS Schedule Dataset

# %% [markdown]
# The GTFS Schedule dataset contains static timetable information of public transport services in Victoria. In the below code chunks, a function is created to download and extract data from the GTFS opensourced data portal

# %%
current_directory = os.getcwd()
dataset_folder = 'mpt_data'
dataset_path = os.path.join(current_directory, dataset_folder)
inner_zip_paths = ['2/google_transit.zip', '3/google_transit.zip', '4/google_transit.zip']

# %%
def API_GTFS(url: str, inner_zip_paths: list) -> dict:

    required_files = ['stops.txt', 'stop_times.txt', 'routes.txt', 'trips.txt', 'calendar.txt']
    datasets = {}
    # Download main zip
    response = requests.get(url)
    response.raise_for_status()

    # Open main zip in memory
    with zipfile.ZipFile(BytesIO(response.content)) as main_zip:
        for inner_zip_path in inner_zip_paths:
            if inner_zip_path not in main_zip.namelist():
                continue

            subfolder_name = os.path.basename(os.path.dirname(inner_zip_path))
            datasets[subfolder_name] = {}

            with main_zip.open(inner_zip_path) as inner_zip_file:
                with zipfile.ZipFile(BytesIO(inner_zip_file.read())) as inner_zip:
                    for file_name in required_files:
                        if file_name in inner_zip.namelist():
                            with inner_zip.open(file_name) as f:
                                datasets[subfolder_name][file_name] = pd.read_csv(f)

    return datasets

# %%
inner_zip_paths = ['2/google_transit.zip']
url = 'https://data.ptv.vic.gov.au/downloads/gtfs.zip'

datasets=API_GTFS(url, inner_zip_paths)

# %% [markdown]
# In the below code, train stations locations are extracted from their respective folder.
# In the datasetm we can see each station's specific ID, name, location (latitude and longitude) and other necessary information like accessibility for wheelchairs or platform code, etc.

# %%
train_stops=datasets["2"]["stops.txt"]
train_stops['stop_name'] = train_stops['stop_name'].astype(str).str.strip()
train_stops = train_stops[
    train_stops['stop_name'].str.contains('Station', case=False, na=False)
].copy()
print(train_stops.head())
# Out:
#   stop_id                  stop_name   stop_lat    stop_lon  location_type  \
# 0   10117        Jordanville Station -37.873763  145.112473            NaN
# 1   10920          Flagstaff Station -37.811880  144.956043            NaN
# 2   10921          Flagstaff Station -37.811725  144.955968            NaN
# 3   10922  Melbourne Central Station -37.809973  144.962513            NaN
# 4   10923  Melbourne Central Station -37.809865  144.962505            NaN
#
#   parent_station  wheelchair_boarding  level_id platform_code
# 0   vic:rail:JOR                  1.0   Level 0             1
# 1   vic:rail:FGS                  1.0  Level -2             1
# 2   vic:rail:FGS                  1.0  Level -2             2
# 3   vic:rail:MCE                  1.0  Level -2             1
# 4   vic:rail:MCE                  1.0  Level -2             2

# %% [markdown]
# The below code shows the stop times dataset, where we can see a list of all trips at each station, their arrival time, and the sequence of each trip.

# %%
stop_times=datasets["2"]["stop_times.txt"]
for df in (stop_times,):
    df["trip_id"]  = df["trip_id"].astype(str)
    df["stop_id"]  = df["stop_id"].astype(str)
stop_times.head()
# Out:
#               trip_id arrival_time departure_time stop_id  stop_sequence  \
# 0  02-ALM--15-T2-2302     04:57:00       04:57:00   11197              1
# 1  02-ALM--15-T2-2302     04:58:00       04:58:00   11198              2
# 2  02-ALM--15-T2-2302     05:00:00       05:00:00   11200              3
# 3  02-ALM--15-T2-2302     05:02:00       05:02:00   11202              4
# 4  02-ALM--15-T2-2302     05:04:00       05:04:00   11203              5
#
#   stop_headsign  pickup_type  drop_off_type  shape_dist_traveled
# 0           NaN            0              0                 0.00
# 1           NaN            0              0               713.74
# 2           NaN            0              0              1918.59
# 3           NaN            0              0              2901.39
# 4           NaN            0              0              3921.94

# %% [markdown]
# The route dataset contains list of all routes with their names, types and how they are visualised on the map.

# %%
routes = datasets["2"]["routes.txt"]
routes.head()
# Out:
#                 route_id  agency_id route_short_name    route_long_name  \
# 0    aus:vic:vic-02-ALM:        NaN          Alamein     Alamein - City
# 1  aus:vic:vic-02-ALM-R:        NaN  Replacement Bus     Alamein - City
# 2    aus:vic:vic-02-BEG:        NaN         Belgrave    Belgrave - City
# 3  aus:vic:vic-02-BEG-R:        NaN  Replacement Bus    Belgrave - City
# 4    aus:vic:vic-02-CBE:        NaN       Cranbourne  Cranbourne - City
#
#    route_type route_color route_text_color
# 0           2      152C6B           FFFFFF
# 1           2      FE5000           FFFFFF
# 2           2      152C6B           FFFFFF
# 3           2      FE5000           FFFFFF
# 4           2      279FD5           000000

# %% [markdown]
# This code snippet processed the trips dataset, converting "trip_id" and "route_id" columns into string datatype.

# %%
trips=datasets["2"]["trips.txt"]
for df in (trips,):
    df["trip_id"]  = df["trip_id"].astype(str)
    df["route_id"] = df["route_id"].astype(str)
trips.head()
# Out:
#               route_id service_id             trip_id          shape_id  \
# 0  aus:vic:vic-02-ALM:         T2  02-ALM--15-T2-2302  2-ALM-vpt-15.1.R
# 1  aus:vic:vic-02-ALM:         T2  02-ALM--15-T2-2304  2-ALM-vpt-15.1.R
# 2  aus:vic:vic-02-ALM:         T2  02-ALM--15-T2-2305  2-ALM-vpt-15.2.H
# 3  aus:vic:vic-02-ALM:         T2  02-ALM--15-T2-2306  2-ALM-vpt-15.1.R
# 4  aus:vic:vic-02-ALM:         T2  02-ALM--15-T2-2307  2-ALM-vpt-15.2.H
#
#   trip_headsign  direction_id  block_id  wheelchair_accessible
# 0    Camberwell             1       NaN                      1
# 1    Camberwell             1       NaN                      1
# 2       Alamein             0       NaN                      1
# 3    Camberwell             1       NaN                      1
# 4       Alamein             0       NaN                      1

# %% [markdown]
# The below code merges all train dataset from PTV for a more holistic view.

# %%
train_data = stop_times.merge(train_stops, on="stop_id", how="left").merge(trips, on="trip_id", how="left").merge(routes, on="route_id", how="left")

# %% [markdown]
# From the below code, data wrangling is performed to drop all unnessary columns and handle missing values.

# %%
train_data_clean=train_data.drop(columns=['location_type','parent_station','wheelchair_boarding','level_id','platform_code','wheelchair_boarding','level_id','platform_code','stop_headsign','pickup_type','drop_off_type','agency_id','service_id','route_type','route_color','route_text_color','shape_id','trip_headsign','direction_id','block_id','wheelchair_accessible'])
train_data_clean= train_data_clean.dropna(subset=['stop_lat', 'stop_lon'])
train_data_clean.head()
# Out:
#               trip_id arrival_time departure_time stop_id  stop_sequence  \
# 0  02-ALM--15-T2-2302     04:57:00       04:57:00   11197              1
# 1  02-ALM--15-T2-2302     04:58:00       04:58:00   11198              2
# 2  02-ALM--15-T2-2302     05:00:00       05:00:00   11200              3
# 3  02-ALM--15-T2-2302     05:02:00       05:02:00   11202              4
# 4  02-ALM--15-T2-2302     05:04:00       05:04:00   11203              5
#
#    shape_dist_traveled          stop_name   stop_lat    stop_lon  \
# 0                 0.00    Alamein Station -37.868186  145.079705
# 1               713.74  Ashburton Station -37.861932  145.081390
# 2              1918.59    Burwood Station -37.851744  145.080540
# 3              2901.39   Hartwell Station -37.843883  145.075426
# 4              3921.94   Willison Station -37.835670  145.070242
#
#               route_id route_short_name route_long_name
# 0  aus:vic:vic-02-ALM:          Alamein  Alamein - City
# 1  aus:vic:vic-02-ALM:          Alamein  Alamein - City
# 2  aus:vic:vic-02-ALM:          Alamein  Alamein - City
# 3  aus:vic:vic-02-ALM:          Alamein  Alamein - City
# 4  aus:vic:vic-02-ALM:          Alamein  Alamein - City

# %% [markdown]
# ### Rental Listings Spreadsheet

# %% [markdown]
# A spreadsheet of rental listings is collected from realestate.com.au to be ranked based on their distance to utilities. This list is gathered from multiple suburbs to provide a variety of locations and compare the accessibility of current rental listings from different areas.

# %%
rental_listings = pd.read_excel("Rental Listings.xlsx")
rental_listings.head()
# Out:
#       Suburb  Postcode                                  Address
# 0   Box Hill      3128           1/8 Ashted Road, Box Hill, Vic
# 1   Box Hill      3128  1112/850 Whitehorse Road, Box Hill, Vic
# 2   Hawthorn      3122     3/494 Glenferrie Road, Hawthorn, Vic
# 3   Hawthorn      3122     517B/200 Burwood Road, Hawthorn, Vic
# 4  Doncaster      3108    6/77-79 Wetherby Road, Doncaster, Vic

# %% [markdown]
# The below code processed the addresses to remove the unit/apartment numbers.

# %%
rental_listings['Address'] = rental_listings['Address'].str.split("/").str[-1]
rental_listings.head()
# Out:
#       Suburb  Postcode                              Address
# 0   Box Hill      3128         8 Ashted Road, Box Hill, Vic
# 1   Box Hill      3128   850 Whitehorse Road, Box Hill, Vic
# 2   Hawthorn      3122   494 Glenferrie Road, Hawthorn, Vic
# 3   Hawthorn      3122      200 Burwood Road, Hawthorn, Vic
# 4  Doncaster      3108  77-79 Wetherby Road, Doncaster, Vic

# %% [markdown]
# ### Generate latitude and longitude from address

# %% [markdown]
# The below code is a function to return the latitude and longitude from a passed in address.

# %%
#Function to geocode an address using Nominatim
def geocode_address(address):
    geolocator = Nominatim(user_agent="mapping_app1.0",timeout=15)
    
    #Define the bounding box for Melbourne
    melbourne_bbox = [(-38.5267, 144.5937), (-37.5113, 145.5125)] 
    
    #Geocode the address within the Melbourne bounding box
    location = geolocator.geocode(address, viewbox=melbourne_bbox, bounded=True)
    
    if location:
        return location.latitude, location.longitude
    else:
        return None

# %% [markdown]
# After passing the function to the rental listings dataframe, specific coordinates of each rental place is gathered.

# %%
rental_listings['coords'] = rental_listings['Address'].apply(geocode_address)
rental_listings.head()
# Out:
#       Suburb  Postcode                              Address  \
# 0   Box Hill      3128         8 Ashted Road, Box Hill, Vic
# 1   Box Hill      3128   850 Whitehorse Road, Box Hill, Vic
# 2   Hawthorn      3122   494 Glenferrie Road, Hawthorn, Vic
# 3   Hawthorn      3122      200 Burwood Road, Hawthorn, Vic
# 4  Doncaster      3108  77-79 Wetherby Road, Doncaster, Vic
#
#                        coords
# 0  (-37.8231233, 145.1236049)
# 1  (-37.8176227, 145.1184549)
# 2  (-37.8318201, 145.0338629)
# 3  (-37.8221063, 145.0299116)
# 4    (-37.79392, 145.1419781)

# %% [markdown]
# In the below code, the "coords" column is divided into latitude and longitude columns for each rental listing.

# %%
rental_listings_clean=rental_listings.dropna(subset='coords')
rental_listings_clean[['latitude', 'longitude']] =pd.DataFrame(
    rental_listings_clean['coords'].tolist(), index=rental_listings_clean.index)
rental_listings_clean=rental_listings_clean.drop(columns=['coords'])
rental_listings_clean.head()
# Out:
#       Suburb  Postcode                              Address   latitude  \
# 0   Box Hill      3128         8 Ashted Road, Box Hill, Vic -37.823123
# 1   Box Hill      3128   850 Whitehorse Road, Box Hill, Vic -37.817623
# 2   Hawthorn      3122   494 Glenferrie Road, Hawthorn, Vic -37.831820
# 3   Hawthorn      3122      200 Burwood Road, Hawthorn, Vic -37.822106
# 4  Doncaster      3108  77-79 Wetherby Road, Doncaster, Vic -37.793920
#
#     longitude
# 0  145.123605
# 1  145.118455
# 2  145.033863
# 3  145.029912
# 4  145.141978

# %% [markdown]
# From the above codes, rental listings table has been added longtitude and latitude columns to navigate the listing on a map.

# %%
# Average lat/lon for center
melbourne_center = [rental_listings_clean['latitude'].mean(), rental_listings_clean['longitude'].mean()]
listing_map = folium.Map(location=melbourne_center, zoom_start=13)

# Add coworking space markers
for _, row in rental_listings_clean.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['Address'],
    ).add_to(listing_map)


# Display the map
listing_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c754f319d1ce2161b880ae8ee0e0ee5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c754f319d1ce2161b880ae8ee0e0ee5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3c754f319d1ce2161b880ae8ee0e0ee5 = L.map(
#                 &quot;map_3c754f319d1ce2161b880ae8ee0e0ee5&quot;,
#                 {
#                     center: [-37.85001128666667, 145.10367756666668],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_febca999c0f52148eb5e5469b030d62f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_febca999c0f52148eb5e5469b030d62f.addTo(map_3c754f319d1ce2161b880ae8ee0e0ee5);
#
#
#             var marker_cc1657fb4dbe022779708ca00befcb64 = L.marker(
#                 [-37.8231233, 145.1236049],
#                 {
# }
#             ).addTo(map_3c754f319d1ce2161b880ae8ee0e0ee5);
#
#
#         var popup_8e22f00e2c38af66e52c1fbd46667074 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_855c8a40c70355b9c79f77e206ad8242 = $(`&lt;div id=&quot;html_855c8a40c70355b9c79f77e206ad8242&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;8 Ashted Road, Box Hill, Vic&lt;/div&gt;`)[0];
#                 popup_8e22f00e2c38af66e52c1fbd46667074.setContent(html_855c8a40c70355b9c79f77e206ad8242);
#
#
#
#         marker_cc1657fb4dbe022779708ca00befcb64.bindPopup(popup_8e22f00e2c38af66e52c1fbd46667074)
#         ;
#
#
#
#
#             var marker_247b753ef4f4a234a1da8a32c8200e64 = L.marker(
#                 [-37.8176227, 145.1184549],
#                 {
# }
#             ).addTo(map_3c754f319d1ce2161b880ae8ee0e0ee5);
#
#
#         var popup_46a750d7bfd325e898a55075eecea1cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e09a62414aad7362084b83a0800033f0 = $(`&lt;div id=&quot;html_e09a62414aad7362084b83a0800033f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;850 Whitehorse Road, Box Hill, Vic&lt;/div&gt;`)[0];
#                 popup_46a750d7bfd325e898a55075eecea1cf.setContent(html_e09a62414aad7362084b83a0800033f0);
#
#
#
#         marker_247b753ef4f4a234a1da8a32c8200e64.bindPopup(popup_46a750d7bfd325e898a55075eecea1cf)
#         ;
#
#
#
#
#             var marker_1a5f6a986845e2a871421f78305752ab = L.marker(
#                 [-37.8318201, 145.0338629],
#                 {
# }
#             ).addTo(map_3c754f319d1ce2161b880ae8ee0e0ee5);
#
#
#         var popup_f70aca8c0d4cd681811a2b487521aaed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef675f3fdb344a01794c6a6edd8835f2 = $(`&lt;div id=&quot;html_ef675f3fdb344a01794c6a6edd8835f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;494 Glenferrie Road, Hawthorn, Vic&lt;/div&gt;`)[0];
#                 popup_f70aca8c0d4cd681811a2b487521aaed.setContent(html_ef675f3fdb344a01794c6a6edd8835f2);
#
#
#
#         marker_1a5f6a986845e2a871421f78305752ab.bindPopup(popup_f70aca8c0d4cd681811a2b487521aaed)
#         ;
#
#
#
#
#             var marker_e45dfee487374a3b16ded71748097a1a = L.marker(
#                 [-37.8221063, 145.0299116],
#                 {
# }
#             ).addTo(map_3c754f319d1ce2161b880ae8ee0e0ee5);
#
#
#         var popup_53003ad48205a195f6dd005d568054be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa39397c92d2076207f5d3898e726e4a = $(`&lt;div id=&quot;html_fa39397c92d2076207f5d3898e726e4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;200 Burwood Road, Hawthorn, Vic&lt;/div&gt;`)[0];
#                 popup_53003ad48205a195f6dd005d568054be.setContent(html_fa39397c92d2076207f5d3898e726e4a);
#
#
#
#         marker_e45dfee487374a3b16ded71748097a1a.bindPopup(popup_53003ad48205a195f6dd005d568054be)
#         ;
#
#
#
#
#             var marker_381fc82413c2eb94b85b426de0abc975 = L.marker(
#                 [-37.79392, 145.1419781],
#                 {
# }
#             ).addTo(map_3c754f319d1ce2161b880ae8ee0e0ee5);
#
#
#         var popup_ef9a5820d9923fe83987b2ec94e239ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46a3e96be980492f17ece674543535d6 = $(`&lt;div id=&quot;html_46a3e96be980492f17ece674543535d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;77-79 Wetherby Road, Doncaster, Vic&lt;/div&gt;`)[0];
#                 popup_ef9a5820d9923fe83987b2ec94e239ce.setContent(html_46a3e96be980492f17ece674543535d6);
#
#
#
#         marker_381fc82413c2eb94b85b426de0abc975.bindPopup(popup_ef9a5820d9923fe83987b2ec94e239ce)
#         ;

# %% [markdown]
# All rental listings have been visualised on a map. By clicking on each marker, the rental listing's address is shown.
# It is visible that the listings are spread out to different suburbs. Most data points collected are situated on the South Eastern area of Melbourne, where there is high demands in renting.

# %% [markdown]
# ### Find nearest station

# %% [markdown]
# The below code is a function to return the nearest station from each rental listing location, using KDTree model. KD-tree is a space-partitioning data structure for fast nearest-neighbor search. KD-trees typically use Euclidean distance to provide angular distance and rank neighbors locally.

# %%
def find_nearest_station(lat, lon, kdtree, df):
    #Query the KDTree with the given latitude and longitude to find nearest station. Distance is returned in degrees so need to calculate the meters
    distances, indices = kdtree.query([[lat, lon]], k=1)

    #Get the nearest station details from the DataFrame
    idx = int(indices[0]) 

    # Nearest station row
    nearest = df.iloc[idx]

    # Distance in meters
    distance_meters = geodesic(
        (lat, lon), (nearest["stop_lat"], nearest["stop_lon"])
    ).meters

    # Return ONLY stop_id + distance
    return nearest["stop_name"], distance_meters, nearest["stop_lat"], nearest["stop_lon"]

# %% [markdown]
# Then the function is applied to the dataset which contains all coordinates of train stations.

# %%
train_stations_coords = train_data_clean[["stop_lat", "stop_lon"]].values
kdtree_train = KDTree(train_stations_coords)
rental_listings_clean[["nearest_station", "distance_meters_station", "nearest_station_lat", "nearest_station_lon"]] = (
    rental_listings_clean.apply(
        lambda r: pd.Series(
            find_nearest_station(r["latitude"], r["longitude"], kdtree_train, train_data_clean)
        ),
        axis=1
    )
)
rental_listings_clean.head()
# Out:
#       Suburb  Postcode                              Address   latitude  \
# 0   Box Hill      3128         8 Ashted Road, Box Hill, Vic -37.823123
# 1   Box Hill      3128   850 Whitehorse Road, Box Hill, Vic -37.817623
# 2   Hawthorn      3122   494 Glenferrie Road, Hawthorn, Vic -37.831820
# 3   Hawthorn      3122      200 Burwood Road, Hawthorn, Vic -37.822106
# 4  Doncaster      3108  77-79 Wetherby Road, Doncaster, Vic -37.793920
#
#     longitude     nearest_station  distance_meters_station  \
# 0  145.123605    Box Hill Station               447.359525
# 1  145.118455    Box Hill Station               306.547766
# 2  145.033863     Kooyong Station               890.688011
# 3  145.029912  Glenferrie Station               574.354559
# 4  145.141978    Laburnum Station              2966.247633
#
#    nearest_station_lat  nearest_station_lon
# 0           -37.819345           145.121835
# 1           -37.819113           145.121386
# 2           -37.839836           145.033395
# 3           -37.821583           145.036402
# 4           -37.820629           145.140820

# %% [markdown]
# From the above table, Nearest station column and its coordinate is added to the listing table. As a result, distance from each rental listing to its nearest station is also calculated and added to the table.

# %%
# Average lat/lon for center
melbourne_center = [rental_listings_clean['latitude'].mean(), rental_listings_clean['longitude'].mean()]
listing_map = folium.Map(location=melbourne_center, zoom_start=13)

# Add coworking space markers
for _, row in rental_listings_clean.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['Address'],
    ).add_to(listing_map)

    folium.Marker(
        location=[row['nearest_station_lat'], row['nearest_station_lon']],
        popup=row['nearest_station'],
        icon=folium.Icon(color='red', icon='train-subway', prefix='fa')
    ).add_to(listing_map)
# Add nearest station markers
listing_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35c1dc6fd4f5044dcb45b3e45fd8f8dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35c1dc6fd4f5044dcb45b3e45fd8f8dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35c1dc6fd4f5044dcb45b3e45fd8f8dd = L.map(
#                 &quot;map_35c1dc6fd4f5044dcb45b3e45fd8f8dd&quot;,
#                 {
#                     center: [-37.85001128666667, 145.10367756666668],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ced2b9db4a8e024f2c3e40cf551d783e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ced2b9db4a8e024f2c3e40cf551d783e.addTo(map_35c1dc6fd4f5044dcb45b3e45fd8f8dd);
#
#
#             var marker_4e25508839525270284cf464aceebefb = L.marker(
#                 [-37.8231233, 145.1236049],
#                 {
# }
#             ).addTo(map_35c1dc6fd4f5044dcb45b3e45fd8f8dd);
#
#
#         var popup_1479d65e92fe03b071a211ce5a52e87c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ba8e08714780df7050d59e30418c0fa = $(`&lt;div id=&quot;html_0ba8e08714780df7050d59e30418c0fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;8 Ashted Road, Box Hill, Vic&lt;/div&gt;`)[0];
#                 popup_1479d65e92fe03b071a211ce5a52e87c.setContent(html_0ba8e08714780df7050d59e30418c0fa);
#
#
#
#         marker_4e25508839525270284cf464aceebefb.bindPopup(popup_1479d65e92fe03b071a211ce5a52e87c)
#         ;
#
#
#
#
#             var marker_914fbb509b855e49a9635869b2175203 = L.marker(
#                 [-37.81934528, 145.12183478],
#                 {
# }
#             ).addTo(map_35c1dc6fd4f5044dcb45b3e45fd8f8dd);
#
#
#             var icon_c89ccecf7942f1bdadf7bb50bf580c3e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;train-subway&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_914fbb509b855e49a9635869b2175203.setIcon(icon_c89ccecf7942f1bdadf7bb50bf580c3e);
#
#
#         var popup_105f374bf108a40c5219740128698dfb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9add761430ba26dda5f5c375487cf837 = $(`&lt;div id=&quot;html_9add761430ba26dda5f5c375487cf837&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Box Hill Station&lt;/div&gt;`)[0];
#                 popup_105f374bf108a40c5219740128698dfb.setContent(html_9add761430ba26dda5f5c375487cf837);
#
#
#
#         marker_914fbb509b855e49a9635869b2175203.bindPopup(popup_105f374bf108a40c5219740128698dfb)
#         ;
#
#
#
#
#             var marker_271a80c031f59fec35cb319745c179ef = L.marker(
#                 [-37.8176227, 145.1184549],
#                 {
# }
#             ).addTo(map_35c1dc6fd4f5044dcb45b3e45fd8f8dd);
#
#
#         var popup_a315356b0074b81ddc6e7daa7252997e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bb057516b6814f3f3ac3e432111952d = $(`&lt;div id=&quot;html_6bb057516b6814f3f3ac3e432111952d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;850 Whitehorse Road, Box Hill, Vic&lt;/div&gt;`)[0];
#                 popup_a315356b0074b81ddc6e7daa7252997e.setContent(html_6bb057516b6814f3f3ac3e432111952d);
#
#
#
#         marker_271a80c031f59fec35cb319745c179ef.bindPopup(popup_a315356b0074b81ddc6e7daa7252997e)
#         ;
#
#
#
#
#             var marker_92dc994a40ff7081982f239f3f3641de = L.marker(
#                 [-37.81911283, 145.12138625],
#                 {
# }
#             ).addTo(map_35c1dc6fd4f5044dcb45b3e45fd8f8dd);
#
#
#             var icon_eceb1d6a3c6a84547543e5c874df60ae = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;train-subway&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_92dc994a40ff7081982f239f3f3641de.setIcon(icon_eceb1d6a3c6a84547543e5c874df60ae);
#
#
#         var popup_d86bbd6607176b1e5d5850aaa531ae56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b5887b0a3dcc065676eb6d1ff3c0abd = $(`&lt;div id=&quot;html_6b5887b0a3dcc065676eb6d1ff3c0abd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Box Hill Station&lt;/div&gt;`)[0];
#                 popup_d86bbd6607176b1e5d5850aaa531ae56.setContent(html_6b5887b0a3dcc065676eb6d1ff3c0abd);
#
#
#
#         marker_92dc994a40ff7081982f239f3f3641de.bindPopup(popup

# %% [markdown]
# ### Find nearest school

# %% [markdown]
# Similarly, a function is created to find the nearest school, also using KDTree.

# %%
def find_nearest_school(lat, lon, kdtree, df):
    #Query the KDTree with the given latitude and longitude to find nearest station. Distance is returned in degrees so need to calculate the meters
    distance, index = kdtree.query([lat, lon])

    #Get the nearest station details from the DataFrame
    nearest_school = df.iloc[index]

    #Extract stations coords
    nearest_school_coords = (nearest_school["Y"], nearest_school["X"])
    point_coords = (lat, lon)

    #Calculate the geodesic distance (in meters) between the point and the nearest statio
    distance_meters = geodesic(point_coords, nearest_school_coords).meters
    school_name = nearest_school.get("School_Name", None)
    
    return school_name, nearest_school_coords[0], nearest_school_coords[1]

# %% [markdown]
# In the below code, schools ' latitude and longitude are extracted for visualisations.

# %%
nearest_school_coords = school_locations[["Y", "X"]].values
kdtree_school = KDTree(nearest_school_coords)
rental_listings_clean[["nearest_school", "school_latitude", "school_longitude"]] = (
    rental_listings_clean.apply(
        lambda r: pd.Series(
            find_nearest_school(r["latitude"], r["longitude"],kdtree_school, school_locations)
        ),
        axis=1
    )
)
rental_listings_clean.head()
# Out:
#       Suburb  Postcode                              Address   latitude  \
# 0   Box Hill      3128         8 Ashted Road, Box Hill, Vic -37.823123
# 1   Box Hill      3128   850 Whitehorse Road, Box Hill, Vic -37.817623
# 2   Hawthorn      3122   494 Glenferrie Road, Hawthorn, Vic -37.831820
# 3   Hawthorn      3122      200 Burwood Road, Hawthorn, Vic -37.822106
# 4  Doncaster      3108  77-79 Wetherby Road, Doncaster, Vic -37.793920
#
#     longitude     nearest_station  distance_meters_station  \
# 0  145.123605    Box Hill Station               447.359525
# 1  145.118455    Box Hill Station               306.547766
# 2  145.033863     Kooyong Station               890.688011
# 3  145.029912  Glenferrie Station               574.354559
# 4  145.141978    Laburnum Station              2966.247633
#
#    nearest_station_lat  nearest_station_lon  \
# 0           -37.819345           145.121835
# 1           -37.819113           145.121386
# 2           -37.839836           145.033395
# 3           -37.821583           145.036402
# 4           -37.820629           145.140820
#
#                       nearest_school  school_latitude  school_longitude
# 0           Our Lady of Sion College        -37.81835         145.12992
# 1  Box Hill Senior Secondary College        -37.80924         145.11191
# 2                     Scotch College        -37.83392         145.03229
# 3                  Rossbourne School        -37.82304         145.02655
# 4        Doncaster Secondary College        -37.78458         145.13805

# %%
# Average lat/lon for center
melbourne_center = [rental_listings_clean['latitude'].mean(), rental_listings_clean['longitude'].mean()]
listing_map = folium.Map(location=melbourne_center, zoom_start=13)

# Add coworking space markers
for _, row in rental_listings_clean.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['Address'],
    ).add_to(listing_map)
    folium.Marker(
        location=[row['school_latitude'], row['school_longitude']],
        popup=row['nearest_school'],
        icon=folium.Icon(color='green', icon='school', prefix='fa')
    ).add_to(listing_map)

# Display the map
listing_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_201cbfc882c347ed4813206f0ec4fa13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_201cbfc882c347ed4813206f0ec4fa13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_201cbfc882c347ed4813206f0ec4fa13 = L.map(
#                 &quot;map_201cbfc882c347ed4813206f0ec4fa13&quot;,
#                 {
#                     center: [-37.85001128666667, 145.10367756666668],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5aa54798363d7f2ad4bc9295b6412b3f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5aa54798363d7f2ad4bc9295b6412b3f.addTo(map_201cbfc882c347ed4813206f0ec4fa13);
#
#
#             var marker_46447265ade0e01e30fc00ef24198acd = L.marker(
#                 [-37.8231233, 145.1236049],
#                 {
# }
#             ).addTo(map_201cbfc882c347ed4813206f0ec4fa13);
#
#
#         var popup_cf83fabf2e9039ecbc33f38d3a365ac5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c969cc660cc20c76143281756a9c88c = $(`&lt;div id=&quot;html_0c969cc660cc20c76143281756a9c88c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;8 Ashted Road, Box Hill, Vic&lt;/div&gt;`)[0];
#                 popup_cf83fabf2e9039ecbc33f38d3a365ac5.setContent(html_0c969cc660cc20c76143281756a9c88c);
#
#
#
#         marker_46447265ade0e01e30fc00ef24198acd.bindPopup(popup_cf83fabf2e9039ecbc33f38d3a365ac5)
#         ;
#
#
#
#
#             var marker_302c5530aa9a91fc2bf90c74d51a3b8f = L.marker(
#                 [-37.81835, 145.12992],
#                 {
# }
#             ).addTo(map_201cbfc882c347ed4813206f0ec4fa13);
#
#
#             var icon_bc28241a98ccf8d96ffde81d74def5de = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;school&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_302c5530aa9a91fc2bf90c74d51a3b8f.setIcon(icon_bc28241a98ccf8d96ffde81d74def5de);
#
#
#         var popup_13e73e9115dbd23069199ae4e8da35e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1a6f64847ad5b88b64001b5fc50981d = $(`&lt;div id=&quot;html_a1a6f64847ad5b88b64001b5fc50981d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Our Lady of Sion College&lt;/div&gt;`)[0];
#                 popup_13e73e9115dbd23069199ae4e8da35e9.setContent(html_a1a6f64847ad5b88b64001b5fc50981d);
#
#
#
#         marker_302c5530aa9a91fc2bf90c74d51a3b8f.bindPopup(popup_13e73e9115dbd23069199ae4e8da35e9)
#         ;
#
#
#
#
#             var marker_bd6ac80f04c97154fd6ffff90e6776f9 = L.marker(
#                 [-37.8176227, 145.1184549],
#                 {
# }
#             ).addTo(map_201cbfc882c347ed4813206f0ec4fa13);
#
#
#         var popup_52c3c687d6fabb37935fdcbb62105509 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7466b1523b289606db534c83aedec5aa = $(`&lt;div id=&quot;html_7466b1523b289606db534c83aedec5aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;850 Whitehorse Road, Box Hill, Vic&lt;/div&gt;`)[0];
#                 popup_52c3c687d6fabb37935fdcbb62105509.setContent(html_7466b1523b289606db534c83aedec5aa);
#
#
#
#         marker_bd6ac80f04c97154fd6ffff90e6776f9.bindPopup(popup_52c3c687d6fabb37935fdcbb62105509)
#         ;
#
#
#
#
#             var marker_eb8b378e514e2c3eab315a78e1b71e15 = L.marker(
#                 [-37.80924, 145.11191],
#                 {
# }
#             ).addTo(map_201cbfc882c347ed4813206f0ec4fa13);
#
#
#             var icon_c497f9bcbaf1c1a019152c231413038a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;school&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_eb8b378e514e2c3eab315a78e1b71e15.setIcon(icon_c497f9bcbaf1c1a019152c231413038a);
#
#
#         var popup_02780fb001768ea0c8075f0f45b6d757 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4160ac2d9bb8ace7bdaf30c7dee058c6 = $(`&lt;div id=&quot;html_4160ac2d9bb8ace7bdaf30c7dee058c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Box Hill Senior Secondary College&lt;/div&gt;`)[0];
#                 popup_02780fb001768ea0c8075f0f45b6d757.setContent(html_4160ac2d9bb8ace7bdaf30c7dee058c6);
#
#
#
#         marker_eb8b378e514e2c3eab315a78e1b71e15.bindPopup(

# %% [markdown]
# From the above codes, nearest schools, coordinates and distances to rental listings are added to the table.

# %% [markdown]
# ### Workplace Location

# %% [markdown]
# In the below code, tenants can fill in their workplace address to calculate their travelling distance by train to the city.

# %%
work_place = input("Enter your workplace address: ")
print(f"You entered: {work_place}")

work_place_coords = geocode_address(work_place)
work_place_coords
# Out:
# You entered: 480 Collins St, Melbourne
# (-37.817696, 144.9580457)

# %% [markdown]
# Then the nearest station from their workplace is found through "find nearest station" function

# %%
work_place_station = find_nearest_station(work_place_coords[0], work_place_coords[1], kdtree_train, train_data_clean)[0]
work_place_station
# Out:
# 'Southern Cross Station'

# %% [markdown]
# ### Train Travelling Time Calculation

# %% [markdown]
# The below function converts a GTFS-style time string like "HH:MM:SS" into a datetime.timedelta. In GTFS, times can go past 24 hours (e.g., "25:10:00") to represent trips after midnight. The code parses the hours, minutes, and seconds; if the hour is 24 or more, it subtracts 24 and returns a timedelta with one extra day plus the remaining hours/minutes/seconds. Otherwise, it returns a normal timedelta for that time since midnight.

# %%
from datetime import  timedelta
def parse_time(gtfs_time: str) -> timedelta:

        hours, minutes, seconds = map(int, gtfs_time.split(':'))
        if hours >= 24:
            hours = hours - 24
            return timedelta(days=1, hours=hours, minutes=minutes, seconds=seconds)
        return timedelta(hours=hours, minutes=minutes, seconds=seconds)

# %% [markdown]
# This below code snippet reorganises the merged GTFS table so it’s indexed by ("stop_name", "trip_id"), which makes looking up all rows for a given station fast. The check_direct_route function then pulls all stop-time rows between two stations, merges them on find trips that include both stations, and filters to keep only those where A’s stop_sequence comes before B’s so that we could find a direct train that reaches B after A on the same trip. It returns a boolean indicating whether such trips exist plus the matching trip_ids. Finally, that function is applied row-by-row to the speadsheet, comparing each listing’s nearest station to work place nearest station, producing two new columns: has_direct_route (True/False) and direct_trip_ids (the list of matching trips).

# %%
stop_times_clean = train_data_clean.set_index(["stop_name", "trip_id"]).sort_index()

def check_direct_route(stop_a, stop_b, stop_times_df):

        try:
            stop_a_times = stop_times_df.xs(stop_a, level='stop_name')
            stop_b_times = stop_times_df.xs(stop_b, level='stop_name')
        except KeyError:
            return False, []

        merged = pd.merge(stop_a_times.reset_index(), stop_b_times.reset_index(), on='trip_id', suffixes=('_a', '_b'))
        valid_trips = merged[merged['stop_sequence_a'] < merged['stop_sequence_b']]

        if not valid_trips.empty:
            return True, valid_trips['trip_id'].unique()
        return False, []

rental_listings_clean[["has_direct_route", "direct_trip_ids"]] = (
    rental_listings_clean.apply(
        lambda r: pd.Series(
            check_direct_route(str(r["nearest_station"]), work_place_station, stop_times_clean)
        ),
        axis=1
    )
)
rental_listings_clean.head()
# Out:
#       Suburb  Postcode                              Address   latitude  \
# 0   Box Hill      3128         8 Ashted Road, Box Hill, Vic -37.823123
# 1   Box Hill      3128   850 Whitehorse Road, Box Hill, Vic -37.817623
# 2   Hawthorn      3122   494 Glenferrie Road, Hawthorn, Vic -37.831820
# 3   Hawthorn      3122      200 Burwood Road, Hawthorn, Vic -37.822106
# 4  Doncaster      3108  77-79 Wetherby Road, Doncaster, Vic -37.793920
#
#     longitude     nearest_station  distance_meters_station  \
# 0  145.123605    Box Hill Station               447.359525
# 1  145.118455    Box Hill Station               306.547766
# 2  145.033863     Kooyong Station               890.688011
# 3  145.029912  Glenferrie Station               574.354559
# 4  145.141978    Laburnum Station              2966.247633
#
#    nearest_station_lat  nearest_station_lon  \
# 0           -37.819345           145.121835
# 1           -37.819113           145.121386
# 2           -37.839836           145.033395
# 3           -37.821583           145.036402
# 4           -37.820629           145.140820
#
#                       nearest_school  school_latitude  school_longitude  \
# 0           Our Lady of Sion College        -37.81835         145.12992
# 1  Box Hill Senior Secondary College        -37.80924         145.11191
# 2                     Scotch College        -37.83392         145.03229
# 3                  Rossbourne School        -37.82304         145.02655
# 4        Doncaster Secondary College        -37.78458         145.13805
#
#    has_direct_route                                    direct_trip_ids
# 0              True  [02-BEG--1-T5-3600, 02-BEG--1-T5-3602, 02-BEG-...
# 1              True  [02-BEG--1-T5-3600, 02-BEG--1-T5-3602, 02-BEG-...
# 2             False                                                 []
# 3              True  [02-ALM--1-T5-2800, 02-ALM--1-T5-2802, 02-ALM-...
# 4              True  [02-BEG--1-T5-3600, 02-BEG--1-T5-3602, 02-BEG-...

# %% [markdown]
# The function below estimates how long a multi-stop public-transport route takes. It sorts the stop-times for fast lookups, then walks the route pair-by-pair (from staion A to statopm B). For each leg it first checks there’s a direct trip from A to B (by using check_direct_route); if not, it returns None. It picks the first matching trip_id, pulls A’s departure and B’s arrival times for that trip, converts them to timedeltas with parse_time, computes the leg duration, and accumulates the total in seconds. At the end it returns the total minutes to travel of all routes.

# %%
def calculate_route_travel_time(route, stops_df, stop_times_df):

        total_travel_time = 0.0

        stop_times_df.sort_index(inplace=True)

        for i in range(len(route) - 1):
            station_a = route[i]
            station_b = route[i + 1]

            direct_route_exists, trip_ids = check_direct_route(station_a, station_b, stop_times_df)
            if not direct_route_exists:
                return None

            best_trip_id = trip_ids[0]

            try:
                stop_a_time = stop_times_df.loc[(station_a, best_trip_id),'departure_time']
                stop_b_time = stop_times_df.loc[(station_b, best_trip_id),'arrival_time']

                if isinstance(stop_a_time, pd.Series):
                    stop_a_time = stop_a_time.iloc[0]
                if isinstance(stop_b_time, pd.Series):
                    stop_b_time = stop_b_time.iloc[0]

            except KeyError:
                return None

            travel_time = parse_time(stop_b_time) - parse_time(stop_a_time)
            total_travel_time += travel_time.total_seconds()

        return total_travel_time / 60  # Return time in minutes

# %% [markdown]
# In the below function, if there is a direct route between two stops, travel time is calculated. Otherwise, it forces a transfer via Flinders Street Station, which is a common transferring center for those working in CBD. In both cases it returns the total travel time (in minutes) computed by calculate_route_travel_time (or None if any leg can’t be found).

# %%
def add_travel_time(has_direct_route,station_a,station_b, stops_df,stop_times_df):
    if has_direct_route:
        return calculate_route_travel_time([station_a]+[station_b], stops_df, stop_times_df)
    return calculate_route_travel_time([station_a] + ['Flinders Street Station'] + [station_b], stops_df, stop_times_df)

# %% [markdown]
# Finally, the train travel time is calculated for each of the rental listing.

# %%
rental_listings_clean[['train_travel_time']] = (
    rental_listings_clean.apply(
        lambda r: pd.Series(
            add_travel_time(r["has_direct_route"],r['nearest_station'], work_place_station,train_stops, stop_times_clean)
        ),
        axis=1
    )
)
rental_listings_clean.head()
# Out:
#       Suburb  Postcode                              Address   latitude  \
# 0   Box Hill      3128         8 Ashted Road, Box Hill, Vic -37.823123
# 1   Box Hill      3128   850 Whitehorse Road, Box Hill, Vic -37.817623
# 2   Hawthorn      3122   494 Glenferrie Road, Hawthorn, Vic -37.831820
# 3   Hawthorn      3122      200 Burwood Road, Hawthorn, Vic -37.822106
# 4  Doncaster      3108  77-79 Wetherby Road, Doncaster, Vic -37.793920
#
#     longitude     nearest_station  distance_meters_station  \
# 0  145.123605    Box Hill Station               447.359525
# 1  145.118455    Box Hill Station               306.547766
# 2  145.033863     Kooyong Station               890.688011
# 3  145.029912  Glenferrie Station               574.354559
# 4  145.141978    Laburnum Station              2966.247633
#
#    nearest_station_lat  nearest_station_lon  \
# 0           -37.819345           145.121835
# 1           -37.819113           145.121386
# 2           -37.839836           145.033395
# 3           -37.821583           145.036402
# 4           -37.820629           145.140820
#
#                       nearest_school  school_latitude  school_longitude  \
# 0           Our Lady of Sion College        -37.81835         145.12992
# 1  Box Hill Senior Secondary College        -37.80924         145.11191
# 2                     Scotch College        -37.83392         145.03229
# 3                  Rossbourne School        -37.82304         145.02655
# 4        Doncaster Secondary College        -37.78458         145.13805
#
#    has_direct_route                                    direct_trip_ids  \
# 0              True  [02-BEG--1-T5-3600, 02-BEG--1-T5-3602, 02-BEG-...
# 1              True  [02-BEG--1-T5-3600, 02-BEG--1-T5-3602, 02-BEG-...
# 2             False                                                 []
# 3              True  [02-ALM--1-T5-2800, 02-ALM--1-T5-2802, 02-ALM-...
# 4              True  [02-BEG--1-T5-3600, 02-BEG--1-T5-3602, 02-BEG-...
#
#    train_travel_time
# 0               30.0
# 1               30.0
# 2               16.0
# 3               15.0
# 4               33.0

# %% [markdown]
# ### Car Travelling Time Calculation

# %% [markdown]
# This function uses the OpenRouteService Directions API to estimate travel time between two points. By passing start/end latitude/longitude plus an api_key (and default the means of transportation is "driving-car"), it builds a client, requests a route in GeoJSON, then looks at the first feature’s first segment and iterates over its turn-by-turn steps, summing each step’s duration and distance. Finally, it converts the summed duration to minutes and returns that number.

# %%
def calculate_driving_time(start_lat, start_lng, end_lat, end_lng,api_key, profile='driving-car'):
    #Create an OpenRouteService client instance
    client = openrouteservice.Client(key=api_key)

    #Set up coordinates for the route
    coordinates = [[start_lng, start_lat], [end_lng, end_lat]]
    #Get the route between the coordinates with the specified profile (e.g. can have walking/driving)
    route = client.directions(coordinates=coordinates, profile=profile, format='geojson')
    steps = route['features'][0]['properties']['segments'][0]['steps']
    total_distance = 0
    total_duration = 0

    #Generating step information
    for step in steps:
        instruction = step['instruction']
        distance = step['distance']
        duration = step['duration']

        #Accumulate total distance and duration
        total_distance += distance
        total_duration += duration
    
    total_duration = total_duration/60
    return total_duration

# %% [markdown]
# Lastly the function was applied to all rental listings and find their driving time from each place to the nearest school.

# %%
api_key = '5b3ce3597851110001cf6248a6b7c97bb850491794bb504b30e2f2f7'

rental_listings_clean[['house_school_travel_time']] = (
    rental_listings_clean.apply(
        lambda r: pd.Series(
            
            calculate_driving_time(r["latitude"], r["longitude"], r['school_latitude'], r['school_longitude'],api_key=api_key, profile='driving-car')
            
        ),
        axis=1
    )
)
rental_listings_clean.head()
# Out:
#       Suburb  Postcode                              Address   latitude  \
# 0   Box Hill      3128         8 Ashted Road, Box Hill, Vic -37.823123
# 1   Box Hill      3128   850 Whitehorse Road, Box Hill, Vic -37.817623
# 2   Hawthorn      3122   494 Glenferrie Road, Hawthorn, Vic -37.831820
# 3   Hawthorn      3122      200 Burwood Road, Hawthorn, Vic -37.822106
# 4  Doncaster      3108  77-79 Wetherby Road, Doncaster, Vic -37.793920
#
#     longitude     nearest_station  distance_meters_station  \
# 0  145.123605    Box Hill Station               447.359525
# 1  145.118455    Box Hill Station               306.547766
# 2  145.033863     Kooyong Station               890.688011
# 3  145.029912  Glenferrie Station               574.354559
# 4  145.141978    Laburnum Station              2966.247633
#
#    nearest_station_lat  nearest_station_lon  \
# 0           -37.819345           145.121835
# 1           -37.819113           145.121386
# 2           -37.839836           145.033395
# 3           -37.821583           145.036402
# 4           -37.820629           145.140820
#
#                       nearest_school  school_latitude  school_longitude  \
# 0           Our Lady of Sion College        -37.81835         145.12992
# 1  Box Hill Senior Secondary College        -37.80924         145.11191
# 2                     Scotch College        -37.83392         145.03229
# 3                  Rossbourne School        -37.82304         145.02655
# 4        Doncaster Secondary College        -37.78458         145.13805
#
#    has_direct_route                                    direct_trip_ids  \
# 0              True  [02-BEG--1-T5-3600, 02-BEG--1-T5-3602, 02-BEG-...
# 1              True  [02-BEG--1-T5-3600, 02-BEG--1-T5-3602, 02-BEG-...
# 2             False                                                 []
# 3              True  [02-ALM--1-T5-2800, 02-ALM--1-T5-2802, 02-ALM-...
# 4              True  [02-BEG--1-T5-3600, 02-BEG--1-T5-3602, 02-BEG-...
#
#    train_travel_time  house_school_travel_time
# 0               30.0                  2.675000
# 1               30.0                  3.571667
# 2               16.0                  0.643333
# 3               15.0                  0.921667
# 4               33.0                  3.001667

# %% [markdown]
# Similarly, travel time from school to the nearest station is calculated by passing latitude and longitude of schools and nearest stations.

# %%
rental_listings_clean[['school_station_travel_time']] = (
    rental_listings_clean.apply(
        lambda r: pd.Series(
            
            calculate_driving_time(r["school_latitude"], r["school_longitude"], r['nearest_station_lat'], r['nearest_station_lon'],api_key=api_key, profile='driving-car')
            
        ),
        axis=1
    )
)
rental_listings_clean.head()
# Out:
#       Suburb  Postcode                              Address   latitude  \
# 0   Box Hill      3128         8 Ashted Road, Box Hill, Vic -37.823123
# 1   Box Hill      3128   850 Whitehorse Road, Box Hill, Vic -37.817623
# 2   Hawthorn      3122   494 Glenferrie Road, Hawthorn, Vic -37.831820
# 3   Hawthorn      3122      200 Burwood Road, Hawthorn, Vic -37.822106
# 4  Doncaster      3108  77-79 Wetherby Road, Doncaster, Vic -37.793920
#
#     longitude     nearest_station  distance_meters_station  \
# 0  145.123605    Box Hill Station               447.359525
# 1  145.118455    Box Hill Station               306.547766
# 2  145.033863     Kooyong Station               890.688011
# 3  145.029912  Glenferrie Station               574.354559
# 4  145.141978    Laburnum Station              2966.247633
#
#    nearest_station_lat  nearest_station_lon  \
# 0           -37.819345           145.121835
# 1           -37.819113           145.121386
# 2           -37.839836           145.033395
# 3           -37.821583           145.036402
# 4           -37.820629           145.140820
#
#                       nearest_school  school_latitude  school_longitude  \
# 0           Our Lady of Sion College        -37.81835         145.12992
# 1  Box Hill Senior Secondary College        -37.80924         145.11191
# 2                     Scotch College        -37.83392         145.03229
# 3                  Rossbourne School        -37.82304         145.02655
# 4        Doncaster Secondary College        -37.78458         145.13805
#
#    has_direct_route                                    direct_trip_ids  \
# 0              True  [02-BEG--1-T5-3600, 02-BEG--1-T5-3602, 02-BEG-...
# 1              True  [02-BEG--1-T5-3600, 02-BEG--1-T5-3602, 02-BEG-...
# 2             False                                                 []
# 3              True  [02-ALM--1-T5-2800, 02-ALM--1-T5-2802, 02-ALM-...
# 4              True  [02-BEG--1-T5-3600, 02-BEG--1-T5-3602, 02-BEG-...
#
#    train_travel_time  house_school_travel_time  school_station_travel_time
# 0               30.0                  2.675000                    4.025000
# 1               30.0                  3.571667                    4.698333
# 2               16.0                  0.643333                    1.788333
# 3               15.0                  0.921667                    2.663333
# 4               33.0                  3.001667                    8.800000

# %% [markdown]
# Lastly, a sum between travelling time by train to the workplace and by car to school is calculated and passed into an index called "total travel time".

# %%
rental_listings_clean = rental_listings_clean.assign(
    total_travel_time = rental_listings_clean[['train_travel_time','house_school_travel_time','school_station_travel_time']].sum(axis=1)
)
rental_listings_clean.head(10)
# Out:
#       Suburb  Postcode                              Address   latitude  \
# 0   Box Hill      3128         8 Ashted Road, Box Hill, Vic -37.823123
# 1   Box Hill      3128   850 Whitehorse Road, Box Hill, Vic -37.817623
# 2   Hawthorn      3122   494 Glenferrie Road, Hawthorn, Vic -37.831820
# 3   Hawthorn      3122      200 Burwood Road, Hawthorn, Vic -37.822106
# 4  Doncaster      3108  77-79 Wetherby Road, Doncaster, Vic -37.793920
# 5  Doncaster      3108    21 Sargent Street, Doncaster, Vic -37.796604
# 6    Mitcham      3132        1A Bruce Street, Mitcham, Vic -37.812899
# 7    Mitcham      3132       12 Norman Street, Mitcham, Vic -37.825342
# 8    Burwood      3125      15 Cumming Street, Burwood, Vic -37.851436
# 9    Burwood      3125    373 Burwood Highway, Burwood, Vic -37.851370
#
#     longitude         nearest_station  distance_meters_station  \
# 0  145.123605        Box Hill Station               447.359525
# 1  145.118455        Box Hill Station               306.547766
# 2  145.033863         Kooyong Station               890.688011
# 3  145.029912      Glenferrie Station               574.354559
# 4  145.141978        Laburnum Station              2966.247633
# 5  145.121610        Box Hill Station              2498.408059
# 6  145.185698         Mitcham Station               869.709394
# 7  145.197730         Mitcham Station               901.263971
# 8  145.113543     Jordanville Station              2473.906468
# 9  145.129730  Mount Waverley Station              2651.115690
#
#    nearest_station_lat  nearest_station_lon  \
# 0           -37.819345           145.121835
# 1           -37.819113           145.121386
# 2           -37.839836           145.033395
# 3           -37.821583           145.036402
# 4           -37.820629           145.140820
# 5           -37.819113           145.121386
# 6           -37.817984           145.193212
# 7           -37.818047           145.193234
# 8           -37.873708           145.112463
# 9           -37.875220           145.128102
#
#                       nearest_school  school_latitude  school_longitude  \
# 0           Our Lady of Sion College        -37.81835         145.12992
# 1  Box Hill Senior Secondary College        -37.80924         145.11191
# 2                     Scotch College        -37.83392         145.03229
# 3                  Rossbourne School        -37.82304         145.02655
# 4        Doncaster Secondary College        -37.78458         145.13805
# 5      Box Hill North Primary School        -37.80079         145.12331
# 6                   St John's School        -37.81744         145.19040
# 7           Rangeview Primary School        -37.82958         145.20630
# 8      Mount Scopus Memorial College        -37.84722         145.11777
# 9            St Scholastica's School        -37.85165         145.12591
#
#    has_direct_route                                    direct_trip_ids  \
# 0              True  [02-BEG--1-T5-3600, 02-BEG--1-T5-3602, 02-BEG-...
# 1              True  [02-BEG--1-T5-3600, 02-BEG--1-T5-3602, 02-BEG-...
# 2             False                                                 []
# 3              True  [02-ALM--1-T5-2800, 02-ALM--1-T5-2802, 02-ALM-...
# 4              True  [02-BEG--1-T5-3600, 02-BEG--1-T5-3602, 02-BEG-...
# 5              True  [02-BEG--1-T5-3600, 02-BEG--1-T5-3602, 02-BEG-...
# 6              True  [02-BEG--1-T5-3600, 02-BEG--1-T5-3602, 02-BEG-...
# 7              True  [02-BEG--1-T5-3600, 02-BEG--1-T5-3602, 02-BEG-...
# 8             False                                                 []
# 9             False                                                 []
#
#    train_travel_time  house_school_travel_time  school_station_travel_time  \
# 0               30.0                  2.675000                    4.025000
# 1               30.0                  3.571667                    4.698333
# 2               16.0                  0.643333                    1.788333
# 3               15.0                  0.921667                    2.663333
# 4               33.0                  3.001667                    8.800000
# 5               30.0                  4.288333                    6.773333
# 6               41.0                  2.390000                    1.933333
# 7               41.0                  5.045000                    5.280000
# 8               31.0                  2.216667                    7.126667
# 9               33.0                  0.591667                    6.053333
#
#    total_travel_time
# 0          36.700000
# 1          38.270000
# 2          18.431667
# 3          18.585000
# 4          44.801667
# 5          41.061667
# 6          45.323333
# 7          51.325000
# 8          40.343333
# 9          39.645000

# %% [markdown]
# ### Ranking travelling time among rental listings

# %% [markdown]
# Based on the travel time, top 10 rental listings that are most convenient and save the most travelling time are listed below by sorting the total travel time by ascending order.

# %%
top10_listing = (rental_listings_clean
         .sort_values("total_travel_time", ascending=True)
         .head(10)
         .copy())
top10_listing
# Out:
#          Suburb  Postcode                               Address   latitude  \
# 2      Hawthorn      3122    494 Glenferrie Road, Hawthorn, Vic -37.831820
# 3      Hawthorn      3122       200 Burwood Road, Hawthorn, Vic -37.822106
# 27  Pascoe vale      3044         14 BOLINGBROKE STREET, PASCOE -37.732244
# 23    Caulfield      3162    7-13 Dudley Street, Caulfield, Vic -37.880196
# 26     Carnegie      3163  1256 Glen Huntly Road, Carnegie, Vic -37.890143
# 17     Brighton      3186    79-81 Asling Street, Brighton, Vic -37.894658
# 15   Camberwell      3124     1101 Toorak Road, Camberwell, Vic -37.847936
# 24   Hughesdale      3166     89 Kangaroo Road, Hughesdale, Vic -37.898793
# 25    Chadstone      3148        2 Kelly Street, Chadstone, Vic -37.885375
# 0      Box Hill      3128          8 Ashted Road, Box Hill, Vic -37.823123
#
#      longitude      nearest_station  distance_meters_station  \
# 2   145.033863      Kooyong Station               890.688011
# 3   145.029912   Glenferrie Station               574.354559
# 27  144.936236  Pascoe Vale Station               706.717089
# 23  145.047438    Caulfield Station               549.733363
# 26  145.047012  Glen Huntly Station               417.646726
# 17  145.003736   Gardenvale Station               220.564460
# 15  145.075152     Hartwell Station               450.452291
# 24  145.078095   Hughesdale Station               567.731399
# 25  145.093011   Holmesglen Station              1223.906970
# 0   145.123605     Box Hill Station               447.359525
#
#     nearest_station_lat  nearest_station_lon              nearest_school  \
# 2            -37.839836           145.033395              Scotch College
# 3            -37.821583           145.036402           Rossbourne School
# 27           -37.731245           144.928318  Pascoe Vale Primary School
# 23           -37.877286           145.042382         St Anthony's School
# 26           -37.889406           145.042356         St Anthony's School
# 17           -37.896622           145.004114      Leibler Yavneh College
# 15           -37.843883           145.075426     Hartwell Primary School
# 24           -37.894022           145.075770            Oakleigh Grammar
# 25           -37.874616           145.089963  Salesian College Chadstone
# 0            -37.819345           145.121835    Our Lady of Sion College
#
#     school_latitude  school_longitude  has_direct_route  \
# 2         -37.83392         145.03229             False
# 3         -37.82304         145.02655              True
# 27        -37.73122         144.93726              True
# 23        -37.88689         145.04710              True
# 26        -37.88689         145.04710             False
# 17        -37.89287         145.00663             False
# 15        -37.84805         145.08447              True
# 24        -37.89591         145.08282              True
# 25        -37.88273         145.10026             False
# 0         -37.81835         145.12992              True
#
#                                       direct_trip_ids  train_travel_time  \
# 2                                                  []               16.0
# 3   [02-ALM--1-T5-2800, 02-ALM--1-T5-2802, 02-ALM-...               15.0
# 27  [02-CGB--1-T2-5200, 02-CGB--1-T3-5460, 02-CGB-...               20.0
# 23  [02-CBE--1-T2-C400, 02-CBE--1-T2-C402, 02-CBE-...               20.0
# 26                                                 []               25.0
# 17                                                 []               22.0
# 15  [02-ALM--1-T5-2800, 02-ALM--1-T5-2802, 02-ALM-...               26.0
# 24  [02-CBE--1-T2-C400, 02-CBE--1-T2-C402, 02-CBE-...               27.0
# 25                                                 []               28.0
# 0   [02-BEG--1-T5-3600, 02-BEG--1-T5-3602, 02-BEG-...               30.0
#
#     house_school_travel_time  school_station_travel_time  total_travel_time
# 2                   0.643333                    1.788333          18.431667
# 3                   0.921667                    2.663333          18.585000
# 27                  1.186667                    1.475000          22.661667
# 23                  3.648333                    3.255000          26.903333
# 26                  1.250000                    1.406667          27.656667
# 17                  2.823333                    3.616667          28.440000
# 15                  2.311667                    3.955000          32.266667
# 24                  3.218333                    2.723333          32.941667
# 25                  3.530000                    3.963333          35.493333
# 0                   2.675000                    4.025000          36.700000

# %% [markdown]
# The above table shows top 10 rental listings based on their accessibility scores.

# %% [markdown]
# ### Visualise top 10 rental listing

# %% [markdown]
# The below function uses Open Route Service API to return a GeoJSON file that could be used to visualise the route between stations.

# %%
def get_route(start_lat, start_lng, end_lat, end_lng, api_key, profile='driving-car'):
    #Create an OpenRouteService client instance
    client = openrouteservice.Client(key=api_key)

    #Set up coordinates for the route
    coordinates = [[start_lng, start_lat], [end_lng, end_lat]]

    #Get the route between the coordinates with the specified profile (e.g. can have walking/driving)
    route = client.directions(coordinates=coordinates, profile=profile, format='geojson')

    #Return the route in GeoJSON format
    return route

# %% [markdown]
# The below code visualises the rental listings. For each listing it adds a marker to represent the listing (Address in popup), a red train icon at the listing’s nearest station, a green school icon at the listing’s nearest school, a briefcase marker for work_place_coords and routes to represent the travelling time by train from nearest stations to workplace.

# %%
# Average lat/lon for center
melbourne_center = [top10_listing['latitude'].mean(), top10_listing['longitude'].mean()]
top_listing_map = folium.Map(location=melbourne_center, zoom_start=11)

# Add coworking space markers
for _, row in top10_listing.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['Address'],
    ).add_to(top_listing_map)
    
    folium.Marker(
        location=[row['nearest_station_lat'], row['nearest_station_lon']],
        popup=row['nearest_station'],
        icon=folium.Icon(color='red', icon='train-subway', prefix='fa')
    ).add_to(top_listing_map)

    folium.Marker(
        location=[row['school_latitude'], row['school_longitude']],
        popup=row['nearest_school'],
        icon=folium.Icon(color='green', icon='school', prefix='fa')
    ).add_to(top_listing_map)

    folium.Marker(
        location=[work_place_coords[0], work_place_coords[1]],
        popup=work_place,
        icon=folium.Icon(color='orange', icon='briefcase', prefix='fa',size=(50,50))
    ).add_to(top_listing_map)

    # Get the route between the coworking space and the nearest public transport station
    transport = get_route(row['nearest_station_lat'], row['nearest_station_lon'], work_place_coords[0], work_place_coords[1], api_key)

    # Add the route to the map
    gj = folium.GeoJson(transport, name="public transport route", style_function=lambda x: {'color': 'blue'})
    folium.Popup(f"Total travel time: {row['train_travel_time']} minutes").add_to(gj)
    gj.add_to(top_listing_map)

# Display the map
top_listing_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b9c4646cc26c4f75cbb1caab941ced37 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b9c4646cc26c4f75cbb1caab941ced37&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b9c4646cc26c4f75cbb1caab941ced37 = L.map(
#                 &quot;map_b9c4646cc26c4f75cbb1caab941ced37&quot;,
#                 {
#                     center: [-37.850639369999996, 145.0468059],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4906c9907651461ba87cdf2cdf418382 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4906c9907651461ba87cdf2cdf418382.addTo(map_b9c4646cc26c4f75cbb1caab941ced37);
#
#
#             var marker_58d1040755421cd5237678d0ff3e10b0 = L.marker(
#                 [-37.8318201, 145.0338629],
#                 {
# }
#             ).addTo(map_b9c4646cc26c4f75cbb1caab941ced37);
#
#
#         var popup_bc86fa32facb5130b17cf78087153df8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c443dfe903a122530d7420bcbfe477cc = $(`&lt;div id=&quot;html_c443dfe903a122530d7420bcbfe477cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;494 Glenferrie Road, Hawthorn, Vic&lt;/div&gt;`)[0];
#                 popup_bc86fa32facb5130b17cf78087153df8.setContent(html_c443dfe903a122530d7420bcbfe477cc);
#
#
#
#         marker_58d1040755421cd5237678d0ff3e10b0.bindPopup(popup_bc86fa32facb5130b17cf78087153df8)
#         ;
#
#
#
#
#             var marker_ebbbedb0d6cd133e922be0f6cc0d69c8 = L.marker(
#                 [-37.83983621, 145.03339498],
#                 {
# }
#             ).addTo(map_b9c4646cc26c4f75cbb1caab941ced37);
#
#
#             var icon_b4198bf2a7f6c4203d9b57b9212f6583 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;train-subway&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_ebbbedb0d6cd133e922be0f6cc0d69c8.setIcon(icon_b4198bf2a7f6c4203d9b57b9212f6583);
#
#
#         var popup_c6671f722384fa17d89dd832af010ce3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_997987bb7ddd03a6af1d04b68fc7f93b = $(`&lt;div id=&quot;html_997987bb7ddd03a6af1d04b68fc7f93b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kooyong Station&lt;/div&gt;`)[0];
#                 popup_c6671f722384fa17d89dd832af010ce3.setContent(html_997987bb7ddd03a6af1d04b68fc7f93b);
#
#
#
#         marker_ebbbedb0d6cd133e922be0f6cc0d69c8.bindPopup(popup_c6671f722384fa17d89dd832af010ce3)
#         ;
#
#
#
#
#             var marker_aaafeefd535b9274adb680106b319b9b = L.marker(
#                 [-37.83392, 145.03229],
#                 {
# }
#             ).addTo(map_b9c4646cc26c4f75cbb1caab941ced37);
#
#
#             var icon_4d03b48bbd4eec385cb04118c734d58b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;school&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_aaafeefd535b9274adb680106b319b9b.setIcon(icon_4d03b48bbd4eec385cb04118c734d58b);
#
#
#         var popup_6d89a3928ee5e36e7e47ec62d662ede3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d0c968f8db39080b03e414c3840ca2e = $(`&lt;div id=&quot;html_1d0c968f8db39080b03e414c3840ca2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Scotch College&lt;/div&gt;`)[0];
#                 popup_6d89a3928ee5e36e7e47ec62d662ede3.setContent(html_1d0c968f8db39080b03e414c3840ca2e);
#
#
#
#         marker_aaafeefd535b9274adb680106b319b9b.bindPopup(popup_6d89a3928ee5e36e7e47ec62d662ede3)
#         ;
#
#
#
#
#             var marker_66ab2a9e7ebe1926f6411b38e3292b04 = L.marker(
#                 [-37.817696, 144.9580457],
#                 {
# }
#             ).addTo(map_b9c4646cc26c4f75cbb1caab941ced37);
#
#
#             var icon_73ee0dc62f3da926cdf4b1e1d600f556 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;briefcase&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
#   &quot;size&quot;: [50, 50],
# }
#             );
#             marker_66ab2a9e7ebe1926f6411b38e3292b04.setIcon(icon_73ee0dc62f3da926cdf4b1e1d600f556);
#
#
#         var popup_5a483ffda2955de0b716a525d5fa1459 = L.popup({
#   &quot;maxWidth&quot

# %% [markdown]
# The top 10 rental listings are visualised into a map. When tenants click on each route, the total time to travel by train is also visualised.
#
# **From the map, there are some insights that can be drawn:**
#
# * Where the top 10 cluster
# Most listings sit in the inner-east / south-east corridor (Hawthorn, Camberwell, Caulfield, Carnegie, Hughesdale, Chadstone, Brighton). Only Pascoe Vale (north) and Deer Park (outer west) are outliers. Routes visibly converge on the CBD hub, which matches Melbourne’s rail topology.
#
# * Accessibility to the station
# Nine of ten are < 1.3 km from a station. Chadstone is the furthese with 1.2 km from the nearest metro station (Holmesglen Station).
#
# * Direct vs transfer
# Most of the top listings have direct route to Southern Cross Station. For example Box Hill, Pascoe Vale, Caulfield, Camberwell, Hughesdale; For Carnegie, Brighton, Chadstone tenants will have to transfer at Flinders St Station.
#
# * Commute time ranking
# Fastest routes are both from Hawthorn. with less than 19 minutes to travel
# Pascoe Vale is the runner up.
# For Caulfield is about 27 minutes total travel time
#
# * Schools proximity
# Most are very close to a school. Hawthorn/Pascoe Vale are the quickest; Chadstone/Caulfield a bit longer but still a short drive.

# %% [markdown]
# This use case provides a flexible solution for those who are looking for a place to rent when multiple rental listings can be visualised through a map with the closest train stations, schools and proximity to their workplace. Tenants can also add multiple places of interest like a friend/relative's house and the codes could provide a holistic view of the most suitable listings to their preference. This could save plenty of time from using multiple platforms to calculate travelling time like Google Maps and PTV.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Melbourne’s rental hunt is really a transport problem in disguise. For families, the daily reality isn’t a single commute; it’s a chain from home to school, and to work via different means of transportation either by car, walking or using public transportation.
#
# That’s why a tool to calculate combined travel time matters. Those times should include driving to school or station, transfers, and travelling to CBD by train. Measured this way, two homes with the same rent can differ by hours per week in “time cost”, which quickly outweighs small rent differences. By using this tool, tenants can input their workplace address or any other place in interest (like shopping malls, a friend's house or doctor's adress), and have a holistic view of how each rental listing can meet their needs and choose the most suitable one.
