# %% [markdown]
# # Housing Recommendation based on distance to nearby utilities
#
# **Authored by**:  Linh Huong Nguyen
#
# **Duration**: 90 mins
#
# **Level**: Intermediate
#
# **Pre-requisite Skills**: Python, Pandas, Matplotlib, NumbPy, Seaborn, Scikit-learn

# %% [markdown]
# ### Scenario

# %% [markdown]
# As a tenant looking for rental houses, I want to calculate the distance between rental listings and key public amenities such as public transportation hubs, schools, and public landmarks in the City of Melbourne, so that I can choose the most suitable place to apply for rent.

# %% [markdown]
# ### What this use case will teach you

# %% [markdown]
# At the end of this use case, you will have demonstrated the following skills:
#
# * Accessed and imported geospatial and rental listing datasets from open data portals and APIs.
#
# * Performed data cleaning, preprocessing, and geocoding of addresses to ensure spatial accuracy.
#
# * Used geospatial libraries to calculate distances between points of interest (POIs) and rental properties.
#
# * Conducted exploratory data analysis (EDA) to assess accessibility patterns and disparities.
#
# * Visualized geospatial data on interactive maps to highlight proximity patterns and coverage gaps.
#
# * Derived actionable insights to inform housing accessibility and urban development policies.

# %% [markdown]
# ### Background and Introduction

# %% [markdown]
# The accessibility of essential public amenities such as transportation hubs, schools, and public landmarks plays a significant role in shaping rental market dynamics, urban livability, and resident satisfaction. For renters, proximity to these amenities can influence housing decisions, commute times, and quality of life. For policymakers and urban planners, understanding how well rental properties are served by these facilities is crucial for identifying underserved areas, prioritizing infrastructure investments, and ensuring equitable access across the community.
#
# This use case addresses the need for a data-driven approach to evaluating the spatial relationship between rental housing and public amenities in the City of Melbourne. By combining rental property data with geospatial datasets of public transport stations, schools, and notable landmarks, we can calculate precise distances and analyze accessibility patterns across the city. These insights can help guide housing policy, transport planning, and community development initiatives.

# %% [markdown]
# ### Datasets used

# %% [markdown]
# * City of Melbourne Public Transport Stops
# This dataset contains the locations of public transport stops (including train, tram, and bus) within the City of Melbourne. It includes stop names, modes, geographic coordinates, and route information. Data is sourced from the Melbourne Open Data portal and accessible via API V2.1.
#
# * Victoria School Locations 2024
# This dataset contains the list of all school locations in Victoria, including primary and secondary schools, government and non-government. Attributes include school name, sector, type, address, phone, and geographic coordinates. Data is sourced from the Victorian Department of Education and accessible via API V2.1.
#
# * City of Melbourne Landmarks and Places of Interest
# This dataset contains key public landmarks, cultural sites, and recreational facilities within the City of Melbourne. It includes location names, categories, and geographic coordinates. Data is sourced from the Melbourne Open Data portal and accessible via API V2.1.
#
# * [Rental Listings Dataset]
# This dataset contains current rental property listings in the City of Melbourne. Attributes may include address, rental price, property type, number of bedrooms, and listing date. Addresses will be geocoded for spatial analysis.

# %% [markdown]
# ### Importing Datasets

# %% [markdown]
# This section imports essential libraries for data manipulation, visualization, geospatial analysis, interactive mapping, and fetching data from APIs. These libraries provide the necessary functionality for processing, analyzing, and visualizing the project data effectively.

# %%
from geopy.geocoders import Nominatim
from scipy.spatial import KDTree
from geopy.distance import geodesic
import openrouteservice
import requests
import pandas as pd
import os
from io import StringIO
import requests
import seaborn as sns
import folium
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import shape, Point
import json
import zipfile
from io import BytesIO
import re

# %% [markdown]
# ### Loading the datasets using API 2.1v

# %% [markdown]
# This section defines functions for fetching data from APIs. The API_Unlimited function retrieves datasets from the Melbourne Open Data Portal using dataset IDs, processes the data into a DataFrame, and provides a preview for verification. Similarly, the fetch_data_from_url function fetches data directly from a given URL, processes it into a DataFrame, and displays a sample for validation. These functions enable seamless access to external datasets for analysis.

# %%
def API_Unlimited(datasetname): # pass in dataset name and api key
    dataset_id = datasetname

    base_url = 'https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/'
    #apikey = api_key
    dataset_id = dataset_id
    format = 'csv'

    url = f'{base_url}{dataset_id}/exports/{format}'
    
    params = {
        'select': '*',
        'limit': -1,  # all records
        'lang': 'en',
        'timezone': 'UTC'
    }

    # GET request
    response = requests.get(url, params=params)

    if response.status_code == 200:
        # StringIO to read the CSV data
        url_content = response.content.decode('utf-8')
        datasetname = pd.read_csv(StringIO(url_content), delimiter=';')
        print(datasetname.sample(10, random_state=999)) # Test
        return datasetname 
    else:
        return (print(f'Request failed with status code {response.status_code}'))

# %%
def API_Unlimited_external(datasetname): # pass in dataset name and api key
    dataset_id = datasetname

    base_url = 'https://www.education.vic.gov.au/Documents/about/research/datavic/'
    dataset_id = dataset_id
    format = 'csv'

    url = f'{base_url}{dataset_id}.{format}'
    params = {
        'select': '*',
        'limit': -1,  # all records
        'lang': 'en',
        'timezone': 'UTC'
    }

    # GET request
    response = requests.get(url, params=params)

    if response.status_code == 200:
        # StringIO to read the CSV data
        url_content = response.text
        datasetname = pd.read_csv(StringIO(url_content), delimiter=',')
        print(datasetname.sample(10, random_state=999)) # Test
        return datasetname 
    else:
        return (print(f'Request failed with status code {response.status_code}'))

# %% [markdown]
# ### Fetching and Previewing Datasets

# %% [markdown]
# This section defines the dataset download links required for the use case and fetches the corresponding data using the API_Unlimited function. The datasets include school locations and landscapes which are essential for calculating distance from rental listings to utilities.

# %%
download_link_1 = 'landmarks-and-places-of-interest-including-schools-theatres-health-services-spor'
download_link_2 = 'dv378_DataVic-SchoolLocations-2024'

# Use functions to download and load data
landmarks = API_Unlimited(download_link_1)
school_locations = API_Unlimited_external(download_link_2)
# Out:
#                   theme                                        sub_theme  \
# 30   Leisure/Recreation               Major Sports & Recreation Facility
# 18   Leisure/Recreation  Informal Outdoor Facility (Park/Garden/Reserve)
# 154           Transport                               Transport Terminal
# 73            Transport                                  Railway Station
# 20            Transport                                  Railway Station
# 195           Transport                                  Railway Station
# 165              Office                                           Office
# 125  Leisure/Recreation               Major Sports & Recreation Facility
# 85        Community Use                                 Public Buildings
# 54   Leisure/Recreation                     Private Sports Club/Facility
#
#                            feature_name                         co_ordinates
# 30       Melbourne Cricket Ground (MCG)  -37.8194921618419, 144.983402879078
# 18          Shrine of Rembrance Reserve  -37.8320733992876, 144.973628364465
# 154                   Port of Melbourne   -37.8137384362671, 144.91753432375
# 73       Southern Cross Railway Station  -37.8181633057171, 144.952944748845
# 20           Parliament Railway Station  -37.8127621113552, 144.973433796529
# 195           Flagstaff Railway Station  -37.8122356514626, 144.956318211113
# 165  SBS (Special Broadcasting Service)  -37.8176921210305, 144.968740597156
# 125                           AAMI Park   -37.8247252673963, 144.98380297866
# 85                Shrine of Remembrance  -37.8302080020387, 144.973441913623
# 54               Royal Park Golf Course  -37.7819171308558, 144.956309119368
#      Education_Sector  Entity_Type  School_No  \
# 1482       Government            1       5244
# 1673       Government            1       5553
# 976        Government            1       3077
# 1926       Government            1       8466
# 1298       Government            1       4923
# 2134      Independent            2       1729
# 1308       Government            1       4943
# 1413       Government            1       5136
# 49           Catholic            2        324
# 352          Catholic            2       1715
#
#                                 School_Name School_Type  \
# 1482                  Findon Primary School     Primary
# 1673              Tulliallan Primary School     Primary
# 976               Korumburra Primary School     Primary
# 1926           Bairnsdale Secondary College   Secondary
# 1298              Mount View Primary School     Primary
# 2134                Sholem Aleichem College     Primary
# 1308  Wilmot Road Primary School Shepparton     Primary
# 1413              James Cook Primary School     Primary
# 49                      Sacred Heart School     Primary
# 352                   Holy Eucharist School     Primary
#
#               Address_Line_1 Address_Line_2      Address_Town Address_State  \
# 1482          Cuthbert Drive            NaN         Mill Park           VIC
# 1673  89 Wheelers Park Drive            NaN  Cranbourne North           VIC
# 976         6 - 16 Mine Road            NaN        Korumburra           VIC
# 1926        90 Mckean Street            NaN        Bairnsdale           VIC
# 1298   274-288 Gallaghers Rd            NaN     Glen Waverley           VIC
# 2134          11 Sinclair St            NaN       ELSTERNWICK           VIC
# 1308       84-90 Wilmot Road            NaN        Shepparton           VIC
# 1413  29-59 James Cook Drive            NaN   Endeavour Hills           VIC
# 49        69-75 Hogan Street            NaN            TATURA           VIC
# 352         20 Chedgey Drive            NaN         ST ALBANS           VIC
#
#       Address_Postcode  ...         Postal_Town Postal_State Postal_Postcode  \
# 1482              3082  ...           MILL PARK          VIC          3082.0
# 1673              3977  ...  Narre Warren South          VIC          3805.0
# 976               3950  ...          KORUMBURRA          VIC          3950.0
# 1926              3875  ...          BAIRNSDALE          VIC          3875.0
# 1298              3150  ...       GLEN WAVERLEY          VIC          3150.0
# 2134              3185  ...         ELSTERNWICK          VIC          3185.0
# 1308              3630  ...          SHEPPARTON          VIC          3630.0
# 1413              3802  ...     ENDEAVOUR HILLS          VIC          3802.0
# 49                3616  ...              TATURA          VIC          3616.0
# 352               3021  ...           ST ALBANS          VIC          3021.0
#
#      Full_Phone_No             Region_Name                AREA_Name LGA_ID  \
# 1482  03 9404 1362  NORTH-WESTERN VICTORIA  North Eastern Melbourne    707
# 1673  03 8766 3100  SOUTH-EASTERN VICTORIA       Southern Melbourne    161
# 976   03 5655 1309  SOUTH-EASTERN VICTORIA          Inner Gippsland    617
# 1926  03 5150 4800  SOUTH-EASTERN VICTORIA          Outer Gippsland    211
# 1298  03 9560 0471  NORTH-EASTERN VICTORIA  Inner Eastern Melbourne    497
# 2134  03 8527 3000  SOUTH-EASTERN VICTORIA        Bayside Peninsula    231
# 1308  03 5821 4953  NORTH-EASTERN VICTORIA                 Goulburn    283
# 1413  03 9700 2601  SOUTH-EASTERN VICTORIA       Southern Melbourne    161
# 49    03 5824 1841  NORTH-EASTERN VICTORIA                 Goulburn    283
# 352   03 8312 0900  SOUTH-WESTERN VICTORIA          Brimbank Melton    118
#
#                     LGA_Name          X         Y
# 1482          Whittlesea (C)  145.05107 -37.66650
# 1673               Casey (C)  145.32734 -38.08160
# 976      South Gippsland (S)  145.82564 -38.43513
# 1926      East Gippsland (S)  147.60500 -37.82871
# 1298              Monash (C)  145.17881 -37.88348
# 2134           Glen Eira (C)  145.00120 -37.88229
# 1308  Greater Shepparton (C)  145.40590 -36.39850
# 1413               Casey (C)  145.24585 -37.97906
# 49    Greater Shepparton (C)  145.22392 -36.43983
# 352             Brimbank (C)  144.81141 -37.75644
#
# [10 rows x 22 columns]

# %%
school_locations= school_locations.dropna(subset=['Y', 'X'])

# %%
landmarks.head()
# Out:
#                 theme                                        sub_theme  \
# 0       Community Use                                     Fire Station
# 1   Place Of Assembly                               Art Gallery/Museum
# 2    Education Centre                            Tertiary (University)
# 3  Leisure/Recreation  Informal Outdoor Facility (Park/Garden/Reserve)
# 4           Transport                                  Railway Station
#
#                       feature_name                         co_ordinates
# 0  Metropolitan Fire Brigade (MFB)  -37.8092318636838, 144.975247619376
# 1        Koorie Heritage Trust Inc  -37.8133854259085, 144.954027907736
# 2                  RMIT University  -37.8080795360545, 144.964452974798
# 3                 Macarthur Square  -37.7983318676737, 144.971514146104
# 4  North Melbourne Railway Station  -37.8073823625058, 144.942429848025

# %%
landmarks_clean=landmarks.dropna(subset='co_ordinates')
landmarks_clean[['latitude', 'longitude']] =landmarks_clean['co_ordinates'].str.split(',', expand=True).astype(float)
landmarks_clean=landmarks_clean.drop(columns=['co_ordinates'])
landmarks_clean.head()
# Out:
#                 theme                                        sub_theme  \
# 0       Community Use                                     Fire Station
# 1   Place Of Assembly                               Art Gallery/Museum
# 2    Education Centre                            Tertiary (University)
# 3  Leisure/Recreation  Informal Outdoor Facility (Park/Garden/Reserve)
# 4           Transport                                  Railway Station
#
#                       feature_name   latitude   longitude
# 0  Metropolitan Fire Brigade (MFB) -37.809232  144.975248
# 1        Koorie Heritage Trust Inc -37.813385  144.954028
# 2                  RMIT University -37.808080  144.964453
# 3                 Macarthur Square -37.798332  144.971514
# 4  North Melbourne Railway Station -37.807382  144.942430

# %% [markdown]
# ### GTFS Schedule Dataset

# %% [markdown]
# The GTFS Schedule dataset contains static timetable information of public transport services in Victoria

# %%
current_directory = os.getcwd()
dataset_folder = 'mpt_data'
dataset_path = os.path.join(current_directory, dataset_folder)
inner_zip_paths = ['2/google_transit.zip', '3/google_transit.zip', '4/google_transit.zip']

# %%
def API_GTFS(url: str, inner_zip_paths: list) -> dict:

    required_files = ['stops.txt', 'stop_times.txt', 'routes.txt', 'trips.txt', 'calendar.txt']
    datasets = {}
    # Download main zip
    response = requests.get(url)
    response.raise_for_status()

    # Open main zip in memory
    with zipfile.ZipFile(BytesIO(response.content)) as main_zip:
        for inner_zip_path in inner_zip_paths:
            if inner_zip_path not in main_zip.namelist():
                continue

            subfolder_name = os.path.basename(os.path.dirname(inner_zip_path))
            datasets[subfolder_name] = {}

            with main_zip.open(inner_zip_path) as inner_zip_file:
                with zipfile.ZipFile(BytesIO(inner_zip_file.read())) as inner_zip:
                    for file_name in required_files:
                        if file_name in inner_zip.namelist():
                            with inner_zip.open(file_name) as f:
                                datasets[subfolder_name][file_name] = pd.read_csv(f)

    return datasets

# %%
url = 'https://data.ptv.vic.gov.au/downloads/gtfs.zip'
inner_zip_paths = ['2/google_transit.zip', '3/google_transit.zip', '4/google_transit.zip']

datasets  = API_GTFS(url,inner_zip_paths)
# Out:
# C:\Users\phuon\AppData\Local\Temp\ipykernel_35476\2046210630.py:23: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   datasets[subfolder_name][file_name] = pd.read_csv(f)
# C:\Users\phuon\AppData\Local\Temp\ipykernel_35476\2046210630.py:23: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   datasets[subfolder_name][file_name] = pd.read_csv(f)

# %%
train_stops=datasets["2"]["stops.txt"]
tram_stops=datasets["3"]["stops.txt"]
bus_stops=datasets["4"]["stops.txt"]

# %%
train_stops.head()
# Out:
#   stop_id                  stop_name   stop_lat    stop_lon  location_type  \
# 0   10117        Jordanville Station -37.873763  145.112473            NaN
# 1   10920          Flagstaff Station -37.811880  144.956043            NaN
# 2   10921          Flagstaff Station -37.811725  144.955968            NaN
# 3   10922  Melbourne Central Station -37.809974  144.962547            NaN
# 4   10923  Melbourne Central Station -37.809865  144.962505            NaN
#
#   parent_station  wheelchair_boarding  level_id platform_code
# 0   vic:rail:JOR                  1.0   Level 0             1
# 1   vic:rail:FGS                  1.0  Level -2             1
# 2   vic:rail:FGS                  1.0  Level -2             2
# 3   vic:rail:MCE                  1.0  Level -2             1
# 4   vic:rail:MCE                  1.0  Level -2             2

# %%
tram_stops.head()
# Out:
#    stop_id                        stop_name   stop_lat    stop_lon  \
# 0    10311  Glenferrie Rd/Wattletree Rd #45 -37.862455  145.028508
# 1    10371   Duncraig Ave/Wattletree Rd #44 -37.862069  145.025382
# 2     1083          Clyde St/Raleigh Rd #42 -37.769699  144.898841
# 3    11285     Egerton Rd/Wattletree Rd #43 -37.861710  145.022754
# 4     1185     Vincent St/Wattletree Rd #50 -37.864226  145.043375
#
#    location_type  parent_station  wheelchair_boarding level_id
# 0            NaN             NaN                    0  Level 0
# 1            NaN             NaN                    0  Level 0
# 2            NaN             NaN                    0  Level 0
# 3            NaN             NaN                    0  Level 0
# 4            NaN             NaN                    0  Level 0

# %%
bus_stops.head()
# Out:
#   stop_id                stop_name   stop_lat    stop_lon  location_type  \
# 0    1000      Dole Ave/Cheddar Rd -37.700775  145.018951            NaN
# 1   10001        Rex St/Taylors Rd -37.726975  144.776152            NaN
# 2   10002  Yuille St/Centenary Ave -37.676159  144.595789            NaN
# 3   10009      Gum Rd/Main Rd West -37.741497  144.775899            NaN
# 4    1001     Lloyd Ave/Cheddar Rd -37.699183  145.019685            NaN
#
#    parent_station  wheelchair_boarding level_id
# 0             NaN                    0  Level 0
# 1             NaN                    0  Level 0
# 2             NaN                    0  Level 0
# 3             NaN                    0  Level 0
# 4             NaN                    0  Level 0

# %% [markdown]
# ### Rental Listings Spreadsheet

# %% [markdown]
# A spreadsheet of rental listings is collected from realestate.com.au to be ranked based on their distance to utilities

# %%
rental_listings = pd.read_excel("Rental Listings.xlsx")
rental_listings.head()
# Out:
#     Suburb  Postcode                                 Address  Price pw  \
# 0  Carlton      3053  2512/551 Swanston Street, Carlton, Vic       755
# 1  Carlton      3053   2006/28 Bouverie Street, Carlton, Vic       795
# 2  Carlton      3053  707A/640 Swanston Street, Carlton, Vic       700
# 3  Carlton      3053       23/411 Lygon Street, Carlton, Vic       660
# 4  Carlton      3053   311/127 Cardigan Street, Carlton, Vic       850
#
#   Available date  Number of bedrooms  Number of bathrooms  \
# 0     2025-08-25                   2                    2
# 1     2025-08-11                   2                    2
# 2     2025-08-25                   2                    1
# 3     2025-08-05                   2                    1
# 4     2025-08-05                   2                    2
#
#    Number of carspaces Type of property
# 0                    0        Apartment
# 1                    0        Apartment
# 2                    1        Apartment
# 3                    1        Townhouse
# 4                    1        Apartment

# %%
rental_listings['Address'] = rental_listings['Address'].str.split("/").str[-1]
rental_listings.head()
# Out:
#     Suburb  Postcode                            Address  Price pw  \
# 0  Carlton      3053  551 Swanston Street, Carlton, Vic       755
# 1  Carlton      3053   28 Bouverie Street, Carlton, Vic       795
# 2  Carlton      3053  640 Swanston Street, Carlton, Vic       700
# 3  Carlton      3053     411 Lygon Street, Carlton, Vic       660
# 4  Carlton      3053  127 Cardigan Street, Carlton, Vic       850
#
#   Available date  Number of bedrooms  Number of bathrooms  \
# 0     2025-08-25                   2                    2
# 1     2025-08-11                   2                    2
# 2     2025-08-25                   2                    1
# 3     2025-08-05                   2                    1
# 4     2025-08-05                   2                    2
#
#    Number of carspaces Type of property
# 0                    0        Apartment
# 1                    0        Apartment
# 2                    1        Apartment
# 3                    1        Townhouse
# 4                    1        Apartment

# %% [markdown]
# ### Generate latitude and longitude from address

# %% [markdown]
# The below code is a function to return the latitude and longitude from a passed in address.

# %%
#Function to geocode an address using Nominatim
def geocode_address(address):
    geolocator = Nominatim(user_agent="mapping_app1.0",timeout=15)
    
    #Define the bounding box for Melbourne
    melbourne_bbox = [(-38.5267, 144.5937), (-37.5113, 145.5125)] 
    
    #Geocode the address within the Melbourne bounding box
    location = geolocator.geocode(address, viewbox=melbourne_bbox, bounded=True)
    
    if location:
        return location.latitude, location.longitude
    else:
        return None

# %%
rental_listings['coords'] = rental_listings['Address'].apply(geocode_address)
rental_listings.head()
# Out:
#     Suburb  Postcode                            Address  Price pw  \
# 0  Carlton      3053  551 Swanston Street, Carlton, Vic       755
# 1  Carlton      3053   28 Bouverie Street, Carlton, Vic       795
# 2  Carlton      3053  640 Swanston Street, Carlton, Vic       700
# 3  Carlton      3053     411 Lygon Street, Carlton, Vic       660
# 4  Carlton      3053  127 Cardigan Street, Carlton, Vic       850
#
#   Available date  Number of bedrooms  Number of bathrooms  \
# 0     2025-08-25                   2                    2
# 1     2025-08-11                   2                    2
# 2     2025-08-25                   2                    1
# 3     2025-08-05                   2                    1
# 4     2025-08-05                   2                    2
#
#    Number of carspaces Type of property                      coords
# 0                    0        Apartment  (-37.8056782, 144.9623566)
# 1                    0        Apartment  (-37.8056215, 144.9618704)
# 2                    1        Apartment  (-37.8048744, 144.9632684)
# 3                    1        Townhouse  (-37.7948366, 144.9675549)
# 4                    1        Apartment  (-37.7976527, 144.9660059)

# %%
rental_listings_clean=rental_listings.dropna(subset='coords')
rental_listings_clean[['latitude', 'longitude']] =pd.DataFrame(
    rental_listings_clean['coords'].tolist(), index=rental_listings_clean.index)
rental_listings_clean=rental_listings_clean.drop(columns=['coords'])
rental_listings_clean.head()
# Out:
# C:\Users\phuon\AppData\Local\Temp\ipykernel_35476\164360247.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rental_listings_clean[['latitude', 'longitude']] =pd.DataFrame(
# C:\Users\phuon\AppData\Local\Temp\ipykernel_35476\164360247.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rental_listings_clean[['latitude', 'longitude']] =pd.DataFrame(
#     Suburb  Postcode                            Address  Price pw  \
# 0  Carlton      3053  551 Swanston Street, Carlton, Vic       755
# 1  Carlton      3053   28 Bouverie Street, Carlton, Vic       795
# 2  Carlton      3053  640 Swanston Street, Carlton, Vic       700
# 3  Carlton      3053     411 Lygon Street, Carlton, Vic       660
# 4  Carlton      3053  127 Cardigan Street, Carlton, Vic       850
#
#   Available date  Number of bedrooms  Number of bathrooms  \
# 0     2025-08-25                   2                    2
# 1     2025-08-11                   2                    2
# 2     2025-08-25                   2                    1
# 3     2025-08-05                   2                    1
# 4     2025-08-05                   2                    2
#
#    Number of carspaces Type of property   latitude   longitude
# 0                    0        Apartment -37.805678  144.962357
# 1                    0        Apartment -37.805622  144.961870
# 2                    1        Apartment -37.804874  144.963268
# 3                    1        Townhouse -37.794837  144.967555
# 4                    1        Apartment -37.797653  144.966006

# %% [markdown]
# From the above codes, rental listings table has been added longtitude and latitude columns to navigate the listing on a map.

# %%
# Average lat/lon for center
melbourne_center = [rental_listings_clean['latitude'].mean(), rental_listings_clean['longitude'].mean()]
listing_map = folium.Map(location=melbourne_center, zoom_start=13)

# Add coworking space markers
for _, row in rental_listings_clean.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['Address'],
    ).add_to(listing_map)


# Display the map
listing_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_366a0c8bda948cb720be40610cf1b8a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_366a0c8bda948cb720be40610cf1b8a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_366a0c8bda948cb720be40610cf1b8a2 = L.map(
#                 &quot;map_366a0c8bda948cb720be40610cf1b8a2&quot;,
#                 {
#                     center: [-37.81808095858586, 144.96240696767674],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b7e54344bfdbfc194e855cb672365516 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b7e54344bfdbfc194e855cb672365516.addTo(map_366a0c8bda948cb720be40610cf1b8a2);
#
#
#             var marker_a494d4f6d62b223d2a5c9fbbfce4ee0b = L.marker(
#                 [-37.8056782, 144.9623566],
#                 {
# }
#             ).addTo(map_366a0c8bda948cb720be40610cf1b8a2);
#
#
#         var popup_0c2d75090a399b44235388951295b366 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_636e1369ac7c6106f88ea4cb3950ee2a = $(`&lt;div id=&quot;html_636e1369ac7c6106f88ea4cb3950ee2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;551 Swanston Street, Carlton, Vic&lt;/div&gt;`)[0];
#                 popup_0c2d75090a399b44235388951295b366.setContent(html_636e1369ac7c6106f88ea4cb3950ee2a);
#
#
#
#         marker_a494d4f6d62b223d2a5c9fbbfce4ee0b.bindPopup(popup_0c2d75090a399b44235388951295b366)
#         ;
#
#
#
#
#             var marker_9119d099fee06d72b88b623be73633fc = L.marker(
#                 [-37.8056215, 144.9618704],
#                 {
# }
#             ).addTo(map_366a0c8bda948cb720be40610cf1b8a2);
#
#
#         var popup_c674bb290d7d2597653ea6946ee6eefa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d098f246ee55603a9c489af2aca3f2f4 = $(`&lt;div id=&quot;html_d098f246ee55603a9c489af2aca3f2f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;28 Bouverie Street, Carlton, Vic&lt;/div&gt;`)[0];
#                 popup_c674bb290d7d2597653ea6946ee6eefa.setContent(html_d098f246ee55603a9c489af2aca3f2f4);
#
#
#
#         marker_9119d099fee06d72b88b623be73633fc.bindPopup(popup_c674bb290d7d2597653ea6946ee6eefa)
#         ;
#
#
#
#
#             var marker_6e4e678a6a2b2dda4890dfaaf7918d48 = L.marker(
#                 [-37.8048744, 144.9632684],
#                 {
# }
#             ).addTo(map_366a0c8bda948cb720be40610cf1b8a2);
#
#
#         var popup_8389ca59c59430b023f2ff6377e88409 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7d7abe8c12f3f8feb70e64a5cb287cb = $(`&lt;div id=&quot;html_a7d7abe8c12f3f8feb70e64a5cb287cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;640 Swanston Street, Carlton, Vic&lt;/div&gt;`)[0];
#                 popup_8389ca59c59430b023f2ff6377e88409.setContent(html_a7d7abe8c12f3f8feb70e64a5cb287cb);
#
#
#
#         marker_6e4e678a6a2b2dda4890dfaaf7918d48.bindPopup(popup_8389ca59c59430b023f2ff6377e88409)
#         ;
#
#
#
#
#             var marker_bb7eb72a9c0d7068d4f9596facb65310 = L.marker(
#                 [-37.7948366, 144.9675549],
#                 {
# }
#             ).addTo(map_366a0c8bda948cb720be40610cf1b8a2);
#
#
#         var popup_21d351f424a7a6b833fc04a78daf6588 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b11c844b858f9115b00ba3da3d47e7f = $(`&lt;div id=&quot;html_0b11c844b858f9115b00ba3da3d47e7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;411 Lygon Street, Carlton, Vic&lt;/div&gt;`)[0];
#                 popup_21d351f424a7a6b833fc04a78daf6588.setContent(html_0b11c844b858f9115b00ba3da3d47e7f);
#
#
#
#         marker_bb7eb72a9c0d7068d4f9596facb65310.bindPopup(popup_21d351f424a7a6b833fc04a78daf6588)
#         ;
#
#
#
#
#             var marker_8422eed65240c8e560795fc6b959a51d = L.marker(
#                 [-37.7976527, 144.9660059],
#                 {
# }
#             ).addTo(map_366a0c8bda948cb720be40610cf1b8a2);
#
#
#         var popup_d3a111f74e43dc40733135fb650aff2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78b53f6b29e1abc434b54408b3dc95f0 = $(`&lt;div id=&quot;html_78b53f6b29e1abc434b54408b3dc95f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;127 Cardigan Street, Carlton, Vic&lt;/div&gt;`)[0];
#                 popup_d3a111f74e43dc40733135fb650aff2e.setContent(html_78b53f6b29e1abc434b54408b3dc95f0);
#
#
#
#         marker_8422eed65240c8e560795fc6b959a51d.bindPopup(popup_d3a111f74e43dc40733135fb650aff2e)
#         ;

# %% [markdown]
# All rental listings have been visualised on a map. By clicking on each marker, the rental listing's address is shown.
#
# It is visible that the listings are within City of Melbourne, spread out to different suburbs.

# %% [markdown]
# ### Find nearest station

# %% [markdown]
# The below code is a function to return the nearest station from each rental listing location, using a ML model called KDTree.

# %%
def find_nearest_station(lat, lon, kdtree, df):
    #Query the KDTree with the given latitude and longitude to find nearest station. Distance is returned in degrees so need to calculate the meters
    distance, index = kdtree.query([lat, lon])

    #Get the nearest station details from the DataFrame
    nearest_station = df.iloc[index]

    #Extract stations coords
    nearest_station_coords = (nearest_station["stop_lat"], nearest_station["stop_lon"])
    point_coords = (lat, lon)

    #Calculate the geodesic distance (in meters) between the point and the nearest statio
    distance_meters = geodesic(point_coords, nearest_station_coords).meters
    
    return nearest_station, distance_meters

# %% [markdown]
# Then the function is applied to the dataset which contains all coordinates of train stations.

# %%
train_stations_coords = train_stops[["stop_lat", "stop_lon"]].values
kdtree_train = KDTree(train_stations_coords)
rental_listings_clean[["nearest_station", "distance_meters_station"]] = (
    rental_listings_clean.apply(
        lambda r: pd.Series(
            find_nearest_station(r["latitude"], r["longitude"], kdtree_train, train_stops)
        ),
        axis=1
    )
)
rental_listings_clean.head()
# Out:
#     Suburb  Postcode                            Address  Price pw  \
# 0  Carlton      3053  551 Swanston Street, Carlton, Vic       755
# 1  Carlton      3053   28 Bouverie Street, Carlton, Vic       795
# 2  Carlton      3053  640 Swanston Street, Carlton, Vic       700
# 3  Carlton      3053     411 Lygon Street, Carlton, Vic       660
# 4  Carlton      3053  127 Cardigan Street, Carlton, Vic       850
#
#   Available date  Number of bedrooms  Number of bathrooms  \
# 0     2025-08-25                   2                    2
# 1     2025-08-11                   2                    2
# 2     2025-08-25                   2                    1
# 3     2025-08-05                   2                    1
# 4     2025-08-05                   2                    2
#
#    Number of carspaces Type of property   latitude   longitude  \
# 0                    0        Apartment -37.805678  144.962357
# 1                    0        Apartment -37.805622  144.961870
# 2                    1        Apartment -37.804874  144.963268
# 3                    1        Townhouse -37.794837  144.967555
# 4                    1        Apartment -37.797653  144.966006
#
#                                      nearest_station  distance_meters_station
# 0  stop_id                                    109...               464.903313
# 1  stop_id                                    109...               474.314037
# 2  stop_id                                    109...               558.004086
# 3  stop_id                                    109...              1726.334823
# 4  stop_id                                    109...              1390.119407

# %% [markdown]
# From the above table, Nearest station column and its coordinate is added to the listing table. As a result, distance from each rental listing to its nearest station is also calculated and added to the table.

# %% [markdown]
# ### Find nearest school

# %% [markdown]
# Similarly, a function is created to find the nearest school

# %%
def find_nearest_school(lat, lon, kdtree, df):
    #Query the KDTree with the given latitude and longitude to find nearest station. Distance is returned in degrees so need to calculate the meters
    distance, index = kdtree.query([lat, lon])

    #Get the nearest station details from the DataFrame
    nearest_school = df.iloc[index]

    #Extract stations coords
    nearest_school_coords = (nearest_school["Y"], nearest_school["X"])
    point_coords = (lat, lon)

    #Calculate the geodesic distance (in meters) between the point and the nearest statio
    distance_meters = geodesic(point_coords, nearest_school_coords).meters
    school_name = nearest_school.get("School_Name", None)
    
    return school_name, distance_meters

# %%
nearest_school_coords = school_locations[["Y", "X"]].values
kdtree_school = KDTree(nearest_school_coords)
rental_listings_clean[["nearest_school", "distance_meters_school"]] = (
    rental_listings_clean.apply(
        lambda r: pd.Series(
            find_nearest_school(r["latitude"], r["longitude"],kdtree_school, school_locations)
        ),
        axis=1
    )
)
rental_listings_clean.head()
# Out:
#     Suburb  Postcode                            Address  Price pw  \
# 0  Carlton      3053  551 Swanston Street, Carlton, Vic       755
# 1  Carlton      3053   28 Bouverie Street, Carlton, Vic       795
# 2  Carlton      3053  640 Swanston Street, Carlton, Vic       700
# 3  Carlton      3053     411 Lygon Street, Carlton, Vic       660
# 4  Carlton      3053  127 Cardigan Street, Carlton, Vic       850
#
#   Available date  Number of bedrooms  Number of bathrooms  \
# 0     2025-08-25                   2                    2
# 1     2025-08-11                   2                    2
# 2     2025-08-25                   2                    1
# 3     2025-08-05                   2                    1
# 4     2025-08-05                   2                    2
#
#    Number of carspaces Type of property   latitude   longitude  \
# 0                    0        Apartment -37.805678  144.962357
# 1                    0        Apartment -37.805622  144.961870
# 2                    1        Apartment -37.804874  144.963268
# 3                    1        Townhouse -37.794837  144.967555
# 4                    1        Apartment -37.797653  144.966006
#
#                                      nearest_station  distance_meters_station  \
# 0  stop_id                                    109...               464.903313
# 1  stop_id                                    109...               474.314037
# 2  stop_id                                    109...               558.004086
# 3  stop_id                                    109...              1726.334823
# 4  stop_id                                    109...              1390.119407
#
#                    nearest_school  distance_meters_school
# 0               River Nile School              642.216005
# 1               River Nile School              599.027095
# 2  Carlton Gardens Primary School              632.785299
# 3          Carlton Primary School              268.698675
# 4          Carlton Primary School              452.892642

# %% [markdown]
# From the above codes, nearest schools, coordinates and distances to rental listings are added to the table.

# %% [markdown]
# ### Find nearest landmark

# %% [markdown]
# The function below finds the nearest landmark, its coordinate and distance to the rental listing.

# %%
def find_nearest_landmark(lat, lon, kdtree, df):
    #Query the KDTree with the given latitude and longitude to find nearest station. Distance is returned in degrees so need to calculate the meters
    distance, index = kdtree.query([lat, lon])

    #Get the nearest station details from the DataFrame
    nearest_landmark = df.iloc[index]

    #Extract stations coords
    nearest_landmark_coords = (nearest_landmark["latitude"], nearest_landmark["longitude"])
    point_coords = (lat, lon)

    #Calculate the geodesic distance (in meters) between the point and the nearest statio
    distance_meters = geodesic(point_coords, nearest_landmark_coords).meters
    landmark = nearest_landmark.get("feature_name", None)
    
    return landmark, distance_meters

# %%
nearest_landmark_coords = landmarks_clean[["latitude", "longitude"]].values
kdtree_landmark = KDTree(nearest_landmark_coords)
rental_listings_clean[["nearest_landmark", "distance_meters_landmark"]] = (
    rental_listings_clean.apply(
        lambda r: pd.Series(
            find_nearest_landmark(r["latitude"], r["longitude"],kdtree_landmark, landmarks_clean)
        ),
        axis=1
    )
)
rental_listings_clean.head()
# Out:
#     Suburb  Postcode                            Address  Price pw  \
# 0  Carlton      3053  551 Swanston Street, Carlton, Vic       755
# 1  Carlton      3053   28 Bouverie Street, Carlton, Vic       795
# 2  Carlton      3053  640 Swanston Street, Carlton, Vic       700
# 3  Carlton      3053     411 Lygon Street, Carlton, Vic       660
# 4  Carlton      3053  127 Cardigan Street, Carlton, Vic       850
#
#   Available date  Number of bedrooms  Number of bathrooms  \
# 0     2025-08-25                   2                    2
# 1     2025-08-11                   2                    2
# 2     2025-08-25                   2                    1
# 3     2025-08-05                   2                    1
# 4     2025-08-05                   2                    2
#
#    Number of carspaces Type of property   latitude   longitude  \
# 0                    0        Apartment -37.805678  144.962357
# 1                    0        Apartment -37.805622  144.961870
# 2                    1        Apartment -37.804874  144.963268
# 3                    1        Townhouse -37.794837  144.967555
# 4                    1        Apartment -37.797653  144.966006
#
#                                      nearest_station  distance_meters_station  \
# 0  stop_id                                    109...               464.903313
# 1  stop_id                                    109...               474.314037
# 2  stop_id                                    109...               558.004086
# 3  stop_id                                    109...              1726.334823
# 4  stop_id                                    109...              1390.119407
#
#                    nearest_school  distance_meters_school  \
# 0               River Nile School              642.216005
# 1               River Nile School              599.027095
# 2  Carlton Gardens Primary School              632.785299
# 3          Carlton Primary School              268.698675
# 4          Carlton Primary School              452.892642
#
#                nearest_landmark  distance_meters_landmark
# 0                    City Baths                179.945130
# 1                    City Baths                206.407972
# 2                Lincoln Square                235.417010
# 3    All Nations Uniting Church                173.551007
# 4  The Ian Potter Museum Of Art                165.380552

# %% [markdown]
# In the above table, all rental listings locations and their information of closest train station, school and landmark is shown.

# %% [markdown]
# ### Ranking rental listings

# %%
rental_listings_ranking = rental_listings_clean.copy()

# %%
# Normalise columns:
cols = ["distance_meters_station", "distance_meters_school", "distance_meters_landmark"]
def minmax_normalize(s: pd.Series) -> pd.Series:
    s_min, s_max = s.min(), s.max()
    if pd.isna(s_min) or pd.isna(s_max) or s_max == s_min:
        # all values equal or empty -> return zeros
        return pd.Series(0.0, index=s.index)
    return (s - s_min) / (s_max - s_min)
# Normalize each distance (0 = closest, 1 = farthest)
for c in cols:
    rental_listings_ranking[f"norm_{c}"] = minmax_normalize(rental_listings_ranking[c])

# Equal-importance composite: average of normalized distances
rental_listings_ranking["accessibility_score"] = (
    rental_listings_ranking[[f"norm_{c}" for c in cols]].mean(axis=1)
)

# Rank: smaller score = closer overall (rank 1 is best)
rental_listings_ranking["accessibility_rank"] = (
    rental_listings_ranking["accessibility_score"].rank(method="dense", ascending=True).astype(int)
)

# %% [markdown]
# The above code normalises the distance columns, calculates an accessibility score by averaging among all distance matrices and lastly ranks the rental listings by their accessibility score.

# %%
top10_listing = (rental_listings_ranking
         .sort_values(["accessibility_rank", "accessibility_score"], ascending=[True, True])
         .head(10)
         .copy())
top10_listing
# Out:
#              Suburb  Postcode                                     Address  \
# 13   East Melbourne      3002         16 Vale Street, East Melbourne, Vic
# 78         St Kilda      3182               6 Redan Street, St Kilda, Vic
# 22        Melbourne      3000  633 Little Lonsdale Street, Melbourne, Vic
# 18       Flemington      3031       125D Victoria Street, Flemington, Vic
# 94      Collingwood      3066      31 Wellington Street, Collingwood, Vic
# 41  North Melbourne      3051   315 Flemington Road, North Melbourne, Vic
# 97         Richmond      3121            8 Garfield Street, Richmond, Vic
# 90          Fitzroy      3065           98 Nicholson Street, Fitzroy, Vic
# 35        Melbourne      3004           605 St Kilda Road, Melbourne, Vic
# 44  North Melbourne      3051       150 Peel Street, North Melbourne, Vic
#
#     Price pw Available date  Number of bedrooms  Number of bathrooms  \
# 13      1500     2025-08-05                   3                    3
# 78       565     2025-08-29                   2                    1
# 22       800     2025-09-20                   2                    1
# 18       700     2025-09-03                   3                    1
# 94       875     2025-08-13                   2                    2
# 41       420     2025-08-28                   1                    1
# 97       490     2025-08-12                   1                    1
# 90       450     2025-08-05                   1                    1
# 35       550     2025-09-03                   1                    1
# 44       750     2025-08-08                   2                    1
#
#     Number of carspaces Type of property   latitude  ...  \
# 13                    1        Townhouse -37.819209  ...
# 78                    1        Apartment -37.860181  ...
# 22                    0        Apartment -37.813811  ...
# 18                    0            House -37.785105  ...
# 94                    1        Apartment -37.807415  ...
# 41                    1        Apartment -37.791667  ...
# 97                    1        Apartment -37.811854  ...
# 90                    0        Apartment -37.802988  ...
# 35                    1        Apartment -37.850939  ...
# 44                    1        Apartment -37.803610  ...
#
#     distance_meters_station                          nearest_school  \
# 13               463.217654  Melbourne Indigenous Transition School
# 78               459.178130                Cheder Levi Yitzchok Inc
# 22               301.006607                          Ozford College
# 18               478.888665           Debney Meadows Primary School
# 94               599.751859     Collingwood English Language School
# 41               505.082957                     St Aloysius College
# 97                96.652089            Richmond West Primary School
# 90               891.443166              Academy of Mary Immaculate
# 35               754.071924          Victorian College For The Deaf
# 44               901.069199                             St Joseph's
#
#     distance_meters_school                              nearest_landmark  \
# 13               37.799155                        Richmond Football Club
# 78               47.311062                                Wesley College
# 22              152.048738                     Koorie Heritage Trust Inc
# 18               99.382328             Flemington Bridge Railway Station
# 94               94.782438  Epworth Freemasons Hospital : Medical Centre
# 41              181.045425                                   St Michaels
# 97              329.969597                                Darling Square
# 90               85.263634                         Carlton Gardens North
# 35              154.882728                                Wesley College
# 44              118.766861                     St Mary's Anglican Church
#
#     distance_meters_landmark norm_distance_meters_station  \
# 13                287.563630                     0.077132
# 78               1539.034326                     0.076364
# 22                 91.202579                     0.046306
# 18                482.238009                     0.080110
# 94                367.879627                     0.103079
# 41                284.003442                     0.085088
# 97                347.117656                     0.007470
# 90                276.978926                     0.158511
# 35                279.409264                     0.132405
# 44                225.242147                     0.160340
#
#     norm_distance_meters_school  norm_distance_meters_landmark  \
# 13                     0.000000                       0.005540
# 78                     0.005686                       0.033246
# 22                     0.068298                       0.001193
# 18                     0.036814                       0.009850
# 94                     0.034064                       0.007318
# 41                     0.085632                       0.005461
# 97                     0.174658                       0.006859
# 90                     0.028374                       0.005306
# 35                     0.069992                       0.005360
# 44                     0.048402                       0.004161
#
#     accessibility_score  accessibility_rank
# 13             0.027557                   1
# 78             0.038432                   2
# 22             0.038599                   3
# 18             0.042258                   4
# 94             0.048154                   5
# 41             0.058727                   6
# 97             0.062996                   7
# 90             0.064064                   8
# 35             0.069252                   9
# 44             0.070968                  10
#
# [10 rows x 22 columns]

# %% [markdown]
# The above table shows top 10 rental listings based on their accessibility scores.

# %% [markdown]
# ### Visualise top 10 rental listing

# %%
# Average lat/lon for center
melbourne_center = [top10_listing['latitude'].mean(), top10_listing['longitude'].mean()]
top_listing_map = folium.Map(location=melbourne_center, zoom_start=13)

# Add coworking space markers
for _, row in top10_listing.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['Address'],
    ).add_to(top_listing_map)
    


# Add the layer control
folium.LayerControl().add_to(top_listing_map)

# Display the map
top_listing_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9325bd1c324b0fb52db395dc90500740 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9325bd1c324b0fb52db395dc90500740&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9325bd1c324b0fb52db395dc90500740 = L.map(
#                 &quot;map_9325bd1c324b0fb52db395dc90500740&quot;,
#                 {
#                     center: [-37.81467807, 144.97044301],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7d7aa6040f0d307d0a9f069222d63d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f7d7aa6040f0d307d0a9f069222d63d8.addTo(map_9325bd1c324b0fb52db395dc90500740);
#
#
#             var marker_699246115eec3d8e16868efbca484b49 = L.marker(
#                 [-37.8192087, 144.9891606],
#                 {
# }
#             ).addTo(map_9325bd1c324b0fb52db395dc90500740);
#
#
#         var popup_2b88610ec33b75338a9a7f89b14bb6a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21a48d6fe31d684b98ab3c65ee00d051 = $(`&lt;div id=&quot;html_21a48d6fe31d684b98ab3c65ee00d051&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;16 Vale Street, East Melbourne, Vic&lt;/div&gt;`)[0];
#                 popup_2b88610ec33b75338a9a7f89b14bb6a5.setContent(html_21a48d6fe31d684b98ab3c65ee00d051);
#
#
#
#         marker_699246115eec3d8e16868efbca484b49.bindPopup(popup_2b88610ec33b75338a9a7f89b14bb6a5)
#         ;
#
#
#
#
#             var marker_67bf57735a446ca3eac8f5d514018146 = L.marker(
#                 [-37.860181, 144.9916902],
#                 {
# }
#             ).addTo(map_9325bd1c324b0fb52db395dc90500740);
#
#
#         var popup_368d7d1d9388150c3bca7ad4e5eb813b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02951f15018a29785185f1d0a336e8af = $(`&lt;div id=&quot;html_02951f15018a29785185f1d0a336e8af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;6 Redan Street, St Kilda, Vic&lt;/div&gt;`)[0];
#                 popup_368d7d1d9388150c3bca7ad4e5eb813b.setContent(html_02951f15018a29785185f1d0a336e8af);
#
#
#
#         marker_67bf57735a446ca3eac8f5d514018146.bindPopup(popup_368d7d1d9388150c3bca7ad4e5eb813b)
#         ;
#
#
#
#
#             var marker_fbf27b402268ae8e883fc6b08e9df5ae = L.marker(
#                 [-37.8138114, 144.9531422],
#                 {
# }
#             ).addTo(map_9325bd1c324b0fb52db395dc90500740);
#
#
#         var popup_e379535a548b6211b9655a29a674c8b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46fa5cf36ed57f8fccfce54ecb4a397f = $(`&lt;div id=&quot;html_46fa5cf36ed57f8fccfce54ecb4a397f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;633 Little Lonsdale Street, Melbourne, Vic&lt;/div&gt;`)[0];
#                 popup_e379535a548b6211b9655a29a674c8b8.setContent(html_46fa5cf36ed57f8fccfce54ecb4a397f);
#
#
#
#         marker_fbf27b402268ae8e883fc6b08e9df5ae.bindPopup(popup_e379535a548b6211b9655a29a674c8b8)
#         ;
#
#
#
#
#             var marker_5c7dc9a197b4e445e78cfc449da5933f = L.marker(
#                 [-37.7851052, 144.9353906],
#                 {
# }
#             ).addTo(map_9325bd1c324b0fb52db395dc90500740);
#
#
#         var popup_1bc9f48869cbea46ea4eef15abde6921 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a007e9d92aecbfc3759073168f589420 = $(`&lt;div id=&quot;html_a007e9d92aecbfc3759073168f589420&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;125D Victoria Street, Flemington, Vic&lt;/div&gt;`)[0];
#                 popup_1bc9f48869cbea46ea4eef15abde6921.setContent(html_a007e9d92aecbfc3759073168f589420);
#
#
#
#         marker_5c7dc9a197b4e445e78cfc449da5933f.bindPopup(popup_1bc9f48869cbea46ea4eef15abde6921)
#         ;
#
#
#
#
#             var marker_5cae496c735bab04c8a6ba2212b6612a = L.marker(
#                 [-37.8074152, 144.9857337],
#                 {
# }
#             ).addTo(map_9325bd1c324b0fb52db395dc90500740);
#
#
#         var popup_26f09d9c8017b6acaea630a5a2ffa34f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_310381ba5173ff71906a67372b2b05ef = $(`&lt;div id=&quot;html_310381ba5173ff71906a67372b2b05ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;31 Wellington Street, Collingwood, Vic&lt;/div&gt;`)[0];
#                 popup_26f09d9c8017b6acaea630a5a2ffa34f.setContent(html_310381ba5173ff71906a67372b2b05ef);
#
#
#
#         marker_5cae496c735bab04c8a6ba2212b6612a.bindPopup(popup_26f09d9c8017b6acaea630a5a2ffa34f)
#         ;

# %% [markdown]
# The top 10 rental listings are visualised into a map. It can be seen that the locations are spread out in different suburbs. The majority are close to Collingwood and North Melbourne.
