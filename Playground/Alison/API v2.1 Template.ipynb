# %% [markdown]
# Code for API v2.1 City of Melburne data collection

# %%
# Import required modules
import requests
import pandas as pd

# %%
# Function to get data from website using API
def get_data(base, data_url, offset=0):    
    # Set the filters, limit retrieves 20 rows at a time, offset says where to start data collection
    filters = f'records?limit={100}&offset={offset}&timezone=UTC'
    # Make the url from base, data url and filters variables stored ouside loop
    url = f'{base}{data_url}/{filters}'
    # print(url) - used to check if code was working
    # Use the requests function to get the data
    result = requests.get(url)
    # Check that the request works, error code 200 = successful
    if result.status_code == 200:
        # Save results as a json file
        result_json = result.json()
        # Store a variable of max_results with total of dataset
        max_results = result_json['total_count']
        # Save the results key data to a list variable
        records = result_json['results']
    else:
        # If data is not collected correctly return the error
        print("ERROR GETTING DATA: ", result.status_code)
        max_results = 0
        records = []
    # At end of function, return the json results in records, max_results count and offset
    return [records, max_results, offset]



# Collect data from API
# Set offset increment
# (needs to match offset in get data function)
OFFSET_INCREMENT = 100
# Base url (this should be the same for all datasets)
BASE_URL = 'https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/'
# Set specific url 
# (change this variable for the dataset you are working with)
SPECIFIC_PATH = 'tree-canopies-2011-urban-forest'
# Call the get data function, passing in variables above, save to result
result = get_data(BASE_URL, SPECIFIC_PATH)
# Save the records data returned in the get_data function to records list variable
records = result[0]
# Save the dataset size data returned in the get_data function to max_results variable
max_results = result[1] 
# Increase the offset returned in the get_data function (result[2]) by the offset increment
offset = result[2] + OFFSET_INCREMENT
# Check the length of the data returned and compare it against the max_results variable
# If the length o fthe data is less than the max_results, run the while loop
while len(records) != max_results:
    # Call the get data function again, passing in url, specific path and new offset value
    data = get_data(BASE_URL, SPECIFIC_PATH, offset)
    # Add the data collected to the existing records list
    records += data[0]
    # Increase the offset by the offset increment
    offset += OFFSET_INCREMENT
# Convert the records list of dictionaries into a pandas dataframe 
df = pd.DataFrame(records)
# Print the dataframe
df
# Out:
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=0&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=100&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=200&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=300&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=400&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=500&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=600&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=700&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=800&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=900&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=1000&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=1100&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=1200&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=1300&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=1400&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=1500&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=1600&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=1700&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=1800&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=1900&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=2000&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=2100&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=2200&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=2300&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=2400&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=2500&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=2600&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=2700&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=2800&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=2900&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=3000&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=3100&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=3200&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=3300&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=3400&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=3500&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=3600&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=3700&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=3800&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=3900&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=4000&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=4100&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=4200&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=4300&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=4400&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=4500&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=4600&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=4700&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=4800&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=4900&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=5000&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=5100&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=5200&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=5300&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=5400&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=5500&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=5600&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=5700&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=5800&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=5900&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=6000&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=6100&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=6200&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=6300&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=6400&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=6500&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=6600&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=6700&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=6800&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=6900&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=7000&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=7100&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=7200&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=7300&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=7400&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=7500&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=7600&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=7700&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=7800&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=7900&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=8000&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=8100&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=8200&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=8300&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=8400&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=8500&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=8600&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=8700&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=8800&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=8900&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=9000&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=9100&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=9200&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=9300&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=9400&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=9500&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=9600&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=9700&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=9800&timezone=UTC
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=9900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=10000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=10100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=10200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=10300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=10400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=10500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=10600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=10700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=10800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=10900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=11000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=11100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=11200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=11300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=11400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=11500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=11600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=11700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=11800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=11900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=12000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=12100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=12200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=12300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=12400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=12500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=12600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=12700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=12800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=12900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=13000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=13100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=13200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=13300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=13400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=13500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=13600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=13700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=13800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=13900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=14000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=14100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=14200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=14300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=14400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=14500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=14600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=14700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=14800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=14900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=15000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=15100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=15200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=15300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=15400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=15500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=15600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=15700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=15800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=15900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=16000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=16100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=16200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=16300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=16400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=16500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=16600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=16700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=16800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=16900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=17000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=17100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=17200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=17300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=17400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=17500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=17600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=17700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=17800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=17900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=18000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=18100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=18200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=18300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=18400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=18500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=18600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=18700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=18800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=18900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=19000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=19100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=19200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=19300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=19400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=19500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=19600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=19700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=19800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=19900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=20000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=20100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=20200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=20300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=20400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=20500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=20600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=20700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=20800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=20900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=21000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=21100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=21200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=21300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=21400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=21500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=21600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=21700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=21800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=21900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=22000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=22100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=22200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=22300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=22400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=22500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=22600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=22700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=22800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=22900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=23000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=23100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=23200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=23300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=23400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=23500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=23600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=23700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=23800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=23900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=24000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=24100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=24200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=24300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=24400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=24500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=24600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=24700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=24800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=24900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=25000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=25100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=25200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=25300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=25400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=25500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=25600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=25700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=25800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=25900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=26000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=26100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=26200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=26300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=26400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=26500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=26600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=26700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=26800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=26900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=27000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=27100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=27200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=27300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=27400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=27500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=27600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=27700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=27800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=27900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=28000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=28100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=28200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=28300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=28400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=28500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=28600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=28700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=28800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=28900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=29000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=29100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=29200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=29300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=29400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=29500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=29600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=29700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=29800&timezone=UTC
# ERROR GETTING DATA:  400
# ...
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=41700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=41800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=41900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=42000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=42100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=42200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=42300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=42400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=42500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=42600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=42700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=42800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=42900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=43000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=43100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=43200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=43300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=43400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=43500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=43600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=43700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=43800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=43900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=44000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=44100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=44200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=44300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=44400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=44500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=44600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=44700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=44800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=44900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=45000&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=45100&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=45200&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=45300&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=45400&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=45500&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=45600&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=45700&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=45800&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=45900&timezone=UTC
# ERROR GETTING DATA:  400
# https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/tree-canopies-2011-urban-forest/records?limit=100&offset=46000&timezone=UTC
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\alito\Documents\SIT764\MOP-Code\Playground\Alison\API v2.1 Template.ipynb Cell 3 line 4
#      <a href='vscode-notebook-cell:/c%3A/Users/alito/Documents/SIT764/MOP-Code/Playground/Alison/API%20v2.1%20Template.ipynb#W2sZmlsZQ%3D%3D?line=44'>45</a> # Check the length of the data returned and compare it against the max_results variable
#      <a href='vscode-notebook-cell:/c%3A/Users/alito/Documents/SIT764/MOP-Code/Playground/Alison/API%20v2.1%20Template.ipynb#W2sZmlsZQ%3D%3D?line=45'>46</a> # If the length o fthe data is less than the max_results, run the while loop
#      <a href='vscode-notebook-cell:/c%3A/Users/alito/Documents/SIT764/MOP-Code/Playground/Alison/API%20v2.1%20Template.ipynb#W2sZmlsZQ%3D%3D?line=46'>47</a> while len(records) != max_results:
#      <a href='vscode-notebook-cell:/c%3A/Users/alito/Documents/SIT764/MOP-Code/Playground/Alison/API%20v2.1%20Template.ipynb#W2sZmlsZQ%3D%3D?line=47'>48</a>     # Call the get data function again, passing in url, specific path and new offset value
# ---> <a href='vscode-notebook-cell:/c%3A/Users/alito/Documents/SIT764/MOP-Code/Playground/Alison/API%20v2.1%20Template.ipynb#W2sZmlsZQ%3D%3D?line=48'>49</a>     data = get_data(BASE_URL, SPECIFIC_PATH, offset)
#      <a href='vscode-notebook-cell:/c%3A/Users/alito/Documents/SIT764/MOP-Code/Playground/Alison/API%20v2.1%20Template.ipynb#W2sZmlsZQ%3D%3D?line=49'>50</a>     # Add the data collected to the existing records list
#      <a href='vscode-notebook-cell:/c%3A/Users/alito/Documents/SIT764/MOP-Code/Playground/Alison/API%20v2.1%20Template.ipynb#W2sZmlsZQ%3D%3D?line=50'>51</a>     records += data[0]
#
# c:\Users\alito\Documents\SIT764\MOP-Code\Playground\Alison\API v2.1 Template.ipynb Cell 3 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/alito/Documents/SIT764/MOP-Code/Playground/Alison/API%20v2.1%20Template.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> print(url)
#       <a href='vscode-notebook-cell:/c%3A/Users/alito/Documents/SIT764/MOP-Code/Playground/Alison/API%20v2.1%20Template.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> # Use the requests function to get the data
# ----> <a href='vscode-notebook-cell:/c%3A/Users/alito/Documents/SIT764/MOP-Code/Playground/Alison/API%20v2.1%20Template.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a> result = requests.get(url)
#      <a href='vscode-notebook-cell:/c%3A/Users/alito/Documents/SIT764/MOP-Code/Playground/Alison/API%20v2.1%20Template.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a> # Check that the request works, error code 200 = successful
#      <a href='vscode-notebook-cell:/c%3A/Users/alito/Documents/SIT764/MOP-Code/Playground/Alison/API%20v2.1%20Template.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a> if result.status_code == 200:
#      <a href='vscode-notebook-cell:/c%3A/Users/alito/Documents/SIT764/MOP-Code/Playground/Alison/API%20v2.1%20Template.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a>     # Save results as a json file
#
# File c:\Python310\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Python310\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Python310\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Python310\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Python310\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Python310\lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File c:\Python310\lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Python310\lib\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File c:\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File c:\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Python310\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Python310\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\alito\Documents\SIT764\MOP-Code\Playground\Alison\API v2.1 Template.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/alito/Documents/SIT764/MOP-Code/Playground/Alison/API%20v2.1%20Template.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df
#
# NameError: name 'df' is not defined
