# %% [markdown]
# Code for API v2.1 City of Melburne data collection

# %%
# Import required modules
import requests
import pandas as pd
import os

# %%
# Fetch parking data from API
def fetch_all_data(base_url, dataset, api_key, num_records=99, offset=0):
    all_records = []
    max_offset = 9900  # Set a maximum offset value based on API limitations

    while True:
        if offset > max_offset:
            break

        filters = f'{dataset}/records?limit={num_records}&offset={offset}'
        url = f'{base_url}{filters}&{api_key}'
        try:
            result = requests.get(url, timeout=10)
            result.raise_for_status()
            records = result.json().get('results')
        except requests.exceptions.RequestException as e:
            raise Exception(f"API request failed: {e}")

        if records is None:
            break
        all_records.extend(records)
        if len(records) < num_records:
            break
        offset += num_records

    df = pd.DataFrame(all_records)
    return df

API_KEY = os.environ.get('MELBOURNE_API_KEY', input("Please enter your API key: "))
BASE_URL = 'https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/'

# %%
# Set specific url 
# (change this variable for the dataset you are working with)
SPECIFIC_PATH = 'laneways-with-greening-potential'

df = fetch_all_data(BASE_URL, SPECIFIC_PATH, API_KEY)

# Extract latitude and longitude
#df['location_lat'] = df['location'].apply(lambda x: x.get('lat', None))
#df['location_lon'] = df['location'].apply(lambda x: x.get('lon', None))

# Drop the original location column
#df.drop(columns=['location'], inplace=True)

len(df)
df.head(3)
# Out:
#                                           geo_point_2d  \
# 0    {'lon': 144.9623447558369, 'lat': -37.81980050...
# 1    {'lon': 144.97170834375964, 'lat': -37.8109763...
# 2    {'lon': 144.97244046374837, 'lat': -37.8111115...
# 3    {'lon': 144.97077449834737, 'lat': -37.8116123...
# 4    {'lon': 144.9713761243581, 'lat': -37.81247349...
# ..                                                 ...
# 241  {'lon': 144.9713271143983, 'lat': -37.80873201...
# 242  {'lon': 144.96646689470336, 'lat': -37.8118915...
# 243  {'lon': 144.96051751381623, 'lat': -37.8098084...
# 244  {'lon': 144.96798312015957, 'lat': -37.8075281...
# 245  {'lon': 144.97079029463796, 'lat': -37.8091174...
#
#                                              geo_shape  segid_1  mapbase_mc  \
# 0    {'type': 'Feature', 'geometry': {'coordinates'...    10714     10714.0
# 1    {'type': 'Feature', 'geometry': {'coordinates'...    20229     20229.0
# 2    {'type': 'Feature', 'geometry': {'coordinates'...    20230     20230.0
# 3    {'type': 'Feature', 'geometry': {'coordinates'...    20233     20233.0
# 4    {'type': 'Feature', 'geometry': {'coordinates'...    20238     20238.0
# ..                                                 ...      ...         ...
# 241  {'type': 'Feature', 'geometry': {'coordinates'...    30169     30169.0
# 242  {'type': 'Feature', 'geometry': {'coordinates'...    30183     30183.0
# 243  {'type': 'Feature', 'geometry': {'coordinates'...    30502     30502.0
# 244  {'type': 'Feature', 'geometry': {'coordinates'...    30509     30509.0
# 245  {'type': 'Feature', 'geometry': {'coordinates'...    30832     30832.0
#
#      insol_scor  verticalsu  segid  driveways   parklane  objectid  ...  \
# 0      6.492595    0.000000  10714          1  53.830526         1  ...
# 1      2.215613    0.000000  20229          2   0.000000         5  ...
# 2      2.750935   63.214997  20230          0   0.000000         6  ...
# 3      1.612879    0.000000  20233          2   0.000000         9  ...
# 4      2.274434   52.835654  20238  5 or more   0.000000        12  ...
# ..          ...         ...    ...        ...        ...       ...  ...
# 241    5.490642   66.427563  30169          1   0.000000       230  ...
# 242    3.711139   60.881620  30183          0  54.888697       233  ...
# 243    2.862526    0.000000  30502          4   0.000000       239  ...
# 244    2.255241   67.407057  30509          0  59.223752       241  ...
# 245    4.151651    0.000000  30832  5 or more   0.000000       244  ...
#
#       farmlane                walls          farm_rank          vert_rank  \
# 0    58.518386  Probably Unsuitable  Highest Potential   Lowest potential
# 1     0.000000  Probably Unsuitable   Lowest potential   Lowest potential
# 2     0.000000             Consider   Lowest potential  Highest potential
# 3     0.000000  Probably Unsuitable   Lowest potential   Lowest potential
# 4     0.000000             Consider   Lowest potential     Good potential
# ..         ...                  ...                ...                ...
# 241  45.517660             Consider  Highest Potential  Highest potential
# 242   0.000000             Consider   Lowest potential  Highest potential
# 243   0.000000  Probably Unsuitable   Lowest potential   Lowest potential
# 244   0.000000             Consider   Lowest potential  Highest potential
# 245   0.000000  Probably Unsuitable   Lowest potential   Lowest potential
#
#            fores_rank     forest          park_rank binsperct  \
# 0    Lowest potential   0.000000  Highest potential       0.0
# 1      Good potential  49.153357   Lowest potential      60.0
# 2    Lowest potential   0.000000   Lowest potential      60.0
# 3    Lowest potential   0.000000   Lowest potential      60.0
# 4      Good potential  37.570031   Lowest potential      40.0
# ..                ...        ...                ...       ...
# 241  Lowest potential   0.000000   Lowest potential       0.0
# 242  Lowest potential   0.000000  Highest potential      40.0
# 243    Good potential  47.678268   Lowest potential      40.0
# 244  Lowest potential   0.000000  Highest potential       0.0
# 245  Lowest potential   0.000000   Lowest potential     100.0
#
#                 mapbase_1                 wsud
# 0            Banana Alley  Probably Unsuitable
# 1           Harwood Place             Consider
# 2          Turnbull Alley             Consider
# 3           Mornane Place             Consider
# 4          Westwood Place             Consider
# ..                    ...                  ...
# 241          Griffin Lane             Consider
# 242      Celestial Avenue             Consider
# 243                Pl5222             Consider
# 244                Pl5184             Consider
# 245  Madame Brussels Lane  Probably Unsuitable
#
# [246 rows x 23 columns]
