# %%
printf('selam')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d4e14aca9ad2> in <module>
# ----> 1 printf('selam')
#
# NameError: name 'printf' is not defined

# %%
print('selam')
# Out:
# selam

# %%
3+5
# Out:
# 8
