# %% [markdown]
# # Summary statisctics -rainfall dataset

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Inspect data

# %%
df = pd.read_csv('rainfall_dataset.csv', parse_dates =['date'], index_col=['date'])
df
# Out:
#             Year Month day of week  Rainfall_amount_(millimetres)
# date
# 2015-01-01  2015   Jan    Thursday                            0.0
# 2015-02-01  2015   Jan      Friday                            0.0
# 2015-03-01  2015   Jan    Saturday                            0.0
# 2015-04-01  2015   Jan      Sunday                            4.2
# 2015-05-01  2015   Jan      Monday                            0.0
# ...          ...   ...         ...                            ...
# 2021-02-24  2021   Feb   Wednesday                            0.0
# 2021-02-25  2021   Feb    Thursday                            0.0
# 2021-02-26  2021   Feb      Friday                            0.4
# 2021-02-27  2021   Feb    Saturday                            0.0
# 2021-02-28  2021   Feb      Sunday                            0.0
#
# [2251 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2251 entries, 2015-01-01 to 2021-02-28
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Year                           2251 non-null   int64
#  1   Month                          2251 non-null   object
#  2   day of week                    2251 non-null   object
#  3   Rainfall_amount_(millimetres)  2251 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 87.9+ KB

# %%
df.describe()
# Out:
#               Year  Rainfall_amount_(millimetres)
# count  2251.000000                    2251.000000
# mean   2017.592181                       1.518257
# std       1.776341                       4.392522
# min    2015.000000                       0.000000
# 25%    2016.000000                       0.000000
# 50%    2018.000000                       0.000000
# 75%    2019.000000                       0.800000
# max    2021.000000                      54.600000

# %%
#cheack missing value
print(df.isnull().sum(axis=0))
# Out:
# Year                             0
# Month                            0
# day of week                      0
# Rainfall_amount_(millimetres)    0
# dtype: int64

# %%
for col_name in df.columns:
    print('\nUnique value in column', col_name, 'is:\n')
    print(df[col_name].unique())
    print('\n-----------------\n')
# Out:
# Unique value in column Year is:
#
# [2015 2016 2017 2018 2019 2020 2021]
#
# -----------------
#
#
# Unique value in column Month is:
#
# ['Jan' 'Feb' 'Mar' 'Apr' 'May' 'Jun' 'Jul' 'Aug' 'Sep' 'Oct' 'Nov' 'Dec']
#
# -----------------
#
#
# Unique value in column day of week is:
#
# ['Thursday' 'Friday' 'Saturday' 'Sunday' 'Monday' 'Tuesday' 'Wednesday']
#
# -----------------
#
#
# Unique value in column Rainfall_amount_(millimetres) is:
#
# [ 0.          4.2        19.4         1.2         5.2        15.8
#   1.          0.6         9.2         3.8        19.6         0.4
#   1.6         3.2         0.8         0.2         2.2         1.4
#   5.6         2.4         3.6         6.4         3.          7.
#   4.          8.6         2.6         6.8         4.4         1.8
#   6.2         8.2         1.33220749  5.          2.         28.4
#  17.4        12.2        17.6         6.         30.6        14.2
#  10.6         8.4        13.4         5.8        12.8        21.6
# ...

# %% [markdown]
# # check values

# %%
print(df.groupby('Year')['Rainfall_amount_(millimetres)'].mean())

df.groupby('Year').agg({'Rainfall_amount_(millimetres)':[sum,min,max]})
# Out:
# Year
# 2015    1.206938
# 2016    1.638251
# 2017    1.649315
# 2018    1.416615
# 2019    1.025753
# 2020    2.149727
# 2021    1.647458
# Name: Rainfall_amount_(millimetres), dtype: float64
#      Rainfall_amount_(millimetres)
#                                sum  min   max
# Year
# 2015                    440.532207  0.0  30.6
# 2016                    599.600000  0.0  22.6
# 2017                    602.000000  0.0  43.8
# 2018                    517.064415  0.0  41.2
# 2019                    374.400000  0.0  15.4
# 2020                    786.800000  0.0  54.6
# 2021                     97.200000  0.0  43.2

# %%
print(df.groupby('Month')['Rainfall_amount_(millimetres)'].mean())

df.groupby('Month').agg({'Rainfall_amount_(millimetres)':[sum,min,max]})
# Out:
# Month
# Apr    2.060000
# Aug    1.661290
# Dec    1.977419
# Feb    0.972727
# Jan    1.874654
# Jul    1.329032
# Jun    1.235179
# Mar    1.026882
# May    1.641935
# Nov    1.785556
# Oct    1.262712
# Sep    1.380000
# Name: Rainfall_amount_(millimetres), dtype: float64
#       Rainfall_amount_(millimetres)
#                                 sum  min   max
# Month
# Apr                      370.800000  0.0  35.2
# Aug                      309.000000  0.0  25.6
# Dec                      367.800000  0.0  43.8
# Feb                      192.600000  0.0  38.0
# Jan                      406.800000  0.0  44.0
# Jul                      247.200000  0.0  28.4
# Jun                      222.332207  0.0  15.6
# Mar                      191.000000  0.0  54.6
# May                      305.400000  0.0  18.6
# Nov                      321.400000  0.0  35.8
# Oct                      234.864415  0.0  32.2
# Sep                      248.400000  0.0  21.4

# %%
print(df.groupby('day of week')['Rainfall_amount_(millimetres)'].mean())

df.groupby('day of week').agg({'Rainfall_amount_(millimetres)':[sum,min,max]})
# Out:
# day of week
# Friday       1.479503
# Monday       1.360748
# Saturday     1.882609
# Sunday       1.695652
# Thursday     1.517802
# Tuesday      1.363029
# Wednesday    1.326892
# Name: Rainfall_amount_(millimetres), dtype: float64
#             Rainfall_amount_(millimetres)
#                                       sum  min   max
# day of week
# Friday                         476.400000  0.0  25.2
# Monday                         436.800000  0.0  32.4
# Saturday                       606.200000  0.0  43.2
# Sunday                         546.000000  0.0  43.8
# Thursday                       488.732207  0.0  54.6
# Tuesday                        437.532207  0.0  44.0
# Wednesday                      425.932207  0.0  38.0

# %% [markdown]
# ## Data visualization

# %%
df.groupby(['day of week'])['Rainfall amount (millimetres)'].sum()
# Out:
# day of week
# Friday       476.400000
# Monday       436.800000
# Saturday     606.200000
# Sunday       546.000000
# Thursday     488.732207
# Tuesday      437.532207
# Wednesday    425.932207
# Name: Rainfall amount (millimetres), dtype: float64

# %%
#insepct col Rainfall amount group by day
values = df.groupby(['day of week'])['Rainfall_amount_(millimetres)'].sum().values
labels = df.groupby(['day of week'])['Rainfall_amount_(millimetres)'].sum().index


plt.figure(1, figsize=(6,6))
plt.style.use('seaborn')
explode = [0.0, 0, 0.1 , 0, 0, 0, 0.2]
plt.pie(
       values, 
       labels = labels,
       shadow = True,
       autopct= '%0.2f%%',
       explode = explode,
       textprops={'fontsize':12.5}
)

plt.title('The amount of rainfall group by day_week', fontsize =14)
plt.show()

# %%
plt.figure(2)
sns.barplot(x = 'day of week', y='Rainfall amount (millimetres)',data =df,estimator= sum)

plt.title('which day of week has more rainfall')
plt.tight_layout()
plt.show()

# %%
#insepct col Rainfall amount group by month

values_month = df.groupby(['Month'])['Rainfall amount (millimetres)'].sum().values
labels_month = df.groupby(['Month'])['Rainfall amount (millimetres)'].sum().index
explode_2 = [0, 0, 0, 0.2, 0.2, 0, 0, 0, 0, 0, 0, 0]
plt.figure(figsize= (12,8))
plt.pie(
       values_month, 
       labels = labels_month,
       shadow = True,
       autopct= '%0.2f%%',
       explode = explode_2 ,
       textprops={'fontsize':12})
#plt.legend(loc = 'upper right')
plt.show()
#ax1.legend(loc = 0)

# %%
sns.boxplot(x= 'Month', y= 'Rainfall_amount_(millimetres)', data = df)
plt.title('Which mont has more rainfall')
plt.tight_layout()
plt.show()

# %%
sns.barplot(x= 'Month', y= 'Rainfall_amount_(millimetres)', data = df, estimator=sum)
plt.title('Which mont has more rainfall')
plt.tight_layout()
plt.show()

# %%
#insepct col Rainfall amount groub by year

values_year = df.groupby(['Year'])['Rainfall amount (millimetres)'].sum().values
labels_year = df.groupby(['Year'])['Rainfall amount (millimetres)'].sum().index


plt.figure(1)
explode_3 = [0, 0, 0, 0, 0, 0.2,0]
plt.pie(
       values_year, 
       labels = labels_year,
       shadow = True,
       autopct= '%0.2f%%',
       explode = explode_3,
       textprops= {'fontsize':12}
)
plt.title('pie chart group by year', fontsize =14)
plt.show()
#ax1.legend(loc = 1)
plt.clf()

plt.figure(2)
sns.barplot(x = labels_year, y=values_year)
plt.tight_layout()
plt.title('which year has more rainfall', fontsize = 15)
plt.show()

# %% [markdown]
# ## Statistics for amount rainfall

# %%
df['Rainfall amount (millimetres)'].describe()
# Out:
# count    2251.000000
# mean        1.518257
# std         4.392522
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.800000
# max        54.600000
# Name: Rainfall amount (millimetres), dtype: float64

# %%
rainfall_amount = df['Rainfall amount (millimetres)'].values
#hist
plt.figure(figsize=(13,6))
plt.style.use('seaborn')
plt.subplot(1,2,1)

plt.hist(rainfall_amount,
        range = (0,50),
        bins = 30,
        edgecolor = 'black')

plt.axvline(np.quantile(rainfall_amount, 0.5), c = 'black', label= 'median')
plt.axvline(np.mean(rainfall_amount), c = 'r', label ='mean')
plt.axvline(np.amax(rainfall_amount), c = 'green', label ='max')
#plt.axvline(np.amin(rainfall_amount), c = 'green', label ='min')

plt.title('Histogram of rainfall', fontsize= 14)
plt.legend( loc = 'upper right')

#log
plt.subplot(1,2,2)
log_rainfall_amout = np.log(rainfall_amount)
plt.hist(log_rainfall_amout,
        range = (0,50),
        bins = 40,
        edgecolor = 'black')
plt.title('(LOG)Histogram of rainfall', fontsize= 14)

plt.show()

# %%
from scipy import stats
print('before log:', stats.describe(rainfall_amount))

print('\nAfter log:', stats.describe(log_rainfall_amout))
# Out:
# before log: DescribeResult(nobs=2251, minmax=(0.0, 54.6), mean=1.5182570512941735, variance=19.29424629326098, skewness=5.485033693668813, kurtosis=39.30449410491126)
#
# After log: DescribeResult(nobs=2251, minmax=(-inf, 4.000033882750859), mean=-inf, variance=nan, skewness=nan, kurtosis=nan)

# %%
# boxplot
plt.figure(2)
plt.boxplot(rainfall_amount)
plt.title('Box plot of rainfall', fontsize= 20)
plt.show()

print('median',np.median(rainfall_amount))
print('mean',np.average(rainfall_amount))
print('max',np.amax(rainfall_amount))
print('min',np.amin(rainfall_amount))
# Out:
# median 0.0
# mean 1.5182570512941735
# max 54.6
# min 0.0

# %% [markdown]
# # Time series

# %%
df['Rainfall amount (millimetres)'].resample('M').sum()
# Out:
# date
# 2015-01-31    47.4
# 2015-02-28    37.8
# 2015-03-31    23.0
# 2015-04-30    36.8
# 2015-05-31    37.6
#               ...
# 2020-10-31    74.2
# 2020-11-30    48.8
# 2020-12-31    42.0
# 2021-01-31    88.0
# 2021-02-28     9.2
# Freq: M, Name: Rainfall amount (millimetres), Length: 74, dtype: float64

# %%
plt.figure()
plt.plot(df['Rainfall amount (millimetres)'].resample('M').sum())
plt.title('Month')
plt.show()

# %%
df['Rainfall amount (millimetres)'].resample('10D').sum()
# Out:
# date
# 2015-01-01    30.0
# 2015-01-11    15.8
# 2015-01-21     1.6
# 2015-01-31    13.0
# 2015-02-10    20.0
#               ...
# 2021-01-19    11.0
# 2021-01-29    50.6
# 2021-02-08     5.0
# 2021-02-18     0.4
# 2021-02-28     0.0
# Freq: 10D, Name: Rainfall amount (millimetres), Length: 226, dtype: float64

# %%
plt.plot(df['Rainfall amount (millimetres)'].resample('10D').sum())
plt.title('10 DAY')
# Out:
# Text(0.5, 1.0, '10 DAY')

# %%
df['Rainfall amount (millimetres)'].resample('7D').sum()
# Out:
# date
# 2015-01-01     4.2
# 2015-01-08    41.6
# 2015-01-15     0.0
# 2015-01-22     1.6
# 2015-01-29    13.0
#               ...
# 2021-01-28    46.8
# 2021-02-04     4.2
# 2021-02-11     4.6
# 2021-02-18     0.0
# 2021-02-25     0.4
# Freq: 7D, Name: Rainfall amount (millimetres), Length: 322, dtype: float64

# %%
plt.clf()
plt.plot(df['Rainfall amount (millimetres)'].resample('7D').sum())
plt.title('7 DAY')
# Out:
# Text(0.5, 1.0, '7 DAY')

# %%
df['Rainfall amount (millimetres)'].resample('Y').sum()
# Out:
# date
# 2015-12-31    440.532207
# 2016-12-31    599.600000
# 2017-12-31    602.000000
# 2018-12-31    517.064415
# 2019-12-31    374.400000
# 2020-12-31    786.800000
# 2021-12-31     97.200000
# Freq: A-DEC, Name: Rainfall amount (millimetres), dtype: float64

# %%
labels = [2015 ,2016,2017,2018,2019,2020, 2021]
plt.plot(df['Rainfall amount (millimetres)'].resample('Y').sum())
plt.xticks(df['Rainfall amount (millimetres)'].resample('Y').sum().index, labels, rotation ='vertical')
plt.title('Year')
# Out:
# Text(0.5, 1.0, 'Year')

# %% [markdown]
# ## Conclusion
# - Day of week
#     - Saturday has lagerst amount of rainfall.
# - Year
#     - Rainfall happend in 2020 is higher than average on past year, more info see as [**Link**]('http://www.bom.gov.au/climate/current/annual/vic/melbourne.shtml)
# - Month
#     - **January** has highest sum of amount rainfall. In contrast, **Feb** has lowerest rainfall.
#     - It may has associtaion among month.
#
# **Overall**: Keep all columns
