# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt 
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
path = '/content/drive/My Drive/DataSets/project _python/pm2.5.csv'
df_1 = pd.read_csv(path)

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120830 entries, 0 to 120829
# Data columns (total 15 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   120830 non-null  int64
#  1   id           120830 non-null  int64
#  2   site_id      120830 non-null  object
#  3   sensor_id    120830 non-null  object
#  4   value        120826 non-null  float64
#  5   local_time   120830 non-null  object
#  6   type         120830 non-null  object
#  7   units        120830 non-null  object
#  8   Date         120830 non-null  object
#  9   Time         120830 non-null  object
#  10  description  120830 non-null  object
#  11  last_data    120830 non-null  object
#  12  latitude     120830 non-null  float64
#  13  longitude    120830 non-null  float64
#  14  location     120830 non-null  object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 13.8+ MB

# %%
df_1['local_time']= pd.to_datetime(df_1['local_time'])

# %%
df_1['Month'] = df_1['local_time'].dt.month
df_1['Day'] = df_1['local_time'].dt.day

# %%
data_arc1048= df_1[df_1['site_id'].isin(['arc1048'])]

# %%
data_arc1048.Month.unique()
# Out:
# array([11, 12,  1,  2,  7,  3,  4,  5,  6,  8])

# %%
data_arc1048_nov= data_arc1048[data_arc1048['Month'].isin(['11'])]

# %%
data_arc1048_nov['value'].describe()
# Out:
# count    1467.000000
# mean        7.613974
# std         3.435264
# min         3.600000
# 25%         5.600000
# 50%         6.800000
# 75%         8.300000
# max        33.900000
# Name: value, dtype: float64

# %%
ax = sns.lineplot(x="local_time", y="value", hue="site_id",
                  err_style="bars", ci=68, data=data_arc1048_nov)

# %%
data_arc1048_dec= data_arc1048[data_arc1048['Month'].isin(['12'])]
data_arc1048_dec['value'].describe()
# Out:
# count    2914.000000
# mean       11.308648
# std        15.278552
# min         3.300000
# 25%         6.200000
# 50%         8.000000
# 75%        10.700000
# max       201.500000
# Name: value, dtype: float64

# %%
ax = sns.lineplot(x="local_time", y="value", hue="site_id",
                  err_style="bars", ci=68, data=data_arc1048_dec)

# %%
data_arc1048_jan= data_arc1048[data_arc1048['Month'].isin(['1'])]
data_arc1048_jan['value'].describe()
# Out:
# count    2919.000000
# mean       44.041213
# std       105.282646
# min         3.500000
# 25%         6.600000
# 50%         9.000000
# 75%        24.800000
# max       920.600000
# Name: value, dtype: float64

# %%
ax = sns.lineplot(x="local_time", y="value", hue="site_id",
                  err_style="bars", ci=68, data=data_arc1048_jan)

# %%
data_arc1048_feb= data_arc1048[data_arc1048['Month'].isin(['2'])]
data_arc1048_feb['value'].describe()
# Out:
# count    2768.000000
# mean       11.041077
# std        13.384241
# min         3.300000
# 25%         5.800000
# 50%         7.000000
# 75%         9.500000
# max       241.400000
# Name: value, dtype: float64

# %%
ax = sns.lineplot(x="local_time", y="value", hue="site_id",
                  err_style="bars", ci=68, data=data_arc1048_feb)

# %%
data_arc1048_march= data_arc1048[data_arc1048['Month'].isin(['3'])]
data_arc1048_march['value'].describe()
# Out:
# count    2964.000000
# mean        6.820918
# std         2.664874
# min         4.100000
# 25%         5.400000
# 50%         6.200000
# 75%         7.500000
# max        82.500000
# Name: value, dtype: float64

# %%
ax = sns.lineplot(x="local_time", y="value", hue="site_id",
                  err_style="bars", ci=68, data=data_arc1048_march)

# %%
data_arc1048_april= data_arc1048[data_arc1048['Month'].isin(['4'])]
data_arc1048_april['value'].describe()
# Out:
# count    2225.000000
# mean        7.818921
# std         3.552509
# min         4.200000
# 25%         5.900000
# 50%         6.800000
# 75%         8.400000
# max        43.100000
# Name: value, dtype: float64

# %%
ax = sns.lineplot(x="local_time", y="value", hue="site_id",
                  err_style="bars", ci=68, data=data_arc1048_april)

# %%
data_arc1048_may= data_arc1048[data_arc1048['Month'].isin(['5'])]
data_arc1048_may['value'].describe()
# Out:
# count    2307.000000
# mean        8.468227
# std         5.355446
# min         4.200000
# 25%         5.500000
# 50%         6.800000
# 75%         8.800000
# max        67.900000
# Name: value, dtype: float64

# %%
ax = sns.lineplot(x="local_time", y="value", hue="site_id",
                  err_style="bars", ci=68, data=data_arc1048_may)

# %%
data_arc1048_june= data_arc1048[data_arc1048['Month'].isin(['6'])]
data_arc1048_june['value'].describe()
# Out:
# count    1781.000000
# mean        9.810668
# std         6.165416
# min         4.200000
# 25%         6.200000
# 50%         7.600000
# 75%        10.900000
# max        50.000000
# Name: value, dtype: float64

# %%
ax = sns.lineplot(x="local_time", y="value", hue="site_id",
                  err_style="bars", ci=68, data=data_arc1048_june)

# %%
data_arc1048_july= data_arc1048[data_arc1048['Month'].isin(['7'])]
data_arc1048_july['value'].describe()
# Out:
# count    2963.000000
# mean       10.501755
# std         6.825195
# min         4.000000
# 25%         5.900000
# 50%         7.500000
# 75%        12.900000
# max        50.000000
# Name: value, dtype: float64

# %%
ax = sns.lineplot(x="local_time", y="value", hue="site_id",
                  err_style="bars", ci=68, data=data_arc1048_july)

# %%
data_arc1048_aug=data_arc1048[data_arc1048['Month'].isin(['8'])]
data_arc1048_aug['value'].describe()
# Out:
# count    468.000000
# mean       7.063675
# std        1.895155
# min        4.200000
# 25%        5.800000
# 50%        6.700000
# 75%        8.100000
# max       21.400000
# Name: value, dtype: float64

# %%
ax = sns.lineplot(x="local_time", y="value", hue="site_id",
                  err_style="bars", ci=68, data=data_arc1048_aug)

# %%
ax = sns.boxplot(x="local_time", y="value", data=data_arc1048_aug)
