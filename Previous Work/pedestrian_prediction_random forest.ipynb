# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

# %%
data=pd.read_csv('machine_learning_preprocessed_data.csv')
data_complete=pd.read_csv('data-jan-dec.csv')

# %%
data_future = data[300289:]
data = data[:300289]
data_future.drop(['Hourly_Counts'],axis=1,inplace=True)
X, Y = data.iloc[:,1:], data.iloc[:,0]

# %%
train_x = X[:250000]
test_x = X[250000:]
train_y = Y[:250000]
test_y = Y[250000:]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
train_x, test_x, train_y, test_y = train_test_split(X,Y,test_size=0.2, random_state=10)

# %%
model = RandomForestRegressor(max_depth=30,
                              min_samples_split=3,
                              min_samples_leaf=2,
                              max_features='auto',
                              min_impurity_decrease=0.01,
                              max_leaf_nodes=100)

model.fit(train_x,train_y)

# %%
#predicting test results
pred=model.predict(test_x)
#converting to array
pred=np.array(pred)
y_test=np.array(test_y)
#calculating error RMSE
error=pred-y_test
error2=error**2
test_rmse=np.sqrt(error2.sum()/len(error2))

#predicting results for train
pred=grid_mse.predict(train_x)
#converting to array
pred=np.array(pred)
y_train=np.array(train_y)
#calculating error RMSE
error=pred-y_train
error2=error**2
train_rmse=np.sqrt(error2.sum()/len(error2))

    
c=[np.mean(test_rmse)]
c1=[np.mean(train_rmse)]

c=pd.DataFrame(c)
c1=pd.DataFrame(c1)
result=pd.concat([c,c1],axis=1)
result.columns=['test','train']
result.index=['RMSE error']
result

# %%
model = RandomForestRegressor(max_depth=25,
                              min_samples_split=4,
                              min_samples_leaf=3,
                              max_features='auto',
                              min_impurity_decrease=0.02,
                              max_leaf_nodes=80)

model.fit(train_x,train_y)

# %%
#predicting test results
pred=model.predict(test_x)
#converting to array
pred=np.array(pred)
y_test=np.array(test_y)
#calculating error RMSE
error=pred-y_test
error2=error**2
test_rmse=np.sqrt(error2.sum()/len(error2))

#predicting results for train
pred=grid_mse.predict(train_x)
#converting to array
pred=np.array(pred)
y_train=np.array(train_y)
#calculating error RMSE
error=pred-y_train
error2=error**2
train_rmse=np.sqrt(error2.sum()/len(error2))

    
c=[np.mean(test_rmse)]
c1=[np.mean(train_rmse)]

c=pd.DataFrame(c)
c1=pd.DataFrame(c1)
result=pd.concat([c,c1],axis=1)
result.columns=['test','train']
result.index=['RMSE error']
result

# %%
model = RandomForestRegressor(max_depth=15,
                              min_samples_split=5,
                              min_samples_leaf=4,
                              max_features='auto',
                              min_impurity_decrease=0.005,
                              max_leaf_nodes=70)

model.fit(train_x,train_y)

# %%
#predicting test results
pred=model.predict(test_x)
#converting to array
pred=np.array(pred)
y_test=np.array(test_y)
#calculating error RMSE
error=pred-y_test
error2=error**2
test_rmse=np.sqrt(error2.sum()/len(error2))

#predicting results for train
pred=grid_mse.predict(train_x)
#converting to array
pred=np.array(pred)
y_train=np.array(train_y)
#calculating error RMSE
error=pred-y_train
error2=error**2
train_rmse=np.sqrt(error2.sum()/len(error2))

    
c=[np.mean(test_rmse)]
c1=[np.mean(train_rmse)]

c=pd.DataFrame(c)
c1=pd.DataFrame(c1)
result=pd.concat([c,c1],axis=1)
result.columns=['test','train']
result.index=['RMSE error']
result

# %%
model = RandomForestRegressor(max_depth=10,
                              min_samples_split=2,
                              min_samples_leaf=2,
                              max_features='auto',
                              min_impurity_decrease=0.01,
                              max_leaf_nodes=90)

model.fit(train_x,train_y)model = RandomForestRegressor(max_depth=30,

# %%
#predicting test results
pred=model.predict(test_x)
#converting to array
pred=np.array(pred)
y_test=np.array(test_y)
#calculating error RMSE
error=pred-y_test
error2=error**2
test_rmse=np.sqrt(error2.sum()/len(error2))

#predicting results for train
pred=grid_mse.predict(train_x)
#converting to array
pred=np.array(pred)
y_train=np.array(train_y)
#calculating error RMSE
error=pred-y_train
error2=error**2
train_rmse=np.sqrt(error2.sum()/len(error2))

    
c=[np.mean(test_rmse)]
c1=[np.mean(train_rmse)]

c=pd.DataFrame(c)
c1=pd.DataFrame(c1)
result=pd.concat([c,c1],axis=1)
result.columns=['test','train']
result.index=['RMSE error']
result

# %%
model = RandomForestRegressor(max_depth=20,
                              min_samples_split=5,
                              min_samples_leaf=5,
                              max_features='auto',
                              min_impurity_decrease=0.05,
                              max_leaf_nodes=50)

model.fit(train_x,train_y)

# %%
#predicting test results
pred=model.predict(test_x)
#converting to array
pred=np.array(pred)
y_test=np.array(test_y)
#calculating error RMSE
error=pred-y_test
error2=error**2
test_rmse=np.sqrt(error2.sum()/len(error2))

#predicting results for train
pred=grid_mse.predict(train_x)
#converting to array
pred=np.array(pred)
y_train=np.array(train_y)
#calculating error RMSE
error=pred-y_train
error2=error**2
train_rmse=np.sqrt(error2.sum()/len(error2))

    
c=[np.mean(test_rmse)]
c1=[np.mean(train_rmse)]

c=pd.DataFrame(c)
c1=pd.DataFrame(c1)
result=pd.concat([c,c1],axis=1)
result.columns=['test','train']
result.index=['RMSE error']
result

# %%
model = RandomForestRegressor(max_depth=10,
                              min_samples_split=2,
                              min_samples_leaf=2,
                              max_features='auto',
                              min_impurity_decrease=0.01,
                              max_leaf_nodes=100)

model.fit(train_x,train_y)

# %%
#predicting test results
pred=model.predict(test_x)
#converting to array
pred=np.array(pred)
y_test=np.array(test_y)
#calculating error RMSE
error=pred-y_test
error2=error**2
test_rmse=np.sqrt(error2.sum()/len(error2))

#predicting results for train
pred=grid_mse.predict(train_x)
#converting to array
pred=np.array(pred)
y_train=np.array(train_y)
#calculating error RMSE
error=pred-y_train
error2=error**2
train_rmse=np.sqrt(error2.sum()/len(error2))

    
c=[np.mean(test_rmse)]
c1=[np.mean(train_rmse)]

c=pd.DataFrame(c)
c1=pd.DataFrame(c1)
result=pd.concat([c,c1],axis=1)
result.columns=['test','train']
result.index=['RMSE error']
result

# %%
df = pd.DataFrame({'max_depth':[30,20,25,25,30,30, 15,15,15,15],
                   'min_samples_split':[3,2,2,4,4,2,2,2,2,2],
                   'min_samples_leaf':[2,2,4,4,4,4,6,6,6,6],
                   'max_features':['auto','auto','auto','auto','auto','auto','auto','auto','auto','auto'],
                   'min_impurity_decrease':[0.01,0.02,0.005,0.05,0.1,0.02,0.01,0.07,0.09,0.01],
                   'max_leaf_nodes':[70,80,70,90,110,100,60,90,70,80],
                   'RMSE for train':[409, 390, 383, 402, 391, 430, 456, 433, 425, 434],
                   'RMSE for test':[423, 465, 378, 384, 422, 465, 490, 444, 439, 416]})

# %%
df
# Out:
#    max_depth  min_samples_split  min_samples_leaf max_features  \
# 0         30                  3                 2         auto
# 1         20                  2                 2         auto
# 2         25                  2                 4         auto
# 3         25                  4                 4         auto
# 4         30                  4                 4         auto
# 5         30                  2                 4         auto
# 6         15                  2                 6         auto
# 7         15                  2                 6         auto
# 8         15                  2                 6         auto
# 9         15                  2                 6         auto
#
#    min_impurity_decrease  max_leaf_nodes  RMSE for train  RMSE for test
# 0                  0.010              70             409            423
# 1                  0.020              80             390            465
# 2                  0.005              70             383            378
# 3                  0.050              90             402            384
# 4                  0.100             110             391            422
# 5                  0.020             100             430            465
# 6                  0.010              60             456            490
# 7                  0.070              90             433            444
# 8                  0.090              70             425            439
# 9                  0.010              80             434            416
