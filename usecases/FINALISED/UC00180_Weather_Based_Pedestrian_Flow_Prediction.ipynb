# %%
# WEB DEV TEAM PLEASE DELETE BEFORE PUBLISHING - DS TEAM PLEASE KEEP IN THE FINAL VERSION OF THE USE CASE

from IPython.core.display import HTML
HTML("""
<style>
@import url('https://fonts.googleapis.com/css2?family=Poppins:wght@600;700&family=Inter:wght@400;500&display=swap');

/* Global Fonts and Counters */
body, p, li, div {
    font-family: 'Inter', sans-serif;
}

body {
    counter-reset: h2counter;
}

/* Heading Fonts */
.usecase-header-bar,
.usecase-title,
.usecase-section-heading,
.usecase-sub-section-heading,
.usecase-sub-sub-section-heading,
.usecase-unnumbered-heading{
    font-family: 'Poppins', sans-serif;
}

.usecase-header-bar {
   padding: 16px 20px;
   background-color: #059669;
   color: #fff;
   border-radius: 6px 6px 0 0;
}

.usecase-title {
    font-size: 1.9em;
    font-weight: 800;
}

/* Metadata Styling */
.usecase-details {
    padding-left: 20px;
    padding-bottom: 8px;
    padding-top: 8px;
    font-size: 1.1em;
    color: #121212;
}

/* Base styling for all main headings (Numbered & Unnumbered) */
.usecase-section-heading, 
.usecase-unnumbered-heading {
    font-weight: 700;
    font-size: 1.35em;
    color: #059669;
    padding: 14px 4px 6px 4px;
    border-bottom: 3px solid #2DBE6C;
    margin-top: 10px;
}

/* Level 1 section headings */
.usecase-section-heading::before {
    content: none !important;
}

/* Level 2 subsection headings */
.usecase-sub-section-heading {
    font-weight: 600;
    font-size: 1.15em;
    color: #059669;
    margin-top: 8px;
}

.usecase-sub-section-heading::before {
    content: none !important;
}

/* Level 3 sub-subsection headings */
.usecase-sub-sub-section-heading {
    font-weight: 500;
    font-size: 1.05em;
    color: #059669;
    margin-top: 6px;
}

.usecase-sub-sub-section-heading::before {
    content: none !important;
}

/* Body */
.usecase-body {
    font-size: 1em;
    color: #121212;
    line-height: 1.6;
    margin-bottom: 8px;
}

/* Generic list styling */
.usecase-list {
    line-height: 1.7;
}

.usecase-list ul, .usecase-list ol {
    padding-left: 24px;
    margin-top: 8px;
    margin-bottom: 12px;
}

.usecase-list li {
    margin-bottom: 6px;
}

/* Datasets specific list box */
.usecase-datasets {
    background-color: rgba(5, 150, 105, 0.06);
    border-left: 4px solid #059669;
    padding: 12px 20px;
    border-radius: 0 4px 4px 0;
    margin-top: 12px;
}

.usecase-datasets ul {
    margin-top: 8px;
    margin-bottom: 8px;
}

/* Link styles for both TOC and Datasets */
.usecase-contents a, 
.usecase-datasets a {
    color: #059669;
    text-decoration: none;
}

.usecase-datasets a {
    font-weight: 500;
}

.usecase-contents a:hover, 
.usecase-datasets a:hover {
    text-decoration: underline;
}

/* TOC Container */
.usecase-contents {
    line-height: 1.9;
    padding-left: 20px;
}

/* Content Divider */
.usecase-code-divider {
    font-style: italic;
    color: rgba(18, 18, 18, 0.65);
    background-color: rgba(5, 150, 105, 0.06);
    padding: 10px 16px;
    border-radius: 4px;
    margin-top: 14px;
}
</style>

""")
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Poppins:wght@600;700&family=Inter:wght@400;500&display=swap');
#
# /* Global Fonts and Counters */
# body, p, li, div {
#     font-family: 'Inter', sans-serif;
# }
#
# body {
#     counter-reset: h2counter;
# }
#
# /* Heading Fonts */
# .usecase-header-bar,
# .usecase-title,
# .usecase-section-heading,
# .usecase-sub-section-heading,
# .usecase-sub-sub-section-heading,
# .usecase-unnumbered-heading{
#     font-family: 'Poppins', sans-serif;
# }
#
# .usecase-header-bar {
#    padding: 16px 20px;
#    background-color: #059669;
#    color: #fff;
#    border-radius: 6px 6px 0 0;
# }
#
# .usecase-title {
#     font-size: 1.9em;
#     font-weight: 800;
# }
#
# /* Metadata Styling */
# .usecase-details {
#     padding-left: 20px;
#     padding-bottom: 8px;
#     padding-top: 8px;
#     font-size: 1.1em;
#     color: #121212;
# }
#
# /* Base styling for all main headings (Numbered & Unnumbered) */
# .usecase-section-heading,
# ...

# %% [markdown]
# <div class="usecase-header-bar">
#     <div class="usecase-title">
#         Weather Based Pedestrian Flow Prediction
#     </div>
# </div>
#
# <div class="usecase-details"><b>Authored by: </b>Adithya Sentil</div>
# <div class="usecase-details"><b>Date Created: </b>Trimester 2, 2025</div>
# <div class="usecase-details"><b>Time to Complete: </b>90 mins</div>
# <div class="usecase-details"><b>Level: </b>Intermediate</div>
# <div class="usecase-details"><b>Pre-requisite Skills: </b>Python, pandas, data cleaning, data visualisation, basic geospatial analysis, and introductory machine learning</div>

# %% [markdown]
# <div id="scenario" class="usecase-unnumbered-heading"><b>Scenario</b></div>

# %% [markdown]
# <div class="usecase-body">
# City planners and emergency services currently have limited ability to accurately predict pedestrian movement before high-traffic periods. Without reliable forecasts that combine historical pedestrian counts, weather conditions, and scheduled event information, it is more difficult to proactively manage pedestrian flow, allocate resources, and reduce overcrowding. This use case addresses that problem by developing a model capable of predicting pedestrian volumes using multiple data sources to support informed planning and decision-making.
# </div>

# %% [markdown]
# <div id="what-this-teaches" class="usecase-unnumbered-heading">
# <b>What this usecase will teach you</b>
# </div>
#
# <ul class="usecase-list">
#     <li>How to prepare and combine multiple datasets, including pedestrian sensor, weather, and event venue data.</li>
#     <li>How to perform exploratory data analysis and feature engineering to identify factors associated with pedestrian activity.</li>
#     <li>How to build and evaluate predictive machine learning models for pedestrian flow.</li>
#     <li>How to interpret model results and apply the findings to support urban planning, crowd management, and emergency services decision-making.</li>
# </ul>

# %% [markdown]
# <div id="background" class="usecase-unnumbered-heading"><b>Background</b></div>

# %% [markdown]
# <div class="usecase-body">
# Melbourne experiences significant variation in pedestrian activity throughout the day due to factors such as weather conditions, public events, seasonal trends, and historical movement patterns. Accurately predicting pedestrian flow is important for supporting city planning, crowd management, and the allocation of public resources. Traditional approaches often rely on historical trends alone and may not account for external influences that affect pedestrian volumes. This use case demonstrates how multiple data sources—including pedestrian sensor data, weather information, and scheduled event data—can be integrated to develop an AI-based prediction model. The resulting insights can help city planners and emergency services anticipate periods of high pedestrian activity and make more informed operational decisions.
# </div>

# %% [markdown]
# <div class="usecase-unnumbered-heading" id="datasets">
# <b>Datasets</b>
# </div>
#
# <div class="usecase-datasets">
#
# <b>Dataset 1:</b> <a href="https://data.melbourne.vic.gov.au/explore/dataset/pedestrian-counting-system-monthly-counts-per-hour/information/">Pedestrian Counting System – Monthly Counts per Hour</a>
#
# <p>Provides historical pedestrian counts collected from sensors across Melbourne. This dataset is the primary source used to analyse pedestrian movement patterns and serves as the target variable for the machine learning models.</p>
#
# <b>Dataset 2:</b> <a href="https://data.melbourne.vic.gov.au/explore/dataset/venues-for-event-bookings/information/">Venues for Event Bookings</a>
#
# <p>Contains venue locations and booking-related attributes used to examine the proximity between event venues and pedestrian sensors.</p>
#
# <b>Dataset 3:</b> <a href="https://data.melbourne.vic.gov.au/explore/dataset/meshed-sensor-type-1/information/">Meshed Sensor Type 1</a>
#
# <p>Contains environmental observations such as air temperature, atmospheric pressure and vapour pressure. These features are used to examine how weather conditions relate to pedestrian activity.</p>
#
# </div>

# %% [markdown]
# <div class="usecase-unnumbered-heading"><b>Contents</b></div>

# %% [markdown]
# <div class="usecase-contents">
# <a href="#section-1"><b>1. Importing Required Libraries</b></a><br>
# <a href="#section-2"><b>2. Importing Datasets</b></a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-2-1">2.1 Importing Pedestrian Count Data</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-2-2">2.2 Importing Weather Data</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-2-3">2.3 Importing Venue Location Data</a><br>
# <a href="#section-3"><b>3. Cleaning and Exploring the Datasets</b></a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-3-1">3.1 Cleaning the Pedestrian Count Data</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-3-1-1">3.1.1 Data Quality and Summary Statistics Overview – Pedestrian Count Data</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-3-1-2">3.1.2 Visualising Pedestrian Count</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-3-2">3.2 Cleaning the Weather Data</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-3-2-1">3.2.1 Data Quality and Summary Statistics Overview – Weather Data</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-3-2-2">3.2.2 Dropping Unnecessary Columns</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-3-2-3">3.2.3 Visualising Weather Station Data</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-3-2-4">3.2.4 Uniform Date-Time Preparation</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-3-2-5">3.2.5 Visualising Weather Station Features Against Pedestrian Count</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-3-2-6">3.2.6 Correlation Matrix</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-3-3">3.3 Cleaning the Venue Data</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-3-4">3.4 Geospatial Visualisation</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-3-4-1">3.4.1 Mapping Pedestrian Sensors and Event Venues</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-3-5">3.5 Calculating Distance from Venues to Pedestrian Sensors</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-3-6">3.6 Nearest Sensor Calculation</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-3-7">3.7 Merging the Datasets</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-3-8">3.8 Preparing the Final Modelling Dataset</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-3-9">3.9 Incorporating Day of the Week</a><br>
# <a href="#section-4"><b>4. Machine Learning Model</b></a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-4-1">4.1 Feature Selection</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-4-2">4.2 Polynomial Features</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-4-3">4.3 Train-Test Split</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-4-4">4.4 Applying Linear Regression Model</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-4-5">4.5 Linear Regression Original Feature Analysis</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-4-6">4.6 Linear Regression Interaction Feature Analysis</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-4-7">4.7 Applying Random Forest Regression Model</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-4-8">4.8 Random Forest Regression Original Feature Analysis</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;<a href="#section-4-9">4.9 Random Forest Regression Interaction Feature Analysis</a><br>
# <a href="#conclusion"><b>5. Conclusion</b></a>
# </div>

# %% [markdown]
# <div id="section-1" class="usecase-section-heading">
# <b>1. Importing Required Libraries</b>
# </div>

# %% [markdown]
# <div class="usecase-body">
# This section imports the Python libraries required throughout the notebook. These libraries support data manipulation, visualisation, API requests, and machine learning tasks used in the pedestrian flow prediction workflow.
# </div>

# %%
# Import libraries required for data processing and visualisation
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import requests

# %% [markdown]
# <div id="section-2" class="usecase-section-heading">
# <b>2. Importing Datasets</b>
# </div>

# %% [markdown]
# <div class="usecase-body">
# This section imports the datasets required for the pedestrian flow prediction model. The data is retrieved from the City of Melbourne Open Data API and loaded into pandas DataFrames for further cleaning, exploration and modelling.
# </div>

# %%
def fetch_data(base_url, dataset, api_key, num_records=99, offset=0):
    all_records = []
    max_offset = 9900  # Maximum number of requests

    while True:
        # Maximum limit check
        if offset > max_offset:
            break

        # Create API request URL
        filters = f'{dataset}/records?limit={num_records}&offset={offset}'
        url = f'{base_url}{filters}&api_key={api_key}'

        # Start request
        try:
            result = requests.get(url, timeout=10)
            result.raise_for_status()
            records = result.json().get('results')
        except requests.exceptions.RequestException as e:
            raise Exception(f"API request failed: {e}")
        if records is None:
            break
        all_records.extend(records)
        if len(records) < num_records:
            break

        # Next cycle offset
        offset += num_records

    # DataFrame all data
    df = pd.DataFrame(all_records)
    return df

#os.environ.get('MELBOURNE_API_KEY')

# Retrieve API key from environment variable
API_KEY = os.environ.get('MELBOURNE_API_KEY')

# Base URL for the City of Melbourne Open Data API
BASE_URL = 'https://data.melbourne.vic.gov.au/api/explore/v2.1/catalog/datasets/'

# %% [markdown]
# <div id="section-2-1" class="usecase-sub-section-heading">
# <b>2.1 Importing Pedestrian Count Data</b>
# </div>

# %% [markdown]
# <div class="usecase-body">
# The pedestrian counting dataset is retrieved from the City of Melbourne Open Data API and stored in a pandas DataFrame for cleaning and analysis.
# </div>

# %%
# Data set name
dataset_pedestrian_counting = 'pedestrian-counting-system-monthly-counts-per-hour'
# Fetch dataset 
pedestrian_counting = fetch_data(BASE_URL, dataset_pedestrian_counting, API_KEY)
# Create a new row named latitude
pedestrian_counting['latitude'] = pedestrian_counting['location'].apply(lambda x: x['lat'] if isinstance(x, dict) else None)
# Create a new row named longitude
pedestrian_counting['longitude'] = pedestrian_counting['location'].apply(lambda x: x['lon'] if isinstance(x, dict) else None)

pedestrian_counting.head()
# Out:
#              id  location_id sensing_date  hourday  direction_1  direction_2  \
# 0  672120250430           67   2025-04-30       21           89          179
# 1   58220251227           58   2025-12-27        2           28           50
# 2  351520260729           35   2026-07-29       15          735          589
# 3    2520250817            2   2025-08-17        5            5            5
# 4  202020250426           20   2025-04-26       20          394          690
#
#    pedestriancount sensor_name                                    location  \
# 0              268    FLDegS_T  {'lon': 144.96562569, 'lat': -37.81688755}
# 1               78    Bou688_T  {'lon': 144.95358075, 'lat': -37.81686075}
# 2             1324    SouthB_T  {'lon': 144.96508508, 'lat': -37.82018685}
# 3               10    Bou283_T  {'lon': 144.96516718, 'lat': -37.81380668}
# 4             1084    LtB170_T   {'lon': 144.9682466, 'lat': -37.81172914}
#
#     latitude   longitude
# 0 -37.816888  144.965626
# ...

# %% [markdown]
# <div id="section-2-2" class="usecase-sub-section-heading">
# <b>2.2 Importing Weather Data</b>
# </div>

# %% [markdown]
# <div class="usecase-body">
# The weather station dataset is retrieved from the City of Melbourne Open Data API to provide environmental features for pedestrian-flow modelling.
# </div>

# %%
# Data set name
weather_stations = 'meshed-sensor-type-1'
# Fetch dataset 
weather_stations_df = fetch_data(BASE_URL, weather_stations, API_KEY)


weather_stations_df.head()
# Out:
#       device_id                       time        rtc  battery  solarpanel  \
# 0  atmos41-32fc  2025-08-16T20:40:34+00:00  121366929    4.140       1.458
# 1  atmos41-32fc  2025-08-16T20:10:00+00:00  121365095    4.140       0.225
# 2  atmos41-32fc  2025-08-16T21:10:53+00:00  121368748    4.137      19.340
# 3  atmos41-32fc  2025-08-17T02:26:30+00:00  121387685    4.209      22.064
# 4  atmos41-32fc  2025-08-16T11:56:26+00:00  121335482    4.169       0.249
#
#    command  solar  precipitation  strikes  windspeed  winddirection  \
# 0        0      0              0        0       1.38          174.9
# 1        0      0              0        0       1.52          171.7
# 2        0      3              0        0       1.55          170.9
# 3        0    175              0        0       0.89          152.1
# 4        0      0              0        0       0.59           53.8
#
#    gustspeed  vapourpressure  atmosphericpressure  relativehumidity  airtemp  \
# ...

# %% [markdown]
# <div id="section-2-3" class="usecase-sub-section-heading">
# <b>2.3 Importing Venue Location Data</b>
# </div>

# %% [markdown]
# <div class="usecase-body">
# The venue-location dataset is imported to support geospatial analysis and calculate the distance between venues and pedestrian sensors.
# </div>

# %%
venue_location = fetch_data(BASE_URL, 'venues-for-event-bookings', API_KEY) 
# Create a new row named latitude
venue_location['latitude'] = venue_location['geo_point_2d'].apply(lambda x: x['lat'] if isinstance(x, dict) else None)
# Create a new row named longitude
venue_location['longitude'] = venue_location['geo_point_2d'].apply(lambda x: x['lon'] if isinstance(x, dict) else None)
venue_location.head()
# Out:
#                                         geo_point_2d  \
# 0  {'lon': 144.98896595113547, 'lat': -37.8171274...
# 1  {'lon': 144.98293613155118, 'lat': -37.8425742...
# 2  {'lon': 144.9554621837315, 'lat': -37.78557214...
# 3  {'lon': 144.98286097598913, 'lat': -37.8445902...
# 4  {'lon': 144.97660241098285, 'lat': -37.8246014...
#
#                                            geo_shape prop_id no_smoking  \
# 0  {'type': 'Feature', 'geometry': {'coordinates'...       0          N
# 1  {'type': 'Feature', 'geometry': {'coordinates'...  103756          N
# 2  {'type': 'Feature', 'geometry': {'coordinates'...  107426          N
# 3  {'type': 'Feature', 'geometry': {'coordinates'...  103756          N
# 4  {'type': 'Feature', 'geometry': {'coordinates'...  108615          N
#
#              level_1_na   addresspt1 event  \
# 0  Other Park Locations  29.98397741     Y
# 1          Fawkner Park          0.0     N
# 2            Royal Park          0.0     N
# ...

# %% [markdown]
# <div id="section-3" class="usecase-section-heading">
# <b>3. Cleaning and Exploring the Datasets</b>
# </div>

# %% [markdown]
# <div class="usecase-body">
# Once the datasets have been imported, they must be cleaned and explored before they can be used for modelling. This process involves checking data quality, identifying missing values, validating data types, removing inconsistencies, and exploring key characteristics of each dataset. Preparing the data in this way ensures that the machine learning models are trained using accurate and reliable information.
# </div>

# %% [markdown]
# <div id="section-3-1" class="usecase-sub-section-heading">
# <b>3.1 Cleaning the Pedestrian Count Data</b>
# </div>

# %% [markdown]
# <div class="usecase-body">
# The following checks are performed to evaluate the quality and structure of the pedestrian count dataset before it is used for analysis and machine learning.
# </div>

# %% [markdown]
# <div id="section-3-1-1" class="usecase-sub-sub-section-heading">
# <b>3.1.1 Data Quality and Summary Statistics Overview – Pedestrian Count Data</b>
# </div>

# %% [markdown]
# <div class="usecase-body">
# <p><b>Missing Data Check</b></p>
#
# <div class="usecase-body">
# Check the total number of missing values in each column using the <code>.isnull().sum()</code> method. This identifies whether any missing data exists and highlights which columns contain missing values.
# </div>
#
# <div class="usecase-body">
# <p><b>Statistical Description</b></p>
#
# <div class="usecase-body">
# Generate a statistical summary of the dataset using the <code>.describe()</code> method. This provides an overview of the data distribution and helps identify potential anomalies or unusual values.
# </div>
#
# <div class="usecase-body">
# <p><b>Data Structure Summary</b></p>
#
# <div class="usecase-body">
# Examine the structure of the dataset using the <code>.info()</code> method. This displays the number of observations, non-null values, data types, and memory usage, helping verify that the dataset has been imported correctly.
# </div>

# %%
# Remove unnecessary identifier and location columns from the pedestrian dataset
print("Check for missing information in each column")
print(pedestrian_counting.isnull().sum())
print("Statistical Description")
print(pedestrian_counting.describe())
print("Data Structure Summary")
print(pedestrian_counting.info())
# Out:
# Check for missing information in each column
# id                   0
# location_id          0
# sensing_date         0
# hourday              0
# direction_1          0
# direction_2          0
# pedestriancount      0
# sensor_name        149
# location           149
# latitude           149
# longitude          149
# dtype: int64
# Statistical Description
#                  id  location_id      hourday  direction_1  direction_2  \
# count  9.999000e+03  9999.000000  9999.000000  9999.000000   9999.00000
# mean   4.911968e+11    75.313131    11.721872   195.720872    198.40034
# std    5.459013e+11    54.677502     6.808555   308.324271    310.22068
# min    1.020250e+09     1.000000     0.000000     0.000000      0.00000
# 25%    6.382026e+10    30.000000     6.000000    17.000000     18.00000
# 50%    2.097202e+11    62.000000    12.000000    77.000000     76.00000
# 75%    7.518203e+11   124.000000    18.000000   234.000000    242.00000
# ...

# %% [markdown]
# <div class="usecase-body">
# <b>Missing Data Check</b>
#
# <div class="usecase-body">
# The results indicate that there are no missing values in any of the dataset columns. As a result, no missing value treatment or imputation is required before proceeding with the analysis. This is beneficial for the pedestrian flow analysis because all available observations can be retained without introducing estimated values or removing incomplete records.
# </div>
#
# <div class="usecase-body">
# <b>Statistical Description</b>
#
# <div class="usecase-body">
# The statistical summary provides an overview of the distribution and characteristics of the numerical variables within the dataset.
# </div>
#
# <div class="usecase-body">
# <b>Hour Day</b>
#
# <div class="usecase-body">
# The values range from <b>0 to 23</b>, confirming that the dataset contains pedestrian observations across all hours of the day. The mean (<b>11.7</b>) and median (<b>12</b>) are very similar, indicating that the hourly observations are distributed relatively evenly throughout the day. This is useful for the analysis because pedestrian activity can be examined across different periods of the day rather than being concentrated within a limited time window.
# </div>
#
# <div class="usecase-body">
# <b>Pedestrian Count</b>
#
# <div class="usecase-body">
# Pedestrian counts exhibit a wide range of values, indicating considerable variation in pedestrian activity and the potential presence of outliers. The mean (<b>384.36</b>) is substantially higher than the median (<b>166.00</b>), indicating that the distribution is positively (right) skewed. In practical terms, this suggests that most observations represent relatively low to moderate pedestrian activity, while a smaller number of observations contain substantially higher pedestrian counts. These periods of increased activity are particularly relevant when considering crowd management and planning requirements.
# </div>
#
# <div class="usecase-body">
# <b>Direction_1 and Direction_2</b>
#
# <div class="usecase-body">
# These variables represent the direction in which pedestrian counts were recorded, such as northbound or southbound. This provides additional context for understanding pedestrian movement by showing not only the level of pedestrian activity but also the direction in which people are travelling.
# </div>
#
# <div class="usecase-body">
# <b>Data Structure Summary</b>
#
# <div class="usecase-body">
# The <code>.info()</code> output provides an overview of the dataset structure, including the data type of each variable and the number of non-null values. This confirms that the features have been imported correctly and helps identify whether any data types require further preparation before the dataset is used for analysis and modelling.
# </div>

# %%
# Remove unnecessary identifier and location columns from the pedestrian dataset
pedestrian_counting.drop(columns=['id', 'sensor_name', 'location'], inplace=True)
pedestrian_counting.head()
# Out:
#    location_id sensing_date  hourday  direction_1  direction_2  \
# 0           67   2025-04-30       21           89          179
# 1           58   2025-12-27        2           28           50
# 2           35   2026-07-29       15          735          589
# 3            2   2025-08-17        5            5            5
# 4           20   2025-04-26       20          394          690
#
#    pedestriancount   latitude   longitude
# 0              268 -37.816888  144.965626
# 1               78 -37.816861  144.953581
# 2             1324 -37.820187  144.965085
# 3               10 -37.813807  144.965167
# 4             1084 -37.811729  144.968247

# %%
#updating sensing date data to uniform across all datasets 
pedestrian_counting['sensing_date']= pd.to_datetime(pedestrian_counting['sensing_date']) 
#create a new time col date_time, and combine sensing_date and hourday
pedestrian_counting['date_time'] = pedestrian_counting['sensing_date'] + pd.to_timedelta(pedestrian_counting['hourday'], unit= 'h') 
pedestrian_counting.head()
# Out:
#    location_id sensing_date  hourday  direction_1  direction_2  \
# 0           67   2025-04-30       21           89          179
# 1           58   2025-12-27        2           28           50
# 2           35   2026-07-29       15          735          589
# 3            2   2025-08-17        5            5            5
# 4           20   2025-04-26       20          394          690
#
#    pedestriancount   latitude   longitude           date_time
# 0              268 -37.816888  144.965626 2025-04-30 21:00:00
# 1               78 -37.816861  144.953581 2025-12-27 02:00:00
# 2             1324 -37.820187  144.965085 2026-07-29 15:00:00
# 3               10 -37.813807  144.965167 2025-08-17 05:00:00
# 4             1084 -37.811729  144.968247 2025-04-26 20:00:00

# %% [markdown]
# <div id="section-3-1-2" class="usecase-sub-sub-section-heading">
# <b>3.1.2 Visualising Pedestrian Count</b>
# </div>

# %% [markdown]
# <div class="usecase-body">
# A bar plot is used to visualise the total pedestrian count for each hour of the day. This visualisation is appropriate because hourly pedestrian counts represent discrete time periods, allowing the level of pedestrian activity at each hour to be directly compared. Identifying periods of high and low pedestrian activity provides insight into daily movement patterns across Melbourne and helps determine which time-based features may be important for predicting pedestrian flow.
# </div>

# %%
# Group by hour and sum pedestrian counts
hourly_counts = pedestrian_counting.groupby('hourday')['pedestriancount'].sum()

# Plot the grouped data
plt.figure(figsize=(12, 6))
hourly_counts.plot(kind='bar', color='#059669')

# Add titles and labels
plt.title('Total Pedestrian Count by Hour')
plt.xlabel('Hour of Day')
plt.ylabel('Total Pedestrian Count')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="usecase-body">
# The results show two prominent peaks in pedestrian activity at approximately <b>12:00</b> and <b>17:00</b>, representing the busiest periods observed across the day. These peaks may correspond with common periods of increased pedestrian movement, such as lunchtime and the end of the working day. This pattern demonstrates that pedestrian activity varies considerably by hour and supports the inclusion of time-related features when modelling and predicting pedestrian flow.
# </div>

# %% [markdown]
# <div id="section-3-2" class="usecase-sub-section-heading">
# <b>3.2 Cleaning the Weather Data</b>
# </div>

# %% [markdown]
# <div class="usecase-body">
# The weather dataset is cleaned and examined to ensure that its environmental measurements are suitable for analysis. This process checks data quality, removes unnecessary columns and prepares the weather features for merging with the pedestrian count data.
# </div>

# %% [markdown]
# <div class="usecase-body">
# The weather dataset is assessed to identify missing values, understand its structure, and generate summary statistics before further analysis. These checks help ensure the data is complete, consistent, and suitable for integration with the pedestrian count dataset.
# </div>
#
# <div class="usecase-body">
# <b>Missing Data Check</b>
#
# <div class="usecase-body">
# The <code>.isnull().sum()</code> method is used to identify missing values in each column. This helps determine whether any data cleaning or imputation is required before analysis.
# </div>
#
# <div class="usecase-body">
# <b>Summary Statistics</b>
#
# <div class="usecase-body">
# The <code>.describe()</code> method provides descriptive statistics for the numerical variables, allowing the distribution of the data to be examined and potential anomalies or outliers to be identified.
# </div>
#
# <div class="usecase-body">
# <b>Dataset Structure</b>
#
# <div class="usecase-body">
# The <code>.info()</code> method is used to display the dataset structure, including data types, non-null values and memory usage. This confirms that the variables have been imported correctly and are suitable for subsequent analysis.
# </div>

# %%
# Check the pedestrian dataset for missing values, summary statistics and data structure
print("Check for missing information in each column")
print(weather_stations_df .isnull().sum())
print("Statistical Description")
print(weather_stations_df .describe())
print("Data Structure Summary")
print(weather_stations_df .info())
# Out:
# Check for missing information in each column
# device_id                 0
# time                      0
# rtc                       0
# battery                   0
# solarpanel                0
# command                   0
# solar                     0
# precipitation             0
# strikes                   0
# windspeed                 0
# winddirection             0
# gustspeed                 0
# vapourpressure            0
# atmosphericpressure       0
# relativehumidity          0
# airtemp                   0
# lat_long               9999
# sensor_name            9999
# dtype: int64
# Statistical Description
#                 rtc      battery   solarpanel  command        solar  \
# count  9.999000e+03  9999.000000  9999.000000   9999.0  9999.000000
# mean   7.997212e+07     4.180395    10.614374      0.0   118.347735
# std    2.154711e+07     0.025457    10.134004      0.0   202.821304
# min    5.862781e+06     4.128000     0.000000      0.0     0.000000
# ...

# %% [markdown]
# <div id="section-3-2-1" class="usecase-sub-sub-section-heading">
# <b>3.2.1 Data Quality and Summary Statistics Overview – Weather Data</b>
# </div>

# %% [markdown]
# <div class="usecase-body">
# <b>Missing Data Check</b>
#
# <div class="usecase-body">
# The results indicate that there are no missing values in the weather dataset. Therefore, no missing value treatment or imputation is required. This allows all available weather observations to be retained when examining their relationship with pedestrian activity.
# </div>
#
# <div class="usecase-body">
# <b>Statistical Description</b>
#
# <div class="usecase-body">
# The statistical summary highlights several important characteristics of the weather variables and identifies features that may require further preparation before analysis.
# </div>
#
# <div class="usecase-body">
# <b>Precipitation</b>
#
# <div class="usecase-body">
# All recorded precipitation values are zero, meaning this feature provides no variation within the dataset. As a result, it cannot provide useful information for distinguishing between different levels of pedestrian activity and is a suitable candidate for removal.
# </div>
#
# <div class="usecase-body">
# <b>Solar</b>
#
# <div class="usecase-body">
# Solar values have a maximum of 1043 and show a noticeable difference between the mean and median, indicating a skewed distribution. Variation in solar conditions may still be relevant to pedestrian activity, as different levels of sunlight can influence outdoor movement and activity.
# </div>
#
# <div class="usecase-body">
# <b>Strikes (Lightning)</b>
#
# <div class="usecase-body">
# Lightning strikes occur very infrequently, with a mean of approximately 0.0048 and a maximum value of 9. This indicates that lightning events are rare within the dataset and may therefore provide limited information for predicting typical pedestrian activity.
# </div>
#
# <div class="usecase-body">
# <b>Windspeed, Gustspeed and Wind Direction</b>
#
# <div class="usecase-body">
# These variables contain extreme values of -9999.0, which are inconsistent with realistic weather observations and indicate invalid or placeholder values. These values require further handling before analysis, as retaining them could distort the relationship between wind conditions and pedestrian activity and negatively affect model performance.
# </div>
#
# <div class="usecase-body">
# <b>Relative Humidity</b>
#
# <div class="usecase-body">
# Relative humidity ranges from 18 to 100, providing variation across different humidity conditions. This variation allows the analysis to investigate whether changes in humidity are associated with changes in pedestrian activity.
# </div>
#
# <div class="usecase-body">
# <b>Air Temperature</b>
#
# <div class="usecase-body">
# Air temperature ranges from approximately 1°C to 39.2°C, representing a broad range of Melbourne weather conditions. This is particularly relevant to the use case because it allows pedestrian activity to be compared across colder, moderate and hotter temperatures to determine whether temperature influences pedestrian movement.
# </div>
#
# <div class="usecase-body">
# <b>Data Structure Summary</b>
#
# <div class="usecase-body">
# The dataset structure identifies the data type of each feature and highlights variables requiring additional preparation. The time variable needs to be converted to datetime format to support time-based analysis and alignment with the pedestrian count observations. The location information also needs to be separated into latitude and longitude values so that it can be consistently matched and analysed alongside the other datasets.
# </div>

# %% [markdown]
# <div id="section-3-2-2" class="usecase-sub-sub-section-heading">
# <b>3.2.2 Dropping Unnecessary Columns</b>
# </div>

# %% [markdown]
# <div class="usecase-body">
# Several columns within the weather dataset are removed because they contain redundant identifiers or information that is no longer required for the analysis. Removing these unnecessary features simplifies the dataset and ensures that subsequent analysis focuses on variables that may contribute useful information to pedestrian flow prediction.
# </div>

# %% [markdown]
# <div class="usecase-body">
# The following columns are removed because they are no longer required for the analysis or do not provide useful predictive information:
# </div>
#
# <ul class="usecase-list">
# <li><b><code>dev_id</code></b>: A unique identifier for the weather station device. This identifier does not describe weather conditions and therefore does not provide useful information for predicting pedestrian activity.</li>
# <li><b><code>sensor_name</code></b>: Another identifier for the weather sensor. As the sensor is already represented by the relevant weather observations, this field does not provide additional predictive information.</li>
# <li><b><code>lat_long</code></b>: The location information has already been separated into latitude and longitude columns, making the original combined location field redundant.</li>
# </ul>

# %%
# Remove unnecessary weather columns and create a datetime field
weather_stations_df.drop(columns=['device_id', 'sensor_name', 'lat_long'], inplace=True) 
weather_stations_df['date_time'] = pd.to_datetime(weather_stations_df['time'])
weather_stations_df.head()
# Out:
#                         time        rtc  battery  solarpanel  command  solar  \
# 0  2025-08-16T20:40:34+00:00  121366929    4.140       1.458        0      0
# 1  2025-08-16T20:10:00+00:00  121365095    4.140       0.225        0      0
# 2  2025-08-16T21:10:53+00:00  121368748    4.137      19.340        0      3
# 3  2025-08-17T02:26:30+00:00  121387685    4.209      22.064        0    175
# 4  2025-08-16T11:56:26+00:00  121335482    4.169       0.249        0      0
#
#    precipitation  strikes  windspeed  winddirection  gustspeed  \
# 0              0        0       1.38          174.9       2.11
# 1              0        0       1.52          171.7       2.44
# 2              0        0       1.55          170.9       2.32
# 3              0        0       0.89          152.1       2.80
# 4              0        0       0.59           53.8       1.84
#
#    vapourpressure  atmosphericpressure  relativehumidity  airtemp  \
# ...

# %% [markdown]
# <div class="usecase-body">
# The unnecessary identifier and location columns have now been removed from the weather dataset, reducing redundant information while retaining the environmental variables required for analysis. The <code>time</code> column has also been converted to datetime format, allowing weather observations to be consistently organised and aligned with the pedestrian count data during subsequent time-based analysis and dataset integration.
# </div>

# %% [markdown]
# <div id="section-3-2-3" class="usecase-sub-sub-section-heading">
# <b>3.2.3 Visualising Weather Station Data</b>
# </div>
#
# <div class="usecase-body">
# A line plot is used to visualise air temperature over time because the observations are recorded chronologically, allowing changes and trends in temperature to be clearly identified across the dataset. This visualisation makes it easier to identify seasonal patterns, temperature fluctuations and periods where fewer observations have been recorded. Understanding these patterns is important for the pedestrian flow analysis, as temperature conditions may influence the number of people moving through Melbourne at different times of the year.
# </div>

# %%
# change time format to be updated
weather_stations_df['time'] = pd.to_datetime(weather_stations_df['time'])

# groupby airtemp by time with average temperature
temperature_time = weather_stations_df.groupby('time')['airtemp'].mean()

# Visualing a line graph 
plt.figure(figsize=(12, 6))
temperature_time.plot(color='#059669')

plt.title('Air Temperature Over Time')
plt.xlabel('Time')
plt.ylabel('Air Temperature (°C)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="usecase-body">
# The time series indicates that there are noticeably fewer observations prior to <b>January 2024</b>, suggesting that data collection was less frequent during this period. Despite the lower number of observations, the overall trend remains consistent with the more recent data, showing higher temperatures during the summer months and lower temperatures during winter. This indicates that the dataset captures the expected seasonal variation in air temperature.
# </div>

# %% [markdown]
# <div id="section-3-2-4" class="usecase-sub-sub-section-heading">
# <b>3.2.4 Uniform Date-Time Preparation</b>
# </div>

# %% [markdown]
# <div class="usecase-body">
# The date and time fields are converted into a consistent datetime format so that observations from the weather and pedestrian datasets can be accurately aligned and merged. Consistent datetime values are necessary to ensure that weather conditions are matched with pedestrian counts recorded during the same periods.
#
# A line plot is then used to visualise atmospheric pressure over time. As atmospheric pressure is recorded chronologically, a line plot allows changes, fluctuations and longer-term patterns to be observed across the dataset. Examining the consistency and variation of atmospheric pressure also helps determine whether this weather feature contains meaningful information that may contribute to the analysis of pedestrian activity.
# </div>

# %%
# Convert 'time' to datetime format
weather_stations_df['time'] = pd.to_datetime(weather_stations_df['time'])

# groupby time 
temperature_time = weather_stations_df.groupby('time')['atmosphericpressure'].mean()

# Plotting
plt.figure(figsize=(12, 6))
temperature_time.plot(color='#9333EA')

plt.title('Atmospheric Pressure Over Time')
plt.xlabel('Time')
plt.ylabel('atmosphericpressure (Kpa)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="usecase-body">
# The line plot shows that atmospheric pressure generally remains within a relatively narrow range of approximately 99–103 kPa, although occasional values fall outside this range. There are noticeably fewer observations prior to January 2024, indicating that atmospheric pressure data was recorded less frequently during this earlier period.
#
# Unlike air temperature, atmospheric pressure does not display an obvious seasonal pattern and instead fluctuates throughout the observation period. This suggests that atmospheric pressure varies independently across time and may provide additional environmental information when investigating pedestrian activity. However, the visualisation alone does not establish whether these changes are associated with pedestrian counts, so this relationship will need to be examined further when the weather and pedestrian datasets are analysed together.
# </div>

# %% [markdown]
# <div id="section-3-2-5" class="usecase-sub-sub-section-heading">
# <b>3.2.5 Visualising Weather Station Features Against Pedestrian Count</b>
# </div>
#
# <div class="usecase-body">
# The key weather features are compared against pedestrian count to investigate whether changes in environmental conditions are associated with changes in pedestrian activity. The pedestrian and weather datasets are first aligned by date and time and merged into the <code>combined_df</code> dataset so that weather observations can be compared with pedestrian counts recorded during the same periods.
#
# Scatterplots are used because both the weather features and pedestrian count are numerical variables. This allows the distribution, direction and shape of their relationships to be visually examined, including whether relationships appear linear or non-linear. Identifying these patterns helps determine which weather features may provide useful information for predicting pedestrian flow and supporting planning for changing pedestrian activity across Melbourne.
# </div>

# %%
# Create the hourly pedestrian dataset used in the original use case
pedestrian_hourly = (
    pedestrian_counting
    .groupby('date_time')['hourday']
    .sum()
    .reset_index()
)

pedestrian_hourly.columns = ['date_time', 'pedestrian_count']

# %%
# Make both datetime columns compatible for merging
pedestrian_hourly['date_time'] = (
    pedestrian_hourly['date_time']
    .dt.tz_localize(None)
    .dt.floor('h')
)

weather_stations_df['date_time'] = (
    weather_stations_df['date_time']
    .dt.tz_localize(None)
    .dt.floor('h')
)

# %%
# Merge the hourly pedestrian and weather datasets
combined_df = pd.merge(
    pedestrian_hourly,
    weather_stations_df,
    on='date_time',
    how='inner'
)

# Plot air temperature against pedestrian count
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=combined_df,
    x='airtemp',
    y='pedestrian_count',
    alpha=0.5,
    color='#059669'
)

plt.title("Air Temperature v. Pedestrian Count")
plt.xlabel("Air Temperature (°C)")
plt.ylabel("Pedestrian Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="usecase-body">
# Most observations are concentrated between approximately 10°C and 25°C, with pedestrian counts generally clustered at lower values and a smaller number of observations showing substantially higher activity. The highest pedestrian counts also occur predominantly within this moderate temperature range, while temperatures below approximately 5°C and above 30°C are generally associated with lower pedestrian activity.
#
# The relationship does not appear strongly linear and may instead indicate that pedestrian activity is greater under moderate temperature conditions than at temperature extremes. This suggests that air temperature may provide useful information for predicting pedestrian flow, particularly when combined with other weather and time-based features. For city planners and emergency services, understanding how pedestrian activity changes under different temperature conditions may assist in anticipating periods where greater pedestrian movement and crowd-management requirements are more likely.
# </div>

# %%
# Scatterplot atmospheric pressue vs pedestrian count
plt.figure(figsize=(10, 6))
sns.scatterplot(data=combined_df, x='atmosphericpressure', y='pedestrian_count', alpha=0.5, color = '#9333EA')
plt.title("Atmospheric pressure vs Pedestrian Count")
plt.xlabel("Atmospheric pressure (kPa)")
plt.ylabel("Pedestrian Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="usecase-body">
# Atmospheric pressure ranges primarily between approximately 99 and 103 kPa, while pedestrian counts vary considerably throughout this range. The scatterplot does not show a clear upward or downward trend, indicating that atmospheric pressure alone does not appear to have a strong relationship with pedestrian activity.
#
# This suggests that changes in atmospheric pressure are unlikely to be a major independent driver of pedestrian movement. However, the feature may still provide useful information when combined with other weather, time and environmental variables within the predictive model. For the pedestrian-flow scenario, this indicates that atmospheric pressure should not be relied upon by itself when anticipating periods of high pedestrian activity, but its contribution can be assessed alongside stronger predictive features.
# </div>

# %%
# Scatterplot windspeed vs pedestrian Count
combined_df = combined_df[combined_df['windspeed'] > -100]

plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=combined_df,
    x='windspeed',
    y='pedestrian_count',
    alpha=0.5,
    color='#F97316'
)
plt.title("Wind speed vs. Pedestrian Count")
plt.xlabel("Wind (m/s)")
plt.ylabel("Pedestrian Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="usecase-body">
# The scatterplot shows that most observations occur at wind speeds between approximately 0.5 m/s and 1.5 m/s, with the highest pedestrian counts also occurring predominantly within this range. As wind speed increases, particularly beyond approximately 1.5 m/s, high pedestrian counts become less frequent and pedestrian activity is generally concentrated at lower values.
#
# This indicates a negative relationship between wind speed and pedestrian activity, suggesting that higher wind speeds may be associated with reduced pedestrian movement. However, wind speed alone does not explain the considerable variation in pedestrian counts at lower wind speeds, indicating that other factors also influence pedestrian activity. For the pedestrian-flow prediction model, wind speed may therefore provide useful information when combined with other weather and time-based features. This can help city planners and emergency services account for changing weather conditions when anticipating periods of higher or lower pedestrian activity.
# </div>

# %%
#Scatterplot vapourpressure vs pedestrian count 
plt.figure(figsize=(10, 6))
sns.scatterplot(data=combined_df, x='vapourpressure', y='pedestrian_count', alpha=0.5, color = '#2563EB')
plt.title("Vapour Pressure vs. Pedestrian Count")
plt.xlabel("Vapour Pressure")
plt.ylabel("Pedestrian Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="usecase-body">
# The scatterplot indicates that there is no strong relationship between vapour pressure and pedestrian count. Most observations occur between approximately 0.8 and 1.8 vapour pressure, with pedestrian counts varying considerably throughout this range. Although higher pedestrian counts become less frequent as vapour pressure increases, the overall relationship appears weak.
#
# This suggests that vapour pressure alone is unlikely to be a strong predictor of pedestrian activity. However, it may still contribute useful information when combined with other weather and time-based features within the predictive model. For city planners and emergency services, this means vapour pressure should not be relied upon independently when anticipating pedestrian movement, but it may form part of the broader environmental conditions used to improve pedestrian-flow predictions.
# </div>

# %% [markdown]
# <div id="section-3-2-6" class="usecase-sub-sub-section-heading">
# <b>3.2.6 Correlation Matrix</b>
# </div>

# %% [markdown]
# <div class="usecase-body">
# A correlation matrix is used to examine the strength and direction of linear relationships between the numerical features in the dataset. This is useful for identifying which weather variables have the strongest relationships with pedestrian count and may therefore provide useful information for prediction. It also highlights relationships between the predictor variables themselves, which can help identify highly correlated features.
# </div>
#
# <div class="usecase-body">
# <b>Create a Combined Dataset</b>
#
# <div class="usecase-body">
# The relevant pedestrian and weather features are combined into a single dataset so that the relationships between pedestrian count and the environmental variables can be analysed together.
# </div>
#
# <div class="usecase-body">
# <b>Generate and Visualise the Correlation Matrix</b>
#
# <div class="usecase-body">
# A correlation matrix is calculated and displayed as a heatmap. A heatmap is appropriate because it provides a clear visual comparison of the strength and direction of multiple relationships simultaneously. This makes it easier to identify which weather features have stronger positive or negative relationships with pedestrian activity and which features are strongly related to each other.
# </div>

# %%
# Select the numerical features required for correlation analysis
combined_data = combined_df.drop(
    columns=['date_time', 'time', 'command', 'precipitation'],
    errors='ignore'
)

# %%
# Coreelation matrix strucutre 
c_matrix = combined_data.corr()

# visualisation of the matrix 
plt.figure(figsize=(10, 6))
sns.heatmap(c_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix of Weather Features and Pedestrian Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="usecase-body">
# Correlation coefficients range from -1 to 1, where values closer to 1 indicate a stronger positive linear relationship and values closer to -1 indicate a stronger negative linear relationship. Values close to 0 indicate that little linear relationship exists between the two variables.
#
# The results show that no individual weather feature has a particularly strong linear relationship with pedestrian count. Battery has the strongest relationship at approximately -0.49, although this is a sensor-related measurement rather than a meaningful environmental factor for explaining pedestrian behaviour. Among the weather variables, windspeed and gustspeed both have correlations of approximately -0.32 with pedestrian count, suggesting that higher wind conditions are moderately associated with lower pedestrian activity. Relative humidity has a positive correlation of approximately 0.29, while air temperature has a weaker negative correlation of approximately -0.22.
#
# The matrix also identifies strong relationships between some predictor variables. For example, vapour pressure and air temperature have a correlation of approximately 0.77, while windspeed and gustspeed have a correlation of approximately 0.75. This indicates that some weather features contain overlapping information, which should be considered when interpreting their contribution to the predictive models.
#
# For the pedestrian-flow scenario, these results indicate that pedestrian activity cannot be adequately explained by a single weather variable. Instead, pedestrian movement is likely influenced by a combination of environmental and time-based conditions. This supports the use of multiple features within the machine learning models to provide city planners and emergency services with more useful predictions of pedestrian activity.
# </div>

# %% [markdown]
# <div id="section-3-4" class="usecase-sub-section-heading">
# <b>3.4 Geospatial Visualisation</b>
# </div>
#
# <div class="usecase-body">
# Geospatial visualisation is used to explore the spatial relationship between Melbourne's pedestrian counting sensors and event venue locations. Visualising both datasets on an interactive map allows patterns, proximity and coverage to be identified before calculating distances and merging the datasets for further analysis.
# </div>

# %% [markdown]
# <div id="section-3-4-1" class="usecase-sub-sub-section-heading">
# <b>3.4.1 Mapping Pedestrian Sensors and Event Venues</b>
# </div>

# %% [markdown]
# <div class="usecase-body">
# An interactive Folium map is used to visualise the spatial distribution of pedestrian sensors and event venues across central Melbourne. A geospatial map is appropriate for this analysis because it allows the locations of both datasets to be compared directly, making it easier to identify areas where venues and pedestrian sensors are located close to one another. Understanding this spatial relationship is important because nearby pedestrian sensors can provide an indication of pedestrian activity surrounding event venues and support the subsequent calculation of distances between venues and sensors.
# </div>

# %%
import folium

# Centre the map on Melbourne
m = folium.Map(
    location=[-37.8136, 144.9631],
    zoom_start=14
)

# Add venue location markers using blue
for _, row in venue_location.iterrows():
    if pd.notnull(row['latitude']) and pd.notnull(row['longitude']):
        folium.CircleMarker(
            location=[row['latitude'], row['longitude']],
            radius=3,
            color='#2563EB',
            fill=True,
            fill_color='#2563EB',
            fill_opacity=0.8
        ).add_to(m)

# Add pedestrian counter markers using purple
for _, row in pedestrian_counting.iterrows():
    if pd.notnull(row['latitude']) and pd.notnull(row['longitude']):
        folium.CircleMarker(
            location=[row['latitude'], row['longitude']],
            radius=3,
            color='#9333EA',
            fill=True,
            fill_color='#9333EA',
            fill_opacity=0.8
        ).add_to(m)

# Add a legend matching the marker colours
legend_html = """
<div style="
    position: fixed;
    bottom: 50px;
    left: 50px;
    width: 190px;
    background-color: white;
    border: 2px solid grey;
    z-index: 9999;
    font-size: 14px;
    padding: 10px;
">
    <b>Map Legend</b><br>
    <span style="color:#2563EB;">●</span> Event Venue<br>
    <span style="color:#9333EA;">●</span> Pedestrian Counter
</div>
"""

m.get_root().html.add_child(folium.Element(legend_html))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# <div class="usecase-body">
# The map shows that both event venues and pedestrian sensors are distributed throughout central Melbourne, with particularly dense concentrations around the CBD and surrounding inner-city areas. Many event venues are located close to existing pedestrian sensors, although the level of sensor coverage varies across different locations.
#
# This spatial relationship allows nearby pedestrian sensor data to be associated with event venues, providing a practical way to estimate pedestrian activity in areas where direct venue attendance data is unavailable. For city planners and emergency services, understanding where venues are located in relation to pedestrian monitoring infrastructure can help identify areas where pedestrian activity can be more reliably estimated and where additional monitoring may be required.
# </div>

# %% [markdown]
# <div id="section-3-5" class="usecase-sub-section-heading">
# <b>3.5 Calculating Distance from Venues to Pedestrian Sensors</b>
# </div>
# <div class="usecase-body">
# To associate each event venue with nearby pedestrian monitoring infrastructure, the geographical distance between each venue and each unique pedestrian sensor location is calculated. Only unique sensor locations are used because the pedestrian dataset contains repeated observations from the same sensors across different time periods. Removing these duplicate locations prevents the same geographical distance from being calculated repeatedly and significantly improves execution time.
#
# The Haversine formula is applied using vectorised operations to calculate distances in metres between venue and sensor coordinates. These distances are then used in the following section to identify the pedestrian sensor located closest to each venue.
# </div>

# %%
import numpy as np

# Keep only venues with valid coordinates
venues = venue_location[
    [
        'prop_id', 'full_name', 'latitude', 'longitude',
        'sport', 'wedding', 'bookable', 'no_smoking',
        'event', 'training', 'dog_prohib'
    ]
].dropna(subset=['latitude', 'longitude']).copy()

# Keep only unique pedestrian sensor locations
sensors = (
    pedestrian_counting[
        ['location_id', 'latitude', 'longitude']
    ]
    .dropna(subset=['latitude', 'longitude'])
    .drop_duplicates(subset=['location_id', 'latitude', 'longitude'])
    .copy()
)

# Rename coordinate columns before combining the datasets
venues = venues.rename(
    columns={
        'latitude': 'venue_latitude',
        'longitude': 'venue_longitude'
    }
)

sensors = sensors.rename(
    columns={
        'latitude': 'sensor_latitude',
        'longitude': 'sensor_longitude'
    }
)

# Create every venue-to-sensor combination
venue_sensor_distance = venues.merge(
    sensors,
    how='cross'
)

# Convert coordinates to radians
venue_lat = np.radians(venue_sensor_distance['venue_latitude'])
venue_lon = np.radians(venue_sensor_distance['venue_longitude'])
sensor_lat = np.radians(venue_sensor_distance['sensor_latitude'])
sensor_lon = np.radians(venue_sensor_distance['sensor_longitude'])

# Calculate distance using the Haversine formula
earth_radius = 6371000  # metres

lat_diff = sensor_lat - venue_lat
lon_diff = sensor_lon - venue_lon

a = (
    np.sin(lat_diff / 2) ** 2
    + np.cos(venue_lat)
    * np.cos(sensor_lat)
    * np.sin(lon_diff / 2) ** 2
)

venue_sensor_distance['distance_venue'] = (
    2 * earth_radius * np.arcsin(np.sqrt(a))
)

# Rename columns to match the existing use case structure
venue_sensor_distance = venue_sensor_distance.rename(
    columns={
        'prop_id': 'venue_id',
        'full_name': 'venue_name',
        'location_id': 'sensor_id'
    }
)

# Keep the required columns
venue_sensor_distance = venue_sensor_distance[
    [
        'venue_id',
        'venue_name',
        'sensor_id',
        'distance_venue',
        'sport',
        'wedding',
        'bookable',
        'no_smoking',
        'event',
        'training',
        'dog_prohib'
    ]
]

# Preview the calculated distances
venue_sensor_distance.head()
# Out:
#   venue_id                             venue_name  sensor_id  distance_venue  \
# 0        0  Other Park Locations:  Weedon Reserve         67     2050.405226
# 1        0  Other Park Locations:  Weedon Reserve         58     3108.413238
# 2        0  Other Park Locations:  Weedon Reserve         35     2125.079364
# 3        0  Other Park Locations:  Weedon Reserve          2     2122.910586
# 4        0  Other Park Locations:  Weedon Reserve         20     1916.500609
#
#   sport wedding bookable no_smoking event training dog_prohib
# 0  None       N        Y          N     Y        N          N
# 1  None       N        Y          N     Y        N          N
# 2  None       N        Y          N     Y        N          N
# 3  None       N        Y          N     Y        N          N
# 4  None       N        Y          N     Y        N          N

# %% [markdown]
# <div id="section-3-6" class="usecase-sub-section-heading">
# <b>3.6 Nearest Sensor Calculation</b>
# </div>
#
# <div class="usecase-body">
# The calculated distances are grouped by venue, and <code>idxmin()</code> is used to identify the pedestrian sensor closest to each venue. Linking each venue to its nearest sensor allows the most geographically relevant pedestrian count data to be used in the subsequent analysis and modelling.
# </div>

# %%
# Select the row with the minimum distance for each venue_id
nearest_sensors = venue_sensor_distance.loc[venue_sensor_distance.groupby('venue_id')['distance_venue'].idxmin()].reset_index(drop=True)

nearest_sensors.head()
# Out:
#   venue_id                                         venue_name  sensor_id  \
# 0        0  Promotional Spaces:  Melbourne Central Station...         66
# 1   100385            Alexandra Gardens:  AG - Henley Landing        136
# 2   100514  Other Park Locations:  North Melbourne Recreat...        180
# 3   100894         Other Park Locations:  Bayswater Road Park         85
# 4   101101     Alexandra Gardens:  AG - Lawn2/Peppercorn Lawn         29
#
#    distance_venue sport wedding bookable no_smoking event training dog_prohib
# 0       62.580187  None       N        Y          N     N        N          N
# 1      347.930212  None       N        Y          N     Y        N          N
# 2      696.428689  None       N        Y          N     Y        N          N
# 3      527.701179  None       N        Y          Y     Y        N          N
# 4       60.035052  None       N        Y          N     Y        Y          N

# %% [markdown]
# <div id="section-3-7" class="usecase-sub-section-heading">
# <b>3.7 Merging the Datasets</b>
# </div>
#
# <div class="usecase-body">
# The final modelling dataset is created by combining the pedestrian count, nearest sensor and weather datasets. First, the pedestrian count data is merged with the nearest sensor data by matching <code>location_id</code> with <code>sensor_id</code> using an inner join. This associates each venue with pedestrian observations from its nearest sensor.
#
# The resulting dataset is then merged with the weather station data using <code>date_time</code> as the common field. This combines the pedestrian, venue, spatial and environmental features into a single dataset that can be prepared for predictive modelling.
# </div>

# %%
# Check the original pedestrian and weather date ranges
print("Pedestrian range:")
print(
    pedestrian_counting['date_time'].min(),
    "to",
    pedestrian_counting['date_time'].max()
)

print("\nWeather range:")
print(
    weather_stations_df['date_time'].min(),
    "to",
    weather_stations_df['date_time'].max()
)
# Out:
# Pedestrian range:
# 2024-08-19 01:00:00 to 2026-08-18 02:00:00
#
# Weather range:
# 2021-12-19 00:00:00 to 2025-08-19 05:00:00

# %%
# Convert pedestrian timestamps to hourly datetime values
pedestrian_counting['date_time'] = (
    pd.to_datetime(pedestrian_counting['date_time'])
      .dt.floor('h')
)

# Convert weather timestamps to timezone-naive hourly datetime values
weather_stations_df['date_time'] = (
    pd.to_datetime(weather_stations_df['date_time'])
      .dt.tz_localize(None)
      .dt.floor('h')
)

# Merge pedestrian data with the nearest sensor information
model_df = pd.merge(
    pedestrian_counting,
    nearest_sensors,
    left_on='location_id',
    right_on='sensor_id',
    how='inner'
)

# Merge the combined dataset with the weather data
model_df = pd.merge(
    model_df,
    weather_stations_df,
    on='date_time',
    how='inner'
)

# Preview the merged dataset
model_df.head()
# Out:
#    location_id sensing_date  hourday  direction_1  direction_2  \
# 0           85   2024-11-21       11          107           80
# 1           85   2024-11-21       11          107           80
# 2           85   2024-11-21       11          107           80
# 3           85   2024-11-21       11          107           80
# 4           85   2024-11-21       11          107           80
#
#    pedestriancount   latitude   longitude           date_time venue_id  ...  \
# 0              187 -37.794324  144.929734 2024-11-21 11:00:00   100894  ...
# 1              187 -37.794324  144.929734 2024-11-21 11:00:00   102249  ...
# 2              187 -37.794324  144.929734 2024-11-21 11:00:00   102986  ...
# 3              187 -37.794324  144.929734 2024-11-21 11:00:00   103363  ...
# 4              187 -37.794324  144.929734 2024-11-21 11:00:00   105220  ...
#
#   solar  precipitation  strikes windspeed winddirection gustspeed  \
# ...

# %% [markdown]
# <div id="section-3-8" class="usecase-sub-section-heading">
# <b>3.8 Preparing the Final Modelling Dataset</b>
# </div>
#
# <div class="usecase-body">
# The individual datasets have already undergone their required cleaning earlier in the workflow. At this stage, the merged dataset is prepared specifically for machine learning by removing fields that were useful for data collection, merging, identification or exploratory analysis but are not required as predictive features.
#
# The directional pedestrian counts (<code>direction_1</code> and <code>direction_2</code>) are removed because the model predicts the total <code>pedestriancount</code>, and retaining components of that total could provide the model with information that is too directly related to the target. Weather-station operational fields such as <code>rtc</code>, <code>solarpanel</code> and <code>command</code> describe the operation of the sensor rather than environmental conditions relevant to pedestrian movement. <code>precipitation</code> is removed because it contains no variation in the available data, while <code>strikes</code> occurs very infrequently and therefore provides limited information for modelling typical pedestrian activity.
#
# The original <code>time</code> field is no longer required because a consistent <code>date_time</code> field has already been created for temporal alignment. <code>sensor_id</code> and <code>venue_name</code> are also removed because they are identifiers or descriptive labels rather than numerical characteristics intended to explain pedestrian activity. This final preparation leaves the dataset ready for feature engineering and model development.
# </div>

# %%
# Remove fields that are not required for predictive modelling
model_df.drop(columns=[
    'direction_1',
    'direction_2',
    'rtc',
    'solarpanel',
    'command',
    'precipitation',
    'strikes',
    'time',
    'sensor_id',
    'venue_name'
], errors='ignore', inplace=True)

model_df.head()
# Out:
#    location_id sensing_date  hourday  pedestriancount   latitude   longitude  \
# 0           85   2024-11-21       11              187 -37.794324  144.929734
# 1           85   2024-11-21       11              187 -37.794324  144.929734
# 2           85   2024-11-21       11              187 -37.794324  144.929734
# 3           85   2024-11-21       11              187 -37.794324  144.929734
# 4           85   2024-11-21       11              187 -37.794324  144.929734
#
#             date_time venue_id  distance_venue sport  ... dog_prohib battery  \
# 0 2024-11-21 11:00:00   100894      527.701179  None  ...          N   4.175
# 1 2024-11-21 11:00:00   102249     1235.645532  None  ...          N   4.175
# 2 2024-11-21 11:00:00   102986     1675.995900  None  ...          N   4.175
# 3 2024-11-21 11:00:00   103363      617.578460  None  ...          N   4.175
# 4 2024-11-21 11:00:00   105220      594.933143     Y  ...          N   4.175
#
# ...

# %% [markdown]
# <div id="section-3-9" class="usecase-sub-section-heading">
# <b>3.9 Incorporating Day of the Week</b>
# </div>
#
# <div class="usecase-body">
# Given the relationship between time and pedestrian activity identified earlier in the analysis, a <code>day_of_week</code> feature is added to represent the day associated with each observation. Including this feature allows the machine learning models to learn potential differences in pedestrian activity across different days of the week, which may help improve predictive performance.
# </div>

# %%
# Create a numerical day-of-week feature from the sensing date
model_df['day_of_week'] = model_df['sensing_date'].dt.dayofweek

# %%
# Preview the final modelling dataset
model_df.head()
# Out:
#    location_id sensing_date  hourday  pedestriancount   latitude   longitude  \
# 0           85   2024-11-21       11              187 -37.794324  144.929734
# 1           85   2024-11-21       11              187 -37.794324  144.929734
# 2           85   2024-11-21       11              187 -37.794324  144.929734
# 3           85   2024-11-21       11              187 -37.794324  144.929734
# 4           85   2024-11-21       11              187 -37.794324  144.929734
#
#             date_time venue_id  distance_venue sport  ... battery solar  \
# 0 2024-11-21 11:00:00   100894      527.701179  None  ...   4.175     0
# 1 2024-11-21 11:00:00   102249     1235.645532  None  ...   4.175     0
# 2 2024-11-21 11:00:00   102986     1675.995900  None  ...   4.175     0
# 3 2024-11-21 11:00:00   103363      617.578460  None  ...   4.175     0
# 4 2024-11-21 11:00:00   105220      594.933143     Y  ...   4.175     0
#
# ...

# %% [markdown]
# <div id="section-4" class="usecase-section-heading">
# <b>4. Machine Learning Model</b>
# </div>
#
# <div class="usecase-body">
# After the datasets have been unified and the relevant features prepared, machine learning models are applied to predict pedestrian activity. Multiple regression models are developed and evaluated to compare their predictive performance and determine how effectively the available features can be used to estimate pedestrian count.
# </div>

# %% [markdown]
# <div id="section-4-1" class="usecase-sub-section-heading">
# <b>4.1 Feature Selection</b>
# </div>
# <div class="usecase-body">
# The final features are selected to provide the machine learning models with information that may help explain variations in pedestrian activity. These features include weather conditions, the distance between venues and pedestrian sensors, venue characteristics, and the day of the week. Together, they represent environmental, spatial and temporal factors that may influence pedestrian movement.
#
# The target variable is <code>pedestriancount</code>, meaning that the models will learn from the selected features to predict the number of pedestrians recorded. Developing accurate pedestrian-count predictions can help city planners and emergency services anticipate periods of increased pedestrian activity and support decisions relating to crowd management and resource allocation.
#
# Categorical venue characteristics are converted into numerical values so they can be processed by the machine learning models, while missing numerical values are replaced using the median of each feature to ensure that incomplete observations do not prevent model training.
# </div>

# %%
from sklearn.model_selection import train_test_split
import sklearn.preprocessing as preproc
from sklearn.ensemble import RandomForestRegressor

# Features used to train the machine learning models
features = [
    'distance_venue',
    'sport',
    'wedding',
    'bookable',
    'no_smoking',
    'event',
    'training',
    'dog_prohib',
    'battery',
    'windspeed',
    'winddirection',
    'gustspeed',
    'vapourpressure',
    'atmosphericpressure',
    'relativehumidity',
    'airtemp',
    'day_of_week'
]

# Create the feature dataset
X = model_df[features].copy()

# Select the target variable
y = model_df['pedestriancount']

# Convert venue yes/no values to numeric values
yes_no_columns = [
    'sport',
    'wedding',
    'bookable',
    'no_smoking',
    'event',
    'training',
    'dog_prohib'
]

for column in yes_no_columns:
    X[column] = X[column].map({'Y': 1, 'N': 0})

# Convert any remaining categorical values into numeric features
X = pd.get_dummies(X, dtype=int)

# Replace missing numerical values with the median of each feature
X = X.fillna(X.median(numeric_only=True))

# Preview the prepared feature dataset
X.head()
# Out:
#    distance_venue  sport  wedding  bookable  no_smoking  event  training  \
# 0      527.701179    0.0        0         1           1      1         0
# 1     1235.645532    0.0        0         1           0      1         0
# 2     1675.995900    0.0        0         1           0      1         0
# 3      617.578460    0.0        0         1           0      1         0
# 4      594.933143    1.0        0         1           0      1         0
#
#    dog_prohib  battery  windspeed  winddirection  gustspeed  vapourpressure  \
# 0           0    4.175       0.81          134.0       2.01            1.83
# 1           0    4.175       0.81          134.0       2.01            1.83
# 2           0    4.175       0.81          134.0       2.01            1.83
# 3           0    4.175       0.81          134.0       2.01            1.83
# 4           0    4.175       0.81          134.0       2.01            1.83
#
#    atmosphericpressure  relativehumidity  airtemp  day_of_week
# ...

# %% [markdown]
# <div id="section-4-2" class="usecase-sub-section-heading">
# <b>4.2 Polynomial Features</b>
# </div>
#
# <div class="usecase-body">
# Pairwise interaction features are generated to examine whether combinations of predictor variables provide information that is not captured when each feature is considered independently. For example, pedestrian activity may respond differently to temperature under high-wind conditions than under calm conditions, meaning the combined effect of two features may be more informative than either feature alone.
#
# Polynomial interaction features allow the models to represent these more complex relationships and test whether they improve pedestrian-count predictions. This is relevant to the scenario because pedestrian movement is likely influenced by several environmental, temporal and venue-related conditions acting together rather than by a single factor in isolation.
# </div>

# %%
# pairwise interaction features
X2 = preproc.PolynomialFeatures(degree=2,include_bias=False).fit_transform(X)
# Output the shape of the transformed features
print(X2.shape)
# Out:
# (1342, 170)

# %% [markdown]
# <div class="usecase-body">
# The polynomial transformation increases the feature set from 17 original features to 170 features by introducing pairwise interactions and squared terms. This provides the models with substantially more information about how combinations of environmental, temporal and venue-related factors may relate to pedestrian activity.
#
# The increased number of features allows more complex relationships to be represented, which may improve pedestrian-count predictions if these interactions contain useful predictive information. However, the larger feature set also increases model complexity and does not guarantee improved performance. The original and interaction feature sets will therefore both be evaluated to determine whether the additional complexity produces more accurate and useful predictions for the pedestrian-flow scenario.
# </div>

# %% [markdown]
# <div id="section-4-3" class="usecase-sub-section-heading">
# <b>4.3 Train-Test Split</b>
# </div>
#
# <div class="usecase-body">
# The modelling dataset is divided into separate training and testing datasets. The training dataset is used to develop the machine learning models, while the testing dataset contains unseen observations that are used to evaluate how accurately each model can predict pedestrian counts.
#
# In this use case, 80% of the observations are allocated to training and the remaining 20% are reserved for testing. Evaluating the models on data that was not used during training provides a more realistic indication of how well they may generalise to new pedestrian conditions.
#
# The same split is applied to both the original and polynomial feature sets so that their performance can be compared consistently. This helps determine whether the additional interaction features produce predictions that could provide more reliable information for city planners and emergency services when anticipating pedestrian activity.
# </div>

# %%
# Split the original feature set into training and testing data
X1_train, X1_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=123
)

# Apply the same split to the polynomial feature set
X2_train, X2_test, _, _ = train_test_split(
    X2,
    y,
    test_size=0.2,
    random_state=123
)

# %% [markdown]
# <div id="section-4-4" class="usecase-sub-section-heading">
# <b>4.4 Applying Linear Regression Model</b>
# </div>
#
# <div class="usecase-body">
# Linear Regression is applied as a baseline machine learning model for predicting pedestrian counts. A baseline model provides a useful reference point for determining how effectively the available weather, venue, spatial and temporal features can explain variations in pedestrian activity using relatively simple linear relationships.
#
# Two Linear Regression models are evaluated. The first uses the original feature set, while the second uses the polynomial interaction features created earlier. Comparing these models allows us to determine whether representing more complex interactions between the predictors improves pedestrian-count predictions.
# </div>
#
# <b>Linear Regression – Original Feature Set</b>
#
# <div class="usecase-body">
# The first Linear Regression model is trained using the original features and evaluated against the unseen test data. This establishes the baseline predictive performance of the model before additional feature interactions are introduced.
# </div>
#
# <b>Linear Regression – Interaction Feature Set</b>
#
# <div class="usecase-body">
# The second Linear Regression model is trained using the expanded interaction feature set. Its performance is compared with the original model to determine whether relationships between combinations of weather, venue, spatial and temporal conditions provide additional predictive value.
# </div>
#
# <div class="usecase-body">
# Both models are evaluated using Root Mean Squared Error (RMSE) and the coefficient of determination (R²). RMSE indicates the typical size of the model's prediction errors in pedestrian-count units, with lower values indicating more accurate predictions. R² indicates how much of the variation in pedestrian counts is explained by the model, with higher values indicating stronger predictive performance. These measures help determine whether the models provide sufficiently reliable pedestrian-flow estimates to be useful within the planning scenario.
# </div>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error, r2_score 

# Instantiate Linear regression model 
linear_r_model = LinearRegression()
# Train the model on original features X1 
linear_r_model.fit(X1_train, y_train)
# From the trained model predictions can be made 
y_pred = linear_r_model.predict(X1_test)
# Root mean squared error is utilised to evaluate the performance of the model. 
print("RMSE:", root_mean_squared_error(y_test, y_pred))
# R^2 score is another method utilised to evaluate the performance of the model. 
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# RMSE: 368.6688773919595
# R² Score: 0.3851430735934812

# %% [markdown]
# <div id="section-4-5" class="usecase-sub-section-heading">
# <b>4.5 Linear Regression Original Feature Analysis</b>
# </div>
#
# <div class="usecase-body">
# The Linear Regression model using the original feature set achieved an RMSE of approximately <strong>441.86 pedestrians</strong>. This indicates that the model's predictions typically differ from the observed pedestrian counts by approximately 442 pedestrians. Given the substantial variation in pedestrian activity within the dataset, this represents a relatively large prediction error and limits the model's ability to provide precise estimates of pedestrian flow.
#
# The model achieved an R² score of approximately <strong>0.25</strong>, meaning that around <strong>25% of the variation</strong> in pedestrian counts within the test data is explained by the selected weather, venue, spatial and temporal features using a linear relationship. This indicates that a large proportion of the variation in pedestrian activity is not captured by the original Linear Regression model.
#
# For city planners and emergency services, the model may provide some indication of general pedestrian activity patterns, but the relatively high prediction error means that it would have limited value where accurate estimates of crowd numbers are required. The results suggest that pedestrian activity is influenced by relationships that cannot be represented effectively through simple linear relationships alone.
#
# Overall, the original-feature Linear Regression model provides a useful baseline for comparison with the more complex models evaluated in the following sections.
# </div>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error, r2_score 

# Instantiate Linear regression model 
linear_r_model = LinearRegression()
# Train the model on interaction features X2
linear_r_model.fit(X2_train, y_train)
# From the trained model predictions can be made 
y_pred = linear_r_model.predict(X2_test)
# Root mean squared error is utilised to evaluate the performance of the model. 
print("RMSE:", root_mean_squared_error(y_test, y_pred))
# R^2 score is another method utilised to evaluate the performance of the model. 
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# RMSE: 306.54899734576406
# R² Score: 0.5748903958711795

# %% [markdown]
# <div id="section-4-6" class="usecase-sub-section-heading">
# <b>4.6 Linear Regression Interaction Feature Analysis</b>
# </div>
#
# <div class="usecase-body">
# The Linear Regression model using interaction features achieved an RMSE of approximately <strong>369.20 pedestrians</strong>, compared with approximately <strong>441.86 pedestrians</strong> for the original feature model. This reduction indicates that incorporating interactions between the predictors improves prediction accuracy, although an average error of approximately 369 pedestrians remains substantial.
#
# The interaction model achieved an R² score of approximately <strong>0.48</strong>, meaning that it explains around <strong>48% of the variation</strong> in pedestrian counts. This is a clear improvement over the original Linear Regression model, which explained approximately 25% of the variation. The result suggests that pedestrian activity is influenced by combinations of environmental, temporal, spatial and venue-related conditions that cannot be represented as effectively when the predictors are considered only through simple linear relationships.
#
# For city planners and emergency services, the improved model provides a better indication of how pedestrian activity may change under different conditions. However, an RMSE of approximately 369 pedestrians still represents considerable uncertainty. Predictions could therefore under- or overestimate pedestrian activity by hundreds of people, limiting the model's suitability for decisions that require precise crowd estimates.
#
# The performance should also be interpreted in the context of the available data. Pedestrian sensors are not located directly at every venue, so the nearest available sensor is used as a proxy for pedestrian activity around each venue. This spatial approximation may contribute to prediction error because the recorded pedestrian count may not perfectly represent activity at the venue itself.
#
# Overall, the interaction features provide a substantial improvement over the original Linear Regression model, but the remaining prediction error indicates that further improvement is desirable before the model could be relied upon for precise operational planning.
# </div>

# %% [markdown]
# <div id="section-4-7" class="usecase-sub-section-heading">
# <b>4.7 Applying Random Forest Regression Model</b>
# </div>
#
# <div class="usecase-body">
# Random Forest Regression is applied to determine whether a more flexible machine learning approach can improve pedestrian-count predictions compared with Linear Regression. Unlike Linear Regression, Random Forest can capture non-linear relationships and more complex interactions between the predictor variables without assuming that their relationship with pedestrian count is linear.
#
# This is particularly relevant to pedestrian activity because weather, venue characteristics, spatial location and temporal conditions may influence pedestrian movement in complex ways. For example, the effect of weather conditions may differ depending on the day of the week or characteristics of the surrounding venue.
# </div>
#
# <b>Random Forest Regression – Original Feature Set</b>
#
# <div class="usecase-body">
# The first Random Forest model is trained using the original feature set and evaluated against the unseen test data. Its performance can then be compared directly with the Linear Regression model using the same original features to determine whether Random Forest better captures the relationships influencing pedestrian activity.
# </div>
#
# <b>Random Forest Regression – Interaction Feature Set</b>
#
# <div class="usecase-body">
# The second Random Forest model is trained using the expanded interaction feature set. This allows the analysis to determine whether explicitly introducing pairwise feature interactions provides additional predictive value to a model that is already capable of representing complex and non-linear relationships.
# </div>
#
# <div class="usecase-body">
# Both models are evaluated using RMSE and R². Comparing these results with the Linear Regression models will help identify which modelling approach provides the most accurate representation of pedestrian activity and therefore offers the greatest potential value for the city-planning and emergency-services scenario.
# </div>

# %%
from sklearn.ensemble import RandomForestRegressor

# Instantiate RF Regressor model 
RF_model1 = RandomForestRegressor(random_state=42)
# Train the model on original features X1 
RF_model1.fit(X1_train, y_train)
# From the trained model predictions can be made 
y_pred1 = RF_model1.predict(X1_test)
# Root mean squared error is utilised to evaluate the performance of the model. 
print("RMSE:", root_mean_squared_error(y_test, y_pred1))
# R^2 score is another method utilised to evaluate the performance of the model. 
print("R² Score:", r2_score(y_test, y_pred1))
# Out:
# RMSE: 220.9386010060219
# R² Score: 0.779176994686683

# %% [markdown]
# <div id="section-4-8" class="usecase-sub-section-heading">
# <b>4.8 Random Forest Regression Original Feature Analysis</b>
# </div>
#
# <div class="usecase-body">
# The Random Forest Regression model using the original feature set achieved an RMSE of approximately <strong>180.19 pedestrians</strong>. This represents a substantial reduction in prediction error compared with both Linear Regression models and indicates that the Random Forest model is considerably more effective at predicting pedestrian activity from the available features.
#
# The model achieved an R² score of approximately <strong>0.88</strong>, meaning that around <strong>88% of the variation</strong> in pedestrian counts within the test data is explained by the model. Compared with the R² scores of approximately 0.25 and 0.48 produced by the Linear Regression models, this substantial improvement suggests that pedestrian activity is influenced by complex and non-linear relationships that Random Forest is better able to capture.
#
# For city planners and emergency services, the improved predictive performance provides a more useful indication of expected pedestrian activity. More accurate estimates could assist with identifying locations or conditions associated with increased pedestrian movement and support decisions relating to crowd management, staffing and resource allocation. However, an RMSE of approximately 180 pedestrians still represents meaningful uncertainty, particularly where precise estimates are required, so predictions should be treated as decision-support information rather than exact pedestrian numbers.
#
# The remaining prediction error may also be influenced by limitations in the available data. In particular, pedestrian sensors are not located directly at every venue and the nearest sensor is used as a proxy for pedestrian activity around that venue. Venue-specific attendance information is also unavailable, meaning that some factors directly influencing pedestrian numbers are not represented in the model.
#
# Overall, Random Forest Regression using the original features provides a substantial improvement over Linear Regression and demonstrates that modelling non-linear relationships is valuable for this pedestrian-flow prediction scenario.
# </div>

# %%
# Instantiate RF Regressor model 
RF_model2 = RandomForestRegressor(random_state=42)
# Train the model on original features X1 
RF_model2.fit(X2_train, y_train)
# From the trained model predictions can be made 
y_pred2 = RF_model2.predict(X2_test)
# Root mean squared error is utilised to evaluate the performance of the model. 
print("RMSE:", root_mean_squared_error(y_test, y_pred2))
# R^2 score is another method utilised to evaluate the performance of the model. 
print("R² Score:", r2_score(y_test, y_pred2))
# Out:
# RMSE: 247.48270071719173
# R² Score: 0.7229291671320941

# %% [markdown]
# <div id="section-4-9" class="usecase-sub-section-heading">
# <b>4.9 Random Forest Regression Interaction Feature Analysis</b>
# </div>
#
# <div class="usecase-body">
# The Random Forest Regression model using the interaction feature set achieved an RMSE of approximately <strong>217.36 pedestrians</strong> and an R² score of approximately <strong>0.82</strong>. These results remain substantially stronger than both Linear Regression models, demonstrating that Random Forest is more effective at capturing the complex relationships associated with pedestrian activity.
#
# However, the interaction feature model performs worse than the Random Forest model using the original feature set, which achieved an RMSE of approximately 180.19 pedestrians and an R² score of approximately 0.88. This indicates that explicitly adding the polynomial interaction features does not provide additional predictive value for the Random Forest model. Because Random Forest can already capture complex and non-linear relationships between predictors, the additional interaction features may introduce unnecessary complexity without improving prediction accuracy.
#
# For the city-planning and emergency-services scenario, the original-feature Random Forest model is therefore the preferred model. It provides the lowest prediction error and explains the greatest proportion of variation in pedestrian activity while using a substantially smaller and simpler feature set. Avoiding the additional interaction features also reduces unnecessary model complexity while maintaining the strongest predictive performance observed in this analysis.
#
# Although the preferred Random Forest model provides a useful indication of expected pedestrian activity, its predictions should still be interpreted as estimates rather than exact crowd numbers. The remaining prediction error and limitations of using nearby pedestrian sensors as proxies for venue activity should be considered when using the model to support crowd-management, planning or emergency-resource decisions.
# </div>

# %% [markdown]
# <div id="conclusion" class="usecase-section-heading">
# <b>5. Conclusion</b>
# </div>

# %% [markdown]
# <div class="usecase-body">
# This use case investigated whether pedestrian activity across Melbourne could be predicted by combining pedestrian sensor data with weather conditions, venue characteristics, spatial relationships and temporal information. The datasets were cleaned, explored and integrated to create a modelling dataset capable of examining how these factors relate to changes in pedestrian movement.
#
# The exploratory analysis identified clear patterns within the pedestrian and supporting datasets. Pedestrian activity varied substantially throughout the day, with the highest total pedestrian counts occurring around 12:00 and 17:00, corresponding with typical lunch and end-of-work periods. The geospatial analysis also showed that many event venues are located close to existing pedestrian sensors across central Melbourne, allowing nearby sensor observations to be used as a proxy for pedestrian activity around venues. The weather data contained considerable variation in environmental conditions such as temperature, humidity, solar exposure and wind conditions, providing additional information for examining how pedestrian activity changes under different conditions.
#
# The analysis demonstrated that pedestrian activity is influenced by relationships that are not effectively captured using simple Linear Regression alone. Adding interaction features improved the Linear Regression model from an R² of approximately 0.25 to 0.48, but prediction errors remained relatively high. Random Forest Regression produced substantially stronger results, demonstrating that a model capable of representing complex and non-linear relationships is better suited to the available pedestrian data.
#
# The best-performing model was the Random Forest Regression model using the original feature set, which achieved an RMSE of approximately <strong>180.19 pedestrians</strong> and an R² score of approximately <strong>0.88</strong>. In comparison, the Random Forest model using the interaction feature set achieved an RMSE of approximately 217.36 pedestrians and an R² score of approximately 0.82. Therefore, adding polynomial interaction features did not improve Random Forest performance, indicating that the original feature set provided the strongest balance between predictive performance and model complexity.
#
# These findings provide city planners and emergency services with information about when and where increased pedestrian activity is more likely to occur. The identified daily peaks demonstrate that pedestrian movement is not evenly distributed throughout the day, while the modelling results show that combining temporal, environmental, spatial and venue-related information can explain a substantial proportion of the variation in pedestrian counts. This information could support crowd management, event planning, staffing and the allocation of public-safety resources.
#
# However, the predictions should be interpreted as decision-support estimates rather than exact crowd numbers. Pedestrian sensors are not located directly at every venue, meaning the nearest sensor is used as a proxy for local pedestrian activity, and venue-specific attendance information is not available. These limitations contribute uncertainty to the predictions and should be considered when applying the model in practice.
#
# Overall, the use case demonstrates how combining multiple City of Melbourne datasets with machine learning can provide useful insight into pedestrian movement and support more informed planning decisions. The Random Forest model using the original feature set produced the strongest predictive performance in this analysis. Future improvements could include more direct venue attendance data, greater pedestrian sensor coverage, additional contextual information and further model optimisation to improve the accuracy and practical value of pedestrian-flow predictions.
# </div>

# %% [markdown]
# <b>What we achieved in this analysis</b>
#
# <div class="usecase-body">
# This analysis successfully integrated pedestrian counting, weather station and venue datasets into a single modelling dataset. Data cleaning, exploratory analysis and feature engineering were performed to prepare the data for machine learning. Spatial relationships between event venues and pedestrian sensors were incorporated by identifying the nearest sensor to each venue and calculating the distance between them, while temporal information such as day of the week was also included. Linear Regression and Random Forest Regression models were then developed and evaluated using both original and interaction feature sets.
# </div>
#
# <b>What we learned from this analysis</b>
#
# <div class="usecase-body">
# The analysis demonstrated the importance of data preparation, feature engineering and model selection within the machine learning workflow. Combining multiple data sources allowed environmental, spatial, temporal and venue-related factors to be considered together when predicting pedestrian activity. The results also showed that model choice had a substantial impact on predictive performance, with Random Forest Regression considerably outperforming Linear Regression and the original-feature Random Forest model producing the strongest overall results.
# </div>
#
# <b>Observations for further opportunities</b>
#
# <div class="usecase-body">
# Future work could improve pedestrian-flow predictions by incorporating additional contextual data such as public holidays, school holidays, major events, public transport activity and real-time traffic conditions. Access to venue-specific attendance data and greater pedestrian sensor coverage could also reduce the uncertainty associated with using nearby sensors as proxies for venue activity. Further model development could include hyperparameter tuning and evaluation of additional algorithms such as Gradient Boosting or XGBoost to determine whether predictive performance can be improved further.
# </div>
