# %% [markdown]
# # Refresh the MOP Data Asset Catalogue
#
# This notebook builds the Data Asset Management Platform from the public GitHub `master/usecases/FINALISED` folder and the City of Melbourne Open Data API. It creates a standalone HTML dashboard and a CSV register.

# %%
from pathlib import Path
import sys

candidates = [
    Path.cwd(),
    Path.cwd() / 'Data Assest Management' / 'files_to_push',
    Path.cwd() / 'usecases' / 'Data Assest Management',
]
PROJECT_DIR = next((path.resolve() for path in candidates if (path / 'data_asset_catalogue.py').exists()), None)
if PROJECT_DIR is None:
    raise FileNotFoundError('Run this notebook from its project directory or the MOP-Code repository root.')
sys.path.insert(0, str(PROJECT_DIR))

from data_asset_catalogue import BuildConfig, build

# %%
summary = build(BuildConfig(project_dir=PROJECT_DIR))
summary

# %% [markdown]
# ## Output checks
#
# The following checks confirm that both distributable files were generated and that at least one FINALISED notebook was scanned.

# %%
assert summary['notebooks_scanned'] > 0
assert Path(summary['html']).exists()
assert Path(summary['csv']).exists()
print('Build checks passed.')
