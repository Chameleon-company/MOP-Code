# %%
import sys
# !{sys.executable} -m pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\mobas\anaconda3\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy in c:\users\mobas\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\mobas\anaconda3\lib\site-packages (from xgboost) (1.13.1)

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %%
import pandas as pd
df= pd.read_csv("E:/mop/MOP-Code/Playground/dip/Dataset/merged_traffic_datav1.csv", usecols=['date','vehicle_class_1','vehicle_class_2','vehicle_class_3','vehicle_class_4','vehicle_class_5','vehicle_class_6','vehicle_class_7','vehicle_class_8','vehicle_class_9','vehicle_class_10','vehicle_class_11','vehicle_class_12','vehicle_class_13','motorcycle','bike','street_id'])
df = df.set_index('date', drop = False)
df.index = pd.to_datetime(df.index, format= 'mixed', dayfirst=True)
##df = df.sort_values(by = ['date'])

# %%
df.tail()
# Out:
#                   date  vehicle_class_1  vehicle_class_2  vehicle_class_3  \
# date
# 2014-11-26  26/11/2014            877.2              0.0              0.0
# 2014-11-20  20/11/2014            292.4            212.5              0.0
# 2014-11-20  20/11/2014            146.2              0.0              0.0
# 2014-11-21  21/11/2014            146.2              0.0              0.0
# 2014-11-21  21/11/2014            146.2              0.0              0.0
#
#             vehicle_class_4  vehicle_class_5  vehicle_class_6  \
# date
# 2014-11-26              0.0              0.0              0.0
# 2014-11-20              0.0              0.0              0.0
# 2014-11-20              0.0              0.0              0.0
# 2014-11-21              0.0              0.0              0.0
# 2014-11-21              0.0              0.0              0.0
#
#             vehicle_class_7  vehicle_class_8  vehicle_class_9  \
# date
# 2014-11-26              0.0              0.0                0
# 2014-11-20              0.0              0.0                0
# 2014-11-20              0.0              0.0                0
# 2014-11-21              0.0              0.0                0
# 2014-11-21              0.0              0.0                0
#
#             vehicle_class_10  vehicle_class_11  vehicle_class_12  \
# date
# 2014-11-26               0.0               0.0                 0
# 2014-11-20               0.0               0.0                 0
# 2014-11-20               0.0               0.0                 0
# 2014-11-21               0.0               0.0                 0
# 2014-11-21               0.0               0.0                 0
#
#             vehicle_class_13  motorcycle  bike  street_id
# date
# 2014-11-26                 0           0     0        720
# 2014-11-20                 0           0     0        720
# 2014-11-20                 0           0     0        720
# 2014-11-21                 0           0     0        720
# 2014-11-21                 0           0     0        720

# %%
df['total_emission']= df['vehicle_class_1'] + df['vehicle_class_2'] + df['vehicle_class_3'] + df['vehicle_class_4']+ df['vehicle_class_5']+df['vehicle_class_6']+df['vehicle_class_7']+df['vehicle_class_8']+df['vehicle_class_9']+df['vehicle_class_10']+df['vehicle_class_11']+df['vehicle_class_12']+df['vehicle_class_13']+df['motorcycle']+df['bike']

# %%
df = df[df['total_emission'] > 0]

# %%
df = df[['date', 'total_emission']]

# %%
df
# Out:
#                   date  total_emission
# date
# 2014-10-11  11/10/2014          3508.8
# 2014-10-11  11/10/2014          6140.4
# 2014-10-11  11/10/2014          5060.3
# 2014-11-11  11/11/2014           438.6
# 2014-11-11  11/11/2014           146.2
# ...                ...             ...
# 2014-11-26  26/11/2014           877.2
# 2014-11-20  20/11/2014           504.9
# 2014-11-20  20/11/2014           146.2
# 2014-11-21  21/11/2014           146.2
# 2014-11-21  21/11/2014           146.2
#
# [57636 rows x 2 columns]

# %%
##df = df.set_index('date')

# %%
df.plot(style= '.', figsize=(15, 5), color= color_pal[0])
# Out:
# <Axes: xlabel='date'>

# %%
##df.index = pd.to_datetime(df.index, format= 'mixed', dayfirst=True)

# %%
##df.plot(style= '.', figsize=(15, 5), color= color_pal[0])

# %%
train = df.loc[df.index < '2016-01-01']
test = df.loc[df.index >= '2016-01-01']
fig, ax = plt.subplots( figsize=(15, 5))
train.plot(ax=ax, label='training set', style = '.')
test.plot(ax=ax, label='testing set', style = '.')
plt.show()

# %%
##df.loc[(df.index > '05-05-2014') & (df.index < '06-06-2014')].plot()

# %%
def create_features(df):
    df = df.copy()
    df['day']= df.index.day
    df['month']= df.index.month
    df['year']= df.index.year
    return df
df = create_features(df)

# %%
sns.boxplot(data=df, x='year', y= "total_emission")
# Out:
# <Axes: xlabel='year', ylabel='total_emission'>

# %%
sns.boxplot(data=df, x='month', y= "total_emission")
# Out:
# <Axes: xlabel='month', ylabel='total_emission'>

# %%
train = create_features(train)
test = create_features(test)

# %%
FEATURES = ['day', 'month', 'year']
TARGET = 'total_emission'

# %%
x_train= train[FEATURES]
y_train = train[TARGET]

x_test= test[FEATURES]
y_test = test[TARGET]

# %%
reg = xgb.XGBRegressor(n_estimators= 1000, early_stopping_rounds=50, learning_rate= 0.01) 
reg.fit(x_train, y_train,
       eval_set= [(x_train, y_train), (x_test, y_test)],
      )
# Out:
# [0]	validation_0-rmse:25756.86505	validation_1-rmse:30333.40112
# [1]	validation_0-rmse:25713.13536	validation_1-rmse:30338.32464
# [2]	validation_0-rmse:25670.20116	validation_1-rmse:30343.36272
# [3]	validation_0-rmse:25628.04960	validation_1-rmse:30348.51153
# [4]	validation_0-rmse:25586.66690	validation_1-rmse:30353.76617
# [5]	validation_0-rmse:25546.04113	validation_1-rmse:30359.18247
# [6]	validation_0-rmse:25506.15787	validation_1-rmse:30364.69510
# [7]	validation_0-rmse:25467.00603	validation_1-rmse:30370.94397
# [8]	validation_0-rmse:25428.57009	validation_1-rmse:30376.63509
# [9]	validation_0-rmse:25390.84046	validation_1-rmse:30383.05400
# [10]	validation_0-rmse:25353.80330	validation_1-rmse:30388.90696
# [11]	validation_0-rmse:25317.44763	validation_1-rmse:30395.48153
# [12]	validation_0-rmse:25280.11473	validation_1-rmse:30397.84355
# [13]	validation_0-rmse:25243.46852	validation_1-rmse:30400.32496
# [14]	validation_0-rmse:25207.49876	validation_1-rmse:30402.92176
# [15]	validation_0-rmse:25172.19203	validation_1-rmse:30405.63031
# [16]	validation_0-rmse:25137.53870	validation_1-rmse:30408.44648
# [17]	validation_0-rmse:25103.52612	validation_1-rmse:30411.36664
# [18]	validation_0-rmse:25070.14378	validation_1-rmse:30414.38729
# [19]	validation_0-rmse:25037.38132	validation_1-rmse:30417.50395
# [20]	validation_0-rmse:25005.22687	validation_1-rmse:30420.71433
# [21]	validation_0-rmse:24974.59419	validation_1-rmse:30427.99825
# [22]	validation_0-rmse:24943.58385	validation_1-rmse:30431.36161
# [23]	validation_0-rmse:24913.15139	validation_1-rmse:30434.80784
# [24]	validation_0-rmse:24883.28746	validation_1-rmse:30438.33469
# [25]	validation_0-rmse:24854.57668	validation_1-rmse:30444.84504
# [26]	validation_0-rmse:24826.40402	validation_1-rmse:30451.40053
# [27]	validation_0-rmse:24798.75876	validation_1-rmse:30459.29651
# [28]	validation_0-rmse:24771.62873	validation_1-rmse:30465.93673
# [29]	validation_0-rmse:24745.01407	validation_1-rmse:30473.80515
# [30]	validation_0-rmse:24718.88989	validation_1-rmse:30480.51895
# [31]	validation_0-rmse:24693.26266	validation_1-rmse:30488.43638
# [32]	validation_0-rmse:24668.28417	validation_1-rmse:30496.15656
# [33]	validation_0-rmse:24642.84885	validation_1-rmse:30500.12028
# [34]	validation_0-rmse:24618.61318	validation_1-rmse:30506.88398
# [35]	validation_0-rmse:24595.18506	validation_1-rmse:30514.78892
# [36]	validation_0-rmse:24571.84236	validation_1-rmse:30521.60082
# [37]	validation_0-rmse:24548.94077	validation_1-rmse:30528.43234
# [38]	validation_0-rmse:24526.46201	validation_1-rmse:30536.55571
# [39]	validation_0-rmse:24503.61970	validation_1-rmse:30540.64109
# [40]	validation_0-rmse:24481.96605	validation_1-rmse:30548.78949
# [41]	validation_0-rmse:24460.72924	validation_1-rmse:30555.69986
# [42]	validation_0-rmse:24440.02459	validation_1-rmse:30563.58292
# [43]	validation_0-rmse:24419.56991	validation_1-rmse:30570.63630
# [44]	validation_0-rmse:24399.50316	validation_1-rmse:30578.79057
# [45]	validation_0-rmse:24378.98460	validation_1-rmse:30583.02352
# [46]	validation_0-rmse:24359.65699	validation_1-rmse:30590.06979
# [47]	validation_0-rmse:24338.72786	validation_1-rmse:30599.60181
# [48]	validation_0-rmse:24318.33596	validation_1-rmse:30602.73721
# [49]	validation_0-rmse:24299.19926	validation_1-rmse:30607.10121
# [50]	validation_0-rmse:24279.35002	validation_1-rmse:30615.57296
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
t = pd.DataFrame(data = reg.feature_importances_, index=reg.feature_names_in_, columns= ['importance'])
t.sort_values('importance').plot(kind='barh', title = 'feature Importance')
plt.show()

# %%
test['prediction']= reg.predict(x_test)
df = df.merge(test[['prediction']], how = 'left', left_index= True, right_index= True)

# %%
df
# Out:
#                   date  total_emission  day  month  year  prediction
# date
# 2014-10-11  11/10/2014          3508.8   11     10  2014         NaN
# 2014-10-11  11/10/2014          6140.4   11     10  2014         NaN
# 2014-10-11  11/10/2014          5060.3   11     10  2014         NaN
# 2014-11-11  11/11/2014           438.6   11     11  2014         NaN
# 2014-11-11  11/11/2014           146.2   11     11  2014         NaN
# ...                ...             ...  ...    ...   ...         ...
# 2014-11-26  26/11/2014           877.2   26     11  2014         NaN
# 2014-11-20  20/11/2014           504.9   20     11  2014         NaN
# 2014-11-20  20/11/2014           146.2   20     11  2014         NaN
# 2014-11-21  21/11/2014           146.2   21     11  2014         NaN
# 2014-11-21  21/11/2014           146.2   21     11  2014         NaN
#
# [5471524 rows x 6 columns]

# %%
ax = df[['total_emission']].plot(style= '.', figsize=(15,5))
df['prediction'].plot(ax=ax, style= '.')
plt.legend(['actual data', 'prediction'])
ax.set_title('raw data vs prediction')
plt.show()
