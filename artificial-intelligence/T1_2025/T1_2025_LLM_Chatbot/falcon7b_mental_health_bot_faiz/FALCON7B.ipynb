# %% [markdown]
# # downloading the libraries

# %%
# !pip install -U transformers accelerate bitsandbytes peft
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 27.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 72.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 37.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 107.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install -U transformers datasets accelerate bitsandbytes peft evaluate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.4/491.4 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 22.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 17.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 22.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# ...

# %% [markdown]
# # Falcon 7 b instruct model

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from peft import prepare_model_for_kbit_training, LoraConfig, get_peft_model

model_id = "tiiuae/falcon-7b-instruct"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype="float16",
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4"
)

tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token

model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map="auto",
    trust_remote_code=True,
    quantization_config=bnb_config
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.13k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/281 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# configuration_falcon.py:   0%|          | 0.00/7.16k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b-instruct:
# - configuration_falcon.py
# ...

# %%
from peft import LoraConfig

model = prepare_model_for_kbit_training(model)

lora_config = LoraConfig(
    r=8,
    lora_alpha=32,
    target_modules=["query_key_value"],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)

model = get_peft_model(model, lora_config)
# Out:
# You are using an old version of the checkpointing format that is deprecated (We will also silently ignore `gradient_checkpointing_kwargs` in case you passed it).Please update to the new format on your modeling file. To use the new format, you need to completely remove the definition of the method `_set_gradient_checkpointing` in your model.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Uploading the dataset

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-0e68c87d-0daf-4ed0-861b-3ca86254109a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0e68c87d-0daf-4ed0-861b-3ca86254109a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from datasets import load_dataset

dataset = load_dataset("json", data_files="colab_gpu_limited_100.json")["train"]
dataset = dataset.map(lambda x: {"instruction": x["question"], "output": x["answer"]})
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]

# %% [markdown]
# # My prompt sending with the dataset

# %%
system_prompt = (
    "You are a compassionate and helpful mental health assistant.\n"
    "Your role is to provide emotional support and practical guidance to users struggling with anxiety, depression, or related issues.\n"
    "Your tone is empathetic, calm, non-judgmental, and professional.\n\n"
)

def format_prompt(example):
    return {
        "text": f"{system_prompt}User: {example['instruction']}\nAssistant: {example['output']}"
    }

dataset = dataset.map(format_prompt)
# Out:
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]

# %%
def tokenize(example):
    return tokenizer(
        example["text"],
        truncation=True,
        padding="max_length",
        max_length=512
    )

tokenized_dataset = dataset.map(tokenize, batched=True)
tokenized_dataset.set_format(type="torch", columns=["input_ids", "attention_mask"])
# Out:
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]

# %% [markdown]
# # TRAINING THE MODEL

# %%
from transformers import TrainingArguments, Trainer, DataCollatorForLanguageModeling
import os

# Disable W&B logging
os.environ["WANDB_DISABLED"] = "true"

# Make sure caching is off for LoRA
model.config.use_cache = False

training_args = TrainingArguments(
    output_dir="./falcon-7b-lora-mentalhealth",  # unique save folder
    per_device_train_batch_size=2,
    gradient_accumulation_steps=4,
    num_train_epochs=3,
    learning_rate=1e-4,
    fp16=True,
    logging_steps=10,
    save_strategy="epoch",
    report_to="none"  # prevent WandB logs
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
    data_collator=DataCollatorForLanguageModeling(tokenizer, mlm=False)
)

# 🚀 Start training!
trainer.train()
# Out:
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='36' max='36' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [36/36 01:40, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
# ...

# %%
model.save_pretrained("./falcon-7b-lora-mentalhealth")
tokenizer.save_pretrained("./falcon-7b-lora-mentalhealth")
# Out:
# ('./falcon-7b-lora-mentalhealth/tokenizer_config.json',
#  './falcon-7b-lora-mentalhealth/special_tokens_map.json',
#  './falcon-7b-lora-mentalhealth/tokenizer.json')

# %%
# !cp -r ./falcon-7b-lora-mentalhealth /content/drive/MyDrive/falcon-7b-lora-mentalhealth

# %%
from tqdm import tqdm

model.gradient_checkpointing_disable()
model.eval()
model.config.use_cache = True
tokenizer.pad_token = tokenizer.eos_token
# Out:
# You are using an old version of the checkpointing format that is deprecated (We will also silently ignore `gradient_checkpointing_kwargs` in case you passed it).Please update to the new format on your modeling file. To use the new format, you need to completely remove the definition of the method `_set_gradient_checkpointing` in your model.

# %%
def generate_response(prompt):
    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        padding=True,
        truncation=True,
        max_length=350  # Safe margin since your inputs are ≤300
    ).to("cuda")

    outputs = model.generate(
        input_ids=inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_new_tokens=180,        # Allow slightly longer, more complete responses
        temperature=0.6,           # More focused (lower temp = less randomness)
        top_p=0.9,                 # Nucleus sampling
        do_sample=True,
        repetition_penalty=1.1,    # Penalize verbatim loops
        pad_token_id=tokenizer.eos_token_id
    )

    return tokenizer.decode(outputs[0], skip_special_tokens=True).split("Assistant:")[-1].strip()

# %%
predictions = []
references = []

for row in tqdm(dataset):
    prompt = f"{system_prompt}User: {row['instruction']}\nAssistant:"
    response = generate_response(prompt)
    predictions.append(response)
    references.append(row["output"])
# Out:
# 100%|██████████| 100/100 [12:13<00:00,  7.33s/it]

# %%
# !pip install evaluate rouge_score bert_score
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Results evaluation

# %%
import evaluate

bleu = evaluate.load("bleu")
rouge = evaluate.load("rouge")
bertscore = evaluate.load("bertscore")

# BLEU expects references as list of lists
bleu_result = bleu.compute(predictions=predictions, references=[[r] for r in references])
rouge_result = rouge.compute(predictions=predictions, references=references)
bertscore_result = bertscore.compute(predictions=predictions, references=references, lang="en")

# Print scores
print("🟦 BLEU:", round(bleu_result["bleu"] * 100, 2))
print("🟥 ROUGE-1:", round(rouge_result["rouge1"] * 100, 2))
print("🟥 ROUGE-2:", round(rouge_result["rouge2"] * 100, 2))
print("🟥 ROUGE-L:", round(rouge_result["rougeL"] * 100, 2))
print("🟩 BERTScore (F1):", round(sum(bertscore_result["f1"]) / len(bertscore_result["f1"]) * 100, 2))
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# ...

# %% [markdown]
# # Bench Mark Dataset

# %%
from google.colab import files

uploaded = files.upload()  # Upload `no_gpu_limit_500.json`
# Out:
#      <input type="file" id="files-eb6d351a-fc67-4818-9fbf-ae9c7d61246a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eb6d351a-fc67-4818-9fbf-ae9c7d61246a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from datasets import load_dataset

full_dataset = load_dataset("json", data_files="no_gpu_limit_500.json")["train"]
full_dataset = full_dataset.map(lambda x: {"instruction": x["question"], "output": x["answer"]})

system_prompt = (
    "You are a compassionate and helpful mental health assistant.\n"
    "Your role is to provide emotional support and practical guidance to users struggling with anxiety, depression, or related issues.\n"
    "Your tone is empathetic, calm, non-judgmental, and professional.\n\n"
)

def format_prompt(example):
    return {
        "text": f"{system_prompt}User: {example['instruction']}\nAssistant: {example['output']}"
    }

full_dataset = full_dataset.map(format_prompt)

# 📌 Extract only the last 100 rows for benchmarking
benchmark_dataset = full_dataset.select(range(len(full_dataset)-100, len(full_dataset)))
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# ...
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]

# %%
def generate_response(prompt):
    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        padding=True,
        truncation=True,
        max_length=350
    ).to("cuda")

    outputs = model.generate(
        input_ids=inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_new_tokens=180,
        temperature=0.6,
        top_p=0.9,
        do_sample=True,
        repetition_penalty=1.1,
        pad_token_id=tokenizer.eos_token_id
    )

    return tokenizer.decode(outputs[0], skip_special_tokens=True).split("Assistant:")[-1].strip()

# %% [markdown]
# # Using the last 100 rows as the bench mark dataset

# %%
benchmark_preds = []
benchmark_refs = []

for row in tqdm(benchmark_dataset):
    prompt = row["text"].split("Assistant:")[0] + "Assistant:"
    response = generate_response(prompt)
    benchmark_preds.append(response)
    benchmark_refs.append(row["output"])
# Out:
# 100%|██████████| 100/100 [13:08<00:00,  7.89s/it]

# %%
import evaluate

bleu = evaluate.load("bleu")
rouge = evaluate.load("rouge")
bertscore = evaluate.load("bertscore")

bleu_result = bleu.compute(predictions=benchmark_preds, references=[[r] for r in benchmark_refs])
rouge_result = rouge.compute(predictions=benchmark_preds, references=benchmark_refs)
bertscore_result = bertscore.compute(predictions=benchmark_preds, references=benchmark_refs, lang="en")

print("\n📊 🔬 Evaluation on Benchmark Dataset (Last 100 Rows):")
print("🟦 BLEU:", round(bleu_result["bleu"] * 100, 2))
print("🟥 ROUGE-1:", round(rouge_result["rouge1"] * 100, 2))
print("🟥 ROUGE-2:", round(rouge_result["rouge2"] * 100, 2))
print("🟥 ROUGE-L:", round(rouge_result["rougeL"] * 100, 2))
print("🟩 BERTScore (F1):", round(sum(bertscore_result["f1"]) / len(bertscore_result["f1"]) * 100, 2))
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 📊 🔬 Evaluation on Benchmark Dataset (Last 100 Rows):
# 🟦 BLEU: 4.67
# 🟥 ROUGE-1: 35.4
# 🟥 ROUGE-2: 10.16
# 🟥 ROUGE-L: 19.0
# 🟩 BERTScore (F1): 87.1

# %% [markdown]
# # Using different prompt to check if the result improves

# %%
## Using different prompts

# %%
from datasets import load_dataset

# Load dataset
dataset = load_dataset("json", data_files="colab_gpu_limited_100.json")["train"]
dataset = dataset.map(lambda x: {"instruction": x["question"], "output": x["answer"]})

# Original system prompt
original_system_prompt = (
    "You are a compassionate and helpful mental health assistant. "
    "You provide emotional support and guidance for users experiencing anxiety and depression."
)

# Format the prompt in original style
def format_chat_prompt(example):
    return {
        "text": f"{original_system_prompt}\n\nUser: {example['instruction']}\nAssistant:"
    }

dataset = dataset.map(format_chat_prompt)
# Out:
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]

# %%
predictions = []
references = []

for row in tqdm(dataset):
    prompt = row["text"]
    response = generate_response(prompt)
    predictions.append(response)
    references.append(row["output"])
# Out:
# 100%|██████████| 100/100 [11:57<00:00,  7.18s/it]

# %%
import evaluate

bleu = evaluate.load("bleu")
rouge = evaluate.load("rouge")
bertscore = evaluate.load("bertscore")

bleu_result = bleu.compute(predictions=predictions, references=[[r] for r in references])
rouge_result = rouge.compute(predictions=predictions, references=references)
bertscore_result = bertscore.compute(predictions=predictions, references=references, lang="en")

print("\n📊 Evaluation with Original Prompt Format:")
print("🟦 BLEU:", round(bleu_result["bleu"] * 100, 2))
print("🟥 ROUGE-1:", round(rouge_result["rouge1"] * 100, 2))
print("🟥 ROUGE-2:", round(rouge_result["rouge2"] * 100, 2))
print("🟥 ROUGE-L:", round(rouge_result["rougeL"] * 100, 2))
print("🟩 BERTScore (F1):", round(sum(bertscore_result["f1"]) / len(bertscore_result["f1"]) * 100, 2))
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 📊 Evaluation with Original Prompt Format:
# 🟦 BLEU: 3.23
# 🟥 ROUGE-1: 33.36
# 🟥 ROUGE-2: 9.96
# 🟥 ROUGE-L: 18.8
# 🟩 BERTScore (F1): 87.14

# %%
import pandas as pd

df = pd.DataFrame({
    "Prompt": [row["text"] for row in dataset],
    "Prediction": predictions,
    "Reference": references
})

df.to_csv("/content/drive/MyDrive/falcon7b_original_prompt_eval.csv", index=False)

with open("/content/drive/MyDrive/falcon7b_original_prompt_scores.txt", "w") as f:
    f.write("📊 Evaluation with Original Prompt Format:\n")
    f.write(f"BLEU: {round(bleu_result['bleu'] * 100, 2)}\n")
    f.write(f"ROUGE-1: {round(rouge_result['rouge1'] * 100, 2)}\n")
    f.write(f"ROUGE-2: {round(rouge_result['rouge2'] * 100, 2)}\n")
    f.write(f"ROUGE-L: {round(rouge_result['rougeL'] * 100, 2)}\n")
    f.write(f"BERTScore (F1): {round(sum(bertscore_result['f1']) / len(bertscore_result['f1']) * 100, 2)}\n")

# %%
# !nvidia-smi
# !pip list | grep transformers
# Out:
# Tue May 13 11:42:01 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   43C    P8             11W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from dotenv import load_dotenv
import os

load_dotenv()
print("HF Token:", os.getenv("HF_API_TOKEN"))
print("OpenAI Key:", os.getenv("OPENAI_API_KEY"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-fbaaca5046e9> in <cell line: 0>()
# ----> 1 from dotenv import load_dotenv
#       2 import os
#       3
#       4 load_dotenv()
#       5 print("HF Token:", os.getenv("HF_API_TOKEN"))
#
# ModuleNotFoundError: No module named 'dotenv'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
