# %%
import pandas as pd
import numpy as np
import datetime

# %%
ParkingDF = pd.read_csv('parkingsensor6.csv')
ParkingDF
# Out:
#         Unnamed: 0  bay_id st_marker_id      status  \
# 0              0.0    4044        C6126     Present
# 1              1.0    5361        8903W  Unoccupied
# 2              2.0    3686        7646N     Present
# 3              3.0    6034       13079S  Unoccupied
# 4              4.0    3843        C5566  Unoccupied
# ...            ...     ...          ...         ...
# 568044         NaN    3719        7722N  Unoccupied
# 568045         NaN    3019        5100E     Present
# 568046         NaN    1471        1775S  Unoccupied
# 568047         NaN    3727        7762N  Unoccupied
# 568048         NaN    2999        5048E     Present
#
#                           datetime
# 0       2021-08-13 12:30:39.749530
# 1       2021-08-13 12:30:39.749530
# 2       2021-08-13 12:30:39.749530
# 3       2021-08-13 12:30:39.749530
# 4       2021-08-13 12:30:39.749530
# ...                            ...
# 568044         2021-08-21 08:56:42
# 568045         2021-08-21 08:56:42
# ...

# %%
Parking2 = ParkingDF.drop(columns = [''])
Parking2
# Out:
#         bay_id st_marker_id        lat         lon
# 0         4044        C6126 -37.804494  144.952380
# 1         5361        8903W -37.824098  144.962115
# 2         3686        7646N -37.805002  144.957122
# 3         6034       13079S -37.821253  144.943510
# 4         3843        C5566 -37.806418  144.953969
# ...        ...          ...        ...         ...
# 567099    3719        7722N -37.803326  144.952904
# 567100    3019        5100E -37.804378  144.957712
# 567101    1471        1775S -37.816754  144.966093
# 567102    3727        7762N -37.802541  144.945822
# 567103    2999        5048E -37.805321  144.958144
#
# [567104 rows x 4 columns]

# %%
Parking2['bay_id'].unique()
# Out:
# array([4044, 5361, 3686, ..., 1055, 1054, 5247])

# %%
stmarker = Parking2['st_marker_id'].drop_duplicates()
Parking2['st_marker_id'] = stmarker
Parking2
# Out:
#         bay_id st_marker_id        lat         lon
# 0         4044        C6126 -37.804494  144.952380
# 1         5361        8903W -37.824098  144.962115
# 2         3686        7646N -37.805002  144.957122
# 3         6034       13079S -37.821253  144.943510
# 4         3843        C5566 -37.806418  144.953969
# ...        ...          ...        ...         ...
# 567099    3719          NaN -37.803326  144.952904
# 567100    3019          NaN -37.804378  144.957712
# 567101    1471          NaN -37.816754  144.966093
# 567102    3727          NaN -37.802541  144.945822
# 567103    2999          NaN -37.805321  144.958144
#
# [567104 rows x 4 columns]

# %%
Parking2.dropna()
# Out:
#         bay_id st_marker_id        lat         lon
# 0         4044        C6126 -37.804494  144.952380
# 1         5361        8903W -37.824098  144.962115
# 2         3686        7646N -37.805002  144.957122
# 3         6034       13079S -37.821253  144.943510
# 4         3843        C5566 -37.806418  144.953969
# ...        ...          ...        ...         ...
# 410640    6328       13474E -37.818795  144.949886
# 410642    6306       13369W -37.819614  144.949728
# 465032    1055         981W -37.818493  144.962179
# 466040    1054         979W -37.818546  144.962204
# 550848    5247       11519S -37.811808  144.952206
#
# [1321 rows x 4 columns]

# %%
Parking2.to_csv('UniqueBays.csv')

# %%
Parking3 = ParkingDF.drop(columns = ['location','lat', 'lon', ':@computed_region_evbi_jbp8', 'hour', 'minute', 'dayofweek', 'date'])
Parking3
# Out:
#         bay_id st_marker_id      status                    datetime
# 0         4044        C6126     Present  2021-08-13 02:30:39.749530
# 1         5361        8903W  Unoccupied  2021-08-13 02:30:39.749530
# 2         3686        7646N     Present  2021-08-13 02:30:39.749530
# 3         6034       13079S  Unoccupied  2021-08-13 02:30:39.749530
# 4         3843        C5566  Unoccupied  2021-08-13 02:30:39.749530
# ...        ...          ...         ...                         ...
# 567099    3719        7722N     Present  2021-08-19 05:23:30.741312
# 567100    3019        5100E  Unoccupied  2021-08-19 05:23:30.741312
# 567101    1471        1775S     Present  2021-08-19 05:23:30.741312
# 567102    3727        7762N  Unoccupied  2021-08-19 05:23:30.741312
# 567103    2999        5048E     Present  2021-08-19 05:23:30.741312
#
# [567104 rows x 4 columns]

# %%
today = datetime.datetime.today().replace(microsecond=0)
print(today)

tomorrow = today + datetime.timedelta(days=1)  
print(tomorrow)
# Out:
# 2021-08-20 21:39:19
# 2021-08-21 21:39:19

# %%
Parking3['datetime'] = pd.to_datetime(Parking3['datetime'])

# %%
Parking3.dtypes
# Out:
# bay_id                   int64
# st_marker_id            object
# status                  object
# datetime        datetime64[ns]
# dtype: object

# %%
test = Parking3['datetime'][0].replace(microsecond=0)

# %%
test
# Out:
# Timestamp('2021-08-13 02:30:39')

# %%
Parking3['datetime'] = Parking3['datetime'] + datetime.timedelta(hours = 10)

# %%
Parking3
# Out:
#         bay_id st_marker_id      status                   datetime
# 0         4044        C6126     Present 2021-08-13 12:30:39.749530
# 1         5361        8903W  Unoccupied 2021-08-13 12:30:39.749530
# 2         3686        7646N     Present 2021-08-13 12:30:39.749530
# 3         6034       13079S  Unoccupied 2021-08-13 12:30:39.749530
# 4         3843        C5566  Unoccupied 2021-08-13 12:30:39.749530
# ...        ...          ...         ...                        ...
# 567099    3719        7722N     Present 2021-08-19 15:23:30.741312
# 567100    3019        5100E  Unoccupied 2021-08-19 15:23:30.741312
# 567101    1471        1775S     Present 2021-08-19 15:23:30.741312
# 567102    3727        7762N  Unoccupied 2021-08-19 15:23:30.741312
# 567103    2999        5048E     Present 2021-08-19 15:23:30.741312
#
# [567104 rows x 4 columns]

# %%
Parking3.to_csv('parkingsensor.csv')

# %%
datetime.datetime.today().replace(microsecond=0) + datetime.timedelta(hours = 10)
# Out:
# datetime.datetime(2021, 8, 21, 7, 56, 56)

# %% [markdown]
# ### Checkpoint

# %% [markdown]
# Instead of using timedelta I am going to use Pandas to get localised time instead as daylightsavings will interupt

# %%
ParkingDF = pd.read_csv('parkingsensor5.csv')
ParkingDF
# Out:
#         bay_id st_marker_id      status  \
# 0         4044        C6126     Present
# 1         5361        8903W  Unoccupied
# 2         3686        7646N     Present
# 3         6034       13079S  Unoccupied
# 4         3843        C5566  Unoccupied
# ...        ...          ...         ...
# 567099    3719        7722N     Present
# 567100    3019        5100E  Unoccupied
# 567101    1471        1775S     Present
# 567102    3727        7762N  Unoccupied
# 567103    2999        5048E     Present
#
#                                                  location        lat  \
# 0       {'latitude': '-37.80449363067284', 'longitude'... -37.804494
# 1       {'latitude': '-37.82409822525305', 'longitude'... -37.824098
# 2       {'latitude': '-37.80500159217506', 'longitude'... -37.805002
# 3       {'latitude': '-37.82125258940435', 'longitude'... -37.821253
# 4       {'latitude': '-37.80641793309145', 'longitude'... -37.806418
# ...

# %%
ParkingDF1 = ParkingDF['datetime']
ParkingDF1 = pd.DataFrame(ParkingDF1)
ParkingDF1
# Out:
#                           datetime
# 0       2021-08-13 02:30:39.749530
# 1       2021-08-13 02:30:39.749530
# 2       2021-08-13 02:30:39.749530
# 3       2021-08-13 02:30:39.749530
# 4       2021-08-13 02:30:39.749530
# ...                            ...
# 567099  2021-08-19 05:23:30.741312
# 567100  2021-08-19 05:23:30.741312
# 567101  2021-08-19 05:23:30.741312
# 567102  2021-08-19 05:23:30.741312
# 567103  2021-08-19 05:23:30.741312
#
# [567104 rows x 1 columns]

# %%
ParkingDF1.tz_localize(tz='Europe/Stockholm')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-dd0999739cec> in <module>
# ----> 1 ParkingDF1[0:1].tz_localize(tz='Europe/Stockholm')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in tz_localize(self, tz, axis, level, copy, ambiguous, nonexistent)
#    9525             if level not in (None, 0, ax.name):
#    9526                 raise ValueError(f"The level {level} is not valid")
# -> 9527             ax = _tz_localize(ax, tz, ambiguous, nonexistent)
#    9528
#    9529         result = self._constructor(self._data, copy=copy)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _tz_localize(ax, tz, ambiguous, nonexistent)
#    9508                     ax_name = self._get_axis_name(axis)
#    9509                     raise TypeError(
# ...

# %%
from pandas import Timestamp

ParkingDF1.Timestamp('datetime', tz='AEST')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-003156d7d7e3> in <module>
#       1 from pandas import Timestamp
#       2
# ----> 3 ParkingDF1.Timestamp('datetime', tz='AEST')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Timestamp'

# %%
ts = pd.Timestamp('2021-08-13 02:30:39', tz = "UTC")
ts
print(ts.tz_convert(tz='Australia/Victoria'))
# Out:
# 2021-08-13 12:30:39+10:00

# %%
a = datetime.datetime.today().replace(microsecond=0)
#print(pd.Timestamp(a, tz = 'Australia/Victoria'), nonexistant = 'timedelta')
#?Timestamp

#Timestamp.tz_localize('2021-08-13 02:30:39.749530', tz = 'Australia/Victoria', nonexistent = 'raise')

ts = pd.Timestamp(a, tz = "UTC")
b = ts.tz_convert(tz='Australia/Victoria')
print(b)
# Out:
# 2021-09-09 08:56:20+10:00

# %%
d = {'datetime': [b]}
>>> df = pd.DataFrame(data=d)
df
# Out:
#                    datetime
# 0 2021-09-09 08:56:20+10:00

# %%
ParkingDF1['test'] = ts.tz_convert(tz='Australia/Victoria')
ParkingDF1
# Out:
#                           datetime                      test
# 0       2021-08-13 02:30:39.749530 2021-09-09 08:56:20+10:00
# 1       2021-08-13 02:30:39.749530 2021-09-09 08:56:20+10:00
# 2       2021-08-13 02:30:39.749530 2021-09-09 08:56:20+10:00
# 3       2021-08-13 02:30:39.749530 2021-09-09 08:56:20+10:00
# 4       2021-08-13 02:30:39.749530 2021-09-09 08:56:20+10:00
# ...                            ...                       ...
# 567101  2021-08-19 05:23:30.741312 2021-09-09 08:56:20+10:00
# 567102  2021-08-19 05:23:30.741312 2021-09-09 08:56:20+10:00
# 567103  2021-08-19 05:23:30.741312 2021-09-09 08:56:20+10:00
# 0        2021-09-09 08:50:10+10:00 2021-09-09 08:56:20+10:00
# 0                             None 2021-09-09 08:56:20+10:00
#
# [567106 rows x 2 columns]

# %%
b
# Out:
# Timestamp('2021-09-09 08:50:10+1000', tz='Australia/Victoria')

# %%
pd.Timestamp(a, tz = 'Australia/Victoria')
# Out:
# Timestamp('2021-09-08 22:40:35+1000', tz='Australia/Victoria')

# %%
ParkingDF2 = pd.read_csv('parkingsensor.csv')
ParkingDF2
# Out:
#          bay_id st_marker_id      status                    datetime
# 0          4044        C6126     Present  2021-08-13 12:30:39.749530
# 1          5361        8903W  Unoccupied  2021-08-13 12:30:39.749530
# 2          3686        7646N     Present  2021-08-13 12:30:39.749530
# 3          6034       13079S  Unoccupied  2021-08-13 12:30:39.749530
# 4          3843        C5566  Unoccupied  2021-08-13 12:30:39.749530
# ...         ...          ...         ...                         ...
# 2565718    5870        C9182  Unoccupied   2021-09-08 23:15:36+10:00
# 2565719    1839        2531S  Unoccupied   2021-09-08 23:15:36+10:00
# 2565720     948         C798     Present   2021-09-08 23:15:36+10:00
# 2565721     956         C826  Unoccupied   2021-09-08 23:15:36+10:00
# 2565722    1471        1775S  Unoccupied   2021-09-08 23:15:36+10:00
#
# [2565723 rows x 4 columns]

# %% [markdown]
# ### Checkpoint

# %% [markdown]
# I need to write some code that will create new files when each day passes

# %%
ParkingDF2.tail(20000)
# Out:
#          bay_id st_marker_id      status                   datetime
# 2545723     875         771W  Unoccupied        2021-09-08 18:54:55
# 2545724    2324        2890N     Present        2021-09-08 18:54:55
# 2545725    1542        1912N  Unoccupied        2021-09-08 18:54:55
# 2545726    5514       11961W  Unoccupied        2021-09-08 18:54:55
# 2545727    2328        2899S  Unoccupied        2021-09-08 18:54:55
# ...         ...          ...         ...                        ...
# 2565718    5870        C9182  Unoccupied  2021-09-08 23:15:36+10:00
# 2565719    1839        2531S  Unoccupied  2021-09-08 23:15:36+10:00
# 2565720     948         C798     Present  2021-09-08 23:15:36+10:00
# 2565721     956         C826  Unoccupied  2021-09-08 23:15:36+10:00
# 2565722    1471        1775S  Unoccupied  2021-09-08 23:15:36+10:00
#
# [20000 rows x 4 columns]

# %%
if timedelta

# %%
a = datetime.datetime.today().replace(microsecond=0)

ts = pd.Timestamp(a, tz = "UTC")
b = ts.tz_convert(tz='Australia/Victoria')
print(b)
# Out:
# 2021-09-09 09:28:58+10:00

# %%
c = datetime.datetime.today().replace(microsecond=0) + datetime.timedelta(hours = 1)
c
# Out:
# datetime.datetime(2021, 9, 9, 0, 34, 37)

# %%
print(c)
# Out:
# 2021-09-09 00:34:37

# %%
c.hour
# Out:
# 0

# %%
if c.hour == 0:
    if
    empty = pd.DataFrame(list())
    empty.to_csv(f'{c.date()}.csv')

# %%
print(f'hello {b}')
# Out:
# hello 2021-09-09 09:28:58+10:00

# %%
df = pd.DataFrame({'bay_id': [], 'st_marker_id': [], 'status': [], 'datetime': []})
df.to_csv(f'{c.date()}.csv', index = False)

# %%
print(c.date())
# Out:
# 2021-09-09

# %%
a = datetime.datetime.today().replace(microsecond=0)

ts = pd.Timestamp(a, tz = "UTC")
d = ts.tz_convert(tz='Australia/Victoria')
print(a)
print(ts)
print(d)
print(d.date())
# Out:
# 2021-09-09 00:28:31
# 2021-09-09 00:28:31+00:00
# 2021-09-09 10:28:31+10:00
# 2021-09-09

# %%
def run(event, context):
    bucket = 'opendataplayground.deakin'
    # get existing dataframe from csv on S3
    s3_resource = boto3.resource('s3')
    a = datetime.datetime.today().replace(microsecond=0)
    ts = pd.Timestamp(a, tz = "UTC")
    d = ts.tz_convert(tz='Australia/Victoria')
    key = f'parkingsensor/{d.date()}.csv'
    
    if read_file = s3_resource.Object(bucket, key).get() == False:  #If file doesn't exist create a new file. PLEASE CHECK
        empty = pd.DataFrame({'bay_id': [], 'st_marker_id': [], 'status': [], 'datetime': []})
        empty.to_csv(f'{d.date()}.csv', index = False)   #Need to add file path
    
    read_file = s3_resource.Object(bucket, key).get()
        

    client = Socrata(
        "data.melbourne.vic.gov.au",
        "EC65cHicC3xqFXHHvAUICVXEr", # app token, just used to reduce throttling, not authentication
        timeout=120
    )

    df = pd.read_csv(read_file['Body'])
    # add another number to the csv
    df1 = pd.DataFrame(client.get("vh2v-4nfs", limit=200000))
    df1.drop(columns = ['location', 'lat', 'lon', ':@computed_region_evbi_jbp8'], inplace = True)
 #  df1['datetime'] = datetime.datetime.today().replace(microsecond=0) + datetime.timedelta(hours = 10) #Melbourne Time
    df1['datetime'] = d  #This is changing it to Melbourne Timezone won't be affect by DST
    df = df.append(df1)


    # write the csv to a buffer
    csv_buffer = StringIO()
    df.to_csv(csv_buffer, index = False)

    s3_resource.Object(bucket, f'parkingsensor/{d.date()}.csv').put(Body=csv_buffer.getvalue())
    return f"CSV now has {len(df)} rows"

# %%
test = pd.read_csv('2021-09-09.csv')
test
# Out:
# Empty DataFrame
# Columns: [bay_id, st_marker_id, status, datetime]
# Index: []

# %%
test = test.append(ParkingDF2)
test
# Out:
#         Unnamed: 0  bay_id st_marker_id      status  \
# 0              NaN  4044.0        C6126     Present
# 1              NaN  5361.0        8903W  Unoccupied
# 2              NaN  3686.0        7646N     Present
# 3              NaN  6034.0       13079S  Unoccupied
# 4              NaN  3843.0        C5566  Unoccupied
# ...            ...     ...          ...         ...
# 2565718        NaN  5870.0        C9182  Unoccupied
# 2565719        NaN  1839.0        2531S  Unoccupied
# 2565720        NaN   948.0         C798     Present
# 2565721        NaN   956.0         C826  Unoccupied
# 2565722        NaN  1471.0        1775S  Unoccupied
#
#                            datetime
# 0        2021-08-13 12:30:39.749530
# 1        2021-08-13 12:30:39.749530
# 2        2021-08-13 12:30:39.749530
# 3        2021-08-13 12:30:39.749530
# 4        2021-08-13 12:30:39.749530
# ...                             ...
# 2565718   2021-09-08 23:15:36+10:00
# 2565719   2021-09-08 23:15:36+10:00
# ...

# %%
pd.DataFrame({'bay_id': [], 'st_marker_id': [], 'status': [], 'datetime': []})
# Out:
# Empty DataFrame
# Columns: [bay_id, st_marker_id, status, datetime]
# Index: []

# %% [markdown]
# ### Checkpoint

# %% [markdown]
# Stripping the file into daily files

# %%
import os

print(os.getcwd())
os.chdir('/Users/jason/Documents/SIT764/THISGIT/d2i---melbourne-city/T2_2021/ETL')
# Out:
# /Users/jason/Documents/SIT784/Daily_Files

# %%
os.getcwd()
# Out:
# '/Users/jason/Documents/SIT764/THISGIT/d2i---melbourne-city/T2_2021/ETL'

# %%
ParkingDF = pd.read_csv('parkingsensor.csv')
ParkingDF
# Out:
#          bay_id st_marker_id      status                    datetime
# 0          4044        C6126     Present  2021-08-13 12:30:39.749530
# 1          5361        8903W  Unoccupied  2021-08-13 12:30:39.749530
# 2          3686        7646N     Present  2021-08-13 12:30:39.749530
# 3          6034       13079S  Unoccupied  2021-08-13 12:30:39.749530
# 4          3843        C5566  Unoccupied  2021-08-13 12:30:39.749530
# ...         ...          ...         ...                         ...
# 2633415    5857        C9130  Unoccupied   2021-09-09 14:41:07+10:00
# 2633416    8306         657W     Present   2021-09-09 14:41:07+10:00
# 2633417     927         C722     Present   2021-09-09 14:41:07+10:00
# 2633418     949         C802     Present   2021-09-09 14:41:07+10:00
# 2633419    1471        1775S     Present   2021-09-09 14:41:07+10:00
#
# [2633420 rows x 4 columns]

# %%
print(ParkingDF.groupby('datetime').count()['bay_id'].min())
print(ParkingDF.groupby('datetime').count()['bay_id'].max())
# Out:
# 485
# 1306

# %%
ParkingDF[ParkingDF['datetime'] == ParkingDF['datetime'][0]]
# Out:
#      bay_id st_marker_id      status                    datetime
# 0      4044        C6126     Present  2021-08-13 12:30:39.749530
# 1      5361        8903W  Unoccupied  2021-08-13 12:30:39.749530
# 2      3686        7646N     Present  2021-08-13 12:30:39.749530
# 3      6034       13079S  Unoccupied  2021-08-13 12:30:39.749530
# 4      3843        C5566  Unoccupied  2021-08-13 12:30:39.749530
# ..      ...          ...         ...                         ...
# 980    3719        7722N     Present  2021-08-13 12:30:39.749530
# 981    3019        5100E  Unoccupied  2021-08-13 12:30:39.749530
# 982    1471        1775S     Present  2021-08-13 12:30:39.749530
# 983    3727        7762N  Unoccupied  2021-08-13 12:30:39.749530
# 984    2999        5048E  Unoccupied  2021-08-13 12:30:39.749530
#
# [985 rows x 4 columns]

# %%
ParkingDF
# Out:
#          bay_id st_marker_id      status                    datetime
# 0          4044        C6126     Present  2021-08-13 12:30:39.749530
# 1          5361        8903W  Unoccupied  2021-08-13 12:30:39.749530
# 2          3686        7646N     Present  2021-08-13 12:30:39.749530
# 3          6034       13079S  Unoccupied  2021-08-13 12:30:39.749530
# 4          3843        C5566  Unoccupied  2021-08-13 12:30:39.749530
# ...         ...          ...         ...                         ...
# 2565718    5870        C9182  Unoccupied   2021-09-08 23:15:36+10:00
# 2565719    1839        2531S  Unoccupied   2021-09-08 23:15:36+10:00
# 2565720     948         C798     Present   2021-09-08 23:15:36+10:00
# 2565721     956         C826  Unoccupied   2021-09-08 23:15:36+10:00
# 2565722    1471        1775S  Unoccupied   2021-09-08 23:15:36+10:00
#
# [2565723 rows x 4 columns]

# %%
ParkingDF['status'].size
# Out:
# 2565723

# %%
i = 0
while i <= ParkingDF['status'].size:
    ParkingDF['date'][i] = pd.Timestamp(ParkingDF['datetime'][i]).date()

ParkingDF
# Out:
# /Users/jason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-142-a05b5b31af44> in <module>
#       1 i = 0
#       2 while i <= ParkingDF['status'].size:
# ----> 3     ParkingDF['date'][i] = pd.Timestamp(ParkingDF['datetime'][i]).date()
#       4
#       5 ParkingDF
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#    1043
#    1044         if cacher_needs_updating:
# -> 1045             self._maybe_update_cacher()
#    1046
# ...

# %%
import time
a = time.time()
ParkingDF['date'][0] = pd.Timestamp(ParkingDF['datetime'][0]).date()
b = time.time()
b-a
# Out:
# /Users/jason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0.014487028121948242

# %%
ParkingDF['datetime']
# Out:
#          bay_id st_marker_id      status                    datetime  \
# 0          4044        C6126     Present  2021-08-13 12:30:39.749530
# 1          5361        8903W  Unoccupied  2021-08-13 12:30:39.749530
# 2          3686        7646N     Present  2021-08-13 12:30:39.749530
# 3          6034       13079S  Unoccupied  2021-08-13 12:30:39.749530
# 4          3843        C5566  Unoccupied  2021-08-13 12:30:39.749530
# ...         ...          ...         ...                         ...
# 2565718    5870        C9182  Unoccupied   2021-09-08 23:15:36+10:00
# 2565719    1839        2531S  Unoccupied   2021-09-08 23:15:36+10:00
# 2565720     948         C798     Present   2021-09-08 23:15:36+10:00
# 2565721     956         C826  Unoccupied   2021-09-08 23:15:36+10:00
# 2565722    1471        1775S  Unoccupied   2021-09-08 23:15:36+10:00
#
#                date
# 0        2021-08-13
# 1        2021-08-13
# 2        2021-08-13
# 3        2021-08-13
# 4        2021-08-13
# ...

# %%
ParkingDF['datetime'] = pd.to_datetime(ParkingDF['datetime'])

# %%
ParkingDF['datetime'][0:1][:4]
# Out:
# 0    2021-08-13 12:30:39.749530
# Name: datetime, dtype: object

# %%
ParkingDF['datetime1'] = ParkingDF['datetime']
ParkingDF['datetime1'] = ParkingDF['datetime1'].astype('str')
ParkingDF.dtypes
# Out:
# bay_id           int64
# st_marker_id    object
# status          object
# datetime        object
# datetime1       object
# dtype: object

# %%
ParkingDF['datetime1'] = ParkingDF['datetime1'].str[:10]
ParkingDF
# Out:
#          bay_id st_marker_id      status                    datetime  \
# 0          4044        C6126     Present  2021-08-13 12:30:39.749530
# 1          5361        8903W  Unoccupied  2021-08-13 12:30:39.749530
# 2          3686        7646N     Present  2021-08-13 12:30:39.749530
# 3          6034       13079S  Unoccupied  2021-08-13 12:30:39.749530
# 4          3843        C5566  Unoccupied  2021-08-13 12:30:39.749530
# ...         ...          ...         ...                         ...
# 2633415    5857        C9130  Unoccupied   2021-09-09 14:41:07+10:00
# 2633416    8306         657W     Present   2021-09-09 14:41:07+10:00
# 2633417     927         C722     Present   2021-09-09 14:41:07+10:00
# 2633418     949         C802     Present   2021-09-09 14:41:07+10:00
# 2633419    1471        1775S     Present   2021-09-09 14:41:07+10:00
#
#           datetime1
# 0        2021-08-13
# 1        2021-08-13
# 2        2021-08-13
# 3        2021-08-13
# 4        2021-08-13
# ...

# %%
ParkingDF.drop(columns = 'date', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-258-a05c3bc83025> in <module>
# ----> 1 ParkingDF.drop(columns = 'date', inplace = True)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
ParkingDF.rename(columns = {'datetime1':'date',}, inplace = True)
ParkingDF
# Out:
#          bay_id st_marker_id      status                    datetime  \
# 0          4044        C6126     Present  2021-08-13 12:30:39.749530
# 1          5361        8903W  Unoccupied  2021-08-13 12:30:39.749530
# 2          3686        7646N     Present  2021-08-13 12:30:39.749530
# 3          6034       13079S  Unoccupied  2021-08-13 12:30:39.749530
# 4          3843        C5566  Unoccupied  2021-08-13 12:30:39.749530
# ...         ...          ...         ...                         ...
# 2633415    5857        C9130  Unoccupied   2021-09-09 14:41:07+10:00
# 2633416    8306         657W     Present   2021-09-09 14:41:07+10:00
# 2633417     927         C722     Present   2021-09-09 14:41:07+10:00
# 2633418     949         C802     Present   2021-09-09 14:41:07+10:00
# 2633419    1471        1775S     Present   2021-09-09 14:41:07+10:00
#
#                date
# 0        2021-08-13
# 1        2021-08-13
# 2        2021-08-13
# 3        2021-08-13
# 4        2021-08-13
# ...

# %%
ParkingDF['date'].unique().size
# Out:
# 27

# %%
import os

os.getcwd()
os.chdir('/Users/jason/Documents/SIT784/Daily_Files')

# %%
os.getcwd()
# Out:
# '/Users/jason/Documents/SIT784/Daily_Files'

# %%
a = ParkingDF['date'][0]

print(f'{a}.csv')
# Out:
# 2021-08-13.csv

# %%
ParkingDF[ParkingDF['date'] == ParkingDF['date'][3]]
# Out:
#        bay_id st_marker_id      status                    datetime        date
# 0        4044        C6126     Present  2021-08-13 12:30:39.749530  2021-08-13
# 1        5361        8903W  Unoccupied  2021-08-13 12:30:39.749530  2021-08-13
# 2        3686        7646N     Present  2021-08-13 12:30:39.749530  2021-08-13
# 3        6034       13079S  Unoccupied  2021-08-13 12:30:39.749530  2021-08-13
# 4        3843        C5566  Unoccupied  2021-08-13 12:30:39.749530  2021-08-13
# ...       ...          ...         ...                         ...         ...
# 35260    2694       10324E  Unoccupied  2021-08-13 23:53:27.630548  2021-08-13
# 35261    2696       10326E  Unoccupied  2021-08-13 23:53:27.630548  2021-08-13
# 35262    3004        5062E  Unoccupied  2021-08-13 23:53:27.630548  2021-08-13
# 35263    2702       10332E  Unoccupied  2021-08-13 23:53:27.630548  2021-08-13
# 35264    3019        5100E  Unoccupied  2021-08-13 23:53:27.630548  2021-08-13
#
# ...

# %%
ParkingDF
# Out:
#          bay_id st_marker_id      status                    datetime  \
# 0          4044        C6126     Present  2021-08-13 12:30:39.749530
# 1          5361        8903W  Unoccupied  2021-08-13 12:30:39.749530
# 2          3686        7646N     Present  2021-08-13 12:30:39.749530
# 3          6034       13079S  Unoccupied  2021-08-13 12:30:39.749530
# 4          3843        C5566  Unoccupied  2021-08-13 12:30:39.749530
# ...         ...          ...         ...                         ...
# 2565718    5870        C9182  Unoccupied   2021-09-08 23:15:36+10:00
# 2565719    1839        2531S  Unoccupied   2021-09-08 23:15:36+10:00
# 2565720     948         C798     Present   2021-09-08 23:15:36+10:00
# 2565721     956         C826  Unoccupied   2021-09-08 23:15:36+10:00
# 2565722    1471        1775S  Unoccupied   2021-09-08 23:15:36+10:00
#
#                date
# 0        2021-08-13
# 1        2021-08-13
# 2        2021-08-13
# 3        2021-08-13
# 4        2021-08-13
# ...

# %%
i=0 

while i < ParkingDF['date'].unique().size:
    a = ParkingDF['date'].unique()[i]
    b = ParkingDF[ParkingDF['date'] == a]
    b.to_csv(f'{a}.csv', index = False)
    i += 1

# %%
ParkingDF['date'].unique()[2]
# Out:
# '2021-08-15'

# %%
ParkingDF['datetime'][0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-127-c821e9aca946> in <module>
# ----> 1 datetime.datetime(ParkingDF['datetime'][0])
#
# TypeError: an integer is required (got type str)

# %%
print(pd.Timestamp(ParkingDF['datetime'][0]).date())
# Out:
# 2021-08-13

# %%
ParkingDF[ParkingDF['datetime'] == ParkingDF['datetime'][0]]
